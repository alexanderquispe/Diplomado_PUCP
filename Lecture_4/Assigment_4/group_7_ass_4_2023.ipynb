# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.
# 2. Append all this datasets and generate a unique dataframe. This newdataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**

# %% [markdown]
# ### SOLUTIONS

# %% [markdown]
# #### Part 1.

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
os.chdir(r'D:\Users\Usuario\Documents\GitHub\Diplomado_PUCP\Lecture_4\Assigment_4')
#os.getcwd()

# %%
# Set relative and full paths

path = '../../_data/sbs/B_RawData/bancos/'
fullpath = os.path.abspath('../../_data/sbs/B_RawData/bancos/')

# %%
fullpath
# Out:
# 'D:\\Users\\Usuario\\Documents\\GitHub\\Diplomado_PUCP\\_data\\sbs\\B_RawData\\bancos'

# %%
# Import excel files and add a column called "date_info", which takes information from the excel files names.

dfs = []
for file in os.listdir(path):
    date_info = file[file.rindex('table_clean_')+12:]
    date_info = date_info[:-5]
    table_names_path = os.path.join(fullpath, f'{file}')
    data = pd.read_excel(table_names_path)
    data['date_info'] = date_info
    dfs.append(data)

# %%
dfs[25]
# Out:
#                                        Tasa Anual (%) Continental Comercio  \
# 0                                        Corporativos        3.14        -
# 1                                          Descuentos        4.16        -
# 2                             Préstamos hasta 30 días        4.25        -
# 3                           Préstamos de 31 a 90 días        2.93        -
# 4                          Préstamos de 91 a 180 días        3.28        -
# 5                         Préstamos de 181 a 360 días        2.27        -
# 6                         Préstamos a más de 360 días           -        -
# 7                                    Grandes Empresas        7.28     9.38
# 8                                          Descuentos        9.82     7.34
# 9                             Préstamos hasta 30 días        5.29    10.00
# 10                          Préstamos de 31 a 90 días        6.82     8.68
# 11                         Préstamos de 91 a 180 días        6.81        -
# 12                        Préstamos de 181 a 360 días        7.11        -
# 13                        Préstamos a más de 360 días        6.23        -
# 14                                  Medianas Empresas        9.44    12.38
# 15                                         Descuentos       12.91        -
# 16                            Préstamos hasta 30 días        9.49    14.00
# 17                          Préstamos de 31 a 90 días       10.34    11.68
# 18                         Préstamos de 91 a 180 días        9.94    13.00
# 19                        Préstamos de 181 a 360 días        6.43        -
# 20                        Préstamos a más de 360 días        9.40        -
# 21                                  Pequeñas Empresas       14.33    10.91
# 22                                         Descuentos       17.73        -
# 23                            Préstamos hasta 30 días       12.46        -
# 24                          Préstamos de 31 a 90 días       13.27        -
# 25                         Préstamos de 91 a 180 días       15.46    15.00
# 26                        Préstamos de 181 a 360 días       16.45        -
# 27                        Préstamos a más de 360 días       13.22     7.50
# 28                                      Microempresas       26.07        -
# 29                                Tarjetas de Crédito       36.14        -
# 30                                         Descuentos       19.25        -
# 31                              Préstamos Revolventes       18.70        -
# 32               Préstamos a cuota fija hasta 30 días           -        -
# 33             Préstamos a cuota fija de 31 a 90 días       13.92        -
# 34            Préstamos a cuota fija de 91 a 180 días       17.25        -
# 35           Préstamos a cuota fija de 181 a 360 días       18.66        -
# 36           Préstamos a cuota fija a más de 360 días       13.15        -
# 37                                            Consumo       36.32    18.04
# 38                                Tarjetas de Crédito       52.67    22.65
# 39                              Préstamos Revolventes       15.41        -
# 40          Préstamos no Revolventes para automóviles       12.58        -
# 41  Préstamos no Revolventes para libre disponibil...        5.62    12.21
# 42  Préstamos no Revolventes para libre disponibil...       16.30    18.01
# 43                             Créditos pignoraticios           -    66.80
# 44                                       Hipotecarios        7.11     9.71
# 45               Préstamos hipotecarios para vivienda        7.11     9.71
#
#    Crédito Financiero    BIF Scotiabank Citibank Interbank Mibanco    GNB  \
# 0     3.48       7.89   4.72       3.54     7.30      4.61       -   4.57
# 1     4.12       7.40   5.71       4.15        -      5.16       -      -
# 2     3.95       6.00   5.30       3.63     7.71      3.30       -   4.57
# 3     3.57       7.64   4.50       3.76     7.41      4.66       -      -
# 4     2.88      10.00   3.54       3.31     6.97      5.61       -      -
# 5     2.51          -      -       2.20        -      3.12       -      -
# 6     5.17       8.65   7.50       4.80        -         -       -      -
# 7     6.25       7.92   7.23       5.52     5.06      6.34       -   8.02
# 8     4.68       7.97   7.06       5.32        -      7.21       -   9.53
# 9     6.95      11.11   4.14       5.08     5.16         -       -   5.12
# 10    7.39       7.91   7.62       5.25     4.87      5.33       -   7.67
# 11    6.06       7.08   7.16       5.68     5.26      6.95       -   8.05
# 12    5.55       8.68   8.09       6.58        -      6.77       -   9.02
# 13    7.27       7.60   7.83       6.65        -      8.53       -      -
# 14   10.22       8.93   9.07       8.99     6.13      9.50   17.23  10.91
# 15    7.41       8.02   8.58       9.65        -      8.91       -  10.08
# 16   12.54      11.43   7.34       9.84     6.08      7.17       -   5.50
# 17   10.75       8.73   9.40       9.15     5.90      8.58       -  10.70
# 18   11.63       8.32   9.46      10.53     6.40     10.01   20.59  11.27
# 19    8.50      10.01  10.27      11.18     8.80     12.97   17.82  10.00
# 20   10.56      12.78   8.56       8.10        -     12.36   16.59  12.51
# 21   16.14      22.68  11.94      17.58        -     18.53   23.75  15.00
# 22    5.90      13.44  11.85      13.09        -      9.76       -      -
# 23   10.23      37.00      -      16.88        -     15.89   34.36      -
# 24   10.11      25.08  12.33      16.78        -     17.72   31.74  11.55
# 25   21.45      24.92   8.99      13.70        -     16.02   32.67  20.39
# 26    9.21      25.57  10.86      16.23        -     17.56   26.37  17.28
# 27   15.95      22.41  11.66      18.02        -     19.38   22.72  14.89
# 28   23.74      32.86   9.72      20.22        -     19.81   39.28  12.95
# 29   25.46      47.55      -      30.62        -         -       -      -
# 30   11.25          -   9.72      11.47        -      9.16       -      -
# 31       -          -      -          -        -     21.79       -      -
# 32       -          -      -          -        -         -   54.93      -
# 33   17.42      41.41      -      18.28        -     23.87   58.24      -
# 34   21.81      35.40      -      13.96        -     31.50   55.64      -
# 35   29.26      41.54      -      15.34        -     50.00   46.15      -
# 36   15.29      31.76      -      16.94        -     16.92   32.44  12.95
# 37   30.83      43.15  19.43      27.19        -     42.78   52.88  26.43
# 38   36.89      70.88  30.00      30.62        -     46.61       -  36.25
# 39       -          -      -          -        -     19.31       -      -
# 40   11.35      10.21  11.11      10.64        -     11.26       -   8.79
# 41   42.67      35.05  16.46      12.35        -     20.81   65.54  13.00
# 42   15.76      38.83  15.97      17.08        -     20.02   42.60  14.19
# 43       -          -      -          -        -         -       -      -
# 44    7.18       9.66   9.05       7.45        -      7.78   15.32   7.95
# 45    7.18       9.66   9.05       7.45        -      7.78   15.32   7.95
#
#    Falabella Santander Ripley  Azteca    CAT  ICBC  Promedio  date_info
# 0          -      6.35      -       -      -  4.50      3.76  28_2_2018
# 1          -      7.36      -       -      -     -      5.30  28_2_2018
# 2          -      4.63      -       -      -     -      3.81  28_2_2018
# 3          -      4.25      -       -      -  4.50      3.57  28_2_2018
# 4          -      5.21      -       -      -     -      3.83  28_2_2018
# 5          -         -      -       -      -     -      2.42  28_2_2018
# 6          -         -      -       -      -     -      5.65  28_2_2018
# 7          -      7.67      -       -      -     -      6.54  28_2_2018
# 8          -      8.37      -       -      -     -      6.55  28_2_2018
# 9          -      7.15      -       -      -     -      6.29  28_2_2018
# 10         -      6.42      -       -      -     -      6.62  28_2_2018
# 11         -      7.01      -       -      -     -      6.37  28_2_2018
# 12         -      7.84      -       -      -     -      6.69  28_2_2018
# 13         -      8.05      -       -      -     -      7.03  28_2_2018
# 14         -      7.93      -       -      -     -      9.61  28_2_2018
# 15         -      7.35      -       -      -     -      9.19  28_2_2018
# 16         -         -      -       -      -     -     10.42  28_2_2018
# 17         -      8.25      -       -      -     -      9.97  28_2_2018
# 18         -      7.89      -       -      -     -     10.38  28_2_2018
# 19         -      8.70      -       -      -     -      7.24  28_2_2018
# 20         -         -      -       -      -     -      9.58  28_2_2018
# 21         -         -      -       -      -     -     19.77  28_2_2018
# 22         -         -      -       -      -     -     10.26  28_2_2018
# 23         -         -      -       -      -     -     12.12  28_2_2018
# 24         -         -      -       -      -     -     14.83  28_2_2018
# 25         -         -      -       -      -     -     20.20  28_2_2018
# 26         -         -      -       -      -     -     23.73  28_2_2018
# 27         -         -      -       -      -     -     19.73  28_2_2018
# 28         -         -      -       -      -     -     36.31  28_2_2018
# 29         -         -      -       -      -     -     26.67  28_2_2018
# 30         -         -      -       -      -     -     11.69  28_2_2018
# 31         -         -      -       -      -     -     21.49  28_2_2018
# 32         -         -      -       -      -     -     54.93  28_2_2018
# 33         -         -      -       -      -     -     53.23  28_2_2018
# 34         -         -      -       -      -     -     49.66  28_2_2018
# 35         -         -      -       -      -     -     45.88  28_2_2018
# 36         -         -      -       -      -     -     31.12  28_2_2018
# 37     71.11         -  65.70  143.92  81.62     -     45.59  28_2_2018
# 38     71.25         -  73.95  151.29  81.62     -     52.99  28_2_2018
# 39         -         -      -       -      -     -     15.57  28_2_2018
# 40     10.41         -      -       -      -     -     11.84  28_2_2018
# 41     13.10         -  44.50  150.91      -     -     53.02  28_2_2018
# 42     12.67         -  29.27  138.46      -     -     20.94  28_2_2018
# 43         -         -      -       -      -     -     66.80  28_2_2018
# 44         -         -      -       -      -     -      7.60  28_2_2018
# 45         -         -      -       -      -     -      7.60  28_2_2018

# %% [markdown]
# #### Part 2.

# %%
# Loop to homogenize the excel files

for i, df in enumerate(dfs):
    if dfs[i].shape[0] < 25:
        dfs[i] = dfs[i].T
        new_colnames = dfs[i].iloc[0]
        dfs[i] = dfs[i][1:]
        dfs[i].columns = new_colnames
        dfs[i] = dfs[i].reset_index()
        dfs[i].columns.values[0] = "first_col"
        dfs[i].columns.values[1] = "second_col"
        dfs[i].columns.values[2] = "third_col"
        dfs[i].columns.values[-1] = "last_col"
        dfs[i][dfs[i]['last_col'].isnull()]=dfs[i][dfs[i]['last_col'].isnull()].shift(axis=1)
        dfs[i] = dfs[i].shift(-1, axis=1).dropna(axis=1)
        dfs[i]['catamaran'] = dfs[i].iloc[:,-1:]
        if dfs[i].shape[1] > 1: 
            dfs[i]['date_info'] = dfs[i]['catamaran'].iloc[len(dfs[i].index) - 1]
            dfs[i]['Tasa Anual (%)'] = dfs[i]['first_col'] + dfs[i]['third_col']
            dfs[i] = dfs[i].drop(['first_col', 'second_col', 'third_col', 'catamaran'], axis=1)
            dfs[i] = dfs[i].iloc[:-1 , :]
            dfs[i].index.names = ['index']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7020\522756400.py in <module>
#      14         dfs[i][dfs[i]['last_col'].isnull()]=dfs[i][dfs[i]['last_col'].isnull()].shift(axis=1)
#      15         dfs[i] = dfs[i].shift(-1, axis=1).dropna(axis=1)
# ---> 16         dfs[i]['catamaran'] = dfs[i].iloc[:,-1:]
#      17         if dfs[i].shape[1] > 1:
#      18             dfs[i]['date_info'] = dfs[i]['catamaran'].iloc[len(dfs[i].index) - 1]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3965             self._setitem_array(key, value)
#    3966         elif isinstance(value, DataFrame):
# -> 3967             self._set_item_frame_value(key, value)
#    3968         elif (
#    3969             is_list_like(value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    4120
#    4121         if len(value.columns) != 1:
# -> 4122             raise ValueError(
#    4123                 "Cannot set a DataFrame with multiple columns to the single "
#    4124                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column catamaran

# %%
# Append vertically the excel files

data = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7020\3342129987.py in <module>
#       1 # Append vertically the excel files
#       2
# ----> 3 data = pd.concat(dfs)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379     )
#     380
# --> 381     return op.get_result()
#     382
#     383
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     610                     obj_labels = obj.axes[1 - ax]
#     611                     if not new_labels.equals(obj_labels):
# --> 612                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     613
#     614                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3903
#    3904         if not self._index_as_unique:
# -> 3905             raise InvalidIndexError(self._requires_unique_msg)
#    3906
#    3907         if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# Order columns

data = data.reindex(columns =['Tasa Anual (%)', 'date_info', 'TRABAJO',
                              'BBVA', 'BANCO DE COMERCIO', 'BANCO DE CREDITO',
                              'BANCO PICHINCHA', 'BANBIF', 'STANDARD CHARTERED',
                              'BANCO SUDAMERICANO', 'WIESE SUDAMERIS', 'BANK BOSTON',
                              'BNP PARIBAS EL', 'CITIBANK DEL PERU','INTERBANK', 
                              'MIBANCO','SCOTIABANK PERU', 'HSBC', 'BANCO FALABELLA', 
                              'SANTANDER PERU','BANCO RIPLEY', 'ALFIN BANCO', 
                              'DEUTSCHE BANK PERU','Promedio del Sistema', 'Comercio', 
                              'Crédito', 'Pichincha', 'BIF','Scotiabank', 'Citibank', 
                              'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 
                              'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio',
                              'Continental', 'Financiero', 'Banco GNB', 'Deutsche', 
                              'Cencosud', 'CAT', 'Alfin', 'B SANTANDER CENTRAL', 'Azteca  *',
                              'HSBC(*)', 'Financiero  *', 'BCI'])

# %%
data

# %%
#What are the top 5 banks each year with the highest interest rate at Préstamos hipotecarios para vivienda

# %% [markdown]
# ### Part 3.

# %%
#DEBEMOS PERCATARNOS que hay datos de múltiples años, será necesario ubicar el dato correspondiente a cada ano y luego generr el ranking para las tres variables requeridas

# %%
df = pd.read_excel(r'E:\UNIVERSIDADES\DIPLOMATURA_QLAB\Fundamentos_Python\Data\final_data.xlsx')
df.head()
# Out:
#                        Tasa Anual (%)  date_info TRABAJO    BBVA  \
# 0           Avances en Cta.Corriente-  26_2_2004   38.92       -
# 1                         Sobregiros-  26_2_2004   48.79  138.18
# 2  Dsctos. y préstamos hasta 30 días-  26_2_2004    8.19   47.46
# 3   Dsctos. y préstamos 31 - 90 días-  26_2_2004    5.94   21.61
# 4  Dsctos. y préstamos 91 - 180 días-  26_2_2004   10.00   19.71
#
#   BANCO DE COMERCIO BANCO DE CREDITO BANCO PICHINCHA BANBIF  \
# 0             73.34                -           39.08      -
# 1             89.00                -           68.30  25.00
# 2              4.62            15.87           14.43      -
# 3              7.19            15.71           10.91      -
# 4              5.34            15.82           10.71      -
#
#   STANDARD CHARTERED BANCO SUDAMERICANO  ... Banco GNB Deutsche Cencosud  CAT  \
# 0              31.73                  -  ...       NaN      NaN      NaN  NaN
# 1              58.10                  -  ...       NaN      NaN      NaN  NaN
# 2              30.68              39.03  ...       NaN      NaN      NaN  NaN
# 3              11.90              10.58  ...       NaN      NaN      NaN  NaN
# 4               9.98               7.56  ...       NaN      NaN      NaN  NaN
#
#   Alfin B SANTANDER CENTRAL Azteca  * HSBC(*) Financiero  *  BCI
# 0   NaN                 NaN       NaN     NaN           NaN  NaN
# 1   NaN                 NaN       NaN     NaN           NaN  NaN
# 2   NaN                 NaN       NaN     NaN           NaN  NaN
# 3   NaN                 NaN       NaN     NaN           NaN  NaN
# 4   NaN                 NaN       NaN     NaN           NaN  NaN
#
# [5 rows x 52 columns]

# %%
index = df.index
print(index)
# Out:
# RangeIndex(start=0, stop=9154, step=1)

# %%
df.iloc[:,0:2]
# Out:
#                                          Tasa Anual (%)  date_info
# 0                             Avances en Cta.Corriente-  26_2_2004
# 1                                           Sobregiros-  26_2_2004
# 2                    Dsctos. y préstamos hasta 30 días-  26_2_2004
# 3                     Dsctos. y préstamos 31 - 90 días-  26_2_2004
# 4                    Dsctos. y préstamos 91 - 180 días-  26_2_2004
# ...                                                 ...        ...
# 9149  Préstamos no Revolventes para libre disponibil...  31_8_2022
# 9150  Préstamos no Revolventes para libre disponibil...  31_8_2022
# 9151                             Créditos pignoraticios  31_8_2022
# 9152                                       Hipotecarios  31_8_2022
# 9153               Préstamos hipotecarios para vivienda  31_8_2022
#
# [9154 rows x 2 columns]

# %%
type(df.iloc[9153])
# Out:
# pandas.core.series.Series

# %%
serie_d = df.iloc[9153]
df2 = serie_d.to_frame() #convertimos la serie a dataframe
df2.drop(['Tasa Anual (%)','date_info','TRABAJO'],axis=0,inplace=True) #eliminamos las primeras filas que no contienen información de los bancos
df2.rename(columns = {9153:'Tasa anual: Préstamos hipotecarios para vivienda'}, inplace = True) #cambiamos el nombre de la fila que tiene la información de tasas de interés
df2= df2.reset_index() #generamos un nuevo índice 
df2.rename(columns = {'index':'Banco'}, inplace = True) #y cambiamos la denominación de la nueva fila con nombres de los bancos
df2['Tasa anual: Préstamos hipotecarios para vivienda'] = df2['Tasa anual: Préstamos hipotecarios para vivienda'].replace(['-','s.i.'], 0) #reemplazamos la información que es texto con valores nulos
df2['Tasa anual: Préstamos hipotecarios para vivienda'] = df2['Tasa anual: Préstamos hipotecarios para vivienda'].fillna(0) # y convertimos los missings en valores nulos
df2['Tasa anual: Préstamos hipotecarios para vivienda'] = df2['Tasa anual: Préstamos hipotecarios para vivienda'].astype(float) #convertimos la columna de tasas a formato float
df2 = df2.sort_values(by="Tasa anual: Préstamos hipotecarios para vivienda",ascending=False) #ordenamos el dataframe ascendentemente
df2
# Out:
#                    Banco  Tasa anual: Préstamos hipotecarios para vivienda
# 28               Mibanco                                             15.54
# 0                   BBVA                                              9.28
# 22               Crédito                                              9.27
# 24                   BIF                                              9.23
# 36              Promedio                                              9.13
# 21              Comercio                                              9.08
# 27             Interbank                                              8.73
# 23             Pichincha                                              8.72
# 25            Scotiabank                                              8.61
# 29                   GNB                                              8.03
# 30             Falabella                                              0.00
# 31             Santander                                              0.00
# 32                Ripley                                              0.00
# 33                Azteca                                              0.00
# 34                  ICBC                                              0.00
# 35         Bank of China                                              0.00
# 4                 BANBIF                                              0.00
# 38            Financiero                                              0.00
# 39             Banco GNB                                              0.00
# 40              Deutsche                                              0.00
# 41              Cencosud                                              0.00
# 42                   CAT                                              0.00
# 43                 Alfin                                              0.00
# 44   B SANTANDER CENTRAL                                              0.00
# 45             Azteca  *                                              0.00
# 46               HSBC(*)                                              0.00
# 47         Financiero  *                                              0.00
# 37           Continental                                              0.00
# 26              Citibank                                              0.00
# 2       BANCO DE CREDITO                                              0.00
# 5     STANDARD CHARTERED                                              0.00
# 6     BANCO SUDAMERICANO                                              0.00
# 7        WIESE SUDAMERIS                                              0.00
# 8            BANK BOSTON                                              0.00
# 9         BNP PARIBAS EL                                              0.00
# 10     CITIBANK DEL PERU                                              0.00
# 11             INTERBANK                                              0.00
# 12               MIBANCO                                              0.00
# 13       SCOTIABANK PERU                                              0.00
# 14                  HSBC                                              0.00
# 15       BANCO FALABELLA                                              0.00
# 16        SANTANDER PERU                                              0.00
# 17          BANCO RIPLEY                                              0.00
# 18           ALFIN BANCO                                              0.00
# 19    DEUTSCHE BANK PERU                                              0.00
# 20  Promedio del Sistema                                              0.00
# 3        BANCO PICHINCHA                                              0.00
# 1      BANCO DE COMERCIO                                              0.00
# 48                   BCI                                              0.00

# %%
top5_hipo= df2.sort_values(by="Tasa anual: Préstamos hipotecarios para vivienda",ascending=False).reset_index(drop=True).loc[0:4]
top5_hipo
# Out:
#       Banco  Tasa anual: Préstamos hipotecarios para vivienda
# 0   Mibanco                                             15.54
# 1      BBVA                                              9.28
# 2   Crédito                                              9.27
# 3       BIF                                              9.23
# 4  Promedio                                              9.13

# %%
df3 = df.set_index('Tasa Anual (%)')
df3
# Out:
#                                                     date_info TRABAJO    BBVA  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                           26_2_2004   38.92       -
# Sobregiros-                                         26_2_2004   48.79  138.18
# Dsctos. y préstamos hasta 30 días-                  26_2_2004    8.19   47.46
# Dsctos. y préstamos 31 - 90 días-                   26_2_2004    5.94   21.61
# Dsctos. y préstamos 91 - 180 días-                  26_2_2004   10.00   19.71
# ...                                                       ...     ...     ...
# Préstamos no Revolventes para libre disponibili...  31_8_2022     NaN   22.13
# Préstamos no Revolventes para libre disponibili...  31_8_2022     NaN   18.22
# Créditos pignoraticios                              31_8_2022     NaN       -
# Hipotecarios                                        31_8_2022     NaN    9.28
# Préstamos hipotecarios para vivienda                31_8_2022     NaN    9.28
#
#                                                    BANCO DE COMERCIO  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                      73.34
# Sobregiros-                                                    89.00
# Dsctos. y préstamos hasta 30 días-                              4.62
# Dsctos. y préstamos 31 - 90 días-                               7.19
# Dsctos. y préstamos 91 - 180 días-                              5.34
# ...                                                              ...
# Préstamos no Revolventes para libre disponibili...               NaN
# Préstamos no Revolventes para libre disponibili...               NaN
# Créditos pignoraticios                                           NaN
# Hipotecarios                                                     NaN
# Préstamos hipotecarios para vivienda                             NaN
#
#                                                    BANCO DE CREDITO  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                         -
# Sobregiros-                                                       -
# Dsctos. y préstamos hasta 30 días-                            15.87
# Dsctos. y préstamos 31 - 90 días-                             15.71
# Dsctos. y préstamos 91 - 180 días-                            15.82
# ...                                                             ...
# Préstamos no Revolventes para libre disponibili...              NaN
# Préstamos no Revolventes para libre disponibili...              NaN
# Créditos pignoraticios                                          NaN
# Hipotecarios                                                    NaN
# Préstamos hipotecarios para vivienda                            NaN
#
#                                                    BANCO PICHINCHA BANBIF  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                    39.08      -
# Sobregiros-                                                  68.30  25.00
# Dsctos. y préstamos hasta 30 días-                           14.43      -
# Dsctos. y préstamos 31 - 90 días-                            10.91      -
# Dsctos. y préstamos 91 - 180 días-                           10.71      -
# ...                                                            ...    ...
# Préstamos no Revolventes para libre disponibili...             NaN    NaN
# Préstamos no Revolventes para libre disponibili...             NaN    NaN
# Créditos pignoraticios                                         NaN    NaN
# Hipotecarios                                                   NaN    NaN
# Préstamos hipotecarios para vivienda                           NaN    NaN
#
#                                                    STANDARD CHARTERED  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                       31.73
# Sobregiros-                                                     58.10
# Dsctos. y préstamos hasta 30 días-                              30.68
# Dsctos. y préstamos 31 - 90 días-                               11.90
# Dsctos. y préstamos 91 - 180 días-                               9.98
# ...                                                               ...
# Préstamos no Revolventes para libre disponibili...                NaN
# Préstamos no Revolventes para libre disponibili...                NaN
# Créditos pignoraticios                                            NaN
# Hipotecarios                                                      NaN
# Préstamos hipotecarios para vivienda                              NaN
#
#                                                    BANCO SUDAMERICANO  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                           -
# Sobregiros-                                                         -
# Dsctos. y préstamos hasta 30 días-                              39.03
# Dsctos. y préstamos 31 - 90 días-                               10.58
# Dsctos. y préstamos 91 - 180 días-                               7.56
# ...                                                               ...
# Préstamos no Revolventes para libre disponibili...                NaN
# Préstamos no Revolventes para libre disponibili...                NaN
# Créditos pignoraticios                                            NaN
# Hipotecarios                                                      NaN
# Préstamos hipotecarios para vivienda                              NaN
#
#                                                    WIESE SUDAMERIS  ...  \
# Tasa Anual (%)                                                      ...
# Avances en Cta.Corriente-                                    82.12  ...
# Sobregiros-                                                  82.12  ...
# Dsctos. y préstamos hasta 30 días-                            3.19  ...
# Dsctos. y préstamos 31 - 90 días-                             3.10  ...
# Dsctos. y préstamos 91 - 180 días-                            8.34  ...
# ...                                                            ...  ...
# Préstamos no Revolventes para libre disponibili...             NaN  ...
# Préstamos no Revolventes para libre disponibili...             NaN  ...
# Créditos pignoraticios                                         NaN  ...
# Hipotecarios                                                   NaN  ...
# Préstamos hipotecarios para vivienda                           NaN  ...
#
#                                                    Banco GNB Deutsche  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                NaN      NaN
# Sobregiros-                                              NaN      NaN
# Dsctos. y préstamos hasta 30 días-                       NaN      NaN
# Dsctos. y préstamos 31 - 90 días-                        NaN      NaN
# Dsctos. y préstamos 91 - 180 días-                       NaN      NaN
# ...                                                      ...      ...
# Préstamos no Revolventes para libre disponibili...       NaN      NaN
# Préstamos no Revolventes para libre disponibili...       NaN      NaN
# Créditos pignoraticios                                   NaN      NaN
# Hipotecarios                                             NaN      NaN
# Préstamos hipotecarios para vivienda                     NaN      NaN
#
#                                                    Cencosud  CAT  Alfin  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                               NaN  NaN    NaN
# Sobregiros-                                             NaN  NaN    NaN
# Dsctos. y préstamos hasta 30 días-                      NaN  NaN    NaN
# Dsctos. y préstamos 31 - 90 días-                       NaN  NaN    NaN
# Dsctos. y préstamos 91 - 180 días-                      NaN  NaN    NaN
# ...                                                     ...  ...    ...
# Préstamos no Revolventes para libre disponibili...      NaN  NaN  74.42
# Préstamos no Revolventes para libre disponibili...      NaN  NaN  69.00
# Créditos pignoraticios                                  NaN  NaN      -
# Hipotecarios                                            NaN  NaN      -
# Préstamos hipotecarios para vivienda                    NaN  NaN      -
#
#                                                    B SANTANDER CENTRAL  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                          NaN
# Sobregiros-                                                        NaN
# Dsctos. y préstamos hasta 30 días-                                 NaN
# Dsctos. y préstamos 31 - 90 días-                                  NaN
# Dsctos. y préstamos 91 - 180 días-                                 NaN
# ...                                                                ...
# Préstamos no Revolventes para libre disponibili...                 NaN
# Préstamos no Revolventes para libre disponibili...                 NaN
# Créditos pignoraticios                                             NaN
# Hipotecarios                                                       NaN
# Préstamos hipotecarios para vivienda                               NaN
#
#                                                    Azteca  * HSBC(*)  \
# Tasa Anual (%)
# Avances en Cta.Corriente-                                NaN     NaN
# Sobregiros-                                              NaN     NaN
# Dsctos. y préstamos hasta 30 días-                       NaN     NaN
# Dsctos. y préstamos 31 - 90 días-                        NaN     NaN
# Dsctos. y préstamos 91 - 180 días-                       NaN     NaN
# ...                                                      ...     ...
# Préstamos no Revolventes para libre disponibili...       NaN     NaN
# Préstamos no Revolventes para libre disponibili...       NaN     NaN
# Créditos pignoraticios                                   NaN     NaN
# Hipotecarios                                             NaN     NaN
# Préstamos hipotecarios para vivienda                     NaN     NaN
#
#                                                    Financiero  *  BCI
# Tasa Anual (%)
# Avances en Cta.Corriente-                                    NaN  NaN
# Sobregiros-                                                  NaN  NaN
# Dsctos. y préstamos hasta 30 días-                           NaN  NaN
# Dsctos. y préstamos 31 - 90 días-                            NaN  NaN
# Dsctos. y préstamos 91 - 180 días-                           NaN  NaN
# ...                                                          ...  ...
# Préstamos no Revolventes para libre disponibili...           NaN    -
# Préstamos no Revolventes para libre disponibili...           NaN    -
# Créditos pignoraticios                                       NaN    -
# Hipotecarios                                                 NaN    -
# Préstamos hipotecarios para vivienda                         NaN    -
#
# [9154 rows x 51 columns]

# %%
print(df3[300:400].index)
# Out:
# Index(['Medianas Empresas', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Pequeñas Empresas', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Microempresas', 'Tarjetas de Crédito', 'Descuentos',
#        'Préstamos Revolventes', 'Préstamos a cuota fija hasta 30 días',
#        'Préstamos a cuota fija de 31 a 90 días',
#        'Préstamos a cuota fija de 91 a 180 días',
#        'Préstamos a cuota fija de 181 a 360 días',
#        'Préstamos a cuota fija a más de 360 días', 'Consumo',
#        'Tarjetas de Crédito', 'Préstamos Revolventes',
#        'Préstamos no Revolventes para automóviles',
#        'Préstamos no Revolventes para libre disponibilidad hasta 360 días',
#        'Préstamos no Revolventes para libre disponibilidad a más de 360 días',
#        'Créditos pignoraticios', 'Hipotecarios',
#        'Préstamos hipotecarios para vivienda',
#        'Nota: Cuadro elaborado sobre la base de la información del Reporte N°6 remitida diariamente por las empresas. Las definiciones de los tipos de crédito se encuentran en el Reglamento para la Evaluación y Clasificación del Deudor y la Exigencia de Provisiones, aprobado mediante Resolución SBS N° 11356-2008 (Ver definiciones).',
#        'Nota: Cuadro elaborado sobre la base de la información del Reporte N°6 remitida diariamente por las empresas. Las definiciones de los tipos de crédito se encuentran en el Reglamento para la Evaluación y Clasificación del Deudor y la Exigencia de Provisiones, aprobado mediante Resolución SBS N° 11356-2008 (Ver definiciones).',
#        'Corporativos', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Grandes Empresas', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Medianas Empresas', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Pequeñas Empresas', 'Descuentos', 'Préstamos hasta 30 días',
#        'Préstamos de 31 a 90 días', 'Préstamos de 91 a 180 días',
#        'Préstamos de 181 a 360 días', 'Préstamos a más de 360 días',
#        'Microempresas', 'Tarjetas de Crédito', 'Descuentos',
#        'Préstamos Revolventes', 'Préstamos a cuota fija hasta 30 días',
#        'Préstamos a cuota fija de 31 a 90 días',
#        'Préstamos a cuota fija de 91 a 180 días',
#        'Préstamos a cuota fija de 181 a 360 días',
#        'Préstamos a cuota fija a más de 360 días', 'Consumo',
#        'Tarjetas de Crédito', 'Préstamos Revolventes',
#        'Préstamos no Revolventes para automóviles',
#        'Préstamos no Revolventes para libre disponibilidad hasta 360 días',
#        'Préstamos no Revolventes para libre disponibilidad a más de 360 días',
#        'Créditos pignoraticios', 'Hipotecarios',
#        'Préstamos hipotecarios para vivienda', 'Corporativos', 'Descuentos',
#        'Préstamos hasta 30 días', 'Préstamos de 31 a 90 días',
#        'Préstamos de 91 a 180 días', 'Préstamos de 181 a 360 días',
#        'Préstamos a más de 360 días', 'Grandes Empresas', 'Descuentos',
#        'Préstamos hasta 30 días', 'Préstamos de 31 a 90 días',
#        'Préstamos de 91 a 180 días', 'Préstamos de 181 a 360 días',
#        'Préstamos a más de 360 días', 'Medianas Empresas', 'Descuentos',
#        'Préstamos hasta 30 días', 'Préstamos de 31 a 90 días',
#        'Préstamos de 91 a 180 días', 'Préstamos de 181 a 360 días'],
#       dtype='object', name='Tasa Anual (%)')

# %%
df3.loc["Consumo"]
# Out:
#                 date_info TRABAJO   BBVA BANCO DE COMERCIO BANCO DE CREDITO  \
# Tasa Anual (%)
# Consumo         26_2_2021     NaN  35.00               NaN              NaN
# Consumo         27_2_2015     NaN    NaN               NaN              NaN
# Consumo         27_3_2013     NaN    NaN               NaN              NaN
# Consumo         27_7_2011     NaN    NaN               NaN              NaN
# Consumo         27_7_2016     NaN    NaN               NaN              NaN
# ...                   ...     ...    ...               ...              ...
# Consumo         31_8_2016     NaN    NaN               NaN              NaN
# Consumo         31_8_2017     NaN    NaN               NaN              NaN
# Consumo         31_8_2020     NaN  37.93               NaN              NaN
# Consumo         31_8_2021     NaN  33.78               NaN              NaN
# Consumo         31_8_2022     NaN  39.06               NaN              NaN
#
#                BANCO PICHINCHA BANBIF STANDARD CHARTERED BANCO SUDAMERICANO  \
# Tasa Anual (%)
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# ...                        ...    ...                ...                ...
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
# Consumo                    NaN    NaN                NaN                NaN
#
#                WIESE SUDAMERIS  ... Banco GNB Deutsche Cencosud    CAT  Alfin  \
# Tasa Anual (%)                  ...
# Consumo                    NaN  ...       NaN      NaN      NaN    NaN    NaN
# Consumo                    NaN  ...     31.16        -    83.53    NaN    NaN
# Consumo                    NaN  ...       NaN        -    76.41    NaN    NaN
# Consumo                    NaN  ...       NaN        -      NaN    NaN    NaN
# Consumo                    NaN  ...       NaN      NaN      NaN  81.78    NaN
# ...                        ...  ...       ...      ...      ...    ...    ...
# Consumo                    NaN  ...       NaN      NaN      NaN  86.86    NaN
# Consumo                    NaN  ...       NaN      NaN      NaN  78.06    NaN
# Consumo                    NaN  ...       NaN      NaN      NaN    NaN    NaN
# Consumo                    NaN  ...       NaN      NaN      NaN    NaN    NaN
# Consumo                    NaN  ...       NaN      NaN      NaN    NaN  69.00
#
#                B SANTANDER CENTRAL Azteca  * HSBC(*) Financiero  *  BCI
# Tasa Anual (%)
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# ...                            ...       ...     ...           ...  ...
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN  NaN
# Consumo                        NaN       NaN     NaN           NaN    -
#
# [145 rows x 51 columns]
