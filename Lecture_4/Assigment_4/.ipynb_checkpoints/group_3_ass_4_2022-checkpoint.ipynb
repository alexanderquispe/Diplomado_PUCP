# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.
# 2. Append all this datasets and generate a unique dataframe. This new dataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**

# %%
import os
import pandas as pd
import numpy as np
import re
import calendar

# %%
pwd
# Out:
# 'C:\\Users\\DORKAS\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_4\\Assigment_4'

# %%
# Directory 
os.chdir(r"../../_data/sbs/B_RawData/bancos")
os.listdir()
# Out:
# ['output',
#  'table_clean_26_2_2004.xlsx',
#  'table_clean_26_2_2010.xlsx',
#  'table_clean_26_2_2021.xlsx',
#  'table_clean_27_2_2009.xlsx',
#  'table_clean_27_2_2015.xlsx',
#  'table_clean_27_3_2013.xlsx',
#  'table_clean_27_7_2005.xlsx',
#  'table_clean_27_7_2010.xlsx',
#  'table_clean_27_7_2011.xlsx',
#  'table_clean_27_7_2016.xlsx',
#  'table_clean_27_7_2022.xlsx',
#  'table_clean_27_8_2019.xlsx',
#  'table_clean_28_10_2011.xlsx',
#  'table_clean_28_11_2003.xlsx',
#  'table_clean_28_11_2008.xlsx',
#  'table_clean_28_11_2014.xlsx',
#  'table_clean_28_12_2012.xlsx',
#  'table_clean_28_2_2003.xlsx',
#  'table_clean_28_2_2005.xlsx',
#  'table_clean_28_2_2006.xlsx',
#  'table_clean_28_2_2007.xlsx',
#  'table_clean_28_2_2011.xlsx',
#  'table_clean_28_2_2013.xlsx',
#  'table_clean_28_2_2014.xlsx',
#  'table_clean_28_2_2017.xlsx',
#  'table_clean_28_2_2018.xlsx',
#  'table_clean_28_2_2019.xlsx',
#  'table_clean_28_2_2020.xlsx',
#  'table_clean_28_2_2022.xlsx',
#  'table_clean_28_3_2018.xlsx',
#  'table_clean_28_3_2019.xlsx',
#  'table_clean_28_4_2006.xlsx',
#  'table_clean_28_4_2017.xlsx',
#  'table_clean_28_6_2007.xlsx',
#  'table_clean_28_6_2012.xlsx',
#  'table_clean_28_6_2013.xlsx',
#  'table_clean_28_6_2017.xlsx',
#  'table_clean_28_6_2018.xlsx',
#  'table_clean_28_6_2019.xlsx',
#  'table_clean_28_9_2007.xlsx',
#  'table_clean_28_9_2012.xlsx',
#  'table_clean_28_9_2018.xlsx',
#  'table_clean_29_10_2004.xlsx',
#  'table_clean_29_10_2010.xlsx',
#  'table_clean_29_10_2021.xlsx',
#  'table_clean_29_11_2002.xlsx',
#  'table_clean_29_11_2005.xlsx',
#  'table_clean_29_11_2013.xlsx',
#  'table_clean_29_11_2019.xlsx',
#  'table_clean_29_12_2006.xlsx',
#  'table_clean_29_12_2017.xlsx',
#  'table_clean_29_1_2004.xlsx',
#  'table_clean_29_1_2010.xlsx',
#  'table_clean_29_1_2016.xlsx',
#  'table_clean_29_1_2021.xlsx',
#  'table_clean_29_2_2008.xlsx',
#  'table_clean_29_2_2012.xlsx',
#  'table_clean_29_2_2016.xlsx',
#  'table_clean_29_4_2005.xlsx',
#  'table_clean_29_4_2011.xlsx',
#  'table_clean_29_4_2016.xlsx',
#  'table_clean_29_4_2022.xlsx',
#  'table_clean_29_5_2009.xlsx',
#  'table_clean_29_5_2015.xlsx',
#  'table_clean_29_5_2020.xlsx',
#  'table_clean_29_8_2003.xlsx',
#  'table_clean_29_8_2008.xlsx',
#  'table_clean_29_8_2012.xlsx',
#  'table_clean_29_8_2013.xlsx',
#  'table_clean_29_8_2014.xlsx',
#  'table_clean_29_8_2018.xlsx',
#  'table_clean_29_9_2006.xlsx',
#  'table_clean_29_9_2017.xlsx',
#  'table_clean_30_10_2009.xlsx',
#  'table_clean_30_10_2015.xlsx',
#  'table_clean_30_10_2019.xlsx',
#  'table_clean_30_10_2020.xlsx',
#  'table_clean_30_11_2004.xlsx',
#  'table_clean_30_11_2006.xlsx',
#  'table_clean_30_11_2007.xlsx',
#  'table_clean_30_11_2009.xlsx',
#  'table_clean_30_11_2010.xlsx',
#  'table_clean_30_11_2011.xlsx',
#  'table_clean_30_11_2012.xlsx',
#  'table_clean_30_11_2015.xlsx',
#  'table_clean_30_11_2016.xlsx',
#  'table_clean_30_11_2017.xlsx',
#  'table_clean_30_11_2018.xlsx',
#  'table_clean_30_11_2020.xlsx',
#  'table_clean_30_11_2021.xlsx',
#  'table_clean_30_12_2005.xlsx',
#  'table_clean_30_12_2008.xlsx',
#  'table_clean_30_12_2009.xlsx',
#  'table_clean_30_12_2011.xlsx',
#  'table_clean_30_12_2013.xlsx',
#  'table_clean_30_12_2016.xlsx',
#  'table_clean_30_1_2009.xlsx',
#  'table_clean_30_1_2015.xlsx',
#  'table_clean_30_3_2007.xlsx',
#  'table_clean_30_3_2012.xlsx',
#  'table_clean_30_4_2003.xlsx',
#  'table_clean_30_4_2004.xlsx',
#  'table_clean_30_4_2007.xlsx',
#  'table_clean_30_4_2008.xlsx',
#  'table_clean_30_4_2009.xlsx',
#  'table_clean_30_4_2010.xlsx',
#  'table_clean_30_4_2012.xlsx',
#  'table_clean_30_4_2013.xlsx',
#  'table_clean_30_4_2014.xlsx',
#  'table_clean_30_4_2015.xlsx',
#  'table_clean_30_4_2018.xlsx',
#  'table_clean_30_4_2019.xlsx',
#  'table_clean_30_4_2020.xlsx',
#  'table_clean_30_4_2021.xlsx',
#  'table_clean_30_5_2003.xlsx',
#  'table_clean_30_5_2008.xlsx',
#  'table_clean_30_5_2014.xlsx',
#  'table_clean_30_6_2003.xlsx',
#  'table_clean_30_6_2004.xlsx',
#  'table_clean_30_6_2005.xlsx',
#  'table_clean_30_6_2006.xlsx',
#  'table_clean_30_6_2008.xlsx',
#  'table_clean_30_6_2009.xlsx',
#  'table_clean_30_6_2010.xlsx',
#  'table_clean_30_6_2011.xlsx',
#  'table_clean_30_6_2014.xlsx',
#  'table_clean_30_6_2015.xlsx',
#  'table_clean_30_6_2016.xlsx',
#  'table_clean_30_6_2020.xlsx',
#  'table_clean_30_6_2021.xlsx',
#  'table_clean_30_6_2022.xlsx',
#  'table_clean_30_7_2004.xlsx',
#  'table_clean_30_7_2021.xlsx',
#  'table_clean_30_9_2002.xlsx',
#  'table_clean_30_9_2003.xlsx',
#  'table_clean_30_9_2004.xlsx',
#  'table_clean_30_9_2005.xlsx',
#  'table_clean_30_9_2008.xlsx',
#  'table_clean_30_9_2009.xlsx',
#  'table_clean_30_9_2010.xlsx',
#  'table_clean_30_9_2011.xlsx',
#  'table_clean_30_9_2013.xlsx',
#  'table_clean_30_9_2014.xlsx',
#  'table_clean_30_9_2015.xlsx',
#  'table_clean_30_9_2016.xlsx',
#  'table_clean_30_9_2019.xlsx',
#  'table_clean_30_9_2020.xlsx',
#  'table_clean_30_9_2021.xlsx',
#  'table_clean_31_10_2002.xlsx',
#  'table_clean_31_10_2003.xlsx',
#  'table_clean_31_10_2005.xlsx',
#  'table_clean_31_10_2006.xlsx',
#  'table_clean_31_10_2007.xlsx',
#  'table_clean_31_10_2008.xlsx',
#  'table_clean_31_10_2012.xlsx',
#  'table_clean_31_10_2013.xlsx',
#  'table_clean_31_10_2014.xlsx',
#  'table_clean_31_10_2016.xlsx',
#  'table_clean_31_10_2017.xlsx',
#  'table_clean_31_10_2018.xlsx',
#  'table_clean_31_12_2002.xlsx',
#  'table_clean_31_12_2003.xlsx',
#  'table_clean_31_12_2004.xlsx',
#  'table_clean_31_12_2007.xlsx',
#  'table_clean_31_12_2010.xlsx',
#  'table_clean_31_12_2014.xlsx',
#  'table_clean_31_12_2015.xlsx',
#  'table_clean_31_12_2018.xlsx',
#  'table_clean_31_12_2019.xlsx',
#  'table_clean_31_12_2020.xlsx',
#  'table_clean_31_12_2021.xlsx',
#  'table_clean_31_1_2003.xlsx',
#  'table_clean_31_1_2005.xlsx',
#  'table_clean_31_1_2006.xlsx',
#  'table_clean_31_1_2007.xlsx',
#  'table_clean_31_1_2008.xlsx',
#  'table_clean_31_1_2011.xlsx',
#  'table_clean_31_1_2012.xlsx',
#  'table_clean_31_1_2013.xlsx',
#  'table_clean_31_1_2014.xlsx',
#  'table_clean_31_1_2017.xlsx',
#  'table_clean_31_1_2018.xlsx',
#  'table_clean_31_1_2019.xlsx',
#  'table_clean_31_1_2020.xlsx',
#  'table_clean_31_1_2022.xlsx',
#  'table_clean_31_3_2001.xlsx',
#  'table_clean_31_3_2003.xlsx',
#  'table_clean_31_3_2004.xlsx',
#  'table_clean_31_3_2005.xlsx',
#  'table_clean_31_3_2006.xlsx',
#  'table_clean_31_3_2008.xlsx',
#  'table_clean_31_3_2009.xlsx',
#  'table_clean_31_3_2010.xlsx',
#  'table_clean_31_3_2011.xlsx',
#  'table_clean_31_3_2014.xlsx',
#  'table_clean_31_3_2015.xlsx',
#  'table_clean_31_3_2016.xlsx',
#  'table_clean_31_3_2017.xlsx',
#  'table_clean_31_3_2020.xlsx',
#  'table_clean_31_3_2021.xlsx',
#  'table_clean_31_3_2022.xlsx',
#  'table_clean_31_5_2004.xlsx',
#  'table_clean_31_5_2005.xlsx',
#  'table_clean_31_5_2006.xlsx',
#  'table_clean_31_5_2007.xlsx',
#  'table_clean_31_5_2010.xlsx',
#  'table_clean_31_5_2011.xlsx',
#  'table_clean_31_5_2012.xlsx',
#  'table_clean_31_5_2013.xlsx',
#  'table_clean_31_5_2016.xlsx',
#  'table_clean_31_5_2017.xlsx',
#  'table_clean_31_5_2018.xlsx',
#  'table_clean_31_5_2019.xlsx',
#  'table_clean_31_5_2021.xlsx',
#  'table_clean_31_5_2022.xlsx',
#  'table_clean_31_7_2003.xlsx',
#  'table_clean_31_7_2006.xlsx',
#  'table_clean_31_7_2007.xlsx',
#  'table_clean_31_7_2008.xlsx',
#  'table_clean_31_7_2009.xlsx',
#  'table_clean_31_7_2012.xlsx',
#  'table_clean_31_7_2013.xlsx',
#  'table_clean_31_7_2014.xlsx',
#  'table_clean_31_7_2015.xlsx',
#  'table_clean_31_7_2017.xlsx',
#  'table_clean_31_7_2018.xlsx',
#  'table_clean_31_7_2019.xlsx',
#  'table_clean_31_7_2020.xlsx',
#  'table_clean_31_8_2004.xlsx',
#  'table_clean_31_8_2005.xlsx',
#  'table_clean_31_8_2006.xlsx',
#  'table_clean_31_8_2007.xlsx',
#  'table_clean_31_8_2009.xlsx',
#  'table_clean_31_8_2010.xlsx',
#  'table_clean_31_8_2011.xlsx',
#  'table_clean_31_8_2015.xlsx',
#  'table_clean_31_8_2016.xlsx',
#  'table_clean_31_8_2017.xlsx',
#  'table_clean_31_8_2020.xlsx',
#  'table_clean_31_8_2021.xlsx',
#  'table_clean_31_8_2022.xlsx']

# %% [markdown]
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.

# %%
# Using for loop in to obtain the last day of each available month of each year. 

for i in range(2001,2023): #the first loop is for all the years
    for j in range(1,13): #the second loop is for the months
        for k in range(1,32): #the third loop es for the days
            try:
                #Obtainig the last day of each available month of each year.
                #dia=calendar.monthrange(i, j)[1] 
                #Importing all the excel files with "table_clean_"+str(k)+"_"+str(j)+"_"+str(i)+".xlsx":            
                exec(f'data_{i}_{j}_{k}=pd.read_excel("table_clean_"+str(k)+"_"+str(j)+"_"+str(i)+".xlsx")') 
                print("Importando: table_clean_"+str(k)+"_"+str(j)+"_"+str(i)+".xlsx")
                #Creating date_info with a date format:
                exec(f'data_{i}_{j}_{k}["date_info"]=str(k).zfill(2)+"/"+str(j).zfill(2)+"/"+str(i)')
                exec(f'data_{i}_{j}_{k}["year"]=str(i)')
                #data_i_j_k["year"] = datetime.strptime(data_i_j_k["date"], '%d/%m/%Y')
            except:
                pass
# Out:
# Importando: table_clean_31_3_2001.xlsx
# Importando: table_clean_30_9_2002.xlsx
# Importando: table_clean_31_10_2002.xlsx
# Importando: table_clean_29_11_2002.xlsx
# Importando: table_clean_31_12_2002.xlsx
# Importando: table_clean_31_1_2003.xlsx
# Importando: table_clean_28_2_2003.xlsx
# Importando: table_clean_31_3_2003.xlsx
# Importando: table_clean_30_4_2003.xlsx
# Importando: table_clean_30_5_2003.xlsx
# Importando: table_clean_30_6_2003.xlsx
# Importando: table_clean_31_7_2003.xlsx
# Importando: table_clean_29_8_2003.xlsx
# Importando: table_clean_30_9_2003.xlsx
# Importando: table_clean_31_10_2003.xlsx
# Importando: table_clean_28_11_2003.xlsx
# Importando: table_clean_31_12_2003.xlsx
# Importando: table_clean_29_1_2004.xlsx
# Importando: table_clean_26_2_2004.xlsx
# Importando: table_clean_31_3_2004.xlsx
# Importando: table_clean_30_4_2004.xlsx
# Importando: table_clean_31_5_2004.xlsx
# Importando: table_clean_30_6_2004.xlsx
# Importando: table_clean_30_7_2004.xlsx
# Importando: table_clean_31_8_2004.xlsx
# Importando: table_clean_30_9_2004.xlsx
# Importando: table_clean_29_10_2004.xlsx
# Importando: table_clean_30_11_2004.xlsx
# Importando: table_clean_31_12_2004.xlsx
# Importando: table_clean_31_1_2005.xlsx
# Importando: table_clean_28_2_2005.xlsx
# Importando: table_clean_31_3_2005.xlsx
# Importando: table_clean_29_4_2005.xlsx
# Importando: table_clean_31_5_2005.xlsx
# Importando: table_clean_30_6_2005.xlsx
# Importando: table_clean_27_7_2005.xlsx
# Importando: table_clean_31_8_2005.xlsx
# Importando: table_clean_30_9_2005.xlsx
# Importando: table_clean_31_10_2005.xlsx
# Importando: table_clean_29_11_2005.xlsx
# Importando: table_clean_30_12_2005.xlsx
# Importando: table_clean_31_1_2006.xlsx
# Importando: table_clean_28_2_2006.xlsx
# Importando: table_clean_31_3_2006.xlsx
# Importando: table_clean_28_4_2006.xlsx
# Importando: table_clean_31_5_2006.xlsx
# Importando: table_clean_30_6_2006.xlsx
# Importando: table_clean_31_7_2006.xlsx
# Importando: table_clean_31_8_2006.xlsx
# Importando: table_clean_29_9_2006.xlsx
# Importando: table_clean_31_10_2006.xlsx
# Importando: table_clean_30_11_2006.xlsx
# Importando: table_clean_29_12_2006.xlsx
# Importando: table_clean_31_1_2007.xlsx
# Importando: table_clean_28_2_2007.xlsx
# Importando: table_clean_30_3_2007.xlsx
# Importando: table_clean_30_4_2007.xlsx
# Importando: table_clean_31_5_2007.xlsx
# Importando: table_clean_28_6_2007.xlsx
# Importando: table_clean_31_7_2007.xlsx
# Importando: table_clean_31_8_2007.xlsx
# Importando: table_clean_28_9_2007.xlsx
# Importando: table_clean_31_10_2007.xlsx
# Importando: table_clean_30_11_2007.xlsx
# Importando: table_clean_31_12_2007.xlsx
# Importando: table_clean_31_1_2008.xlsx
# Importando: table_clean_29_2_2008.xlsx
# Importando: table_clean_31_3_2008.xlsx
# Importando: table_clean_30_4_2008.xlsx
# Importando: table_clean_30_5_2008.xlsx
# Importando: table_clean_30_6_2008.xlsx
# Importando: table_clean_31_7_2008.xlsx
# Importando: table_clean_29_8_2008.xlsx
# Importando: table_clean_30_9_2008.xlsx
# Importando: table_clean_31_10_2008.xlsx
# Importando: table_clean_28_11_2008.xlsx
# Importando: table_clean_30_12_2008.xlsx
# Importando: table_clean_30_1_2009.xlsx
# Importando: table_clean_27_2_2009.xlsx
# Importando: table_clean_31_3_2009.xlsx
# Importando: table_clean_30_4_2009.xlsx
# Importando: table_clean_29_5_2009.xlsx
# Importando: table_clean_30_6_2009.xlsx
# Importando: table_clean_31_7_2009.xlsx
# Importando: table_clean_31_8_2009.xlsx
# Importando: table_clean_30_9_2009.xlsx
# Importando: table_clean_30_10_2009.xlsx
# Importando: table_clean_30_11_2009.xlsx
# Importando: table_clean_30_12_2009.xlsx
# Importando: table_clean_29_1_2010.xlsx
# Importando: table_clean_26_2_2010.xlsx
# Importando: table_clean_31_3_2010.xlsx
# Importando: table_clean_30_4_2010.xlsx
# Importando: table_clean_31_5_2010.xlsx
# Importando: table_clean_30_6_2010.xlsx
# Importando: table_clean_27_7_2010.xlsx
# Importando: table_clean_31_8_2010.xlsx
# Importando: table_clean_30_9_2010.xlsx
# Importando: table_clean_29_10_2010.xlsx
# Importando: table_clean_30_11_2010.xlsx
# Importando: table_clean_31_12_2010.xlsx
# Importando: table_clean_31_1_2011.xlsx
# Importando: table_clean_28_2_2011.xlsx
# Importando: table_clean_31_3_2011.xlsx
# Importando: table_clean_29_4_2011.xlsx
# Importando: table_clean_31_5_2011.xlsx
# Importando: table_clean_30_6_2011.xlsx
# Importando: table_clean_27_7_2011.xlsx
# Importando: table_clean_31_8_2011.xlsx
# Importando: table_clean_30_9_2011.xlsx
# Importando: table_clean_28_10_2011.xlsx
# Importando: table_clean_30_11_2011.xlsx
# Importando: table_clean_30_12_2011.xlsx
# Importando: table_clean_31_1_2012.xlsx
# Importando: table_clean_29_2_2012.xlsx
# Importando: table_clean_30_3_2012.xlsx
# Importando: table_clean_30_4_2012.xlsx
# Importando: table_clean_31_5_2012.xlsx
# Importando: table_clean_28_6_2012.xlsx
# Importando: table_clean_31_7_2012.xlsx
# Importando: table_clean_29_8_2012.xlsx
# Importando: table_clean_28_9_2012.xlsx
# Importando: table_clean_31_10_2012.xlsx
# Importando: table_clean_30_11_2012.xlsx
# Importando: table_clean_28_12_2012.xlsx
# Importando: table_clean_31_1_2013.xlsx
# Importando: table_clean_28_2_2013.xlsx
# Importando: table_clean_27_3_2013.xlsx
# Importando: table_clean_30_4_2013.xlsx
# Importando: table_clean_31_5_2013.xlsx
# Importando: table_clean_28_6_2013.xlsx
# Importando: table_clean_31_7_2013.xlsx
# Importando: table_clean_29_8_2013.xlsx
# Importando: table_clean_30_9_2013.xlsx
# Importando: table_clean_31_10_2013.xlsx
# Importando: table_clean_29_11_2013.xlsx
# Importando: table_clean_30_12_2013.xlsx
# Importando: table_clean_31_1_2014.xlsx
# Importando: table_clean_28_2_2014.xlsx
# Importando: table_clean_31_3_2014.xlsx
# Importando: table_clean_30_4_2014.xlsx
# Importando: table_clean_30_5_2014.xlsx
# Importando: table_clean_30_6_2014.xlsx
# Importando: table_clean_31_7_2014.xlsx
# Importando: table_clean_29_8_2014.xlsx
# Importando: table_clean_30_9_2014.xlsx
# Importando: table_clean_31_10_2014.xlsx
# Importando: table_clean_28_11_2014.xlsx
# Importando: table_clean_31_12_2014.xlsx
# Importando: table_clean_30_1_2015.xlsx
# Importando: table_clean_27_2_2015.xlsx
# Importando: table_clean_31_3_2015.xlsx
# Importando: table_clean_30_4_2015.xlsx
# Importando: table_clean_29_5_2015.xlsx
# Importando: table_clean_30_6_2015.xlsx
# Importando: table_clean_31_7_2015.xlsx
# Importando: table_clean_31_8_2015.xlsx
# Importando: table_clean_30_9_2015.xlsx
# Importando: table_clean_30_10_2015.xlsx
# Importando: table_clean_30_11_2015.xlsx
# Importando: table_clean_31_12_2015.xlsx
# Importando: table_clean_29_1_2016.xlsx
# Importando: table_clean_29_2_2016.xlsx
# Importando: table_clean_31_3_2016.xlsx
# Importando: table_clean_29_4_2016.xlsx
# Importando: table_clean_31_5_2016.xlsx
# Importando: table_clean_30_6_2016.xlsx
# Importando: table_clean_27_7_2016.xlsx
# Importando: table_clean_31_8_2016.xlsx
# Importando: table_clean_30_9_2016.xlsx
# Importando: table_clean_31_10_2016.xlsx
# Importando: table_clean_30_11_2016.xlsx
# Importando: table_clean_30_12_2016.xlsx
# Importando: table_clean_31_1_2017.xlsx
# Importando: table_clean_28_2_2017.xlsx
# Importando: table_clean_31_3_2017.xlsx
# Importando: table_clean_28_4_2017.xlsx
# Importando: table_clean_31_5_2017.xlsx
# Importando: table_clean_28_6_2017.xlsx
# Importando: table_clean_31_7_2017.xlsx
# Importando: table_clean_31_8_2017.xlsx
# Importando: table_clean_29_9_2017.xlsx
# Importando: table_clean_31_10_2017.xlsx
# Importando: table_clean_30_11_2017.xlsx
# Importando: table_clean_29_12_2017.xlsx
# Importando: table_clean_31_1_2018.xlsx
# Importando: table_clean_28_2_2018.xlsx
# Importando: table_clean_28_3_2018.xlsx
# Importando: table_clean_30_4_2018.xlsx
# Importando: table_clean_31_5_2018.xlsx
# Importando: table_clean_28_6_2018.xlsx
# Importando: table_clean_31_7_2018.xlsx
# Importando: table_clean_29_8_2018.xlsx
# Importando: table_clean_28_9_2018.xlsx
# Importando: table_clean_31_10_2018.xlsx
# Importando: table_clean_30_11_2018.xlsx
# Importando: table_clean_31_12_2018.xlsx
# Importando: table_clean_31_1_2019.xlsx
# Importando: table_clean_28_2_2019.xlsx
# Importando: table_clean_28_3_2019.xlsx
# Importando: table_clean_30_4_2019.xlsx
# Importando: table_clean_31_5_2019.xlsx
# Importando: table_clean_28_6_2019.xlsx
# Importando: table_clean_31_7_2019.xlsx
# Importando: table_clean_27_8_2019.xlsx
# Importando: table_clean_30_9_2019.xlsx
# Importando: table_clean_30_10_2019.xlsx
# Importando: table_clean_29_11_2019.xlsx
# Importando: table_clean_31_12_2019.xlsx
# Importando: table_clean_31_1_2020.xlsx
# Importando: table_clean_28_2_2020.xlsx
# Importando: table_clean_31_3_2020.xlsx
# Importando: table_clean_30_4_2020.xlsx
# Importando: table_clean_29_5_2020.xlsx
# Importando: table_clean_30_6_2020.xlsx
# Importando: table_clean_31_7_2020.xlsx
# Importando: table_clean_31_8_2020.xlsx
# Importando: table_clean_30_9_2020.xlsx
# Importando: table_clean_30_10_2020.xlsx
# Importando: table_clean_30_11_2020.xlsx
# Importando: table_clean_31_12_2020.xlsx
# Importando: table_clean_29_1_2021.xlsx
# Importando: table_clean_26_2_2021.xlsx
# Importando: table_clean_31_3_2021.xlsx
# Importando: table_clean_30_4_2021.xlsx
# Importando: table_clean_31_5_2021.xlsx
# Importando: table_clean_30_6_2021.xlsx
# Importando: table_clean_30_7_2021.xlsx
# Importando: table_clean_31_8_2021.xlsx
# Importando: table_clean_30_9_2021.xlsx
# Importando: table_clean_29_10_2021.xlsx
# Importando: table_clean_30_11_2021.xlsx
# Importando: table_clean_31_12_2021.xlsx
# Importando: table_clean_31_1_2022.xlsx
# Importando: table_clean_28_2_2022.xlsx
# Importando: table_clean_31_3_2022.xlsx
# Importando: table_clean_29_4_2022.xlsx
# Importando: table_clean_31_5_2022.xlsx
# Importando: table_clean_30_6_2022.xlsx
# Importando: table_clean_27_7_2022.xlsx
# Importando: table_clean_31_8_2022.xlsx

# %%
#This second loop is for the group of data with an error, because the first column is "Unnamed: 0" and we need to transform this to "Tasa Anual (%)"
for i in range(2001,2023):  #First loop indicate the range of years
    for j in range(1,13):   #Second loop indicate the range of months 
        for k in range(1,32):  #Third lood indicate the range of days
            try:
                exec(f'data = data_{i}_{j}_{k}')   #conditional to transpose the dataframe
                if "Unnamed: 0" in data.columns.tolist():
                    data=data.drop("date_info",axis=1)   #To drop a variable 
                    aux=data.T #Transpose
                    aux=aux.reset_index(drop=True) #Reset the index
                    aux[1][0] = "Tasa Anual (%)"  #Rename Tasa Anual
                    aux.columns = aux.iloc[0] #first row as header
                    aux=aux.drop(aux.index[0]) #Drop index
                    aux=aux.reset_index(drop=True) #Restart index
                    aux=aux.iloc[:,1:-1] 
                    exec(f'data_{i}_{j}_{k}=aux')
                    exec(f'data_{i}_{j}_{k}["date_info"]=str(k).zfill(2)+"/"+str(j).zfill(2)+"/"+str(i)') #Create date_info again
                    
            except:
                pass

# %% [markdown]
# 2. Append all this datasets and generate a unique dataframe. This new dataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**

# %% [markdown]
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.

# %% [markdown]
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**
