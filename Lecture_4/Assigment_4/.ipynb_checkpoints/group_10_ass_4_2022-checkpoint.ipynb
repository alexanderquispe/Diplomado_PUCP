# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.
# 2. Append all this datasets and generate a unique dataframe. This newdataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**

# %% [markdown]
# ### Solution 1

# %%
import pickle
import os
import pandas as pd

# %%
# !pip install "numpy<1.24"

# %%
# !pip install "openpyxl==3.0.7"

# %%
var_archivos = os.listdir(r"../../_data/sbs/B_RawData/bancos")

# %%
ruta = "../../_data/sbs/B_RawData/bancos"

# %%
v = []
for i in range(0,len(var_archivos)): 
    arch = pd.read_excel(ruta+"/"+var_archivos[i])
    v.append(arch.columns)

# %%
## CASO A
## Tipo 1
'Unnamed: 0', 'COMERCIAL', 'COMERCIAL.1', 'COMERCIAL.2', 'COMERCIAL.3',
        'COMERCIAL.4', 'COMERCIAL.5', 'COMERCIAL.6', 'A MICROEMPRESAS2',
        'A MICROEMPRESAS2.1', 'A MICROEMPRESAS2.2', 'CONSUMO', 'CONSUMO.1',
        'CONSUMO.2', 'CONSUMO.3', 'CONSUMO.4', 'CONSUMO.5', 'CONSUMO.6',
        'CONSUMO.7', 'CONSUMO.8', 'HIPOTECARIO'
        
## Tipo2
'Tasa Anual (%)', 'CRÉDITOS COMERCIALES', 'CRÉDITOS COMERCIALES.1',
        'CRÉDITOS COMERCIALES.2', 'CRÉDITOS COMERCIALES.3',
        'CRÉDITOS COMERCIALES.4', 'CRÉDITOS COMERCIALES.5',
        'CRÉDITOS COMERCIALES.6', 'CRÉDITOS COMERCIALES.7',
        'CRÉDITOS COMERCIALES.8', 'CRÉDITOS COMERCIALES.9',
        'CRÉDITOS COMERCIALES.10', 'CRÉDITOS COMERCIALES.11',
        'CRÉDITOS COMERCIALES.12', 'CRÉDITOS COMERCIALES.13',
        'CRÉDITOS COMERCIALES.14', 'CRÉDITOS COMERCIALES.15',
        'CRÉDITOS COMERCIALES.16', 'CRÉDITOS COMERCIALES.17',
        'CRÉDITOS COMERCIALES.18', 'CRÉDITOS COMERCIALES.19',
        'CRÉDITOS COMERCIALES.20', 'CRÉDITOS A MICROEMPRESAS2',
        'CRÉDITOS A MICROEMPRESAS2.1', 'CRÉDITOS A MICROEMPRESAS2.2',
        'CRÉDITOS A MICROEMPRESAS2.3', 'CRÉDITOS DE CONSUMO',
        'CRÉDITOS DE CONSUMO.1', 'CRÉDITOS DE CONSUMO.2',
        'CRÉDITOS DE CONSUMO.3', 'CRÉDITOS DE CONSUMO.4',
        'CRÉDITOS DE CONSUMO.5', 'CRÉDITOS DE CONSUMO.6',
        'CRÉDITOS DE CONSUMO.7', 'CRÉDITOS DE CONSUMO.8',
        'CRÉDITOS DE CONSUMO.9', 'PRÉSTAMOS HIPOTECARIOS'

## CASO B 
#Tipo 3

'Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF',
        'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella',
        'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio'
        
# Tipo 4
'Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero',
        'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'HSBC',
        'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'Promedio'

# %%
# CASO A
# Columns 
v_casoAx = []
ax=[]
for i in range(0,len(var_archivos)): 
    arch = pd.read_excel(ruta+"/"+var_archivos[i])
    if arch.columns[0]=="Unnamed: 0" and arch.columns[1]== "COMERCIAL":
        v_casoAx.append(arch.columns)
        for i in range(len(v_casoAx)):
            a= list(map(lambda x: x  , v_casoAx[i] ))
            for x in a : 
                ax.append(x)
unique_heads_a = pd.unique(a)

# %%
unique_heads_a
# Out:
# array(['Unnamed: 0', 'COMERCIAL', 'COMERCIAL.1', 'COMERCIAL.2',
#        'COMERCIAL.3', 'COMERCIAL.4', 'COMERCIAL.5', 'COMERCIAL.6',
#        'A MICROEMPRESAS2', 'A MICROEMPRESAS2.1', 'A MICROEMPRESAS2.2',
#        'CONSUMO', 'CONSUMO.1', 'CONSUMO.2', 'CONSUMO.3', 'CONSUMO.4',
#        'CONSUMO.5', 'CONSUMO.6', 'CONSUMO.7', 'CONSUMO.8', 'HIPOTECARIO'],
#       dtype=object)

# %%
# Index 
arch = pd.read_excel(ruta+"/"+var_archivos[0])
arch= pd.DataFrame(arch)
List_index = arch['Unnamed: 0']
List_index
# Out:
# 0                      NaN
# 1                      NaN
# 2                  TRABAJO
# 3                     BBVA
# 4        BANCO DE COMERCIO
# 5         BANCO DE CREDITO
# 6          BANCO PICHINCHA
# 7                   BANBIF
# 8       STANDARD CHARTERED
# 9       BANCO SUDAMERICANO
# 10         WIESE SUDAMERIS
# 11             BANK BOSTON
# 12          BNP PARIBAS EL
# 13       CITIBANK DEL PERU
# 14               INTERBANK
# 15                 MIBANCO
# 16    Promedio del Sistema
# Name: Unnamed: 0, dtype: object

# %%
arch = pd.read_excel(ruta+"/"+var_archivos[0])
y=arch.transpose()
e=y.iloc[:, 1:]
f=e.fillna('NOMBRE')
f=f.set_index([1])
f
# Out:
#                                                   2      3   \
# 1
# NOMBRE                                       TRABAJO   BBVA
# Avances en Cta.Corriente                           -  38.92
# Sobregiros                                         -  48.79
# Dsctos. y préstamos hasta 30 días                  -   8.19
# Dsctos. y préstamos 31 - 90 días                   -   5.94
# Dsctos. y préstamos 91 - 180 días                  -  10.00
# Dsctos. y préstamos 181 - 360 días                 -  26.18
# Dsctos. y préstamos más 360 días                   -  23.38
# Sobregiros                                         -  49.00
# Dsctos. y préstamos hasta 360 días             46.50  34.56
# Dsctos. y préstamos más 360 días               55.38  33.47
# Tarjetas de crédito abiertas4                  70.46  48.57
# Tarjetas de crédito cerradas5                  73.34      -
# Tarjetas de crédito                            72.54  48.57
# Para préstamos menores o iguales a S/. 1800    57.27  22.36
# Para préstamos mayores a S/. 1800              50.57  20.55
# Préstamos hasta 360 días                       54.66  20.70
# Para préstamos menores o iguales a S/. 1800    66.46  23.72
# Para préstamos mayores a S/. 1800              64.27  22.29
# Préstamos más de 360 días                      64.84  22.34
# HIPOTECARIO                                        -  15.92
#
#                                                             4   \
# 1
# NOMBRE                                       BANCO DE COMERCIO
# Avances en Cta.Corriente                                     -
# Sobregiros                                              138.18
# Dsctos. y préstamos hasta 30 días                        47.46
# Dsctos. y préstamos 31 - 90 días                         21.61
# Dsctos. y préstamos 91 - 180 días                        19.71
# Dsctos. y préstamos 181 - 360 días                           -
# Dsctos. y préstamos más 360 días                             -
# Sobregiros                                              138.18
# Dsctos. y préstamos hasta 360 días                           -
# Dsctos. y préstamos más 360 días                             -
# Tarjetas de crédito abiertas4                            24.01
# Tarjetas de crédito cerradas5                                -
# Tarjetas de crédito                                      24.01
# Para préstamos menores o iguales a S/. 1800              24.88
# Para préstamos mayores a S/. 1800                        32.40
# Préstamos hasta 360 días                                 25.19
# Para préstamos menores o iguales a S/. 1800              24.99
# Para préstamos mayores a S/. 1800                        24.97
# Préstamos más de 360 días                                24.97
# HIPOTECARIO                                                  -
#
#                                                            5   \
# 1
# NOMBRE                                       BANCO DE CREDITO
# Avances en Cta.Corriente                                73.34
# Sobregiros                                              89.00
# Dsctos. y préstamos hasta 30 días                        4.62
# Dsctos. y préstamos 31 - 90 días                         7.19
# Dsctos. y préstamos 91 - 180 días                        5.34
# Dsctos. y préstamos 181 - 360 días                       8.14
# Dsctos. y préstamos más 360 días                         3.77
# Sobregiros                                                  -
# Dsctos. y préstamos hasta 360 días                      50.60
# Dsctos. y préstamos más 360 días                        50.89
# Tarjetas de crédito abiertas4                           34.84
# Tarjetas de crédito cerradas5                               -
# Tarjetas de crédito                                     34.84
# Para préstamos menores o iguales a S/. 1800                 -
# Para préstamos mayores a S/. 1800                       19.51
# Préstamos hasta 360 días                                19.51
# Para préstamos menores o iguales a S/. 1800                 -
# Para préstamos mayores a S/. 1800                       25.25
# Préstamos más de 360 días                               25.25
# HIPOTECARIO                                                 -
#
#                                                           6       7   \
# 1
# NOMBRE                                       BANCO PICHINCHA  BANBIF
# Avances en Cta.Corriente                                   -   39.08
# Sobregiros                                                 -   68.30
# Dsctos. y préstamos hasta 30 días                      15.87   14.43
# Dsctos. y préstamos 31 - 90 días                       15.71   10.91
# Dsctos. y préstamos 91 - 180 días                      15.82   10.71
# Dsctos. y préstamos 181 - 360 días                     26.00    8.56
# Dsctos. y préstamos más 360 días                       21.28   13.34
# Sobregiros                                                 -       -
# Dsctos. y préstamos hasta 360 días                         -   16.22
# Dsctos. y préstamos más 360 días                           -       -
# Tarjetas de crédito abiertas4                          51.11   24.00
# Tarjetas de crédito cerradas5                              -       -
# Tarjetas de crédito                                    51.11   24.00
# Para préstamos menores o iguales a S/. 1800                -   23.23
# Para préstamos mayores a S/. 1800                      20.60   24.66
# Préstamos hasta 360 días                               20.60   24.61
# Para préstamos menores o iguales a S/. 1800                -   21.85
# Para préstamos mayores a S/. 1800                      28.79   21.96
# Préstamos más de 360 días                              28.79   21.95
# HIPOTECARIO                                                -       -
#
#                                                              8   \
# 1
# NOMBRE                                       STANDARD CHARTERED
# Avances en Cta.Corriente                                      -
# Sobregiros                                                25.00
# Dsctos. y préstamos hasta 30 días                             -
# Dsctos. y préstamos 31 - 90 días                              -
# Dsctos. y préstamos 91 - 180 días                             -
# Dsctos. y préstamos 181 - 360 días                            -
# Dsctos. y préstamos más 360 días                              -
# Sobregiros                                                    -
# Dsctos. y préstamos hasta 360 días                            -
# Dsctos. y préstamos más 360 días                              -
# Tarjetas de crédito abiertas4                                 -
# Tarjetas de crédito cerradas5                                 -
# Tarjetas de crédito                                           -
# Para préstamos menores o iguales a S/. 1800                   -
# Para préstamos mayores a S/. 1800                             -
# Préstamos hasta 360 días                                      -
# Para préstamos menores o iguales a S/. 1800                   -
# Para préstamos mayores a S/. 1800                             -
# Préstamos más de 360 días                                     -
# HIPOTECARIO                                                   -
#
#                                                              9   \
# 1
# NOMBRE                                       BANCO SUDAMERICANO
# Avances en Cta.Corriente                                  31.73
# Sobregiros                                                58.10
# Dsctos. y préstamos hasta 30 días                         30.68
# Dsctos. y préstamos 31 - 90 días                          11.90
# Dsctos. y préstamos 91 - 180 días                          9.98
# Dsctos. y préstamos 181 - 360 días                         0.10
# Dsctos. y préstamos más 360 días                           7.00
# Sobregiros                                                    -
# Dsctos. y préstamos hasta 360 días                        40.63
# Dsctos. y préstamos más 360 días                          40.76
# Tarjetas de crédito abiertas4                             25.00
# Tarjetas de crédito cerradas5                                 -
# Tarjetas de crédito                                       25.00
# Para préstamos menores o iguales a S/. 1800               27.29
# Para préstamos mayores a S/. 1800                         28.00
# Préstamos hasta 360 días                                  27.60
# Para préstamos menores o iguales a S/. 1800               30.97
# Para préstamos mayores a S/. 1800                         24.64
# Préstamos más de 360 días                                 24.70
# HIPOTECARIO                                                   -
#
#                                                           10           11  \
# 1
# NOMBRE                                       WIESE SUDAMERIS  BANK BOSTON
# Avances en Cta.Corriente                                   -        82.12
# Sobregiros                                                 -        82.12
# Dsctos. y préstamos hasta 30 días                      39.03         3.19
# Dsctos. y préstamos 31 - 90 días                       10.58         3.10
# Dsctos. y préstamos 91 - 180 días                       7.56         8.34
# Dsctos. y préstamos 181 - 360 días                      6.14         4.33
# Dsctos. y préstamos más 360 días                       33.60            -
# Sobregiros                                                 -            -
# Dsctos. y préstamos hasta 360 días                         -            -
# Dsctos. y préstamos más 360 días                           -            -
# Tarjetas de crédito abiertas4                          54.52            -
# Tarjetas de crédito cerradas5                          90.53            -
# Tarjetas de crédito                                    76.56            -
# Para préstamos menores o iguales a S/. 1800            86.08            -
# Para préstamos mayores a S/. 1800                      25.09            -
# Préstamos hasta 360 días                               65.48            -
# Para préstamos menores o iguales a S/. 1800            89.22            -
# Para préstamos mayores a S/. 1800                      27.32            -
# Préstamos más de 360 días                              36.33            -
# HIPOTECARIO                                                -            -
#
#                                                          12  \
# 1
# NOMBRE                                       BNP PARIBAS EL
# Avances en Cta.Corriente                                  -
# Sobregiros                                                -
# Dsctos. y préstamos hasta 30 días                         -
# Dsctos. y préstamos 31 - 90 días                          -
# Dsctos. y préstamos 91 - 180 días                         -
# Dsctos. y préstamos 181 - 360 días                        -
# Dsctos. y préstamos más 360 días                          -
# Sobregiros                                                -
# Dsctos. y préstamos hasta 360 días                        -
# Dsctos. y préstamos más 360 días                          -
# Tarjetas de crédito abiertas4                             -
# Tarjetas de crédito cerradas5                             -
# Tarjetas de crédito                                       -
# Para préstamos menores o iguales a S/. 1800               -
# Para préstamos mayores a S/. 1800                         -
# Préstamos hasta 360 días                                  -
# Para préstamos menores o iguales a S/. 1800               -
# Para préstamos mayores a S/. 1800                         -
# Préstamos más de 360 días                                 -
# HIPOTECARIO                                               -
#
#                                                             13         14  \
# 1
# NOMBRE                                       CITIBANK DEL PERU  INTERBANK
# Avances en Cta.Corriente                                     -      33.38
# Sobregiros                                               89.47      67.51
# Dsctos. y préstamos hasta 30 días                         3.16      19.23
# Dsctos. y préstamos 31 - 90 días                          7.80       9.87
# Dsctos. y préstamos 91 - 180 días                         9.95       8.14
# Dsctos. y préstamos 181 - 360 días                       13.20       6.56
# Dsctos. y préstamos más 360 días                          6.85       8.56
# Sobregiros                                                   -          -
# Dsctos. y préstamos hasta 360 días                           -          -
# Dsctos. y préstamos más 360 días                             -          -
# Tarjetas de crédito abiertas4                            59.93      35.05
# Tarjetas de crédito cerradas5                                -          -
# Tarjetas de crédito                                      59.93      35.05
# Para préstamos menores o iguales a S/. 1800                  -      27.66
# Para préstamos mayores a S/. 1800                            -      25.97
# Préstamos hasta 360 días                                     -      27.13
# Para préstamos menores o iguales a S/. 1800                  -      28.83
# Para préstamos mayores a S/. 1800                            -      29.02
# Préstamos más de 360 días                                    -      29.01
# HIPOTECARIO                                                  -          -
#
#                                                   15                    16
# 1
# NOMBRE                                       MIBANCO  Promedio del Sistema
# Avances en Cta.Corriente                           -                 68.42
# Sobregiros                                         -                 83.69
# Dsctos. y préstamos hasta 30 días                  -                  5.31
# Dsctos. y préstamos 31 - 90 días                   -                  7.04
# Dsctos. y préstamos 91 - 180 días              57.87                  6.68
# Dsctos. y préstamos 181 - 360 días             50.53                  7.78
# Dsctos. y préstamos más 360 días                   -                  6.46
# Sobregiros                                         -                 60.81
# Dsctos. y préstamos hasta 360 días             64.91                 53.68
# Dsctos. y préstamos más 360 días               52.30                 52.06
# Tarjetas de crédito abiertas4                      -                 40.97
# Tarjetas de crédito cerradas5                      -                 79.54
# Tarjetas de crédito                                -                 45.23
# Para préstamos menores o iguales a S/. 1800    75.93                 59.72
# Para préstamos mayores a S/. 1800              61.82                 45.02
# Préstamos hasta 360 días                       65.45                 50.97
# Para préstamos menores o iguales a S/. 1800    69.84                 56.31
# Para préstamos mayores a S/. 1800              48.11                 30.83
# Préstamos más de 360 días                      48.26                 32.84
# HIPOTECARIO                                    26.00                 16.28

# %%
# CASO B 
# Columns 
v_casoB = []
b=[]
for i in range(0,len(var_archivos)): 
    arch = pd.read_excel(ruta+"/"+var_archivos[i])
    if arch.columns[0]=="Tasa Anual (%)" and arch.columns[1]== "BBVA":
        v_casoB.append(arch.columns)
        for i in range(len(v_casoB)):
            a= list(map(lambda x: x  , v_casoB[i] ))
            for x in a : 
                b.append(x)
unique_heads = pd.unique(b)
unique_heads = np.append(unique_heads,'date_info')
unique_heads

# %%
# CASO B 
# Index 
v_casoB_index = []
arch = pd.read_excel(ruta+"/"+var_archivos[28])
for x in arch['Tasa Anual (%)'] :
    v_casoB_index.append(x)
unique_index = v_casoB_index

# %%
df = pd.DataFrame(arch, unique_index, unique_heads)
v= pd.DataFrame(0, unique_index, unique_heads)

# %%
## Bucle de casos similares 
for i in range(0,len(var_archivos)): 
    arch = pd.read_excel(ruta+"/"+var_archivos[i])
    if arch.columns[0]=="Tasa Anual (%)" and arch.columns[1]== "BBVA":
        a=[]
        for x in arch['Tasa Anual (%)'] :
            a.append(x)
        arch=arch.set_index(pd.Index(a))
        arch['date_info'] = var_archivos[i][12:-5]
        arch= pd.DataFrame(arch, unique_index, unique_heads)
        v = pd.concat([v,arch])
    else : arch=pd.DataFrame(0, unique_index, unique_heads)

# %%
v= v[v['date_info'] != 0].dropna(how='all')
v= v.set_index(['Tasa Anual (%)'])
v
# Out:
#                                                      BBVA Comercio Crédito  \
# Tasa Anual (%)
# Corporativos                                         1.01        -    2.04
# Descuentos                                           3.46        -    2.22
# Préstamos hasta 30 días                              0.28        -    0.78
# Préstamos de 31 a 90 días                            2.36        -    2.53
# Préstamos de 91 a 180 días                           1.23        -    2.56
# ...                                                   ...      ...     ...
# Préstamos no Revolventes para libre disponibili...  22.13    33.35   63.03
# Préstamos no Revolventes para libre disponibili...  18.22    14.66   18.99
# Créditos pignoraticios                                  -    42.40       -
# Hipotecarios                                         9.28     9.08    9.27
# Préstamos hipotecarios para vivienda                 9.28     9.08    9.27
#
#                                                    Pichincha    BIF  \
# Tasa Anual (%)
# Corporativos                                            3.36   2.76
# Descuentos                                              3.89   3.45
# Préstamos hasta 30 días                                 2.52   1.85
# Préstamos de 31 a 90 días                               7.25   2.14
# Préstamos de 91 a 180 días                              4.79   2.19
# ...                                                      ...    ...
# Préstamos no Revolventes para libre disponibili...     26.69  10.00
# Préstamos no Revolventes para libre disponibili...     33.05  13.39
# Créditos pignoraticios                                     -      -
# Hipotecarios                                            8.72   9.23
# Préstamos hipotecarios para vivienda                    8.72   9.23
#
#                                                    Scotiabank Citibank  \
# Tasa Anual (%)
# Corporativos                                             1.97        -
# Descuentos                                               1.47        -
# Préstamos hasta 30 días                                  0.28        -
# Préstamos de 31 a 90 días                                0.53        -
# Préstamos de 91 a 180 días                               0.82        -
# ...                                                       ...      ...
# Préstamos no Revolventes para libre disponibili...      26.47        -
# Préstamos no Revolventes para libre disponibili...      17.84        -
# Créditos pignoraticios                                      -        -
# Hipotecarios                                             8.61        -
# Préstamos hipotecarios para vivienda                     8.61        -
#
#                                                    Interbank Mibanco    GNB  \
# Tasa Anual (%)
# Corporativos                                            3.06       -   1.78
# Descuentos                                              4.32       -      -
# Préstamos hasta 30 días                                 0.46       -      -
# Préstamos de 31 a 90 días                               0.85       -   1.78
# Préstamos de 91 a 180 días                              2.01       -      -
# ...                                                      ...     ...    ...
# Préstamos no Revolventes para libre disponibili...     28.87   66.89      -
# Préstamos no Revolventes para libre disponibili...     21.23   37.15  11.30
# Créditos pignoraticios                                     -       -      -
# Hipotecarios                                            8.73   15.54   8.03
# Préstamos hipotecarios para vivienda                    8.73   15.54   8.03
#
#                                                    Falabella Santander Ripley  \
# Tasa Anual (%)
# Corporativos                                               -      5.87      -
# Descuentos                                                 -      6.06      -
# Préstamos hasta 30 días                                    -         -      -
# Préstamos de 31 a 90 días                                  -      3.35      -
# Préstamos de 91 a 180 días                                 -      3.76      -
# ...                                                      ...       ...    ...
# Préstamos no Revolventes para libre disponibili...     36.14         -  39.93
# Préstamos no Revolventes para libre disponibili...     32.22         -  26.03
# Créditos pignoraticios                                     -         -      -
# Hipotecarios                                               -         -      -
# Préstamos hipotecarios para vivienda                       -         -      -
#
#                                                    Azteca  ICBC Bank of China  \
# Tasa Anual (%)
# Corporativos                                            -  3.56          s.i.
# Descuentos                                              -     -          s.i.
# Préstamos hasta 30 días                                 -     -          s.i.
# Préstamos de 31 a 90 días                               -  3.56          s.i.
# Préstamos de 91 a 180 días                              -     -          s.i.
# ...                                                   ...   ...           ...
# Préstamos no Revolventes para libre disponibili...    NaN     -          s.i.
# Préstamos no Revolventes para libre disponibili...    NaN     -          s.i.
# Créditos pignoraticios                                NaN     -          s.i.
# Hipotecarios                                          NaN     -          s.i.
# Préstamos hipotecarios para vivienda                  NaN     -          s.i.
#
#                                                    Promedio  Alfin  BCI  \
# Tasa Anual (%)
# Corporativos                                           2.21    NaN  NaN
# Descuentos                                             3.94    NaN  NaN
# Préstamos hasta 30 días                                 0.5    NaN  NaN
# Préstamos de 31 a 90 días                               1.3    NaN  NaN
# Préstamos de 91 a 180 días                             1.66    NaN  NaN
# ...                                                     ...    ...  ...
# Préstamos no Revolventes para libre disponibili...    48.58  74.42    -
# Préstamos no Revolventes para libre disponibili...    22.48  69.00    -
# Créditos pignoraticios                                 42.4      -    -
# Hipotecarios                                           9.13      -    -
# Préstamos hipotecarios para vivienda                   9.13      -    -
#
#                                                     date_info
# Tasa Anual (%)
# Corporativos                                        26_2_2021
# Descuentos                                          26_2_2021
# Préstamos hasta 30 días                             26_2_2021
# Préstamos de 31 a 90 días                           26_2_2021
# Préstamos de 91 a 180 días                          26_2_2021
# ...                                                       ...
# Préstamos no Revolventes para libre disponibili...  31_8_2022
# Préstamos no Revolventes para libre disponibili...  31_8_2022
# Créditos pignoraticios                              31_8_2022
# Hipotecarios                                        31_8_2022
# Préstamos hipotecarios para vivienda                31_8_2022
#
# [1840 rows x 20 columns]
