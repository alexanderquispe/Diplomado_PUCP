# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.
# 2. Append all this datasets and generate a unique dataframe. This newdataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**

# %% [markdown]
# ### Answers:

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %% [markdown]
# #### Answer 1:

# %%
xlsx_files = [*map(lambda x: x[12:-5], os.listdir('../../_data/sbs/B_RawData/bancos'))]

# %%
d = {}
for x in xlsx_files:
    d["table_"+x] = pd.read_excel(r'../../_data/sbs/B_RawData/bancos/table_clean_'+x+'.xlsx')
    d["table_"+x]["date_info"] = datetime.strptime(x, "%d_%m_%Y").date()

# %% [markdown]
# #### Answer 2:

# %%
# Identificar patrón en el formato de los dataframes
df = pd.DataFrame(columns = ["SegundaColumna", "Fecha"])
i = 0

for x in xlsx_files:
    df.loc[i,"SegundaColumna"] = d["table_"+x].columns[1]
    df.loc[i,"Fecha"] = d["table_"+x].iloc[0,-1]
    i += 1

df = df.sort_values("Fecha").reset_index()

for x in range(np.shape(df)[0]):
    print(f'Primera columna: [{df.loc[x,"SegundaColumna"]}] y Fecha: [{df.loc[x,"Fecha"]}]')
# Out:
# Primera columna: [BBVA] y Fecha: [2001-03-31]
# Primera columna: [COMERCIAL] y Fecha: [2002-09-30]
# Primera columna: [COMERCIAL] y Fecha: [2002-10-31]
# Primera columna: [COMERCIAL] y Fecha: [2002-11-29]
# Primera columna: [COMERCIAL] y Fecha: [2002-12-31]
# Primera columna: [COMERCIAL] y Fecha: [2003-01-31]
# Primera columna: [COMERCIAL] y Fecha: [2003-02-28]
# Primera columna: [COMERCIAL] y Fecha: [2003-03-31]
# Primera columna: [COMERCIAL] y Fecha: [2003-04-30]
# Primera columna: [COMERCIAL] y Fecha: [2003-05-30]
# Primera columna: [COMERCIAL] y Fecha: [2003-06-30]
# Primera columna: [COMERCIAL] y Fecha: [2003-07-31]
# Primera columna: [COMERCIAL] y Fecha: [2003-08-29]
# Primera columna: [COMERCIAL] y Fecha: [2003-09-30]
# Primera columna: [COMERCIAL] y Fecha: [2003-10-31]
# Primera columna: [COMERCIAL] y Fecha: [2003-11-28]
# Primera columna: [COMERCIAL] y Fecha: [2003-12-31]
# Primera columna: [COMERCIAL] y Fecha: [2004-01-29]
# Primera columna: [COMERCIAL] y Fecha: [2004-02-26]
# Primera columna: [Continental] y Fecha: [2018-10-31]
# Primera columna: [Continental] y Fecha: [2018-11-30]
# Primera columna: [Continental] y Fecha: [2018-12-31]
# Primera columna: [Continental] y Fecha: [2019-01-31]
# Primera columna: [Continental] y Fecha: [2019-02-28]
# Primera columna: [Continental] y Fecha: [2019-03-28]
# Primera columna: [Continental] y Fecha: [2019-04-30]
# Primera columna: [Continental] y Fecha: [2019-05-31]
# Primera columna: [BBVA] y Fecha: [2019-06-28]
# Primera columna: [BBVA] y Fecha: [2019-07-31]
# Primera columna: [BBVA] y Fecha: [2019-08-27]
# Primera columna: [BBVA] y Fecha: [2019-09-30]
# Primera columna: [BBVA] y Fecha: [2019-10-30]
# Primera columna: [BBVA] y Fecha: [2019-11-29]
# Primera columna: [BBVA] y Fecha: [2019-12-31]
# Primera columna: [BBVA] y Fecha: [2020-01-31]
# Primera columna: [BBVA] y Fecha: [2020-02-28]
# Primera columna: [BBVA] y Fecha: [2020-03-31]
# Primera columna: [BBVA] y Fecha: [2020-04-30]
# Primera columna: [BBVA] y Fecha: [2020-05-29]
# Primera columna: [BBVA] y Fecha: [2020-06-30]
# Primera columna: [BBVA] y Fecha: [2020-07-31]
# Primera columna: [BBVA] y Fecha: [2020-08-31]
# Primera columna: [BBVA] y Fecha: [2020-09-30]
# Primera columna: [BBVA] y Fecha: [2020-10-30]
# Primera columna: [BBVA] y Fecha: [2020-11-30]
# Primera columna: [BBVA] y Fecha: [2020-12-31]
# Primera columna: [BBVA] y Fecha: [2021-01-29]
# Primera columna: [BBVA] y Fecha: [2021-02-26]
# Primera columna: [BBVA] y Fecha: [2021-03-31]
# Primera columna: [BBVA] y Fecha: [2021-04-30]
# Primera columna: [BBVA] y Fecha: [2021-05-31]
# Primera columna: [BBVA] y Fecha: [2021-06-30]
# Primera columna: [BBVA] y Fecha: [2021-07-30]
# Primera columna: [BBVA] y Fecha: [2021-08-31]
# Primera columna: [BBVA] y Fecha: [2021-09-30]
# Primera columna: [BBVA] y Fecha: [2021-10-29]
# Primera columna: [BBVA] y Fecha: [2021-11-30]
# Primera columna: [BBVA] y Fecha: [2021-12-31]
# Primera columna: [BBVA] y Fecha: [2022-01-31]
# Primera columna: [BBVA] y Fecha: [2022-02-28]
# Primera columna: [BBVA] y Fecha: [2022-03-31]
# Primera columna: [BBVA] y Fecha: [2022-04-29]
# Primera columna: [BBVA] y Fecha: [2022-05-31]
# Primera columna: [BBVA] y Fecha: [2022-06-30]
# Primera columna: [BBVA] y Fecha: [2022-07-27]
# Primera columna: [BBVA] y Fecha: [2022-08-31]

# %%
for x in xlsx_files:
    if datetime.strptime("30_9_2010", "%d_%m_%Y").date() > datetime.strptime(x, "%d_%m_%Y").date() > datetime.strptime("31_3_2001", "%d_%m_%Y").date():
        d["table_"+x].columns = ['Tasa Anual (%)']+list(d["table_"+x].iloc[1])[1:]
        d["table_"+x] = d["table_"+x].loc[2:,:]
        d["table_"+x] = d["table_"+x].transpose().reset_index()
        d["table_"+x].columns = list(d["table_"+x].iloc[0])
        d["table_"+x] = d["table_"+x].iloc[1:-1,:]
        d["table_"+x]["date_info"] = datetime.strptime(x, "%d_%m_%Y").date()
        # Solo falta corregir nombres de bancos
    else:
        d["table_"+x].columns = [d["table_"+x].columns[0]]+[*map(lambda k: k.upper(), d["table_"+x].columns[1:-2])]+d["table_"+x].columns[-2:].tolist()
        d["table_"+x].rename(columns = {"CONTINENTAL": "BBVA", "BANCO GNB": "GNB"}, inplace = True)

# %%
# Tomar en consideración que el banco Financiero se convierte en Pichincha?
# Tomar en consideración que el banco Azteca se convierte en Alfin?
# Retirar posibles "  *"

# %%
print(d["table_31_3_2001"].columns)
print(d["table_31_5_2005"].columns)
print(d["table_31_3_2009"].columns)
print(d["table_30_6_2010"].columns)
print(d["table_30_4_2012"].columns)
print(d["table_30_1_2015"].columns)
print(d["table_31_5_2016"].columns)
print(d["table_28_2_2019"].columns)
print(d["table_28_6_2019"].columns)
print(d["table_31_12_2020"].columns)
print(d["table_30_7_2021"].columns)
print(d["table_31_8_2022"].columns)
# Out:
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'ALFIN', 'ICBC', 'BANK OF CHINA', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'TRABAJO', 'BBVA', 'BANCO DE COMERCIO',
#        'BANCO DE CREDITO', 'BANCO PICHINCHA', 'BANBIF', 'STANDARD CHARTERED',
#        'BANCO SUDAMERICANO', 'WIESE SUDAMERIS', 'BANK BOSTON',
#        'BNP PARIBAS EL', 'CITIBANK DEL PERU', 'INTERBANK', 'MIBANCO',
#        'Promedio del Sistema', 'date_info'],
#       dtype='object')
# Index([      'Tasa Anual (%)',                 'BBVA',    'BANCO DE COMERCIO',
#            'BANCO DE CREDITO',      'BANCO PICHINCHA',               'BANBIF',
#             'SCOTIABANK PERU',    'CITIBANK DEL PERU',            'INTERBANK',
#                     'MIBANCO',                 'HSBC',      'BANCO FALABELLA',
#              'SANTANDER PERU',         'BANCO RIPLEY',          'ALFIN BANCO',
#          'DEUTSCHE BANK PERU', 'Promedio del Sistema',                    nan,
#                   'date_info'],
#       dtype='object')
# Index([      'Tasa Anual (%)',                 'BBVA',    'BANCO DE COMERCIO',
#            'BANCO DE CREDITO',      'BANCO PICHINCHA',               'BANBIF',
#             'SCOTIABANK PERU',    'CITIBANK DEL PERU',            'INTERBANK',
#                     'MIBANCO',                 'HSBC',      'BANCO FALABELLA',
#              'SANTANDER PERU',         'BANCO RIPLEY',          'ALFIN BANCO',
#          'DEUTSCHE BANK PERU', 'Promedio del Sistema',                    nan,
#                   'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'FINANCIERO', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'HSBC', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA  *', 'DEUTSCHE', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'FINANCIERO', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'DEUTSCHE', 'CENCOSUD', 'ICBC',
#        'Promedio', 'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'FINANCIERO', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'DEUTSCHE', 'CAT', 'ICBC', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'CAT', 'ICBC', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'ICBC', 'Promedio', 'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'ICBC', 'BANK OF CHINA', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'AZTECA', 'ICBC', 'BANK OF CHINA', 'Promedio',
#        'date_info'],
#       dtype='object')
# Index(['Tasa Anual (%)', 'BBVA', 'COMERCIO', 'CRÉDITO', 'PICHINCHA', 'BIF',
#        'SCOTIABANK', 'CITIBANK', 'INTERBANK', 'MIBANCO', 'GNB', 'FALABELLA',
#        'SANTANDER', 'RIPLEY', 'ALFIN', 'ICBC', 'BANK OF CHINA', 'BCI',
#        'Promedio', 'date_info'],
#       dtype='object')

# %%
# Cuentas dentro del rango de fechas:
# Fila numero 1 debe convertirse en nombres de columna, luego Transpose
d["table_"+xlsx_files[6]].columns = ['Tasa Anual (%)']+list(d["table_"+xlsx_files[6]].iloc[1])[1:]
d["table_"+xlsx_files[6]] = d["table_"+xlsx_files[6]].loc[2:,:]
d["table_"+xlsx_files[6]] = d["table_"+xlsx_files[6]].transpose().reset_index()
d["table_"+xlsx_files[6]].columns = list(d["table_"+xlsx_files[6]].iloc[0])
d["table_"+xlsx_files[6]] = d["table_"+xlsx_files[6]].iloc[1:-1,:]
d["table_"+xlsx_files[6]]["date_info"] = datetime.strptime(xlsx_files[6], "%d_%m_%Y").date()

# %%
d["table_"+xlsx_files[6]]
# Out:
#                                  Tasa Anual (%) TRABAJO   BBVA  \
# 1                      Avances en Cta.Corriente       -  36.64
# 2                                    Sobregiros       -  46.56
# 3             Dsctos. y préstamos hasta 30 días       -   8.64
# 4              Dsctos. y préstamos 31 - 90 días       -   8.93
# 5             Dsctos. y préstamos 91 - 180 días   41.00   8.72
# 6            Dsctos. y préstamos 181 - 360 días   44.37  19.11
# 7              Dsctos. y préstamos más 360 días   41.00   8.18
# 8                                    Sobregiros       -  48.99
# 9            Dsctos. y préstamos hasta 360 días   40.35  36.08
# 10             Dsctos. y préstamos más 360 días   40.63  37.03
# 11                Tarjetas de crédito abiertas4   81.88  44.27
# 12                Tarjetas de crédito cerradas5   77.08      -
# 13                          Tarjetas de crédito   78.58  44.27
# 14  Para préstamos menores o iguales a S/. 1800   44.10  21.66
# 15            Para préstamos mayores a S/. 1800   41.71  19.37
# 16                     Préstamos hasta 360 días   43.23  19.53
# 17  Para préstamos menores o iguales a S/. 1800   46.52  22.39
# 18            Para préstamos mayores a S/. 1800   46.32  19.49
# 19                    Préstamos más de 360 días   46.38  19.65
# 20                                  HIPOTECARIO       -  11.68
#
#    BANCO DE COMERCIO BANCO DE CREDITO BANCO PICHINCHA BANBIF  \
# 1              37.62            32.14               -  23.62
# 2             138.18            37.60               -  41.61
# 3              36.37             5.28           14.11  16.43
# 4              20.34             7.61           12.66  10.13
# 5              15.63             8.89           14.63  10.16
# 6                  -             5.00           50.00   8.15
# 7                  -             5.18           38.78   9.36
# 8             138.19                -               -      -
# 9              30.35            39.42               -  19.20
# 10                 -            37.40               -      -
# 11             24.02            32.17           51.11  25.00
# 12                 -                -               -      -
# 13             24.02            32.17           51.11  25.00
# 14             24.90                -               -  22.31
# 15             16.57            19.63           24.81  22.90
# 16             24.17            19.63           24.81  22.89
# 17             24.91            23.50               -  20.14
# 18             24.88            20.03           27.21  18.99
# 19             24.88            20.03           27.21  19.02
# 20                 -            10.70               -      -
#
#    STANDARD CHARTERED BANCO SUDAMERICANO WIESE SUDAMERIS BANK BOSTON  \
# 1                   -              28.48           21.85           -
# 2                   -              62.23           44.60           -
# 3                   -              12.54           17.69           -
# 4                   -               8.11            9.16           -
# 5                   -              11.33            6.96           -
# 6                   -               7.92           10.54           -
# 7                   -              13.76            5.53           -
# 8                   -                  -           85.00           -
# 9                   -              42.05           46.26           -
# 10                  -              41.19           47.30           -
# 11                  -              25.00           31.02           -
# 12                  -                  -           95.13           -
# 13                  -              25.00           39.68           -
# 14                  -              26.70           77.96           -
# 15                  -              36.34           26.30           -
# 16                  -              30.19           53.52           -
# 17                  -              27.69           88.35           -
# 18                  -              24.82           21.80           -
# 19                  -              24.95           29.41           -
# 20                  -                  -               -           -
#
#    BNP PARIBAS EL CITIBANK DEL PERU INTERBANK MIBANCO Promedio del Sistema  \
# 1               -                 -     64.03       -                31.71
# 2               -             77.41      5.09       -                28.67
# 3               -              6.00     11.06   50.00                 6.11
# 4               -              6.13      6.57       -                 8.18
# 5               -              8.79      6.91   49.85                 8.73
# 6               -              8.73      5.83   41.88                 8.06
# 7               -                 -     12.01   39.22                 6.45
# 8               -                 -         -       -                90.62
# 9               -                 -         -   55.48                47.37
# 10              -                 -         -   45.06                42.14
# 11              -             59.93     39.39       -                44.15
# 12              -                 -     62.32       -                72.86
# 13              -             59.93     43.74       -                49.71
# 14              -                 -     30.07   75.57                52.97
# 15              -                 -     27.59   62.41                42.03
# 16              -                 -     28.45   66.66                46.30
# 17              -                 -     26.98   75.57                49.86
# 18              -                 -     27.53   51.12                26.68
# 19              -                 -     27.52   51.40                27.73
# 20              -                 -         -   27.14                12.03
#
#      date_info
# 1   2005-07-27
# 2   2005-07-27
# 3   2005-07-27
# 4   2005-07-27
# 5   2005-07-27
# 6   2005-07-27
# 7   2005-07-27
# 8   2005-07-27
# 9   2005-07-27
# 10  2005-07-27
# 11  2005-07-27
# 12  2005-07-27
# 13  2005-07-27
# 14  2005-07-27
# 15  2005-07-27
# 16  2005-07-27
# 17  2005-07-27
# 18  2005-07-27
# 19  2005-07-27
# 20  2005-07-27

# %%
xlsx_files[4]
# Out:
# '27_2_2015'
