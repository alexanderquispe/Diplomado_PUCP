# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.
# 2. Append all this datasets and generate a unique dataframe. This newdataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**

# %% [markdown]
# # Question 1

# %%
#First, we installed the packages as required.
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request
import glob

# %%
pwd
# Out:
# 'C:\\Users\\Laptop\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_4\\Assigment_4'

# %%
#Then we used the function "glob" to get all the xlsx files. We searched in #Fuente: https://www.geeksforgeeks.org/how-to-read-all-excel-files-under-a-directory-as-a-pandas-dataframe/?ref=rp .
path="C:/Users/Laptop/Documents/GitHub/Diplomado_PUCP/_data/sbs/B_RawData/bancos"
csv_files = glob.glob(os.path.join(path, "*.xlsx"))

# %%
relative_path = os.path.relpath(path)
print(relative_path)
# Out:
# ..\..\_data\sbs\B_RawData\bancos

# %%
#After that, we applied a loop over the list of xls files.
for f in csv_files:
    # read the csv file
    df = pd.read_excel(f)
    #We deactivated the functions below, since when they were run, although the dataframes were displayed, the page would hang.
    #display(df) 
    #print()

# %%
# loop over the list of csv files
for f in csv_files:
    
    # read the csv file (procurar no tener un archivo abierto porque, de lo contrario, saldrá un signo dólar que podría dañar el código)
    basename=os.path.basename(f)
    b=basename[basename.find('_', 7)+1:basename.find('.')]
    #print(b)

# %%
df1 = pd.read_excel(r'C:/Users/Laptop/Documents/GitHub/Diplomado_PUCP/_data/sbs/B_RawData/bancos\table_clean_28_2_2007.xlsx')
df1
# Out:
#               Unnamed: 0                 COMERCIAL COMERCIAL.1  \
# 0                    NaN  Avances en Cta.Corriente  Sobregiros
# 1                    NaN  Avances en Cta.Corriente  Sobregiros
# 2                TRABAJO                         -           -
# 3                   BBVA                     21.90       48.32
# 4      BANCO DE COMERCIO                    138.18      138.18
# 5       BANCO DE CREDITO                     41.16       29.27
# 6        BANCO PICHINCHA                         -           -
# 7                 BANBIF                     25.47       84.00
# 8        SCOTIABANK PERU                     14.37       53.88
# 9      CITIBANK DEL PERU                         -       89.98
# 10             INTERBANK                      7.36       12.06
# 11               MIBANCO                         -           -
# 12                  HSBC                         -       60.00
# 13  Promedio del Sistema                     29.78       26.29
#
#                           COMERCIAL.2                       COMERCIAL.3  \
# 0   Dsctos. y préstamos hasta 30 días  Dsctos. y préstamos 31 - 90 días
# 1   Dsctos. y préstamos hasta 30 días  Dsctos. y préstamos 31 - 90 días
# 2                                   -                                 -
# 3                               10.01                             12.04
# 4                               15.86                             13.01
# 5                                5.68                              7.60
# 6                               12.99                             11.46
# 7                               11.53                             10.21
# 8                                5.84                              8.47
# 9                                6.15                              7.04
# 10                              13.55                              9.77
# 11                                  -                             36.85
# 12                                  -                              9.41
# 13                               6.07                              8.79
#
#                           COMERCIAL.4                         COMERCIAL.5  \
# 0   Dsctos. y préstamos 91 - 180 días  Dsctos. y préstamos 181 - 360 días
# 1   Dsctos. y préstamos 91 - 180 días  Dsctos. y préstamos 181 - 360 días
# 2                                   -                               30.50
# 3                                8.91                                9.61
# 4                               11.02                               14.03
# 5                                6.90                                6.21
# 6                               12.01                               10.50
# 7                                8.28                                9.65
# 8                                6.93                                6.03
# 9                                8.84                                9.77
# 10                               7.00                                8.31
# 11                              30.04                               31.45
# 12                               7.50                                   -
# 13                               7.71                                8.24
#
#                          COMERCIAL.6 A MICROEMPRESAS2  \
# 0   Dsctos. y préstamos más 360 días       Sobregiros
# 1   Dsctos. y préstamos más 360 días       Sobregiros
# 2                              30.02                -
# 3                               7.67            48.92
# 4                                  -           138.18
# 5                               9.05                -
# 6                               9.80                -
# 7                               6.66                -
# 8                               9.98            63.93
# 9                               7.00                -
# 10                              8.46            69.00
# 11                             38.28                -
# 12                              9.00                -
# 13                              8.40            64.73
#
#                     A MICROEMPRESAS2.1  ...                        CONSUMO  \
# 0   Dsctos. y préstamos hasta 360 días  ...            Tarjeta de crédito3
# 1   Dsctos. y préstamos hasta 360 días  ...  Tarjetas de crédito abiertas4
# 2                                27.91  ...                          75.68
# 3                                34.07  ...                          43.81
# 4                                27.77  ...                          18.68
# 5                                32.38  ...                          30.75
# 6                                66.58  ...                          51.11
# 7                                18.53  ...                          30.00
# 8                                37.35  ...                          22.58
# 9                                    -  ...                          59.93
# 10                               13.12  ...                          34.90
# 11                               51.24  ...                              -
# 12                                   -  ...                              -
# 13                               39.76  ...                          40.55
#
#                         CONSUMO.1            CONSUMO.2  \
# 0             Tarjeta de crédito3  Tarjeta de crédito3
# 1   Tarjetas de crédito cerradas5  Tarjetas de crédito
# 2                           84.98                81.93
# 3                               -                43.81
# 4                               -                18.68
# 5                               -                30.75
# 6                               -                51.11
# 7                               -                30.00
# 8                          100.05                22.58
# 9                               -                59.93
# 10                          65.37                39.17
# 11                              -                    -
# 12                              -                    -
# 13                          77.59                46.30
#
#                                       CONSUMO.3  \
# 0                      Préstamos hasta 360 días
# 1   Para préstamos menores o iguales a S/. 1800
# 2                                         36.06
# 3                                         23.37
# 4                                         24.79
# 5                                             -
# 6                                             -
# 7                                         18.88
# 8                                         55.36
# 9                                             -
# 10                                        25.37
# 11                                        75.25
# 12                                            -
# 13                                        52.00
#
#                             CONSUMO.4                 CONSUMO.5  \
# 0            Préstamos hasta 360 días  Préstamos hasta 360 días
# 1   Para préstamos mayores a S/. 1800  Préstamos hasta 360 días
# 2                               28.13                     31.75
# 3                               18.01                     18.37
# 4                               22.04                     24.17
# 5                               13.80                     13.80
# 6                               98.14                     98.14
# 7                               23.68                     23.47
# 8                               16.73                     30.12
# 9                                   -                         -
# 10                              20.50                     22.13
# 11                              58.61                     63.22
# 12                                  -                         -
# 13                              38.61                     42.23
#
#                                       CONSUMO.6  \
# 0                        Préstamos más 360 días
# 1   Para préstamos menores o iguales a S/. 1800
# 2                                         52.29
# 3                                         23.66
# 4                                         23.17
# 5                                             -
# 6                                             -
# 7                                         18.91
# 8                                         32.50
# 9                                             -
# 10                                        26.69
# 11                                        74.45
# 12                                            -
# 13                                        38.44
#
#                             CONSUMO.7                  CONSUMO.8  HIPOTECARIO
# 0              Préstamos más 360 días     Préstamos más 360 días  HIPOTECARIO
# 1   Para préstamos mayores a S/. 1800  Préstamos más de 360 días  HIPOTECARIO
# 2                               46.90                      47.98            -
# 3                               15.66                      15.71        10.66
# 4                               24.64                      24.59        14.03
# 5                               17.41                      17.41         9.38
# 6                               52.15                      52.15            -
# 7                               18.82                      18.82            -
# 8                               19.79                      20.02            -
# 9                                   -                          -            -
# 10                              23.18                      23.21         9.75
# 11                              45.85                      46.41        22.79
# 12                                  -                          -            -
# 13                              23.79                      24.02        10.04
#
# [14 rows x 21 columns]

# %%
# A partir de aquí estoy intentando crear una regla, para diferenciar los archivos antiguos (como el anterior) de los nuevos (que tienen a los bancos por columna).
# Aquí estoy haciendo el ejercicio para una tabla, o sea, si existe esa palabra, entonces...
df3=df1['COMERCIAL'][1]
df3
# Out:
# 'Avances en Cta.Corriente'

# %%
#... que transponga la matriz.
#Habría que ver, cómo eliminar la primera columna y la primera fila, para que sean tablas mucho más homogéneas.
if df3 == 'Avances en Cta.Corriente':
    df4 = df1.transpose( )
    
display(df4)
# Out:
#                                                     0   \
# Unnamed: 0                                         NaN
# COMERCIAL                     Avances en Cta.Corriente
# COMERCIAL.1                                 Sobregiros
# COMERCIAL.2          Dsctos. y préstamos hasta 30 días
# COMERCIAL.3           Dsctos. y préstamos 31 - 90 días
# COMERCIAL.4          Dsctos. y préstamos 91 - 180 días
# COMERCIAL.5         Dsctos. y préstamos 181 - 360 días
# COMERCIAL.6           Dsctos. y préstamos más 360 días
# A MICROEMPRESAS2                            Sobregiros
# A MICROEMPRESAS2.1  Dsctos. y préstamos hasta 360 días
# A MICROEMPRESAS2.2    Dsctos. y préstamos más 360 días
# CONSUMO                            Tarjeta de crédito3
# CONSUMO.1                          Tarjeta de crédito3
# CONSUMO.2                          Tarjeta de crédito3
# CONSUMO.3                     Préstamos hasta 360 días
# CONSUMO.4                     Préstamos hasta 360 días
# CONSUMO.5                     Préstamos hasta 360 días
# CONSUMO.6                       Préstamos más 360 días
# CONSUMO.7                       Préstamos más 360 días
# CONSUMO.8                       Préstamos más 360 días
# HIPOTECARIO                                HIPOTECARIO
#
#                                                              1        2   \
# Unnamed: 0                                                  NaN  TRABAJO
# COMERCIAL                              Avances en Cta.Corriente        -
# COMERCIAL.1                                          Sobregiros        -
# COMERCIAL.2                   Dsctos. y préstamos hasta 30 días        -
# COMERCIAL.3                    Dsctos. y préstamos 31 - 90 días        -
# COMERCIAL.4                   Dsctos. y préstamos 91 - 180 días        -
# COMERCIAL.5                  Dsctos. y préstamos 181 - 360 días    30.50
# COMERCIAL.6                    Dsctos. y préstamos más 360 días    30.02
# A MICROEMPRESAS2                                     Sobregiros        -
# A MICROEMPRESAS2.1           Dsctos. y préstamos hasta 360 días    27.91
# A MICROEMPRESAS2.2             Dsctos. y préstamos más 360 días    36.07
# CONSUMO                           Tarjetas de crédito abiertas4    75.68
# CONSUMO.1                         Tarjetas de crédito cerradas5    84.98
# CONSUMO.2                                   Tarjetas de crédito    81.93
# CONSUMO.3           Para préstamos menores o iguales a S/. 1800    36.06
# CONSUMO.4                     Para préstamos mayores a S/. 1800    28.13
# CONSUMO.5                              Préstamos hasta 360 días    31.75
# CONSUMO.6           Para préstamos menores o iguales a S/. 1800    52.29
# CONSUMO.7                     Para préstamos mayores a S/. 1800    46.90
# CONSUMO.8                             Préstamos más de 360 días    47.98
# HIPOTECARIO                                         HIPOTECARIO        -
#
#                        3                  4                 5   \
# Unnamed: 0           BBVA  BANCO DE COMERCIO  BANCO DE CREDITO
# COMERCIAL           21.90             138.18             41.16
# COMERCIAL.1         48.32             138.18             29.27
# COMERCIAL.2         10.01              15.86              5.68
# COMERCIAL.3         12.04              13.01              7.60
# COMERCIAL.4          8.91              11.02              6.90
# COMERCIAL.5          9.61              14.03              6.21
# COMERCIAL.6          7.67                  -              9.05
# A MICROEMPRESAS2    48.92             138.18                 -
# A MICROEMPRESAS2.1  34.07              27.77             32.38
# A MICROEMPRESAS2.2  30.12              38.45             28.76
# CONSUMO             43.81              18.68             30.75
# CONSUMO.1               -                  -                 -
# CONSUMO.2           43.81              18.68             30.75
# CONSUMO.3           23.37              24.79                 -
# CONSUMO.4           18.01              22.04             13.80
# CONSUMO.5           18.37              24.17             13.80
# CONSUMO.6           23.66              23.17                 -
# CONSUMO.7           15.66              24.64             17.41
# CONSUMO.8           15.71              24.59             17.41
# HIPOTECARIO         10.66              14.03              9.38
#
#                                  6       7                8   \
# Unnamed: 0          BANCO PICHINCHA  BANBIF  SCOTIABANK PERU
# COMERCIAL                         -   25.47            14.37
# COMERCIAL.1                       -   84.00            53.88
# COMERCIAL.2                   12.99   11.53             5.84
# COMERCIAL.3                   11.46   10.21             8.47
# COMERCIAL.4                   12.01    8.28             6.93
# COMERCIAL.5                   10.50    9.65             6.03
# COMERCIAL.6                    9.80    6.66             9.98
# A MICROEMPRESAS2                  -       -            63.93
# A MICROEMPRESAS2.1            66.58   18.53            37.35
# A MICROEMPRESAS2.2            59.04       -            38.14
# CONSUMO                       51.11   30.00            22.58
# CONSUMO.1                         -       -           100.05
# CONSUMO.2                     51.11   30.00            22.58
# CONSUMO.3                         -   18.88            55.36
# CONSUMO.4                     98.14   23.68            16.73
# CONSUMO.5                     98.14   23.47            30.12
# CONSUMO.6                         -   18.91            32.50
# CONSUMO.7                     52.15   18.82            19.79
# CONSUMO.8                     52.15   18.82            20.02
# HIPOTECARIO                       -       -                -
#
#                                    9          10       11     12  \
# Unnamed: 0          CITIBANK DEL PERU  INTERBANK  MIBANCO   HSBC
# COMERCIAL                           -       7.36        -      -
# COMERCIAL.1                     89.98      12.06        -  60.00
# COMERCIAL.2                      6.15      13.55        -      -
# COMERCIAL.3                      7.04       9.77    36.85   9.41
# COMERCIAL.4                      8.84       7.00    30.04   7.50
# COMERCIAL.5                      9.77       8.31    31.45      -
# COMERCIAL.6                      7.00       8.46    38.28   9.00
# A MICROEMPRESAS2                    -      69.00        -      -
# A MICROEMPRESAS2.1                  -      13.12    51.24      -
# A MICROEMPRESAS2.2                  -          -    42.82      -
# CONSUMO                         59.93      34.90        -      -
# CONSUMO.1                           -      65.37        -      -
# CONSUMO.2                       59.93      39.17        -      -
# CONSUMO.3                           -      25.37    75.25      -
# CONSUMO.4                           -      20.50    58.61      -
# CONSUMO.5                           -      22.13    63.22      -
# CONSUMO.6                           -      26.69    74.45      -
# CONSUMO.7                           -      23.18    45.85      -
# CONSUMO.8                           -      23.21    46.41      -
# HIPOTECARIO                         -       9.75    22.79      -
#
#                                       13
# Unnamed: 0          Promedio del Sistema
# COMERCIAL                          29.78
# COMERCIAL.1                        26.29
# COMERCIAL.2                         6.07
# COMERCIAL.3                         8.79
# COMERCIAL.4                         7.71
# COMERCIAL.5                         8.24
# COMERCIAL.6                         8.40
# A MICROEMPRESAS2                   64.73
# A MICROEMPRESAS2.1                 39.76
# A MICROEMPRESAS2.2                 38.70
# CONSUMO                            40.55
# CONSUMO.1                          77.59
# CONSUMO.2                          46.30
# CONSUMO.3                          52.00
# CONSUMO.4                          38.61
# CONSUMO.5                          42.23
# CONSUMO.6                          38.44
# CONSUMO.7                          23.79
# CONSUMO.8                          24.02
# HIPOTECARIO                        10.04
