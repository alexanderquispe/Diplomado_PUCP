# %% [markdown]
# # Assigment 4
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Import all the data and generate a column named as `date_info` that should have the day to information corresponds.

# %%
pip install savReaderWriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
pwd # working directory
# Out:
# 'C:\\Users\\Mariana Otero\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_4\\Assigment_4'

# %%
# We use the relative path to import the data for 2001 (there is only data for March)
Mar_2001 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2001.xlsx")

# %%
type(Mar_2001) #We corroborate that the data is imported as a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
#We generate a column named as date_info containing the date to which the information corresponds
Mar_2001.insert(0, "date_info", "31-03-2001") 
Mar_2001 #we see that the dataframe contains the new column that we generated
# Out:
#      date_info                                     Tasa Anual (%)   BBVA  \
# 0   31-03-2001                                       Corporativos   2.69
# 1   31-03-2001                                         Descuentos   4.11
# 2   31-03-2001                            Préstamos hasta 30 días   2.81
# 3   31-03-2001                          Préstamos de 31 a 90 días   2.74
# 4   31-03-2001                         Préstamos de 91 a 180 días   3.07
# 5   31-03-2001                        Préstamos de 181 a 360 días      -
# 6   31-03-2001                        Préstamos a más de 360 días   2.27
# 7   31-03-2001                                   Grandes Empresas   6.26
# 8   31-03-2001                                         Descuentos   8.53
# 9   31-03-2001                            Préstamos hasta 30 días   5.46
# 10  31-03-2001                          Préstamos de 31 a 90 días   5.16
# 11  31-03-2001                         Préstamos de 91 a 180 días   5.68
# ...

# %%
#We convert the column type for date_info to datetime format: DD-MM-YYYY
Mar_2001['date_info']= pd.to_datetime(Mar_2001['date_info'], format = '%d-%m-%Y' )

# %%
Mar_2001.info('date_info') #we corroborate that the data type for date_info is datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date_info       46 non-null     datetime64[ns]
#  1   Tasa Anual (%)  46 non-null     object
#  2   BBVA            46 non-null     object
#  3   Comercio        46 non-null     object
#  4   Crédito         46 non-null     object
#  5   Pichincha       46 non-null     object
#  6   BIF             46 non-null     object
#  7   Scotiabank      46 non-null     object
#  8   Citibank        46 non-null     object
#  9   Interbank       46 non-null     object
#  10  Mibanco         46 non-null     object
#  11  GNB             46 non-null     object
#  12  Falabella       46 non-null     object
#  13  Santander       46 non-null     object
#  14  Ripley          46 non-null     object
#  15  Alfin           46 non-null     object
#  16  ICBC            46 non-null     object
# ...

# %%
# Now we import the data for 2002 and repeat the process to generate the column date_info and convert it to datetime.
Sep_2002 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2002.xlsx")
Sep_2002.insert(0, "date_info", "30-09-2002")
Sep_2002['date_info']= pd.to_datetime(Sep_2002['date_info'], format = '%d-%m-%Y' )

Oct_2002 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2002.xlsx")
Oct_2002.insert(0, "date_info", "31-10-2002")
Oct_2002['date_info']= pd.to_datetime(Oct_2002['date_info'], format = '%d-%m-%Y' )

Nov_2002 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_11_2002.xlsx")
Nov_2002.insert(0, "date_info", "29-11-2002")
Nov_2002['date_info']= pd.to_datetime(Nov_2002['date_info'], format = '%d-%m-%Y' )

Dec_2002 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2002.xlsx")
Dec_2002.insert(0, "date_info", "31-12-2002")
Dec_2002['date_info']= pd.to_datetime(Dec_2002['date_info'], format = '%d-%m-%Y' )

# %%
# We repeat the above process: Data for 2003
Jan_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2003.xlsx")
Jan_2003.insert(0, "date_info", "31-01-2003")
Jan_2003['date_info']= pd.to_datetime(Jan_2003['date_info'], format = '%d-%m-%Y' )

Feb_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2003.xlsx")
Feb_2003.insert(0, "date_info", "28-02-2003")
Feb_2003['date_info']= pd.to_datetime(Feb_2003['date_info'], format = '%d-%m-%Y' )

Mar_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2003.xlsx")
Mar_2003.insert(0, "date_info", "31-03-2003")
Mar_2003['date_info']= pd.to_datetime(Mar_2003['date_info'], format = '%d-%m-%Y' )

Apr_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2003.xlsx")
Apr_2003.insert(0, "date_info", "30-04-2003")
Apr_2003['date_info']= pd.to_datetime(Apr_2003['date_info'], format = '%d-%m-%Y' )

May_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_5_2003.xlsx")
May_2003.insert(0, "date_info", "30-05-2003")
May_2003['date_info']= pd.to_datetime(May_2003['date_info'], format = '%d-%m-%Y' )

Jun_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2003.xlsx")
Jun_2003.insert(0, "date_info", "30-06-2003")
Jun_2003['date_info']= pd.to_datetime(Jun_2003['date_info'], format = '%d-%m-%Y' )

Jul_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2003.xlsx")
Jul_2003.insert(0, "date_info", "31-07-2003")
Jul_2003['date_info']= pd.to_datetime(Jul_2003['date_info'], format = '%d-%m-%Y' )

Aug_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2003.xlsx")
Aug_2003.insert(0, "date_info", "29-08-2003")
Aug_2003['date_info']= pd.to_datetime(Aug_2003['date_info'], format = '%d-%m-%Y' )

Sep_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2003.xlsx")
Sep_2003.insert(0, "date_info", "30-09-2003")
Sep_2003['date_info']= pd.to_datetime(Sep_2003['date_info'], format = '%d-%m-%Y' )

Oct_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2003.xlsx")
Oct_2003.insert(0, "date_info", "31-10-2003")
Oct_2003['date_info']= pd.to_datetime(Oct_2003['date_info'], format = '%d-%m-%Y' )

Nov_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_11_2003.xlsx")
Nov_2003.insert(0, "date_info", "28-11-2003")
Nov_2003['date_info']= pd.to_datetime(Nov_2003['date_info'], format = '%d-%m-%Y' )

Dec_2003 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2003.xlsx")
Dec_2003.insert(0, "date_info", "31-12-2003")
Dec_2003['date_info']= pd.to_datetime(Dec_2003['date_info'], format = '%d-%m-%Y' )

# %%
#2004
Jan_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_1_2004.xlsx")
Jan_2004.insert(0, "date_info", "29-01-2004")
Jan_2004['date_info']= pd.to_datetime(Jan_2004['date_info'], format = '%d-%m-%Y' )

Feb_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_26_2_2004.xlsx")
Feb_2004.insert(0, "date_info", "26-02-2004")
Feb_2004['date_info']= pd.to_datetime(Feb_2004['date_info'], format = '%d-%m-%Y' )

Mar_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2004.xlsx")
Mar_2004.insert(0, "date_info", "31-03-2004")
Mar_2004['date_info']= pd.to_datetime(Mar_2004['date_info'], format = '%d-%m-%Y' )

Apr_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2004.xlsx")
Apr_2004.insert(0, "date_info", "30-04-2004")
Apr_2004['date_info']= pd.to_datetime(Apr_2004['date_info'], format = '%d-%m-%Y' )

May_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2004.xlsx")
May_2004.insert(0, "date_info", "31-05-2004")
May_2004['date_info']= pd.to_datetime(May_2004['date_info'], format = '%d-%m-%Y' )

Jun_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2004.xlsx")
Jun_2004.insert(0, "date_info", "30-06-2004")
Jun_2004['date_info']= pd.to_datetime(Jun_2004['date_info'], format = '%d-%m-%Y' )

Jul_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_7_2004.xlsx")
Jul_2004.insert(0, "date_info", "30-07-2004")
Jul_2004['date_info']= pd.to_datetime(Jul_2004['date_info'], format = '%d-%m-%Y' )

Aug_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2004.xlsx")
Aug_2004.insert(0, "date_info", "31-08-2004")
Aug_2004['date_info']= pd.to_datetime(Aug_2004['date_info'], format = '%d-%m-%Y' )

Sep_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2004.xlsx")
Sep_2004.insert(0, "date_info", "30-09-2004")
Sep_2004['date_info']= pd.to_datetime(Sep_2004['date_info'], format = '%d-%m-%Y' )

Oct_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_10_2004.xlsx")
Oct_2004.insert(0, "date_info", "29-10-2004")
Oct_2004['date_info']= pd.to_datetime(Oct_2004['date_info'], format = '%d-%m-%Y' )

Nov_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2004.xlsx")
Nov_2004.insert(0, "date_info", "30-11-2004")
Nov_2004['date_info']= pd.to_datetime(Nov_2004['date_info'], format = '%d-%m-%Y' )

Dec_2004 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2004.xlsx")
Dec_2004.insert(0, "date_info", "31-12-2004")
Dec_2004['date_info']= pd.to_datetime(Dec_2004['date_info'], format = '%d-%m-%Y' )

# %%
#2005
Jan_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2005.xlsx")
Jan_2005.insert(0, "date_info", "31-01-2005")
Jan_2005['date_info']= pd.to_datetime(Jan_2005['date_info'], format = '%d-%m-%Y' )

Feb_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2005.xlsx")
Feb_2005.insert(0, "date_info", "28-02-2005")
Feb_2005['date_info']= pd.to_datetime(Feb_2005['date_info'], format = '%d-%m-%Y' )

Mar_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2005.xlsx")
Mar_2005.insert(0, "date_info", "31-03-2005")
Mar_2005['date_info']= pd.to_datetime(Mar_2005['date_info'], format = '%d-%m-%Y' )

Apr_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_4_2005.xlsx")
Apr_2005.insert(0, "date_info", "29-04-2005")
Apr_2005['date_info']= pd.to_datetime(Apr_2005['date_info'], format = '%d-%m-%Y' )

May_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2005.xlsx")
May_2005.insert(0, "date_info", "31-05-2005")
May_2005['date_info']= pd.to_datetime(May_2005['date_info'], format = '%d-%m-%Y' )

Jun_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2005.xlsx")
Jun_2005.insert(0, "date_info", "30-06-2005")
Jun_2005['date_info']= pd.to_datetime(Jun_2005['date_info'], format = '%d-%m-%Y' )

Jul_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_7_2005.xlsx")
Jul_2005.insert(0, "date_info", "27-07-2005")
Jul_2005['date_info']= pd.to_datetime(Jul_2005['date_info'], format = '%d-%m-%Y' )

Aug_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2005.xlsx")
Aug_2005.insert(0, "date_info", "31-08-2005")
Aug_2005['date_info']= pd.to_datetime(Aug_2005['date_info'], format = '%d-%m-%Y' )

Sep_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2005.xlsx")
Sep_2005.insert(0, "date_info", "30-09-2005")
Sep_2005['date_info']= pd.to_datetime(Sep_2005['date_info'], format = '%d-%m-%Y' )

Oct_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2005.xlsx")
Oct_2005.insert(0, "date_info", "31-10-2005")
Oct_2005['date_info']= pd.to_datetime(Oct_2005['date_info'], format = '%d-%m-%Y' )

Nov_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_11_2005.xlsx")
Nov_2005.insert(0, "date_info", "29-11-2005")
Nov_2005['date_info']= pd.to_datetime(Nov_2005['date_info'], format = '%d-%m-%Y' )

Dec_2005 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2005.xlsx")
Dec_2005.insert(0, "date_info", "30-12-2005")
Dec_2005['date_info']= pd.to_datetime(Dec_2005['date_info'], format = '%d-%m-%Y' )

# %%
#2006
Jan_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2006.xlsx")
Jan_2006.insert(0, "date_info", "31-01-2006")
Jan_2006['date_info']= pd.to_datetime(Jan_2006['date_info'], format = '%d-%m-%Y' )

Feb_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2006.xlsx")
Feb_2006.insert(0, "date_info", "28-02-2006")
Feb_2006['date_info']= pd.to_datetime(Feb_2006['date_info'], format = '%d-%m-%Y' )

Mar_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2006.xlsx")
Mar_2006.insert(0, "date_info", "31-03-2006")
Mar_2006['date_info']= pd.to_datetime(Mar_2006['date_info'], format = '%d-%m-%Y' )

Apr_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_4_2006.xlsx")
Apr_2006.insert(0, "date_info", "28-04-2006")
Apr_2006['date_info']= pd.to_datetime(Apr_2006['date_info'], format = '%d-%m-%Y' )

May_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2006.xlsx")
May_2006.insert(0, "date_info", "31-05-2006")
May_2006['date_info']= pd.to_datetime(May_2006['date_info'], format = '%d-%m-%Y' )

Jun_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2006.xlsx")
Jun_2006.insert(0, "date_info", "30-06-2006")
Jun_2006['date_info']= pd.to_datetime(Jun_2006['date_info'], format = '%d-%m-%Y' )

Jul_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2006.xlsx")
Jul_2006.insert(0, "date_info", "31-07-2006")
Jul_2006['date_info']= pd.to_datetime(Jul_2006['date_info'], format = '%d-%m-%Y' )

Aug_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2006.xlsx")
Aug_2006.insert(0, "date_info", "31-08-2006")
Aug_2006['date_info']= pd.to_datetime(Aug_2006['date_info'], format = '%d-%m-%Y' )

Sep_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_9_2006.xlsx")
Sep_2006.insert(0, "date_info", "29-09-2006")
Sep_2006['date_info']= pd.to_datetime(Jan_2005['date_info'], format = '%d-%m-%Y' )

Oct_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2006.xlsx")
Oct_2006.insert(0, "date_info", "31-10-2006")
Oct_2006['date_info']= pd.to_datetime(Sep_2006['date_info'], format = '%d-%m-%Y' )

Nov_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2006.xlsx")
Nov_2006.insert(0, "date_info", "30-11-2006")
Nov_2006['date_info']= pd.to_datetime(Nov_2006['date_info'], format = '%d-%m-%Y' )

Dec_2006 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_12_2006.xlsx")
Dec_2006.insert(0, "date_info", "29-12-2006")
Dec_2006['date_info']= pd.to_datetime(Dec_2006['date_info'], format = '%d-%m-%Y' )

# %%
#2007
Jan_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2007.xlsx")
Jan_2007.insert(0, "date_info", "31-01-2007")
Jan_2007['date_info']= pd.to_datetime(Jan_2007['date_info'], format = '%d-%m-%Y' )

Feb_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2007.xlsx")
Feb_2007.insert(0, "date_info", "28-02-2007")
Feb_2007['date_info']= pd.to_datetime(Feb_2007['date_info'], format = '%d-%m-%Y' )

Mar_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_3_2007.xlsx")
Mar_2007.insert(0, "date_info", "30-03-2007")
Mar_2007['date_info']= pd.to_datetime(Mar_2007['date_info'], format = '%d-%m-%Y' )

Apr_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2007.xlsx")
Apr_2007.insert(0, "date_info", "30-04-2007")
Apr_2007['date_info']= pd.to_datetime(Apr_2007['date_info'], format = '%d-%m-%Y' )

May_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2007.xlsx")
May_2007.insert(0, "date_info", "31-05-2007")
May_2007['date_info']= pd.to_datetime(May_2007['date_info'], format = '%d-%m-%Y' )

Jun_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2007.xlsx")
Jun_2007.insert(0, "date_info", "28-016-2007")
Jun_2007['date_info']= pd.to_datetime(Jun_2007['date_info'], format = '%d-%m-%Y' )

Jul_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2007.xlsx")
Jul_2007.insert(0, "date_info", "31-07-2007")
Jul_2007['date_info']= pd.to_datetime(Jul_2007['date_info'], format = '%d-%m-%Y' )

Aug_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2007.xlsx")
Aug_2007.insert(0, "date_info", "31-08-2007")
Aug_2007['date_info']= pd.to_datetime(Aug_2007['date_info'], format = '%d-%m-%Y' )

Sep_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_9_2007.xlsx")
Sep_2007.insert(0, "date_info", "28-09-2007")
Sep_2007['date_info']= pd.to_datetime(Sep_2007['date_info'], format = '%d-%m-%Y' )

Oct_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2007.xlsx")
Oct_2007.insert(0, "date_info", "31-10-2007")
Oct_2007['date_info']= pd.to_datetime(Oct_2007['date_info'], format = '%d-%m-%Y' )

Nov_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2007.xlsx")
Nov_2007.insert(0, "date_info", "30-11-2007")
Nov_2007['date_info']= pd.to_datetime(Nov_2007['date_info'], format = '%d-%m-%Y' )

Dec_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2007.xlsx")
Dec_2007.insert(0, "date_info", "31-12-2007")
Dec_2007['date_info']= pd.to_datetime(Dec_2007['date_info'], format = '%d-%m-%Y' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\AnacondaPython\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\AnacondaPython\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7412\3735153227.py in <module>
#      22 Jun_2007 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2007.xlsx")
# ...

# %%
#2008
Jan_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2008.xlsx")
Jan_2008.insert(0, "date_info", "31-01-2008")
Jan_2008['date_info']= pd.to_datetime(Jan_2008['date_info'], format = '%d-%m-%Y' )

Feb_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_2_2008.xlsx")
Feb_2008.insert(0, "date_info", "29-02-2008")
Feb_2008['date_info']= pd.to_datetime(Feb_2008['date_info'], format = '%d-%m-%Y' )

Mar_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2008.xlsx")
Mar_2008.insert(0, "date_info", "31-03-2008")
Mar_2008['date_info']= pd.to_datetime(Mar_2008['date_info'], format = '%d-%m-%Y' )

Apr_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2008.xlsx")
Apr_2008.insert(0, "date_info", "30-04-2008")
Apr_2008['date_info']= pd.to_datetime(Apr_2008['date_info'], format = '%d-%m-%Y' )

May_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_5_2008.xlsx")
May_2008.insert(0, "date_info", "30-05-2008")
May_2008['date_info']= pd.to_datetime(May_2008['date_info'], format = '%d-%m-%Y' )

Jun_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2008.xlsx")
Jun_2008.insert(0, "date_info", "30-06-2008")
Jun_2008['date_info']= pd.to_datetime(Jun_2008['date_info'], format = '%d-%m-%Y' )

Jul_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2008.xlsx")
Jul_2008.insert(0, "date_info", "31-07-2008")
Jul_2008['date_info']= pd.to_datetime(Jul_2008['date_info'], format = '%d-%m-%Y' )

Aug_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2008.xlsx")
Aug_2008.insert(0, "date_info", "29-08-2008")
Aug_2008['date_info']= pd.to_datetime(Aug_2008['date_info'], format = '%d-%m-%Y' )

Sep_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2008.xlsx")
Sep_2008.insert(0, "date_info", "310-09-2008")
Sep_2008['date_info']= pd.to_datetime(Sep_2008['date_info'], format = '%d-%m-%Y' )

Oct_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2008.xlsx")
Oct_2008.insert(0, "date_info", "31-10-2008")
Oct_2008['date_info']= pd.to_datetime(Oct_2008['date_info'], format = '%d-%m-%Y' )

Nov_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_11_2008.xlsx")
Nov_2008.insert(0, "date_info", "28-11-2008")
Nov_2008['date_info']= pd.to_datetime(Nov_2008['date_info'], format = '%d-%m-%Y' )

Dec_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2008.xlsx")
Dec_2008.insert(0, "date_info", "30-12-2008")
Dec_2008['date_info']= pd.to_datetime(Dec_2008['date_info'], format = '%d-%m-%Y' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\AnacondaPython\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\AnacondaPython\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7412\2023541773.py in <module>
#      34 Sep_2008 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2008.xlsx")
# ...

# %%
#2009
Jan_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_1_2009.xlsx")
Jan_2009.insert(0, "date_info", "30-01-2009")
Jan_2009['date_info']= pd.to_datetime(Jan_2009['date_info'], format = '%d-%m-%Y' )

Feb_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_2_2009.xlsx")
Feb_2009.insert(0, "date_info", "27-02-2009")
Feb_2009['date_info']= pd.to_datetime(Feb_2009['date_info'], format = '%d-%m-%Y' )

Mar_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2009.xlsx")
Mar_2009.insert(0, "date_info", "31-03-2009")
Mar_2009['date_info']= pd.to_datetime(Mar_2009['date_info'], format = '%d-%m-%Y' )

Apr_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2009.xlsx")
Apr_2009.insert(0, "date_info", "30-04-2009")
Apr_2009['date_info']= pd.to_datetime(Apr_2009['date_info'], format = '%d-%m-%Y' )

May_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_5_2009.xlsx")
May_2009.insert(0, "date_info", "29-05-2009")
May_2009['date_info']= pd.to_datetime(May_2009['date_info'], format = '%d-%m-%Y' )

Jun_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2009.xlsx")
Jun_2009.insert(0, "date_info", "30-06-2009")
Jun_2009['date_info']= pd.to_datetime(Jun_2009['date_info'], format = '%d-%m-%Y' )

Jul_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2009.xlsx")
Jul_2009.insert(0, "date_info", "31-07-2009")
Jul_2009['date_info']= pd.to_datetime(Jul_2009['date_info'], format = '%d-%m-%Y' )

Aug_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2009.xlsx")
Aug_2009.insert(0, "date_info", "31-08-2009")
Aug_2009['date_info']= pd.to_datetime(Aug_2009['date_info'], format = '%d-%m-%Y' )

Sep_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2009.xlsx")
Sep_2009.insert(0, "date_info", "30-09-2009")
Sep_2009['date_info']= pd.to_datetime(Sep_2009['date_info'], format = '%d-%m-%Y' )

Oct_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_10_2009.xlsx")
Oct_2009.insert(0, "date_info", "30-10-2009)
Oct_2009['date_info']= pd.to_datetime(Oct_2009['date_info'], format = '%d-%m-%Y' )

Nov_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2009.xlsx")
Nov_2009.insert(0, "date_info", "30-11-2009")
Nov_2009['date_info']= pd.to_datetime(Nov_2009['date_info'], format = '%d-%m-%Y' )

Dec_2009 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2009.xlsx")
Dec_2009.insert(0, "date_info", "30-12-2009")
Dec_2009['date_info']= pd.to_datetime(Dec_2009['date_info'], format = '%d-%m-%Y' )
# Out:
#   File "C:\Users\Mariana Otero\AppData\Local\Temp\ipykernel_7412\2975749494.py", line 39
#     Oct_2009.insert(0, "date_info", "30-10-2009)
#                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
#2010
Jan_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_1_2010.xlsx")
Jan_2010.insert(0, "date_info", "29-01-2010")
Jan_2010['date_info']= pd.to_datetime(Jan_2010['date_info'], format = '%d-%m-%Y' )

Feb_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_26_2_2010.xlsx")
Feb_2010.insert(0, "date_info", "26-02-2010")
Feb_2010['date_info']= pd.to_datetime(Feb_2010['date_info'], format = '%d-%m-%Y' )

Mar_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2010.xlsx")
Mar_2010.insert(0, "date_info", "31-03-2010")
Mar_2010['date_info']= pd.to_datetime(Mar_2010['date_info'], format = '%d-%m-%Y' )

Apr_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2010.xlsx")
Apr_2010.insert(0, "date_info", "30-04-2010")
Apr_2010['date_info']= pd.to_datetime(Apr_2010['date_info'], format = '%d-%m-%Y' )

May_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2010.xlsx")
May_2010.insert(0, "date_info", "31-05-2010")
May_2010['date_info']= pd.to_datetime(May_2010['date_info'], format = '%d-%m-%Y' )

Jun_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2010.xlsx")
Jun_2010.insert(0, "date_info", "30-06-2010")
Jun_2010['date_info']= pd.to_datetime(Jun_2010['date_info'], format = '%d-%m-%Y' )

Jul_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_7_2010.xlsx")
Jul_2010.insert(0, "date_info", "27-07-2010")
Jul_2010['date_info']= pd.to_datetime(Jul_2010['date_info'], format = '%d-%m-%Y' )

Aug_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2010.xlsx")
Aug_2010.insert(0, "date_info", "31-08-2010")
Aug_2010['date_info']= pd.to_datetime(Aug_2010['date_info'], format = '%d-%m-%Y' )

Sep_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2010.xlsx")
Sep_2005.insert(0, "date_info", "30-09-2010")
Sep_2005['date_info']= pd.to_datetime(Sep_2010['date_info'], format = '%d-%m-%Y' )

Oct_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_10_2010.xlsx")
Oct_2010.insert(0, "date_info", "29-10-2010")
Oct_2010['date_info']= pd.to_datetime(Oct_2010['date_info'], format = '%d-%m-%Y' )

Nov_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2010.xlsx")
Nov_2010.insert(0, "date_info", "30-11-2010")
Nov_2010['date_info']= pd.to_datetime(Nov_2010['date_info'], format = '%d-%m-%Y' )

Dec_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2010.xlsx")
Dec_2010.insert(0, "date_info", "31-12-2010")
Dec_2010['date_info']= pd.to_datetime(Dec_2010['date_info'], format = '%d-%m-%Y' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7412\1969682390.py in <module>
#      33
#      34 Sep_2010 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2010.xlsx")
# ---> 35 Sep_2005.insert(0, "date_info", "30-09-2010")
#      36 Sep_2005['date_info']= pd.to_datetime(Sep_2010['date_info'], format = '%d-%m-%Y' )
#      37
#
# C:\AnacondaPython\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
#    4442             # Should this be a different kind of error??
# -> 4443             raise ValueError(f"cannot insert {column}, already exists")
#    4444         if not isinstance(loc, int):
#    4445             raise TypeError("loc must be int")
#
# ValueError: cannot insert date_info, already exists

# %%
#2011
Jan_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2011.xlsx")
Jan_2011.insert(0, "date_info", "31-01-2011")
Jan_2011['date_info']= pd.to_datetime(Jan_2011['date_info'], format = '%d-%m-%Y' )

Feb_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2011.xlsx")
Feb_2011.insert(0, "date_info", "28-02-2011")
Feb_2011['date_info']= pd.to_datetime(Feb_2011['date_info'], format = '%d-%m-%Y' )

Mar_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2011.xlsx")
Mar_2011.insert(0, "date_info", "31-03-2011")
Mar_2011['date_info']= pd.to_datetime(Mar_2011['date_info'], format = '%d-%m-%Y' )

Apr_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_4_2011.xlsx")
Apr_2011.insert(0, "date_info", "29-04-2011")
Apr_2011['date_info']= pd.to_datetime(Apr_2011['date_info'], format = '%d-%m-%Y' )

May_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2011.xlsx")
May_2011.insert(0, "date_info", "31-05-2011")
May_2011['date_info']= pd.to_datetime(May_2011['date_info'], format = '%d-%m-%Y' )

Jun_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2011.xlsx")
Jun_2011.insert(0, "date_info", "30-06-2011")
Jun_2011['date_info']= pd.to_datetime(Jun_2011['date_info'], format = '%d-%m-%Y' )

Jul_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_7_2011.xlsx")
Jul_2011.insert(0, "date_info", "27-07-2011")
Jul_2011['date_info']= pd.to_datetime(Jul_2011['date_info'], format = '%d-%m-%Y' )

Aug_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2011.xlsx")
Aug_2011.insert(0, "date_info", "31-08-2011")
Aug_2011['date_info']= pd.to_datetime(Aug_2011['date_info'], format = '%d-%m-%Y' )

Sep_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2011.xlsx")
Sep_2011.insert(0, "date_info", "30-09-2011")
Sep_2011['date_info']= pd.to_datetime(Sep_2011['date_info'], format = '%d-%m-%Y' )

Oct_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_10_2011.xlsx")
Oct_2011.insert(0, "date_info", "28-10-2011")
Oct_2011['date_info']= pd.to_datetime(Oct_2011['date_info'], format = '%d-%m-%Y' )

Nov_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2011.xlsx")
Nov_2011.insert(0, "date_info", "30-11-2011")
Nov_2011['date_info']= pd.to_datetime(Nov_2011['date_info'], format = '%d-%m-%Y' )

Dec_2011 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2011.xlsx")
Dec_2011.insert(0, "date_info", "30-12-2011")
Dec_2011['date_info']= pd.to_datetime(Dec_2011['date_info'], format = '%d-%m-%Y' )

# %%
#2012
Jan_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2012.xlsx")
Jan_2012.insert(0, "date_info", "31-01-2012")
Jan_2012['date_info']= pd.to_datetime(Jan_2012['date_info'], format = '%d-%m-%Y' )

Feb_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_2_2012.xlsx")
Feb_2012.insert(0, "date_info", "29-02-2012")
Feb_2012['date_info']= pd.to_datetime(Feb_2012['date_info'], format = '%d-%m-%Y' )

Mar_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_3_2012.xlsx")
Mar_2012.insert(0, "date_info", "30-03-2012")
Mar_2012['date_info']= pd.to_datetime(Mar_2012['date_info'], format = '%d-%m-%Y' )

Apr_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2012.xlsx")
Apr_2012.insert(0, "date_info", "30-04-2012")
Apr_2012['date_info']= pd.to_datetime(Apr_2012['date_info'], format = '%d-%m-%Y' )

May_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2012.xlsx")
May_2012.insert(0, "date_info", "31-05-2012")
May_2012['date_info']= pd.to_datetime(May_2012['date_info'], format = '%d-%m-%Y' )

Jun_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2012.xlsx")
Jun_2012.insert(0, "date_info", "28-06-2012")
Jun_2012['date_info']= pd.to_datetime(Jun_2012['date_info'], format = '%d-%m-%Y' )

Jul_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2012.xlsx")
Jul_2012.insert(0, "date_info", "31-07-2012")
Jul_2012['date_info']= pd.to_datetime(Jul_2012['date_info'], format = '%d-%m-%Y' )

Aug_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2012.xlsx")
Aug_2012.insert(0, "date_info", "29-08-2012")
Aug_2012['date_info']= pd.to_datetime(Aug_2012['date_info'], format = '%d-%m-%Y' )

Sep_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_9_2012.xlsx")
Sep_2012.insert(0, "date_info", "28-09-2012")
Sep_2012['date_info']= pd.to_datetime(Sep_2012['date_info'], format = '%d-%m-%Y' )

Oct_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2012.xlsx")
Oct_2012.insert(0, "date_info", "31-10-2012")
Oct_2012['date_info']= pd.to_datetime(Oct_2012['date_info'], format = '%d-%m-%Y' )

Nov_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2012.xlsx")
Nov_2012.insert(0, "date_info", "30-11-2012")
Nov_2012['date_info']= pd.to_datetime(Nov_2012['date_info'], format = '%d-%m-%Y' )

Dec_2012 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_12_2012.xlsx")
Dec_2012.insert(0, "date_info", "28-12-2012")
Dec_2012['date_info']= pd.to_datetime(Dec_2012['date_info'], format = '%d-%m-%Y' )

# %%
#2013
Jan_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2013.xlsx")
Jan_2013.insert(0, "date_info", "31-01-2013")
Jan_2013['date_info']= pd.to_datetime(Jan_2013['date_info'], format = '%d-%m-%Y' )

Feb_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2013.xlsx")
Feb_2013.insert(0, "date_info", "28-02-2013")
Feb_2013['date_info']= pd.to_datetime(Feb_2013['date_info'], format = '%d-%m-%Y' )

Mar_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_3_2013.xlsx")
Mar_2013.insert(0, "date_info", "27-03-2013")
Mar_2013['date_info']= pd.to_datetime(Mar_2013['date_info'], format = '%d-%m-%Y' )

Apr_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2013.xlsx")
Apr_2013.insert(0, "date_info", "30-04-2013")
Apr_2013['date_info']= pd.to_datetime(Apr_2013['date_info'], format = '%d-%m-%Y' )

May_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2013.xlsx")
May_2013.insert(0, "date_info", "31-05-2013")
May_2013['date_info']= pd.to_datetime(May_2013['date_info'], format = '%d-%m-%Y' )

Jun_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2013.xlsx")
Jun_2013.insert(0, "date_info", "28-06-2013")
Jun_2013['date_info']= pd.to_datetime(Jun_2013['date_info'], format = '%d-%m-%Y' )

Jul_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2013.xlsx")
Jul_2013.insert(0, "date_info", "31-07-2013")
Jul_2013['date_info']= pd.to_datetime(Jul_2013['date_info'], format = '%d-%m-%Y' )

Aug_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2013.xlsx")
Aug_2013.insert(0, "date_info", "29-08-2013")
Aug_2013['date_info']= pd.to_datetime(Aug_2013['date_info'], format = '%d-%m-%Y' )

Sep_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2013.xlsx")
Sep_2013.insert(0, "date_info", "30-09-2013")
Sep_2013['date_info']= pd.to_datetime(Sep_2013['date_info'], format = '%d-%m-%Y' )

Oct_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2013.xlsx")
Oct_2013.insert(0, "date_info", "31-10-2013")
Oct_2013['date_info']= pd.to_datetime(Oct_2013['date_info'], format = '%d-%m-%Y' )

Nov_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_11_2013.xlsx")
Nov_2013.insert(0, "date_info", "29-11-2013")
Nov_2013['date_info']= pd.to_datetime(Nov_2013['date_info'], format = '%d-%m-%Y' )

Dec_2013 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2013.xlsx")
Dec_2013.insert(0, "date_info", "30-12-2013")
Dec_2013['date_info']= pd.to_datetime(Dec_2013['date_info'], format = '%d-%m-%Y' )

# %%
#2014
Jan_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2014.xlsx")
Jan_2014.insert(0, "date_info", "31-01-2014")
Jan_2014['date_info']= pd.to_datetime(Jan_2014['date_info'], format = '%d-%m-%Y' )

Feb_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2014.xlsx")
Feb_2014.insert(0, "date_info", "28-02-2014")
Feb_2014['date_info']= pd.to_datetime(Feb_2014['date_info'], format = '%d-%m-%Y' )

Mar_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2014.xlsx")
Mar_2014.insert(0, "date_info", "31-03-2014")
Mar_2014['date_info']= pd.to_datetime(Mar_2014['date_info'], format = '%d-%m-%Y' )

Apr_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2014.xlsx")
Apr_2014.insert(0, "date_info", "30-04-2014")
Apr_2014['date_info']= pd.to_datetime(Apr_2014['date_info'], format = '%d-%m-%Y' )

May_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_5_2014.xlsx")
May_2014.insert(0, "date_info", "30-05-2014")
May_2014['date_info']= pd.to_datetime(May_2014['date_info'], format = '%d-%m-%Y' )

Jun_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2014.xlsx")
Jun_2014.insert(0, "date_info", "30-06-2014")
Jun_2014['date_info']= pd.to_datetime(Jun_2014['date_info'], format = '%d-%m-%Y' )

Jul_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2014.xlsx")
Jul_2014.insert(0, "date_info", "31-07-2014")
Jul_2014['date_info']= pd.to_datetime(Jul_2014['date_info'], format = '%d-%m-%Y' )

Aug_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2014.xlsx")
Aug_2014.insert(0, "date_info", "29-08-2014")
Aug_2014['date_info']= pd.to_datetime(Aug_2014['date_info'], format = '%d-%m-%Y' )

Sep_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2014.xlsx")
Sep_2014.insert(0, "date_info", "30-09-2014")
Sep_2014['date_info']= pd.to_datetime(Sep_2014['date_info'], format = '%d-%m-%Y' )

Oct_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2014.xlsx")
Oct_2014.insert(0, "date_info", "31-10-2014")
Oct_2014['date_info']= pd.to_datetime(Oct_2014['date_info'], format = '%d-%m-%Y' )

Nov_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_11_2014.xlsx")
Nov_2014.insert(0, "date_info", "28-11-2014")
Nov_2014['date_info']= pd.to_datetime(Nov_2014['date_info'], format = '%d-%m-%Y' )

Dec_2014 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2014.xlsx")
Dec_2014.insert(0, "date_info", "31-12-2014")
Dec_2014['date_info']= pd.to_datetime(Dec_2014['date_info'], format = '%d-%m-%Y' )

# %%
#2015
Jan_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_1_2015.xlsx")
Jan_2015.insert(0, "date_info", "31-01-2015")
Jan_2015['date_info']= pd.to_datetime(Jan_2015['date_info'], format = '%d-%m-%Y' )

Feb_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_2_2015.xlsx")
Feb_2015.insert(0, "date_info", "27-02-2015")
Feb_2015['date_info']= pd.to_datetime(Feb_2015['date_info'], format = '%d-%m-%Y' )

Mar_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2015.xlsx")
Mar_2015.insert(0, "date_info", "31-03-2015")
Mar_2015['date_info']= pd.to_datetime(Mar_2015['date_info'], format = '%d-%m-%Y' )

Apr_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2015.xlsx")
Apr_2015.insert(0, "date_info", "30-04-2015")
Apr_2015['date_info']= pd.to_datetime(Apr_2015['date_info'], format = '%d-%m-%Y' )

May_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_5_2015.xlsx")
May_2015.insert(0, "date_info", "29-05-2015")
May_2015['date_info']= pd.to_datetime(May_2015['date_info'], format = '%d-%m-%Y' )

Jun_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2015.xlsx")
Jun_2015.insert(0, "date_info", "30-06-2015")
Jun_2015['date_info']= pd.to_datetime(Jun_2015['date_info'], format = '%d-%m-%Y' )

Jul_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2015.xlsx")
Jul_2015.insert(0, "date_info", "31-07-2015")
Jul_2015['date_info']= pd.to_datetime(Jul_2015['date_info'], format = '%d-%m-%Y' )

Aug_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2015.xlsx")
Aug_2015.insert(0, "date_info", "31-08-2015")
Aug_2015['date_info']= pd.to_datetime(Aug_2015['date_info'], format = '%d-%m-%Y' )

Sep_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2015.xlsx")
Sep_2015.insert(0, "date_info", "30-09-2015")
Sep_2015['date_info']= pd.to_datetime(Sep_2015['date_info'], format = '%d-%m-%Y' )

Oct_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_10_2015.xlsx")
Oct_2015.insert(0, "date_info", "30-10-2015")
Oct_2015['date_info']= pd.to_datetime(Oct_2015['date_info'], format = '%d-%m-%Y' )

Nov_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2015.xlsx")
Nov_2015.insert(0, "date_info", "30-11-2015")
Nov_2015['date_info']= pd.to_datetime(Nov_2015['date_info'], format = '%d-%m-%Y' )

Dec_2015 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2015.xlsx")
Dec_2015.insert(0, "date_info", "31-12-2015")
Dec_2015['date_info']= pd.to_datetime(Dec_2015['date_info'], format = '%d-%m-%Y' )

# %%
#2016
Jan_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_1_2016.xlsx")
Jan_2016.insert(0, "date_info", "29-01-2016")
Jan_2016['date_info']= pd.to_datetime(Jan_2016['date_info'], format = '%d-%m-%Y' )

Feb_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_2_2016.xlsx")
Feb_2016.insert(0, "date_info", "29-02-2016")
Feb_2016['date_info']= pd.to_datetime(Feb_2016['date_info'], format = '%d-%m-%Y' )

Mar_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2016.xlsx")
Mar_2016.insert(0, "date_info", "31-03-2016")
Mar_2016['date_info']= pd.to_datetime(Mar_2016['date_info'], format = '%d-%m-%Y' )

Apr_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_4_2016.xlsx")
Apr_2016.insert(0, "date_info", "29-04-2016")
Apr_2016['date_info']= pd.to_datetime(Apr_2016['date_info'], format = '%d-%m-%Y' )

May_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2016.xlsx")
May_2016.insert(0, "date_info", "31-015-2016")
May_2016['date_info']= pd.to_datetime(May_2016['date_info'], format = '%d-%m-%Y' )

Jun_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2016.xlsx")
Jun_2016.insert(0, "date_info", "30-06-2016")
Jun_2016['date_info']= pd.to_datetime(Jun_2016['date_info'], format = '%d-%m-%Y' )

Jul_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_7_2016.xlsx")
Jul_2016.insert(0, "date_info", "27-07-2016")
Jul_2016['date_info']= pd.to_datetime(Jul_2016['date_info'], format = '%d-%m-%Y' )

Aug_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2016.xlsx")
Aug_2016.insert(0, "date_info", "31-08-2016")
Aug_2016['date_info']= pd.to_datetime(Aug_2016['date_info'], format = '%d-%m-%Y' )

Sep_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2016.xlsx")
Sep_2016.insert(0, "date_info", "30-09-2016")
Sep_2016['date_info']= pd.to_datetime(Sep_2016['date_info'], format = '%d-%m-%Y' )

Oct_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2016.xlsx")
Oct_2016.insert(0, "date_info", "31-10-2016")
Oct_2016['date_info']= pd.to_datetime(Oct_2016['date_info'], format = '%d-%m-%Y' )

Nov_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2016.xlsx")
Nov_2016.insert(0, "date_info", "30-11-2016")
Nov_2016['date_info']= pd.to_datetime(Nov_2016['date_info'], format = '%d-%m-%Y' )

Dec_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_12_2016.xlsx")
Dec_2016.insert(0, "date_info", "30-12-2016")
Dec_2016['date_info']= pd.to_datetime(Dec_2016['date_info'], format = '%d-%m-%Y' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\AnacondaPython\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\AnacondaPython\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7412\628997656.py in <module>
#      18 May_2016 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2016.xlsx")
# ...

# %%
#2017
Jan_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2017.xlsx")
Jan_2017.insert(0, "date_info", "31-01-2017")
Jan_2017['date_info']= pd.to_datetime(Jan_2017['date_info'], format = '%d-%m-%Y' )

Feb_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2017.xlsx")
Feb_2017.insert(0, "date_info", "28-02-2017")
Feb_2017['date_info']= pd.to_datetime(Feb_2017['date_info'], format = '%d-%m-%Y' )

Mar_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2017.xlsx")
Mar_2017.insert(0, "date_info", "31-03-2017")
Mar_2017['date_info']= pd.to_datetime(Mar_2017['date_info'], format = '%d-%m-%Y' )

Apr_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_4_2017.xlsx")
Apr_2017.insert(0, "date_info", "28-04-2017")
Apr_2017['date_info']= pd.to_datetime(Apr_2017['date_info'], format = '%d-%m-%Y' )

May_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2017.xlsx")
May_2017.insert(0, "date_info", "31-05-2017")
May_2017['date_info']= pd.to_datetime(May_2017['date_info'], format = '%d-%m-%Y' )

Jun_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2017.xlsx")
Jun_2017.insert(0, "date_info", "28-06-2017")
Jun_2017['date_info']= pd.to_datetime(Jun_2017['date_info'], format = '%d-%m-%Y' )

Jul_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2017.xlsx")
Jul_2017.insert(0, "date_info", "31-07-2017")
Jul_2017['date_info']= pd.to_datetime(Jul_2017['date_info'], format = '%d-%m-%Y' )

Aug_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2017.xlsx")
Aug_2017.insert(0, "date_info", "31-08-2017")
Aug_2017['date_info']= pd.to_datetime(Aug_2017['date_info'], format = '%d-%m-%Y' )

Sep_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_9_2017.xlsx")
Sep_2017.insert(0, "date_info", "29-09-2017")
Sep_2017['date_info']= pd.to_datetime(Sep_2017['date_info'], format = '%d-%m-%Y' )

Oct_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2017.xlsx")
Oct_2017.insert(0, "date_info", "31-10-2017")
Oct_2017['date_info']= pd.to_datetime(Oct_2017['date_info'], format = '%d-%m-%Y' )

Nov_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2017.xlsx")
Nov_2017.insert(0, "date_info", "30-11-2017")
Nov_2017['date_info']= pd.to_datetime(Nov_2017['date_info'], format = '%d-%m-%Y' )

Dec_2017 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_12_2017.xlsx")
Dec_2017.insert(0, "date_info", "29-12-2017")
Dec_2017['date_info']= pd.to_datetime(Dec_2017['date_info'], format = '%d-%m-%Y' )

# %%
#2018
Jan_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2018.xlsx")
Jan_2018.insert(0, "date_info", "31-01-2018")
Jan_2018['date_info']= pd.to_datetime(Jan_2018['date_info'], format = '%d-%m-%Y' )

Feb_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2018.xlsx")
Feb_2018.insert(0, "date_info", "28-02-2018")
Feb_2018['date_info']= pd.to_datetime(Feb_2018['date_info'], format = '%d-%m-%Y' )

Mar_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_3_2018.xlsx")
Mar_2018.insert(0, "date_info", "28-03-2018")
Mar_2018['date_info']= pd.to_datetime(Mar_2018['date_info'], format = '%d-%m-%Y' )

Apr_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2018.xlsx")
Apr_2018.insert(0, "date_info", "30-04-2018")
Apr_2018['date_info']= pd.to_datetime(Apr_2018['date_info'], format = '%d-%m-%Y' )

May_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2018.xlsx")
May_2018.insert(0, "date_info", "31-05-2018")
May_2018['date_info']= pd.to_datetime(May_2018['date_info'], format = '%d-%m-%Y' )

Jun_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2018.xlsx")
Jun_2018.insert(0, "date_info", "28-06-2018")
Jun_2018['date_info']= pd.to_datetime(Jun_2018['date_info'], format = '%d-%m-%Y' )

Jul_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2018.xlsx")
Jul_2018.insert(0, "date_info", "31-07-2018")
Jul_2018['date_info']= pd.to_datetime(Jul_2018['date_info'], format = '%d-%m-%Y' )

Aug_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_8_2018.xlsx")
Aug_2018.insert(0, "date_info", "29-08-2018")
Aug_2018['date_info']= pd.to_datetime(Aug_2018['date_info'], format = '%d-%m-%Y' )

Sep_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_9_2018.xlsx")
Sep_2018.insert(0, "date_info", "28-09-2018")
Sep_2018['date_info']= pd.to_datetime(Sep_2018['date_info'], format = '%d-%m-%Y' )

Oct_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_10_2018.xlsx")
Oct_2018.insert(0, "date_info", "31-10-2018")
Oct_2018['date_info']= pd.to_datetime(Oct_2018['date_info'], format = '%d-%m-%Y' )

Nov_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2018.xlsx")
Nov_2018.insert(0, "date_info", "30-11-2018")
Nov_2018['date_info']= pd.to_datetime(Nov_2018['date_info'], format = '%d-%m-%Y' )

Dec_2018 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2018.xlsx")
Dec_2018.insert(0, "date_info", "31-12-2018")
Dec_2018['date_info']= pd.to_datetime(Dec_2018['date_info'], format = '%d-%m-%Y' )

# %%
#2019
Jan_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2019.xlsx")
Jan_2019.insert(0, "date_info", "31-01-2019")
Jan_2019['date_info']= pd.to_datetime(Jan_2019['date_info'], format = '%d-%m-%Y' )

Feb_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2019.xlsx")
Feb_2019.insert(0, "date_info", "28-02-2019")
Feb_2019['date_info']= pd.to_datetime(Feb_2019['date_info'], format = '%d-%m-%Y' )

Mar_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_3_2019.xlsx")
Mar_2019.insert(0, "date_info", "28-03-2019")
Mar_2019['date_info']= pd.to_datetime(Mar_2019['date_info'], format = '%d-%m-%Y' )

Apr_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2019.xlsx")
Apr_2019.insert(0, "date_info", "30-04-2019")
Apr_2019['date_info']= pd.to_datetime(Apr_2019['date_info'], format = '%d-%m-%Y' )

May_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2019.xlsx")
May_2019.insert(0, "date_info", "31-05-2019")
May_2019['date_info']= pd.to_datetime(May_2019['date_info'], format = '%d-%m-%Y' )

Jun_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_6_2019.xlsx")
Jun_2019.insert(0, "date_info", "28-06-2019")
Jun_2019['date_info']= pd.to_datetime(Jun_2019['date_info'], format = '%d-%m-%Y' )

Jul_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2019.xlsx")
Jul_2019.insert(0, "date_info", "31-07-2019")
Jul_2019['date_info']= pd.to_datetime(Jul_2019['date_info'], format = '%d-%m-%Y' )

Aug_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_8_2019.xlsx")
Aug_2019.insert(0, "date_info", "27-08-2019")
Aug_2019['date_info']= pd.to_datetime(Aug_2019['date_info'], format = '%d-%m-%Y' )

Sep_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2019.xlsx")
Sep_2019.insert(0, "date_info", "30-19-2019")
Sep_2019['date_info']= pd.to_datetime(Sep_2019['date_info'], format = '%d-%m-%Y' )

Oct_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_10_2019.xlsx")
Oct_2019.insert(0, "date_info", "31-10-2019")
Oct_2019['date_info']= pd.to_datetime(Oct_2019['date_info'], format = '%d-%m-%Y' )

Nov_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_11_2019.xlsx")
Nov_2019.insert(0, "date_info", "29-11-2019")
Nov_2019['date_info']= pd.to_datetime(Nov_2019['date_info'], format = '%d-%m-%Y' )

Dec_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2019.xlsx")
Dec_2019.insert(0, "date_info", "31-21-2019")
Dec_2019['date_info']= pd.to_datetime(Dec_2019['date_info'], format = '%d-%m-%Y' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\AnacondaPython\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\AnacondaPython\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7412\1691840939.py in <module>
#      34 Sep_2019 = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2019.xlsx")
# ...

# %%
#2020
Jan_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2020.xlsx")
Jan_2020.insert(0, "date_info", "31-01-2020")
Jan_2020['date_info']= pd.to_datetime(Jan_2020['date_info'], format = '%d-%m-%Y' )

Feb_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2020.xlsx")
Feb_2020.insert(0, "date_info", "28-02-2020")
Feb_2020['date_info']= pd.to_datetime(Feb_2020['date_info'], format = '%d-%m-%Y' )

Mar_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2020.xlsx")
Mar_2020.insert(0, "date_info", "31-03-2020")
Mar_2020['date_info']= pd.to_datetime(Mar_2020['date_info'], format = '%d-%m-%Y' )

Apr_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2020.xlsx")
Apr_2020.insert(0, "date_info", "30-04-2020")
Apr_2020['date_info']= pd.to_datetime(Apr_2020['date_info'], format = '%d-%m-%Y' )

May_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_5_2020.xlsx")
May_2020.insert(0, "date_info", "29-05-2020")
May_2020['date_info']= pd.to_datetime(May_2020['date_info'], format = '%d-%m-%Y' )

Jun_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2020.xlsx")
Jun_2020.insert(0, "date_info", "30-06-2020")
Jun_2020['date_info']= pd.to_datetime(Jun_2020['date_info'], format = '%d-%m-%Y' )

Jul_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_7_2020.xlsx")
Jul_2020.insert(0, "date_info", "31-07-2020")
Jul_2020['date_info']= pd.to_datetime(Jul_2020['date_info'], format = '%d-%m-%Y' )

Aug_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2020.xlsx")
Aug_2020.insert(0, "date_info", "31-08-2020")
Aug_2020['date_info']= pd.to_datetime(Aug_2020['date_info'], format = '%d-%m-%Y' )

Sep_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2020.xlsx")
Sep_2020.insert(0, "date_info", "30-09-2020")
Sep_2020['date_info']= pd.to_datetime(Sep_2020['date_info'], format = '%d-%m-%Y' )

Oct_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_10_2020.xlsx")
Oct_2020.insert(0, "date_info", "30-10-2020")
Oct_2020['date_info']= pd.to_datetime(Oct_2020['date_info'], format = '%d-%m-%Y' )

Nov_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2020.xlsx")
Nov_2020.insert(0, "date_info", "30-11-2020")
Nov_2020['date_info']= pd.to_datetime(Nov_2020['date_info'], format = '%d-%m-%Y' )

Dec_2020  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2020.xlsx")
Dec_2020.insert(0, "date_info", "31-12-2020")
Dec_2020['date_info']= pd.to_datetime(Dec_2020['date_info'], format = '%d-%m-%Y' )

# %%
#2021
Jan_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_1_2021.xlsx")
Jan_2021.insert(0, "date_info", "29-01-2021")
Jan_2021['date_info']= pd.to_datetime(Jan_2021['date_info'], format = '%d-%m-%Y' )

Feb_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_26_2_2021.xlsx")
Feb_2021.insert(0, "date_info", "26-02-2021")
Feb_2021['date_info']= pd.to_datetime(Feb_2021['date_info'], format = '%d-%m-%Y' )

Mar_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2021.xlsx")
Mar_2021.insert(0, "date_info", "31-03-2021")
Mar_2021['date_info']= pd.to_datetime(Mar_2021['date_info'], format = '%d-%m-%Y' )

Apr_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_4_2021.xlsx")
Apr_2021.insert(0, "date_info", "30-04-2021")
Apr_2021['date_info']= pd.to_datetime(Apr_2021['date_info'], format = '%d-%m-%Y' )

May_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2021.xlsx")
May_2021.insert(0, "date_info", "31-05-2021")
May_2021['date_info']= pd.to_datetime(May_2021['date_info'], format = '%d-%m-%Y' )

Jun_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2021.xlsx")
Jun_2021.insert(0, "date_info", "30-06-2021")
Jun_2021['date_info']= pd.to_datetime(Jun_2021['date_info'], format = '%d-%m-%Y' )

Jul_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_7_2021.xlsx")
Jul_2021.insert(0, "date_info", "30-07-2021")
Jul_2021['date_info']= pd.to_datetime(Jul_2021['date_info'], format = '%d-%m-%Y' )

Aug_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2021.xlsx")
Aug_2021.insert(0, "date_info", "31-08-2021")
Aug_2021['date_info']= pd.to_datetime(Aug_2021['date_info'], format = '%d-%m-%Y' )

Sep_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_9_2021.xlsx")
Sep_2021.insert(0, "date_info", "30-09-2021")
Sep_2021['date_info']= pd.to_datetime(Sep_2021['date_info'], format = '%d-%m-%Y' )

Oct_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_10_2021.xlsx")
Oct_2021.insert(0, "date_info", "29-10-2021")
Oct_2021['date_info']= pd.to_datetime(Oct_2021['date_info'], format = '%d-%m-%Y' )

Nov_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_11_2021.xlsx")
Nov_2021.insert(0, "date_info", "30-11-2021")
Nov_2021['date_info']= pd.to_datetime(Nov_2021['date_info'], format = '%d-%m-%Y' )

Dec_2021  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_12_2021.xlsx")
Dec_2021.insert(0, "date_info", "31-12-2021")
Dec_2021['date_info']= pd.to_datetime(Dec_2021['date_info'], format = '%d-%m-%Y' )

# %%
#2022
Jan_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_1_2022.xlsx")
Jan_2022.insert(0, "date_info", "31-01-2022")
Jan_2022['date_info']= pd.to_datetime(Jan_2022['date_info'], format = '%d-%m-%Y' )

Feb_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_28_2_2022.xlsx")
Feb_2022.insert(0, "date_info", "28-02-2022")
Feb_2022['date_info']= pd.to_datetime(Feb_2022['date_info'], format = '%d-%m-%Y' )

Mar_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_3_2022.xlsx")
Mar_2022.insert(0, "date_info", "31-03-2022")
Mar_2022['date_info']= pd.to_datetime(Mar_2022['date_info'], format = '%d-%m-%Y' )

Apr_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_29_4_2022.xlsx")
Apr_2022.insert(0, "date_info", "29-04-2022")
Apr_2022['date_info']= pd.to_datetime(Apr_2022['date_info'], format = '%d-%m-%Y' )

May_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_5_2022.xlsx")
May_2022.insert(0, "date_info", "31-05-2022")
May_2022['date_info']= pd.to_datetime(May_2022['date_info'], format = '%d-%m-%Y' )

Jun_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_30_6_2022.xlsx")
Jun_2022.insert(0, "date_info", "30-06-2022")
Jun_2022['date_info']= pd.to_datetime(Jun_2022['date_info'], format = '%d-%m-%Y' )

Jul_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_27_7_2022.xlsx")
Jul_2022.insert(0, "date_info", "27-07-2022")
Jul_2022['date_info']= pd.to_datetime(Jul_2022['date_info'], format = '%d-%m-%Y' )

Aug_2022  = pd.read_excel (r"../../_data/sbs/B_RawData/bancos/table_clean_31_8_2022.xlsx")
Aug_2022.insert(0, "date_info", "31-08-2022")
Aug_2022['date_info']= pd.to_datetime(Aug_2022['date_info'], format = '%d-%m-%Y' )

# %% [markdown]
# 2. Append all this datasets and generate a unique dataframe. This newdataset should have information at `rate interest` and `date` level. The columns should be the name of the banks. Be careful since not all the excel files have the same format. **It is totally prohibited to manipulate manually the excel files. This kind of action means NO GRADE on this project.**
# 3. What are the top 5 banks each year with the highest interest rate at `Préstamos hipotecarios para vivienda`, `Consumo -
# Tarjetas de Crédito`. Present a dataframe with these variables: `year`, `rate_concept`, `banks`, `rate_value`.
# 4. We want to save this dataset in the folder **_output/sbs/group_#**, but we want to save a file per bank. We want to have the information disaggregated at the bank level. Please, save your files with the name of the bank. Avoid blank spaces and use only lowercase letters. Generate the folder of your group using python code. **Hint: os library**
