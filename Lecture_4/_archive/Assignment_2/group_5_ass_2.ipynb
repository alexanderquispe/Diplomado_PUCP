# %% [markdown]
# # 1 Assignment 2

# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request

# %% [markdown]
# 1. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %%
#pip install pyreadstat
#pip install savReaderWriter
# Out:
# Requirement already satisfied: pyreadstat in c:\anaconda\lib\site-packages (1.1.3)
# Requirement already satisfied: pandas>0.24.0 in c:\anaconda\lib\site-packages (from pyreadstat) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda\lib\site-packages (from pandas>0.24.0->pyreadstat) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\anaconda\lib\site-packages (from pandas>0.24.0->pyreadstat) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>0.24.0->pyreadstat) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas>0.24.0->pyreadstat) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import REC0111.sav

# %%
rec_1 = pd.read_spss(r"../../_data/endes/2019/REC0111.sav")

# %%
rec_1.head(5)
# Out:
#       ID1             HHID              CASEID  V001  V002  V003  V004  \
# 0  2019.0        000100201        000100201  2   1.0   2.0   2.0   1.0
# 1  2019.0        000100201        000100201  3   1.0   2.0   3.0   1.0
# 2  2019.0        000102801        000102801  2   1.0  28.0   2.0   1.0
# 3  2019.0        000102801        000102801  6   1.0  28.0   6.0   1.0
# 4  2019.0        000104801        000104801  2   1.0  48.0   2.0   1.0
#
#      V007    V008  V009  ...  QD333_4  QD333_5  QD333_6  UBIGEO V022  \
# 0  2019.0  1434.0   4.0  ...       No       No       No  010101  3.0
# 1  2019.0  1434.0   1.0  ...       No       No       No  010101  3.0
# 2  2019.0  1434.0   6.0  ...       No       No       No  010101  3.0
# 3  2019.0  1434.0   3.0  ...       No       No       No  010101  3.0
# 4  2019.0  1434.0   5.0  ...       No       No       No  010101  3.0
#
#        V005    V190      V191                                   mujeres12a49  \
# 0  154803.0    Rico  1.234450                Mujeres de 15 a 49 años de edad
# 1  154803.0    Rico  1.234450  Mujeres de 12 a 14 de edad, nunca embarazadas
# 2  154803.0    Rico  1.295611                Mujeres de 15 a 49 años de edad
# 3  154803.0    Rico  1.295611                Mujeres de 15 a 49 años de edad
# 4  154803.0  Pobrer -0.256431                Mujeres de 15 a 49 años de edad
#
#    NCONGLOME
# 0     7065.0
# 1     7065.0
# 2     7065.0
# 3     7065.0
# 4     7065.0
#
# [5 rows x 105 columns]

# %%
# Método 1

import savReaderWriter as sav
with sav.SavHeaderReader(r"../../_data/endes/2019/REC0111.sav", ioUtf8=True) as header:
    metadata1 = header.all()
    value_labels1 = metadata1.valueLabels
    var_labels1 = metadata1.varLabels

# %%
# Método 2

import pyreadstat
rec1, meta = pyreadstat.read_sav( r"../../_data/endes/2019/REC0111.sav" )
value_labels1 = meta.variable_value_labels
var_labels1 = meta.column_names_to_labels

# %%
rec_1.attrs['value_labels'] = value_labels1
rec_1.attrs['var_labels'] = var_labels1

# %%
print(var_labels1["V131"])
value_labels1["V131"]
# Out:
# Etnicidad
# {1.0: 'Quechua',
#  2.0: 'Aimara',
#  3.0: 'Ashaninka',
#  4.0: 'Awajún/Aguaruna',
#  5.0: 'Shipibo/Konibo',
#  6.0: 'Shawi/Chayahuita',
#  7.0: 'Matsigenka/ Machiguenga',
#  8.0: 'Achuar',
#  9.0: 'Otra lengua nativa u originaria',
#  10.0: 'Castellano',
#  11.0: 'Portugués',
#  12.0: 'Otra lengua extranjera'}

# %% [markdown]
# #### Import RE223132.sav

# %%
rec_2 = pd.read_spss(r"../../_data/endes/2019/RE223132.sav")

# %%
# Método 1

with sav.SavHeaderReader(r"../../_data/endes/2019/RE223132.sav", ioUtf8=True) as header:
    metadata2 = header.all()
    value_labels2 = metadata2.valueLabels
    var_labels2 = metadata2.varLabels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ccff528af9bb> in <module>
#       1 # Método 1
#       2
# ----> 3 with sav.SavHeaderReader(r"../../_data/endes/2019/RE223132.sav", ioUtf8=True) as header:
#       4     metadata2 = header.all()
#       5     value_labels2 = metadata2.valueLabels
#
# NameError: name 'sav' is not defined

# %%
# Método 2

import pyreadstat
rec1, meta = pyreadstat.read_sav( r"../../_data/endes/2019/RE223132.sav" )
value_labels2 = meta.variable_value_labels
var_labels2 = meta.column_names_to_labels

# %%
rec_2.attrs['value_labels'] = value_labels2
rec_2.attrs['var_labels'] = var_labels2

# %%
print(var_labels2['V213'])
value_labels2['V213']
# Out:
# Actualmente embarazada
# {0.0: 'No o no está segura', 1.0: 'Sí'}

# %% [markdown]
# #### Import RE516171.sav

# %%
rec_3 = pd.read_spss(r"../../_data/endes/2019/RE516171.sav")

# %%
# Método 1

with sav.SavHeaderReader(r"../../_data/endes/2019/RE516171.sav", ioUtf8=True) as header:
    metadata3 = header.all()
    value_labels3 = metadata3.valueLabels
    var_labels3 = metadata3.varLabels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f2a48e48a4ea> in <module>
#       1 # Método 1
#       2
# ----> 3 with sav.SavHeaderReader(r"../../_data/endes/2019/RE516171.sav", ioUtf8=True) as header:
#       4     metadata3 = header.all()
#       5     value_labels3 = metadata3.valueLabels
#
# NameError: name 'sav' is not defined

# %%
# Método 2

import pyreadstat
rec1, meta = pyreadstat.read_sav( r"../../_data/endes/2019/RE516171.sav" )
value_labels3 = meta.variable_value_labels
var_labels3 = meta.column_names_to_labels

# %%
rec_3.attrs['value_labels'] = value_labels3
rec_3.attrs['var_labels'] = var_labels3

# %%
print(var_labels3['V501'])
print(value_labels3['V501'])
print(var_labels3['V525'])
print(value_labels3['V525'])
# Out:
# Estado civil actual
# {0.0: 'Nunca casada', 1.0: 'Casado', 2.0: 'Viviendo juntos', 3.0: 'Viuda', 4.0: 'Divorciada', 5.0: 'No viven juntos'}
# Edad en la primera relación sexual
# {0.0: 'Nunca tuvo relaciones sexuales', 96.0: 'En la primera union'}

# %% [markdown]
# 2. Select the following columns for each data set:
# |Data|Columns|
# |---|---|
# |rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133 |
# |rec2| CASEID, V201, V218, V301, V302, V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380 |
# |rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715 |
#
#
# Additioanlly, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter, `for loop`,   and [this link](https://stackoverflow.com/questions/3420122/filter-dict-to-contain-only-certain-keys) to update the var and value dictionary.**

# %%
var_labels1.keys()
# Out:
# dict_keys(['ID1', 'HHID', 'CASEID', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 'V010', 'V011', 'V012', 'V013', 'V014', 'V015', 'V017', 'V018', 'V019', 'V019A', 'V020', 'V021', 'V023', 'V024', 'V025', 'V026', 'V027', 'V028', 'V029', 'V030', 'V031', 'V032', 'V033', 'V034', 'V040', 'V042', 'V043', 'V044', 'V000', 'Q105DD', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V113', 'V115', 'V116', 'V119', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V127', 'V128', 'V129', 'V130', 'V131', 'V133', 'V134', 'V135', 'V136', 'V137', 'V138', 'V139', 'V140', 'V141', 'V149', 'V150', 'V151', 'V152', 'V153', 'AWFACTT', 'AWFACTU', 'AWFACTR', 'AWFACTE', 'AWFACTW', 'V155', 'V156', 'V157', 'V158', 'V159', 'V160', 'V161', 'V166', 'V167', 'V168', 'ML101', 'QD333_1', 'QD333_2', 'QD333_3', 'QD333_4', 'QD333_5', 'QD333_6', 'UBIGEO', 'V022', 'V005', 'V190', 'V191', 'mujeres12a49', 'NCONGLOME'])

# %%
rec1_1 = rec_1.filter( items = ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 'V010', 'V011', 'V012',
                       'V024', 'V102', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V127', 'V133'  ])

# %%
rec1_1.shape
# Out:
# (38335, 22)

# %%
var_labels2.keys()
# Out:
# dict_keys(['ID1', 'CASEID', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V210', 'V211', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V218', 'V219', 'V220', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V230', 'V231', 'V232', 'V233', 'V234', 'V235', 'V237', 'V238', 'V239', 'V240', 'V241', 'V242', 'V243', 'V301', 'V302', 'V310', 'V311', 'V312', 'V313', 'V315', 'V316', 'V317', 'V318', 'V319', 'V320', 'V321', 'V322', 'V323', 'V323A', 'V325A', 'V326', 'V327', 'V337', 'V359', 'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380', 'V384A', 'V384B', 'V384C', 'V393', 'V394', 'V395', 'V3A00A', 'V3A00B', 'V3A00C', 'V3A00D', 'V3A00E', 'V3A00F', 'V3A00G', 'V3A00H', 'V3A00I', 'V3A00J', 'V3A00K', 'V3A00L', 'V3A00M', 'V3A00N', 'V3A00O', 'V3A00P', 'V3A00Q', 'V3A00R', 'V3A00S', 'V3A00T', 'V3A00U', 'V3A00V', 'V3A00W', 'V3A00X', 'V3A00Y', 'V3A00Z', 'V3A01', 'V3A02', 'V3A03', 'V3A04', 'V3A05', 'V3A06', 'V3A07', 'V3A08A', 'V3A08B', 'V3A08C', 'V3A08D', 'V3A08E', 'V3A08F', 'V3A08G', 'V3A08H', 'V3A08I', 'V3A08J', 'V3A08K', 'V3A08L', 'V3A08M', 'V3A08N', 'V3A08O', 'V3A08P', 'V3A08Q', 'V3A08R', 'V3A08S', 'V3A08T', 'V3A08U', 'V3A08V', 'V3A08W', 'V3A08X', 'V3A08Z', 'V3A09A', 'V3A09B', 'V305_01', 'V305_02', 'V305_03', 'V305_05', 'V305_06', 'V305_07', 'V305_08', 'V305_09', 'V305_10', 'V305_11', 'V305_13', 'V305_14', 'V305_15', 'V305_16', 'V307_01', 'V307_02', 'V307_03', 'V307_04', 'V307_05', 'V307_06', 'V307_07', 'V307_08', 'V307_09', 'V307_10', 'V307_11', 'V307_12', 'V307_13', 'V307_14', 'V307_15', 'V307_16', 'QI302_05A', 'QI302_05B'])

# %%
rec2_1 = rec_2.filter( items = ['CASEID', 'V201', 'V218', 'V301', 'V302', 'V323', 'V323A', 'V325A', 'V326', 'V327', 'V337', 'V359',
                       'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380'  ])
rec2_1.shape
# Out:
# (36922, 25)

# %%
rec_3.columns
# Out:
# Index(['ID1', 'CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507',
#        'V508', 'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V527', 'V528',
#        'V529', 'V530', 'V531', 'V532', 'V535', 'V536', 'V537', 'V538', 'V539',
#        'V540', 'V541', 'V602', 'V603', 'V604', 'V605', 'V613', 'V614', 'V616',
#        'V621', 'V623', 'V624', 'V625', 'V626', 'V627', 'V628', 'V629', 'V631',
#        'V632', 'V633A', 'V633B', 'V633C', 'V633D', 'V633E', 'V633F', 'V633G',
#        'V634', 'V701', 'V702', 'V704', 'V705', 'V714', 'V714A', 'V715', 'V716',
#        'V717', 'V719', 'V721', 'V729', 'V730', 'V731', 'V732', 'V739', 'V740',
#        'V741', 'V743A', 'V743B', 'V743C', 'V743D', 'V743E', 'V743F', 'V744A',
#        'V744B', 'V744C', 'V744D', 'V744E', 'V746'],
#       dtype='object')

# %%
rec3_1 = rec_3.loc[ : , ['CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507',
       'V508', 'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V613', 'V714', 'V715']]
rec3_1.shape
# Out:
# (33311, 18)

# %%
selected_cols_rec1_1 = rec1_1.columns
new_var_labels1 = { col: var_labels1[ col ] for col in selected_cols_rec1_1 }
new_value_labels1 = { key: value_labels1[ key ] for key in selected_cols_rec1_1 if key in value_labels1.keys() }

# %%
selected_cols_rec2_1 = rec2_1.columns
new_var_labels2 = { col: var_labels2[ col ] for col in selected_cols_rec2_1 }
new_value_labels2 = { key: value_labels2[ key ] for key in selected_cols_rec2_1 if key in value_labels2.keys() }

# %%
selected_cols_rec3_1 = rec3_1.columns
new_var_labels3 = { col: var_labels3[ col ] for col in selected_cols_rec3_1 }
new_value_labels3 = { key: value_labels3[ key ] for key in selected_cols_rec3_1 if key in value_labels3.keys() }

# %% [markdown]
# 3. Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %%
# creating a new column with df.assign

rec1_1.assign(year = 2019)
# Out:
#                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0            000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1            000100201  3  PE6     1.0   2.0   3.0     1.0  2019.0  1434.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2019.0  1434.0
# 3            000102801  6  PE6     1.0  28.0   6.0     1.0  2019.0  1434.0
# 4            000104801  2  PE6     1.0  48.0   2.0     1.0  2019.0  1434.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 38330        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 38331        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 38332        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 38333        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 38334        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
#        V009    V010  ...    V102  V120 V121 V122 V123 V124 V125  \
# 0       4.0  1986.0  ...  Urbano    Si   Si   Si   No   No   No
# 1       1.0  2007.0  ...  Urbano    Si   Si   Si   No   No   No
# 2       6.0  1983.0  ...  Urbano    Si   Si   Si   Si   Si   Si
# 3       3.0  1970.0  ...  Urbano    Si   Si   Si   Si   Si   Si
# 4       5.0  1991.0  ...  Urbano    No   No   No   No   No   No
# ...     ...     ...  ...     ...   ...  ...  ...  ...  ...  ...
# 38330  12.0  1971.0  ...   Rural    No   No   No   No   No   No
# 38331   6.0  1988.0  ...   Rural    No   No   No   No   No   No
# 38332   7.0  1973.0  ...   Rural    No   No   No   No   No   No
# 38333  12.0  1994.0  ...   Rural    No   No   No   No   No   No
# 38334  10.0  1996.0  ...   Rural    No   No   No   No   No   No
#
#                                 V127  V133  year
# 0      Losetas, terrazos o similares  16.0  2019
# 1      Losetas, terrazos o similares   6.0  2019
# 2      Losetas, terrazos o similares  16.0  2019
# 3      Losetas, terrazos o similares   4.0  2019
# 4                   Cemento/ladrillo   1.0  2019
# ...                              ...   ...   ...
# 38330                           Pona   4.0  2019
# 38331                           Pona   6.0  2019
# 38332                           Pona   3.0  2019
# 38333                           Pona   9.0  2019
# 38334                           Pona   9.0  2019
#
# [38335 rows x 23 columns]

# %%
# updating the new variable in the new_var_labels1 dictionary

new_var_labels1.update({"Year": "Year of the survey"})
new_var_labels1.get('Year')
# Out:
# 'Year of the survey'

# %% [markdown]
# 4. Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`. **Hint: Use [this link](https://stackoverflow.com/questions/53645882/pandas-merging-101)**

# %%
(rec1_1.shape, rec2_1.shape)
# Out:
# ((38335, 22), (36922, 25))

# %%
rec12_merge = rec1_1.merge(rec2_1 , 
                           on = [ 'CASEID'], 
                           how = "left", 
                           validate = "m:1" )
rec12_merge.shape
# Out:
# (38335, 46)

# %%
endes_2019 = rec12_merge.merge(rec3_1, 
                               on = [ 'CASEID']
                               , how = "left",
                               validate = "m:1" )
endes_2019.shape
# Out:
# (38335, 63)

# %% [markdown]
# 5. Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. Your final output should be equal to `endes_2019_ta` object **Hint: Use `update` method.**

# %%
output = urllib.request.urlopen(r'https://www.dropbox.com/s/gwcssinb1j9zr6s/endes_2019_ta.pkl?dl=1')
endes_2019_ta = pickle.load( output )

# %%
# Unifying all the new_var_labels

new_var_labels1.update(new_var_labels2)
new_var_labels1.update(new_var_labels3)

# naming it var_labels
var_labels = new_var_labels1

# %%
# Unifying all the new_var_labels

new_value_labels1.update(new_value_labels2)
new_value_labels1.update(new_value_labels3)

# naming it var_labels
value_labels = new_value_labels1

# %%
endes_2019.attrs['var_labels'] = var_labels
endes_2019.attrs['value_labels'] = value_labels

# %%
endes_2019.attrs[ 'var_labels' ] == endes_2019_ta.attrs[ 'var_labels' ]
# Out:
# False

# %%
endes_2019.attrs[ 'value_labels' ] == endes_2019_ta.attrs[ 'value_labels' ]
# Out:
# False

# %% [markdown]
# 6. Now, replicate your code of the prevoius sections but for years **2019, 2018, 2017, 2016, 2015**. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their **variables and values labels** from this path `"../../_data/endes/"`. For this excersie you must use a for loop. This loop must iterate over **2019, 2018, 2017, 2016, 2015 folders** and import these files. All the files have the same name. You must store these files and their labels in a nested dictionary named as `all_data`. The keys of the dictionary should be named as `year_2019`, for example, and the keys of the nested dictionary should be `data`, `var_labels`, and `value_labels`. The output of this exercise should be equal to the `all_data_ta` object. **Hint: Use [this link](https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=4d6de78e00e7001f16bf6473c2eb7ce24fb611cd&device=unknown_device&enc_url=&logged_in=true&nwo=alexanderquispe%2FDiplomado_PUCP&path=Lecture_4%2FLecture_4.ipynb&platform=windows&repository_id=427747212&repository_type=Repository&version=95#4.2.)**

# %%
value_labels = []
var_labels = []
rec1_filters = ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 'V010', 'V011', 'V012','V024', 'V102', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V127', 'V133' ]
rec2_filters = ['CASEID', 'V201', 'V218', 'V301', 'V302', 'V323', 'V323A', 'V325A', 'V326', 'V327', 'V337', 'V359', 'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380']
rec3_filters = ['CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507', 'V508', 'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V613', 'V714', 'V715']
rec1_filters_1 = ["CASEID", "V000", "V001", "V002", "V003", "V004", "V008", "V009", "V010", "V011", "V012", "V024", "V102","V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"]
all_data = []

for i in range(2015,2020):
    
    # Opening files 
    
    globals()[f"rec1_{i}"], globals()[f"meta_1_{i}"] = pyreadstat.read_sav( fr"../../_data/endes/{i}/REC0111.sav" )
    globals()[f"rec2_{i}"], globals()[f"meta_2_{i}"] = pyreadstat.read_sav( fr"../../_data/endes/{i}/RE223132.sav" )
    globals()[f"rec3_{i}"], globals()[f"meta_3_{i}"] = pyreadstat.read_sav( fr"../../_data/endes/{i}/RE516171.sav" )
    
    for a in range(1,4):
        print(f" When we first import rec{a} from year {i}, dimension's file was", {globals()[f"rec{a}_{i}"].shape})

        globals()[f"value_labels_{a}_{i}"] = globals()[f"meta_{a}_{i}"].variable_value_labels
        globals()[f"var_labels_{a}_{i}"] = globals()[f"meta_{a}_{i}"].column_names_to_labels
        globals()[f"rec{a}_{i}"].attrs['value_labels'] = globals()[f"value_labels_{a}_{i}"]
        globals()[f"rec{a}_{i}"].attrs['var_labels'] = globals()[f"var_labels_{a}_{i}"]
       
        if i == 2018:
            rec1_2018_1 = rec1_2018.filter( items = rec1_filters_1 )
            rec2_2018_1 = rec2_2018.filter( items = rec2_filters )
            rec3_2018_1 = rec3_2018.filter( items = rec3_filters )
        else:
            globals()[f"rec{a}_{i}_1"] = globals()[f"rec{a}_{i}"].filter( items = globals()[f"rec{a}_filters"] )
        print(f"Once we do the filter task, rec{a} from year {i}'s new dimension is", {globals()[f"rec{a}_{i}_1"].shape})

        globals()[f"selected_cols_rec{a}_{i}_1_1"] = globals()[f"rec{a}_{i}_1"].columns
        globals()[f"new_var_labels{a}_{i}_1_1"] = { col: globals()[f"var_labels_{a}_{i}"][ col ] for col in globals()[f"selected_cols_rec{a}_{i}_1_1"] }
        globals()[f"new_value_labels{a}_{i}_1_1"] = { key: globals()[f"value_labels_{a}_{i}"] for key in globals()[f"selected_cols_rec{a}_{i}_1_1"] if key in globals()[f"value_labels_{a}_{i}"].keys() }
     
        globals()[f"rec{a}_{i}_1"]['year'] = i
        print(f"After creating this new var, rec{a} from year {i}, has", {globals()[f"rec{a}_{i}_1"].shape}, "obs")
       
        # updating the new variable in the new_var_labels# dictionary

        globals()[f"new_var_labels{a}_{i}_1_1"].update({"Year": "Year of the survey"})
        globals()[f"new_var_labels{a}_{i}_1_1"].get('Year')
# Out:
#  When we first import rec1 from year 2015, dimension's file was {(36655, 96)}
# Once we do the filter task, rec1 from year 2015's new dimension is {(36655, 22)}
# After creating this new var, rec1 from year 2015, has {(36655, 23)} obs
#  When we first import rec2 from year 2015, dimension's file was {(35766, 207)}
# Once we do the filter task, rec2 from year 2015's new dimension is {(35766, 25)}
# After creating this new var, rec2 from year 2015, has {(35766, 26)} obs
#  When we first import rec3 from year 2015, dimension's file was {(35766, 83)}
# Once we do the filter task, rec3 from year 2015's new dimension is {(35766, 18)}
# After creating this new var, rec3 from year 2015, has {(35766, 19)} obs
#  When we first import rec1 from year 2016, dimension's file was {(34131, 97)}
# Once we do the filter task, rec1 from year 2016's new dimension is {(34131, 22)}
# After creating this new var, rec1 from year 2016, has {(34131, 23)} obs
#  When we first import rec2 from year 2016, dimension's file was {(33135, 163)}
# Once we do the filter task, rec2 from year 2016's new dimension is {(33135, 25)}
# After creating this new var, rec2 from year 2016, has {(33135, 26)} obs
#  When we first import rec3 from year 2016, dimension's file was {(33135, 83)}
# Once we do the filter task, rec3 from year 2016's new dimension is {(33135, 18)}
# After creating this new var, rec3 from year 2016, has {(33135, 19)} obs
#  When we first import rec1 from year 2017, dimension's file was {(34002, 97)}
# Once we do the filter task, rec1 from year 2017's new dimension is {(34002, 22)}
# After creating this new var, rec1 from year 2017, has {(34002, 23)} obs
#  When we first import rec2 from year 2017, dimension's file was {(33168, 173)}
# Once we do the filter task, rec2 from year 2017's new dimension is {(33168, 25)}
# After creating this new var, rec2 from year 2017, has {(33168, 26)} obs
#  When we first import rec3 from year 2017, dimension's file was {(33168, 83)}
# Once we do the filter task, rec3 from year 2017's new dimension is {(33168, 18)}
# After creating this new var, rec3 from year 2017, has {(33168, 19)} obs
#  When we first import rec1 from year 2018, dimension's file was {(39745, 103)}
# Once we do the filter task, rec1 from year 2018's new dimension is {(39745, 21)}
# After creating this new var, rec1 from year 2018, has {(39745, 22)} obs
#  When we first import rec2 from year 2018, dimension's file was {(38777, 175)}
# Once we do the filter task, rec2 from year 2018's new dimension is {(38777, 25)}
# After creating this new var, rec2 from year 2018, has {(38777, 26)} obs
#  When we first import rec3 from year 2018, dimension's file was {(34996, 83)}
# Once we do the filter task, rec3 from year 2018's new dimension is {(34996, 18)}
# After creating this new var, rec3 from year 2018, has {(34996, 19)} obs
#  When we first import rec1 from year 2019, dimension's file was {(38335, 105)}
# Once we do the filter task, rec1 from year 2019's new dimension is {(38335, 22)}
# After creating this new var, rec1 from year 2019, has {(38335, 23)} obs
#  When we first import rec2 from year 2019, dimension's file was {(36922, 176)}
# Once we do the filter task, rec2 from year 2019's new dimension is {(36922, 25)}
# After creating this new var, rec2 from year 2019, has {(36922, 26)} obs
#  When we first import rec3 from year 2019, dimension's file was {(33311, 84)}
# Once we do the filter task, rec3 from year 2019's new dimension is {(33311, 18)}
# After creating this new var, rec3 from year 2019, has {(33311, 19)} obs

# %%
for i in range(2015,2020):
    
    # merge
            
    rec1_merge = globals()[f"rec1_{i}_1"].merge(globals()[f"rec2_{i}_1"] , 
                       on = [ 'CASEID'], 
                       how = "left", 
                       validate = "m:1" )
    globals()[f"endes_{i}"] = rec1_merge.merge(globals()[f"rec3_{i}_1"], 
                           on = [ 'CASEID']
                           , how = "left",
                           validate = "m:1" )
    print(f"Now, endes_{i} has", {globals()[f"endes_{i}"].shape}, "of dimension")

    # Unifying all the new_var_labels

    globals()[f"new_var_labels1_{i}_1_1"].update(globals()[f"new_var_labels2_{i}_1_1"])
    globals()[f"new_var_labels1_{i}_1_1"].update(globals()[f"new_var_labels3_{i}_1_1"])
    globals()[f"var_labels_{i}"] = globals()[f"new_var_labels1_{i}_1_1"]

    # Unifying all the new_var_labels

    globals()[f"new_value_labels1_{i}_1_1"].update(globals()[f"new_value_labels2_{i}_1_1"])
    globals()[f"new_value_labels1_{i}_1_1"].update(globals()[f"new_value_labels3_{i}_1_1"])
    globals()[f"value_labels_{i}"]  = globals()[f"new_value_labels1_{i}_1_1"]

    globals()[f"endes_{i}"].attrs['var_labels'] = globals()[f"var_labels_{i}"]
    globals()[f"endes_{i}"].attrs['value_labels'] = globals()[f"value_labels_{i}"]
# Out:
# Now, endes_2015 has {(36655, 66)} of dimension
# Now, endes_2016 has {(34131, 66)} of dimension
# Now, endes_2017 has {(34002, 66)} of dimension
# Now, endes_2018 has {(39745, 63)} of dimension
# Now, endes_2019 has {(38335, 66)} of dimension

# %%
all_data = { 'year_2015' : { 'data' : endes_2015,
                          'var_labels' : var_labels_2015,
                          'value_labels' : value_labels_2015 },
           'year_2016' : { 'data' : endes_2016,
                          'var_labels' : var_labels_2016,
                          'value_labels' : value_labels_2016 },
           'year_2017' : { 'data' : endes_2017,
                          'var_labels' : var_labels_2017,
                          'value_labels' : value_labels_2017 },
           'year_2018' : { 'data' : endes_2018,
                          'var_labels' : var_labels_2018,
                          'value_labels' : value_labels_2018 },
           'year_2019' : { 'data' : endes_2019,
                          'var_labels' : var_labels_2019,
                          'value_labels' : value_labels_2019 }}

# %%
# Now we are ask to compare endes_"year" with all_data_ta

output = urllib.request.urlopen(r'https://www.dropbox.com/s/dqv1d9of2uo6hul/all_data_ta.pkl?dl=1')
all_data_ta = pickle.load( output )

# %%
all_data.values() == all_data_ta.values()
# Out:
# False

# %%
all_data.keys() == all_data_ta.keys()
# Out:
# True

# %% [markdown]
# 7. Use `all_data` to append all the data sets. Store all data sets in a list using `for loop`. Then, use `pd.concat` to append all the data sets. Also, you must reset the index to have a good-looking data. This new object should be named as `endes_data_2015_2019`. **Hint: Use [this code](https://stackoverflow.com/questions/32444138/concatenate-a-list-of-pandas-dataframes-together)**

# %%
all_data.values()
# Out:
# dict_values([{'data':                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0            000102701  1  PE6     1.0  27.0   1.0     1.0  2015.0  1386.0
# 1            000104301  1  PE6     1.0  43.0   1.0     1.0  2015.0  1386.0
# 2            000104801  2  PE6     1.0  48.0   2.0     1.0  2015.0  1386.0
# 3            000104801  3  PE6     1.0  48.0   3.0     1.0  2015.0  1386.0
# 4            000105001  3  PE6     1.0  50.0   3.0     1.0  2015.0  1386.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 36650        317503501  2  PE6  3175.0  35.0   2.0  3175.0  2015.0  1389.0
# 36651        317503701  2  PE6  3175.0  37.0   2.0  3175.0  2015.0  1389.0
# 36652        317507601  1  PE6  3175.0  76.0   1.0  3175.0  2015.0  1389.0
# 36653        317507801  2  PE6  3175.0  78.0   2.0  3175.0  2015.0  1389.0
# 36654        317508001  2  PE6  3175.0  80.0   2.0  3175.0  2015.0  1389.0
#
#        V009    V010  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0       7.0  1985.0  ...  1220.0   1.0  16.0  13.0   3.0  15.0   4.0   1.0
# 1       4.0  1974.0  ...  1290.0   1.0  33.0   8.0   2.0  26.0   2.0   0.0
# 2       1.0  1980.0  ...  1177.0   1.0  18.0  17.0   4.0  18.0   1.0   1.0
# 3      11.0  1999.0  ...     NaN   NaN   NaN   NaN   0.0   0.0   0.0   1.0
# 4       8.0  1993.0  ...     NaN   NaN   NaN   NaN   0.0  21.0   2.0   0.0
# ...     ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 36650   1.0  1989.0  ...  1303.0   1.0  19.0   7.0   2.0  15.0   1.0   1.0
# 36651  12.0  1970.0  ...  1098.0   1.0  20.0  24.0   5.0  14.0   3.0   1.0
# 36652  10.0  1972.0  ...  1118.0   1.0  20.0  22.0   5.0  12.0   3.0   1.0
# 36653   4.0  2000.0  ...     NaN   NaN   NaN   NaN   0.0   0.0   2.0   0.0
# 36654   7.0  1984.0  ...  1250.0   1.0  19.0  11.0   3.0  18.0   2.0   0.0
#
#        V715    year
# 0       3.0  2015.0
# 1       9.0  2015.0
# 2      11.0  2015.0
# 3       NaN  2015.0
# 4       NaN  2015.0
# ...     ...     ...
# 36650  11.0  2015.0
# 36651   0.0  2015.0
# 36652   3.0  2015.0
# 36653   NaN  2015.0
# 36654  11.0  2015.0
#
# [36655 rows x 66 columns], 'var_labels': {'CASEID': 'Case Identification', 'V000': 'Country code and phase', 'V001': 'Cluster number', 'V002': 'Household number', 'V003': "Respondent's line number", 'V004': 'Ultimate area unit', 'V007': 'Year of interview', 'V008': 'Date of interview (CMC)', 'V009': "Respondent's month of birth", 'V010': "Respondent's year of birth", 'V011': 'Date of birth (CMC)', 'V012': 'Current age - respondent', 'V024': 'Region', 'V102': 'Type of place of residence', 'V120': 'Has radio', 'V121': 'Has television', 'V122': 'Has refrigerator', 'V123': 'Has bicycle', 'V124': 'Has motorcycle/scooter', 'V125': 'Has car/truck', 'V127': 'Main floor material', 'V133': 'Education in single years', 'Year': 'Year of the survey', 'V201': 'Total children ever born', 'V218': 'Number of living children', 'V301': 'Knowledge of any method', 'V302': 'Ever use of any method', 'V323': 'Brand of pill used', 'V323A': 'Brand of condom used', 'V325A': 'Cost of current method', 'V326': 'Last source for current users', 'V327': 'Last source for users by type', 'V337': 'Months of use of current method', 'V359': 'Last method disc. last 5 years', 'V360': 'Reason of last discontinuation', 'V361': 'Pattern of use', 'V362': 'Intention to use', 'V363': 'Preferred future method', 'V364': 'Contraceptive use & intention', 'V367': 'Wanted last child', 'V372': 'Shown pill package', 'V372A': 'Shown condom package', 'V375A': 'Main reason not using a method', 'V376': 'Main reason not to use a meth.', 'V376A': 'Would ever use method if marr.', 'V379': 'Source known for any method', 'V380': 'Source known for any method', 'V501': 'Current marital status', 'V502': 'Currently/formerly/never marr.', 'V503': 'Number of unions', 'V504': 'Husband lives in house', 'V505': 'Number of other wives', 'V506': 'Wife rank number', 'V507': 'Month of first marriage', 'V508': 'Year of first marriage', 'V509': 'Date of first marriage (CMC)', 'V510': 'Completeness of date inform.', 'V511': 'Age at first marriage', 'V512': 'Years since first marriage', 'V513': 'Marital duration (grouped)', 'V525': 'Age at first intercourse', 'V613': 'Ideal number of children', 'V714': 'Respondent currently working', 'V715': 'Husbands education-single yrs'}, 'value_labels': {'V024': {'V013': {1.0: '15-19', 2.0: '20-24', 3.0: '25-29', 4.0: '30-34', 5.0: '35-39', 6.0: '40-44', 7.0: '45-49'}, 'V014': {1.0: 'Month and year', 2.0: 'Month and age -y imp', 3.0: 'Year and age - m imp', 4.0: 'Y & age - y ignored', 5.0: 'Year - a, m imp', 6.0: 'Age - y, m imp', 7.0: 'Month - a, y imp', 8.0: 'None - all imp'}, 'V015': {1.0: 'Completed', 2.0: 'Not at home', 3.0: 'Postponed', 4.0: 'Refused', 5.0: 'Partly completed', 6.0: 'Incapacitated', 7.0: 'Other'}, 'V018': {0.0: 'No calendar'}, 'V019': {0.0: 'No calendar'}, 'V020': {0.0: 'All woman sample', 1.0: 'Ever married sample'}, 'V023': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V024': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V025': {1.0: 'Urban', 2.0: 'Rural'}, 'V026': {0.0: 'Capital, large city', 1.0: 'Small city', 2.0: 'Town', 3.0: 'Countryside'}, 'V034': {0.0: 'Husband not in HH'}, 'V042': {0.0: 'Not selected', 1.0: 'Selected'}, 'V043': {0.0: 'Woman not selected', 1.0: 'Woman selected'}, 'V044': {0.0: 'Wom ...
# 0            000100301  2  PE6     1.0   3.0   2.0     1.0  2016.0  1398.0
# 1            000102801  1  PE6     1.0  28.0   1.0     1.0  2016.0  1398.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2016.0  1398.0
# 3            000106101  2  PE6     1.0  61.0   2.0     1.0  2016.0  1398.0
# 4            000106801  2  PE6     1.0  68.0   2.0     1.0  2016.0  1398.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 34126        317500701  2  PE6  3175.0   7.0   2.0  3175.0  2016.0  1401.0
# 34127        317501001  2  PE6  3175.0  10.0   2.0  3175.0  2016.0  1401.0
# 34128        317501101  2  PE6  3175.0  11.0   2.0  3175.0  2016.0  1401.0
# 34129        317501601  2  PE6  3175.0  16.0   2.0  3175.0  2016.0  1401.0
# 34130        317501801  2  PE6  3175.0  18.0   2.0  3175.0  2016.0  1401.0
#
#        V009    V010  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0      11.0  1982.0  ...  1352.0   1.0  29.0   3.0   1.0  19.0   2.0   0.0
# 1      10.0  1979.0  ...  1123.0   5.0  13.0  22.0   5.0  13.0   5.0   1.0
# 2       6.0  1998.0  ...     NaN   NaN   NaN   NaN   0.0  16.0   1.0   1.0
# 3       4.0  1990.0  ...  1366.0   1.0  23.0   2.0   1.0  20.0   4.0   0.0
# 4       6.0  1973.0  ...  1105.0   1.0  18.0  24.0   5.0  18.0   2.0   1.0
# ...     ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 34126   4.0  1995.0  ...  1365.0   1.0  18.0   3.0   1.0  13.0   2.0   0.0
# 34127   3.0  1978.0  ...  1083.0   1.0  12.0  26.0   6.0  12.0   1.0   1.0
# 34128   2.0  2001.0  ...  1389.0   1.0  14.0   1.0   1.0  14.0   2.0   1.0
# 34129   3.0  1987.0  ...  1249.0   1.0  16.0  12.0   3.0  15.0   3.0   0.0
# 34130   5.0  1971.0  ...  1078.0   1.0  18.0  26.0   6.0  13.0   2.0   1.0
#
#        V715    year
# 0       9.0  2016.0
# 1       6.0  2016.0
# 2       NaN  2016.0
# 3      16.0  2016.0
# 4       8.0  2016.0
# ...     ...     ...
# 34126   9.0  2016.0
# 34127   5.0  2016.0
# 34128   6.0  2016.0
# 34129   9.0  2016.0
# 34130  11.0  2016.0
#
# [34131 rows x 66 columns], 'var_labels': {'CASEID': 'Case Identification', 'V000': 'Country code and phase', 'V001': 'Cluster number', 'V002': 'Household number', 'V003': "Respondent's line number", 'V004': 'Ultimate area unit', 'V007': 'Year of interview', 'V008': 'Date of interview (CMC)', 'V009': "Respondent's month of birth", 'V010': "Respondent's year of birth", 'V011': 'Date of birth (CMC)', 'V012': 'Current age - respondent', 'V024': 'Region', 'V102': 'Type of place of residence', 'V120': 'Has radio', 'V121': 'Has television', 'V122': 'Has refrigerator', 'V123': 'Has bicycle', 'V124': 'Has motorcycle/scooter', 'V125': 'Has car/truck', 'V127': 'Main floor material', 'V133': 'Education in single years', 'Year': 'Year of the survey', 'V201': 'Total children ever born', 'V218': 'Number of living children', 'V301': 'Knowledge of any method', 'V302': 'Ever use of any method', 'V323': 'Brand of pill used', 'V323A': 'Brand of condom used', 'V325A': 'Cost of current method', 'V326': 'Last source for current users', 'V327': 'Last source for users by type', 'V337': 'Months of use of current method', 'V359': 'Last method disc. last 5 years', 'V360': 'Reason of last discontinuation', 'V361': 'Pattern of use', 'V362': 'Intention to use', 'V363': 'Preferred future method', 'V364': 'Contraceptive use & intention', 'V367': 'Wanted last child', 'V372': 'Shown pill package', 'V372A': 'Shown condom package', 'V375A': 'Main reason not using a method', 'V376': 'Main reason not to use a meth.', 'V376A': 'Would ever use method if marr.', 'V379': 'Source known for any method', 'V380': 'Source known for any method', 'V501': 'Current marital status', 'V502': 'Currently/formerly/never marr.', 'V503': 'Number of unions', 'V504': 'Husband lives in house', 'V505': 'Number of other wives', 'V506': 'Wife rank number', 'V507': 'Month of first marriage', 'V508': 'Year of first marriage', 'V509': 'Date of first marriage (CMC)', 'V510': 'Completeness of date inform.', 'V511': 'Age at first marriage', 'V512': 'Years since first marriage', 'V513': 'Marital duration (grouped)', 'V525': 'Age at first intercourse', 'V613': 'Ideal number of children', 'V714': 'Respondent currently working', 'V715': 'Husbands education-single yrs'}, 'value_labels': {'V024': {'V013': {1.0: '15-19', 2.0: '20-24', 3.0: '25-29', 4.0: '30-34', 5.0: '35-39', 6.0: '40-44', 7.0: '45-49'}, 'V014': {1.0: 'Month and year', 2.0: 'Month and age -y imp', 3.0: 'Year and age - m imp', 4.0: 'Y & age - y ignored', 5.0: 'Year - a, m imp', 6.0: 'Age - y, m imp', 7.0: 'Month - a, y imp', 8.0: 'None - all imp'}, 'V015': {1.0: 'Completed', 2.0: 'Not at home', 3.0: 'Postponed', 4.0: 'Refused', 5.0: 'Partly completed', 6.0: 'Incapacitated', 7.0: 'Other'}, 'V018': {0.0: 'No calendar'}, 'V019': {0.0: 'No calendar'}, 'V020': {0.0: 'All woman sample', 1.0: 'Ever married sample'}, 'V023': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V024': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V025': {1.0: 'Urban', 2.0: 'Rural'}, 'V026': {0.0: 'Capital, large city', 1.0: 'Small city', 2.0: 'Town', 3.0: 'Countryside'}, 'V034': {0.0: 'Husband not in HH'}, 'V042': {0.0: 'Not selected', 1.0: 'Selected'}, 'V043': {0.0: 'Woman not selected', 1.0: 'Woman selected'}, 'V044': {0.0: 'Wom ...
# 0            000102501  2  PE6     1.0   25.0   2.0     1.0  2017.0  1409.0
# 1            000103201  2  PE6     1.0   32.0   2.0     1.0  2017.0  1409.0
# 2            000103601  2  PE6     1.0   36.0   2.0     1.0  2017.0  1409.0
# 3            000104501  2  PE6     1.0   45.0   2.0     1.0  2017.0  1409.0
# 4            000105201  2  PE6     1.0   52.0   2.0     1.0  2017.0  1409.0
# ...                   ...  ...     ...    ...   ...     ...     ...     ...
# 33997        317510001  2  PE6  3175.0  100.0   2.0  3175.0  2017.0  1413.0
# 33998        317510101  2  PE6  3175.0  101.0   2.0  3175.0  2017.0  1413.0
# 33999        317510301  2  PE6  3175.0  103.0   2.0  3175.0  2017.0  1413.0
# 34000        317510601  2  PE6  3175.0  106.0   2.0  3175.0  2017.0  1413.0
# 34001        317510701  2  PE6  3175.0  107.0   2.0  3175.0  2017.0  1413.0
#
#        V009    V010  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0       3.0  1978.0  ...  1136.0   5.0  16.0  22.0   5.0  16.0   2.0   1.0
# 1       2.0  1995.0  ...  1344.0   1.0  16.0   5.0   2.0  16.0   2.0   0.0
# 2       5.0  1998.0  ...  1368.0   1.0  15.0   3.0   1.0  15.0   0.0   1.0
# 3       4.0  1984.0  ...  1211.0   1.0  16.0  16.0   4.0  14.0  96.0   0.0
# 4       4.0  1984.0  ...  1386.0   1.0  31.0   1.0   1.0  17.0   2.0   0.0
# ...     ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 33997  11.0  1982.0  ...  1196.0   1.0  16.0  18.0   4.0  14.0   2.0   1.0
# 33998   5.0  1975.0  ...  1267.0   1.0  30.0  12.0   3.0  27.0  10.0   1.0
# 33999   5.0  1986.0  ...  1205.0   1.0  14.0  17.0   4.0  13.0   3.0   1.0
# 34000   5.0  1992.0  ...  1298.0   1.0  15.0   9.0   2.0  15.0  96.0   0.0
# 34001   2.0  1988.0  ...  1321.0   1.0  21.0   7.0   2.0  21.0   5.0   1.0
#
#        V715    year
# 0       6.0  2017.0
# 1      11.0  2017.0
# 2      11.0  2017.0
# 3       6.0  2017.0
# 4      98.0  2017.0
# ...     ...     ...
# 33997   3.0  2017.0
# 33998   3.0  2017.0
# 33999   1.0  2017.0
# 34000   3.0  2017.0
# 34001   5.0  2017.0
#
# [34002 rows x 66 columns], 'var_labels': {'CASEID': 'Case Identification', 'V000': 'Country code and phase', 'V001': 'Cluster number', 'V002': 'Household number', 'V003': "Respondent's line number", 'V004': 'Ultimate area unit', 'V007': 'Year of interview', 'V008': 'Date of interview (CMC)', 'V009': "Respondent's month of birth", 'V010': "Respondent's year of birth", 'V011': 'Date of birth (CMC)', 'V012': 'Current age - respondent', 'V024': 'Region', 'V102': 'Type of place of residence', 'V120': 'Has radio', 'V121': 'Has television', 'V122': 'Has refrigerator', 'V123': 'Has bicycle', 'V124': 'Has motorcycle/scooter', 'V125': 'Has car/truck', 'V127': 'Main floor material', 'V133': 'Education in single years', 'Year': 'Year of the survey', 'V201': 'Total children ever born', 'V218': 'Number of living children', 'V301': 'Knowledge of any method', 'V302': 'Ever use of any method', 'V323': 'Brand of pill used', 'V323A': 'Brand of condom used', 'V325A': 'Cost of current method', 'V326': 'Last source for current users', 'V327': 'Last source for users by type', 'V337': 'Months of use of current method', 'V359': 'Last method disc. last 5 years', 'V360': 'Reason of last discontinuation', 'V361': 'Pattern of use', 'V362': 'Intention to use', 'V363': 'Preferred future method', 'V364': 'Contraceptive use & intention', 'V367': 'Wanted last child', 'V372': 'Shown pill package', 'V372A': 'Shown condom package', 'V375A': 'Main reason not using a method', 'V376': 'Main reason not to use a meth.', 'V376A': 'Would ever use method if marr.', 'V379': 'Source known for any method', 'V380': 'Source known for any method', 'V501': 'Current marital status', 'V502': 'Currently/formerly/never marr.', 'V503': 'Number of unions', 'V504': 'Husband lives in house', 'V505': 'Number of other wives', 'V506': 'Wife rank number', 'V507': 'Month of first marriage', 'V508': 'Year of first marriage', 'V509': 'Date of first marriage (CMC)', 'V510': 'Completeness of date inform.', 'V511': 'Age at first marriage', 'V512': 'Years since first marriage', 'V513': 'Marital duration (grouped)', 'V525': 'Age at first intercourse', 'V613': 'Ideal number of children', 'V714': 'Respondent currently working', 'V715': 'Husbands education-single yrs'}, 'value_labels': {'V009': {'V009': {98.0: ''}, 'V010': {9998.0: ''}, 'V013': {1.0: '15-19', 2.0: '20-24', 3.0: '25-29', 4.0: '30-34', 5.0: '35-39', 6.0: '40-44', 7.0: '45-49'}, 'V014': {1.0: 'Month and year', 2.0: 'Month and age -y imp', 3.0: 'Year and age - m imp', 4.0: 'Y & age - y ignored', 5.0: 'Year - a, m imp', 6.0: 'Age - y, m imp', 7.0: 'Month - a, y imp', 8.0: 'None - all imp'}, 'V015': {1.0: 'Completed', 2.0: 'Not at home', 3.0: 'Postponed', 4.0: 'Refused', 5.0: 'Partly completed', 6.0: 'Incapacitated', 7.0: 'Other'}, 'V018': {0.0: 'No calendar'}, 'V019': {0.0: 'No calendar'}, 'V020': {0.0: 'All woman sample', 1.0: 'Ever married sample'}, 'V023': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V024': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huanuco', 11.0: 'Ica', 12.0: 'Junin', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martin', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V025': {1.0: 'Urban', 2.0: 'Rural'}, 'V026': {0.0: 'Capital, large city', 1.0: 'Small city', 2.0: 'Town', 3.0: 'Countryside'}, 'V034': {0.0: 'Husband not in HH'}, 'V042': {0.0: 'Not selected', 1.0: 'Selected'}, 'V043': {0.0: 'Woman not selected',  ...
# 0            000100701  2  PE6     1.0   7.0   2.0     1.0  1422.0   8.0
# 1            000100701  3  PE6     1.0   7.0   3.0     1.0  1422.0   2.0
# 2            000101401  2  PE6     1.0  14.0   2.0     1.0  1422.0   6.0
# 3            000103501  4  PE6     1.0  35.0   4.0     1.0  1422.0   6.0
# 4            000103501  5  PE6     1.0  35.0   5.0     1.0  1422.0   5.0
# ...                   ...  ...     ...   ...   ...     ...     ...   ...
# 39740        325405401  4  PE6  3254.0  54.0   4.0  3254.0  1426.0   7.0
# 39741        325405701  2  PE6  3254.0  57.0   2.0  3254.0  1426.0   9.0
# 39742        325405801  3  PE6  3254.0  58.0   3.0  3254.0  1426.0  11.0
# 39743        325405901  2  PE6  3254.0  59.0   2.0  3254.0  1426.0  10.0
# 39744        325406101  2  PE6  3254.0  61.0   2.0  3254.0  1426.0   9.0
#
#          V010    V011  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0      1975.0   909.0  ...  1141.0   6.0  19.0  23.0   5.0  18.0   2.0   1.0
# 1      2002.0  1227.0  ...     NaN   NaN   NaN   NaN   0.0   0.0   2.0   0.0
# 2      1997.0  1171.0  ...  1399.0   1.0  19.0   1.0   1.0  17.0   2.0   0.0
# 3      2001.0  1219.0  ...     NaN   NaN   NaN   NaN   0.0  16.0   2.0   0.0
# 4      2006.0  1278.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...       ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 39740  2004.0  1255.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 39741  1977.0   933.0  ...  1161.0   1.0  19.0  22.0   5.0  16.0   3.0   0.0
# 39742  2004.0  1260.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 39743  2000.0  1210.0  ...  1355.0   1.0  12.0   5.0   2.0  12.0   2.0   0.0
# 39744  1988.0  1066.0  ...  1243.0   1.0  14.0  15.0   4.0  14.0   4.0   0.0
#
#        V715    year
# 0       6.0  2018.0
# 1       NaN  2018.0
# 2      11.0  2018.0
# 3       NaN  2018.0
# 4       NaN     NaN
# ...     ...     ...
# 39740   NaN     NaN
# 39741   8.0  2018.0
# 39742   NaN     NaN
# 39743  10.0  2018.0
# 39744   7.0  2018.0
#
# [39745 rows x 63 columns], 'var_labels': {'CASEID': 'Identificación Cuestionario Individual', 'V000': 'Código del país', 'V001': 'Número de conglomerado', 'V002': 'Número de hogar', 'V003': 'Número de línea de entrevistada', 'V004': 'Ultima unidad de área', 'V008': 'Fecha de entrevista (CMC)', 'V009': 'Mes de nacimiento de la entrevistada', 'V010': 'Año de nacimiento de la entrevistada', 'V011': 'Fecha de nacimiento (CMC)', 'V012': 'Edad actual - entrevistada', 'V024': 'Región', 'V102': 'Tipo de lugar de residencia', 'V120': 'Tiene radio', 'V121': 'Tiene televisión', 'V122': 'Tiene refrigerador', 'V123': 'Tiene bicicleta', 'V124': 'Tiene motocicleta / scooter', 'V125': 'Tiene carro o camión', 'V127': 'Material principal del piso', 'V133': 'Educación en años simples', 'Year': 'Year of the survey', 'V201': 'Total de niños que alguna vez nacieron', 'V218': 'Número de niños con vida', 'V301': 'Conocimiento de algún método', 'V302': 'Alguna vez usó algún método', 'V323': 'Marca de píldora', 'V323A': 'Marca de condón usado', 'V325A': 'Costo del método actual', 'V326': 'Ultima fuente para usuarios actuales', 'V327': 'Ultima fuente para usuarios por tipo', 'V337': 'Mes de uso del método actual', 'V359': 'Ultimo método suspendido en los últimos 5 años', 'V360': 'Motivo de la última suspensión', 'V361': 'Patrón de uso', 'V362': 'Intención de uso', 'V363': 'Método preferido para el futuro', 'V364': 'Uso e intención de anticoncepción', 'V367': 'Quería último hijo', 'V372': 'Empaque píldora visto', 'V372A': 'Empaque de condón visto', 'V375A': 'Razón principal por la que no usa método', 'V376': 'Razón principal por la que no usaría método', 'V376A': 'Usaría método si se casa', 'V379': 'Fuente conocida para cualquier método', 'V380': 'Fuente conocida para cualquier método', 'V501': 'Estado conyugal actual', 'V502': 'Actualmente/anteriormente/nunca casada', 'V503': 'Número de uniones', 'V504': 'Esposo vive en casa', 'V505': 'Número de otras esposas', 'V506': 'Número de clasificación de esposa', 'V507': 'Mes de primer matrimonio', 'V508': 'Año de primer matrimonio', 'V509': 'Fecha de primer matrimonio (CMC)', 'V510': 'Fecha de información completa', 'V511': 'Edad en el primer matrimonio', 'V512': 'Años desde el primer matrimonio', 'V513': 'Duración de matrimonio (grupos)', 'V525': 'Edad en la primera relación sexual', 'V613': 'Número ideal de hijos', 'V714': 'Entrevistada actualmente trabaja', 'V715': 'Años simples de educación del esposo'}, 'value_labels': {'V024': {'V013': {0.0: '12-14', 1.0: '15-19', 2.0: '20-24', 3.0: '25-29', 4.0: '30-34', 5.0: '35-39', 6.0: '40-44', 7.0: '45-49'}, 'V014': {1.0: 'Mes y año', 2.0: 'Mes y edad -A imp', 3.0: 'Año y edad - m imp', 4.0: 'A y edad - A ignorado', 5.0: 'Año - a, m imp', 6.0: 'Edad -a, m imp', 7.0: 'Mes - a, y imp', 8.0: 'Ninguno - todo imp'}, 'V015': {1.0: 'Completa', 2.0: 'No en casa', 3.0: 'Pospuesta', 4.0: 'Rechazada', 5.0: 'Parcialmente completa', 6.0: 'Incapacidad', 7.0: 'Otra'}, 'V018': {0.0: 'No calendario'}, 'V019': {0.0: 'No calendario'}, 'V020': {0.0: 'Todas las mujeres de la muestra', 1.0: 'Muestra alguna vez casada'}, 'V023': {1.0: 'Amazonas', 2.0: 'Áncash', 3.0: 'Apurímac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huánuco', 11.0: 'Ica', 12.0: 'Junín', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martín', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V024': {1.0: 'Amazonas', 2.0: 'Áncash', 3.0: 'Apurímac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: 'Huánuco', 11.0: 'Ica', 12.0: 'Junín', 13.0: 'La Libertad', 14.0: 'Lambayeque', 15.0: 'Lima', 16.0: 'Loreto', 17.0: 'Madre de Dios', 18.0: 'Moquegua', 19.0: 'Pasco', 20.0: 'Piura', 21.0: 'Puno', 22.0: 'San Martín', 23.0: 'Tacna', 24.0: 'Tumbes', 25.0: 'Ucayali'}, 'V025': {1.0: 'Urbana', ...
# 0            000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1            000100201  3  PE6     1.0   2.0   3.0     1.0  2019.0  1434.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2019.0  1434.0
# 3            000102801  6  PE6     1.0  28.0   6.0     1.0  2019.0  1434.0
# 4            000104801  2  PE6     1.0  48.0   2.0     1.0  2019.0  1434.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 38330        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 38331        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 38332        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 38333        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 38334        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
#        V009    V010  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0       4.0  1986.0  ...  1297.0   1.0  21.0  11.0   3.0  17.0   2.0   1.0
# 1       1.0  2007.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       6.0  1983.0  ...  1344.0   1.0  28.0   7.0   2.0  18.0   3.0   1.0
# 3       3.0  1970.0  ...  1016.0   5.0  14.0  34.0   7.0  14.0   0.0   0.0
# 4       5.0  1991.0  ...  1320.0   1.0  18.0   9.0   2.0  15.0   2.0   0.0
# ...     ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 38330  12.0  1971.0  ...  1032.0   1.0  14.0  34.0   7.0  12.0   3.0   0.0
# 38331   6.0  1988.0  ...  1236.0   1.0  14.0  17.0   4.0  12.0   3.0   0.0
# 38332   7.0  1973.0  ...  1043.0   1.0  13.0  33.0   7.0  12.0   4.0   0.0
# 38333  12.0  1994.0  ...  1301.0   1.0  13.0  11.0   3.0  13.0   2.0   0.0
# 38334  10.0  1996.0  ...  1362.0   1.0  16.0   6.0   2.0  15.0   2.0   0.0
#
#        V715    year
# 0      11.0  2019.0
# 1       NaN     NaN
# 2      14.0  2019.0
# 3       6.0  2019.0
# 4       6.0  2019.0
# ...     ...     ...
# 38330   5.0  2019.0
# 38331   7.0  2019.0
# 38332   5.0  2019.0
# 38333  11.0  2019.0
# 38334  11.0  2019.0
#
# [38335 rows x 66 columns], 'var_labels': {'CASEID': 'Identificación Cuestionario Individual', 'V000': 'Código y fase del país', 'V001': 'Conglomerado', 'V002': 'Número de vivienda', 'V003': 'Número de línea de entrevistada', 'V004': 'Unidad de área final', 'V007': 'Año de la entrevista', 'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)', 'V009': 'Mes de nacimiento de la entrevistada', 'V010': 'Año de nacimiento de la entrevistada', 'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)', 'V012': 'Edad actual - entrevistada', 'V024': 'Región', 'V102': 'Tipo de lugar de residencia', 'V120': 'En su hogar tiene: radio', 'V121': 'En su hogar tiene: televisión', 'V122': 'En su hogar tiene: refrigerador', 'V123': 'En su hogar tiene: bicicleta', 'V124': 'En su hogar tiene: motocicleta/motocar', 'V125': 'En su hogar tiene: coche/camión', 'V127': 'Material predominante del piso de la vivienda', 'V133': 'Educación en años simples', 'Year': 'Year of the survey', 'V201': 'Total de niños nacidos', 'V218': 'Número de niños vivos', 'V301': 'Conocimiento de cualquier método', 'V302': 'Alguna vez usó cualquier método', 'V323': 'Marca de la píldora usada', 'V323A': 'Marca del preservativo utilizado', 'V325A': 'Costo del método actual', 'V326': 'Fuente para obtener el actual método anticonceptivo', 'V327': 'Fuente para obtener el actual método anticonceptivo (Grupos)', 'V337': 'Meses de uso del método actual', 'V359': 'Última discontinuidad del método los últimos 5 años', 'V360': 'Motivo de la última discontinuidad', 'V361': 'Patrón de uso', 'V362': 'Intención de uso', 'V363': 'Método futuro preferido', 'V364': 'Uso e intención de anticonceptivos', 'V367': 'Quería quedar embarazada:', 'V372': 'Se muestra el paquete de pastillas', 'V372A': 'Se muestra el paquete de Condónes', 'V375A': 'La razón principal para no utilizar un método', 'V376': 'La razón principal por la que no piensa usar ningún método en el futuro', 'V376A': 'Alguna vez usaría algún método', 'V379': 'Fuente conocida por cualquier método', 'V380': 'Fuente conocida por cualquier método (Grupos)', 'V501': 'Estado civil actual', 'V502': 'Actualmente, antes o nunca sacada', 'V503': 'Usted ha estado casada o conviviendo solo una vez, más de una vez', 'V504': 'Su esposo/compañer vive en el hogar o vive en otro lugar', 'V505': 'Número de otras esposas', 'V506': 'Número de rango de la esposa', 'V507': 'Mes - Primer matrimonio', 'V508': 'Año - Primer matrimonio', 'V509': 'Fecha del primer matrimonio (CMC)', 'V510': 'Integridad de la información para la fecha de inicio del primer matrimonio o unión', 'V511': 'Edad al primer matrimonio', 'V512': 'Años desde el primer matrimonio', 'V513': 'Duración del matrimonio (agrupado)', 'V525': 'Edad en la primera relación sexual', 'V613': 'Número ideal de niños', 'V714': 'Actualmente se encuentra trabajando', 'V715': 'Educación en años individuales del esposo/compañero'}, 'value_labels': {'V024': {'V013': {0.0: 'De 12 a 14 años de edad', 1.0: 'De 15 a 19 años de edad', 2.0: 'De 20 a 24 años de edad', 3.0: 'De 25 a 29 años de edad', 4.0: 'De 30 a 34 años de edad', 5.0: 'De 35 a 39 años de edad', 6.0: 'De 40 a 44 años de edad', 7.0: 'De 45 a 49 años de edad'}, 'V014': {1.0: 'Mes y año', 2.0: 'Mes y edad - año imputado', 3.0: 'Año y edad - mes imputado', 4.0: 'Año y edad - año ignorado supera el año de entrevista', 5.0: 'Año - edad y mes imputados', 6.0: 'Edad - año y mes imputados', 7.0: 'Mes - edad y año imputados', 8.0: 'Ninguno - edad, mes y año imputados'}, 'V015': {1.0: 'Completa', 2.0: 'Ausente', 3.0: 'Aplazada', 4.0: 'Rechazada', 5.0: 'Incoompleta', 6.0: 'Discapacitada', 7.0: 'Otra'}, 'V018': {0.0: 'Sin calendario'}, 'V019': {0.0: 'Sin calendario'}, 'V020': {0.0: 'Toda la mujer muestra', 1.0: 'Alguna muestra casada'}, 'V023': {1.0: 'Amazonas', 2.0: 'Ancash', 3.0: 'Apurimac', 4.0: 'Arequipa', 5.0: 'Ayacucho', 6.0: 'Cajamarca', 7.0: 'Callao', 8.0: 'Cusco', 9.0: 'Huancavelica', 10.0: ' Huanuco', 11.0: ' Ica', 12.0: ' ...

# %%
all_data_1 = [] 

for i in range(2015, 2020):
    aux =  all_data[f"year_{i}"]["data"] 
    all_data_1.append(aux)

# %%
endes_data_2015_2019_1 = pd.concat(all_data_1)
endes_data_2015_2019 = endes_data_2015_2019_1.reset_index( drop = True )

# %%
endes_data_2015_2019
# Out:
#                     CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0             000102701  1  PE6     1.0  27.0   1.0     1.0  2015.0  1386.0
# 1             000104301  1  PE6     1.0  43.0   1.0     1.0  2015.0  1386.0
# 2             000104801  2  PE6     1.0  48.0   2.0     1.0  2015.0  1386.0
# 3             000104801  3  PE6     1.0  48.0   3.0     1.0  2015.0  1386.0
# 4             000105001  3  PE6     1.0  50.0   3.0     1.0  2015.0  1386.0
# ...                    ...  ...     ...   ...   ...     ...     ...     ...
# 182863        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 182864        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 182865        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 182866        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 182867        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
#         V009    V010  ...    V509  V510  V511  V512  V513  V525  V613  V714  \
# 0        7.0  1985.0  ...  1220.0   1.0  16.0  13.0   3.0  15.0   4.0   1.0
# 1        4.0  1974.0  ...  1290.0   1.0  33.0   8.0   2.0  26.0   2.0   0.0
# 2        1.0  1980.0  ...  1177.0   1.0  18.0  17.0   4.0  18.0   1.0   1.0
# 3       11.0  1999.0  ...     NaN   NaN   NaN   NaN   0.0   0.0   0.0   1.0
# 4        8.0  1993.0  ...     NaN   NaN   NaN   NaN   0.0  21.0   2.0   0.0
# ...      ...     ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 182863  12.0  1971.0  ...  1032.0   1.0  14.0  34.0   7.0  12.0   3.0   0.0
# 182864   6.0  1988.0  ...  1236.0   1.0  14.0  17.0   4.0  12.0   3.0   0.0
# 182865   7.0  1973.0  ...  1043.0   1.0  13.0  33.0   7.0  12.0   4.0   0.0
# 182866  12.0  1994.0  ...  1301.0   1.0  13.0  11.0   3.0  13.0   2.0   0.0
# 182867  10.0  1996.0  ...  1362.0   1.0  16.0   6.0   2.0  15.0   2.0   0.0
#
#         V715    year
# 0        3.0  2015.0
# 1        9.0  2015.0
# 2       11.0  2015.0
# 3        NaN  2015.0
# 4        NaN  2015.0
# ...      ...     ...
# 182863   5.0  2019.0
# 182864   7.0  2019.0
# 182865   5.0  2019.0
# 182866  11.0  2019.0
# 182867  11.0  2019.0
#
# [182868 rows x 66 columns]

# %% [markdown]
# 8. Store all the `var_labels` and `value_labels` in a dictionary named as `all_var_labels` and `all_value_labels`. The first keys should be the year for both dictionaries.Then, use them to generate new attributes for `endes_data_2015_2019`. These attributes should be named as `var_labels` and `value_labels`. Your final output should be equal to `endes_data_2015_2019_ta` object. **Hint: Use [this link](https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=4d6de78e00e7001f16bf6473c2eb7ce24fb611cd&device=unknown_device&enc_url=&logged_in=true&nwo=alexanderquispe%2FDiplomado_PUCP&path=Lecture_4%2FLecture_4.ipynb&platform=windows&repository_id=427747212&repository_type=Repository&version=95#4.2.3.)**

# %%
all_var_labels = {}
all_value_labels = {} 

for i in range (2015, 2020):
    all_var_labels[f'{i}'] = all_data[f"year_{i}"]["var_labels"]
    all_value_labels[f'{i}'] = all_data[f"year_{i}"]["value_labels"]

# %%
endes_data_2015_2019.attrs['var_labels'] = all_var_labels
endes_data_2015_2019.attrs['value_labels'] = all_value_labels

# %%
output = urllib.request.urlopen( r'https://www.dropbox.com/s/oifvyjrr7s0e1md/endes_data_2015_2019_ta.pkl?dl=1')
endes_data_2015_2019_ta = pickle.load( output )

# %%
endes_data_2015_2019.attrs['value_labels'] == endes_data_2015_2019_ta.attrs['value_labels']
# Out:
# False

# %% [markdown]
# 9. Use `endes_data_2015_2019` data to generate a new object named `mean_key_vars` to find the mean of **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)** by year and department **(V024)**. Name these columns as **mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage**, respectively. **Hint: Use groupby and [this link](https://stackoverflow.com/questions/40901770/is-there-a-simple-way-to-change-a-column-of-yes-no-to-1-0-in-a-pandas-dataframe).**

# %%
#'V201', 'V613', 'V715', 'V511'

# %%
# subsetting dataframe
endes_subset = endes_data_2015_2019_ta.loc[:, ['year', 'V024', 'V201', 'V613', 'V715', 'V511'] ]
endes_subset.shape
# Out:
# (182868, 6)

# %%
# checking for NaN values
endes_subset.isnull().sum()
# Out:
# year        0
# V024        0
# V201     5100
# V613    12492
# V715    50729
# V511    50645
# dtype: int64

# %%
endes_subset.dtypes
# Out:
# year      int64
# V024     object
# V201    float64
# V613     object
# V715     object
# V511    float64
# dtype: object

# %%
import pandas as pd
endes_subset = pd.DataFrame(endes_subset)

# %%
endes_subset = endes_subset.reset_index(drop=True)
endes_subset
# Out:
#         year      V024  V201 V613  V715  V511
# 0       2015  Amazonas   3.0  4.0   3.0  16.0
# 1       2015  Amazonas   2.0  2.0   9.0  33.0
# 2       2015  Amazonas   2.0  1.0  11.0  18.0
# 3       2015  Amazonas   0.0  0.0   NaN   NaN
# 4       2015  Amazonas   0.0  2.0   NaN   NaN
# ...      ...       ...   ...  ...   ...   ...
# 182863  2019   Ucayali   5.0  3.0   5.0  14.0
# 182864  2019   Ucayali   5.0  3.0   7.0  14.0
# 182865  2019   Ucayali   8.0  4.0   5.0  13.0
# 182866  2019   Ucayali   2.0  2.0  11.0  13.0
# 182867  2019   Ucayali   1.0  2.0  11.0  16.0
#
# [182868 rows x 6 columns]

# %%
pd.to_numeric(endes_subset['V613'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Non-numeric response"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-0e66ce03bb6e> in <module>
# ----> 1 pd.to_numeric(endes_subset['V613'])
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Non-numeric response" at position 317

# %%
# endes_subset[['V201']].astype('float')
endes_subset[['V613']].astype('float')
# endes_subset[['V201']].astype('float')
# endes_subset[['V201']].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-6f57996baf8d> in <module>
#       1 # endes_subset[['V201']].astype('float')
# ----> 2 endes_subset[['V613']].astype('float')
#       3 # endes_subset[['V201']].astype('float')
#       4 # endes_subset[['V201']].astype('float')
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1093     if arr.ndim > 1:
#    1094         flat = arr.ravel()
# -> 1095         result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1096         # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1097         # attribute "reshape"
#
# ~\anaconda3\envs\renvi\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Non-numeric response'

# %%
# droping rows if either ['V715', 'V511'] columns have NaN values
#endes_key_vars = endes_subset.dropna( subset = ['V715', 'V511'], how = 'any' )

# %%
#endes_key_vars.isnull().sum()

# %%
endes_key_vars.shape
# Out:
# (132138, 6)

# %%
# grouping by by year and department 
key_vars_grouped = endes_subset.groupby( ['year', 'V024'], as_index = False)

# %%
key_vars_grouped.agg('mean')
# Out:
#      year          V024      V201       V511
# 0    2015      Amazonas  2.445515  19.014493
# 1    2015        Ancash  2.028594  20.587935
# 2    2015      Apurimac  2.415771  19.641466
# 3    2015      Arequipa  1.711661  22.038043
# 4    2015      Ayacucho  2.493585  20.037555
# ..    ...           ...       ...        ...
# 120  2019      Ayacucho  1.848787  20.340228
# 121  2019     Cajamarca  1.931559  19.610695
# 122  2019        Callao  1.567164  21.517241
# 123  2019         Cusco  1.894415  20.283154
# 124  2019  Huancavelica  2.083969  19.780769
#
# [125 rows x 4 columns]

# %%
# couldn't agg for variables 'V715' and 'V511'
mean_key_vars = key_vars_grouped.agg(
    mean_total_children = ('V201', np.mean),
    mean_first_marriage = ('V511', np.mean))
    #mean_ideal_children =  ('V715', np.mean),
    #mean_hb_yr_educ = ('V511', np.mean))
mean_key_vars
# Out:
#      year          V024  mean_total_children  mean_first_marriage
# 0    2015      Amazonas             2.445515            19.014493
# 1    2015        Ancash             2.028594            20.587935
# 2    2015      Apurimac             2.415771            19.641466
# 3    2015      Arequipa             1.711661            22.038043
# 4    2015      Ayacucho             2.493585            20.037555
# ..    ...           ...                  ...                  ...
# 120  2019      Ayacucho             1.848787            20.340228
# 121  2019     Cajamarca             1.931559            19.610695
# 122  2019        Callao             1.567164            21.517241
# 123  2019         Cusco             1.894415            20.283154
# 124  2019  Huancavelica             2.083969            19.780769
#
# [125 rows x 4 columns]

# %%
#'V201', 'V613', 'V715', 'V511'

# %% [markdown]
# 10. Merge `mean_key_vars` with `endes_data_2015_2019`. Name this object `final_result`. Your ouput should be equal to `final_result_ta`. **Hint: Use merge.**

# %%
output = urllib.request.urlopen( r'https://www.dropbox.com/s/ntor3jbpdxpj9u1/final_result_ta.pkl?dl=1' )
final_result_ta = pickle.load( output )

# %%
final_result_ta
# Out:
#                     CASEID V000    V001  V002  V003    V004    V008  V009  \
# 0             000102701  1  PE6     1.0  27.0   1.0     1.0  1386.0   7.0
# 1             000104301  1  PE6     1.0  43.0   1.0     1.0  1386.0   4.0
# 2             000104801  2  PE6     1.0  48.0   2.0     1.0  1386.0   1.0
# 3             000104801  3  PE6     1.0  48.0   3.0     1.0  1386.0  11.0
# 4             000105001  3  PE6     1.0  50.0   3.0     1.0  1386.0   8.0
# ...                    ...  ...     ...   ...   ...     ...     ...   ...
# 182863        325406201  2  PE6  3254.0  62.0   2.0  3254.0  1440.0  12.0
# 182864        325406301  2  PE6  3254.0  63.0   2.0  3254.0  1440.0   6.0
# 182865        325407001  2  PE6  3254.0  70.0   2.0  3254.0  1440.0   7.0
# 182866        325407201  2  PE6  3254.0  72.0   2.0  3254.0  1440.0  12.0
# 182867        325407401  2  PE6  3254.0  74.0   2.0  3254.0  1440.0  10.0
#
#           V010    V011  ...  V512              V513                 V525 V613  \
# 0       1985.0  1027.0  ...  13.0             10-14                 15.0  4.0
# 1       1974.0   892.0  ...   8.0               5-9                 26.0  2.0
# 2       1980.0   961.0  ...  17.0             15-19                 18.0  1.0
# 3       1999.0  1199.0  ...   NaN     Never married  Not had intercourse  0.0
# 4       1993.0  1124.0  ...   NaN     Never married                 21.0  2.0
# ...        ...     ...  ...   ...               ...                  ...  ...
# 182863  1971.0   864.0  ...  34.0  De 30 a más años                 12.0  3.0
# 182864  1988.0  1063.0  ...  17.0   De 15 a 19 años                 12.0  3.0
# 182865  1973.0   883.0  ...  33.0  De 30 a más años                 12.0  4.0
# 182866  1994.0  1140.0  ...  11.0   De 10 a 14 años                 13.0  2.0
# 182867  1996.0  1163.0  ...   6.0     De 5 a 9 años                 15.0  2.0
#
#        V714  V715 mean_total_children mean_ideal_children mean_hb_yr_educ  \
# 0       Yes   3.0            2.445515            2.556632        8.195632
# 1        No   9.0            2.445515            2.556632        8.195632
# 2       Yes  11.0            2.445515            2.556632        8.195632
# 3       Yes   NaN            2.445515            2.556632        8.195632
# 4        No   NaN            2.445515            2.556632        8.195632
# ...     ...   ...                 ...                 ...             ...
# 182863   No   5.0            2.012258            2.388399       10.709355
# 182864   No   7.0            2.012258            2.388399       10.709355
# 182865   No   5.0            2.012258            2.388399       10.709355
# 182866   No  11.0            2.012258            2.388399       10.709355
# 182867   No  11.0            2.012258            2.388399       10.709355
#
#        mean_first_marriage
# 0                19.014493
# 1                19.014493
# 2                19.014493
# 3                19.014493
# 4                19.014493
# ...                    ...
# 182863           18.985481
# 182864           18.985481
# 182865           18.985481
# 182866           18.985481
# 182867           18.985481
#
# [182868 rows x 67 columns]

# %%
final_result = endes_data_2015_2019_ta.merge(mean_key_vars , 
                           on = ['year', 'V024'], 
                           how = "left", 
                           validate = "m:1" )
final_result
# Out:
#                     CASEID V000    V001  V002  V003    V004    V008  V009  \
# 0             000102701  1  PE6     1.0  27.0   1.0     1.0  1386.0   7.0
# 1             000104301  1  PE6     1.0  43.0   1.0     1.0  1386.0   4.0
# 2             000104801  2  PE6     1.0  48.0   2.0     1.0  1386.0   1.0
# 3             000104801  3  PE6     1.0  48.0   3.0     1.0  1386.0  11.0
# 4             000105001  3  PE6     1.0  50.0   3.0     1.0  1386.0   8.0
# ...                    ...  ...     ...   ...   ...     ...     ...   ...
# 182863        325406201  2  PE6  3254.0  62.0   2.0  3254.0  1440.0  12.0
# 182864        325406301  2  PE6  3254.0  63.0   2.0  3254.0  1440.0   6.0
# 182865        325407001  2  PE6  3254.0  70.0   2.0  3254.0  1440.0   7.0
# 182866        325407201  2  PE6  3254.0  72.0   2.0  3254.0  1440.0  12.0
# 182867        325407401  2  PE6  3254.0  74.0   2.0  3254.0  1440.0  10.0
#
#           V010    V011  ...             V510  V511  V512              V513  \
# 0       1985.0  1027.0  ...   Month and year  16.0  13.0             10-14
# 1       1974.0   892.0  ...   Month and year  33.0   8.0               5-9
# 2       1980.0   961.0  ...   Month and year  18.0  17.0             15-19
# 3       1999.0  1199.0  ...              NaN   NaN   NaN     Never married
# 4       1993.0  1124.0  ...              NaN   NaN   NaN     Never married
# ...        ...     ...  ...              ...   ...   ...               ...
# 182863  1971.0   864.0  ...  Tiene mes y año  14.0  34.0  De 30 a más años
# 182864  1988.0  1063.0  ...  Tiene mes y año  14.0  17.0   De 15 a 19 años
# 182865  1973.0   883.0  ...  Tiene mes y año  13.0  33.0  De 30 a más años
# 182866  1994.0  1140.0  ...  Tiene mes y año  13.0  11.0   De 10 a 14 años
# 182867  1996.0  1163.0  ...  Tiene mes y año  16.0   6.0     De 5 a 9 años
#
#                        V525 V613 V714  V715 mean_total_children  \
# 0                      15.0  4.0  Yes   3.0            2.445515
# 1                      26.0  2.0   No   9.0            2.445515
# 2                      18.0  1.0  Yes  11.0            2.445515
# 3       Not had intercourse  0.0  Yes   NaN            2.445515
# 4                      21.0  2.0   No   NaN            2.445515
# ...                     ...  ...  ...   ...                 ...
# 182863                 12.0  3.0   No   5.0            2.012258
# 182864                 12.0  3.0   No   7.0            2.012258
# 182865                 12.0  4.0   No   5.0            2.012258
# 182866                 13.0  2.0   No  11.0            2.012258
# 182867                 15.0  2.0   No  11.0            2.012258
#
#        mean_first_marriage
# 0                19.014493
# 1                19.014493
# 2                19.014493
# 3                19.014493
# 4                19.014493
# ...                    ...
# 182863           18.985481
# 182864           18.985481
# 182865           18.985481
# 182866           18.985481
# 182867           18.985481
#
# [182868 rows x 65 columns]
