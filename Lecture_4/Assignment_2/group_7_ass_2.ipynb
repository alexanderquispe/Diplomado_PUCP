# %% [markdown]
# # 1 Assignment 2

# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request

# %% [markdown]
# 1. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %%
# !pip install pyreadstat
# !pip install savReaderWriter
# Out:
# ...
#   Created wheel for savReaderWriter: filename=savReaderWriter-3.4.2-py3-none-any.whl size=51142027 sha256=490679373e50dfd3226734c9aa613fb621070908b536aee5f6165140104ba249
#   Stored in directory: c:\users\faouser1\appdata\local\pip\cache\wheels\da\4b\be\7d3f512ed6ed438b2a72c00a0e568b37930b461f29c0e59e09
# Successfully built savReaderWriter
# ...

# %%
pwd
# Out:
# 'C:\\Users\\FAOUSER1\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_4\\Assignment_2'

# %% [markdown]
# Importing REC0111.sav

# %%
rec_1 = pd.read_spss( r"../../_data/endes/2019/REC0111.sav" )

# %%
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()
    
    value_labels1 = metadata.valueLabels
    var_labels1 = metadata.varLabels

# %%
# adding labels to variables
rec_1.attrs[ 'value_labels1' ] = value_labels1
rec_1.attrs[ 'var_labels1' ] =  var_labels1

# %% [markdown]
# Importing RE223132.sav

# %%
rec_2 = pd.read_spss( r"../../_data/endes/2019/RE223132.sav" )

# %%
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/RE223132.sav", ioUtf8=True) as header:
    metadata = header.all()
    
    value_labels2 = metadata.valueLabels
    var_labels2 = metadata.varLabels

# %%
# adding labels to variables
rec_2.attrs[ 'value_labels2' ] = value_labels2
rec_2.attrs[ 'var_labels2' ] =  var_labels2

# %% [markdown]
# Importing RE516171.sav

# %%
rec_3 = pd.read_spss( r"../../_data/endes/2019/RE516171.sav" )

# %%
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/RE516171.sav", ioUtf8=True) as header:
    metadata = header.all()
    
    value_labels3 = metadata.valueLabels
    var_labels3 = metadata.varLabels

# %%
# adding labels to variables
rec_3.attrs[ 'value_labels3' ] = value_labels3
rec_3.attrs[ 'var_labels3' ] =  var_labels3

# %% [markdown]
# 2. Select the following columns for each data set:
# |Data|Columns|
# |---|---|
# |rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133 |
# |rec2| CASEID, V201, V2018, V301, V302, ..., V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380 |
# |rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715 |
#
#
# Additioanlly, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter, `for loop`,   and [this link](https://stackoverflow.com/questions/3420122/filter-dict-to-contain-only-certain-keys) to update the var and value dictionary.**

# %%
rec1_1 = rec_1.loc[ : , ["CASEID" , "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"] ]

# %%
rec2_1 = rec_2.loc[ : , ["CASEID", "V201", "V218", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"] ]

# %%
rec3_1 = rec_3.loc[ : , ["CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"] ]

# %% [markdown]
# The new varible labels objects should be named as new_var_labels1, new_var_labels2, and new_var_labels3

# %%
old_dict = var_labels1
wanted_keys = ["CASEID" , "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"]
new_var_labels1 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %%
old_dict = var_labels2
wanted_keys = ["CASEID", "V201", "V218", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"]
new_var_labels2 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %%
old_dict = var_labels3
wanted_keys = ["CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"]
new_var_labels3 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %% [markdown]
# The new value labels objects should be named as new_value_labels1, new_value_labels2, and new_value_labels3

# %%
old_dict = value_labels1
wanted_keys = ["CASEID" , "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"]
new_value_labels1 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %%
old_dict = value_labels2
wanted_keys = ["CASEID", "V201", "V218", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"]
new_value_labels2 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %%
old_dict = value_labels3
wanted_keys = ["CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"]
new_value_labels3 = {k: old_dict[k] for k in set(wanted_keys) & set(old_dict.keys())}

# %% [markdown]
# 3. Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %%
rec1_1[ 'year' ] = 2019

# %% [markdown]
# Generate a new key for new_var_labels1 and the value for this key should be "Year of the survey"

# %%
new_var_labels1.update({'year': "Year of the survey" })

new_var_labels1
# Out:
# {'V012': 'Edad actual - entrevistada',
#  'V004': 'Unidad de área final',
#  'V121': 'En su hogar tiene: televisión',
#  'V002': 'Número de vivienda',
#  'V124': 'En su hogar tiene: motocicleta/motocar',
#  'V123': 'En su hogar tiene: bicicleta',
#  'V122': 'En su hogar tiene: refrigerador',
#  'V125': 'En su hogar tiene: coche/camión',
#  'V000': 'Código y fase del país',
#  'V024': 'Región',
#  'V120': 'En su hogar tiene: radio',
#  'V127': 'Material predominante del piso de la vivienda',
#  'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)',
#  'V007': 'Año de la entrevista',
#  'V133': 'Educación en años simples',
#  'V102': 'Tipo de lugar de residencia',
#  'V001': 'Conglomerado',
#  'V010': 'Año de nacimiento de la entrevistada',
#  'V003': 'Número de línea de entrevistada',
#  'CASEID': 'Identificación Cuestionario Individual',
#  'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)',
#  'V009': 'Mes de nacimiento de la entrevistada',
# ...

# %% [markdown]
# 4. Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`. **Hint: Use [this link](https://stackoverflow.com/questions/53645882/pandas-merging-101)**

# %%
len(rec1_1)
# Out:
# 38335

# %%
len(rec2_1)
# Out:
# 36922

# %%
endes_2019 = rec1_1.merge(rec2_1, on='CASEID', how='left').merge(rec3_1, on='CASEID', how='left')  

len(endes_2019)
# Out:
# 38335

# %% [markdown]
# 5. Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. Your final output should be equal to `endes_2019_ta` object **Hint: Use `update` method.**

# %%
#Merge dictionaries
var_labels = {**new_var_labels1, **new_var_labels2, **new_var_labels3}

#Sorted dictionary
var_labels = dict( sorted(var_labels.items() ) )

# %%
#Merge dictionaries
value_labels = {**new_value_labels1, **new_value_labels2, **new_value_labels3}

#Sorted dictionary
value_labels = dict( sorted(value_labels.items() ) ) 
value_labels
# Out:
# {'V024': {1.0: 'Amazonas',
#   2.0: 'Ancash',
#   3.0: 'Apurimac',
#   4.0: 'Arequipa',
#   5.0: 'Ayacucho',
#   6.0: 'Cajamarca',
#   7.0: 'Callao',
#   8.0: 'Cusco',
#   9.0: 'Huancavelica',
#   10.0: ' Huanuco',
#   11.0: ' Ica',
#   12.0: ' Junin',
#   13.0: ' La Libertad',
#   14.0: ' Lambayeque',
#   15.0: ' Lima',
#   16.0: ' Loreto',
#   17.0: ' Madre de Dios',
#   18.0: ' Moquegua',
#   19.0: ' Pasco',
#   20.0: ' Piura',
#   21.0: ' Puno',
#   22.0: ' San Martin',
#   23.0: ' Tacna',
#   24.0: ' Tumbes',
#   25.0: ' Ucayali'},
#  'V102': {1.0: 'Urbano', 2.0: 'Rural'},
#  'V120': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V121': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V122': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V123': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V124': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V125': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
# ...

# %%
endes_2019.attrs[ 'value_labels' ] = value_labels
endes_2019.attrs[ 'var_labels ' ] =  var_labels

# %% [markdown]
# Your final output should be equal to endes_2019_ta object

# %%
len(endes_2019)
# Out:
# 38335

# %%
endes_2019.head()
# Out:
#                CASEID V000  V001  V002  V003  V004    V007    V008  V009  \
# 0        000100201  2  PE6   1.0   2.0   2.0   1.0  2019.0  1434.0   4.0
# 1        000100201  3  PE6   1.0   2.0   3.0   1.0  2019.0  1434.0   1.0
# 2        000102801  2  PE6   1.0  28.0   2.0   1.0  2019.0  1434.0   6.0
# 3        000102801  6  PE6   1.0  28.0   6.0   1.0  2019.0  1434.0   3.0
# 4        000104801  2  PE6   1.0  48.0   2.0   1.0  2019.0  1434.0   5.0
#
#      V010  ...    V508    V509                    V510  V511  V512  \
# 0  1986.0  ...  2008.0  1297.0         Tiene mes y año  21.0  11.0
# 1  2007.0  ...     NaN     NaN                     NaN   NaN   NaN
# 2  1983.0  ...  2011.0  1344.0         Tiene mes y año  28.0   7.0
# 3  1970.0  ...  1984.0  1016.0  Tiene año - imputa mes  14.0  34.0
# 4  1991.0  ...  2009.0  1320.0         Tiene mes y año  18.0   9.0
#
#                V513 V525 V613 V714 V715
# 0   De 10 a 14 años   17    2   Sí   11
# 1               NaN  NaN  NaN  NaN  NaN
# ...

# %%
output = urllib.request.urlopen(r'https://www.dropbox.com/s/gwcssinb1j9zr6s/endes_2019_ta.pkl?dl=1')
endes_2019_ta = pickle.load( output )

# %%
len(endes_2019_ta)
# Out:
# 38335

# %%
endes_2019_ta.head()
# Out:
#                CASEID V000  V001  V002  V003  V004    V007    V008  V009  \
# 0        000100201  2  PE6   1.0   2.0   2.0   1.0  2019.0  1434.0   4.0
# 1        000100201  3  PE6   1.0   2.0   3.0   1.0  2019.0  1434.0   1.0
# 2        000102801  2  PE6   1.0  28.0   2.0   1.0  2019.0  1434.0   6.0
# 3        000102801  6  PE6   1.0  28.0   6.0   1.0  2019.0  1434.0   3.0
# 4        000104801  2  PE6   1.0  48.0   2.0   1.0  2019.0  1434.0   5.0
#
#      V010  ...    V508    V509                    V510  V511  V512  \
# 0  1986.0  ...  2008.0  1297.0         Tiene mes y año  21.0  11.0
# 1  2007.0  ...     NaN     NaN                     NaN   NaN   NaN
# 2  1983.0  ...  2011.0  1344.0         Tiene mes y año  28.0   7.0
# 3  1970.0  ...  1984.0  1016.0  Tiene año - imputa mes  14.0  34.0
# 4  1991.0  ...  2009.0  1320.0         Tiene mes y año  18.0   9.0
#
#                V513 V525 V613 V714 V715
# 0   De 10 a 14 años   17    2   Sí   11
# 1               NaN  NaN  NaN  NaN  NaN
# ...

# %% [markdown]
# 6. Now, replicate your code of the prevoius sections but for years **2019, 2018, 2017, 2016, 2015**. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their **variables and values labels** from this path `"../../_data/endes/"`. For this excersie you must use a for loop. This loop must iterate over **2019, 2018, 2017, 2016, 2015 folders** and import these files. All the files have the same name. You must store these files and their labels in a nested dictionary named as `all_data`. The keys of the dictionary should be named as `year_2019`, for example, and the keys of the nested dictionary should be `data`, `var_labels`, and `value_labels`. The output of this exercise should be equal to the `all_data_ta` object. **Hint: Use [this link](https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=4d6de78e00e7001f16bf6473c2eb7ce24fb611cd&device=unknown_device&enc_url=&logged_in=true&nwo=alexanderquispe%2FDiplomado_PUCP&path=Lecture_4%2FLecture_4.ipynb&platform=windows&repository_id=427747212&repository_type=Repository&version=95#4.2.)**

# %%
pwd
# Out:
# 'C:\\Users\\FAOUSER1\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_4\\Assignment_2'

# %% [markdown]
# First with 2019

# %%
select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2018 = rec_1_2018.loc[ :, select_colums_1 ]
rec1_1_2018
new_value_labels1_2018 = { new_key: value_labels1_2018[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2018.keys() }
new_var_labels1_2018 = { new_key: var_labels1_2018[ new_key ] for new_key in select_colums_1 }

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2019 = rec_1_2019.loc[ :, select_colums_1 ]
rec1_1_2019
new_value_labels1_2019 = { new_key: value_labels1_2019[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2019.keys() }
new_var_labels1_2019 = { new_key: var_labels1_2019[ new_key ] for new_key in select_colums_1 }

# %%
rec_1_2019 = pd.read_spss( r"../../_data/endes/2019/REC0111.sav" )
rec_2_2019 = pd.read_spss( r"../../_data/endes/2019/RE223132.sav" )
rec_3_2019 = pd.read_spss( r"../../_data/endes/2019/RE516171.sav" )


import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels1_2019 = metadata.valueLabels
    var_labels1_2019 = metadata.varLabels
rec_1_2019.attrs[ 'value_labels1_2019' ] = value_labels1_2019
rec_1_2019.attrs[ 'var_labels1_2019' ] = var_labels1_2019

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/RE223132.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels2_2019 = metadata.valueLabels
    var_labels2_2019 = metadata.varLabels
rec_2_2019.attrs[ 'value_labels2_2019' ] = value_labels2_2019
rec_2_2019.attrs[ 'var_labels2_2019' ] = var_labels2_2019

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2019/RE516171.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels3_2019 = metadata.valueLabels
    var_labels3_2019 = metadata.varLabels
rec_3_2019.attrs[ 'value_labels3_2019' ] = value_labels3_2019
rec_3_2019.attrs[ 'var_labels3_2019' ] = var_labels3_2019

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2019 = rec_1_2019.loc[ :, select_colums_1 ]
rec1_1_2019
new_value_labels1_2019 = { new_key: value_labels1_2019[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2019.keys() }
new_var_labels1_2019 = { new_key: var_labels1_2019[ new_key ] for new_key in select_colums_1 }

select_colums_2 = "CASEID", "V201", "V208", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"
rec2_1_2019 = rec_2_2019.loc[ :, select_colums_2 ]
rec2_1_2019
new_value_labels2_2019 = { new_key: value_labels2_2019[ new_key ] for new_key in select_colums_2 if new_key in value_labels2_2019.keys() }
new_var_labels2_2019 = { new_key: var_labels2_2019[ new_key ] for new_key in select_colums_2 }

select_colums_3 = "CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"
rec3_1_2019 = rec_3_2019.loc[ :, select_colums_3 ]
rec3_1_2019
new_value_labels3_2019 = { new_key: value_labels3_2019[ new_key ] for new_key in select_colums_3 if new_key in value_labels3_2019.keys() }
new_var_labels3_2019 = { new_key: var_labels3_2019[ new_key ] for new_key in select_colums_3 }

new_var_labels1_2019.update(new_var_labels2_2019)
new_var_labels1_2019.update(new_var_labels3_2019)
var_labels_2019 = new_var_labels1_2019.copy()

new_value_labels1_2019.update(new_value_labels2_2019)
new_value_labels1_2019.update(new_value_labels3_2019)
value_labels_2019 = new_value_labels1_2019.copy()

endes_2019 = rec_1_2019.merge(rec_2_2019, on = 'CASEID', how = 'left', validate = "1:1").merge(rec_3_2019, on = 'CASEID', how = 'left',validate = "1:1" )

# %% [markdown]
# Now with 2018

# %%
rec_1_2018 = pd.read_spss( r"../../_data/endes/2018/REC0111.SAV" )
rec_2_2018 = pd.read_spss( r"../../_data/endes/2018/RE223132.SAV" )
rec_3_2018 = pd.read_spss( r"../../_data/endes/2018/RE516171.SAV" )

#rec_1_2018
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2018/REC0111.SAV", ioUtf8=True) as header:
    metadata = header.all()
    value_labels1_2018 = metadata.valueLabels
    var_labels1_2018 = metadata.varLabels
rec_1_2018.attrs[ 'value_labels1_2018' ] = value_labels1_2018
rec_1_2018.attrs[ 'var_labels1_2018' ] = var_labels1_2018

# rec_2_2018
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2018/RE223132.SAV", ioUtf8=True) as header:
    metadata = header.all()
    value_labels2_2018 = metadata.valueLabels
    var_labels2_2018 = metadata.varLabels
rec_2_2018.attrs[ 'value_labels2_2018' ] = value_labels2_2018
rec_2_2018.attrs[ 'var_labels2_2018' ] = var_labels2_2018

# rec_3_2018
import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2018/RE516171.SAV", ioUtf8=True) as header:
    metadata = header.all()
    value_labels3_2018 = metadata.valueLabels
    var_labels3_2018 = metadata.varLabels
rec_3_2018.attrs[ 'value_labels3_2018' ] = value_labels3_2018
rec_3_2018.attrs[ 'var_labels3_2018' ] = var_labels3_2018

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2018 = rec_1_2018.loc[ :, select_colums_1 ]
rec1_1_2018
new_value_labels1_2018 = { new_key: value_labels1_2018[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2018.keys() }
new_var_labels1_2018 = { new_key: var_labels1_2018[ new_key ] for new_key in select_colums_1 }

select_colums_2 = "CASEID", "V201", "V208", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"
rec2_1_2018 = rec_2_2018.loc[ :, select_colums_2 ]
rec2_1_2018
new_value_labels2_2018 = { new_key: value_labels2_2018[ new_key ] for new_key in select_colums_2 if new_key in value_labels2_2018.keys() }
new_var_labels2_2018 = { new_key: var_labels2_2018[ new_key ] for new_key in select_colums_2 }

select_colums_3 = "CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"
rec3_1_2018 = rec_3_2018.loc[ :, select_colums_3 ]
rec3_1_2018
new_value_labels3_2018 = { new_key: value_labels3_2018[ new_key ] for new_key in select_colums_3 if new_key in value_labels3_2018.keys() }
new_var_labels3_2018 = { new_key: var_labels3_2018[ new_key ] for new_key in select_colums_3 }

new_var_labels1_2018.update(new_var_labels2_2018)
new_var_labels1_2018.update(new_var_labels3_2018)
var_labels_2018 = new_var_labels1_2018.copy()

new_value_labels1_2018.update(new_value_labels2_2018)
new_value_labels1_2018.update(new_value_labels3_2018)
value_labels_2018 = new_value_labels1_2018.copy()

endes_2018 = rec_1_2018.merge(rec_2_2018, on = 'CASEID', how = 'left', validate = "1:1").merge(rec_3_2018, on = 'CASEID', how = 'left',validate = "1:1" )

# %% [markdown]
# 2017

# %%
rec_1_2017 = pd.read_spss( r"../../_data/endes/2017/REC0111.sav" )
rec_2_2017 = pd.read_spss( r"../../_data/endes/2017/RE223132.sav" )
rec_3_2017 = pd.read_spss( r"../../_data/endes/2017/RE516171.sav" )

#rec_1_2017

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2017/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels1_2017 = metadata.valueLabels
    var_labels1_2017 = metadata.varLabels
rec_1_2017.attrs[ 'value_labels1_2017' ] = value_labels1_2017
rec_1_2017.attrs[ 'var_labels1_2017' ] = var_labels1_2017

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2017/RE223132.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels2_2017 = metadata.valueLabels
    var_labels2_2017 = metadata.varLabels
rec_2_2017.attrs[ 'value_labels2_2017' ] = value_labels2_2017
rec_2_2017.attrs[ 'var_labels2_2017' ] = var_labels2_2017


import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2017/RE516171.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels3_2017 = metadata.valueLabels
    var_labels3_2017 = metadata.varLabels
rec_3_2017.attrs[ 'value_labels3_2017' ] = value_labels3_2017
rec_3_2017.attrs[ 'var_labels3_2017' ] = var_labels3_2017

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2017 = rec_1_2017.loc[ :, select_colums_1 ]
rec1_1_2017
new_value_labels1_2017 = { new_key: value_labels1_2017[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2017.keys() }
new_var_labels1_2017 = { new_key: var_labels1_2017[ new_key ] for new_key in select_colums_1 }


select_colums_2 = "CASEID", "V201", "V208", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"
rec2_1_2017 = rec_2_2017.loc[ :, select_colums_2 ]
rec2_1_2017
new_value_labels2_2017 = { new_key: value_labels2_2017[ new_key ] for new_key in select_colums_2 if new_key in value_labels2_2017.keys() }
new_var_labels2_2017 = { new_key: var_labels2_2017[ new_key ] for new_key in select_colums_2 }


select_colums_3 = "CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"
rec3_1_2017 = rec_3_2017.loc[ :, select_colums_3 ]
rec3_1_2017
new_value_labels3_2017 = { new_key: value_labels3_2017[ new_key ] for new_key in select_colums_3 if new_key in value_labels3_2017.keys() }
new_var_labels3_2017 = { new_key: var_labels3_2017[ new_key ] for new_key in select_colums_3 }


new_var_labels1_2017.update(new_var_labels2_2017)
new_var_labels1_2017.update(new_var_labels3_2017)
var_labels_2017 = new_var_labels1_2017.copy()

new_value_labels1_2017.update(new_value_labels2_2017)
new_value_labels1_2017.update(new_value_labels3_2017)
value_labels_2017 = new_value_labels1_2017.copy()

endes_2017 = rec_1_2017.merge(rec_2_2017, on = 'CASEID', how = 'left', validate = "1:1").merge(rec_3_2017, on = 'CASEID', how = 'left',validate = "1:1" )

# %% [markdown]
# 2016

# %%
rec_1_2016 = pd.read_spss( r"../../_data/endes/2016/REC0111.sav" )
rec_2_2016 = pd.read_spss( r"../../_data/endes/2016/RE223132.sav" )
rec_3_2016 = pd.read_spss( r"../../_data/endes/2016/RE516171.sav" )


import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2016/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels1_2016 = metadata.valueLabels
    var_labels1_2016 = metadata.varLabels
rec_1_2016.attrs[ 'value_labels1_2016' ] = value_labels1_2016
rec_1_2016.attrs[ 'var_labels1_2016' ] = var_labels1_2016


import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2016/RE223132.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels2_2016 = metadata.valueLabels
    var_labels2_2016 = metadata.varLabels
rec_2_2016.attrs[ 'value_labels2_2016' ] = value_labels2_2016
rec_2_2016.attrs[ 'var_labels2_2016' ] = var_labels2_2016


import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2016/RE516171.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels3_2016 = metadata.valueLabels
    var_labels3_2016 = metadata.varLabels
rec_3_2016.attrs[ 'value_labels3_2016' ] = value_labels3_2016
rec_3_2016.attrs[ 'var_labels3_2016' ] = var_labels3_2016

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2016 = rec_1_2016.loc[ :, select_colums_1 ]
rec1_1_2016
new_value_labels1_2016 = { new_key: value_labels1_2016[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2016.keys() }
new_var_labels1_2016 = { new_key: var_labels1_2016[ new_key ] for new_key in select_colums_1 }


select_colums_2 = "CASEID", "V201", "V208", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"
rec2_1_2016 = rec_2_2016.loc[ :, select_colums_2 ]
rec2_1_2016
new_value_labels2_2016 = { new_key: value_labels2_2016[ new_key ] for new_key in select_colums_2 if new_key in value_labels2_2016.keys() }
new_var_labels2_2016 = { new_key: var_labels2_2016[ new_key ] for new_key in select_colums_2 }


select_colums_3 = "CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"
rec3_1_2016 = rec_3_2016.loc[ :, select_colums_3 ]
rec3_1_2016
new_value_labels3_2016 = { new_key: value_labels3_2016[ new_key ] for new_key in select_colums_3 if new_key in value_labels3_2016.keys() }
new_var_labels3_2016 = { new_key: var_labels3_2016[ new_key ] for new_key in select_colums_3 }


new_var_labels1_2016.update(new_var_labels2_2016)
new_var_labels1_2016.update(new_var_labels3_2016)
var_labels_2016 = new_var_labels1_2016.copy()

new_value_labels1_2016.update(new_value_labels2_2016)
new_value_labels1_2016.update(new_value_labels3_2016)
value_labels_2016 = new_value_labels1_2016.copy()

endes_2016 = rec_1_2016.merge(rec_2_2016, on = 'CASEID', how = 'left', validate = "1:1").merge(rec_3_2016, on = 'CASEID', how = 'left',validate = "1:1" )

# %% [markdown]
# 2015

# %%
rec_1_2015 = pd.read_spss( r"../../_data/endes/2015/REC0111.sav" )
rec_2_2015 = pd.read_spss( r"../../_data/endes/2015/RE223132.sav" )
rec_3_2015 = pd.read_spss( r"../../_data/endes/2015/RE516171.sav" )

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2015/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels1_2015 = metadata.valueLabels
    var_labels1_2015 = metadata.varLabels
rec_1_2015.attrs[ 'value_labels1_2015' ] = value_labels1_2015
rec_1_2015.attrs[ 'var_labels1_2015' ] = var_labels1_2015

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2015/RE223132.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels2_2015 = metadata.valueLabels
    var_labels2_2015 = metadata.varLabels
rec_2_2015.attrs[ 'value_labels2_2015' ] = value_labels2_2015
rec_2_2015.attrs[ 'var_labels2_2015' ] = var_labels2_2015

import savReaderWriter as sav
with sav.SavHeaderReader( r"../../_data/endes/2015/RE516171.sav", ioUtf8=True) as header:
    metadata = header.all()
    value_labels3_2015 = metadata.valueLabels
    var_labels3_2015 = metadata.varLabels
rec_3_2015.attrs[ 'value_labels3_2015' ] = value_labels3_2015
rec_3_2015.attrs[ 'var_labels3_2015' ] = var_labels3_2015

select_colums_1 = "CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"
rec1_1_2015 = rec_1_2015.loc[ :, select_colums_1 ]
rec1_1_2015
new_value_labels1_2015 = { new_key: value_labels1_2015[ new_key ] for new_key in select_colums_1 if new_key in value_labels1_2015.keys() }
new_var_labels1_2015 = { new_key: var_labels1_2015[ new_key ] for new_key in select_colums_1 }

select_colums_2 = "CASEID", "V201", "V208", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"
rec2_1_2015 = rec_2_2015.loc[ :, select_colums_2 ]
rec2_1_2015
new_value_labels2_2015 = { new_key: value_labels2_2015[ new_key ] for new_key in select_colums_2 if new_key in value_labels2_2015.keys() }
new_var_labels2_2015 = { new_key: var_labels2_2015[ new_key ] for new_key in select_colums_2 }

select_colums_3 = "CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513", "V525", "V613", "V714", "V715"
rec3_1_2015 = rec_3_2015.loc[ :, select_colums_3 ]
rec3_1_2015
new_value_labels3_2015 = { new_key: value_labels3_2015[ new_key ] for new_key in select_colums_3 if new_key in value_labels3_2015.keys() }
new_var_labels3_2015 = { new_key: var_labels3_2015[ new_key ] for new_key in select_colums_3 }

new_var_labels1_2015.update(new_var_labels2_2015)
new_var_labels1_2015.update(new_var_labels3_2015)
var_labels_2015 = new_var_labels1_2015.copy()

new_value_labels1_2015.update(new_value_labels2_2015)
new_value_labels1_2015.update(new_value_labels3_2015)
value_labels_2015 = new_value_labels1_2015.copy()

endes_2015 = rec_1_2015.merge(rec_2_2015, on = 'CASEID', how = 'left', validate = "1:1").merge(rec_3_2015, on = 'CASEID', how = 'left',validate = "1:1" )

# %% [markdown]
# Now, we create the nested dictionary

# %%
all_data = {} # first it is necessary to create an empty dictionary

#Then, we create dictionaries for the years:

all_data["year_2019"] = {}   
all_data["year_2018"] = {}    
all_data["year_2017"] = {}   
all_data["year_2016"] = {}    
all_data["year_2015"] = {}    

#making the nest estructure with the selected variables and labels:

all_data["year_2019"]["data"] = endes_2019 
all_data["year_2019"]["var_labels"] = var_labels_2019        
all_data["year_2019"]["value_labels"] = value_labels_2019      

all_data["year_2018"]["data"] = endes_2018    
all_data["year_2018"]["var_labels"] = var_labels_2018         
all_data["year_2018"]["value_labels"] = var_labels_2018      

all_data["year_2017"]["data"] = endes_2017     
all_data["year_2017"]["var_labels"] = var_labels_2017         
all_data["year_2017"]["value_labels"] = var_labels_2017      

all_data["year_2016"]["data"] = endes_2016     
all_data["year_2016"]["var_labels"] = var_labels_2016         
all_data["year_2016"]["value_labels"] = var_labels_2016      

all_data["year_2015"]["data"] = endes_2015     
all_data["year_2015"]["var_labels"] = var_labels_2015         
all_data["year_2015"]["value_labels"] = var_labels_2015      


print(all_data)
# Out:
# {'year_2019': {'data':         ID1_x             HHID              CASEID    V001  V002  V003  \
# 0      2019.0        000100201        000100201  2     1.0   2.0   2.0
# 1      2019.0        000100201        000100201  3     1.0   2.0   3.0
# 2      2019.0        000102801        000102801  2     1.0  28.0   2.0
# 3      2019.0        000102801        000102801  6     1.0  28.0   6.0
# 4      2019.0        000104801        000104801  2     1.0  48.0   2.0
# ...       ...              ...                 ...     ...   ...   ...
# 38330  2019.0        325406201        325406201  2  3254.0  62.0   2.0
# 38331  2019.0        325406301        325406301  2  3254.0  63.0   2.0
# 38332  2019.0        325407001        325407001  2  3254.0  70.0   2.0
# 38333  2019.0        325407201        325407201  2  3254.0  72.0   2.0
# 38334  2019.0        325407401        325407401  2  3254.0  74.0   2.0
#
#          V004    V007    V008  V009  ...                            V743C  \
# ...

# %%
output = urllib.request.urlopen(r'https://www.dropbox.com/s/dqv1d9of2uo6hul/all_data_ta.pkl?dl=1')
all_data_ta = pickle.load( output )

# %%
all_data_ta

# %% [markdown]
# 7. Use `all_data` to append all the data sets. Store all data sets in a list using `for loop`. Then, use `pd.concat` to append all the data sets. Also, you must reset the index to have a good-looking data. This new object should be named as `endes_data_2015_2019`. **Hint: Use [this code](https://stackoverflow.com/questions/32444138/concatenate-a-list-of-pandas-dataframes-together)**

# %%
all_data
# Out:
# {'year_2019': {'data':         ID1_x             HHID              CASEID    V001  V002  V003  \
#   0      2019.0        000100201        000100201  2     1.0   2.0   2.0
#   1      2019.0        000100201        000100201  3     1.0   2.0   3.0
#   2      2019.0        000102801        000102801  2     1.0  28.0   2.0
#   3      2019.0        000102801        000102801  6     1.0  28.0   6.0
#   4      2019.0        000104801        000104801  2     1.0  48.0   2.0
#   ...       ...              ...                 ...     ...   ...   ...
#   38330  2019.0        325406201        325406201  2  3254.0  62.0   2.0
#   38331  2019.0        325406301        325406301  2  3254.0  63.0   2.0
#   38332  2019.0        325407001        325407001  2  3254.0  70.0   2.0
#   38333  2019.0        325407201        325407201  2  3254.0  72.0   2.0
#   38334  2019.0        325407401        325407401  2  3254.0  74.0   2.0
#
# ...

# %% [markdown]
# Creating the list with the appended data sets:

# %%
list_2015_2019 = [ ["year_2019"] , ["year_2018"] , ["year_2017"] , ["year_2016"] , ["year_2015"]]

for year in list_2015_2019:
    print( list_2015_2019 )
# Out:
# [['year_2019'], ['year_2018'], ['year_2017'], ['year_2016'], ['year_2015']]
# [['year_2019'], ['year_2018'], ['year_2017'], ['year_2016'], ['year_2015']]
# [['year_2019'], ['year_2018'], ['year_2017'], ['year_2016'], ['year_2015']]
# [['year_2019'], ['year_2018'], ['year_2017'], ['year_2016'], ['year_2015']]
# [['year_2019'], ['year_2018'], ['year_2017'], ['year_2016'], ['year_2015']]

# %% [markdown]
# Concanating them:

# %%
type(list_2015_2019)
# Out:
# list

# %%
import pandas as pd
df = pd.concat(list_2015_2019)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-658a6eb9c97d> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.concat(list_2015_2019)
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
#     372             # consolidate
#
# ...

# %% [markdown]
# 8. Store all the `var_labels` and `value_labels` in a dictionary named as `all_var_labels` and `all_value_labels`. The first keys should be the year for both dictionaries.Then, use them to generate new attributes for `endes_data_2015_2019`. These attributes should be named as `var_labels` and `value_labels`. Your final output should be equal to `endes_data_2015_2019_ta` object. **Hint: Use [this link](https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=4d6de78e00e7001f16bf6473c2eb7ce24fb611cd&device=unknown_device&enc_url=&logged_in=true&nwo=alexanderquispe%2FDiplomado_PUCP&path=Lecture_4%2FLecture_4.ipynb&platform=windows&repository_id=427747212&repository_type=Repository&version=95#4.2.3.)**

# %%
output = urllib.request.urlopen( r'https://www.dropbox.com/s/oifvyjrr7s0e1md/endes_data_2015_2019_ta.pkl?dl=1')
endes_data_2015_2019_ta = pickle.load( output )

# %% [markdown]
# 9. Use `endes_data_2015_2019` data to generate a new object named `mean_key_vars` to find the mean of **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)** by year and department **(V024)**. Name these columns as **mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage**, respectively. **Hint: Use groupby and [this link](https://stackoverflow.com/questions/40901770/is-there-a-simple-way-to-change-a-column-of-yes-no-to-1-0-in-a-pandas-dataframe).**

# %% [markdown]
# 10. Merge `mean_key_vars` with `endes_data_2015_2019`. Name this object `final_result`. Your ouput should be equal to `final_result_ta`. **Hint: Use merge.**

# %%
output = urllib.request.urlopen( r'https://www.dropbox.com/s/ntor3jbpdxpj9u1/final_result_ta.pkl?dl=1' )
final_result_ta = pickle.load( output )
