# %% [markdown]
# # Exploring with Pandas and SAV files

# %% [markdown]
# 1. Explore Endes `RECH1.SAV` file. It is located in this path `Diplomado_PUCP/_data/endes/2015/RECH1.SAV`.

# %%
import pandas as pd

# %%
import pyreadstat

filepath = '../_data/endes/2015/RECH1.SAV'
df, meta = pyreadstat.read_sav(filepath) # devuelve una tupla de dos elementos (df, meta)b

# %%
df
# Out:
#                    HHID  HVIDX  HV101  HV102  HV103  HV104  HV105  HV106  \
# 0             000104301    3.0    3.0    1.0    1.0    1.0    2.0    0.0
# 1             000207901    5.0    3.0    1.0    1.0    1.0    0.0    0.0
# 2             000211901    4.0    3.0    1.0    1.0    1.0    3.0    0.0
# 3             000213001    5.0   10.0    1.0    1.0    1.0    2.0    0.0
# 4             000218601    2.0    3.0    1.0    1.0    1.0    3.0    0.0
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# 151262        157921501    6.0   10.0    1.0    1.0    2.0   81.0    1.0
# 151263        316602101   12.0    7.0    1.0    1.0    2.0   80.0    0.0
# 151264        316911501    1.0    1.0    1.0    1.0    2.0   86.0    1.0
# 151265        317203201    2.0    2.0    1.0    1.0    2.0   80.0    0.0
# 151266        317406201    2.0    6.0    1.0    1.0    2.0   81.0    0.0
#
#         HV107  HV108  ...  HV137  HV138  HV139  HV140  QH13A1  QH13A2  QH13A3  \
# ...

# %%
meta

# %%
meta.column_labels # etiquetas de los nombres de las columnas
# Out:
# ['Case Identification',
#  'Line number',
#  'Relationship to head',
#  'Usual resident',
#  'Slept last night',
#  'Sex of household member',
#  'Age of household members',
#  'Highest educational level',
#  'Highest year of education',
#  'Education in single years',
#  'Educational attainment',
#  'Member still in school',
#  'Mother alive',
#  "Mother's line number",
#  'Father alive',
#  "Father's line number",
#  'Current marital status',
#  'Currently, formerly, never m.',
#  'Eligibility for female interview',
#  'Eligibility for male interview',
#  'Children eligibility for height/weight and hemoglobin',
#  'Member attended school during current school year',
#  'Educational level during current school year',
#  'Grade of education during current school year',
#  'Education in single years - current school year',
#  'Member attended school during previous school year',
#  'Educational level during previous school year',
#  'Grade of education during previous school year',
# ...

# %%
meta.column_names # nombres de las columnas
# Out:
# ['HHID',
#  'HVIDX',
#  'HV101',
#  'HV102',
#  'HV103',
#  'HV104',
#  'HV105',
#  'HV106',
#  'HV107',
#  'HV108',
#  'HV109',
#  'HV110',
#  'HV111',
#  'HV112',
#  'HV113',
#  'HV114',
#  'HV115',
#  'HV116',
#  'HV117',
#  'HV118',
#  'HV120',
#  'HV121',
#  'HV122',
#  'HV123',
#  'HV124',
#  'HV125',
#  'HV126',
#  'HV127',
#  'HV128',
#  'HV129',
#  'HV130',
#  'HV131',
#  'HV132',
#  'HV133',
#  'HV134',
#  'HV135',
#  'HV136',
#  'HV137',
#  'HV138',
#  'HV139',
#  'HV140',
#  'QH13A1',
#  'QH13A2',
#  'QH13A3',
#  'QH13A4',
#  'QH13A5',
#  'QH13A6']

# %%
meta.column_names_to_labels # diccionario con el nombre de la variable (key) y su definición
# Out:
# {'HHID': 'Case Identification',
#  'HVIDX': 'Line number',
#  'HV101': 'Relationship to head',
#  'HV102': 'Usual resident',
#  'HV103': 'Slept last night',
#  'HV104': 'Sex of household member',
#  'HV105': 'Age of household members',
#  'HV106': 'Highest educational level',
#  'HV107': 'Highest year of education',
#  'HV108': 'Education in single years',
#  'HV109': 'Educational attainment',
#  'HV110': 'Member still in school',
#  'HV111': 'Mother alive',
#  'HV112': "Mother's line number",
#  'HV113': 'Father alive',
#  'HV114': "Father's line number",
#  'HV115': 'Current marital status',
#  'HV116': 'Currently, formerly, never m.',
#  'HV117': 'Eligibility for female interview',
#  'HV118': 'Eligibility for male interview',
#  'HV120': 'Children eligibility for height/weight and hemoglobin',
#  'HV121': 'Member attended school during current school year',
#  'HV122': 'Educational level during current school year',
#  'HV123': 'Grade of education during current school year',
# ...

# %%
meta.variable_value_labels # diccionario con las etiquetas de las categorías de las variables
# Out:
# {'HV101': {1.0: 'Head',
#   2.0: 'Wife or husband',
#   3.0: 'Son/daughter',
#   4.0: 'Son/daughter-in-law',
#   5.0: 'Grandchild',
#   6.0: 'Parent',
#   7.0: 'Parent-in-law',
#   8.0: 'Brother/sister',
#   9.0: 'Co-spouse',
#   10.0: 'Other relative',
#   11.0: 'Adopted/foster child',
#   12.0: 'Not related',
#   13.0: 'Niece/nehew by blood',
#   14.0: 'Niece/nephew by marriage',
#   15.0: 'Maid',
#   98.0: 'DK'},
#  'HV102': {0.0: 'No', 1.0: 'Yes'},
#  'HV103': {0.0: 'No', 1.0: 'Yes'},
#  'HV104': {1.0: 'Male', 2.0: 'Female'},
#  'HV105': {97.0: '97+', 98.0: 'DK'},
#  'HV106': {0.0: 'No education, preschool',
#   1.0: 'Primary',
#   2.0: 'Secondary',
#   3.0: 'Higher',
#   8.0: 'DK'},
#  'HV107': {98.0: 'DK'},
#  'HV108': {97.0: 'Inconsistent', 98.0: 'DK'},
#  'HV109': {0.0: 'No education',
#   1.0: 'Incomplete primary',
#   2.0: 'Complete primary',
#   3.0: 'Incomplete secondary',
#   4.0: 'Complete secondary',
#   5.0: 'Higher',
#   8.0: 'DK'},
# ...

# %%
df.attrs # es un diccionario vacío al que se le pueden agregar atributos
# Out:
# {}

# %%
df.attrs['cols_and_labels'] = meta.column_names_to_labels
df.attrs['vars_and_labels'] = meta.variable_value_labels
df.attrs
# Out:
# {'cols_and_labels': {'HHID': 'Case Identification',
#   'HVIDX': 'Line number',
#   'HV101': 'Relationship to head',
#   'HV102': 'Usual resident',
#   'HV103': 'Slept last night',
#   'HV104': 'Sex of household member',
#   'HV105': 'Age of household members',
#   'HV106': 'Highest educational level',
#   'HV107': 'Highest year of education',
#   'HV108': 'Education in single years',
#   'HV109': 'Educational attainment',
#   'HV110': 'Member still in school',
#   'HV111': 'Mother alive',
#   'HV112': "Mother's line number",
#   'HV113': 'Father alive',
#   'HV114': "Father's line number",
#   'HV115': 'Current marital status',
#   'HV116': 'Currently, formerly, never m.',
#   'HV117': 'Eligibility for female interview',
#   'HV118': 'Eligibility for male interview',
#   'HV120': 'Children eligibility for height/weight and hemoglobin',
#   'HV121': 'Member attended school during current school year',
#   'HV122': 'Educational level during current school year',
# ...

# %% [markdown]
# 2. Import all the RECH1.SAV files from all the subfolder located in this folder. `Diplomado_PUCP/_data/endes`

# %% [markdown]
# Doing one by one

# %%
import numpy as np

np.arange(2015, 2020)

df2015 = pd.read_spss('../_data/endes/2015/RECH1.SAV')

df2015.loc[ :, 'year_sample'] = 2015

df2016 = pd.read_spss('../_data/endes/2016/RECH1.SAV')

df2016.loc[ :, 'year_sample'] = 2016

df2017 = pd.read_spss('../_data/endes/2017/RECH1.SAV')

df2017.loc[ :, 'year_sample'] = 2017

# %%
# append data
df_app = pd.concat([df2015, df2016, df2017]) # por default appendea (uno debajo de otro)

# %% [markdown]
# Using a loop

# %%
import pandas as pd

years = np.arange(2015, 2020)
dfs = []

for year in years:
    file_path = f'../_data/endes/{year}/RECH1.SAV'  # definimos la ruta (que irá cambiando año a año)
    df = pd.read_spss(file_path) # se lee el archivo
    df['year_sample'] = year # se añade una columna con el año
    dfs.append(df) # se coloca cada base debajo de la otra

# Concatenate the DataFrames for different years into a single DataFrame, para cada año es una lista
result_df = pd.concat(dfs, ignore_index=False)

# %%
dfs # lista de data frames
# Out:
# [                   HHID  HVIDX            HV101 HV102 HV103   HV104 HV105  \
#  0             000104301    3.0     Son/daughter   Yes   Yes    Male   2.0
#  1             000207901    5.0     Son/daughter   Yes   Yes    Male   0.0
#  2             000211901    4.0     Son/daughter   Yes   Yes    Male   3.0
#  3             000213001    5.0   Other relative   Yes   Yes    Male   2.0
#  4             000218601    2.0     Son/daughter   Yes   Yes    Male   3.0
#  ...                 ...    ...              ...   ...   ...     ...   ...
#  151262        157921501    6.0   Other relative   Yes   Yes  Female  81.0
#  151263        316602101   12.0    Parent-in-law   Yes   Yes  Female  80.0
#  151264        316911501    1.0             Head   Yes   Yes  Female  86.0
#  151265        317203201    2.0  Wife or husband   Yes   Yes  Female  80.0
#  151266        317406201    2.0           Parent   Yes   Yes  Female  81.0
#
# ...

# %%
result_df
# Out:
#                    HHID  HVIDX            HV101 HV102 HV103   HV104 HV105  \
# 0             000104301    3.0     Son/daughter   Yes   Yes    Male   2.0
# 1             000207901    5.0     Son/daughter   Yes   Yes    Male   0.0
# 2             000211901    4.0     Son/daughter   Yes   Yes    Male   3.0
# 3             000213001    5.0   Other relative   Yes   Yes    Male   2.0
# 4             000218601    2.0     Son/daughter   Yes   Yes    Male   3.0
# ...                 ...    ...              ...   ...   ...     ...   ...
# 143481        325407201    3.0        Hijo/Hija    Sí    Sí  Hombre   9.0
# 143482        325407301    1.0   Jefe del Hogar    Sí    Sí  Hombre  35.0
# 143483        325407401    1.0   Jefe del Hogar    Sí    Sí  Hombre  24.0
# 143484        325407401    2.0  Esposa o esposo    Sí    Sí   Mujer  23.0
# 143485        325407401    3.0        Hijo/Hija    Sí    Sí  Hombre   4.0
#
#                             HV106 HV107 HV108  ... QH13A4 QH13A5 QH13A6  \
# ...

# %% [markdown]
# 1. We have data `MotherData.csv` excerpted from a recent Demographic and Health Survey.  First convert the dataset from `wide` (each observation is a mother) to `long` (each observation is a birth, with associated mother id). The id `caseid` identifies uniquely all the mothers.  These columns refer to variable of children **['bidx', 'bord', 'b0', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'b10', 'b11', 'b12', 'b13', 'b15', 'b16']** and have new columns for all their children. We have information for 20 children. It starts from last child to oldest one. Use for loops to reshape this dataset from `wide` to `long` ate mother and children level. If you want to get more information from the columns please see [this pdf](http://www.dhsprogram.com/pubs/pdf/DHSG4/Recode6_DHS_22March2013_DHSG4.pdf).

# %% [markdown]
# Max number of children is 20. We want data at mother, child level. From children, we only want month (b1) and year (b2) of birth (b4), and sex and have data

# %%
df_mother = pd.read_csv('../_data/MotherData.csv')
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_26436\1107978888.py:1: DtypeWarning: Columns (67,128,129,130,131,132,133,208,209,210,211,212,213,228,229,230,231,232,233,240,241,245,247,248,249,250,308,309,310,311,312,313,328,329,330,331,332,333,387,388,389,390,391,392,407,408,409,410,411,412,426,428,429,430,431,433) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mother = pd.read_csv('../_data/MotherData.csv')

# %%
df_mother.caseid.is_unique
# Out:
# True

# %%
df_mother
# Out:
#                caseid v000  v001  v002  v003  v004     v005  v006  v007  v008  \
# 0          1  1     2  NG6     1     1     2     1   700223    11  2010  1331
# 1          1  1     3  NG6     1     1     3     1   700223    11  2010  1331
# 2          1  2     2  NG6     1     2     2     1   700223    11  2010  1331
# 3          1  3     3  NG6     1     3     3     1   700223    11  2010  1331
# 4          1  4     2  NG6     1     4     2     1   700223    11  2010  1331
# ...               ...  ...   ...   ...   ...   ...      ...   ...   ...   ...
# 6339     240 21     2  NG6   240    21     2   240  1336359    12  2010  1332
# 6340     240 22     2  NG6   240    22     2   240  1336359    12  2010  1332
# 6341     240 23     2  NG6   240    23     2   240  1336359    12  2010  1332
# 6342     240 24     2  NG6   240    24     2   240  1336359    12  2010  1332
# 6343     240 26     3  NG6   240    26     3   240  1336359    12  2010  1332
#
# ...

# %%
df_mother.columns.to_list()
# Out:
# ['caseid',
#  'v000',
#  'v001',
#  'v002',
#  'v003',
#  'v004',
#  'v005',
#  'v006',
#  'v007',
#  'v008',
#  'v009',
#  'v010',
#  'v011',
#  'v012',
#  'v013',
#  'v014',
#  'v015',
#  'v016',
#  'v017',
#  'v018',
#  'v019',
#  'v019a',
#  'v020',
#  'v021',
#  'v022',
#  'v023',
#  'v024',
#  'v025',
#  'v026',
#  'v027',
#  'v028',
#  'v029',
#  'v030',
#  'v031',
#  'v032',
#  'v034',
#  'v040',
#  'v042',
#  'v101',
#  'v102',
#  'v103',
#  'v104',
#  'v105',
#  'v106',
#  'v107',
#  'v113',
#  'v116',
#  'v119',
#  'v120',
#  'v121',
#  'v122',
#  'v123',
#  'v124',
#  'v125',
#  'v127',
#  'v128',
#  'v129',
#  'v130',
#  'v131',
#  'v133',
#  'v134',
#  'v135',
#  'v136',
#  'v137',
#  'v138',
#  'v139',
#  'v140',
#  'v141',
#  'v149',
#  'v150',
#  'v151',
#  'v152',
#  'v153',
#  'v155',
#  'v161',
#  'v190',
#  'v191',
#  'ml101',
#  'bidx_01',
#  'bidx_02',
#  'bidx_03',
#  'bidx_04',
#  'bidx_05',
#  'bidx_06',
#  'bidx_07',
#  'bidx_08',
#  'bidx_09',
# ...

# %%
list(df_mother.iterrows()) # es una lista compuesta por muchas tuplas, conteniendo el número de fila y la información de dicha fila
# Out:
# [(0,
#   caseid         1  1     2
#   v000                  NG6
#   v001                    1
#   v002                    1
#   v003                    2
#                  ...
#   v223                  NaN
#   v224                    7
#   v235                    1
#   v237                   no
#   v238                    1
#   Name: 0, Length: 461, dtype: object),
#  (1,
#   caseid         1  1     3
#   v000                  NG6
#   v001                    1
#   v002                    1
#   v003                    3
#                  ...
#   v223                  NaN
#   v224                    0
#   v235       no prior child
#   v237                  NaN
#   v238                    0
#   Name: 1, Length: 461, dtype: object),
#  (2,
#   caseid         1  2     2
#   v000                  NG6
#   v001                    1
#   v002                    2
#   v003                    2
#                  ...
#   v223                  NaN
#   v224                    6
# ...

# %%
i = 8
f'bord_{i:02d}'
# i: Es la variable cuyo valor será insertado.
#:02d: Especifica el formato del número. Aquí:
# 02 indica que el número debe estar compuesto por al menos 2 dígitos, añadiendo ceros a la izquierda si es necesario.
# d indica que el valor es un número entero (dígito).
# Out:
# 'bord_08'

# %%
reshaped_data = [] # aquí se guardará la información
# Iterate through each row in the dataframe
for index, row in df_mother.iterrows(): # index es número de fila, row es la información de la columna
# para trabajar con este tipo de loops simultáneo (index, row) es necesaria una lista con tuplas
    caseid = row['caseid']
    # Iterate over the 20 sets of columns
    for i in range(1, 21):
        bord_col = f'bord_{i:02d}' # bord es birthday order (orden de nacimiento)
        b1_col = f'b1_{i:02d}'
        b2_col = f'b2_{i:02d}'
        b4_col = f'b4_{i:02d}'
        
        # Check if bord_col is NaN, and if so, continue to the next iteration
        if pd.isna(row[bord_col]):
            break  # para este loop, ya no revisa más hijos
        
        # Append the reshaped row to the list
        reshaped_data.append({
            'caseid': caseid,
            'bord': row[bord_col],
            'b1': row[b1_col], # mes de nacimiento del hijo
            'b2': row[b2_col], # año de nacimiento del hijo
            'b4': row[b4_col] # sexo del hijo
        })

# Convert the list to a dataframe
reshaped_df_mother = pd.DataFrame(reshaped_data)
reshaped_df_mother
# Out:
#                 caseid  bord    b1      b2      b4
# 0           1  1     2   7.0   3.0  2010.0    male
# 1           1  1     2   6.0  11.0  2006.0  female
# 2           1  1     2   5.0   1.0  2004.0  female
# 3           1  1     2   4.0   3.0  1999.0  female
# 4           1  1     2   3.0   6.0  1996.0  female
# ...                ...   ...   ...     ...     ...
# 19639     240 23     2   1.0   6.0  2007.0  female
# 19640     240 24     2   4.0  10.0  2010.0    male
# 19641     240 24     2   3.0  12.0  2007.0    male
# 19642     240 24     2   2.0   9.0  2005.0    male
# 19643     240 24     2   1.0   7.0  2000.0    male
#
# [19644 rows x 5 columns]

# %%
reshaped_df_mother.sort_values( ['caseid', 'bord'] ).head(20)
# Out:
#              caseid  bord    b1      b2      b4
# 6        1  1     2   1.0  11.0  1987.0  female
# 5        1  1     2   2.0   6.0  1993.0  female
# 4        1  1     2   3.0   6.0  1996.0  female
# 3        1  1     2   4.0   3.0  1999.0  female
# 2        1  1     2   5.0   1.0  2004.0  female
# 1        1  1     2   6.0  11.0  2006.0  female
# 0        1  1     2   7.0   3.0  2010.0    male
# 12       1  2     2   1.0   7.0  1999.0    male
# 11       1  2     2   2.0  12.0  2002.0  female
# 10       1  2     2   3.0   6.0  2004.0    male
# 9        1  2     2   4.0   5.0  2005.0    male
# 8        1  2     2   5.0   4.0  2006.0  female
# 7        1  2     2   6.0   2.0  2009.0  female
# 14       1  3     3   1.0  10.0  2004.0    male
# 13       1  3     3   2.0   9.0  2007.0  female
# 18       1  4     2   1.0   6.0  2002.0  female
# 17       1  4     2   2.0  11.0  2004.0    male
# 16       1  4     2   3.0   5.0  2007.0    male
# 15       1  4     2   4.0   1.0  2010.0    male
# ...

# %%
# Use pandas wide_to_long function
df_mother_long = pd.wide_to_long(df_mother, stubnames=['bord', 'b1', 'b2', 'b4'], 
                                 i='caseid', j='index', sep='_', suffix='\\d+') 
# bord, b1, b2, b3 y b4 son el comienzo del nombre de las columnas para las que se tiene la información de hijos
# i es la columna que se mantndrá fija
# j es la columna que se crearán con el id
# sep = "_" dice que luego de bord va un guión, y así con las otras columnas
# suffic = '\\d+' significa que van a haber más de un dígito luego de _

df_mother_long
# Out:
#                            b0_01         b0_02         b0_03         b0_04  \
# caseid       index
#   1  1     2 1      single birth  single birth  single birth  single birth
#   1  1     3 1               NaN           NaN           NaN           NaN
#   1  2     2 1      single birth  single birth  single birth  single birth
#   1  3     3 1      single birth  single birth           NaN           NaN
#   1  4     2 1      single birth  single birth  single birth  single birth
# ...                          ...           ...           ...           ...
# 240 21     2 20     single birth           NaN           NaN           NaN
# 240 22     2 20     single birth  single birth  single birth  single birth
# 240 23     2 20     single birth           NaN           NaN           NaN
# 240 24     2 20     single birth  single birth  single birth  single birth
# 240 26     3 20              NaN           NaN           NaN           NaN
#
# ...

# %%
# Reset the index to get a flat dataframe
df_mother_long = df_mother_long.reset_index() # el index pasa a ser una columna, case index ahora es columna
df_mother_long
# Out:
#                  caseid  index         b0_01         b0_02         b0_03  \
# 0            1  1     2      1  single birth  single birth  single birth
# 1            1  1     3      1           NaN           NaN           NaN
# 2            1  2     2      1  single birth  single birth  single birth
# 3            1  3     3      1  single birth  single birth           NaN
# 4            1  4     2      1  single birth  single birth  single birth
# ...                 ...    ...           ...           ...           ...
# 126875     240 21     2     20  single birth           NaN           NaN
# 126876     240 22     2     20  single birth  single birth  single birth
# 126877     240 23     2     20  single birth           NaN           NaN
# 126878     240 24     2     20  single birth  single birth  single birth
# 126879     240 26     3     20           NaN           NaN           NaN
#
#                b0_04         b0_05         b0_06         b0_07 b0_08  ...  \
# ...

# %%
# Drop rows where 'bord' is NaN
df_mother_long = df_mother_long.dropna(subset=['bord'])
df_mother_long
# Out:
#                 caseid  index            b0_01            b0_02  \
# 0           1  1     2      1     single birth     single birth
# 2           1  2     2      1     single birth     single birth
# 3           1  3     3      1     single birth     single birth
# 4           1  4     2      1     single birth     single birth
# 5           1  5     3      1     single birth              NaN
# ...                ...    ...              ...              ...
# 90887      77  4     2     15     single birth     single birth
# 92070     117  6     2     15     single birth     single birth
# 92124     118 24     2     15  3rd of multiple  2nd of multiple
# 98414     117  6     2     16     single birth     single birth
# 98468     118 24     2     16  3rd of multiple  2nd of multiple
#
#                  b0_03            b0_04         b0_05            b0_06  \
# 0         single birth     single birth  single birth     single birth
# ...

# %%
df_mother_long.loc[ :, ['caseid', 'bord', 'b1', 'b2', 'b4']].sort_values( ['caseid', 'bord' ] )
# Out:
#                 caseid  bord    b1      b2      b4
# 38064       1  1     2   1.0  11.0  1987.0  female
# 31720       1  1     2   2.0   6.0  1993.0  female
# 25376       1  1     2   3.0   6.0  1996.0  female
# 19032       1  1     2   4.0   3.0  1999.0  female
# 12688       1  1     2   5.0   1.0  2004.0  female
# ...                ...   ...   ...     ...     ...
# 6341      240 23     2   1.0   6.0  2007.0  female
# 25374     240 24     2   1.0   7.0  2000.0    male
# 19030     240 24     2   2.0   9.0  2005.0    male
# 12686     240 24     2   3.0  12.0  2007.0    male
# 6342      240 24     2   4.0  10.0  2010.0    male
#
# [19644 rows x 5 columns]

# %% [markdown]
# FIN
