# %% [markdown]
# # Assigment 5
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Generate a function called **import_data_sbs_banks** that take as arguments `start_month`, `start_year`, `end_month` and `end_year`. This function should be able to import the files in **..\_data\sbs\B_RawData\bancos** taking into consideration these arguments. Additionally, it should work if it is only given the first two arguments `(start_mont, start_year)`. The function should `returns` a nested dictionary. The `main key` must be year and `second key` must be `month`. The values should be the dataframes.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# This function imports data taking into consideration four arguments, from which two are optional. The mandatory arguments are: start_month and start_year, and the optional arguments are end_month and end_year. Based on the provided link from SBS, we assume the start_month is the near previous month respect the one mentioned in the name of the file.

# %%
def import_data_sbs_banks( start_month, start_year, end_month = None, end_year = None ):
    
    path = '../../_data/sbs/B_RawData/bancos/'
    
    # In case we are only given the first two arguments
    if end_month == None and end_year == None:
        
        # In case we are only given the first two arguments and the start month is december
        if start_month == 12:
            start_month_file = str( 1 )
            start_year_file = str( start_year + 1 )
            for filename in os.listdir( path ):
                
                # In case we are only given the first two arguments, the start month is december and the filename has 26 characters
                if len( filename ) == 26: 
                    if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )                        
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
                
                # In case we are only given the first two arguments, the start month is december and the filename has 27 characters
                if len( filename ) == 27:
                    if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
        
        # In case we are only given the first two arguments and  the start month is not december
        else:
            start_month_file = str( start_month + 1 )
            start_year_file = str( start_year )
            for filename in os.listdir( path ):
                
                # In case we are only given the first two arguments, the start month is noy december and the filename has 26 characters
                if len( filename ) == 26: 
                    if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
                
                # In case we are only given the first two arguments, the start month is noy december and the filename has 27 characters
                if len( filename ) == 27:
                    if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
    
    # In case we are given the four arguments
    else:
        start_month_file = str( end_month )
        start_year_file = str( end_year )
        for filename in os.listdir( path ):
            
            # In case we are given de four arguments and the filename has 26 characters
            if len( filename ) == 26: 
                if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                    new_path = os.path.join( path, filename )
                    data = pd.read_excel( new_path )
                    Dict = { }
                    Dict[ start_year_file ] = {}
                    Dict[ start_year_file ][ start_month_file ] = data
                    return Dict
            
            # In case we are given de four arguments and the filename has 27 characters
            if len( filename ) == 27:
                if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                    new_path = os.path.join( path, filename )
                    data = pd.read_excel( new_path )
                    Dict = { }
                    Dict[ start_year_file ] = {}
                    Dict[ start_year_file ][ start_month_file ] = data
                    return Dict

# %% [markdown]
# ## 2. Test the function

# %% [markdown]
# ### 2.1. In case we specify the four arguments

# %%
import_data_sbs_banks( 1, 2004, 2, 2004 )
# Out:
# {'2004': {'2':               Unnamed: 0                 COMERCIAL COMERCIAL.1  \
#   0                    NaN  Avances en Cta.Corriente  Sobregiros
#   1                    NaN  Avances en Cta.Corriente  Sobregiros
#   2                TRABAJO                         -           -
#   3                   BBVA                     38.92       48.79
#   4      BANCO DE COMERCIO                         -      138.18
#   5       BANCO DE CREDITO                     73.34       89.00
#   6        BANCO PICHINCHA                         -           -
#   7                 BANBIF                     39.08       68.30
#   8     STANDARD CHARTERED                         -       25.00
#   9     BANCO SUDAMERICANO                     31.73       58.10
#   10       WIESE SUDAMERIS                         -           -
#   11           BANK BOSTON                     82.12       82.12
#   12        BNP PARIBAS EL                         -           -
#   13     CITIBANK DEL PERU                         -       89.47
#   14             INTERBANK                     33.38       67.51
#   15               MIBANCO                         -           -
#   16  Promedio del Sistema                     68.42       83.69
#
#                             COMERCIAL.2                       COMERCIAL.3  \
#   0   Dsctos. y préstamos hasta 30 días  Dsctos. y préstamos 31 - 90 días
#   1   Dsctos. y préstamos hasta 30 días  Dsctos. y préstamos 31 - 90 días
#   2                                   -                                 -
#   3                                8.19                              5.94
#   4                               47.46                             21.61
#   5                                4.62                              7.19
#   6                               15.87                             15.71
#   7                               14.43                             10.91
#   8                                   -                                 -
#   9                               30.68                             11.90
#   10                              39.03                             10.58
#   11                               3.19                              3.10
#   12                                  -                                 -
#   13                               3.16                              7.80
#   14                              19.23                              9.87
#   15                                  -                                 -
#   16                               5.31                              7.04
#
#                             COMERCIAL.4                         COMERCIAL.5  \
#   0   Dsctos. y préstamos 91 - 180 días  Dsctos. y préstamos 181 - 360 días
#   1   Dsctos. y préstamos 91 - 180 días  Dsctos. y préstamos 181 - 360 días
#   2                                   -                                   -
#   3                               10.00                               26.18
#   4                               19.71                                   -
#   5                                5.34                                8.14
#   6                               15.82                               26.00
#   7                               10.71                                8.56
#   8                                   -                                   -
#   9                                9.98                                0.10
#   10                               7.56                                6.14
#   11                               8.34                                4.33
#   12                                  -                                   -
#   13                               9.95                               13.20
#   14                               8.14                                6.56
#   15                              57.87                               50.53
#   16                               6.68                                7.78
#
#                            COMERCIAL.6 A MICROEMPRESAS2  \
#   0   Dsctos. y préstamos más 360 días       Sobregiros
#   1   Dsctos. y préstamos más 360 días       Sobregiros
#   2                                  -                -
#   3                              23.38            49.00
#   4                                  -           138.18
#   5                               3.77                -
#   6                              21.28                -
#   7                              13.34                -
#   8                                  -                -
#   9                               7.00                -
#   10                             33.60                -
#   11                                 -                -
#   12                                 -                -
#   13                              6.85                -
#   14                              8.56                -
#   15                                 -                -
#   16                              6.46            60.81
#
#                       A MICROEMPRESAS2.1  ...                        CONSUMO  \
#   0   Dsctos. y préstamos hasta 360 días  ...            Tarjeta de crédito3
#   1   Dsctos. y préstamos hasta 360 días  ...  Tarjetas de crédito abiertas4
#   2                                46.50  ...                          70.46
#   3                                34.56  ...                          48.57
#   4                                    -  ...                          24.01
#   5                                50.60  ...                          34.84
#   6                                    -  ...                          51.11
#   7                                16.22  ...                          24.00
#   8                                    -  ...                              -
#   9                                40.63  ...                          25.00
#   10                                   -  ...                          54.52
#   11                                   -  ...                              -
#   12                                   -  ...                              -
#   13                                   -  ...                          59.93
#   14                                   -  ...                          35.05
#   15                               64.91  ...                              -
#   16                               53.68  ...                          40.97
#
#                           CONSUMO.1            CONSUMO.2  \
#   0             Tarjeta de crédito3  Tarjeta de crédito3
#   1   Tarjetas de crédito cerradas5  Tarjetas de crédito
#   2                           73.34                72.54
#   3                               -                48.57
#   4                               -                24.01
#   5                               -                34.84
#   6                               -                51.11
#   7                               -                24.00
#   8                               -                    -
#   9                               -                25.00
#   10                          90.53                76.56
#   11                              -                    -
#   12                              -                    -
#   13                              -                59.93
#   14                              -                35.05
#   15                              -                    -
#   16                          79.54                45.23
#
#                                         CONSUMO.3  \
#   0                      Préstamos hasta 360 días
#   1   Para préstamos menores o iguales a S/. 1800
#   2                                         57.27
#   3                                         22.36
#   4                                         24.88
#   5                                             -
#   6                                             -
#   7                                         23.23
#   8                                             -
#   9                                         27.29
#   10                                        86.08
#   11                                            -
#   12                                            -
#   13                                            -
#   14                                        27.66
#   15                                        75.93
#   16                                        59.72
#
#                               CONSUMO.4                 CONSUMO.5  \
#   0            Préstamos hasta 360 días  Préstamos hasta 360 días
#   1   Para préstamos mayores a S/. 1800  Préstamos hasta 360 días
#   2                               50.57                     54.66
#   3                               20.55                     20.70
#   4                               32.40                     25.19
#   5                               19.51                     19.51
#   6                               20.60                     20.60
#   7                               24.66                     24.61
#   8                                   -                         -
#   9                               28.00                     27.60
#   10                              25.09                     65.48
#   11                                  -                         -
#   12                                  -                         -
#   13                                  -                         -
#   14                              25.97                     27.13
#   15                              61.82                     65.45
#   16                              45.02                     50.97
#
#                                         CONSUMO.6  \
#   0                        Préstamos más 360 días
#   1   Para préstamos menores o iguales a S/. 1800
#   2                                         66.46
#   3                                         23.72
#   4                                         24.99
#   5                                             -
#   6                                             -
#   7                                         21.85
#   8                                             -
#   9                                         30.97
#   10                                        89.22
#   11                                            -
#   12                                            -
#   13                                            -
#   14                                        28.83
#   15                                        69.84
#   16                                        56.31
#
#                               CONSUMO.7                  CONSUMO.8  HIPOTECARIO
#   0              Préstamos más 360 días     Préstamos más 360 días  HIPOTECARIO
#   1   Para préstamos mayores a S/. 1800  Préstamos más de 360 días  HIPOTECARIO
#   2                               64.27                      64.84            -
#   3                               22.29                      22.34        15.92
#   4                               24.97                      24.97            -
#   5                               25.25                      25.25            -
#   6                               28.79                      28.79            -
#   7                               21.96                      21.95            -
#   8                                   -                          -            -
#   9                               24.64                      24.70            -
#   10                              27.32                      36.33            -
#   11                                  -                          -            -
#   12                                  -                          -            -
#   13                                  -                          -            -
#   14                              29.02                      29.01            -
#   15                              48.11                      48.26        26.00
#   16                              30.83                      32.84        16.28
#
#   [17 rows x 21 columns]}}

# %% [markdown]
# ### 2.2. In case we use only the two mandatory arguments

# %%
import_data_sbs_banks( 12, 2011 )
# Out:
# {'2012': {'1':                                        Tasa Anual (%) Continental Comercio  \
#   0                                        Corporativos        5.85        -
#   1                                          Descuentos        5.77        -
#   2                             Préstamos hasta 30 días        5.53        -
#   3                           Préstamos de 31 a 90 días        5.40        -
#   4                          Préstamos de 91 a 180 días        5.50        -
#   5                         Préstamos de 181 a 360 días           -        -
#   6                         Préstamos a más de 360 días        6.38        -
#   7                                    Grandes Empresas        7.51    11.77
#   8                                          Descuentos        8.20    13.93
#   9                             Préstamos hasta 30 días        6.81    11.94
#   10                          Préstamos de 31 a 90 días        7.90    11.99
#   11                         Préstamos de 91 a 180 días        7.53        -
#   12                        Préstamos de 181 a 360 días        7.10        -
#   13                        Préstamos a más de 360 días        7.08    10.00
#   14                                  Medianas Empresas       12.91    14.90
#   15                                         Descuentos       12.74    18.14
#   16                            Préstamos hasta 30 días       14.56    10.27
#   17                          Préstamos de 31 a 90 días       12.65    11.42
#   18                         Préstamos de 91 a 180 días       12.63    13.00
#   19                        Préstamos de 181 a 360 días       13.62        -
#   20                        Préstamos a más de 360 días       13.21        -
#   21                                  Pequeñas Empresas       21.63    26.86
#   22                                         Descuentos       22.89    26.58
#   23                            Préstamos hasta 30 días       23.50        -
#   24                          Préstamos de 31 a 90 días       21.68    31.12
#   25                         Préstamos de 91 a 180 días       22.40        -
#   26                        Préstamos de 181 a 360 días       21.82    32.00
#   27                        Préstamos a más de 360 días       19.34    26.49
#   28                                      Microempresas       33.21    30.25
#   29                                Tarjetas de Crédito       36.18    25.00
#   30                                         Descuentos       32.47    25.84
#   31                              Préstamos Revolventes       32.00        -
#   32               Préstamos a cuota fija hasta 30 días       30.99        -
#   33             Préstamos a cuota fija de 31 a 90 días       31.33    29.75
#   34            Préstamos a cuota fija de 91 a 180 días       31.09    36.09
#   35           Préstamos a cuota fija de 181 a 360 días       31.34    39.24
#   36           Préstamos a cuota fija a más de 360 días       30.58    30.10
#   37                                            Consumo       39.85    16.85
#   38                                Tarjetas de Crédito       47.67    25.63
#   39                              Préstamos Revolventes       14.78        -
#   40          Préstamos no Revolventes para automóviles       10.09        -
#   41  Préstamos no Revolventes para libre disponibil...       20.12    16.95
#   42  Préstamos no Revolventes para libre disponibil...       20.42    16.68
#   43                             Créditos pignoraticios           -    64.79
#   44                                       Hipotecarios        9.82        -
#   45               Préstamos hipotecarios para vivienda        9.82        -
#   46  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
#   47  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
#
#      Crédito Financiero    BIF Scotiabank Citibank Interbank Mibanco   HSBC  \
#   0     5.78          -   7.01       5.49     5.90      5.66       -   6.65
#   1     6.69          -   6.86       6.34        -      5.99       -      -
#   2     5.40          -   6.80       4.78     5.80         -       -      -
#   3     6.41          -   7.50       5.12     5.86      6.44       -   6.80
#   4     5.31          -   7.30       5.01     6.15      5.67       -   6.26
#   5     5.33          -   7.00       5.40        -      4.87       -      -
#   6     5.87          -      -       6.88        -         -       -      -
#   7     7.19       8.61   7.80       6.51     6.11      7.08       -   8.10
#   8     7.03       7.74   8.69       6.57     5.72      6.89       -   7.69
#   9     7.27          -   6.23       6.53     5.61      7.04       -   9.80
#   10    7.87       9.61   8.45       6.91     6.14      7.60       -   8.22
#   20         -         -      -         -        -     15.93
#   21         -         -      -         -        -     22.94
#   22         -         -      -         -        -     14.43
#   23         -         -      -         -        -     23.31
#   24         -         -      -         -        -     17.34
#   25         -         -      -         -        -     23.44
#   26         -         -      -         -        -     25.64
#   27         -         -      -         -        -     24.49
#   28         -         -      -         -        -     32.88
#   29         -         -      -         -        -     31.85
#   30         -         -      -         -        -     28.11
#   31         -         -      -         -        -     28.28
#   32         -         -      -         -        -     30.74
#   33         -         -      -         -        -     29.26
#   34         -         -      -         -        -     33.39
#   35         -         -      -         -        -     43.84
#   36         -         -      -         -        -     30.11
#   37     47.18         -  51.02    123.75        -     38.09
#   38     47.24         -  52.68    167.69        -     41.29
#   39         -         -      -         -        -     21.65
#   40         -         -      -         -        -     10.12
#   41     21.97         -  34.43    163.89        -     86.10
#   42     21.40         -  25.73    104.38        -     25.84
#   43         -         -      -         -        -     64.79
#   44         -         -      -         -        -      9.40
#   45         -         -      -         -        -      9.40
#   46       NaN       NaN    NaN       NaN      NaN       NaN
#   47       NaN       NaN    NaN       NaN      NaN       NaN  }}

# %% [markdown]
# ### 2.3. We observe that the output data type is a dictionary

# %%
a = import_data_sbs_banks( 9, 2014, 10, 2014 )
type( a )
# Out:
# dict

# %% [markdown]
# ### 2.4. We acces the dataframe through the keys

# %%
a['2014']['10']
# Out:
#                                        Tasa Anual (%) Continental Comercio  \
# 0                                        Corporativos        4.66        -
# 1                                          Descuentos        5.29        -
# 2                             Préstamos hasta 30 días        4.44        -
# 3                           Préstamos de 31 a 90 días        4.66        -
# 4                          Préstamos de 91 a 180 días        4.63        -
# 5                         Préstamos de 181 a 360 días        4.75        -
# 6                         Préstamos a más de 360 días           -        -
# 7                                    Grandes Empresas        6.75    19.93
# 8                                          Descuentos        8.47    45.55
# 9                             Préstamos hasta 30 días        5.74    13.00
# 10                          Préstamos de 31 a 90 días        6.05     9.54
# 11                         Préstamos de 91 a 180 días        6.77        -
# 12                        Préstamos de 181 a 360 días        7.57        -
# 13                        Préstamos a más de 360 días        7.68     8.50
# 14                                  Medianas Empresas       11.78    16.18
# 15                                         Descuentos       13.27    34.74
# 16                            Préstamos hasta 30 días       11.72    11.22
# 17                          Préstamos de 31 a 90 días       11.38    15.01
# 18                         Préstamos de 91 a 180 días       11.64    14.04
# 19                        Préstamos de 181 a 360 días       11.98        -
# 20                        Préstamos a más de 360 días       10.22        -
# 21                                  Pequeñas Empresas       16.43    27.17
# 22                                         Descuentos       18.24    30.55
# 23                            Préstamos hasta 30 días       15.29    15.00
# 24                          Préstamos de 31 a 90 días       17.32    15.73
# 25                         Préstamos de 91 a 180 días       16.73        -
# 26                        Préstamos de 181 a 360 días       18.18    32.50
# 27                        Préstamos a más de 360 días       12.76    29.90
# 28                                      Microempresas       28.68    36.89
# 29                                Tarjetas de Crédito       36.07    33.39
# 30                                         Descuentos       17.20        -
# 31                              Préstamos Revolventes       13.00        -
# 32               Préstamos a cuota fija hasta 30 días           -        -
# 33             Préstamos a cuota fija de 31 a 90 días       16.84    39.66
# 34            Préstamos a cuota fija de 91 a 180 días       19.63    52.00
# 35           Préstamos a cuota fija de 181 a 360 días       20.26    36.43
# 36           Préstamos a cuota fija a más de 360 días       13.66    36.89
# 37                                            Consumo       41.08    19.49
# 38                                Tarjetas de Crédito       57.06    26.15
# 39                              Préstamos Revolventes       21.86        -
# 40          Préstamos no Revolventes para automóviles       10.07        -
# 41  Préstamos no Revolventes para libre disponibil...       16.88    16.53
# 42  Préstamos no Revolventes para libre disponibil...       14.58    19.42
# 43                             Créditos pignoraticios           -    71.84
# 44                                       Hipotecarios        8.88     9.69
# 45               Préstamos hipotecarios para vivienda        8.88     9.69
# 46  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
# 47  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
#
#    Crédito Financiero    BIF Scotiabank Citibank Interbank Mibanco Banco GNB  \
# 0     5.51       5.80   5.98       4.64     6.58      6.54       -      8.39
# 1     6.26          -   6.40          -        -      5.54       -         -
# 2     4.36       5.00   5.20       3.87     6.14      6.08       -         -
# 3     6.76       7.40   5.99       4.84     6.51         -       -      7.60
# 4     4.75       7.47   5.45       5.04     7.03      5.14       -      8.49
# 5     4.71          -   7.70       4.56        -      7.80       -         -
# 6     5.76          -      -       4.44        -      6.76       -      8.50
# 7     7.12       7.68   8.02       6.63     5.98      7.11       -      8.60
# 8     7.42       8.13   8.53       6.48     6.35      6.64       -     11.97
# 9     6.88       7.42   6.97       6.49     7.14      6.85       -      8.77
# 10    7.20       6.91   7.14       7.03     5.85      7.17       -      7.25
# 11    6.63       7.90   7.90       5.93     5.80      6.86       -      7.14
# 12    7.20       8.23  10.27          -        -      7.50       -         -
# 13    7.25       8.13  11.57       7.12        -      8.26       -         -
# 14    9.73       9.65  10.56      10.15     6.17      9.34   18.47     11.04
# 15    9.46       9.55  10.78       9.42        -      8.03       -     11.47
# 16    8.91       3.37  13.00       8.85        -      5.69   18.47     12.59
# 17    9.31      11.19   9.60       9.19     5.95     11.25   20.73     10.54
# 18    9.99      11.17  10.60       8.93        -      8.75   16.73      9.60
# 19   13.59      14.71  12.94      11.22     6.80     11.84   18.07      8.70
# 20   10.16      16.16  11.42      13.14        -     11.04   18.55     11.47
# 21   19.12      22.26  14.46      23.68        -     18.55   22.11      9.99
# 22   10.81      12.45  13.27      13.33        -     10.91       -         -
# 23   12.91      32.30  14.79      16.43        -         -   21.22         -
# 24   13.00      25.04  13.99      19.12        -     18.39   25.52      9.67
# 25   23.59      21.54  12.73      16.96        -     16.63   25.73     10.00
# 26   23.61      25.32  14.10      21.87        -     20.50   22.99         -
# 27   13.68      22.25  19.41      24.79        -     18.86   21.88         -
# 28   29.73      34.87  19.04      30.05        -     21.36   34.00         -
# 29   31.36     112.84      -      47.15        -         -       -         -
# 30   10.48      14.00  12.25      20.06        -      9.81       -         -
# 31       -          -  12.35          -        -     16.32   23.44         -
# 32       -          -      -      34.00        -         -   42.91         -
# 33   19.36      35.38  50.00      23.22        -     22.39   30.97         -
# 34   29.70      38.31  19.00      25.18        -     31.05   36.98         -
# 35   29.35      47.65  36.01      25.71        -     24.97   42.58         -
