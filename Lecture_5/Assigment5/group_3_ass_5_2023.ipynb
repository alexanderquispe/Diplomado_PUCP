# %% [markdown]
# # Assigment 5
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. USE RELATIVE PATHS. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# ASK EVERYTHING! WE ARE HERE TO HELP YOU!

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Generate a function called **import_data_sbs_banks** that take as arguments `start_month`, `start_year`, `end_month` and `end_year`. This function should be able to import the files in **..\_data\sbs\B_RawData\bancos** taking into consideration these arguments. Additionally, it should work if it is only given the first two arguments `(start_mont, start_year)`. The function should `returns` a nested dictionary. The `main key` must be year and `second key` must be `month`. The values should be the dataframes.

# %%
#1.1 import libraries
import os
import pandas as pd
import numpy as np

# %%
#1.2 define the function
def import_data_sbs_banks(start_month, start_year, end_month=None, end_year=None):
    
    # define the route
    path = r"../../_data/sbs/B_RawData/bancos"
    
    
    # in the case when give two arguments
    if end_month == None and end_month==None:
        
        #In case we are only given the first two arguments and the start month is december
        if start_month == 12:
            start_month_file = str ( 1 )
            start_year_file = str ( start_year + 1 )
            for filename in os.listdir ( path ):
                
                #In case we are only given the first two arguments, the start month is december and the filename has 26 characters
                if len ( filename ) == 26: 
                    if filename [ 15:-10 ] == start_month_file and filename [ 17:-5 ] == start_year_file:
                        new_path =os.path.join ( path, filename )
                        data = pd.read_excel ( new_path )
                        Dict = {}
                        Dict = [ start_year_file ] = {}
                        Dict = [ start_year_file ][start_month_file] = data
                        return Dict
                    
                #In case we are  only given the fisrt two arguments, the start month is december and the filename has 27 characters

# %%
import os
import pandas as pd

def importar_datos_sbs_bancos(inicio_mes, inicio_anio, fin_mes=None, fin_anio=None):
    
    # Definir la ruta de los datos
    ruta_datos = r"../../_data/sbs/B_RawData/bancos"
    
    # Listar todos los archivos en la ruta de datos
    archivos = os.listdir(ruta_datos)
    
    # Diccionario donde se almacenarán los datos
    diccionario_resultado = {}
    
    for archivo in archivos:
        # Verificar si el archivo comienza con "table_clean_" y tiene extensión .xlsx
        if archivo.startswith("table_clean_") and archivo.endswith(".xlsx"):
            # Si es así, extraer día, mes y año del nombre del archivo
            _, _, dia, mes, anio = archivo[:-5].split('_')
            # Convertir a enteros lo necesario (mes y año)
            mes = int(mes)
            anio = int(anio)
            
            # Verificar si los valores en 'inicio_anio', 'inicio_mes', 'fin_anio' y 'fin_mes' del archivo
            # se encuentran dentro del rango de tiempo especificado (rango definido al usar la función)
            if (inicio_anio < anio or (inicio_anio == anio and inicio_mes <= mes)) and \
               (fin_anio is None or (fin_anio > anio or (fin_anio == anio and fin_mes >= mes))):
                
                try:
                    # Si los valores están en el rango, construir la ruta completa del archivo
                    ruta_archivo = os.path.join(ruta_datos, archivo)
                    # Leer el archivo Excel en un DataFrame
                    df = pd.read_excel(ruta_archivo)
                    
                    # Verificar si la clave de año existe en el diccionario_resultado, si no, crearla
                    if anio not in diccionario_resultado:
                        diccionario_resultado[anio] = {}
                    
                    # Almacenar el DataFrame en diccionario_resultado bajo el año y mes correspondientes
                    diccionario_resultado[anio][mes] = df
                
                # Manejar el caso en el que el archivo no se encuentra
                except FileNotFoundError:
                    print(f"El archivo {archivo} no se encuentra.")
                   
                
    # Ordenar diccionario_resultado por año y mes
    diccionario_ordenado = dict(sorted(diccionario_resultado.items()))

    for anio, meses in diccionario_ordenado.items():
        diccionario_ordenado[anio] = dict(sorted(meses.items()))
    
    # Devolver el diccionario resultante
    return diccionario_ordenado

# %% [markdown]
# Example 1: To import all the files in data path for a range

# %%
# Primero, definimos el rango: por ejemplo, la segunda mitad del año 2008, momentos críticos de la crisis financiera de 2008
inicio_mes = 7
inicio_anio = 2008
fin_mes = 12
fin_anio = 2008

# Segundo, utilizamos la función (corregir el nombre de la función aquí)
datos_dict = importar_datos_sbs_bancos(inicio_mes, inicio_anio, fin_mes, fin_anio)

# Finalmente, imprimimos los resultados
print(datos_dict)
# Out:
# {2008: {7:           Tasa Anual (%)         CRÉDITOS COMERCIALES CRÉDITOS COMERCIALES.1  \
# 0         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
# 1         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
# 2                TRABAJO                            -                      -
# 3                   BBVA                        10.41                  45.94
# 4      BANCO DE COMERCIO                            -                 138.18
# 5       BANCO DE CREDITO                        36.53                  54.84
# 6        BANCO PICHINCHA                            -                 101.22
# 7                 BANBIF                        54.64                  83.96
# 8        SCOTIABANK PERU                        16.85                  53.93
# 9      CITIBANK DEL PERU                        50.00                  14.85
# 10             INTERBANK                        21.75                   3.93
# ...

# %% [markdown]
# Example 2: To find out oldest dataframe avaliable and see, from then on, all files available to date

# %%
# Definimos una fecha de inicio más antigua, como enero de 2010
inicio_mes = 1
inicio_anio = 2010

# Luego, utilizamos la función
resultado_dict = importar_datos_sbs_bancos(inicio_mes, inicio_anio)

# Mostramos las fechas disponibles desde esta fecha de inicio
if resultado_dict:
    print("Meses y años obtenidos:")
    for year in resultado_dict.keys():
        for month in resultado_dict[year].keys():
            print(f"{month}/{year}")
# Out:
# Meses y años obtenidos:
# 1/2010
# 2/2010
# 3/2010
# 4/2010
# 5/2010
# 6/2010
# 7/2010
# 8/2010
# 9/2010
# 10/2010
# 11/2010
# 12/2010
# 1/2011
# 2/2011
# 3/2011
# 4/2011
# 5/2011
# 6/2011
# 7/2011
# 8/2011
# 9/2011
# 10/2011
# 11/2011
# 12/2011
# 1/2012
# 2/2012
# 3/2012
# 4/2012
# 5/2012
# 6/2012
# 7/2012
# 8/2012
# 9/2012
# 10/2012
# 11/2012
# 12/2012
# 1/2013
# 2/2013
# 3/2013
# 4/2013
# 5/2013
# 6/2013
# 7/2013
# 8/2013
# 9/2013
# 10/2013
# 11/2013
# 12/2013
# 1/2014
# 2/2014
# 3/2014
# 4/2014
# 5/2014
# 6/2014
# 7/2014
# 8/2014
# 9/2014
# 10/2014
# 11/2014
# 12/2014
# 1/2015
# 2/2015
# 3/2015
# 4/2015
# 5/2015
# 6/2015
# 7/2015
# 8/2015
# 9/2015
# 10/2015
# 11/2015
# 12/2015
# 1/2016
# 2/2016
# 3/2016
# 4/2016
# 5/2016
# 6/2016
# 7/2016
# 8/2016
# 9/2016
# 10/2016
# 11/2016
# 12/2016
# 1/2017
# 2/2017
# 3/2017
# 4/2017
# 5/2017
# 6/2017
# 7/2017
# 8/2017
# 9/2017
# 10/2017
# 11/2017
# 12/2017
# 1/2018
# 2/2018
# 3/2018
# 4/2018
# 5/2018
# 6/2018
# 7/2018
# 8/2018
# 9/2018
# ...

# %%
importar_datos_sbs_bancos(4, 2010)
# Out:
# {2010: {4:           Tasa Anual (%)         CRÉDITOS COMERCIALES CRÉDITOS COMERCIALES.1  \
#   0         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
#   1         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
#   2                   BBVA                         8.36                  48.55
#   3      BANCO DE COMERCIO                            -                 138.18
#   4       BANCO DE CREDITO                        62.38                  28.89
#   5        BANCO PICHINCHA                            -                      -
#   6                 BANBIF                        18.37                  77.79
#   7        SCOTIABANK PERU                         8.05                  50.41
#   8      CITIBANK DEL PERU                         5.28                   4.42
#   9              INTERBANK                        29.55                   9.38
#   10               MIBANCO                            -                      -
# ...
