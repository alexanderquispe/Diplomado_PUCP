# %% [markdown]
# # Assigment 5
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**

# %% [markdown]
# In this path **..\_data\sbs\B_RawData\bancos** you will find scraped data from [this link](https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B). We get all the information of the last available day of every each month.
#
# 1. Generate a function called **import_data_sbs_banks** that take as arguments `start_month`, `start_year`, `end_month` and `end_year`. This function should be able to import the files in **..\_data\sbs\B_RawData\bancos** taking into consideration these arguments. Additionally, it should work if it is only given the first two arguments `(start_mont, start_year)`. The function should `returns` a nested dictionary. The `main key` must be year and `second key` must be `month`. The values should be the dataframes.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# In this function that previously has imported data, we need to consider four arguments, two of which are optional. The main arguments are: start_month and start_year, and the optional arguments are end_month and end_year.
# P.D. We assume the start_month is the near previous month respect the one mentioned in the name of the file.

# %%
def import_data_sbs_banks( start_month, start_year, end_month = None, end_year = None ):
    
    path = '../../_data/sbs/B_RawData/bancos/'
    
    # First, for the condition : when we are only given two arguments 
    if end_month == None and end_year == None:
        
        # Second contidion: when we are given the first two arguments and the start month is december
        if start_month == 12:
            start_month_file = str( 1 )
            start_year_file = str( start_year + 1 )
            for filename in os.listdir( path ):
                
                # Third condition: when we are only given the first two arguments, the start month is december and the filename has 26 characters
                if len( filename ) == 26: 
                    if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )                        
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
                
                # Fourth condition: when we are only given the first two arguments, the start month is december and the filename has 27 characters
                if len( filename ) == 27:
                    if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
        
        # Fifth condition: when we are only given the first two arguments and  the start month is not december
        else:
            start_month_file = str( start_month + 1 )
            start_year_file = str( start_year )
            for filename in os.listdir( path ):
                
                # Sixth condition: when we are only given the first two arguments, the start month is not december and the filename has 26 characters
                if len( filename ) == 26: 
                    if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
                
                # Seventh condition: when we are only given the first two arguments, the start month is not december and the filename has 27 characters
                if len( filename ) == 27:
                    if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                        new_path = os.path.join( path, filename )
                        data = pd.read_excel( new_path )
                        Dict = { }
                        Dict[ start_year_file ] = {}
                        Dict[ start_year_file ][ start_month_file ] = data
                        return Dict
    
    # Eighth condition: when we are given the four arguments
    else:
        start_month_file = str( end_month )
        start_year_file = str( end_year )
        for filename in os.listdir( path ):
            
            # Ninth condition: when we are given de four arguments and the filename has 26 characters
            if len( filename ) == 26: 
                if filename[ 15:-10 ] == start_month_file and filename[ 17:-5 ] == start_year_file:
                    new_path = os.path.join( path, filename )
                    data = pd.read_excel( new_path )
                    Dict = { }
                    Dict[ start_year_file ] = {}
                    Dict[ start_year_file ][ start_month_file ] = data
                    return Dict
            
            # Tenth condition : when we are given de four arguments and the filename has 27 characters
            if len( filename ) == 27:
                if filename[ 15:-10 ] == start_month_file and filename[ 18:-5 ] == start_year_file:
                    new_path = os.path.join( path, filename )
                    data = pd.read_excel( new_path )
                    Dict = { }
                    Dict[ start_year_file ] = {}
                    Dict[ start_year_file ][ start_month_file ] = data
                    return Dict

# %%
# 1.1 When we apply the four arguments 
import_data_sbs_banks( 1, 2010, 3, 2010 )
# Out:
# {'2010': {'3':           Tasa Anual (%)         CRÉDITOS COMERCIALES CRÉDITOS COMERCIALES.1  \
#   0         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
#   1         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
#   2                   BBVA                        13.77                  48.71
#   3      BANCO DE COMERCIO                            -                 138.18
#   4       BANCO DE CREDITO                        53.32                  17.00
#   5        BANCO PICHINCHA                            -                      -
#   6                 BANBIF                        14.44                  81.05
#   7        SCOTIABANK PERU                         7.92                  42.38
#   8      CITIBANK DEL PERU                         4.85                  29.72
#   9              INTERBANK                        15.12                   9.07
#   10               MIBANCO                            -                      -
#   11                  HSBC                            -                      -
#   12       BANCO FALABELLA                            -                      -
#   13        SANTANDER PERU                            -                  81.82
#   14          BANCO RIPLEY                            -                      -
#   15           ALFIN BANCO                            -                      -
#   16    DEUTSCHE BANK PERU                            -                      -
#   17  Promedio del Sistema                        32.45                  18.38
#   18                   NaN                          NaN                    NaN
#
#      CRÉDITOS COMERCIALES.2      CRÉDITOS COMERCIALES.3 CRÉDITOS COMERCIALES.4  \
#   0              Descuentos       Promedio de Préstamos  Promedio de Préstamos
#   1              Descuentos  Clientes deuda > S/. 5 MM4         Demás Clientes
#   2                   12.90                        3.32                   9.75
#   3                   12.85                           -                  18.59
#   4                    5.80                        4.26                   5.82
#   5                    9.60                        6.56                  17.36
#   6                    7.87                        3.69                   8.69
#   7                    6.89                        2.22                   7.82
#   8                       -                        4.53                   3.36
#   9                    6.93                        6.08                   7.48
#   10                      -                           -                  22.86
#   11                   6.79                        3.33                   5.26
#   12                      -                           -                      -
#   13                      -                           -                   6.26
#   14                      -                           -                      -
#   15                      -                           -                      -
#   16                      -                           -                      -
#   17                   7.41                        3.83                   9.24
#   18                    NaN                         NaN                    NaN
#
#      CRÉDITOS COMERCIALES.5     CRÉDITOS COMERCIALES.6   CRÉDITOS COMERCIALES.7  \
#   0   Promedio de Préstamos    Préstamos hasta 30 días  Préstamos hasta 30 días
#   1                Promedio  Clientes deuda > S/. 5 MM           Demás Clientes
#   2                    5.67                       1.68                     6.76
#   3                   18.59                          -                    18.94
#   4                    4.72                       6.32                     5.97
#   5                   15.72                          -                        -
#   6                    5.15                          -                    14.86
#   7                    4.85                       1.55                    11.85
#   8                    4.26                       3.56                        -
#   9                    6.89                       7.50                     9.00
#   10                  22.86                          -                        -
#   11                   4.46                          -                     3.70
#   12                      -                          -                        -
#   13                   6.26                          -                        -
#   14                      -                          -                        -
#   15                      -                          -                        -
#   16                      -                          -                        -
#   17                   5.82                       2.27                     7.84
#   18                    NaN                        NaN                      NaN
#
#        CRÉDITOS COMERCIALES.8  ...          CRÉDITOS DE CONSUMO.1  \
#   0   Préstamos hasta 30 días  ...            Tarjetas de crédito
#   1                  Promedio  ...            Tarjetas de crédito
#   2                      2.19  ...  Tarjetas de crédito cerradas4
#   3                     18.94  ...                              -
#   4                      6.13  ...                              -
#   5                         -  ...                              -
#   6                     14.86  ...                              -
#   7                      2.46  ...                              -
#   8                      3.56  ...                              -
#   9                      7.98  ...                              -
#   10                        -  ...                          69.70
#   11                     3.70  ...                              -
#   12                        -  ...                              -
#   13                        -  ...                              -
#   14                        -  ...                              -
#   15                        -  ...                              -
#   16                        -  ...                              -
#   17                     3.39  ...                              -
#   18                      NaN  ...                          69.70
#
#      CRÉDITOS DE CONSUMO.2     CRÉDITOS DE CONSUMO.3  \
#   0    Tarjetas de crédito  Préstamos no revolventes
#   1    Tarjetas de crédito          Para Automóviles
#   2               Promedio          Para Automóviles
#   3                  50.88                      9.02
#   4                  21.43                         -
#   5                  31.94                     10.22
#   6                  32.35                     11.44
#   7                  30.00                         -
#   8                  22.90                         -
#   9                  43.93                         -
#   10                 45.42                     15.94
#   11                 57.65                         -
#   12                 39.41                      8.84
#   13                 52.16                      9.99
#   14                     -                         -
#   15                 74.33                         -
#   16                183.86                         -
#   17                     -                         -
#   18                 47.38                     10.70
#
#                     CRÉDITOS DE CONSUMO.4           CRÉDITOS DE CONSUMO.5  \
#   0              Préstamos no revolventes        Préstamos no revolventes
#   1        Otros Préstamos Hasta 360 días  Otros Préstamos Hasta 360 días
#   2   Montos menores o iguales a S/. 1800       Montos mayores a S/. 1800
#   3                                 20.72                           16.66
#   4                                 16.72                           20.45
#   5                                 33.29                           15.82
#   6                                 70.28                           21.20
#   7                                 18.01                           17.47
#   8                                 13.64                           13.25
#   9                                     -                               -
#   10                                    -                               -
#   11                                56.42                           50.74
#   12                                19.08                           16.84
#   13                                39.00                               -
#   14                                    -                               -
#   15                                30.59                           28.25
#   16                               164.05                          131.67
#   17                                    -                               -
#   18                               123.63                           44.76
#
#                CRÉDITOS DE CONSUMO.6                CRÉDITOS DE CONSUMO.7  \
#   0         Préstamos no revolventes             Préstamos no revolventes
#   1   Otros Préstamos Hasta 360 días    Otros Préstamos a Más de 360 días
#   2                         Promedio  Montos menores o iguales a S/. 1800
#   3                            16.92                                20.33
#   4                            17.61                                15.83
#   5                            16.72                                34.91
#   6                            31.53                                76.49
#   7                            17.76                                17.55
#   8                            13.31                                17.58
#   9                                -                                    -
#   10                               -                                20.76
#   11                           52.91                                58.55
#   12                           17.09                                21.75
#   13                           39.00                                39.80
#   14                               -                                    -
#   15                           28.73                                36.12
#   16                          157.36                               133.71
#   17                               -                                    -
#   18                           80.00                                97.54
#
#                   CRÉDITOS DE CONSUMO.8              CRÉDITOS DE CONSUMO.9  \
#   0            Préstamos no revolventes           Préstamos no revolventes
#   1   Otros Préstamos a Más de 360 días  Otros Préstamos a Más de 360 días
#   2           Montos mayores a S/. 1800                           Promedio
#   3                               16.06                              16.08
#   4                               16.68                              16.67
#   5                               16.87                              16.94
#   6                               26.40                              32.15
#   7                               17.25                              17.25
#   8                               14.85                              14.86
#   9                               19.56                              19.56
#   10                              19.91                              19.92
#   11                              43.19                              43.99
#   12                              16.14                              16.14
#   13                              20.35                              20.83
#   14                                  -                                  -
#   15                              23.90                              24.42
#   16                             126.23                             129.71
#   17                                  -                                  -
#   18                              19.29                              21.23
#
#       PRÉSTAMOS HIPOTECARIOS
#   0   PRÉSTAMOS HIPOTECARIOS
#   1   PRÉSTAMOS HIPOTECARIOS
#   2   PRÉSTAMOS HIPOTECARIOS
#   3                     9.67
#   4                    11.00
#   5                     9.73
#   6                    11.02
#   7                     8.91
#   8                     9.44
#   9                        -
#   10                    9.81
#   11                   14.11
#   12                    9.12
#   13                       -
#   14                       -
#   15                       -
#   16                       -
#   17                       -
#   18                    9.66
#
#   [19 rows x 37 columns]}}

# %%
# 1.2 When we apply the two main arguments 
import_data_sbs_banks( 11, 2012)
# Out:
# {'2012': {'12':                                        Tasa Anual (%) Continental Comercio  \
#   0                                        Corporativos        5.21    10.00
#   1                                          Descuentos        5.48    10.00
#   2                             Préstamos hasta 30 días        5.08        -
#   3                           Préstamos de 31 a 90 días        5.16        -
#   4                          Préstamos de 91 a 180 días        5.28        -
#   5                         Préstamos de 181 a 360 días        4.83        -
#   6                         Préstamos a más de 360 días        5.85        -
#   7                                    Grandes Empresas        7.47    12.87
#   8                                          Descuentos        7.76    11.99
#   9                             Préstamos hasta 30 días        7.85    10.45
#   10                          Préstamos de 31 a 90 días        7.36    11.42
#   11                         Préstamos de 91 a 180 días        7.40    14.00
#   12                        Préstamos de 181 a 360 días        7.56        -
#   13                        Préstamos a más de 360 días        7.37        -
#   14                                  Medianas Empresas       12.42    15.73
#   15                                         Descuentos       11.89    20.17
#   16                            Préstamos hasta 30 días       11.94    11.88
#   17                          Préstamos de 31 a 90 días       12.46     8.07
#   18                         Préstamos de 91 a 180 días       12.45    12.16
#   19                        Préstamos de 181 a 360 días       13.40    25.00
#   20                        Préstamos a más de 360 días       12.84    17.97
#   21                                  Pequeñas Empresas       21.83    27.18
#   22                                         Descuentos       22.58    34.77
#   23                            Préstamos hasta 30 días       21.95    26.33
#   24                          Préstamos de 31 a 90 días       21.29    27.95
#   25                         Préstamos de 91 a 180 días       21.72    26.67
#   26                        Préstamos de 181 a 360 días       21.94    17.29
#   27                        Préstamos a más de 360 días       21.75    26.95
#   28                                      Microempresas       33.18    32.12
#   29                                Tarjetas de Crédito       35.77    34.35
#   30                                         Descuentos       32.54    24.69
#   31                              Préstamos Revolventes       31.56        -
#   32               Préstamos a cuota fija hasta 30 días       32.24    42.00
#   33             Préstamos a cuota fija de 31 a 90 días       31.13    37.06
#   34            Préstamos a cuota fija de 91 a 180 días       29.99    33.33
#   35           Préstamos a cuota fija de 181 a 360 días       30.67    33.68
#   36           Préstamos a cuota fija a más de 360 días       30.28    31.87
#   37                                            Consumo       36.47    16.67
#   38                                Tarjetas de Crédito       45.58    23.38
#   39                              Préstamos Revolventes       22.11        -
#   40          Préstamos no Revolventes para automóviles        9.70        -
#   41  Préstamos no Revolventes para libre disponibil...       17.29    16.54
#   42  Préstamos no Revolventes para libre disponibil...       15.59    16.46
#   43                             Créditos pignoraticios           -    63.00
#   44                                       Hipotecarios        8.70     9.78
#   45               Préstamos hipotecarios para vivienda        8.70     9.78
#   46  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
#   47  Nota: Cuadro elaborado sobre la base de la inf...         NaN      NaN
#
#      Crédito Financiero    BIF Scotiabank Citibank Interbank Mibanco   HSBC  \
#   0     6.17          -   6.99       4.59     5.23      5.20       -      -
#   1     7.15          -   7.18       7.09     5.17      5.34       -      -
#   2     7.20          -      -       4.33     4.56      4.85       -      -
#   3     5.33          -   6.78          -     6.86      5.84       -      -
#   4     6.92          -   6.89       6.55     5.69      5.08       -      -
#   5        -          -      -       4.80        -         -       -      -
#   6     7.20          -      -          -        -      6.80       -      -
#   7     7.54       8.65   8.34       5.65     6.06      7.03       -   9.01
#   8     7.36       8.78   9.33       6.80     9.80      6.90       -   9.28
#   9     7.68       7.64   7.71       5.63     5.39      6.94       -   8.88
#   10    8.25       9.15   8.14       6.37     6.04      7.69       -   9.20
#   11    7.83       8.15   7.92       5.95     5.82      7.10       -   8.60
#   12    7.02      11.00   8.85       4.43     5.62         -       -      -
#   13    7.36       8.69   8.18       6.61        -      7.27       -      -
#   14    9.93      12.24  10.85      11.62     7.34     10.06   18.42  10.57
#   15    9.89      11.58  10.83       9.60    10.25      8.36       -  11.56
#   16    9.00      13.24  11.06      12.85     7.58      8.51   18.36  10.48
#   17   10.45      10.54  10.85      10.98     5.86      9.49   17.39  10.38
#   18   11.13      10.91  11.50      10.59        -      8.31   22.50  10.39
#   19    8.06      18.81  11.23      13.78        -     15.89   19.02  14.00
#   20    9.78      18.14  10.44      18.26        -     12.77   18.54  10.29
#   21   16.74      24.66  15.01      26.76        -     17.83   24.39  10.77
#   22   12.46      13.84  14.77      13.48        -     10.18       -      -
#   23   11.93      26.05  17.05      17.94        -     16.84   22.60      -
#   24   17.21      24.58  14.48      21.49        -     18.56   27.12  11.02
#   25   22.24      24.64  14.12      22.37        -     14.41   25.23   9.17
#   26   12.42      27.83  13.30      27.63        -     17.96   26.40  11.70
#   27   12.91      24.71  17.19      28.07        -     18.59   24.42      -
#   28   28.15      38.51  18.80      29.40        -     19.47   38.09      -
#   29   31.14          -      -      47.48        -         -       -      -
#   30   11.16          -  14.70      18.71        -      9.24       -      -
#   31       -      35.01  12.82          -        -     19.68   28.68      -
#   32       -          -      -      24.67        -         -   33.71      -
#   33   27.82      37.67  23.00      21.32        -     28.38   35.89      -
#   34   28.08      36.16  14.00      25.82        -         -   42.97      -
#   35       -      43.17  28.32      26.33        -     30.03   45.56      -
#   36   16.46      37.67  20.45      27.12        -     26.24   32.48      -
#   37   30.49      26.43  19.78      21.42    39.10     23.98   47.95  25.07
#   38   35.25          -  30.00      21.93    44.13     27.52   55.94  26.81
#   39       -          -      -     115.00        -     19.52       -      -
#   40   10.88      10.57   8.02       7.99        -     11.01       -   8.60
#   41   17.07      26.61  14.72      13.13        -         -   49.75  15.61
#   42   16.97      26.52  15.84      14.94    17.57     16.31   45.12  12.18
#   43       -          -      -          -        -         -       -      -
#   44    8.41       9.20   9.15       8.95        -      9.28   14.24   8.77
#   45    8.41       9.20   9.15       8.95        -      9.28   14.24   8.77
#   46     NaN        NaN    NaN        NaN      NaN       NaN     NaN    NaN
#   47     NaN        NaN    NaN        NaN      NaN       NaN     NaN    NaN
#
#      Falabella Santander Ripley  Azteca Deutsche Cencosud  Promedio
#   0          -      8.32      -       -        -        -      5.78
#   1          -      8.65      -       -        -        -      6.92
#   2          -         -      -       -        -        -      5.17
#   3          -         -      -       -        -        -      5.35
#   4          -         -      -       -        -        -      6.27
#   5          -      6.25      -       -        -        -      5.17
#   6          -         -      -       -        -        -      6.39
#   7          -      8.47      -       -        -        -      7.36
#   8          -      8.56      -       -        -        -      7.45
#   9          -         -      -       -        -        -      7.46
#   10         -         -      -       -        -        -      7.50
#   11         -         -      -       -        -        -      7.56
#   12         -      7.99      -       -        -        -      5.75
#   13         -         -      -       -        -        -      7.46
#   14         -      8.28      -       -        -        -     10.96
#   15         -      9.03      -       -        -        -     10.30
#   16         -         -      -       -        -        -      9.95
#   17         -         -      -       -        -        -     11.10
#   18         -         -      -       -        -        -     11.32
#   19         -      8.05      -       -        -        -     11.57
#   20         -      7.90      -       -        -        -     12.38
#   21         -         -      -       -        -        -     22.45
#   22         -         -      -       -        -        -     14.99
#   23         -         -      -       -        -        -     21.93
#   24         -         -      -       -        -        -     20.91
#   25         -         -      -       -        -        -     22.27
#   26         -         -      -       -        -        -     24.86
#   27         -         -      -       -        -        -     23.33
#   28         -         -      -       -        -        -     33.15
#   29         -         -      -       -        -        -     31.97
#   30         -         -      -       -        -        -     27.75
#   31         -         -      -       -        -        -     28.05
#   32         -         -      -       -        -        -     31.80
#   33         -         -      -       -        -        -     30.58
#   34         -         -      -       -        -        -     30.75
#   35         -         -      -       -        -        -     44.37
#   36         -         -      -       -        -        -     29.48
#   37     56.57         -  59.35  135.45        -    64.91     40.40
#   38     56.60         -  60.79  165.40        -    64.91     43.98
#   39         -         -      -       -        -        -     19.59
#   40         -         -      -  174.64        -        -     16.51
#   41      3.73         -  37.26  168.64        -        -    126.67
#   42     13.10         -  24.48  110.19        -        -     25.83
#   43         -         -      -       -        -        -     63.00
#   44         -         -      -       -        -        -      8.76
#   45         -         -      -       -        -        -      8.76
#   46       NaN       NaN    NaN     NaN      NaN      NaN       NaN
#   47       NaN       NaN    NaN     NaN      NaN      NaN       NaN  }}

# %%
# 1.3 We verify that the output is a data frame 
cats = import_data_sbs_banks( 1, 2010, 3, 2010 )
type( cats )
# Out:
# dict

# %%
# 1.4 We obtain the dataframe through the keys
cats['2010']['3']
# Out:
#           Tasa Anual (%)         CRÉDITOS COMERCIALES CRÉDITOS COMERCIALES.1  \
# 0         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
# 1         Tasa Anual (%)  Avances en Cuenta Corriente             Sobregiros
# 2                   BBVA                        13.77                  48.71
# 3      BANCO DE COMERCIO                            -                 138.18
# 4       BANCO DE CREDITO                        53.32                  17.00
# 5        BANCO PICHINCHA                            -                      -
# 6                 BANBIF                        14.44                  81.05
# 7        SCOTIABANK PERU                         7.92                  42.38
# 8      CITIBANK DEL PERU                         4.85                  29.72
# 9              INTERBANK                        15.12                   9.07
# 10               MIBANCO                            -                      -
# 11                  HSBC                            -                      -
# 12       BANCO FALABELLA                            -                      -
# 13        SANTANDER PERU                            -                  81.82
# 14          BANCO RIPLEY                            -                      -
# 15           ALFIN BANCO                            -                      -
# 16    DEUTSCHE BANK PERU                            -                      -
# 17  Promedio del Sistema                        32.45                  18.38
# 18                   NaN                          NaN                    NaN
#
#    CRÉDITOS COMERCIALES.2      CRÉDITOS COMERCIALES.3 CRÉDITOS COMERCIALES.4  \
# 0              Descuentos       Promedio de Préstamos  Promedio de Préstamos
# 1              Descuentos  Clientes deuda > S/. 5 MM4         Demás Clientes
# 2                   12.90                        3.32                   9.75
# 3                   12.85                           -                  18.59
# 4                    5.80                        4.26                   5.82
# 5                    9.60                        6.56                  17.36
# 6                    7.87                        3.69                   8.69
# 7                    6.89                        2.22                   7.82
# 8                       -                        4.53                   3.36
# 9                    6.93                        6.08                   7.48
# 10                      -                           -                  22.86
# 11                   6.79                        3.33                   5.26
# 12                      -                           -                      -
# 13                      -                           -                   6.26
# 14                      -                           -                      -
# 15                      -                           -                      -
# 16                      -                           -                      -
# 17                   7.41                        3.83                   9.24
# 18                    NaN                         NaN                    NaN
#
#    CRÉDITOS COMERCIALES.5     CRÉDITOS COMERCIALES.6   CRÉDITOS COMERCIALES.7  \
# 0   Promedio de Préstamos    Préstamos hasta 30 días  Préstamos hasta 30 días
# 1                Promedio  Clientes deuda > S/. 5 MM           Demás Clientes
# 2                    5.67                       1.68                     6.76
# 3                   18.59                          -                    18.94
# 4                    4.72                       6.32                     5.97
# 5                   15.72                          -                        -
# 6                    5.15                          -                    14.86
# 7                    4.85                       1.55                    11.85
# 8                    4.26                       3.56                        -
# 9                    6.89                       7.50                     9.00
# 10                  22.86                          -                        -
# 11                   4.46                          -                     3.70
# 12                      -                          -                        -
# 13                   6.26                          -                        -
# 14                      -                          -                        -
# 15                      -                          -                        -
# 16                      -                          -                        -
# 17                   5.82                       2.27                     7.84
# 18                    NaN                        NaN                      NaN
#
#      CRÉDITOS COMERCIALES.8  ...          CRÉDITOS DE CONSUMO.1  \
# 0   Préstamos hasta 30 días  ...            Tarjetas de crédito
# 1                  Promedio  ...            Tarjetas de crédito
# 2                      2.19  ...  Tarjetas de crédito cerradas4
# 3                     18.94  ...                              -
# 4                      6.13  ...                              -
# 5                         -  ...                              -
# 6                     14.86  ...                              -
# 7                      2.46  ...                              -
# 8                      3.56  ...                              -
# 9                      7.98  ...                              -
# 10                        -  ...                          69.70
# 11                     3.70  ...                              -
# 12                        -  ...                              -
# 13                        -  ...                              -
# 14                        -  ...                              -
# 15                        -  ...                              -
# 16                        -  ...                              -
# 17                     3.39  ...                              -
# 18                      NaN  ...                          69.70
#
#    CRÉDITOS DE CONSUMO.2     CRÉDITOS DE CONSUMO.3  \
# 0    Tarjetas de crédito  Préstamos no revolventes
# 1    Tarjetas de crédito          Para Automóviles
# 2               Promedio          Para Automóviles
# 3                  50.88                      9.02
# 4                  21.43                         -
# 5                  31.94                     10.22
# 6                  32.35                     11.44
# 7                  30.00                         -
# 8                  22.90                         -
# 9                  43.93                         -
# 10                 45.42                     15.94
# 11                 57.65                         -
# 12                 39.41                      8.84
# 13                 52.16                      9.99
# 14                     -                         -
# 15                 74.33                         -
# 16                183.86                         -
# 17                     -                         -
# 18                 47.38                     10.70
#
#                   CRÉDITOS DE CONSUMO.4           CRÉDITOS DE CONSUMO.5  \
# 0              Préstamos no revolventes        Préstamos no revolventes
# 1        Otros Préstamos Hasta 360 días  Otros Préstamos Hasta 360 días
# 2   Montos menores o iguales a S/. 1800       Montos mayores a S/. 1800
# 3                                 20.72                           16.66
# 4                                 16.72                           20.45
# 5                                 33.29                           15.82
# 6                                 70.28                           21.20
# 7                                 18.01                           17.47
# 8                                 13.64                           13.25
# 9                                     -                               -
# 10                                    -                               -
# 11                                56.42                           50.74
# 12                                19.08                           16.84
# 13                                39.00                               -
# 14                                    -                               -
# 15                                30.59                           28.25
# 16                               164.05                          131.67
# 17                                    -                               -
# 18                               123.63                           44.76
#
#              CRÉDITOS DE CONSUMO.6                CRÉDITOS DE CONSUMO.7  \
# 0         Préstamos no revolventes             Préstamos no revolventes
# 1   Otros Préstamos Hasta 360 días    Otros Préstamos a Más de 360 días
# 2                         Promedio  Montos menores o iguales a S/. 1800
# 3                            16.92                                20.33
# 4                            17.61                                15.83
# 5                            16.72                                34.91
# 6                            31.53                                76.49
# 7                            17.76                                17.55
# 8                            13.31                                17.58
# 9                                -                                    -
# 10                               -                                20.76
# 11                           52.91                                58.55
# 12                           17.09                                21.75
# 13                           39.00                                39.80
# 14                               -                                    -
# 15                           28.73                                36.12
# 16                          157.36                               133.71
# 17                               -                                    -
# 18                           80.00                                97.54
#
#                 CRÉDITOS DE CONSUMO.8              CRÉDITOS DE CONSUMO.9  \
# 0            Préstamos no revolventes           Préstamos no revolventes
# 1   Otros Préstamos a Más de 360 días  Otros Préstamos a Más de 360 días
# 2           Montos mayores a S/. 1800                           Promedio
# 3                               16.06                              16.08
# 4                               16.68                              16.67
# 5                               16.87                              16.94
# 6                               26.40                              32.15
# 7                               17.25                              17.25
# 8                               14.85                              14.86
# 9                               19.56                              19.56
# 10                              19.91                              19.92
# 11                              43.19                              43.99
# 12                              16.14                              16.14
# 13                              20.35                              20.83
# 14                                  -                                  -
# 15                              23.90                              24.42
# 16                             126.23                             129.71
# 17                                  -                                  -
# 18                              19.29                              21.23
#
#     PRÉSTAMOS HIPOTECARIOS
# 0   PRÉSTAMOS HIPOTECARIOS
# 1   PRÉSTAMOS HIPOTECARIOS
# 2   PRÉSTAMOS HIPOTECARIOS
# 3                     9.67
# 4                    11.00
# 5                     9.73
# 6                    11.02
# 7                     8.91
# 8                     9.44
# 9                        -
# 10                    9.81
# 11                   14.11
# 12                    9.12
# 13                       -
# 14                       -
# 15                       -
# 16                       -
# 17                       -
# 18                    9.66
#
# [19 rows x 37 columns]
