# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mpl
import chardet
import mapclassify

# %%
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap

# %% [markdown]
# ### 2) Import the data located at this link. It has information on people infected with dengue at the district level for 2015 to 2021

# %%
dengue= pd.read_csv( r'../../_data/data_dengue_peru.csv', thousands = ",", dtype={'Ubigeo': 'str'} , low_memory = False)
#, thousands = ","

# %%
#dengue['Ubigeo'] = dengue['Ubigeo'].astype(str).astype(int)

# %% [markdown]
# ### 3) Generate ubigeo for Departments and Provinces taking the first two and four numbers

# %%
dengue['UbigeoD'] = dengue['Ubigeo'].astype(str).str[:2]

# %%
dengue['UbigeoP'] = dengue['Ubigeo'].astype(str).str[:4]

# %%
maps = gpd.read_file(r'../../_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')

# %%
#maps = maps[['UBIGEO', 'geometry']]
maps = maps.rename({'UBIGEO':'Ubigeo'}, axis =1 )

# %%
#maps['Ubigeo'] = maps['Ubigeo'].astype('Int64')

# %% [markdown]
# ### 4) Use geopandas to plot the number of cases in 2021 by the district using a continuous legend. Do not forget to indicate the color of NA values.

# %%
dengue_2021 = dengue[dengue.Año == 2021]

# %%
dengue_2021['Casos'] = pd.to_numeric(dengue_2021['Casos'])
# Out:
# C:\Users\soyma\AppData\Local\Temp\ipykernel_22948\312242040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengue_2021['Casos'] = pd.to_numeric(dengue_2021['Casos'])

# %%
ex4 = dengue_2021.groupby(['Ubigeo'], as_index= False)[['Casos']].sum()

# %%
dataset = pd.merge(maps, ex4, how="left", on= "Ubigeo")

# %%
fig, ax = plt.subplots( figsize = ( 20, 20 ) )

dataset.plot( ax = ax, column = 'Casos', cmap = 'Purples', 
             linestyle = 'dotted', 
             edgecolor = 'black', missing_kwds= {
                 "color": "lightgrey"},
             legend = True,
             )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5) Use geopandas to plot the number of cases in 2021 by the province using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the province level.

# %%
prov = maps.dissolve (by = 'IDPROV', as_index = False)
prov
# Out:
#     IDPROV                                           geometry CCDD   NOMBDEP  \
# 0     0101  POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS
# 1     0102  POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS
# 2     0103  POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS
# 3     0104  POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS
# 4     0105  POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS
# ..     ...                                                ...  ...       ...
# 191   2403  POLYGON ((-80.19606 -3.61959, -80.19610 -3.620...   24    TUMBES
# 192   2501  POLYGON ((-73.27613 -9.68486, -73.27596 -9.685...   25   UCAYALI
# 193   2502  POLYGON ((-72.18238 -11.01266, -72.18112 -11.0...   25   UCAYALI
# 194   2503  POLYGON ((-75.11866 -8.90145, -75.11869 -8.902...   25   UCAYALI
# 195   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
#
#     CCPP          NOMBPROV CCDI                NOMBDIST  \
# 0     01       CHACHAPOYAS   06             CHUQUIBAMBA
# 1     02             BAGUA   04                EL PARCO
# 2     03           BONGARA   11                  VALERA
# 3     04      CONDORCANQUI   01                   NIEVA
# 4     05              LUYA   17  SAN FRANCISCO DEL YESO
# ..   ...               ...  ...                     ...
# 191   03         ZARUMILLA   01               ZARUMILLA
# 192   01  CORONEL PORTILLO   03                  IPARIA
# 193   02           ATALAYA   02                 SEPAHUA
# 194   03        PADRE ABAD   01              PADRE ABAD
# 195   04             PURUS   01                   PURUS
#
#                     CAPITAL  Ubigeo  CODIGO  CNT_CCPP              DESCRIPCIO  \
# 0               CHUQUIBAMBA  010106  010106        39             CHUQUIBAMBA
# 1                  EL PARCO  010204  010204         9                EL PARCO
# 2        VALERA (SAN PABLO)  010311  010311        16                  VALERA
# 3      SANTA MARIA DE NIEVA  010401  010401       131                   NIEVA
# 4    SAN FRANCISCO DEL YESO  010517  010517        22  SAN FRANCISCO DEL YESO
# ..                      ...     ...     ...       ...                     ...
# 191               ZARUMILLA  240301  240301         3               ZARUMILLA
# 192                  IPARIA  250103  250103        67                  IPARIA
# 193                 SEPAHUA  250202  250202        48                 SEPAHUA
# 194                AGUAYTIA  250301  250301       105              PADRE ABAD
# 195                   PURUS  250401  250401        49                   PURUS
#
#               DESCARGAR   WHATSAPP                  CONTACTO
# 0    www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 1    www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 2    www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 3    www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 4    www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# ..                  ...        ...                       ...
# 191  www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 192  www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 193  www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 194  www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
# 195  www.geogpsperu.com  931381206  juan.suyo@geogpsperu.com
#
# [196 rows x 16 columns]

# %%
ex5 = dengue_2021.groupby(['UbigeoP'], as_index= False)[['Casos']].sum()

# %%
dataset1 = pd.merge(prov, ex5, how="left", left_on= "IDPROV", right_on= "UbigeoP")

# %%
fig, ax = plt.subplots( figsize = ( 20, 20 ) )

dataset1.plot( ax = ax, column = 'Casos', cmap = 'Blues', 
             linestyle = 'dotted', 
             edgecolor = 'black', missing_kwds= {
                 "color": "lightgrey"},
             legend = True,
             )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 6.) Use geopandas to plot the number of cases by the department for all the years using subplots. Every subplot for each year. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the department level.

# %%
dep = maps.dissolve (by = 'CCDD', as_index = False)

# %%
dengue['CasosN'] = pd.to_numeric(dengue['Casos'])

# %%
ex6 = dengue.groupby(['Año','UbigeoD'], as_index= False)[['CasosN']].sum()

# %%
ex6
# Out:
#       Año UbigeoD  CasosN
# 0    2015      01    37.0
# 1    2015      02   118.0
# 2    2015      05   268.0
# 3    2015      06   218.0
# 4    2015      07     0.0
# ..    ...     ...     ...
# 142  2021      20  4010.0
# 143  2021      21     0.0
# 144  2021      22  3966.0
# 145  2021      24  1364.0
# 146  2021      25  1613.0
#
# [147 rows x 3 columns]

# %%
dataset2 = pd.merge(dep, ex6, how="left", left_on= "CCDD", right_on= "UbigeoD")

# %%
dataset2 = dataset2.drop(dataset2[dataset2['Año'].isna()].index)

# %%
fig, axis = plt.subplots( nrows = 3, ncols = 3, figsize = ( 20, 20 ) )

cmap = 'YlGn'

idx = 0

for i in range( 3 ):
    for j in range( 3 ):
        if idx < 7:
            ax = axis[ i ][ j ]
            year = dataset2.Año.unique()[ idx ]
            new_data = dataset2[ dataset2.Año == year ]
            new_data.plot( column = 'CasosN', cmap = cmap, linestyle = '--', edgecolor = 'black', ax = ax, legend = True, missing_kwds = dict( color = 'white' ) )
            ax.set_title( round(year) )
            idx = idx + 1

# %% [markdown]
# ### 7). Use geopandas to plot the number of cases by the department for all 2021 quarters using subplots. Every subplot for each quarter. Use a categorical legend with 5 bins. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the department level. Hint: Use Semana variable to group by quarters.

# %%
ex7 = dengue_2021

# %%
def cat(x):
    if x >= 40:
        return "Q4"
    if 27 <= x < 40:
        return "Q3"
    if 14 <= x < 27:
        return "Q2"
    if x < 14:
        return "Q1"
    return float ("nan")

ex7['Quarter'] = ex7['Semana'].apply(lambda x: cat(x))
# Out:
# C:\Users\soyma\AppData\Local\Temp\ipykernel_22948\1586223591.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ex7['Quarter'] = ex7['Semana'].apply(lambda x: cat(x))

# %%
ex7 = ex7.groupby(['Quarter','UbigeoD'], as_index= False)[['Casos']].sum()

# %%
dataset3 = pd.merge(dep, ex7, how="left", left_on= "CCDD", right_on= "UbigeoD")

# %%
cuts = pd.qcut(dataset3[ 'Casos' ], 5, retbins = True )[ 1 ][ 1: ]
bins = mapclassify.Quantiles(dataset3[ 'Casos' ], k=5).bins

# %%
fig, axis = plt.subplots( nrows = 2, ncols = 2, figsize = ( 20, 20 ) )

cmap = 'coolwarm'

idx = 0

for i in range( 2 ):
    for j in range( 2 ):
        ax = axis[ i ][ j ]
        quarter = dataset3.Quarter.unique()[ idx ]
        new_data = dataset3[ ( ( dataset3[ 'Quarter' ] == quarter ) | ( dataset3[ 'Quarter' ].isna() ) ) ]
        new_data.plot( column = 'Casos', cmap = cmap, linestyle = '--', edgecolor = 'black', ax = ax, scheme="User_Defined", legend = True, missing_kwds = dict( color = 'white' ), classification_kwds=dict(bins = cuts))
        ax.set_title( quarter )
        idx = idx + 1

# %% [markdown]
# Graphic based on: https://stackoverflow.com/questions/56690524/matplotlib-geopandas-plot-chloropleth-with-set-bins-for-colorscheme
