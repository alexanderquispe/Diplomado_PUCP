# %%
# Libraries
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
# !pip install chardet
import chardet

import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap
# Out:
# Requirement already satisfied: chardet in c:\users\luzmi\anaconda3\envs\geo2\lib\site-packages (4.0.0)

# %% [markdown]
# ### 2. Import the data located at this link. It has information on people infected with dengue at the district level for 2015 to 2021.

# %%
# Getting character format
base = open(r'../../_data/data_dengue_peru.csv', 'rb').read()
det = chardet.detect(base)
charenc = det['encoding']

# Import data

df_dengue = pd.read_csv( r'../../_data/data_dengue_peru.csv', encoding = charenc, dtype={'Ubigeo': 'str'},low_memory = False)
df_dengue
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo Casos
# 0        LA CONVENCION  080914     2
# 1       MARISCAL NIETO  180101   NaN
# 2       MARISCAL NIETO  180101   NaN
# 3        LA CONVENCION  080914     0
# 4        LA CONVENCION  080914     2
# ...                ...     ...   ...
# 172139            MANU  170203   NaN
# 172140       TAHUAMANU  170303   NaN
# 172141            MANU  170203   NaN
# 172142       TAHUAMANU  170303   NaN
# 172143       TAHUAMANU  170303   NaN
#
# [172144 rows x 8 columns]

# %% [markdown]
# ### 3. Generate ubigeo for Departments and Provinces taking the first two and four numbers.

# %%
df_dengue['IDPROV'] = df_dengue['Ubigeo'].astype(str).str[0:4]
df_dengue['IDDPTO'] = df_dengue['Ubigeo'].astype(str).str[0:2]

df_dengue=df_dengue.rename({'Ubigeo': 'IDDIST'}, axis=1)
df_dengue['IDDIST'] = df_dengue['IDDIST'].astype(str).astype(int)

df_dengue
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  IDDIST Casos IDPROV IDDPTO
# 0        LA CONVENCION   80914     2   0809     08
# 1       MARISCAL NIETO  180101   NaN   1801     18
# 2       MARISCAL NIETO  180101   NaN   1801     18
# 3        LA CONVENCION   80914     0   0809     08
# 4        LA CONVENCION   80914     2   0809     08
# ...                ...     ...   ...    ...    ...
# 172139            MANU  170203   NaN   1702     17
# 172140       TAHUAMANU  170303   NaN   1703     17
# 172141            MANU  170203   NaN   1702     17
# 172142       TAHUAMANU  170303   NaN   1703     17
# 172143       TAHUAMANU  170303   NaN   1703     17
#
# [172144 rows x 10 columns]

# %% [markdown]
# ### 4. Use geopandas to plot the number of cases in 2021 by the district using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile.

# %%
# Upload shapefile-distric level
maps = gpd.read_file(r'../../_data/shape_file/DISTRITOS.shp')
maps
# Out:
#      IDDPTO DEPARTAMEN IDPROV      PROVINCIA  IDDIST                DISTRITO  \
# 0        10    HUANUCO   1009    PUERTO INCA  100902         CODO DEL POZUZO
# 1        10    HUANUCO   1009    PUERTO INCA  100904             TOURNAVISTA
# 2        25    UCAYALI   2503     PADRE ABAD  250305  ALEXANDER VON HUMBOLDT
# 3        25    UCAYALI   2503     PADRE ABAD  250302                 IRAZOLA
# 4        25    UCAYALI   2503     PADRE ABAD  250304                 NESHUYA
# ...     ...        ...    ...            ...     ...                     ...
# 1868     10    HUANUCO   1006  LEONCIO PRADO  100608         CASTILLO GRANDE
# 1869     10    HUANUCO   1006  LEONCIO PRADO  100609            PUEBLO NUEVO
# 1870     10    HUANUCO   1006  LEONCIO PRADO  100610   SANTO DOMINGO DE ANDA
# 1871     21       PUNO   2111      SAN ROMAN  211105              SAN MIGUEL
# 1872     15       LIMA   1508         HUAURA  150806                  HUAURA
#
#                      CAPITAL CODCCPP  AREA FUENTE  \
# 0            CODO DEL POZUZO    0001     1   INEI
# 1                TOURNAVISTA    0001     1   INEI
# 2     ALEXANDER VON HUMBOLDT    0001     1   INEI
# 3              SAN ALEJANDRO    0001     1   INEI
# 4               MONTE ALEGRE    0001     1   INEI
# ...                      ...     ...   ...    ...
# 1868         CASTILLO GRANDE    0001     1   INEI
# 1869            PUEBLO NUEVO    0001     1   INEI
# 1870                   PACAE    0001     1   INEI
# 1871              SAN MIGUEL    0001     1   INEI
# 1872                  HUAURA    0001     1   INEI
#
#                                                geometry
# 0     POLYGON ((-75.31797 -9.29529, -75.31710 -9.297...
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...
# ...                                                 ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...
# 1872  POLYGON ((-77.37630 -10.89734, -77.37604 -10.8...
#
# [1873 rows x 11 columns]

# %%
df_dengue['Casos'] = df_dengue['Casos'].str.replace(",","")
df_dengue['Casos'] = df_dengue['Casos'].fillna(0)
df_dengue['Casos'] = df_dengue['Casos'].astype(str).astype(int)
df_dengue
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  IDDIST  Casos IDPROV IDDPTO
# 0        LA CONVENCION   80914      2   0809     08
# 1       MARISCAL NIETO  180101      0   1801     18
# 2       MARISCAL NIETO  180101      0   1801     18
# 3        LA CONVENCION   80914      0   0809     08
# 4        LA CONVENCION   80914      2   0809     08
# ...                ...     ...    ...    ...    ...
# 172139            MANU  170203      0   1702     17
# 172140       TAHUAMANU  170303      0   1703     17
# 172141            MANU  170203      0   1702     17
# 172142       TAHUAMANU  170303      0   1703     17
# 172143       TAHUAMANU  170303      0   1703     17
#
# [172144 rows x 10 columns]

# %%
df_dengue_2021d = df_dengue[df_dengue.Año == 2021]
df_dengue_2021d
# Out:
#          Año  Semana Eventos o daños   Departamento                 Distrito  \
# 1       2021      41          Dengue       MOQUEGUA                 MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA                 MOQUEGUA
# 6       2021      41          Dengue           LIMA            INDEPENDENCIA
# 7       2021      41          Dengue           LIMA  VILLA MARIA DEL TRIUNFO
# 8       2021      41          Dengue           LIMA                      ATE
# ...      ...     ...             ...            ...                      ...
# 172139  2021      49          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS                TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS                TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS                TAHUAMANU
#
#              Provincia  IDDIST  Casos IDPROV IDDPTO
# 1       MARISCAL NIETO  180101      0   1801     18
# 2       MARISCAL NIETO  180101      0   1801     18
# 6                 LIMA  150112      0   1501     15
# 7                 LIMA  150143      0   1501     15
# 8                 LIMA  150103      0   1501     15
# ...                ...     ...    ...    ...    ...
# 172139            MANU  170203      0   1702     17
# 172140       TAHUAMANU  170303      0   1703     17
# 172141            MANU  170203      0   1702     17
# 172142       TAHUAMANU  170303      0   1703     17
# 172143       TAHUAMANU  170303      0   1703     17
#
# [24857 rows x 10 columns]

# %%
df_dengue_2021d['Distrito'].unique().size
# Out:
# 449

# %%
# group_by district
df_dengue_districts= df_dengue.groupby(['IDDIST'])['Casos'].sum().reset_index().copy()
df_dengue_districts
# Out:
#      IDDIST  Casos
# 0     10101      6
# 1     10201    949
# 2     10202     49
# 3     10203     47
# 4     10204     10
# ..      ...    ...
# 470  250302    125
# 471  250303    187
# 472  250304     45
# 473  250305      8
# 474  250401      1
#
# [475 rows x 2 columns]

# %%
# group_by district
#df_dengue_districts = df_dengue.copy()
#df_dengue_districts['Casos_distrito'] = df_dengue_districts.groupby(['Distrito'])['Casos_distrito'].transform('sum')

# Merge geometry with data
maps['IDDIST'] = maps['IDDIST'].astype(str).astype(int)

maps1 = maps[['IDDIST','DISTRITO', 'geometry']]
data_geo1 = maps1.merge(df_dengue_districts, on='IDDIST', how='left')
data_geo1
# Out:
#       IDDIST                DISTRITO  \
# 0     100902         CODO DEL POZUZO
# 1     100904             TOURNAVISTA
# 2     250305  ALEXANDER VON HUMBOLDT
# 3     250302                 IRAZOLA
# 4     250304                 NESHUYA
# ...      ...                     ...
# 1868  100608         CASTILLO GRANDE
# 1869  100609            PUEBLO NUEVO
# 1870  100610   SANTO DOMINGO DE ANDA
# 1871  211105              SAN MIGUEL
# 1872  150806                  HUAURA
#
#                                                geometry  Casos
# 0     POLYGON ((-75.31797 -9.29529, -75.31710 -9.297...   49.0
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...   56.0
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...    8.0
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...  125.0
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...   45.0
# ...                                                 ...    ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...  562.0
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...   22.0
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...    NaN
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...    NaN
# 1872  POLYGON ((-77.37630 -10.89734, -77.37604 -10.8...    NaN
#
# [1873 rows x 4 columns]

# %%
base=gpd.GeoDataFrame(data_geo1, geometry=data_geo1.geometry)

# %%
base
# Out:
#       IDDIST                DISTRITO  \
# 0     100902         CODO DEL POZUZO
# 1     100904             TOURNAVISTA
# 2     250305  ALEXANDER VON HUMBOLDT
# 3     250302                 IRAZOLA
# 4     250304                 NESHUYA
# ...      ...                     ...
# 1868  100608         CASTILLO GRANDE
# 1869  100609            PUEBLO NUEVO
# 1870  100610   SANTO DOMINGO DE ANDA
# 1871  211105              SAN MIGUEL
# 1872  150806                  HUAURA
#
#                                                geometry  Casos
# 0     POLYGON ((-75.31797 -9.29529, -75.31710 -9.297...   49.0
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...   56.0
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...    8.0
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...  125.0
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...   45.0
# ...                                                 ...    ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...  562.0
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...   22.0
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...    NaN
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...    NaN
# 1872  POLYGON ((-77.37630 -10.89734, -77.37604 -10.8...    NaN
#
# [1873 rows x 4 columns]

# %%
#fig, ax = plt.subplots(figsize=(20, 20))

#base.plot(  ax=ax, color='midnightblue', linestyle='dashdot',edgecolor='black' )
#plt.show()


base.plot(column='Casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          legend = True)


#plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5. Use geopandas to plot the number of cases in 2021 by the province using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the province level.

# %%
# group_by district
df_dengue['IDPROV'] = df_dengue['IDPROV'].astype(str).astype(int)
df_dengue
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  IDDIST  Casos  IDPROV IDDPTO
# 0        LA CONVENCION   80914      2     809     08
# 1       MARISCAL NIETO  180101      0    1801     18
# 2       MARISCAL NIETO  180101      0    1801     18
# 3        LA CONVENCION   80914      0     809     08
# 4        LA CONVENCION   80914      2     809     08
# ...                ...     ...    ...     ...    ...
# 172139            MANU  170203      0    1702     17
# 172140       TAHUAMANU  170303      0    1703     17
# 172141            MANU  170203      0    1702     17
# 172142       TAHUAMANU  170303      0    1703     17
# 172143       TAHUAMANU  170303      0    1703     17
#
# [172144 rows x 10 columns]

# %%
df_dengue_2021p = df_dengue[df_dengue.Año == 2021]
df_dengue_province= df_dengue_2021p.groupby(['IDPROV'])['Casos'].sum().reset_index().copy()
df_dengue_province
# Out:
#     IDPROV  Casos
# 0      101      0
# 1      102    676
# 2      103      0
# 3      104    435
# 4      107    719
# ..     ...    ...
# 87    2403     72
# 88    2501   1241
# 89    2502    179
# 90    2503    193
# 91    2504      0
#
# [92 rows x 2 columns]

# %%
# Merge geometry with data

maps['IDPROV'] = maps['IDPROV'].astype(str).astype(int)

maps2 = maps[['IDPROV','PROVINCIA', 'geometry']]

data_geo2 = maps2.merge(df_dengue_province, on='IDPROV', how='left')
data_geo2
# Out:
#       IDPROV      PROVINCIA  \
# 0       1009    PUERTO INCA
# 1       1009    PUERTO INCA
# 2       2503     PADRE ABAD
# 3       2503     PADRE ABAD
# 4       2503     PADRE ABAD
# ...      ...            ...
# 1868    1006  LEONCIO PRADO
# 1869    1006  LEONCIO PRADO
# 1870    1006  LEONCIO PRADO
# 1871    2111      SAN ROMAN
# 1872    1508         HUAURA
#
#                                                geometry   Casos
# 0     POLYGON ((-75.31797 -9.29529, -75.31710 -9.297...   258.0
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...   258.0
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...   193.0
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...   193.0
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...   193.0
# ...                                                 ...     ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...  2290.0
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...  2290.0
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...  2290.0
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...     NaN
# 1872  POLYGON ((-77.37630 -10.89734, -77.37604 -10.8...     NaN
#
# [1873 rows x 4 columns]

# %%
base= gpd.GeoDataFrame(data_geo2, geometry=data_geo2.geometry)

# %%
base.plot(column='Casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          legend = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 6 Use geopandas to plot the number of cases by the department for all the years using subplots. Every subplot for each year. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the department level.

# %%
limit_dist= gpd.read_file(r'../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp')
limit_dist.head()
# Out:
#    OBJECTID_1  OBJECTID CCDD   NOMBDEP      CAPITAL  Shape_STAr  Shape_STLe  \
# 0           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 1           2       2.0   02    ANCASH       HUARAZ    2.954592   11.780424
# 2           3       3.0   03  APURIMAC      ABANCAY    1.765933    7.730154
# 3           4       4.0   04  AREQUIPA     AREQUIPA    5.330203   17.405040
# 4           5       5.0   05  AYACUCHO     AYACUCHO    3.643705   17.127166
#
#    ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1         1   11.780424    2.954592  juan.suyo@geogpsperu.com
# 2         2    7.730154    1.765933  juan.suyo@geogpsperu.com
# 3         3   17.405040    5.330203  juan.suyo@geogpsperu.com
# 4         4   17.127166    3.643705  juan.suyo@geogpsperu.com
#
#              CONTACTO   WHATSAPP  \
# 0  www.geogpsperu.com  931381206
# 1  www.geogpsperu.com  931381206
# 2  www.geogpsperu.com  931381206
# 3  www.geogpsperu.com  931381206
# 4  www.geogpsperu.com  931381206
#
#                                             geometry
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2  POLYGON ((-73.74655 -13.17442, -73.74570 -13.1...
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4  POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...

# %%
df_dengue_dpt = df_dengue.groupby(['Departamento','Año'], as_index = False )[ [ 'Casos' ] ].sum()
df_dengue_dpt.head()
# Out:
#   Departamento   Año  Casos
# 0     AMAZONAS  2015     37
# 1     AMAZONAS  2016     90
# 2     AMAZONAS  2017     93
# 3     AMAZONAS  2018    109
# 4     AMAZONAS  2019    164

# %%
dpt_dengue_limit = limit_dist.merge(df_dengue_dpt, left_on='NOMBDEP', right_on='Departamento', how='left')
dpt_dengue_limit.head()
# Out:
#    OBJECTID_1  OBJECTID CCDD   NOMBDEP      CAPITAL  Shape_STAr  Shape_STLe  \
# 0           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 1           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 2           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 3           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 4           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
#
#    ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 2         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 3         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 4         0   12.912088    3.203006  juan.suyo@geogpsperu.com
#
#              CONTACTO   WHATSAPP  \
# 0  www.geogpsperu.com  931381206
# 1  www.geogpsperu.com  931381206
# 2  www.geogpsperu.com  931381206
# 3  www.geogpsperu.com  931381206
# 4  www.geogpsperu.com  931381206
#
#                                             geometry Departamento     Año  \
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...     AMAZONAS  2015.0
# 1  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...     AMAZONAS  2016.0
# 2  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...     AMAZONAS  2017.0
# 3  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...     AMAZONAS  2018.0
# 4  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...     AMAZONAS  2019.0
#
#    Casos
# 0   37.0
# 1   90.0
# 2   93.0
# 3  109.0
# 4  164.0

# %%
years = df_dengue_dpt['Año'].unique().tolist()

# %%
fig, axis = plt.subplots( nrows = 4, ncols= 3, figsize = ( 15, 15 ) )
idx = 0
for i in range( 4 ):
    for j in range ( 3 ):
        ax = axis[ i ][ j ]
        years = dpt_dengue_limit.years.unique()[ idx ]
        df6 = dpt_dengue_limit[ dpt_dengue_limit.years == years ]
        df6.plot( column='Casos', 
                  cmap='Reds', 
                  linestyle='--',
                  edgecolor='black', 
                  legend = True, 
                  ax = ax 
                )
        ax.set_title( years )
        idx = idx + 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6224/2197655143.py in <module>
#       4     for j in range ( 3 ):
#       5         ax = axis[ i ][ j ]
# ----> 6         years = dpt_dengue_limit.years.unique()[ idx ]
#       7         df6 = dpt_dengue_limit[ dpt_dengue_limit.years == years ]
#       8         df6.plot( column='Casos',
#
# ~\anaconda3\envs\geo2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'years'
