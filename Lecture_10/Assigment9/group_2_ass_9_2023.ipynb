# %% [markdown]
# # Assigment 9

# %% [markdown]
# ## 1. Import the data located at this <a href="https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/data_dengue_peru.csv">link</a>. It has information on people infected with dengue at the district level for 2015 to 2021.

# %%
# !pip install geopandas
# !pip install folium
# Out:
# Requirement already satisfied: geopandas in c:\users\gustavo\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: packaging in c:\users\gustavo\anaconda3\lib\site-packages (from geopandas) (23.0)
# Requirement already satisfied: shapely>=1.7 in c:\users\gustavo\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\gustavo\anaconda3\lib\site-packages (from geopandas) (1.9.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\gustavo\anaconda3\lib\site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\gustavo\anaconda3\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: click~=8.0 in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: munch>=2.3.2 in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (63.4.1)
# Requirement already satisfied: certifi in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2022.9.14)
# Requirement already satisfied: cligj>=0.5 in c:\users\gustavo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gustavo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gustavo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gustavo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: colorama in c:\users\gustavo\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.6)
# Requirement already satisfied: six in c:\users\gustavo\anaconda3\lib\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      -------------------------------------- 102.3/102.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\gustavo\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\gustavo\anaconda3\lib\site-packages (from folium) (2.11.3)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\gustavo\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gustavo\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gustavo\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gustavo\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\gustavo\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gustavo\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap
import chardet

# %%
# Gettting the character format

base = open(r'../../_data/data_dengue_peru.csv', 'rb').read()
det = chardet.detect(base)
charenc = det['encoding']
charenc
# Out:
# 'UTF-8-SIG'

# %%
data_dengue = pd.read_csv( r'../../_data/data_dengue_peru.csv', encoding = charenc)
data_dengue
# Out:
# C:\Users\GUSTAVO\AppData\Local\Temp\ipykernel_13864\1040543773.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_dengue = pd.read_csv( r'../../_data/data_dengue_peru.csv', encoding = charenc)
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo Casos
# 0        LA CONVENCION   80914   2.0
# 1       MARISCAL NIETO  180101   NaN
# 2       MARISCAL NIETO  180101   NaN
# 3        LA CONVENCION   80914   0.0
# 4        LA CONVENCION   80914   2.0
# ...                ...     ...   ...
# 172139            MANU  170203   NaN
# 172140       TAHUAMANU  170303   NaN
# 172141            MANU  170203   NaN
# 172142       TAHUAMANU  170303   NaN
# 172143       TAHUAMANU  170303   NaN
#
# [172144 rows x 8 columns]

# %%
data_dengue.dtypes
# Out:
# Año                 int64
# Semana              int64
# Eventos o daños    object
# Departamento       object
# Distrito           object
# Provincia          object
# Ubigeo              int64
# Casos              object
# dtype: object

# %% [markdown]
# ## 2. Generate ubigeo for Departments and Provinces taking the first two and four numbers. Hint: Use this <a href="https://stackoverflow.com/questions/35552874/get-first-letter-of-a-string-from-column">code</a>.

# %%
data_dengue['Ubigeo'] = data_dengue['Ubigeo'].astype('string')

for i in range(len(data_dengue.index)):
    if len(data_dengue['Ubigeo'][i]) == 5:
        data_dengue['Ubigeo'][i] = '0' + data_dengue['Ubigeo'][i]
    else:
        data_dengue['Ubigeo'][i] = data_dengue['Ubigeo'][i]
#data_dengue['Ubigeo'] = pd.to_numeric(data_dengue['Ubigeo'])

data_dengue['Ubigeo_dep'] = [x[0:2] for x in data_dengue['Ubigeo']]
data_dengue['Ubigeo_prov'] = [z[0:4] for z in data_dengue['Ubigeo']]

data_dengue
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo Casos Ubigeo_dep Ubigeo_prov
# 0        LA CONVENCION  080914   2.0         08        0809
# 1       MARISCAL NIETO  180101   NaN         18        1801
# 2       MARISCAL NIETO  180101   NaN         18        1801
# 3        LA CONVENCION  080914   0.0         08        0809
# 4        LA CONVENCION  080914   2.0         08        0809
# ...                ...     ...   ...        ...         ...
# 172139            MANU  170203   NaN         17        1702
# 172140       TAHUAMANU  170303   NaN         17        1703
# 172141            MANU  170203   NaN         17        1702
# 172142       TAHUAMANU  170303   NaN         17        1703
# 172143       TAHUAMANU  170303   NaN         17        1703
#
# [172144 rows x 10 columns]

# %%
data_dengue.dtypes
# Out:
# Año                 int64
# Semana              int64
# Eventos o daños    object
# Departamento       object
# Distrito           object
# Provincia          object
# Ubigeo             string
# Casos              object
# Ubigeo_dep         object
# Ubigeo_prov        object
# dtype: object

# %% [markdown]
# ## 3. Use geopandas to plot the number of cases in 2021 by the district using a continuous legend. Do not forget to indicate the color of NA values. Use this <a href="https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/_data/LIMITE_DISTRITAL_2020_INEI">this shapefile</a>.

# %%
# Upload shape file at district level
shape_file = gpd.read_file(r'../../_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')
shape_file
# Out:
#      CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0      06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1      06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2      06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3      06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4      06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
# ...   ...        ...  ...         ...  ...           ...              ...
# 1869   04   AREQUIPA   04    CASTILLA   04       CHACHAS          CHACHAS
# 1870   04   AREQUIPA   04    CASTILLA   05  CHILCAYMARCA     CHILCAYMARCA
# 1871   04   AREQUIPA   04    CASTILLA   06         CHOCO            CHOCO
# 1872   04   AREQUIPA   04    CASTILLA   07    HUANCARQUI       HUANCARQUI
# 1873   12      JUNIN   06      SATIPO   04      MAZAMARI              NaN
#
#       UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# 0     060504   0605  060504        50      GUZMANGO  www.geogpsperu.com
# 1     061105   0611  061105        15      EL PRADO  www.geogpsperu.com
# 2     061109   0611  061109        41        NIEPOS  www.geogpsperu.com
# 3     061110   0611  061110        48  SAN GREGORIO  www.geogpsperu.com
# 4     061203   0612  061203         9      SAN LUIS  www.geogpsperu.com
# ...      ...    ...     ...       ...           ...                 ...
# 1869  040404   0404  040404        19       CHACHAS  www.geogpsperu.com
# 1870  040405   0404  040405        24  CHILCAYMARCA  www.geogpsperu.com
# 1871  040406   0404  040406        58         CHOCO  www.geogpsperu.com
# 1872  040407   0404  040407        25    HUANCARQUI  www.geogpsperu.com
# 1873  120604   1206  120604       152      MAZAMARI  www.geogpsperu.com
#
#        WHATSAPP                  CONTACTO  \
# 0     931381206  juan.suyo@geogpsperu.com
# 1     931381206  juan.suyo@geogpsperu.com
# 2     931381206  juan.suyo@geogpsperu.com
# 3     931381206  juan.suyo@geogpsperu.com
# 4     931381206  juan.suyo@geogpsperu.com
# ...         ...                       ...
# 1869  931381206  juan.suyo@geogpsperu.com
# 1870  931381206  juan.suyo@geogpsperu.com
# 1871  931381206  juan.suyo@geogpsperu.com
# 1872  931381206  juan.suyo@geogpsperu.com
# 1873  931381206  juan.suyo@geogpsperu.com
#
#                                                geometry
# 0     POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1     POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2     POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3     POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4     POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...                                                 ...
# 1869  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
# [1874 rows x 16 columns]

# %%
data_dengue['Año'] = data_dengue['Año'].astype('string')
data_dengue = data_dengue.rename(columns={'Ubigeo':'UBIGEO'})
dengue2021 = data_dengue.loc[data_dengue.Año == '2021', :].reset_index( drop = True )
dengue2021 = dengue2021.loc[:, ['Año', 'Semana', 'Departamento', 'Provincia', 'Distrito', 'UBIGEO', 'Ubigeo_prov', 'Ubigeo_dep', 'Casos']]
#dengue2021['Casos'] = pd.to_numeric(dengue2021['Casos'],errors='coerce').astype(pd.Int64Dtype())
dengue2021 = dengue2021.dropna()
dengue2021['Casos'] = dengue2021['Casos'].astype('int')
dengue2021
# Out:
#         Año  Semana Departamento      Provincia   Distrito  UBIGEO  \
# 39     2021       3        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1478   2021       4        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1479   2021       2        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1526   2021       6        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1527   2021       8        CUSCO  LA CONVENCION  MEGANTONI  080914
# ...     ...     ...          ...            ...        ...     ...
# 24625  2021      14          ICA        CHINCHA    SUNAMPE  110210
# 24626  2021      14  LA LIBERTAD      PACASMAYO  PACASMAYO  130704
# 24627  2021      15  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24628  2021      16  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24629  2021      18  LA LIBERTAD         CHEPEN     CHEPEN  130401
#
#       Ubigeo_prov Ubigeo_dep  Casos
# 39           0809         08      0
# 1478         0809         08      0
# 1479         0809         08      0
# 1526         0809         08      0
# 1527         0809         08      0
# ...           ...        ...    ...
# 24625        1102         11      2
# 24626        1307         13      1
# 24627        1304         13      2
# 24628        1304         13      2
# 24629        1304         13      2
#
# [18760 rows x 9 columns]

# %%
#dengue2021['Casos'].unique()
dengue2021.dtypes
# Out:
# Año             string
# Semana           int64
# Departamento    object
# Provincia       object
# Distrito        object
# UBIGEO          string
# Ubigeo_prov     object
# Ubigeo_dep      object
# Casos            int32
# dtype: object

# %%
dengue2021_dist = dengue2021.groupby( ['Departamento', 'Provincia','Distrito', 'UBIGEO', 'Ubigeo_prov', 'Ubigeo_dep'], as_index = False).agg(Total_casos=('Casos', 'sum'))
dengue2021_dist
# Out:
#     Departamento   Provincia    Distrito  UBIGEO Ubigeo_prov Ubigeo_dep  \
# 0       AMAZONAS       BAGUA    ARAMANGO  010202        0102         01
# 1       AMAZONAS       BAGUA       BAGUA  010201        0102         01
# 2       AMAZONAS       BAGUA    COPALLIN  010203        0102         01
# 3       AMAZONAS       BAGUA    EL PARCO  010204        0102         01
# 4       AMAZONAS       BAGUA       IMAZA  010205        0102         01
# ..           ...         ...         ...     ...         ...        ...
# 464      UCAYALI  PADRE ABAD    CURIMANA  250303        2503         25
# 465      UCAYALI  PADRE ABAD     IRAZOLA  250302        2503         25
# 466      UCAYALI  PADRE ABAD     NESHUYA  250304        2503         25
# 467      UCAYALI  PADRE ABAD  PADRE ABAD  250301        2503         25
# 468      UCAYALI       PURUS       PURUS  250401        2504         25
#
#      Total_casos
# 0             25
# 1            474
# 2             38
# 3              8
# 4            109
# ..           ...
# 464           32
# 465           26
# 466           14
# 467          119
# 468            0
#
# [469 rows x 7 columns]

# %%
geo_dist = shape_file.loc[:,['CCDD', 'IDPROV', 'UBIGEO', 'geometry', 'NOMBDEP', 'NOMBPROV', 'NOMBDIST']].reset_index( drop = True)
#geo_dep = geo_dep.drop_duplicates( subset=['UBIGEO', 'geometry']).reset_index( drop = True)
geo_dist
# Out:
#      CCDD IDPROV  UBIGEO                                           geometry  \
# 0      06   0605  060504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1      06   0611  061105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2      06   0611  061109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3      06   0611  061110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4      06   0612  061203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...   ...    ...     ...                                                ...
# 1869   04   0404  040404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870   04   0404  040405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871   04   0404  040406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872   04   0404  040407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873   12   1206  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
#         NOMBDEP    NOMBPROV      NOMBDIST
# 0     CAJAMARCA   CONTUMAZA      GUZMANGO
# 1     CAJAMARCA  SAN MIGUEL      EL PRADO
# 2     CAJAMARCA  SAN MIGUEL        NIEPOS
# 3     CAJAMARCA  SAN MIGUEL  SAN GREGORIO
# 4     CAJAMARCA   SAN PABLO      SAN LUIS
# ...         ...         ...           ...
# 1869   AREQUIPA    CASTILLA       CHACHAS
# 1870   AREQUIPA    CASTILLA  CHILCAYMARCA
# 1871   AREQUIPA    CASTILLA         CHOCO
# 1872   AREQUIPA    CASTILLA    HUANCARQUI
# 1873      JUNIN      SATIPO      MAZAMARI
#
# [1874 rows x 7 columns]

# %%
dengue_2021_dist = pd.merge(geo_dist, dengue2021_dist, how='left', on=['UBIGEO'])
dengue_2021_dist = dengue_2021_dist.drop(columns=['Departamento','Provincia','Distrito'])
dengue_2021_dist['UBIGEO'] = dengue_2021_dist['UBIGEO'].astype(str).astype(int)
dengue_2021_dist
# Out:
#      CCDD IDPROV  UBIGEO                                           geometry  \
# 0      06   0605   60504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1      06   0611   61105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2      06   0611   61109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3      06   0611   61110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4      06   0612   61203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...   ...    ...     ...                                                ...
# 1869   04   0404   40404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870   04   0404   40405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871   04   0404   40406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872   04   0404   40407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873   12   1206  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
#         NOMBDEP    NOMBPROV      NOMBDIST Ubigeo_prov Ubigeo_dep  Total_casos
# 0     CAJAMARCA   CONTUMAZA      GUZMANGO         NaN        NaN          NaN
# 1     CAJAMARCA  SAN MIGUEL      EL PRADO         NaN        NaN          NaN
# 2     CAJAMARCA  SAN MIGUEL        NIEPOS         NaN        NaN          NaN
# 3     CAJAMARCA  SAN MIGUEL  SAN GREGORIO         NaN        NaN          NaN
# 4     CAJAMARCA   SAN PABLO      SAN LUIS         NaN        NaN          NaN
# ...         ...         ...           ...         ...        ...          ...
# 1869   AREQUIPA    CASTILLA       CHACHAS         NaN        NaN          NaN
# 1870   AREQUIPA    CASTILLA  CHILCAYMARCA         NaN        NaN          NaN
# 1871   AREQUIPA    CASTILLA         CHOCO         NaN        NaN          NaN
# 1872   AREQUIPA    CASTILLA    HUANCARQUI         NaN        NaN          NaN
# 1873      JUNIN      SATIPO      MAZAMARI        1206         12        193.0
#
# [1874 rows x 10 columns]

# %%
dengue_2021_dist.dtypes
# Out:
# CCDD             object
# IDPROV           object
# UBIGEO            int32
# geometry       geometry
# NOMBDEP          object
# NOMBPROV         object
# NOMBDIST         object
# Ubigeo_prov      object
# Ubigeo_dep       object
# Total_casos     float64
# dtype: object

# %%
dengue_2021_dist.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Use geopandas to plot the number of cases in 2021by the province using a continuous legend. Do not forget to indicate the color of NA values. Use <a href="https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/_data/LIMITE_DISTRITAL_2020_INEI">this shapefile</a>. For this task, you will have to aggregate shapefiles at the province level.

# %%
geo_prov = geo_dist.dissolve( by = 'IDPROV' ).reset_index()
geo_prov = geo_prov.drop(columns=['UBIGEO','NOMBDIST'])
geo_prov
# Out:
#     IDPROV                                           geometry CCDD   NOMBDEP  \
# 0     0101  POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS
# 1     0102  POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS
# 2     0103  POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS
# 3     0104  POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS
# 4     0105  POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS
# ..     ...                                                ...  ...       ...
# 191   2403  POLYGON ((-80.19606 -3.61959, -80.19610 -3.620...   24    TUMBES
# 192   2501  POLYGON ((-73.27613 -9.68486, -73.27596 -9.685...   25   UCAYALI
# 193   2502  POLYGON ((-72.18238 -11.01266, -72.18112 -11.0...   25   UCAYALI
# 194   2503  POLYGON ((-75.11866 -8.90145, -75.11869 -8.902...   25   UCAYALI
# 195   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
#
#              NOMBPROV
# 0         CHACHAPOYAS
# 1               BAGUA
# 2             BONGARA
# 3        CONDORCANQUI
# 4                LUYA
# ..                ...
# 191         ZARUMILLA
# 192  CORONEL PORTILLO
# 193           ATALAYA
# 194        PADRE ABAD
# 195             PURUS
#
# [196 rows x 5 columns]

# %%
dengue2021_prov = dengue2021_dist.groupby( ['Departamento', 'Provincia', 'Ubigeo_prov', 'Ubigeo_dep'], as_index = False).agg(Total_casos=('Total_casos', 'sum'))
dengue2021_prov = dengue2021_prov.rename(columns={'Ubigeo_prov':'IDPROV'})
dengue2021_prov
# Out:
#    Departamento         Provincia IDPROV Ubigeo_dep  Total_casos
# 0      AMAZONAS             BAGUA   0102         01          676
# 1      AMAZONAS           BONGARA   0103         01            0
# 2      AMAZONAS       CHACHAPOYAS   0101         01            0
# 3      AMAZONAS      CONDORCANQUI   0104         01          435
# 4      AMAZONAS         UTCUBAMBA   0107         01          719
# ..          ...               ...    ...        ...          ...
# 87       TUMBES         ZARUMILLA   2403         24           72
# 88      UCAYALI           ATALAYA   2502         25          179
# 89      UCAYALI  CORONEL PORTILLO   2501         25         1241
# 90      UCAYALI        PADRE ABAD   2503         25          193
# 91      UCAYALI             PURUS   2504         25            0
#
# [92 rows x 5 columns]

# %%
dengue_2021_prov = pd.merge(geo_prov, dengue2021_prov, how='left', on=['IDPROV'])
dengue_2021_prov = dengue_2021_prov.drop(columns=['Departamento','Provincia'])
dengue_2021_prov['IDPROV'] = dengue_2021_prov['IDPROV'].astype(str).astype(int)
dengue_2021_prov
# Out:
#      IDPROV                                           geometry CCDD   NOMBDEP  \
# 0       101  POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS
# 1       102  POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS
# 2       103  POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS
# 3       104  POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS
# 4       105  POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS
# ..      ...                                                ...  ...       ...
# 191    2403  POLYGON ((-80.19606 -3.61959, -80.19610 -3.620...   24    TUMBES
# 192    2501  POLYGON ((-73.27613 -9.68486, -73.27596 -9.685...   25   UCAYALI
# 193    2502  POLYGON ((-72.18238 -11.01266, -72.18112 -11.0...   25   UCAYALI
# 194    2503  POLYGON ((-75.11866 -8.90145, -75.11869 -8.902...   25   UCAYALI
# 195    2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
#
#              NOMBPROV Ubigeo_dep  Total_casos
# 0         CHACHAPOYAS         01          0.0
# 1               BAGUA         01        676.0
# 2             BONGARA         01          0.0
# 3        CONDORCANQUI         01        435.0
# 4                LUYA        NaN          NaN
# ..                ...        ...          ...
# 191         ZARUMILLA         24         72.0
# 192  CORONEL PORTILLO         25       1241.0
# 193           ATALAYA         25        179.0
# 194        PADRE ABAD         25        193.0
# 195             PURUS         25          0.0
#
# [196 rows x 7 columns]

# %%
dengue_2021_prov.dtypes
# Out:
# IDPROV            int32
# geometry       geometry
# CCDD             object
# NOMBDEP          object
# NOMBPROV         object
# Ubigeo_dep       object
# Total_casos     float64
# dtype: object

# %%
dengue_2021_prov.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Use geopandas to plot the number of cases by the department for all the years using subplots. Every subplot for each year. Do not forget to indicate the color of NA values. Use <a href="https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/_data/LIMITE_DISTRITAL_2020_INEI">this shapefile</a>. For this task, you will have to aggregate shapefiles at the department level.

# %%
geo_dep = geo_prov.dissolve( by = 'CCDD' ).reset_index()
geo_dep = geo_dep.drop(columns=['IDPROV','NOMBPROV'])
geo_dep
# Out:
#    CCDD                                           geometry        NOMBDEP
# 0    01  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...       AMAZONAS
# 1    02  POLYGON ((-77.70012 -10.32263, -77.70189 -10.3...         ANCASH
# 2    03  POLYGON ((-72.35713 -14.43812, -72.35740 -14.4...       APURIMAC
# 3    04  POLYGON ((-71.32410 -17.06147, -71.32365 -17.0...       AREQUIPA
# 4    05  POLYGON ((-74.50249 -15.16092, -74.50336 -15.1...       AYACUCHO
# 5    06  POLYGON ((-78.81352 -7.42584, -78.81432 -7.425...      CAJAMARCA
# 6    07  POLYGON ((-77.10456 -12.06373, -77.10449 -12.0...         CALLAO
# 7    08  POLYGON ((-71.89418 -14.78954, -71.89579 -14.7...          CUSCO
# 8    09  POLYGON ((-75.25853 -14.04317, -75.26012 -14.0...   HUANCAVELICA
# 9    10  POLYGON ((-76.49368 -10.31116, -76.49334 -10.3...        HUANUCO
# 10   11  POLYGON ((-74.66456 -15.00605, -74.66471 -15.0...            ICA
# 11   12  POLYGON ((-75.56051 -12.41137, -75.56055 -12.4...          JUNIN
# 12   13  POLYGON ((-78.55792 -8.78238, -78.55894 -8.784...    LA LIBERTAD
# 13   14  POLYGON ((-79.82045 -6.98332, -79.82121 -6.982...     LAMBAYEQUE
# 14   15  MULTIPOLYGON (((-76.79916 -12.47212, -76.79917...           LIMA
# 15   16  POLYGON ((-74.50407 -7.26835, -74.50620 -7.269...         LORETO
# 16   17  POLYGON ((-70.40343 -13.11693, -70.40352 -13.1...  MADRE DE DIOS
# 17   18  POLYGON ((-71.08304 -17.72526, -71.08243 -17.7...       MOQUEGUA
# 18   19  POLYGON ((-76.18965 -10.95992, -76.19058 -10.9...          PASCO
# 19   20  POLYGON ((-80.07971 -5.80231, -80.07779 -5.803...          PIURA
# 20   21  MULTIPOLYGON (((-69.56622 -17.17833, -69.57322...           PUNO
# 21   22  POLYGON ((-76.12733 -8.36118, -76.12657 -8.363...     SAN MARTIN
# 22   23  POLYGON ((-70.37083 -18.34110, -70.37618 -18.3...          TACNA
# 23   24  POLYGON ((-80.84677 -4.18862, -80.84785 -4.189...         TUMBES
# 24   25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...        UCAYALI

# %%
dengue2021_dep = dengue2021_prov.groupby( ['Departamento', 'Ubigeo_dep'], as_index = False).agg(Total_casos=('Total_casos', 'sum'))
dengue2021_dep = dengue2021_dep.rename(columns={'Ubigeo_dep':'CCDD'})
dengue2021_dep
# Out:
#      Departamento CCDD  Total_casos
# 0        AMAZONAS   01         1830
# 1          ANCASH   02           26
# 2        AYACUCHO   05         1346
# 3       CAJAMARCA   06         2555
# 4          CALLAO   07            2
# 5           CUSCO   08         1341
# 6         HUANUCO   10         2735
# 7             ICA   11         4577
# 8           JUNIN   12         3168
# 9     LA LIBERTAD   13          382
# 10     LAMBAYEQUE   14          815
# 11           LIMA   15         1119
# 12         LORETO   16         4106
# 13  MADRE DE DIOS   17          883
# 14       MOQUEGUA   18            0
# 15          PASCO   19          358
# 16          PIURA   20         4010
# 17           PUNO   21            0
# 18     SAN MARTIN   22         3966
# 19         TUMBES   24         1364
# 20        UCAYALI   25         1613

# %%
dengue_2021_dep = pd.merge(geo_dep, dengue2021_dep, how='left', on=['CCDD'])
dengue_2021_dep = dengue_2021_dep.drop(columns=['Departamento'])
dengue_2021_dep['CCDD'] = dengue_2021_dep['CCDD'].astype(str).astype(int)
dengue_2021_dep
# Out:
#     CCDD                                           geometry        NOMBDEP  \
# 0      1  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...       AMAZONAS
# 1      2  POLYGON ((-77.70012 -10.32263, -77.70189 -10.3...         ANCASH
# 2      3  POLYGON ((-72.35713 -14.43812, -72.35740 -14.4...       APURIMAC
# 3      4  POLYGON ((-71.32410 -17.06147, -71.32365 -17.0...       AREQUIPA
# 4      5  POLYGON ((-74.50249 -15.16092, -74.50336 -15.1...       AYACUCHO
# 5      6  POLYGON ((-78.81352 -7.42584, -78.81432 -7.425...      CAJAMARCA
# 6      7  POLYGON ((-77.10456 -12.06373, -77.10449 -12.0...         CALLAO
# 7      8  POLYGON ((-71.89418 -14.78954, -71.89579 -14.7...          CUSCO
# 8      9  POLYGON ((-75.25853 -14.04317, -75.26012 -14.0...   HUANCAVELICA
# 9     10  POLYGON ((-76.49368 -10.31116, -76.49334 -10.3...        HUANUCO
# 10    11  POLYGON ((-74.66456 -15.00605, -74.66471 -15.0...            ICA
# 11    12  POLYGON ((-75.56051 -12.41137, -75.56055 -12.4...          JUNIN
# 12    13  POLYGON ((-78.55792 -8.78238, -78.55894 -8.784...    LA LIBERTAD
# 13    14  POLYGON ((-79.82045 -6.98332, -79.82121 -6.982...     LAMBAYEQUE
# 14    15  MULTIPOLYGON (((-76.79916 -12.47212, -76.79917...           LIMA
# 15    16  POLYGON ((-74.50407 -7.26835, -74.50620 -7.269...         LORETO
# 16    17  POLYGON ((-70.40343 -13.11693, -70.40352 -13.1...  MADRE DE DIOS
# 17    18  POLYGON ((-71.08304 -17.72526, -71.08243 -17.7...       MOQUEGUA
# 18    19  POLYGON ((-76.18965 -10.95992, -76.19058 -10.9...          PASCO
# 19    20  POLYGON ((-80.07971 -5.80231, -80.07779 -5.803...          PIURA
# 20    21  MULTIPOLYGON (((-69.56622 -17.17833, -69.57322...           PUNO
# 21    22  POLYGON ((-76.12733 -8.36118, -76.12657 -8.363...     SAN MARTIN
# 22    23  POLYGON ((-70.37083 -18.34110, -70.37618 -18.3...          TACNA
# 23    24  POLYGON ((-80.84677 -4.18862, -80.84785 -4.189...         TUMBES
# 24    25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...        UCAYALI
#
#     Total_casos
# 0        1830.0
# 1          26.0
# 2           NaN
# 3           NaN
# 4        1346.0
# 5        2555.0
# 6           2.0
# 7        1341.0
# 8           NaN
# 9        2735.0
# 10       4577.0
# 11       3168.0
# 12        382.0
# 13        815.0
# 14       1119.0
# 15       4106.0
# 16        883.0
# 17          0.0
# 18        358.0
# 19       4010.0
# 20          0.0
# 21       3966.0
# 22          NaN
# 23       1364.0
# 24       1613.0

# %%
dengue_2021_dep.dtypes
# Out:
# CCDD              int32
# geometry       geometry
# NOMBDEP          object
# Total_casos     float64
# dtype: object

# %%
dengue_2021_dep.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 6. Use geopandas to plot the number of cases by the department for all 2021 quarters using subplots. Every subplot for each quarter. Use a categorical legend with 5 bins. Do not forget to indicate the color of NA values. Use <a href="https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/_data/LIMITE_DISTRITAL_2020_INEI">this shapefile</a>. For this task, you will have to aggregate shapefiles at the department level. Hint: Use Semana variable to group by quarters.

# %%
dengue2021
# Out:
#         Año  Semana Departamento      Provincia   Distrito  UBIGEO  \
# 39     2021       3        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1478   2021       4        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1479   2021       2        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1526   2021       6        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1527   2021       8        CUSCO  LA CONVENCION  MEGANTONI  080914
# ...     ...     ...          ...            ...        ...     ...
# 24625  2021      14          ICA        CHINCHA    SUNAMPE  110210
# 24626  2021      14  LA LIBERTAD      PACASMAYO  PACASMAYO  130704
# 24627  2021      15  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24628  2021      16  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24629  2021      18  LA LIBERTAD         CHEPEN     CHEPEN  130401
#
#       Ubigeo_prov Ubigeo_dep  Casos quarters Quarters
# 39           0809         08      0       Q1       Q1
# 1478         0809         08      0       Q1       Q1
# 1479         0809         08      0       Q1       Q1
# 1526         0809         08      0       Q1       Q1
# 1527         0809         08      0       Q1       Q1
# ...           ...        ...    ...      ...      ...
# 24625        1102         11      2       Q2       Q2
# 24626        1307         13      1       Q2       Q2
# 24627        1304         13      2       Q2       Q2
# 24628        1304         13      2       Q2       Q2
# 24629        1304         13      2       Q2       Q2
#
# [18760 rows x 11 columns]

# %%
def get_quarter(week):
    if week <= 13:
        return 'Q1'
    elif week <= 26:
        return 'Q2'
    elif week <= 39:
        return 'Q3'
    else:
        return 'Q4'

# %%
dengue2021['Quarters'] = dengue2021['Semana'].apply(lambda x: get_quarter(x))
dengue2021
# Out:
#         Año  Semana Departamento      Provincia   Distrito  UBIGEO  \
# 39     2021       3        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1478   2021       4        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1479   2021       2        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1526   2021       6        CUSCO  LA CONVENCION  MEGANTONI  080914
# 1527   2021       8        CUSCO  LA CONVENCION  MEGANTONI  080914
# ...     ...     ...          ...            ...        ...     ...
# 24625  2021      14          ICA        CHINCHA    SUNAMPE  110210
# 24626  2021      14  LA LIBERTAD      PACASMAYO  PACASMAYO  130704
# 24627  2021      15  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24628  2021      16  LA LIBERTAD         CHEPEN     CHEPEN  130401
# 24629  2021      18  LA LIBERTAD         CHEPEN     CHEPEN  130401
#
#       Ubigeo_prov Ubigeo_dep  Casos quarters Quarters
# 39           0809         08      0       Q1       Q1
# 1478         0809         08      0       Q1       Q1
# 1479         0809         08      0       Q1       Q1
# 1526         0809         08      0       Q1       Q1
# 1527         0809         08      0       Q1       Q1
# ...           ...        ...    ...      ...      ...
# 24625        1102         11      2       Q2       Q2
# 24626        1307         13      1       Q2       Q2
# 24627        1304         13      2       Q2       Q2
# 24628        1304         13      2       Q2       Q2
# 24629        1304         13      2       Q2       Q2
#
# [18760 rows x 11 columns]

# %%
dengue2021Q = dengue2021.groupby( ['Departamento', 'Ubigeo_dep', 'Quarters'], as_index = False).agg(Total_casos=('Casos', 'sum'))
dengue2021Q = dengue2021Q.rename(columns={'Ubigeo_dep':'CCDD'})
dengue2021Q
# Out:
#    Departamento CCDD Quarters  Total_casos
# 0      AMAZONAS   01       Q1          599
# 1      AMAZONAS   01       Q2          609
# 2      AMAZONAS   01       Q3          583
# 3      AMAZONAS   01       Q4           39
# 4        ANCASH   02       Q1            3
# ..          ...  ...      ...          ...
# 79       TUMBES   24       Q4           14
# 80      UCAYALI   25       Q1          923
# 81      UCAYALI   25       Q2          214
# 82      UCAYALI   25       Q3          424
# 83      UCAYALI   25       Q4           52
#
# [84 rows x 4 columns]

# %%
dengue_2021Q = pd.merge(geo_dep, dengue2021Q, how='left', on=['CCDD'])
dengue_2021Q['CCDD'] = dengue_2021Q['CCDD'].astype(str).astype(int)
dengue_2021Q
# Out:
#     CCDD                                           geometry   NOMBDEP  \
# 0      1  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...  AMAZONAS
# 1      1  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...  AMAZONAS
# 2      1  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...  AMAZONAS
# 3      1  POLYGON ((-77.78625 -6.94929, -77.78681 -6.951...  AMAZONAS
# 4      2  POLYGON ((-77.70012 -10.32263, -77.70189 -10.3...    ANCASH
# ..   ...                                                ...       ...
# 83    24  POLYGON ((-80.84677 -4.18862, -80.84785 -4.189...    TUMBES
# 84    25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...   UCAYALI
# 85    25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...   UCAYALI
# 86    25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...   UCAYALI
# 87    25  POLYGON ((-72.17858 -11.01843, -72.17786 -11.0...   UCAYALI
#
#    Departamento Quarters  Total_casos
# 0      AMAZONAS       Q1        599.0
# 1      AMAZONAS       Q2        609.0
# 2      AMAZONAS       Q3        583.0
# 3      AMAZONAS       Q4         39.0
# 4        ANCASH       Q1          3.0
# ..          ...      ...          ...
# 83       TUMBES       Q4         14.0
# 84      UCAYALI       Q1        923.0
# 85      UCAYALI       Q2        214.0
# 86      UCAYALI       Q3        424.0
# 87      UCAYALI       Q4         52.0
#
# [88 rows x 6 columns]

# %%
dengue_2021Q.dtypes
# Out:
# CCDD               int32
# geometry        geometry
# NOMBDEP           object
# Departamento      object
# Quarters          object
# Total_casos      float64
# dtype: object

# %%
dengue_2021Q1=dengue_2021Q[dengue_2021Q['Quarters']=='Q1']
dengue_2021Q2=dengue_2021Q[dengue_2021Q['Quarters']=='Q2']
dengue_2021Q3=dengue_2021Q[dengue_2021Q['Quarters']=='Q3']
dengue_2021Q4=dengue_2021Q[dengue_2021Q['Quarters']=='Q4']

# %%
dengue_2021Q1.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %%
dengue_2021Q2.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %%
dengue_2021Q3.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>

# %%
dengue_2021Q4.plot( column='Total_casos', cmap='Reds', 
          figsize=(20, 20),
          linestyle='-',
          edgecolor='gray',
          missing_kwds= dict(color='#DADADB',),           
          legend = True )
# Out:
# <AxesSubplot:>
