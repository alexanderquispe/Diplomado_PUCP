# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }a
# </style>

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet

# %%
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap

# %% [markdown]
# #### 2. Import the data located at this link. It has information on people infected with dengue at the district level for 2015 to 2021.

# %%
base = open(r'../../_data/data_dengue_peru.csv', 'rb').read()
det = chardet.detect(base)
charenc = det['encoding']
charenc
# Out:
# 'UTF-8-SIG'

# %%
dengue = pd.read_csv( r'../../_data/data_dengue_peru.csv', encoding = charenc, thousands = ",", dtype= {"Ubigeo":"str"})
dengue.head( 5 )
# Out:
#     Año  Semana Eventos o daños Departamento   Distrito       Provincia  \
# 0  2020      43          Dengue        CUSCO  MEGANTONI   LA CONVENCION
# 1  2021      41          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
# 2  2021      42          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
# 3  2020       1          Dengue        CUSCO  MEGANTONI   LA CONVENCION
# 4  2020      53          Dengue        CUSCO  MEGANTONI   LA CONVENCION
#
#    Ubigeo  Casos
# 0  080914    2.0
# 1  180101    NaN
# 2  180101    NaN
# 3  080914    0.0
# 4  080914    2.0

# %% [markdown]
# #### 3. Generate ubigeo for Departments and Provinces taking the first two and four numbers.

# %%
dengue['Dpt_Ubigeo'] = dengue['Ubigeo'].astype(str).str[0:2]
dengue['Prv_Ubigeo'] = dengue['Ubigeo'].astype(str).str[0:4]

# %%
dengue.head(3)
# Out:
#     Año  Semana Eventos o daños Departamento   Distrito       Provincia  \
# 0  2020      43          Dengue        CUSCO  MEGANTONI   LA CONVENCION
# 1  2021      41          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
# 2  2021      42          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
#
#    Ubigeo  Casos Dpt_Ubigeo Prv_Ubigeo
# 0  080914    2.0         08       0809
# 1  180101    NaN         18       1801
# 2  180101    NaN         18       1801

# %% [markdown]
# #### 4. Use geopandas to plot the number of cases in 2021 by the district using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile.

# %%
distritos = gpd.read_file(r'../../_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')
distritos.head(3)
# Out:
#   CCDD    NOMBDEP CCPP    NOMBPROV CCDI  NOMBDIST   CAPITAL  UBIGEO IDPROV  \
# 0   06  CAJAMARCA   05   CONTUMAZA   04  GUZMANGO  GUZMANGO  060504   0605
# 1   06  CAJAMARCA   11  SAN MIGUEL   05  EL PRADO  EL PRADO  061105   0611
# 2   06  CAJAMARCA   11  SAN MIGUEL   09    NIEPOS    NIEPOS  061109   0611
#
#    CODIGO  CNT_CCPP DESCRIPCIO           DESCARGAR   WHATSAPP  \
# 0  060504        50   GUZMANGO  www.geogpsperu.com  931381206
# 1  061105        15   EL PRADO  www.geogpsperu.com  931381206
# 2  061109        41     NIEPOS  www.geogpsperu.com  931381206
#
#                    CONTACTO                                           geometry
# 0  juan.suyo@geogpsperu.com  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1  juan.suyo@geogpsperu.com  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2  juan.suyo@geogpsperu.com  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...

# %%
dengue_2021 = dengue[dengue.Año == 2021]
dengue_2021.head(3)
# Out:
#     Año  Semana Eventos o daños Departamento       Distrito       Provincia  \
# 1  2021      41          Dengue     MOQUEGUA       MOQUEGUA  MARISCAL NIETO
# 2  2021      42          Dengue     MOQUEGUA       MOQUEGUA  MARISCAL NIETO
# 6  2021      41          Dengue         LIMA  INDEPENDENCIA            LIMA
#
#    Ubigeo  Casos Dpt_Ubigeo Prv_Ubigeo
# 1  180101    NaN         18       1801
# 2  180101    NaN         18       1801
# 6  150112    NaN         15       1501

# %% [markdown]
# #### 5. Use geopandas to plot the number of cases in 2021by the province using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the province level.

# %% [markdown]
# #### 6. Use geopandas to plot the number of cases by the department for all the years using subplots. Every subplot for each year. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the department level.

# %%
#dengue_departamento= dengue_2021.groupby(['Departamento'])['Casos'].sum().reset_index().copy()
#dengue_departamento
# Out:
#      Departamento   Casos
# 0        AMAZONAS  1830.0
# 1          ANCASH    26.0
# 2        AYACUCHO  1346.0
# 3       CAJAMARCA  2555.0
# 4          CALLAO     2.0
# 5           CUSCO  1341.0
# 6         HUANUCO  2735.0
# 7             ICA  4577.0
# 8           JUNIN  3168.0
# 9     LA LIBERTAD   382.0
# 10     LAMBAYEQUE   815.0
# 11           LIMA  1119.0
# 12         LORETO  4106.0
# 13  MADRE DE DIOS   883.0
# 14       MOQUEGUA     0.0
# 15          PASCO   358.0
# 16          PIURA  4010.0
# 17           PUNO     0.0
# 18     SAN MARTIN  3966.0
# 19         TUMBES  1364.0
# 20        UCAYALI  1613.0

# %%
#dengue_dpt_alldpt_shapes = gpd.read_file(r'../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp')

# %%
#dengue_dpt_all = dengue.groupby(['Departamento','Año'], as_index = False )[ [ 'Casos' ] ].sum()

# %%
#dengue_dpt_2021 = dengue_dpt_all[dengue_dpt_all.Año == 2021]
#dengue_dpt_2021
# Out:
#       Departamento   Año   Casos
# 6         AMAZONAS  2021  1830.0
# 13          ANCASH  2021    26.0
# 20        AYACUCHO  2021  1346.0
# 27       CAJAMARCA  2021  2555.0
# 34          CALLAO  2021     2.0
# 41           CUSCO  2021  1341.0
# 48         HUANUCO  2021  2735.0
# 55             ICA  2021  4577.0
# 62           JUNIN  2021  3168.0
# 69     LA LIBERTAD  2021   382.0
# 76      LAMBAYEQUE  2021   815.0
# 83            LIMA  2021  1119.0
# 90          LORETO  2021  4106.0
# 97   MADRE DE DIOS  2021   883.0
# 104       MOQUEGUA  2021     0.0
# 111          PASCO  2021   358.0
# 118          PIURA  2021  4010.0
# 125           PUNO  2021     0.0
# 132     SAN MARTIN  2021  3966.0
# 139         TUMBES  2021  1364.0
# 146        UCAYALI  2021  1613.0

# %%
table2 = gpd.read_file( r'..\..\_data\LIMITE_DISTRITAL_2020_INEI\INEI_LIMITE_DISTRITAL.shp' )
table2

# %%
table3 = table2[['UBIGEO', 'geometry']]
table3 = table3.rename(columns={'UBIGEO':'Ubigeo'})
table3 = table3.sort_values('Ubigeo')
table3
# Out:
#       Ubigeo                                           geometry
# 1159  010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...
# 1331  010102  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 1125  010103  POLYGON ((-77.93580 -6.69039, -77.93531 -6.690...
# 1153  010104  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 1172  010105  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...      ...                                                ...
# 1627  250302  POLYGON ((-75.14649 -8.53886, -75.14614 -8.544...
# 1630  250303  POLYGON ((-75.45297 -8.21007, -75.45304 -8.210...
# 1629  250304  POLYGON ((-75.01663 -8.44514, -75.01650 -8.445...
# 1626  250305  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1621  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...
#
# [1874 rows x 2 columns]

# %%
table1 = pd.read_csv('../../_data/data_dengue_peru.csv', encoding = charenc, thousands = ",", dtype= {"Ubigeo":"str"})
table1['Ubigeo_Departments'] = table1['Ubigeo'].astype(str).str[:2]
table1
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo  Casos Ubigeo_Departments
# 0        LA CONVENCION  080914    2.0                 08
# 1       MARISCAL NIETO  180101    NaN                 18
# 2       MARISCAL NIETO  180101    NaN                 18
# 3        LA CONVENCION  080914    0.0                 08
# 4        LA CONVENCION  080914    2.0                 08
# ...                ...     ...    ...                ...
# 172139            MANU  170203    NaN                 17
# 172140       TAHUAMANU  170303    NaN                 17
# 172141            MANU  170203    NaN                 17
# 172142       TAHUAMANU  170303    NaN                 17
# 172143       TAHUAMANU  170303    NaN                 17
#
# [172144 rows x 9 columns]

# %%
Tabla_2021 = table1[table1.Año == 2021]
Tabla_2021
# Out:
#          Año  Semana Eventos o daños   Departamento                 Distrito  \
# 1       2021      41          Dengue       MOQUEGUA                 MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA                 MOQUEGUA
# 6       2021      41          Dengue           LIMA            INDEPENDENCIA
# 7       2021      41          Dengue           LIMA  VILLA MARIA DEL TRIUNFO
# 8       2021      41          Dengue           LIMA                      ATE
# ...      ...     ...             ...            ...                      ...
# 172139  2021      49          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS                TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS                TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS                TAHUAMANU
#
#              Provincia  Ubigeo  Casos Ubigeo_Departments
# 1       MARISCAL NIETO  180101    NaN                 18
# 2       MARISCAL NIETO  180101    NaN                 18
# 6                 LIMA  150112    NaN                 15
# 7                 LIMA  150143    NaN                 15
# 8                 LIMA  150103    NaN                 15
# ...                ...     ...    ...                ...
# 172139            MANU  170203    NaN                 17
# 172140       TAHUAMANU  170303    NaN                 17
# 172141            MANU  170203    NaN                 17
# 172142       TAHUAMANU  170303    NaN                 17
# 172143       TAHUAMANU  170303    NaN                 17
#
# [24857 rows x 9 columns]

# %%
Dengue_dep= table3.merge(Tabla_2021)
Dengue_dep
# Out:
#        Ubigeo                                           geometry   Año  \
# 0      010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...  2021
# 1      010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...  2021
# 2      010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...  2021
# 3      010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...  2021
# 4      010101  POLYGON ((-77.88580 -6.17780, -77.88323 -6.178...  2021
# ...       ...                                                ...   ...
# 24852  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...  2021
# 24853  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...  2021
# 24854  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...  2021
# 24855  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...  2021
# 24856  250401  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...  2021
#
#        Semana Eventos o daños Departamento     Distrito    Provincia  Casos  \
# 0          41          Dengue     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS    NaN
# 1          42          Dengue     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS    NaN
# 2          43          Dengue     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS    NaN
# 3          44          Dengue     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS    NaN
# 4          45          Dengue     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS    NaN
# ...       ...             ...          ...          ...          ...    ...
# 24852      49          Dengue      UCAYALI        PURUS        PURUS    NaN
# 24853      50          Dengue      UCAYALI        PURUS        PURUS    NaN
# 24854      51          Dengue      UCAYALI        PURUS        PURUS    NaN
# 24855      52          Dengue      UCAYALI        PURUS        PURUS    NaN
# 24856      53          Dengue      UCAYALI        PURUS        PURUS    NaN
#
#       Ubigeo_Departments
# 0                     01
# 1                     01
# 2                     01
# 3                     01
# 4                     01
# ...                  ...
# 24852                 25
# 24853                 25
# 24854                 25
# 24855                 25
# 24856                 25
#
# [24857 rows x 10 columns]

# %%
Dengue_dep.plot( column='Casos', cmap='Reds', figsize=(10, 10), linestyle='--',
                      edgecolor='black', 
                      missing_kwds= {
                          "color": "lightgrey",
                          "edgecolor": "gray",
                          "hatch": "///",
                        "label": "Missing values",},
                      legend = True, legend_kwds={'label': "Cases of Dengue in 2021 by department ",
                        'orientation': "horizontal"})
# Out:
# <AxesSubplot:>
