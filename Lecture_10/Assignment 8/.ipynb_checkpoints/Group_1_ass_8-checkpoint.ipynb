# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }a
# </style>

# %%
#! pip install lxml
#! pip install unidecode
#! pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (4.1.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from selenium) (1.26.8)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: certifi in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from urllib3[secure]~=1.26->selenium) (36.0.1)
# Requirement already satisfied: pycparser in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: six>=1.5.2 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
#! pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)

# %%
#! pip install webdriver_manager
# Out:
# Requirement already satisfied: webdriver_manager in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (3.5.2)
# Requirement already satisfied: requests in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from webdriver_manager) (2.27.1)
# Requirement already satisfied: crayons in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from webdriver_manager) (0.4.0)
# Requirement already satisfied: configparser in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from webdriver_manager) (5.2.0)
# Requirement already satisfied: colorama in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from crayons->webdriver_manager) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from requests->webdriver_manager) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from requests->webdriver_manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from requests->webdriver_manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\limon\anaconda3\envs\envirmnt2\lib\site-packages (from requests->webdriver_manager) (2.0.10)

# %%
import time
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode
import time 
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import matplotlib.pyplot as plt 
import chardet
import geopandas as gpd

# %% [markdown]
# ## Import "Data Dengue infected by district for 2015 to 2021"

# %%
base = open(r'../../_data/data_dengue_peru.csv', 'rb').read()
det = chardet.detect(base)
charenc = det['encoding']
charenc
# Out:
# 'UTF-8-SIG'

# %%
table1 = pd.read_csv('../../_data/data_dengue_peru.csv', encoding = charenc, thousands = ",", dtype= {"Ubigeo":"str"})
table1
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo  Casos
# 0        LA CONVENCION  080914    2.0
# 1       MARISCAL NIETO  180101    NaN
# 2       MARISCAL NIETO  180101    NaN
# 3        LA CONVENCION  080914    0.0
# 4        LA CONVENCION  080914    2.0
# ...                ...     ...    ...
# 172139            MANU  170203    NaN
# 172140       TAHUAMANU  170303    NaN
# 172141            MANU  170203    NaN
# 172142       TAHUAMANU  170303    NaN
# 172143       TAHUAMANU  170303    NaN
#
# [172144 rows x 8 columns]

# %%
table1.dtypes
# Out:
# Año                  int64
# Semana               int64
# Eventos o daños     object
# Departamento        object
# Distrito            object
# Provincia           object
# Ubigeo              object
# Casos              float64
# dtype: object

# %%
table1 ['Año'].unique()
# Out:
# array([2020, 2021, 2019, 2017, 2016, 2018, 2015], dtype=int64)

# %% [markdown]
# ## Generate "Ubigeo" for Departments and Provinces, taking the first two and four numbers

# %%
table1['Ubigeo_Departments'] = table1['Ubigeo'].astype(str).str[:2]
table1
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo  Casos Ubigeo_Departments
# 0        LA CONVENCION  080914    2.0                 08
# 1       MARISCAL NIETO  180101    NaN                 18
# 2       MARISCAL NIETO  180101    NaN                 18
# 3        LA CONVENCION  080914    0.0                 08
# 4        LA CONVENCION  080914    2.0                 08
# ...                ...     ...    ...                ...
# 172139            MANU  170203    NaN                 17
# 172140       TAHUAMANU  170303    NaN                 17
# 172141            MANU  170203    NaN                 17
# 172142       TAHUAMANU  170303    NaN                 17
# 172143       TAHUAMANU  170303    NaN                 17
#
# [172144 rows x 9 columns]

# %%
table1['Ubigeo_Provinces'] = table1['Ubigeo'].astype(str).str[:4]
table1
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo  Casos Ubigeo_Departments Ubigeo_Provinces
# 0        LA CONVENCION  080914    2.0                 08             0809
# 1       MARISCAL NIETO  180101    NaN                 18             1801
# 2       MARISCAL NIETO  180101    NaN                 18             1801
# 3        LA CONVENCION  080914    0.0                 08             0809
# 4        LA CONVENCION  080914    2.0                 08             0809
# ...                ...     ...    ...                ...              ...
# 172139            MANU  170203    NaN                 17             1702
# 172140       TAHUAMANU  170303    NaN                 17             1703
# 172141            MANU  170203    NaN                 17             1702
# 172142       TAHUAMANU  170303    NaN                 17             1703
# 172143       TAHUAMANU  170303    NaN                 17             1703
#
# [172144 rows x 10 columns]

# %%
table1.dtypes
# Out:
# Año                     int64
# Semana                  int64
# Eventos o daños        object
# Departamento           object
# Distrito               object
# Provincia              object
# Ubigeo                 object
# Casos                 float64
# Ubigeo_Departments     object
# Ubigeo_Provinces       object
# dtype: object

# %%
table_dengue['Ubigeo'].unique().size
# Out:
# 475

# %% [markdown]
# ## Geopandas: Plot the number of cases in 2021 by district, usign continuous legend.

# %%
table2 = gpd.read_file( r'..\..\_data\LIMITE_DISTRITAL_2020_INEI\INEI_LIMITE_DISTRITAL.shp' )
table2
# Out:
#      CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0      06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1      06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2      06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3      06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4      06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
# ...   ...        ...  ...         ...  ...           ...              ...
# 1869   04   AREQUIPA   04    CASTILLA   04       CHACHAS          CHACHAS
# 1870   04   AREQUIPA   04    CASTILLA   05  CHILCAYMARCA     CHILCAYMARCA
# 1871   04   AREQUIPA   04    CASTILLA   06         CHOCO            CHOCO
# 1872   04   AREQUIPA   04    CASTILLA   07    HUANCARQUI       HUANCARQUI
# 1873   12      JUNIN   06      SATIPO   04      MAZAMARI             None
#
#       UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# 0     060504   0605  060504        50      GUZMANGO  www.geogpsperu.com
# 1     061105   0611  061105        15      EL PRADO  www.geogpsperu.com
# 2     061109   0611  061109        41        NIEPOS  www.geogpsperu.com
# 3     061110   0611  061110        48  SAN GREGORIO  www.geogpsperu.com
# 4     061203   0612  061203         9      SAN LUIS  www.geogpsperu.com
# ...      ...    ...     ...       ...           ...                 ...
# 1869  040404   0404  040404        19       CHACHAS  www.geogpsperu.com
# 1870  040405   0404  040405        24  CHILCAYMARCA  www.geogpsperu.com
# 1871  040406   0404  040406        58         CHOCO  www.geogpsperu.com
# 1872  040407   0404  040407        25    HUANCARQUI  www.geogpsperu.com
# 1873  120604   1206  120604       152      MAZAMARI  www.geogpsperu.com
#
#        WHATSAPP                  CONTACTO  \
# 0     931381206  juan.suyo@geogpsperu.com
# 1     931381206  juan.suyo@geogpsperu.com
# 2     931381206  juan.suyo@geogpsperu.com
# 3     931381206  juan.suyo@geogpsperu.com
# 4     931381206  juan.suyo@geogpsperu.com
# ...         ...                       ...
# 1869  931381206  juan.suyo@geogpsperu.com
# 1870  931381206  juan.suyo@geogpsperu.com
# 1871  931381206  juan.suyo@geogpsperu.com
# 1872  931381206  juan.suyo@geogpsperu.com
# 1873  931381206  juan.suyo@geogpsperu.com
#
#                                                geometry
# 0     POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1     POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2     POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3     POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4     POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...                                                 ...
# 1869  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
# [1874 rows x 16 columns]

# %%
table2 ['NOMBDEP'].unique()
# Out:
# array(['CAJAMARCA', 'LAMBAYEQUE', 'LIMA', 'ANCASH', 'AREQUIPA', 'CUSCO',
#        'AYACUCHO', 'HUANCAVELICA', 'APURIMAC', 'PIURA', 'TACNA', 'JUNIN',
#        'HUANUCO', 'UCAYALI', 'MADRE DE DIOS', 'PUNO', 'LA LIBERTAD',
#        'TUMBES', 'CALLAO', 'AMAZONAS', 'LORETO', 'SAN MARTIN', 'ICA',
#        'PASCO', 'MOQUEGUA'], dtype=object)

# %%
table2.dtypes
# Out:
# CCDD            object
# NOMBDEP         object
# CCPP            object
# NOMBPROV        object
# CCDI            object
# NOMBDIST        object
# CAPITAL         object
# UBIGEO          object
# IDPROV          object
# CODIGO          object
# CNT_CCPP         int64
# DESCRIPCIO      object
# DESCARGAR       object
# WHATSAPP        object
# CONTACTO        object
# geometry      geometry
# dtype: object

# %%
table2['UBIGEO'].unique().size
# Out:
# 1874

# %%
table3 = table2[['UBIGEO', 'geometry']]
table3
# Out:
#       UBIGEO                                           geometry
# 0     060504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1     061105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2     061109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3     061110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4     061203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...      ...                                                ...
# 1869  040404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870  040405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871  040406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872  040407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
# [1874 rows x 2 columns]

# %%
# Longitud-Latitud projection
table3.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
dengue_2021 = table1[table1.Año == 2021]
dengue_2021
# Out:
#          Año  Semana Eventos o daños   Departamento                 Distrito  \
# 1       2021      41          Dengue       MOQUEGUA                 MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA                 MOQUEGUA
# 6       2021      41          Dengue           LIMA            INDEPENDENCIA
# 7       2021      41          Dengue           LIMA  VILLA MARIA DEL TRIUNFO
# 8       2021      41          Dengue           LIMA                      ATE
# ...      ...     ...             ...            ...                      ...
# 172139  2021      49          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS                TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS                TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS                TAHUAMANU
#
#              Provincia  Ubigeo  Casos Ubigeo_Departments Ubigeo_Provinces
# 1       MARISCAL NIETO  180101    NaN                 18             1801
# 2       MARISCAL NIETO  180101    NaN                 18             1801
# 6                 LIMA  150112    NaN                 15             1501
# 7                 LIMA  150143    NaN                 15             1501
# 8                 LIMA  150103    NaN                 15             1501
# ...                ...     ...    ...                ...              ...
# 172139            MANU  170203    NaN                 17             1702
# 172140       TAHUAMANU  170303    NaN                 17             1703
# 172141            MANU  170203    NaN                 17             1702
# 172142       TAHUAMANU  170303    NaN                 17             1703
# 172143       TAHUAMANU  170303    NaN                 17             1703
#
# [24857 rows x 10 columns]

# %%
dengue_shp = table3.merge(dengue_2021, how = "left", left_on=['UBIGEO'], right_on=['Ubigeo'])
dengue_shp
# Out:
#        UBIGEO                                           geometry     Año  \
# 0      060504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...     NaN
# 1      061105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...     NaN
# 2      061109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...     NaN
# 3      061110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...     NaN
# 4      061203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...     NaN
# ...       ...                                                ...     ...
# 26257  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
# 26258  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
# 26259  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
# 26260  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
# 26261  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
#
#        Semana Eventos o daños Departamento  Distrito Provincia  Ubigeo  Casos  \
# 0         NaN             NaN          NaN       NaN       NaN     NaN    NaN
# 1         NaN             NaN          NaN       NaN       NaN     NaN    NaN
# 2         NaN             NaN          NaN       NaN       NaN     NaN    NaN
# 3         NaN             NaN          NaN       NaN       NaN     NaN    NaN
# 4         NaN             NaN          NaN       NaN       NaN     NaN    NaN
# ...       ...             ...          ...       ...       ...     ...    ...
# 26257    15.0          Dengue        JUNIN  MAZAMARI    SATIPO  120604    6.0
# 26258    16.0          Dengue        JUNIN  MAZAMARI    SATIPO  120604    6.0
# 26259    20.0          Dengue        JUNIN  MAZAMARI    SATIPO  120604    7.0
# 26260    21.0          Dengue        JUNIN  MAZAMARI    SATIPO  120604    5.0
# 26261    17.0          Dengue        JUNIN  MAZAMARI    SATIPO  120604   13.0
#
#       Ubigeo_Departments Ubigeo_Provinces
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# ...                  ...              ...
# 26257                 12             1206
# 26258                 12             1206
# 26259                 12             1206
# 26260                 12             1206
# 26261                 12             1206
#
# [26262 rows x 12 columns]

# %%
dengue_shp.dtypes
# Out:
# UBIGEO                  object
# geometry              geometry
# Año                    float64
# Semana                 float64
# Eventos o daños         object
# Departamento            object
# Distrito                object
# Provincia               object
# Ubigeo                  object
# Casos                  float64
# Ubigeo_Departments      object
# Ubigeo_Provinces        object
# dtype: object
