# %%
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time
import requests

# %% [markdown]
# 1. Open the data

# %%
#Gettting the character format
import chardet

rawdata = open( 'C:/Users/Claudia/Documents/GitHub/Diplomado_PUCP/_data/Base5.csv', 'rb').read()
result = chardet.detect(rawdata)
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
charenc = result['encoding']
print(charenc)
# Out:
# UTF-8-SIG

# %%
CEM = pd.read_csv( 'C:/Users/Claudia/Documents/GitHub/Diplomado_PUCP/_data/Base5.csv' , delimiter = ';' , header = None , encoding = charenc )
CEM = CEM.rename( columns = { CEM.columns[ 6 ] : 'Address' } )
CEM
# Out:
#        0          1             2             3              4            5  \
# 0     N°  CATEGORÍA  DEPARTAMENTO           CEM  TELÉFONO FIJO  CELULAR CEM
# 1      1    REGULAR      AMAZONAS         BAGUA            NaN    980047461
# 2      2    REGULAR      AMAZONAS       BONGARA            NaN    914179014
# 3      3    REGULAR      AMAZONAS   CHACHAPOYAS       41479309    994834149
# 4      4    REGULAR      AMAZONAS  CONDORCANQUI            NaN    994841361
# ..   ...        ...           ...           ...            ...          ...
# 242  242    REGULAR        TUMBES     ZARUMILLA       72507829    994800813
# 243  243    REGULAR       UCAYALI       ATALAYA            NaN    994801097
# 244  244    REGULAR       UCAYALI    PADRE ABAD            NaN    994800884
# 245  245    REGULAR       UCAYALI      PUCALLPA       61573247    994801093
# 246  246    REGULAR       UCAYALI         PURÚS            NaN          NaN
#
# ...

# %%
CEM['Address'].shape[0]
# Out:
# 247

# %%
# !pip install googlemaps
from datetime import datetime

# %%
import googlemaps
from datetime import datetime

coord = np.zeros(shape=( CEM['Address'].shape[0] , 2), dtype = float )

i=0

gmaps = googlemaps.Client( key='AIzaSyCDr79v4CHSAmF-drAZQqtR_Bh2gIFr1wo' )

for index, row in tqdm(CEM.iterrows()):   

    # Geocoding an address
    geocode_result = gmaps.geocode( row['Address'] , region='ch')
    if len(geocode_result)==0 :
        coord[i][0] = "nan"
        coord[i][1] = "nan"
        
        i=i+1
        
        print(row['Address'])
        print("el codigo encontro error")
        
    else :
        coord[i][0]=geocode_result[0]['geometry']['location']['lat']
        coord[i][1]=geocode_result[0]['geometry']['location']['lng']
        i=i+1
# Out:
# <ipython-input-41-1f8c481c2954>:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm(CEM.iterrows()):
# 0it [00:00, ?it/s]
# PLAZA DE ARMAS DE AIJA - JR. INDEPENDENCIA N° 480
# el codigo encontro error
# JIRON MANUEL GONZALES PRADA S/N (A DOS CUADRAS DEL PARQUE CENTRAL)
# el codigo encontro error
# JR. PLAZA DE ARMAS N°506 - 1ER PISO DE LA MUNICIPALIDAD
# el codigo encontro error
# JR. GRAU 206, PLAZA DE ARMAS- INTERIOR DE LA MUNICIPALIDAD PROVINCIAL DE COROINGO
# el codigo encontro error
# AV. RAIMONI S/N CUADRA 10 - INTERIOR DE LA DIRECCION REGIONAL DEL MINISTERIO DEL TRABAJO Y DEL EMPELO.
# el codigo encontro error
# AV. CENTRAL BRUCES S/N (INTERIOR DEL POLIDEPORTIVO BRUCES-PILAR NORES DE GARCIA)
# el codigo encontro error
# JR. BOLIVAR N°290-INTERIOR DEL HOTEL PASTORURI
# . 1ER PISO
# el codigo encontro error
# ...

# %%
coord
# Out:
# array([[  41.3671571,    2.1391522],
#        [  -5.6428867,  -78.525286 ],
#        [  -5.857687 ,  -77.792343 ],
#        [ -12.0422714,  -77.020402 ],
#        [  -4.6010065,  -77.8610254],
#        [  -6.1362221,  -77.9505261],
#        [  -6.3941102,  -77.4855682],
#        [  -5.7567899,  -78.4378428],
#        [         nan,          nan],
#        [  -9.0992611,  -77.0140741],
#        [         nan,          nan],
#        [ -12.0958018,  -77.0729327],
#        [  -9.281744 ,  -77.6450215],
#        [         nan,          nan],
#        [  -9.4718308,  -78.3006626],
#        [ -12.0667854,  -77.0319585],
#        [         nan,          nan],
#        [         nan,          nan],
#        [  -9.3483845,  -77.1708039],
#        [ -10.0696687,  -78.152911 ],
#        [  10.8575824,  -74.7746834],
#        [  -8.8641745,  -77.3581045],
#        [         nan,          nan],
#        [ -10.4031418,  -77.3977529],
#        [  -8.3944043,  -78.006695 ],
# ...

# %%
CEM[ [ 'latitude' , 'longitude' ] ] = pd.DataFrame( coord.tolist(), index = CEM.index )
CEM
# Out:
#        0          1             2             3              4            5  \
# 0     N°  CATEGORÍA  DEPARTAMENTO           CEM  TELÉFONO FIJO  CELULAR CEM
# 1      1    REGULAR      AMAZONAS         BAGUA            NaN    980047461
# 2      2    REGULAR      AMAZONAS       BONGARA            NaN    914179014
# 3      3    REGULAR      AMAZONAS   CHACHAPOYAS       41479309    994834149
# 4      4    REGULAR      AMAZONAS  CONDORCANQUI            NaN    994841361
# ..   ...        ...           ...           ...            ...          ...
# 242  242    REGULAR        TUMBES     ZARUMILLA       72507829    994800813
# 243  243    REGULAR       UCAYALI       ATALAYA            NaN    994801097
# 244  244    REGULAR       UCAYALI    PADRE ABAD            NaN    994800884
# 245  245    REGULAR       UCAYALI      PUCALLPA       61573247    994801093
# 246  246    REGULAR       UCAYALI         PURÚS            NaN          NaN
#
# ...

# %%
Base_final = CEM.iloc[:,[6,9,10]]

# %%
Base_final1 = CEM.iloc[1:,]
Base_final1
# Out:
#        0        1         2             3         4          5  \
# 1      1  REGULAR  AMAZONAS         BAGUA       NaN  980047461
# 2      2  REGULAR  AMAZONAS       BONGARA       NaN  914179014
# 3      3  REGULAR  AMAZONAS   CHACHAPOYAS  41479309  994834149
# 4      4  REGULAR  AMAZONAS  CONDORCANQUI       NaN  994841361
# 5      5  REGULAR  AMAZONAS          LUYA       NaN  994841220
# ..   ...      ...       ...           ...       ...        ...
# 242  242  REGULAR    TUMBES     ZARUMILLA  72507829  994800813
# 243  243  REGULAR   UCAYALI       ATALAYA       NaN  994801097
# 244  244  REGULAR   UCAYALI    PADRE ABAD       NaN  994800884
# 245  245  REGULAR   UCAYALI      PUCALLPA  61573247  994801093
# 246  246  REGULAR   UCAYALI         PURÚS       NaN        NaN
#
#                                                Address  \
# 1    JR. SARGENTO LORES S/N A 2 CUADRAS DE LA GEREN...
# 2    AV. 26 DE DICIEMBRE 460. FRENTE A LA PLAZA DE ...
# ...

# %%
Base_final1.to_csv (r"group_3_ass_5.csv", index = False, header=True)
