# %%
#pip install googlemaps

# %%
# import library
import googlemaps
import json
import pprint
import pandas as pd
import numpy as np
import re

# %%
API_KEY = 'AIzaSyDI7hubt3vDOr4mTmSIfnW3GTTXpWImHq0'

# %%
data = pd.read_excel('publicas.xlsx', header=[1])

# %%
data
# Out:
#      Nro.        Institución Educativa                  Nivel  \
# 0       1          NIÑO JESUS DE PRAGA       Inicial - Jardín
# 1       2              0082 LA CANTUTA       Inicial - Jardín
# 2       3              0082 LA CANTUTA               Primaria
# 3       4              0082 LA CANTUTA             Secundaria
# 4       5         0083 SAN JUAN MASIAS               Primaria
# ..    ...                          ...                    ...
# 231   232               MAHATMA GANDHI               Primaria
# 232   233          MILAGRITOS DE JESUS  Inicial - Cuna-Jardín
# 233   234  7066 ANDRES AVELINO CACERES       Inicial - Jardín
# 234   235  7066 ANDRES AVELINO CACERES               Primaria
# 235   236  7066 ANDRES AVELINO CACERES             Secundaria
#
#                                        Dirección           Distrito  \
# 0    Jr. Surimana S/N Urb. Túpac Amaru, San Luis           San Luis
# 1       Avenida Mariscal Santa Cruz 165, El pino           San Luis
# 2       Avenida Mariscal Santa Cruz 165, El pino           San Luis
# 3       Avenida Mariscal Santa Cruz 165, El pino           San Luis
# 4                             Jr. Ríos Piura 401           San Luis
# ..                                           ...                ...
# 231                                          NaN  Santiago de Surco
# 232                           Av. San Martín S/N         Chorrillos
# 233                       Av. 12 de octubre  S/N         Chorrillos
# 234                       Av. 12 de octubre  S/N         Chorrillos
# 235                       Av. 12 de octubre  S/N         Chorrillos
#
#     Teléfono de contacto
# 0                3239113
# 1                3263676
# 2                3263676
# 3                3263676
# 4      3241959 - 4326322
# ..                   ...
# 231                  NaN
# 232              5607373
# 233                  NaN
# 234                  NaN
# 235                  NaN
#
# [236 rows x 6 columns]

# %%
instituciones = data.iloc[:, 1:5]

# %%
instituciones.dropna(subset = ["Dirección"], inplace = True) # if column 'Dirección' contains NaN remove that row

# %%
instituciones
# Out:
#            Institución Educativa                  Nivel  \
# 0            NIÑO JESUS DE PRAGA       Inicial - Jardín
# 1                0082 LA CANTUTA       Inicial - Jardín
# 2                0082 LA CANTUTA               Primaria
# 3                0082 LA CANTUTA             Secundaria
# 4           0083 SAN JUAN MASIAS               Primaria
# ..                           ...                    ...
# 229     7076 LAS BRISAS DE VILLA             Secundaria
# 232          MILAGRITOS DE JESUS  Inicial - Cuna-Jardín
# 233  7066 ANDRES AVELINO CACERES       Inicial - Jardín
# 234  7066 ANDRES AVELINO CACERES               Primaria
# 235  7066 ANDRES AVELINO CACERES             Secundaria
#
#                                        Dirección    Distrito
# 0    Jr. Surimana S/N Urb. Túpac Amaru, San Luis    San Luis
# 1       Avenida Mariscal Santa Cruz 165, El pino    San Luis
# 2       Avenida Mariscal Santa Cruz 165, El pino    San Luis
# 3       Avenida Mariscal Santa Cruz 165, El pino    San Luis
# 4                             Jr. Ríos Piura 401    San Luis
# ..                                           ...         ...
# 229           Autopista Panamericana Sur  KM 165  Chorrillos
# 232                           Av. San Martín S/N  Chorrillos
# 233                       Av. 12 de octubre  S/N  Chorrillos
# 234                       Av. 12 de octubre  S/N  Chorrillos
# 235                       Av. 12 de octubre  S/N  Chorrillos
#
# [180 rows x 4 columns]

# %%
def join_columns( row_series ):
    
    return address

# %%
def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']
    except:
        lat = np.nan
        lon = np.nan
        
    return( lat, lon )

# %%
def geo_instituciones( row_series ):
    
    address = f"{row_series['Dirección']}, {row_series['Distrito']}"
    
    #Set Geolocation
    gmaps = googlemaps.Client( key = 'AIzaSyDI7hubt3vDOr4mTmSIfnW3GTTXpWImHq0' )
    result_api = gmaps.geocode( address , region = 'PE' )
    
    # Information
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']
    except:
        lat = np.nan
        lon = np.nan
        
    return( address, lat, lon )

# %%
instituciones2 = instituciones.sample( frac = 0.70 ).copy()

# %%
instituciones2['results'] = instituciones2.apply( lambda x: geo_instituciones( x ) , axis = 1)

# %%
instituciones2
# Out:
#              Institución Educativa                  Nivel  \
# 182           COMUNAL SANTA TERESA  Inicial - Cuna-Jardín
# 36               PEQUEÑO SAN BORJA  Inicial - Cuna-Jardín
# 45               6082 LOS PROCERES             Secundaria
# 185         VIRGEN DEL MORRO SOLAR             Secundaria
# 29       6079 SANTISIMA NIÑA MARIA               Primaria
# ..                             ...                    ...
# 57          536 AMIGUITOS DE JESUS       Inicial - Jardín
# 40   557 VICTOR RAUL HAYA DE TORRE       Inicial - Jardín
# 39       555 INMACULADA CONCEPCION       Inicial - Jardín
# 113          ENRIQUE ARNAEZ NAVEDA             Secundaria
# 204           568 VIRGEN DE FATIMA       Inicial - Jardín
#
#                                              Dirección           Distrito  \
# 182                                     Av. El Sol s/n         Chorrillos
# 36                             Av. Eduardo Ordoñez 402          San Borja
# 45                     Av. Alameda Pérez de Toledo S/N  Santiago de Surco
# 185                         Prolongación Matellini s/n         Chorrillos
# 29                                Las begonias 300 S/N          San Borja
# ..                                                 ...                ...
# 57                        Los Seibos s/n, la Capullana  Santiago de Surco
# 40   Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mon...  Santiago de Surco
# 39                           Felipe Pardo y Aliaga 200  Santiago de Surco
# 113                                      Av. Lima 209.           Barranco
# 204                                 Calle los Laureles         Chorrillos
#
#                                                results
# 182  (Av. El Sol s/n, Chorrillos, -12.1750078, -77....
# 36   (Av. Eduardo Ordoñez 402, San Borja, -12.10589...
# 45   (Av. Alameda Pérez de Toledo S/N, Santiago de ...
# 185  (Prolongación Matellini s/n, Chorrillos, -12.1...
# 29   (Las begonias 300 S/N, San Borja, -12.0954443,...
# ..                                                 ...
# 57   (Los Seibos s/n, la Capullana, Santiago de Sur...
# 40   (Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mo...
# 39   (Felipe Pardo y Aliaga 200, Santiago de Surco,...
# 113  (Av. Lima 209., Barranco, -12.1488841, -77.018...
# 204  (Calle los Laureles, Chorrillos, -12.1867107, ...
#
# [126 rows x 5 columns]

# %%
pd.DataFrame( instituciones2.results.tolist() )
# Out:
#                                                      0          1          2
# 0                           Av. El Sol s/n, Chorrillos -12.175008 -77.000360
# 1                   Av. Eduardo Ordoñez 402, San Borja -12.105895 -77.002226
# 2    Av. Alameda Pérez de Toledo S/N, Santiago de S... -12.163473 -76.988314
# 3               Prolongación Matellini s/n, Chorrillos -12.181321 -77.012315
# 4                      Las begonias 300 S/N, San Borja -12.095444 -76.994709
# ..                                                 ...        ...        ...
# 121    Los Seibos s/n, la Capullana, Santiago de Surco -12.137743 -77.001651
# 122  Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mon... -12.092340 -76.977334
# 123       Felipe Pardo y Aliaga 200, Santiago de Surco -12.155325 -76.988669
# 124                            Av. Lima 209., Barranco -12.148884 -77.018933
# 125                     Calle los Laureles, Chorrillos -12.186711 -76.990641
#
# [126 rows x 3 columns]

# %%
instituciones2[['address', 'lat', 'lng']] = pd.DataFrame( instituciones2.results.tolist(), index = instituciones2.index)

# %%
instituciones2
# Out:
#              Institución Educativa                  Nivel  \
# 182           COMUNAL SANTA TERESA  Inicial - Cuna-Jardín
# 36               PEQUEÑO SAN BORJA  Inicial - Cuna-Jardín
# 45               6082 LOS PROCERES             Secundaria
# 185         VIRGEN DEL MORRO SOLAR             Secundaria
# 29       6079 SANTISIMA NIÑA MARIA               Primaria
# ..                             ...                    ...
# 57          536 AMIGUITOS DE JESUS       Inicial - Jardín
# 40   557 VICTOR RAUL HAYA DE TORRE       Inicial - Jardín
# 39       555 INMACULADA CONCEPCION       Inicial - Jardín
# 113          ENRIQUE ARNAEZ NAVEDA             Secundaria
# 204           568 VIRGEN DE FATIMA       Inicial - Jardín
#
#                                              Dirección           Distrito  \
# 182                                     Av. El Sol s/n         Chorrillos
# 36                             Av. Eduardo Ordoñez 402          San Borja
# 45                     Av. Alameda Pérez de Toledo S/N  Santiago de Surco
# 185                         Prolongación Matellini s/n         Chorrillos
# 29                                Las begonias 300 S/N          San Borja
# ..                                                 ...                ...
# 57                        Los Seibos s/n, la Capullana  Santiago de Surco
# 40   Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mon...  Santiago de Surco
# 39                           Felipe Pardo y Aliaga 200  Santiago de Surco
# 113                                      Av. Lima 209.           Barranco
# 204                                 Calle los Laureles         Chorrillos
#
#                                                results  \
# 182  (Av. El Sol s/n, Chorrillos, -12.1750078, -77....
# 36   (Av. Eduardo Ordoñez 402, San Borja, -12.10589...
# 45   (Av. Alameda Pérez de Toledo S/N, Santiago de ...
# 185  (Prolongación Matellini s/n, Chorrillos, -12.1...
# 29   (Las begonias 300 S/N, San Borja, -12.0954443,...
# ..                                                 ...
# 57   (Los Seibos s/n, la Capullana, Santiago de Sur...
# 40   (Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mo...
# 39   (Felipe Pardo y Aliaga 200, Santiago de Surco,...
# 113  (Av. Lima 209., Barranco, -12.1488841, -77.018...
# 204  (Calle los Laureles, Chorrillos, -12.1867107, ...
#
#                                                address        lat        lng
# 182                         Av. El Sol s/n, Chorrillos -12.175008 -77.000360
# 36                  Av. Eduardo Ordoñez 402, San Borja -12.105895 -77.002226
# 45   Av. Alameda Pérez de Toledo S/N, Santiago de S... -12.163473 -76.988314
# 185             Prolongación Matellini s/n, Chorrillos -12.181321 -77.012315
# 29                     Las begonias 300 S/N, San Borja -12.095444 -76.994709
# ..                                                 ...        ...        ...
# 57     Los Seibos s/n, la Capullana, Santiago de Surco -12.137743 -77.001651
# 40   Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mon... -12.092340 -76.977334
# 39        Felipe Pardo y Aliaga 200, Santiago de Surco -12.155325 -76.988669
# 113                            Av. Lima 209., Barranco -12.148884 -77.018933
# 204                     Calle los Laureles, Chorrillos -12.186711 -76.990641
#
# [126 rows x 8 columns]

# %%
data_final = instituciones2[['address', 'lat', 'lng']]
data_final
# Out:
#                                                address        lat        lng
# 182                         Av. El Sol s/n, Chorrillos -12.175008 -77.000360
# 36                  Av. Eduardo Ordoñez 402, San Borja -12.105895 -77.002226
# 45   Av. Alameda Pérez de Toledo S/N, Santiago de S... -12.163473 -76.988314
# 185             Prolongación Matellini s/n, Chorrillos -12.181321 -77.012315
# 29                     Las begonias 300 S/N, San Borja -12.095444 -76.994709
# ..                                                 ...        ...        ...
# 57     Los Seibos s/n, la Capullana, Santiago de Surco -12.137743 -77.001651
# 40   Calle Lomas de la Cavidias Mz 2 Lt 15 Urb. Mon... -12.092340 -76.977334
# 39        Felipe Pardo y Aliaga 200, Santiago de Surco -12.155325 -76.988669
# 113                            Av. Lima 209., Barranco -12.148884 -77.018933
# 204                     Calle los Laureles, Chorrillos -12.186711 -76.990641
#
# [126 rows x 3 columns]

# %%
# Save final output

data_final.to_csv(r"group_2_ass_5.csv", index = False, header = True)
instituciones2.to_csv(r"group_2_ass_5_all.csv", index = False, header = True)
