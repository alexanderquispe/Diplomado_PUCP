# %% [markdown]
# ### Assignment 5

# %%
! pip install -U googlemaps

# %%
import googlemaps
import json
import pprint
import time
import pandas as pd
import numpy as np
import re

# %%
munis = pd.read_excel(r'../../Munis.xlsx')

# %%
munis
# Out:
#               Municipalidad                                     Alcalde  \
# 0                      Lima            JORGE VICENTE MARTIN MUÑOZ WELLS
# 1                     Ancón                   PEDRO JOHN BARRERA BERNUI
# 2                       Ate                        EDDE CUELLAR ALEGRIA
# 3                  Barranco              JOSE JUAN RODRIGUEZ \nCARDENAS
# 4                     Breña                        JOSE DALTON LI BRAVO
# 5                Carabayllo              MARCOS LORENZO ESPINOZA\nORTIZ
# 6                Chaclacayo              MANUEL JAVIER CAMPOS SOLOGUREN
# 7                Chorrillos           AUGUSTO SERGIO MIYASHIRO USHIKUBO
# 8               Cieneguilla                       EDWIN SUBILETI ARECHE
# 9                     Comas                             RAUL DIAZ PEREZ
# 10              El Agustino                VICTOR MODESTO SALCEDO\nRIOS
# 11            Independencia                   YURI JOSE PANDO FERNANDEZ
# ...

# %%
API_KEY = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4'

# %%
def join_columns( row_series ):
    
    
    return address

# %%
def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
def geo_munis( row_series ):
    
    address = f"{ row_series[ 'Direccion' ]}, { row_series[ 'Municipalidad' ]}"
    
    # Set Geolocation
    gmaps = googlemaps.Client( key = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4' )
    result_api = gmaps.geocode( address , region = 'PE' )
    
    # Information
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( address, lat, lon )

# %%
munis['results'] = munis.apply( lambda x: geo_munis( x )  , axis = 1 )

# %%
munis
# Out:
#               Municipalidad                                     Alcalde  \
# 0                      Lima            JORGE VICENTE MARTIN MUÑOZ WELLS
# 1                     Ancón                   PEDRO JOHN BARRERA BERNUI
# 2                       Ate                        EDDE CUELLAR ALEGRIA
# 3                  Barranco              JOSE JUAN RODRIGUEZ \nCARDENAS
# 4                     Breña                        JOSE DALTON LI BRAVO
# 5                Carabayllo              MARCOS LORENZO ESPINOZA\nORTIZ
# 6                Chaclacayo              MANUEL JAVIER CAMPOS SOLOGUREN
# 7                Chorrillos           AUGUSTO SERGIO MIYASHIRO USHIKUBO
# 8               Cieneguilla                       EDWIN SUBILETI ARECHE
# 9                     Comas                             RAUL DIAZ PEREZ
# 10              El Agustino                VICTOR MODESTO SALCEDO\nRIOS
# 11            Independencia                   YURI JOSE PANDO FERNANDEZ
# ...

# %%
pd.DataFrame( munis.results.tolist()  )
# Out:
#                                                     0          1          2
# 0                        Jr. De la Unión N° 300, Lima -12.045340 -77.030952
# 1                     Malecón Ferreyros N° 376, Ancón -11.773805 -77.176282
# 2                     Av. Nicolás Ayllón N° 5818, Ate -11.984603 -76.807023
# 3                        Av. San Martín S/N, Barranco -12.142510 -77.023201
# 4                             Av. Arica N° 500, Breña -12.058635 -77.046036
# 5                 Av. Túpac Amaru N° 1733, Carabayllo -11.889950 -77.026985
# 6               Av. Nicolás Ayllón N° 856, Chaclacayo -11.975379 -76.768785
# 7       Av. Defensores del Morro \nN° 550, Chorrillos -12.169311 -77.024376
# 8         Av. Nueva Toledo N° 97 \nMz. B, Cieneguilla -12.102783 -76.799410
# 9   Av. España S/N (Cdra. 4) - Plaza de Armas , Comas -11.957235 -77.049790
# 10  Av. José de Riva Agüero \nN° 1358 Mz. D, El Ag... -12.048215 -77.000509
# ...

# %%
munis[['addres', 'lat', 'lng']] = pd.DataFrame( munis.results.tolist() ,  index = munis.index )

# %%
munis
# Out:
#               Municipalidad                                     Alcalde  \
# 0                      Lima            JORGE VICENTE MARTIN MUÑOZ WELLS
# 1                     Ancón                   PEDRO JOHN BARRERA BERNUI
# 2                       Ate                        EDDE CUELLAR ALEGRIA
# 3                  Barranco              JOSE JUAN RODRIGUEZ \nCARDENAS
# 4                     Breña                        JOSE DALTON LI BRAVO
# 5                Carabayllo              MARCOS LORENZO ESPINOZA\nORTIZ
# 6                Chaclacayo              MANUEL JAVIER CAMPOS SOLOGUREN
# 7                Chorrillos           AUGUSTO SERGIO MIYASHIRO USHIKUBO
# 8               Cieneguilla                       EDWIN SUBILETI ARECHE
# 9                     Comas                             RAUL DIAZ PEREZ
# 10              El Agustino                VICTOR MODESTO SALCEDO\nRIOS
# 11            Independencia                   YURI JOSE PANDO FERNANDEZ
# ...

# %%
munis = munis [['addres','lat','lng']]
munis
# Out:
#                                                addres        lat        lng
# 0                        Jr. De la Unión N° 300, Lima -12.045340 -77.030952
# 1                     Malecón Ferreyros N° 376, Ancón -11.773805 -77.176282
# 2                     Av. Nicolás Ayllón N° 5818, Ate -11.984603 -76.807023
# 3                        Av. San Martín S/N, Barranco -12.142510 -77.023201
# 4                             Av. Arica N° 500, Breña -12.058635 -77.046036
# 5                 Av. Túpac Amaru N° 1733, Carabayllo -11.889950 -77.026985
# 6               Av. Nicolás Ayllón N° 856, Chaclacayo -11.975379 -76.768785
# 7       Av. Defensores del Morro \nN° 550, Chorrillos -12.169311 -77.024376
# 8         Av. Nueva Toledo N° 97 \nMz. B, Cieneguilla -12.102783 -76.799410
# 9   Av. España S/N (Cdra. 4) - Plaza de Armas , Comas -11.957235 -77.049790
# 10  Av. José de Riva Agüero \nN° 1358 Mz. D, El Ag... -12.048215 -77.000509
# ...

# %%
munis.to_csv( r'..\..\..\Diplomado_PUCP\Lecture_8\_data_results\group_1_ass_5.csv' , index =False)
