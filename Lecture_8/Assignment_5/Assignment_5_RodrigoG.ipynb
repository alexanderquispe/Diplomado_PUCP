# %%
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
import requests
import os
import json
import pandas as pd
import csv
from datetime import datetime
import dateutil.parser
import unicodedata
import time
import requests
import chardet
import googlemaps

# %%
rawdata = open( r'../../_data/Base5.csv', 'rb').read()
result = chardet.detect(rawdata)
charenc = result[ 'encoding' ]

# %%
CEM = pd.read_csv( r'../../_data/Base5.csv' , delimiter = ';', encoding = charenc )
CEM = CEM.rename( columns = { CEM.columns[ 6 ] : 'Address' } )
CEM
# Out:
#       N° CATEGORÍA DEPARTAMENTO           CEM TELÉFONO FIJO CELULAR CEM  \
# 0      1   REGULAR     AMAZONAS         BAGUA           NaN   980047461
# 1      2   REGULAR     AMAZONAS       BONGARA           NaN   914179014
# 2      3   REGULAR     AMAZONAS   CHACHAPOYAS      41479309   994834149
# 3      4   REGULAR     AMAZONAS  CONDORCANQUI           NaN   994841361
# 4      5   REGULAR     AMAZONAS          LUYA           NaN   994841220
# ..   ...       ...          ...           ...           ...         ...
# 241  242   REGULAR       TUMBES     ZARUMILLA      72507829   994800813
# 242  243   REGULAR      UCAYALI       ATALAYA           NaN   994801097
# 243  244   REGULAR      UCAYALI    PADRE ABAD           NaN   994800884
# 244  245   REGULAR      UCAYALI      PUCALLPA      61573247   994801093
# 245  246   REGULAR      UCAYALI         PURÚS           NaN         NaN
#
#                                                Address  \
# ...

# %%
CEM = CEM.sample( 100, random_state = 1 ).reset_index( drop = True )

# %%
CEM
# Out:
#      N° CATEGORÍA DEPARTAMENTO                   CEM TELÉFONO FIJO  \
# 0    68   REGULAR    CAJAMARCA            SAN MARCOS           NaN
# 1   246   REGULAR      UCAYALI                 PURÚS           NaN
# 2   209   REGULAR        PIURA               SECHURA      73376704
# 3   223   REGULAR         PUNO                  PUNO       5136520
# 4    91   REGULAR        CUSCO                SAYLLA           NaN
# ..  ...       ...          ...                   ...           ...
# 95    6   REGULAR     AMAZONAS  RODRIGUEZ DE MENDOZA      41476294
# 96  184   REGULAR       LORETO     DATEM DEL MARAÑON           NaN
# 97  186   REGULAR       LORETO                  NAPO           NaN
# 98   49   REGULAR     AYACUCHO         HUANCA SANCOS           NaN
# 99  199   REGULAR     MOQUEGUA              MOQUEGUA      61573247
#
#    CELULAR CEM                                            Address  \
# 0    994819604                   JIRON JOSE GALVEZ 113 SAN MARCOS
# ...

# %%
coord = np.zeros( shape = ( CEM[ 'Address' ].shape[ 0 ], 2 ), dtype = float )

i = 0

gmaps = googlemaps.Client( key = 'AIzaSyCDr79v4CHSAmF-drAZQqtR_Bh2gIFr1wo' )

for index, row in tqdm( CEM.iterrows() ):   

    # Geocoding an address
    geocode_result = gmaps.geocode( row[ 'Address' ] , region = 'pe')
    if len( geocode_result ) == 0:
        coord[ i ][ 0 ] = "nan"
        coord[ i ][ 1 ] = "nan"
        
        i += 1
        
        print( row[ 'Address' ] )
        print( "el codigo encontro error" )
        
    else :
        coord[ i ][ 0 ] = geocode_result[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
        coord[ i ][ 1 ] = geocode_result[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]
        i += 1
# Out:
# C:\Users\Work\AppData\Local\Temp/ipykernel_8364/1248149981.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm( CEM.iterrows() ):
# 0it [00:00, ?it/s]
# JR. PROGRESO, CUADRA 4- FRENTE A LA GOBERNACIÓN PROVINCIAL.
# el codigo encontro error
# PLAZA DE ARMAS S/N - INTERIOR DEL PALACIO MUNICIPAL 3ER PISO. (EX RADIO MUNICIPAL)
# el codigo encontro error
# PASAJE SANTA ZORAYA  ESQUINA CON INDEPENDENCIA S/N
# el codigo encontro error
# AV. ARIAS GRACIANI S/N (A MEDIA CUADRA DE LA PLAZA DE ARMAS)
# el codigo encontro error
# CALLE COPACABANA N° 300 - 2 PISO (LOCAL COMUNAL)
# el codigo encontro error
# JR. GRAU 159-161 , 1ER PISO (COSTADO DE RENIEC)
# el codigo encontro error
# JR. SAN MARTIN S/N MZ. B6 LT. 1 - BARRIO MALAMBO. (INTERIOR DEL ESTADIO MUNICIPAL DE HUAYLAS "GERARDO LARA" PUERTA N° 2 OCCIDENTE)
# el codigo encontro error
# ...

# %%
coord
# Out:
# array([[ -12.0903847,  -77.072941 ],
#        [  -9.7720457,  -70.709537 ],
#        [ -12.0384329,  -76.9570244],
#        [ -16.4090474,  -71.537451 ],
#        [ -13.5506489,  -71.8274846],
#        [ -14.8842942,  -70.5889612],
#        [  -7.6395065,  -78.0423683],
#        [  -6.4814296,  -76.3678685],
#        [         nan,          nan],
#        [  -6.1362221,  -77.9505261],
#        [         nan,          nan],
#        [ -13.3140102,  -71.5931657],
#        [ -13.2833411,  -75.3181947],
#        [ -18.0065679,  -70.2462741],
#        [         nan,          nan],
#        [ -12.0889191,  -76.8818604],
#        [  -3.9072082,  -70.5165822],
#        [ -14.6940206,  -74.1241607],
#        [         nan,          nan],
#        [ -12.0384329,  -76.9570244],
#        [ -12.0516677,  -77.0280674],
#        [ -14.105258 ,  -72.708062 ],
#        [ -11.9673793,  -77.0679912],
#        [  -7.1790007,  -76.7309644],
#        [ -12.1326738,  -76.9961508],
# ...

# %%
CEM[ [ 'latitude' , 'longitude' ] ] = pd.DataFrame( coord.tolist(), index = CEM.index )
CEM
# Out:
#      N° CATEGORÍA DEPARTAMENTO                   CEM TELÉFONO FIJO  \
# 0    68   REGULAR    CAJAMARCA            SAN MARCOS           NaN
# 1   246   REGULAR      UCAYALI                 PURÚS           NaN
# 2   209   REGULAR        PIURA               SECHURA      73376704
# 3   223   REGULAR         PUNO                  PUNO       5136520
# 4    91   REGULAR        CUSCO                SAYLLA           NaN
# ..  ...       ...          ...                   ...           ...
# 95    6   REGULAR     AMAZONAS  RODRIGUEZ DE MENDOZA      41476294
# 96  184   REGULAR       LORETO     DATEM DEL MARAÑON           NaN
# 97  186   REGULAR       LORETO                  NAPO           NaN
# 98   49   REGULAR     AYACUCHO         HUANCA SANCOS           NaN
# 99  199   REGULAR     MOQUEGUA              MOQUEGUA      61573247
#
#    CELULAR CEM                                            Address  \
# 0    994819604                   JIRON JOSE GALVEZ 113 SAN MARCOS
# ...

# %%
Base_final = CEM[ [ 'Address', 'latitude', 'longitude' ] ]
Base_final
# Out:
#                                               Address   latitude  longitude
# 0                    JIRON JOSE GALVEZ 113 SAN MARCOS -12.090385 -77.072941
# 1   AV. JULIO VILLACORTA S/N - INTERIOR DE LA MUNI...  -9.772046 -70.709537
# 2   AAHH VICENTE CHUNGA ALDANA MZ O LOTE 1 (INTERI... -12.038433 -76.957024
# 3   JR. AREQUIPA Nº 857 (INTERIOR DEL EDIFICIO DE ... -16.409047 -71.537451
# 4   PLAZA MUNICIPAL S/N DISTRITO DE SAYLLA-PALACIO... -13.550649 -71.827485
# ..                                                ...        ...        ...
# 95  JR. MATIAZA RIMACHI N°510 (INT. MUNICIPALIDAD ...  -6.395685 -77.482304
# 96  Calle Tigre N° 249-2° Piso- LOCAL DE LA MUNICI...  -4.827869 -76.553626
# 97     calle Patricio Mosquera S/N ex hotel Municipal  -0.602472 -80.424393
# 98     AV.LOS AYLLUS S/N - LOCAL MUNICIPAL - 1ER PISO        NaN        NaN
# 99     JR. TACNA Nº 292 (REF. EX LOCAL DEL SERENAZGO) -12.056158 -77.084520
#
# [100 rows x 3 columns]

# %%
Base_final.to_csv ( r"group_3_ass_5.csv", index = False, header=True)
