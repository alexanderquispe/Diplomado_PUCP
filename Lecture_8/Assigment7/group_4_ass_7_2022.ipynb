# %% [markdown]
# # Assignment 7

# %% [markdown]
# # Parte 1. Importar datos desde PDF

# %% [markdown]
# ### 1.1 Librerías

# %%
pip install camelot-py[cv] tabula-py
# Out:
# ...
#      -------------------------------------- 41.0/41.0 kB 394.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.0/12.0 MB 4.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 4.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 244.0/244.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 4.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install googlemaps
#instalamos los paquetes necesarios
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40717 sha256=2ec6ee26676947a778e5b4858a3eb3ce97b18deabf60dcae18c814bda84685c8
#   Stored in directory: c:\users\usuario\appdata\local\pip\cache\wheels\d9\5f\46\54a2bdb4bcb07d3faba4463d2884865705914cc72a7b8bb5f0
# Successfully built googlemaps
# ...

# %%
import requests
import os
import json
import pandas as pd
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
import tabula
# import camelot

# %%
#import os 
#os.chdir(r"D:\Users\Usuario\Documents\GitHub\Diplomado_PUCP\Lecture_8")

# %% [markdown]
# ### 1.2 Importar datos de PDF

# %%
dbanco = tabula.read_pdf("https://www.bbva.pe/content/dam/public-web/peru/documents/personas/canales-de-atencion/oficinas/Oficinas-BBVA-abiertas-23.10.20.pdf", pages="all", stream=True)
# Out:
# Got stderr: mar 03, 2023 4:29:33 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# ADVERTENCIA: New fonts found, font cache will be re-built
# mar 03, 2023 4:29:33 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Building on-disk font cache, this may take a while
# mar 03, 2023 4:29:48 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Finished building on-disk font cache, found 371 fonts

# %%
print(type(dbanco), type(dbanco[0])) #el resultado es una lista de dataframes (uno por cada página)
# Out:
# <class 'list'> <class 'pandas.core.frame.DataFrame'>

# %%
# Observamos que hay un error al importar la página 2
print([len(i.columns) for i in dbanco])
# Out:
# [5, 6, 5, 5, 5, 5, 5, 5]

# %%
print(len(dbanco))
dbanco[0]
# Out:
# 8
#                        Unnamed: 0  \
# 0                         OFICINA
# 1                    BAGUA GRANDE
# 2                        CHIMBOTE
# 3                          HUARAZ
# 4              MEGAPLAZA CHIMBOTE
# 5                             NaN
# 6         MERCADO MODELO CHIMBOTE
# 7                  NUEVO CHIMBOTE
# 8                             NaN
# 9                     ANDAHUAYLAS
# 10                     LAS BAMBAS
# 11                       AREQUIPA
# 12              CAMANA - AREQUIPA
# 13                          CAYMA
# 14                 CERRO COLORADO
# 15                    EL PEDREGAL
# 16                            NaN
# 17  JOSE LUIS BUSTAMANTE Y RIVERO
# 18                            NaN
# 19       MALL AVENTURA PLAZA  AQP
# 20                            NaN
# 21          MIRAFLORES - AREQUIPA
# 22              PARQUE INDUSTRIAL
# 23                     SAN CAMILO
# 24                      YANAHUARA
# 25          UNIVERSIDAD SAN PABLO
# ...

# %%
# Se elimina columna vacía
dbanco[1].dropna(how='all', axis=1, inplace=True)

# %%
for i in range(len(dbanco)):
    dbanco[i] = dbanco[i].reset_index().T.reset_index().T.reset_index()
    dbanco[i].drop(dbanco[i].iloc[:, 0:2], axis = 1, inplace=True)
    dbanco[i].set_axis(["oficina", "direccion", "distrito", "provincia", "departamento"], axis=1, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\356026288.py:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   dbanco[i].set_axis(["oficina", "direccion", "distrito", "provincia", "departamento"], axis=1, inplace=True)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\356026288.py:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   dbanco[i].set_axis(["oficina", "direccion", "distrito", "provincia", "departamento"], axis=1, inplace=True)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\356026288.py:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
# ...

# %%
# En la data de la primera hoja se elimina las primeras dos columnas mal importadas
dbanco[0]= dbanco[0].iloc[2:, :]

# %%
# Se concatena toda la data
bbva_peru = pd.concat(dbanco, ignore_index= True)

# %%
# Nos quedamos solo con Lima
bbva_peru["departamento"].replace(["LIMA.1"], ["LIMA"], inplace =   True)
print(bbva_peru['departamento'].value_counts())
bbva_lima = bbva_peru.loc[bbva_peru["departamento"] == "LIMA", :]
# Out:
# LIMA             206
# AREQUIPA          12
# LA LIBERTAD       12
# PIURA             10
# JUNIN              9
# LAMBAYEQUE         7
# SAN MARTIN         6
# CUSCO              6
# ICA                5
# ANCASH             5
# LORETO             4
# CAJAMARCA          4
# PUNO               3
# UCAYALI            3
# HUANUCO            3
# MOQUEGUA           2
# APURIMAC           2
# TACNA              2
# MADRE DE DIOS      1
# PASCO.1            1
# AYACUCHO           1
# TUMBES             1
# AMAZONAS           1
# Name: departamento, dtype: int64

# %%
bbva_lima
# Out:
#                     oficina  \
# 78              CAMINO REAL
# 79              28 DE JULIO
# 80         ABANCAY-CONGRESO
# 81               AEROPUERTO
# 82             ANGAMOS ESTE
# ..                      ...
# 322     NESTLE-DONOFRIO 164
# 323  BIENESTAR DE LA MARINA
# 324                 SEDAPAL
# 326         ESPECIAL SENATI
# 327          VILLA INFANTAS
#
#                                              direccion       distrito  \
# 78                                 AV. CAMINO REAL 355     SAN ISIDRO
# 79                                 AV. 28 DE JULIO 775           LIMA
# 80                                 AV. ABANCAY 260-262           LIMA
# 81        CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 82   Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 322                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
cols = ['direccion', 'distrito']
bbva_lima[ 'complete_address' ] = bbva_lima[ cols ].apply(lambda row: ', '.\
                                  join( row.values.astype( str ) ) , axis = 1 )
#unimos la dirección con el distrito para contar con una ubicación más precisa de cada punto en el mapa
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\970328610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbva_lima[ 'complete_address' ] = bbva_lima[ cols ].apply(lambda row: ', '.\

# %%
bbva_lima.head(3)
# Out:
#              oficina            direccion    distrito provincia departamento  \
# 78       CAMINO REAL  AV. CAMINO REAL 355  SAN ISIDRO      LIMA         LIMA
# 79       28 DE JULIO  AV. 28 DE JULIO 775        LIMA      LIMA         LIMA
# 80  ABANCAY-CONGRESO  AV. ABANCAY 260-262        LIMA      LIMA         LIMA
#
#                    complete_address
# 78  AV. CAMINO REAL 355, SAN ISIDRO
# 79        AV. 28 DE JULIO 775, LIMA
# 80        AV. ABANCAY 260-262, LIMA

# %% [markdown]
# # Parte 2. Geocode

# %%
# Importamos el paquete correspondiente y seteamos el API
import googlemaps
gmaps = googlemaps.Client( key = 'AIzaSyCOeOz6pzPmjHcGmQkFXvuwUm1_j9PcWgw' )

# %%
# Definimos la función para la geolocalización

def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']  
        
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
# Aplicaciones de la función anteriormente definina mediante el método lambda. 
# Se crea una nueva columna denominada "results", que alberga la latitud y longitud de las oficinas

bbva_lima[ 'results' ] = bbva_lima.apply( lambda x: get_results( gmaps.geocode( x[ 'complete_address' ] , region = 'pe' ) ) , axis = 1 )
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\2455220768.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbva_lima[ 'results' ] = bbva_lima.apply( lambda x: get_results( gmaps.geocode( x[ 'complete_address' ] , region = 'pe' ) ) , axis = 1 )

# %%
# Verificamos el porcentage de oficinas que no pudieron ser geolocalizadas

bbva_lima[ 'results' ].value_counts( normalize = True )
# Out:
# (nan, nan)                    0.048544
# (-12.104926, -76.9707944)     0.014563
# (-12.1416088, -76.9918155)    0.004854
# (-12.0963256, -77.059482)     0.004854
# (-12.0675511, -77.097178)     0.004854
#                                 ...
# (-11.9872235, -77.0076916)    0.004854
# (-11.9700381, -77.067261)     0.004854
# (-12.0781849, -77.0367809)    0.004854
# (-12.0713228, -77.0983092)    0.004854
# (-11.9638112, -77.063462)     0.004854
# Name: results, Length: 195, dtype: float64

# %%
# Desdoblamos la columna "results" en columnas separadas de latitud y longitud

bbva_lima[ [ 'latitude' , 'longitud' ] ] = pd.DataFrame( bbva_lima.results.tolist(), index = bbva_lima.index )
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\1857123055.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbva_lima[ [ 'latitude' , 'longitud' ] ] = pd.DataFrame( bbva_lima.results.tolist(), index = bbva_lima.index )
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\1857123055.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbva_lima[ [ 'latitude' , 'longitud' ] ] = pd.DataFrame( bbva_lima.results.tolist(), index = bbva_lima.index )

# %%
# Identificamos las filas en las que las oficinas no pudieron ser geolocalizadas

bbva_lima[ bbva_lima [ 'latitude' ].isna() ]
# Out:
#                              oficina  \
# 122                            CAPON
# 149                          EL MURO
# 164                          GAMARRA
# 169                  HIPOLITO UNANUE
# 211                             MALA
# 214  MALL AVENTURA PLAZA SANTA ANITA
# 230                  NACIONES UNIDAS
# 281           SAN JUAN DE MIRAFLORES
# 299                     VALLE SHARON
# 308                VILLA EL SALVADOR
#
#                                              direccion           distrito  \
# 122                                    JR. UCAYALI 735        LA VICTORIA
# 149  AV. WIESSE TDA A, PROGR. CIUDAD MARISCAL CACER...        SAN JUAN DE
# 164                               PROLONG. UNANUE 1599        LA VICTORIA
# 169                 JR HIPOLITO UNANUE 1616-1620, LC 3        LA VICTORIA
# 211                                       JR. REAL 305               MALA
# 214  AV. CARRETERA CENTRAL 111, LOCAL COMERCIAL N° ...        SANTA ANITA
# ...

# %% [markdown]
# Rellenamos manualmente la longitud y latitud de aquellas oficinas que no pudieron ser localizadas

# %%
# Oficina El Muro

row_149 = gmaps.geocode( "AV. WIESSE TDA A, PROGR. CIUDAD MARISCAL CACERES, SEC. II, MZ. J1 LT. 28, SJL" , region = 'pe' )

row_149_lat = row_149[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_149_lng = row_149[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 149, 'latitude' ] = row_149_lat
bbva_lima.at[ 149, 'longitud' ] = row_149_lng

# %%
# Oficina Gamarra

row_164 = gmaps.geocode( "PROLONGACION UNANUE 1599, LA VICTORIA " , region = 'pe' )

row_164_lat = row_164[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_164_lng = row_164[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 164, 'latitude' ] = row_164_lat
bbva_lima.at[ 164, 'longitud' ] = row_164_lng

# %%
# Oficina Hipólito Unanue

row_169 = gmaps.geocode( "JR. HIPóLITO UNANUE, 1620, LC 3, LA VICTORIA" , region = 'pe' )

row_169_lat = row_169[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_169_lng = row_169[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 169, 'latitude' ] = row_169_lat
bbva_lima.at[ 169, 'longitud' ] = row_169_lng

# %%
# Oficina Mala

row_211 = gmaps.geocode( "JR. REAL 305, MALA, CAÑETE", region = 'pe' )

row_211_lat = row_211[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_211_lng = row_211[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 211, 'latitude' ] = row_211_lat
bbva_lima.at[ 211, 'longitud' ] = row_211_lng

# %%
# Oficina Mall Aventura Plaza Santa Anita

row_214 = gmaps.geocode( "AV. CARRETERA CENTRAL 111, SANTA ANITA", region = 'pe' )

row_214_lat = row_214[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_214_lng = row_214[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 214, 'latitude' ] = row_214_lat
bbva_lima.at[ 214, 'longitud' ] = row_214_lng

# %%
# Oficina Naciones Unidas

row_230 = gmaps.geocode( "Av. Jorge Chavez, BBVA, Miraflores", region = 'pe' )

row_230_lat = row_230[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_230_lng = row_230[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 230, 'latitude' ] = row_230_lat
bbva_lima.at[ 230, 'longitud' ] = row_230_lng

# %%
# Oficina San Juan de Miraflores

row_281 = gmaps.geocode( "AV. DE LOS HEROES 502, San Juan de Miraflores", region = 'pe' )

row_281_lat = row_281[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_281_lng = row_281[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 281, 'latitude' ] = row_281_lat
bbva_lima.at[ 281, 'longitud' ] = row_281_lng

# %%
# Oficina Valle Sharon

row_299 = gmaps.geocode( "AV. VICTOR C. IGLESIAS 790, San Juan de Miraflores", region = 'pe' )

row_299_lat = row_299[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_299_lng = row_299[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 299, 'latitude' ] = row_299_lat
bbva_lima.at[ 299, 'longitud' ] = row_299_lng

# %%
# Oficina Villa El Salvador

row_308 = gmaps.geocode( "LT. 17 DE LA AV. REVOLUCIÓN, Villa El Salvador", region = 'pe' )

row_308_lat = row_308[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_308_lng = row_308[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 308, 'latitude' ] = row_308_lat
bbva_lima.at[ 308, 'longitud' ] = row_308_lng

# %%
# Oficina Strip Center Barranca

row_316 = gmaps.geocode( "CA. CASTILLA 370, Strip Center, Barranca", region = 'pe' )

row_316_lat = row_316[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
row_316_lng = row_316[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

bbva_lima.at[ 316, 'latitude' ] = row_316_lat
bbva_lima.at[ 316, 'longitud' ] = row_316_lng

# %%
# Verificamos que no queden oficinas sin geolocalización

bbva_lima[ 'latitude' ].value_counts( normalize = True )
# Out:
# -12.104926    0.014706
# -12.097362    0.004902
# -12.086785    0.004902
# -12.063719    0.004902
# -12.096326    0.004902
#                 ...
# -12.078185    0.004902
# -12.071323    0.004902
# -12.063116    0.004902
# -12.029842    0.004902
# -11.963811    0.004902
# Name: latitude, Length: 202, dtype: float64

# %%
# Borramos la columna results, dado que ya tenemos la latitud y longitud en sus respectivas columnas

bbva_lima = bbva_lima.drop( [ 'results' ], axis = 1 )

# %% [markdown]
# # Parte 3. Driving time

# %% [markdown]
# El primer paso será delimitar cuatro puntos de origen (uno por cada dirección de los integrantes del equipo). Uniremos la columna con este origen a la base de datos de dirección de sedes BBVA previamente generada:
# * Integrante 1: Av. Universitaria 2095, Torre C, Depto 1505, Pueblo Libre
# * Integrante 2: Av. Alameda Astral 301, Pueblo Libre
# * Integrante 3: Jr. Cusco 280, Magdalena del Mar
# * Integrante 4: Av. Manuel Cipriano Dulanto 1414, Pueblo Libre
#
# A partir de estas direcciones identificamos las coordenadas

# %%
import urllib.request, json
import csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
import re

# %%
int1 = requests.get( 
    "https://maps.googleapis.com/maps/api/geocode/json?address=Av.+Universitaria+2095,+Torre+C,+Depto+1505,+Pueblo+Libre&key=AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI&language=es&region=pe")
int2 = requests.get( 
    "https://maps.googleapis.com/maps/api/geocode/json?address=Av.+Alameda+Astral+301,+Pueblo+Libre&key=AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI&language=es&region=pe")
int3 = requests.get( 
    "https://maps.googleapis.com/maps/api/geocode/json?address=Jr.+Cusco+280,+Magdalena+del+Mar&key=AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI&language=es&region=pe")
int4 = requests.get( 
    "https://maps.googleapis.com/maps/api/geocode/json?address=Av.+Manuel+Cipriano+Dulanto+1414+Pueblo+Libre&key=AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI&language=es&region=pe")

print(int1,int2,int3, int4)
# Out:
# <Response [200]> <Response [200]> <Response [200]> <Response [200]>

# %%
#generamos tres estructuras json con información geográfica
data_json_1 = int1.json()
data_json_2 = int2.json()
data_json_3 = int3.json()
data_json_4 = int4.json()

# %%
#extraemos las coordenadas para cada origen (dirección de integrante del grupo)
lat_1 = data_json_1[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
lng_1 = data_json_1[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]
lat_2 = data_json_2[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
lng_2 = data_json_2[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]
lat_3 = data_json_3[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
lng_3 = data_json_3[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]
lat_4 = data_json_4[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
lng_4 = data_json_4[ 'results' ][ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]
print(f"Coordenadas Integrante 1:{lat_1},{lng_1}")
print(f"Coordenadas Integrante 2:{lat_2},{lng_2}")
print(f"Coordenadas Integrante 3:{lat_3},{lng_3}")
print(f"Coordenadas Integrante 3:{lat_4},{lng_4}")
# Out:
# Coordenadas Integrante 1:-12.0746809,-77.0792089
# Coordenadas Integrante 2:-12.0692917,-77.074049
# Coordenadas Integrante 3:-12.0896938,-77.0681613
# Coordenadas Integrante 3:-12.0774071,-77.06962879999999

# %%
#recordemos la estructura del dataframe principal
back_up_bbva_lima =bbva_lima.copy()
bbva_lima.head(4)
# Out:
#              oficina                                     direccion  \
# 78       CAMINO REAL                           AV. CAMINO REAL 355
# 79       28 DE JULIO                           AV. 28 DE JULIO 775
# 80  ABANCAY-CONGRESO                           AV. ABANCAY 260-262
# 81        AEROPUERTO  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A
#
#       distrito provincia departamento  \
# 78  SAN ISIDRO      LIMA         LIMA
# 79        LIMA      LIMA         LIMA
# 80        LIMA      LIMA         LIMA
# 81      CALLAO      LIMA         LIMA
#
#                                      complete_address   latitude   longitud
# 78                    AV. CAMINO REAL 355, SAN ISIDRO -12.097362 -77.036099
# 79                          AV. 28 DE JULIO 775, LIMA -12.064030 -77.037961
# 80                          AV. ABANCAY 260-262, LIMA -12.047955 -77.026997
# 81  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A, ... -12.023538 -77.104397

# %%
#generaremos nuevas columnas con esta información de origen por integrante
bbva_lima["lat_1"] = lat_1
bbva_lima["lat_2"] = lat_2
bbva_lima["lat_3"] = lat_3
bbva_lima["lat_4"] = lat_4
bbva_lima["lng_1"] = lng_1
bbva_lima["lng_2"] = lng_2
bbva_lima["lng_3"] = lng_3
bbva_lima["lng_4"] = lng_4

bbva_lima["coma"] = ","

bbva_lima["origen_1"] = bbva_lima["lat_1"].astype(str) +  bbva_lima["coma"] + bbva_lima["lng_1"].astype(str)
bbva_lima["origen_2"] = bbva_lima["lat_2"].astype(str) +  bbva_lima["coma"] + bbva_lima["lng_2"].astype(str)
bbva_lima["origen_3"] = bbva_lima["lat_3"].astype(str) +  bbva_lima["coma"] + bbva_lima["lng_3"].astype(str)
bbva_lima["origen_4"] = bbva_lima["lat_4"].astype(str) +  bbva_lima["coma"] + bbva_lima["lng_4"].astype(str)

#eliminamos las columnas con nombre lat y lng
bbva_lima = bbva_lima[bbva_lima.columns.drop(list(bbva_lima.filter(regex='lat_')))]
bbva_lima = bbva_lima[bbva_lima.columns.drop(list(bbva_lima.filter(regex='lng_')))]
bbva_lima.drop('coma', inplace=True, axis=1)

# %%
bbva_lima.head(4)
# Out:
#              oficina                                     direccion  \
# 78       CAMINO REAL                           AV. CAMINO REAL 355
# 79       28 DE JULIO                           AV. 28 DE JULIO 775
# 80  ABANCAY-CONGRESO                           AV. ABANCAY 260-262
# 81        AEROPUERTO  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A
#
#       distrito provincia departamento  \
# 78  SAN ISIDRO      LIMA         LIMA
# 79        LIMA      LIMA         LIMA
# 80        LIMA      LIMA         LIMA
# 81      CALLAO      LIMA         LIMA
#
#                                      complete_address   latitude   longitud  \
# 78                    AV. CAMINO REAL 355, SAN ISIDRO -12.097362 -77.036099
# 79                          AV. 28 DE JULIO 775, LIMA -12.064030 -77.037961
# 80                          AV. ABANCAY 260-262, LIMA -12.047955 -77.026997
# 81  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A, ... -12.023538 -77.104397
#
# ...

# %%
bbva_lima["origen_1"]
# Out:
# 78     -12.0746809,-77.0792089
# 79     -12.0746809,-77.0792089
# 80     -12.0746809,-77.0792089
# 81     -12.0746809,-77.0792089
# 82     -12.0746809,-77.0792089
#                 ...
# 322    -12.0746809,-77.0792089
# 323    -12.0746809,-77.0792089
# 324    -12.0746809,-77.0792089
# 326    -12.0746809,-77.0792089
# 327    -12.0746809,-77.0792089
# Name: origen_1, Length: 206, dtype: object

# %%
bbva_lima2 = bbva_lima.sample(frac=0.1, replace=True, random_state=1)
bbva_lima2.shape
# Out:
# (21, 12)

# %% [markdown]
# También generaremos una columna que permita identificar el destino (ubicación de las agencias BBVA)

# %%
bbva_lima["coma"] = ","
bbva_lima["destino"] = bbva_lima["latitude"].astype(str) +  bbva_lima["coma"] + bbva_lima["longitud"].astype(str)
bbva_lima.drop('coma', inplace=True, axis=1)
bbva_lima.head(2)
# Out:
#         oficina            direccion    distrito provincia departamento  \
# 78  CAMINO REAL  AV. CAMINO REAL 355  SAN ISIDRO      LIMA         LIMA
# 79  28 DE JULIO  AV. 28 DE JULIO 775        LIMA      LIMA         LIMA
#
#                    complete_address   latitude   longitud  \
# 78  AV. CAMINO REAL 355, SAN ISIDRO -12.097362 -77.036099
# 79        AV. 28 DE JULIO 775, LIMA -12.064030 -77.037961
#
#                    origen_1                origen_2                 origen_3  \
# 78  -12.0746809,-77.0792089  -12.0692917,-77.074049  -12.0896938,-77.0681613
# 79  -12.0746809,-77.0792089  -12.0692917,-77.074049  -12.0896938,-77.0681613
#
#                           origen_4                  destino
# 78  -12.0774071,-77.06962879999999  -12.0973616,-77.0360994
# 79  -12.0774071,-77.06962879999999  -12.0640305,-77.0379609

# %%
#generamos una columna con números que identifiquen a las filas
bbva_lima['combinación'] = bbva_lima.reset_index().index
bbva_lima['combinación'] = bbva_lima.apply( lambda x:  x["combinación"]+1 , axis = 1 ) #le sumamos 1 a cada fila para comenzar en 1 (en lugar de 0)
bbva_lima
# Out:
#                     oficina  \
# 78              CAMINO REAL
# 79              28 DE JULIO
# 80         ABANCAY-CONGRESO
# 81               AEROPUERTO
# 82             ANGAMOS ESTE
# ..                      ...
# 322     NESTLE-DONOFRIO 164
# 323  BIENESTAR DE LA MARINA
# 324                 SEDAPAL
# 326         ESPECIAL SENATI
# 327          VILLA INFANTAS
#
#                                              direccion       distrito  \
# 78                                 AV. CAMINO REAL 355     SAN ISIDRO
# 79                                 AV. 28 DE JULIO 775           LIMA
# 80                                 AV. ABANCAY 260-262           LIMA
# 81        CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 82   Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 322                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
# Generamos una lista 
combi = bbva_lima['combinación'].tolist()
org_1 = bbva_lima['origen_1'].tolist()
org_2 = bbva_lima['origen_2'].tolist()
org_3 = bbva_lima['origen_3'].tolist()
org_4 = bbva_lima['origen_4'].tolist()
dest= bbva_lima['destino'].tolist()

# %%
org_1
# Out:
# ['-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
#  '-12.0746809,-77.0792089',
# ...

# %%
type(dest)
# Out:
# list

# %%
# Generamos ahora un diccionario para almacenar todos los datos por integrante
data_distance_1 = {} 
data_distance_2 = {} 
data_distance_3 = {} 
data_distance_4 = {}

# %%
#combinamos todos los elementos previamente generados:
for c,o,d in tqdm(list(zip(combi,org_1, dest))):
    print(c,o,d)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\1256328901.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combi,org_1, dest))):
#   0%|          | 0/206 [00:00<?, ?it/s]
# 1 -12.0746809,-77.0792089 -12.0973616,-77.0360994
# 2 -12.0746809,-77.0792089 -12.0640305,-77.0379609
# 3 -12.0746809,-77.0792089 -12.0479547,-77.02699679999999
# 4 -12.0746809,-77.0792089 -12.0235384,-77.10439749999999
# 5 -12.0746809,-77.0792089 -12.1134759,-77.028582
# 6 -12.0746809,-77.0792089 -12.1120524,-77.0117853
# 7 -12.0746809,-77.0792089 -12.0719308,-77.011235
# 8 -12.0746809,-77.0792089 -12.1036288,-77.0307414
# 9 -12.0746809,-77.0792089 -12.0716113,-77.0374212
# 10 -12.0746809,-77.0792089 -12.0915794,-77.03373189999999
# 11 -12.0746809,-77.0792089 -12.1140109,-77.0480248
# 12 -12.0746809,-77.0792089 -12.0307591,-77.0848436
# 13 -12.0746809,-77.0792089 -12.0807507,-77.0665087
# ...

# %% [markdown]
# ### Distancia respecto a la dirección del integrante 1

# %%
# Loop para generar información sobre geolocalización
distance_info_1 = np.zeros(shape=(len(combi),7), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combi,org_1, dest))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Parámetros
        # Parámetro de tipo de cálculo
        traffic_model = 'best_guess'  

        # Hora de salida
        departure_time= 'now'

        # driving (en carro), walking (caminando), biclycling (en bicicleta), transit (en transporte público)
        mode = 'driving'

        # key (cambiar de acuerdo a tu API)
        api_key = 'AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI'

        # Regi{on} (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parámetros
        # Origen (punto de partida)
        origin = o
        
        # Destinos
        destination = d
        
        #Construímos el url para hacer el requerimiento
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # ejemplo anterior: https://maps.googleapis.com/maps/api/directions/json?origin=Toledo&destination=Madrid&region=es&key=AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE
        
        
        # Encadenamos los strings 
        request = endpoint + nav_request

        #Realizamos el pedido y se lee la respuesta
        response = urllib.request.urlopen(request).read()

        #Se carga la respuesta como un archivo JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_1[i][0] = c
        distance_info_1[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_1[i][2] = legs['distance']['value']

        distance_info_1[i][3] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
        distance_info_1[i][4] = legs['duration']['value']
        
        distance_info_1[i][5] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
        distance_info_1[i][6] = legs['duration_in_traffic']['value']
        
        i=i+1
        
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_1[c] = info 
    
    #En caso no se cuente con la información generar nans
    except Exception as e:
        
        distance_info_1[i][0] = c
        
        distance_info_1[i][1] = "nan"
        distance_info_1[i][2] = "nan"

        distance_info_1[i][3] = "nan"
        distance_info_1[i][4] = "nan"
        
        distance_info_1[i][5] = "nan"
        distance_info_1[i][6] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\1546355447.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combi,org_1, dest))):
#   0%|          | 0/206 [00:00<?, ?it/s]
# 41
# 93
# 170

# %%
distance_info_1
# Out:
# array([[1.0000e+00, 8.0000e+00, 8.0070e+03, ..., 1.5380e+03, 1.8000e+01,
#         1.0930e+03],
#        [2.0000e+00, 6.3000e+00, 6.2800e+03, ..., 1.1620e+03, 1.5000e+01,
#         9.0900e+02],
#        [3.0000e+00, 1.1700e+01, 1.1745e+04, ..., 1.7690e+03, 2.2000e+01,
#         1.3290e+03],
#        ...,
#        [2.0400e+02, 1.6700e+01, 1.6652e+04, ..., 2.5540e+03, 2.9000e+01,
#         1.7590e+03],
#        [2.0500e+02, 1.3700e+01, 1.3655e+04, ..., 1.9620e+03, 2.3000e+01,
#         1.4070e+03],
#        [2.0600e+02, 1.4000e+01, 1.4027e+04, ..., 2.2630e+03, 2.9000e+01,
#         1.7270e+03]])

# %%
#Generamos el dataframe con la información obtenída
distance_api_1 = pd.DataFrame(distance_info_1, columns = ['Combinación', 'Distancia (km)','Distancia (m)','Duración (min)', 'Duration (sec)', \
                                           'Duración con Tráfico (min)', 'Duración con Tráfico (sec)'])
distance_api_1
# Out:
#      Combinación  Distancia (km)  Distancia (m)  Duración (min)  \
# 0            1.0             7.6         7631.0            24.0
# 1            2.0             6.3         6273.0            19.0
# 2            3.0            11.7        11745.0            29.0
# 3            4.0             8.0         7955.0            22.0
# 4            5.0            10.4        10412.0            34.0
# ..           ...             ...            ...             ...
# 201        202.0             4.1         4070.0            10.0
# 202        203.0             3.9         3943.0             9.0
# 203        204.0            17.5        17514.0            38.0
# 204        205.0            10.4        10411.0            30.0
# 205        206.0            14.3        14289.0            36.0
#
#      Duration (sec)  Duración con Tráfico (min)  Duración con Tráfico (sec)
# 0            1436.0                        25.0                      1513.0
# ...

# %%
#Generamos una columna de identificación para cada integrante del grupo
distance_api_1["Integrante"]= "Fabio"
distance_api_1
# Out:
#      Combinación  Distancia (km)  Distancia (m)  Duración (min)  \
# 0            1.0             7.6         7631.0            24.0
# 1            2.0             6.3         6273.0            19.0
# 2            3.0            11.7        11745.0            29.0
# 3            4.0             8.0         7955.0            22.0
# 4            5.0            10.4        10412.0            34.0
# ..           ...             ...            ...             ...
# 201        202.0             4.1         4070.0            10.0
# 202        203.0             3.9         3943.0             9.0
# 203        204.0            17.5        17514.0            38.0
# 204        205.0            10.4        10411.0            30.0
# 205        206.0            14.3        14289.0            36.0
#
#      Duration (sec)  Duración con Tráfico (min)  Duración con Tráfico (sec)  \
# 0            1436.0                        25.0                      1513.0
# ...

# %%
#uniremos este dataframe con información de los nombres de las ubicaciones (nombres de las oficinas)
bbva_lima["Combinación"]= bbva_lima["combinación"]
distance_api_all= pd.merge(distance_api_1, bbva_lima[["Combinación","oficina"]], how="left", on=["Combinación"])
distance_api_all.head(2)
# Out:
#    Combinación  Distancia (km)  Distancia (m)  Duración (min)  Duration (sec)  \
# 0          1.0             7.6         7631.0            24.0          1436.0
# 1          2.0             6.3         6273.0            19.0          1153.0
#
#    Duración con Tráfico (min)  Duración con Tráfico (sec) Integrante  \
# 0                        25.0                      1513.0      Fabio
# 1                        21.0                      1267.0      Fabio
#
#        oficina
# 0  CAMINO REAL
# 1  28 DE JULIO

# %% [markdown]
# ### Distancia respecto a la dirección del integrante 2

# %%
#los elementos que cambian en el código son los siguientes: 
#(1) distance_info_1 -> distance_info_2; (2) org_1 -> org_2; (3) data_distance_1 -> data_distance_2


# Loop para generar información sobre geolocalización
distance_info_2 = np.zeros(shape=(len(combi),7), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combi,org_2, dest))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Parámetros
        # Parámetro de tipo de cálculo
        traffic_model = 'best_guess'  

        # Hora de salida
        departure_time= 'now'

        # driving (en carro), walking (caminando), biclycling (en bicicleta), transit (en transporte público)
        mode = 'driving'

        # key (cambiar de acuerdo a tu API)
        api_key = 'AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI'

        # Regi{on} (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parámetros
        # Origen (punto de partida)
        origin = o
        
        # Destinos
        destination = d
        
        #Construímos el url para hacer el requerimiento
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # ejemplo anterior: https://maps.googleapis.com/maps/api/directions/json?origin=Toledo&destination=Madrid&region=es&key=AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE
        
        
        # Encadenamos los strings 
        request = endpoint + nav_request

        #Realizamos el pedido y se lee la respuesta
        response = urllib.request.urlopen(request).read()

        #Se carga la respuesta como un archivo JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_2[i][0] = c
        distance_info_2[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_2[i][2] = legs['distance']['value']

        distance_info_2[i][3] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
        distance_info_2[i][4] = legs['duration']['value']
        
        distance_info_2[i][5] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
        distance_info_2[i][6] = legs['duration_in_traffic']['value']
        
        i=i+1
        
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_2[c] = info 
    
    #En caso no se cuente con la información generar nans
    except Exception as e:
        
        distance_info_2[i][0] = c
        
        distance_info_2[i][1] = "nan"
        distance_info_2[i][2] = "nan"

        distance_info_2[i][3] = "nan"
        distance_info_2[i][4] = "nan"
        
        distance_info_2[i][5] = "nan"
        distance_info_2[i][6] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\980404595.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combi,org_2, dest))):
#   0%|          | 0/206 [00:00<?, ?it/s]
# 41
# 93
# 170

# %% [markdown]
# ### Distancia respecto a la dirección del integrante 3

# %%
# Loop para generar información sobre geolocalización
distance_info_3 = np.zeros(shape=(len(combi),7), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combi,org_3, dest))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Parámetros
        # Parámetro de tipo de cálculo
        traffic_model = 'best_guess'  

        # Hora de salida
        departure_time= 'now'

        # driving (en carro), walking (caminando), biclycling (en bicicleta), transit (en transporte público)
        mode = 'driving'

        # key (cambiar de acuerdo a tu API)
        api_key = 'AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI'

        # Regi{on} (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parámetros
        # Origen (punto de partida)
        origin = o
        
        # Destinos
        destination = d
        
        #Construímos el url para hacer el requerimiento
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # ejemplo anterior: https://maps.googleapis.com/maps/api/directions/json?origin=Toledo&destination=Madrid&region=es&key=AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE
        
        
        # Encadenamos los strings 
        request = endpoint + nav_request

        #Realizamos el pedido y se lee la respuesta
        response = urllib.request.urlopen(request).read()

        #Se carga la respuesta como un archivo JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_3[i][0] = c
        distance_info_3[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_3[i][2] = legs['distance']['value']

        distance_info_3[i][3] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
        distance_info_3[i][4] = legs['duration']['value']
        
        distance_info_3[i][5] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
        distance_info_3[i][6] = legs['duration_in_traffic']['value']
        
        i=i+1
        
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_3[c] = info 
    
    #En caso no se cuente con la información generar nans
    except Exception as e:
        
        distance_info_3[i][0] = c
        
        distance_info_3[i][1] = "nan"
        distance_info_3[i][2] = "nan"

        distance_info_3[i][3] = "nan"
        distance_info_3[i][4] = "nan"
        
        distance_info_3[i][5] = "nan"
        distance_info_3[i][6] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\3652925720.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combi,org_3, dest))):
#   0%|          | 0/206 [00:00<?, ?it/s]
# 41
# 93
# 170

# %% [markdown]
# ### Distancia respecto a la dirección del integrante 4

# %%
# Loop para generar información sobre geolocalización
distance_info_4 = np.zeros(shape=(len(combi),7), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combi,org_4, dest))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Parámetros
        # Parámetro de tipo de cálculo
        traffic_model = 'best_guess'  

        # Hora de salida
        departure_time= 'now'

        # driving (en carro), walking (caminando), biclycling (en bicicleta), transit (en transporte público)
        mode = 'driving'

        # key (cambiar de acuerdo a tu API)
        api_key = 'AIzaSyAM17CpUHZ4ZbMHQS5b4pcC7vr9ftygCaI'

        # Regi{on} (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parámetros
        # Origen (punto de partida)
        origin = o
        
        # Destinos
        destination = d
        
        #Construímos el url para hacer el requerimiento
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # ejemplo anterior: https://maps.googleapis.com/maps/api/directions/json?origin=Toledo&destination=Madrid&region=es&key=AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE
        
        
        # Encadenamos los strings 
        request = endpoint + nav_request

        #Realizamos el pedido y se lee la respuesta
        response = urllib.request.urlopen(request).read()

        #Se carga la respuesta como un archivo JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_4[i][0] = c
        distance_info_4[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_4[i][2] = legs['distance']['value']

        distance_info_4[i][3] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
        distance_info_4[i][4] = legs['duration']['value']
        
        distance_info_4[i][5] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
        distance_info_4[i][6] = legs['duration_in_traffic']['value']
        
        i=i+1
        
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_4[c] = info 
    
    #En caso no se cuente con la información generar nans
    except Exception as e:
        
        distance_info_4[i][0] = c
        
        distance_info_4[i][1] = "nan"
        distance_info_4[i][2] = "nan"

        distance_info_4[i][3] = "nan"
        distance_info_4[i][4] = "nan"
        
        distance_info_4[i][5] = "nan"
        distance_info_4[i][6] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\4197702523.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combi,org_4, dest))):
#   0%|          | 0/206 [00:00<?, ?it/s]
# 41
# 93
# 170

# %%
#generamos el resto de dataframes, junto con información para identificar la dirección de los integrantes 
distance_api_2 = pd.DataFrame(distance_info_2, columns = ['Combinación', 'Distancia (km)','Distancia (m)','Duración (min)', 'Duration (sec)', \
                                           'Duración con Tráfico (min)', 'Duración con Tráfico (sec)'])
distance_api_2["Integrante"]= "Josue"
distance_api_22=pd.merge(distance_api_2, bbva_lima[["Combinación","oficina"]], how="left", on=["Combinación"])


distance_api_3 = pd.DataFrame(distance_info_3, columns = ['Combinación', 'Distancia (km)','Distancia (m)','Duración (min)', 'Duration (sec)', \
                                           'Duración con Tráfico (min)', 'Duración con Tráfico (sec)'])
distance_api_3["Integrante"]= "Mauricio"
distance_api_33=pd.merge(distance_api_3, bbva_lima[["Combinación","oficina"]], how="left", on=["Combinación"])

distance_api_4 = pd.DataFrame(distance_info_4, columns = ['Combinación', 'Distancia (km)','Distancia (m)','Duración (min)', 'Duration (sec)', \
                                           'Duración con Tráfico (min)', 'Duración con Tráfico (sec)'])
distance_api_4["Integrante"]= "Gabriela"
distance_api_44=pd.merge(distance_api_4, bbva_lima[["Combinación","oficina"]], how="left", on=["Combinación"])

# %%
df_direcciones = distance_api_all.append(distance_api_22).append(distance_api_33).append(distance_api_44)
df_direcciones
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\3069393055.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_direcciones = distance_api_all.append(distance_api_22).append(distance_api_33).append(distance_api_44)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\3069393055.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_direcciones = distance_api_all.append(distance_api_22).append(distance_api_33).append(distance_api_44)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8952\3069393055.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_direcciones = distance_api_all.append(distance_api_22).append(distance_api_33).append(distance_api_44)
# ...

# %% [markdown]
# # Parte 4. Reporte

# %% [markdown]
# Para identificar las oficinas que están más cerca y más lejos de cada dirección primero dividimos el dataframe en cuatro (un dataframe por cada integrante) e identificamos los valores máximos y mínimos de la distancia en metros

# %%
#filtramos el dataframe 
fabio = df_direcciones.loc[df_direcciones['Integrante'] == 'Fabio']
josue = df_direcciones.loc[df_direcciones['Integrante'] == 'Josue']
mauricio = df_direcciones.loc[df_direcciones['Integrante'] == 'Mauricio']
gabriela = df_direcciones.loc[df_direcciones['Integrante'] == 'Gabriela']

#imrpimimos la información sobre distancia
print('Información sobre la agencia más cercana a la casa de Fabio')
print(fabio[fabio['Distancia (m)'] == fabio['Distancia (m)'].min()].iloc[0])
print('Información sobre la agencia más lejana a la casa de Fabio')
print(fabio[fabio['Distancia (m)'] == fabio['Distancia (m)'].max()].iloc[0])
# Out:
# Información sobre la agencia más cercana a la casa de Fabio
# Combinación                             31.0
# Distancia (km)                           1.8
# Distancia (m)                         1810.0
# Duración (min)                           6.0
# Duration (sec)                         362.0
# Duración con Tráfico (min)               6.0
# Duración con Tráfico (sec)             380.0
# Integrante                             Fabio
# oficina                       C.C.SAN MIGUEL
# Name: 30, dtype: object
# Información sobre la agencia más lejana a la casa de Fabio
# Combinación                       159.0
# Distancia (km)                   1804.0
# Distancia (m)                 1803866.0
# Duración (min)                     15.0
# Duration (sec)                 104807.0
# Duración con Tráfico (min)         15.0
# Duración con Tráfico (sec)     105370.0
# Integrante                        Fabio
# oficina                           RIMAC
# Name: 158, dtype: object

# %% [markdown]
# Los resultados indicarían que la agencia más cercana a la dirección de Fabio es la que se encuentra en el Centro Comercial San Miguel. Fabio constata esto al comentarnos que su departamento está solo a un par de cuadras de dicho centro comercial

# %%
bbva_lima.iloc[30,:]
# Out:
# oficina                                                C.C.SAN MIGUEL
# direccion           AV. UNIVERSITARIA, ESQ. AV. LA MARINA, CC PLAZ...
# distrito                                                   SAN MIGUEL
# provincia                                                        LIMA
# departamento                                                     LIMA
# complete_address    AV. UNIVERSITARIA, ESQ. AV. LA MARINA, CC PLAZ...
# latitude                                                   -12.077054
# longitud                                                   -77.081311
# origen_1                                      -12.0746809,-77.0792089
# origen_2                                       -12.0692917,-77.074049
# origen_3                                      -12.0896938,-77.0681613
# origen_4                               -12.0774071,-77.06962879999999
# destino                                       -12.0770545,-77.0813106
# ...

# %%
print('Información sobre la agencia más cercana a la casa de Josue')
print(josue[josue['Distancia (m)'] == josue['Distancia (m)'].min()].iloc[0])
print('Información sobre la agencia más lejana a la casa de Josue')
print(josue[josue['Distancia (m)'] == josue['Distancia (m)'].max()].iloc[0])
print('Información sobre la agencia más cercana a la casa de Mauricio')
print(mauricio[mauricio['Distancia (m)'] == mauricio['Distancia (m)'].min()].iloc[0])
print('Información sobre la agencia más lejana a la casa de Mauricio')
print(mauricio[mauricio['Distancia (m)'] == mauricio['Distancia (m)']].iloc[0])
print('Información sobre la agencia más cercana a la casa de Gabriela')
print(gabriela[gabriela['Distancia (m)'] == gabriela['Distancia (m)'].min()].iloc[0])
print('Información sobre la agencia más lejana a la casa de Gabriela')
print(gabriela[gabriela['Distancia (m)'] == gabriela['Distancia (m)'].max()].iloc[0])
# Out:
# Información sobre la agencia más cercana a la casa de Josue
# Combinación                      21.0
# Distancia (km)                    1.7
# Distancia (m)                  1732.0
# Duración (min)                    6.0
# Duration (sec)                  340.0
# Duración con Tráfico (min)        7.0
# Duración con Tráfico (sec)      390.0
# Integrante                      Josue
# oficina                       BOLIVAR
# Name: 20, dtype: object
# Información sobre la agencia más lejana a la casa de Josue
# Combinación                       159.0
# Distancia (km)                   1804.0
# Distancia (m)                 1804208.0
# Duración (min)                     15.0
# Duration (sec)                 104921.0
# Duración con Tráfico (min)         15.0
# Duración con Tráfico (sec)     105389.0
# Integrante                        Josue
# oficina                           RIMAC
# Name: 158, dtype: object
# Información sobre la agencia más cercana a la casa de Mauricio
# ...
