# %%
pip install praw
# Out:
# ...
#
#    -------------------------- ------------- 2/3 [praw]
#    -------------------------- ------------- 2/3 [praw]
#    ---------------------------------------- 3/3 [praw]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
name="Fluid_Year6261"
print(f"Python:websecrapingProject:v1.0 (by /u/{name})")
# Out:
# Python:websecrapingProject:v1.0 (by /u/Fluid_Year6261)
