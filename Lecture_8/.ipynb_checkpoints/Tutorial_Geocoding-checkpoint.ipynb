# %%
# import the library
import googlemaps
import json
import pprint
import time
import pandas as pd
import numpy as np
import re

# %%
API_KEY = 'AIzaSyAXb1CyMDuAKkbk25LPIo9_XGSMGioLhEU'

# %%
data = pd.read_csv(  r"../_data/peru_excel_clean.csv")

# %%
df1 = data[ data.iloc[ :, 3 ].notnull() ].copy()

# %%
df1.head()
# Out:
#   Departamento             Provincia      Distrito  \
# 0     AMAZONAS              AMAZONAS   CHACHAPOYAS
# 1     AMAZONAS  Rodriguez de Mendoza   San Nicolás
# 2     AMAZONAS                 BAGUA         BAGUA
# 3     AMAZONAS               BONGARA         JAZAN
# 4     AMAZONAS             UTCUBAMBA  BAGUA GRANDE
#
#                               Dirección
# 0        Jirón Triunfo Nº 903 1er piso
# 1  Jirón Victor Mori Nº 204 San Nicolás
# 2                       Calle Junín S/N
# 3    Avenida marginal N° 100 Pedro Ruíz
# 4            Jirón Simón Bolivar N° 545

# %%
def join_columns( row_series ):
    
    
    return address

# %%
def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
def geo_reniec( row_series ):
    
    address = f"{row_series['Departamento']}, {row_series['Provincia']}, {row_series['Distrito']}, {row_series['Dirección']}"
    
    # Set Geolocation
    gmaps = googlemaps.Client( key = 'AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE' )
    result_api = gmaps.geocode( address , region = 'PE' )
    
    # Information
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( address, lat, lon )

# %%
df2 = df1.sample( frac = 0.05 ).copy()

# %%
df2['results'] = df2.apply( lambda x: geo_reniec( x )  , axis = 1 )

# %%
df2

# %%
pd.DataFrame( df2.results.tolist()  )

# %%
df2[['addres', 'lat', 'lng']] = pd.DataFrame( df2.results.tolist() ,  index = df2.index )

# %%
df2
# Out:
#     Departamento         Provincia           Distrito  \
# 215         PUNO              PUNO               PUNO
# 151         LIMA              LIMA        CIENEGUILLA
# 58     CAJAMARCA              JAEN             PUCARA
# 0       AMAZONAS          AMAZONAS        CHACHAPOYAS
# 10        ANCASH             SANTA              SANTA
# 64         CUSCO           CANCHIS            SICUANI
# 123  LA LIBERTAD              VIRÚ               VIRÚ
# 231   SAN MARTIN  MARISCAL CACERES   MARISCAL CACERES
# 205        PIURA           SULLANA            SULLANA
# 73         CUSCO          URUBAMBA           URUBAMBA
# 56     CAJAMARCA         CONTUMAZA          CONTUMAZA
# 158         LIMA              LIMA  VILLA EL SALVADOR
#
#                                              Dirección  \
# 215                        Jirón Arequipa Nº 1145 Puno
