# %%
#importar paquetes
import pandas as pd
import csv
import json
import os
import urllib.request
import numpy as np
from tqdm import tqdm_notebook as tqdm
import requests
import googlemaps

# %%
import chardet

# %%
pwd
# Out:
# 'C:\\Users\\Liliana\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_8\\Assignment_5'

# %% [markdown]
# #### 1. Detectar encoding

# %%
rawdata = open( fr'../../_data/Base5.csv', 'rb').read()

# %%
result = chardet.detect(rawdata)
charenc = result['encoding']
print(charenc)
# Out:
# UTF-8-SIG

# %%
pwd
# Out:
# 'C:\\Users\\Liliana\\Documents\\GitHub\\Diplomado_PUCP\\Lecture_8\\Assignment_5'

# %% [markdown]
# #### 2. Importar base de datos

# %%
CEM_data = pd.read_csv(fr'../../_data/Base5.csv', delimiter = ';', header = None, encoding = charenc)

# %%
CEM_data = CEM_data.rename( columns = { CEM_data.columns[ 6 ] : 'Address' } )

# %%
CEM = CEM_data.iloc[1:,:]
CEM.iloc[0:4,:]
# Out:
#    0        1         2             3         4          5  \
# 1  1  REGULAR  AMAZONAS         BAGUA       NaN  980047461
# 2  2  REGULAR  AMAZONAS       BONGARA       NaN  914179014
# 3  3  REGULAR  AMAZONAS   CHACHAPOYAS  41479309  994834149
# 4  4  REGULAR  AMAZONAS  CONDORCANQUI       NaN  994841361
#
#                                              Address  \
# 1  JR. SARGENTO LORES S/N A 2 CUADRAS DE LA GEREN...
# 2  AV. 26 DE DICIEMBRE 460. FRENTE A LA PLAZA DE ...
# 3  AAHH SEÑOR DE LOS MILAGROS - JIRON MANUEL MOLL...
# 4  JR GONZALO PUERTA N° 102 - DISTRITO SANTA MARI...
#
#                                    7                            8
# 1            LUIS FELIPE REYES CHUÑE   luisreyes_ch18@hotmail.com
# 2        JACLYN JULISSA UBILLUS RUIZ          july-89@hotmail.com
# 3  DEBORAH MARIEL MORI CHUQUIMBALQUI     mariel57931311@gmail.com
# 4        PAULO CESAR CESPEDES DURAND  paulo_cesar1974@hotmail.com

# %%
CEM['Address'].shape[0]
# Out:
# 246

# %% [markdown]
# #### 3. Geocoding usando iterrows

# %%
coord = np.zeros(shape=( CEM['Address'].shape[0] , 2), dtype = float )

i=0

gmaps = googlemaps.Client(key='AIzaSyDPOyiibh5KGAyb_A7iPFHOXdg83W-Blao')

for index, row in tqdm(CEM.iterrows()):   

    # Geocoding an address
    geocode_result = gmaps.geocode( row['Address'] , region='pe')
    if len(geocode_result)==0 :
        coord[i][0] = "nan"
        coord[i][1] = "nan"
        
        i=i+1
        
        print(row['Address'])
        print("el codigo encontro error")
        
    else :
        coord[i][0]=geocode_result[0]['geometry']['location']['lat']
        coord[i][1]=geocode_result[0]['geometry']['location']['lng']
        i=i+1
# Out:
# <ipython-input-74-1e12814f0aa4>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm(CEM.iterrows()):
# 0it [00:00, ?it/s]
# JIRON MANUEL GONZALES PRADA S/N (A DOS CUADRAS DEL PARQUE CENTRAL)
# el codigo encontro error
# JR. PLAZA DE ARMAS N°506 - 1ER PISO DE LA MUNICIPALIDAD
# el codigo encontro error
# JR. GRAU 206, PLAZA DE ARMAS- INTERIOR DE LA MUNICIPALIDAD PROVINCIAL DE COROINGO
# el codigo encontro error
# AV. RAIMONI S/N CUADRA 10 - INTERIOR DE LA DIRECCION REGIONAL DEL MINISTERIO DEL TRABAJO Y DEL EMPELO.
# el codigo encontro error
# JR. SAN MARTIN S/N MZ. B6 LT. 1 - BARRIO MALAMBO. (INTERIOR DEL ESTADIO MUNICIPAL DE HUAYLAS "GERARDO LARA" PUERTA N° 2 OCCIDENTE)
# el codigo encontro error
# AV. CENTRAL BRUCES S/N (INTERIOR DEL POLIDEPORTIVO BRUCES-PILAR NORES DE GARCIA)
# el codigo encontro error
# AV. ARIAS GRACIANI S/N (A MEDIA CUADRA DE LA PLAZA DE ARMAS)
# el codigo encontro error
# CALLE CALVARIO CON ESQUINA CALLE HUANCA S/N, BARRIO ALTO
# el codigo encontro error
# AV. FERNANDO BELAUNDE TERRY S/N - 5 ESQUINAS, FRENTE AL SEMÁFORO
# el codigo encontro error
# CALLE COPACABANA N° 300 - 2 PISO (LOCAL COMUNAL)
# el codigo encontro error
# AV.LOS AYLLUS S/N - LOCAL MUNICIPAL - 1ER PISO
# el codigo encontro error
# CENTRO CIVICO OFICINA N°11, SAN MIGUEL -LA MAR (AL COSTADO DE SENASA)
# el codigo encontro error
# AV. VICTOR FAJARDO S/N CUADRA 7 (LOCAL DE LA GOBERNACION)
# el codigo encontro error
# JR. BELEN  N° 683( COSTADO DE NIÑA DE BELEN)
# el codigo encontro error
# CALLE UNIVERSIDAD ENTRE LA CDRA 4 Y 5 (INGRESANDO POR EL PASAJE 2 MANO DERECHA)- URB. EL EDEN.
# el codigo encontro error
# JIRÓN BOLÍVAR S/N FRENTE A LA SBP - ALTURA DE LA PLAZA DE ARMAS
# el codigo encontro error
# CALLE LAS PALOMAS S/N EX - ZONA COMERCIAL - LOCAL LA CASA DE MUJER.
# el codigo encontro error
# PLAZA DE ARMAS S/N - INTERIOR DEL PALACIO MUNICIPAL 3ER PISO. (EX RADIO MUNICIPAL)
# el codigo encontro error
# AV. SAN MARTIN 316- CERCADO (FRENTE AL HOTEL PLAZA Y COSTADO DEL TEATRO MUNICIPAL)
# el codigo encontro error
# JR. BELÉN S/N (REF. ESQUINA BELÉN CON GRAU - LOCAL MUNICIPAL)
# el codigo encontro error
# JR. POTOCCHI S/N ESPALDA DE LA PISCINA SAN CRISTOBAL -
# el codigo encontro error
# JR. MARISCAL CASTILLA CDRA 02 -AL LADO DEL BANCO DE LA NACIÓN
# el codigo encontro error
# 2DO PISO DEL MERCADILLO DEL DISTRITO DE RIPAN - PASANDO EL PUENTE DE PIEDRA
# el codigo encontro error
# CALLE VIRGEN DE FATIMA S/N 3ER PISO . EX HOTEL MUNICIPAL
# el codigo encontro error
# JR. GRAU 159-161 , 1ER PISO (COSTADO DE RENIEC)
# el codigo encontro error
# JIRON RICARDO PALMA S/N PLATAFORMA DEL MERCADO MODELO (COSTADO DE LA RENIEC)
# el codigo encontro error
# JR.GILDEMEISTER Nº 187 ( A ESPALADAS DEL INSTITUTO TECNOLOGICO)
# el codigo encontro error
# CALLE JOSÉ DE LA TORRE UGARTE, N° 1000 2DO PISO (DENTRO DE LA MUNICIPALIDAD)
# el codigo encontro error
# JR. JOSÉ GALVEZ S/N - 4TA CDRA DEL CENTRO CIVICO, 1ER PISO.
# el codigo encontro error
# CALLE HERALDOS NEGROS Nº. 355 - 2DO PISO (INTERIOR DE LOCAL PSICINA MUNICIPAL FRENTE AL HOTEL  EL MIRADOR)
# el codigo encontro error
# PASAJE SANTA ZORAYA  ESQUINA CON INDEPENDENCIA S/N
# el codigo encontro error
# CALLE PLAZA DE ARMAS N° 109
# el codigo encontro error
# JR.28 DE JULIO N° 491. (COSTADO DE LA BIBLIOTECA VIRTUAL, INTERIOR DE LA GALERIA MUNICIPAL)
# el codigo encontro error
# CALLE SAN ANTONIO S/N - 2 DO PISO DE RENIEC
# el codigo encontro error
# ESQ. JR. MAYER Y JR. RUFFINER S/N (1ER PISO DEL MERCADO SANTA ROSA -TIENDA 9)
# el codigo encontro error
# JR. FELIX OJEDA S/N CUADRA 02 ESQ. CON AVENIDA LETICIA, FRENTE A LA PLAZA CENTRAL-ESPALDA DE LA BIBLIOTECA MUNICIPAL
# el codigo encontro error
# AV LA CULTURA S/N EX ALBERGUE MUNICIPAL TERCER PISO
# el codigo encontro error
# JR. PROGRESO, CUADRA 4- FRENTE A LA GOBERNACIÓN PROVINCIAL.
# el codigo encontro error
# AV. GRAU CDRA 4 (AL COSTADO DEL MERCADO AYAYMAMA - CAMPO FERIAL AYYAMAMA)
# el codigo encontro error
# JR.TEOBALDO LOPEZ CUADRA 3 ( AL COSTADO DEL MODULO DE JUSTICIA - FRENTE AL MERCADO ZONAL)
# el codigo encontro error
# AV. VILLA MUNICIPAL S/N (INTERIOR DEL LOCAL DE SEGURIDAD CIUDADANA - PRIMER PISO - ALT. DE ESSALUD).
# el codigo encontro error
# CALLE HIPÓLITO UNANUE Nº 970 ( COSTADO DE LA EMPRESA DISTRIBUIDORA DE COCA COLA)
# el codigo encontro error
# CALLE ZELA S/N - 2DO. PISO - COSTADO DEL PODER JUDICIAL
# el codigo encontro error

# %%
# Tal vez podamos quitar el texto entre parentesis para evitar errores en la geolocalización

# %%
coord
# Out:
# array([[  -5.6428867,  -78.525286 ],
#        [  -5.857687 ,  -77.792343 ],
#        [ -12.0422714,  -77.020402 ],
#        [  -4.6010065,  -77.8610254],
#        [  -6.1362221,  -77.9505261],
#        [  -6.3956855,  -77.4823035],
#        [  -5.7567899,  -78.4378428],
#        [  -9.780803 ,  -77.6092188],
#        [  -9.0992611,  -77.0140741],
#        [         nan,          nan],
#        [ -18.0065679,  -70.2462741],
#        [  -9.281744 ,  -77.6450215],
#        [         nan,          nan],
#        [  -9.4718308,  -78.3006626],
#        [ -12.0667854,  -77.0319585],
#        [         nan,          nan],
#        [         nan,          nan],
#        [  -9.3483845,  -77.1708039],
#        [ -10.0696687,  -78.152911 ],
#        [         nan,          nan],
#        [  -8.8641745,  -77.3581045],
#        [         nan,          nan],
#        [ -10.4031418,  -77.3977529],
#        [  -8.3944043,  -78.006695 ],
#        [ -12.0460038,  -77.0305458],
#        [  -9.92     ,  -77.182222 ],
#        [  -8.5543698,  -77.6309204],
#        [         nan,          nan],
#        [ -12.0463731,  -77.042754 ],
#        [ -13.6568694,  -73.3794303],
#        [         nan,          nan],
#        [ -14.2951956,  -73.2423004],
#        [         nan,          nan],
#        [ -13.3010672,  -71.9633913],
#        [ -14.105258 ,  -72.708062 ],
#        [ -16.4084458,  -71.5368997],
#        [ -14.0749764,  -75.7243605],
#        [ -13.1528871,  -74.2292822],
#        [ -16.0761834,  -72.492153 ],
#        [         nan,          nan],
#        [ -16.4090474,  -71.537451 ],
#        [ -15.2121955,  -72.8898665],
#        [ -16.3571908,  -72.1888149],
#        [ -16.4024547,  -71.5079446],
#        [ -12.0384329,  -76.9570244],
#        [ -16.4660314,  -71.5308508],
#        [ -13.62902  ,  -74.1436827],
#        [ -13.5306135,  -71.9364696],
#        [         nan,          nan],
#        [ -12.9384113,  -74.2502122],
#        [         nan,          nan],
#        [ -14.6940206,  -74.1241607],
#        [ -15.0163124,  -73.7801447],
#        [ -12.0059644,  -77.0591617],
#        [ -12.5080596,  -73.8624893],
#        [ -13.9891662,  -73.8183804],
#        [         nan,          nan],
#        [ -13.6541087,  -73.9521468],
#        [  -7.6395065,  -78.0423683],
#        [         nan,          nan],
#        [  -6.8666512,  -78.1421905],
#        [  -7.1617465,  -78.5127855],
#        [ -12.0427215,  -77.0340162],
#        [  -6.3760453,  -78.821275 ],
#        [  -6.6781923,  -78.5174942],
#        [         nan,          nan],
#        [  -5.1447483,  -79.0064902],
#        [ -12.0903847,  -77.072941 ],
#        [         nan,          nan],
#        [  36.778261 , -119.4179324],
#        [ -12.0687547,  -77.1284554],
#        [ -12.0578301,  -77.1150189],
#        [ -12.0567562,  -77.1428253],
#        [ -11.8491154,  -77.153201 ],
#        [         nan,          nan],
#        [ -13.9194933,  -71.6833925],
#        [ -13.4622252,  -72.1494902],
#        [ -12.1635236,  -76.9723739],
#        [         nan,          nan],
#        [ -14.4501924,  -72.0819794],
#        [ -13.5239992,  -71.9613554],
#        [ -12.6478324,  -73.0481735],
#        [         nan,          nan],
#        [ -12.6194392,  -73.7882793],
#        [ -13.7619463,  -71.8476237],
#        [ -13.3140102,  -71.5931657],
#        [ -12.5177532,  -73.8271024],
#        [ -12.8738347,  -72.6945296],
#        [ -13.6824359,  -71.6228355],
#        [ -13.53195  ,  -71.9674626],
#        [ -13.5506489,  -71.8274846],
#        [ -12.0725527,  -77.0614641],
#        [         nan,          nan],
#        [ -12.0240527,  -77.112036 ],
#        [ -12.9951759,  -74.7249281],
#        [ -13.2833411,  -75.3181947],
#        [ -12.0677056,  -75.2074747],
#        [         nan,          nan],
#        [ -13.6040212,  -75.3532422],
#        [ -12.3992902,  -74.8659421],
#        [         nan,          nan],
#        [         nan,          nan],
#        [  -9.0950407,  -76.8368896],
#        [  -9.5495518,  -76.8179391],
#        [  -9.9427212,  -76.2461258],
#        [ -11.9773437,  -77.0571246],
#        [  -8.6042821,  -77.1504626],
#        [  -9.8979032,  -75.9931798],
#        [  -9.9207648,  -76.2410843],
#        [  -9.9207648,  -76.2410843],
#        [         nan,          nan],
#        [ -14.0504533,  -73.087749 ],
#        [ -18.0065679,  -70.2462741],
#        [ -16.4090474,  -71.537451 ],
#        [  18.4825243,  -69.9446158],
#        [ -13.7129199,  -76.1474231],
#        [ -12.0472216,  -77.0506644],
#        [ -11.8340504,  -77.1121282],
#        [ -11.0545869,  -75.3303317],
#        [ -12.1326738,  -76.9961508],
#        [         nan,          nan],
#        [         nan,          nan],
#        [ -13.53195  ,  -71.9674626],
#        [ -12.0569212,  -77.0287397],
#        [ -11.1615645,  -75.9992677],
#        [ -11.8998089,  -74.3118212],
#        [ -10.9265815,  -74.8745545],
#        [  -6.4814296,  -76.3678685],
#        [  -5.115146 ,  -78.1108279],
#        [ -12.0083714,  -76.8422129],
#        [  38.7368192,   -9.138705 ],
#        [  -7.2271893,  -79.4288257],
#        [         nan,          nan],
#        [  -8.0666028,  -79.014354 ],
#        [         nan,          nan],
#        [ -11.1227218,  -77.6105679],
#        [  -7.816461 ,  -78.0452048],
#        [  -8.0442754,  -78.4880543],
#        [  -8.0568859,  -79.0524998],
#        [ -18.0065679,  -70.2462741],
#        [  -7.4304331,  -79.5044694],
#        [         nan,          nan],
#        [         nan,          nan],
#        [ -12.0790868,  -77.0488287],
#        [  -8.41487  ,  -78.7540614],
#        [  -6.7448809,  -79.8464804],
#        [ -12.0838879,  -77.0493484],
#        [  -3.5696714,  -80.4575829],
#        [ -11.792902 ,  -76.9873477],
#        [ -11.9741308,  -76.7622932],
#        [ -12.0096967,  -76.9053613],
#        [ -12.1060257,  -76.8295806],
#        [ -11.924646 ,  -77.0398396],
#        [ -12.0513713,  -76.9977264],
#        [ -11.9970501,  -77.0545257],
#        [ -12.0701221,  -76.9578802],
#        [ -12.0686349,  -77.0288072],
#        [ -12.032535 ,  -77.0815918],
#        [ -12.0029308,  -77.0827819],
#        [ -12.090338 ,  -77.062329 ],
#        [ -12.0889191,  -76.8818604],
#        [  -8.1092248,  -79.0132942],
#        [  27.6648274,  -81.5157535],
#        [ -11.9918478,  -77.0149192],
#        [ -12.2122941,  -76.9565477],
#        [ -12.0350845,  -77.0549398],
#        [ -12.0111302,  -77.0822012],
#        [ -12.0400571,  -77.0965422],
#        [ -12.1415788,  -76.9763187],
#        [ -12.1116941,  -77.0125394],
#        [ -12.2216819,  -76.9362182],
#        [ -12.1675125,  -76.9201161],
#        [ -12.0011855,  -77.0089804],
#        [         nan,          nan],
#        [         nan,          nan],
#        [ -11.4691392,  -76.6232202],
#        [ -11.1227218,  -77.6105679],
#        [  -3.4763823,  -80.2225448],
#        [ -18.0065679,  -70.2462741],
#        [         nan,          nan],
#        [ -12.1468353,  -77.0204988],
#        [ -12.0240527,  -77.112036 ],
#        [  -3.9072082,  -70.5165822],
#        [  -4.8278693,  -76.5536258],
#        [  -7.1790007,  -76.7309644],
#        [  -0.6024717,  -80.4243928],
#        [  -4.5065713,  -73.5757325],
#        [ -16.4090474,  -71.537451 ],
#        [         nan,          nan],
#        [  -3.7703142,  -73.2803099],
#        [  -6.5766068,  -77.7680952],
#        [  -5.8846104,  -76.1304244],
#        [ -11.9970501,  -77.0545257],
#        [ -11.9593005,  -77.0760254],
#        [ -12.0697326,  -77.0557625],
#        [ -12.592623 ,  -69.1821705],
#        [ -30.981979 ,  -64.1057959],
#        [  -9.0395314,  -75.5131117],
#        [ -12.0561578,  -77.0845196],
#        [ -10.4911471,  -76.5155834],
#        [         nan,          nan],
#        [ -12.0881445,  -77.0794458],
#        [ -10.7394842,  -75.2741089],
#        [ -12.0485608,  -77.0425015],
#        [  -5.2383234,  -79.4514218],
#        [  37.7749295, -122.4194155],
#        [ -12.1218773,  -77.030539 ],
#        [  -5.19136  ,  -80.659726 ],
#        [ -12.0384329,  -76.9570244],
#        [ -12.0987775,  -76.962168 ],
#        [         nan,          nan],
#        [  -4.581152 ,  -81.2628961],
#        [ -15.8375222,  -70.0265946],
#        [ -14.9164287,  -70.196185 ],
#        [ -14.0691337,  -70.4281661],
#        [ -15.9039696,  -69.8865431],
#        [ -15.2053189,  -69.7614568],
#        [ -16.0825395,  -69.6384724],
#        [ -15.5012857,  -70.131268 ],
#        [         nan,          nan],
#        [ -14.8842942,  -70.5889612],
#        [ -12.0516677,  -77.0280674],
#        [ -16.4090474,  -71.537451 ],
#        [  -8.1435933,  -78.4751945],
#        [ -15.4996879,  -70.129653 ],
#        [  -8.9314988,  -76.1119603],
#        [  -3.7436735,  -73.2516326],
#        [  -8.1119714,  -79.0297759],
#        [  -4.2324729,  -74.2179326],
#        [  -6.4613046,  -76.4517934],
#        [         nan,          nan],
#        [         nan,          nan],
#        [  -6.4969628,  -76.365414 ],
#        [         nan,          nan],
#        [  -6.4931279,  -76.3623455],
#        [ -12.0516677,  -77.0280674],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [  -5.1782884,  -80.6548882],
#        [  -3.5599942,  -80.4280409],
#        [ -12.1200771,  -77.0360416],
#        [ -30.981979 ,  -64.1057959],
#        [  -9.0395314,  -75.5131117],
#        [ -12.0561578,  -77.0845196],
#        [  -8.3875498,  -74.5359872]])

# %%
CEM[ [ 'latitude' , 'longitud' ] ] = pd.DataFrame( coord.tolist(), index = CEM.index )
CEM.iloc[0:4,:]
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    0        1         2             3         4          5  \
# 1  1  REGULAR  AMAZONAS         BAGUA       NaN  980047461
# 2  2  REGULAR  AMAZONAS       BONGARA       NaN  914179014
# 3  3  REGULAR  AMAZONAS   CHACHAPOYAS  41479309  994834149
# 4  4  REGULAR  AMAZONAS  CONDORCANQUI       NaN  994841361
#
#                                              Address  \
# 1  JR. SARGENTO LORES S/N A 2 CUADRAS DE LA GEREN...
# 2  AV. 26 DE DICIEMBRE 460. FRENTE A LA PLAZA DE ...
# 3  AAHH SEÑOR DE LOS MILAGROS - JIRON MANUEL MOLL...
# 4  JR GONZALO PUERTA N° 102 - DISTRITO SANTA MARI...
#
#                                    7                            8   latitude  \
# 1            LUIS FELIPE REYES CHUÑE   luisreyes_ch18@hotmail.com  -5.642887
# 2        JACLYN JULISSA UBILLUS RUIZ          july-89@hotmail.com  -5.857687
# 3  DEBORAH MARIEL MORI CHUQUIMBALQUI     mariel57931311@gmail.com -12.042271
# 4        PAULO CESAR CESPEDES DURAND  paulo_cesar1974@hotmail.com  -4.601007
#
#     longitud
# 1 -78.525286
# 2 -77.792343
# 3 -77.020402
# 4 -77.861025
