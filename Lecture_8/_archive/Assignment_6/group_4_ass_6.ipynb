# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

import urllib.request, json, csv
import pandas as pd
import numpy as np

import googlemaps
from tqdm import tqdm_notebook as tqdm

import re

import os
import unidecode
import time 
import json
import pprint
import urllib.request, json, csv
import requests
import datetime
import dateutil.parser
import unicodedata
import chardet
from datetime import datetime

# %% [markdown]
# ### 1. Take the information from national and private universities.

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\CSIESOFT\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-32-df34e5553bb5>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %%
url = 'https://www.sunedu.gob.pe/lista-universidades/'
driver.get( url )

# %% [markdown]
# #### Public

# %%
public_type = driver.find_element_by_xpath( '/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[1]/a' )
public_type.click()
# Out:
# <ipython-input-34-b07c135104e0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   public_type = driver.find_element_by_xpath( '/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[1]/a' )

# %%
table_public = driver.find_element_by_id( "tablepress-22_wrapper" )
# Out:
# <ipython-input-35-52acab28b004>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_public = driver.find_element_by_id( "tablepress-22_wrapper" )

# %%
table_public_html = table_public.get_attribute ('innerHTML')
pd_table_public = pd.read_html (table_public_html)

# %%
format_table_public = pd_table_public [0]
format_table_public
# Out:
#     N°                                        UNIVERSIDAD   DEPARTAMENTO  \
# 0    1           Universidad Nacional Mayor de San Marcos           Lima
# 1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
# 2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
# 3    4                   Universidad Nacional de Trujillo    La Libertad
# 4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
# 5    6                 Universidad Nacional de Ingeniería           Lima
# 6    7             Universidad Nacional Agraria La Molina           Lima
# 7    8              Universidad Nacional San Luis Gonzaga            Ica
# 8    9           Universidad Nacional del Centro del Perú          Junín
# 9   10        Universidad Nacional de la Amazonía Peruana         Loreto
# 10  11                 Universidad Nacional del Altiplano           Puno
# 11  12                      Universidad Nacional de Piura          Piura
# ...

# %% [markdown]
# #### Private

# %%
private_type = driver.find_element_by_xpath( '/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]/a' )
private_type.click()
# Out:
# <ipython-input-38-e9e83597a5f6>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   private_type = driver.find_element_by_xpath( '/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]/a' )

# %%
table_private = driver.find_element_by_id( "tablepress-23_wrapper" )
# Out:
# <ipython-input-39-b150219a5b9c>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_private = driver.find_element_by_id( "tablepress-23_wrapper" )

# %%
table_private_html = table_private.get_attribute ( 'innerHTML' )
pd_table_private = pd.read_html ( table_private_html )

# %%
format_table_private = pd_table_private [0]
format_table_private
# Out:
#     N°                                        UNIVERSIDAD  DEPARTAMENTO  \
# 0    1           Pontificia Universidad Católica del Perú          Lima
# 1    2               Universidad Peruana Cayetano Heredia          Lima
# 2    3                Universidad Católica de Santa María      Arequipa
# 3    4                           Universidad del Pacífico          Lima
# 4    5                                Universidad de Lima          Lima
# 5    6                Universidad de San Martín de Porres          Lima
# 6    7           Universidad Femenina del Sagrado Corazón          Lima
# 7    8              Universidad Inca Garcilaso de la Vega          Lima
# 8    9                               Universidad de Piura         Piura
# 9   10                          Universidad Ricardo Palma          Lima
# 10  11        Universidad Andina Néstor Cáceres Velásquez          Puno
# 11  12                      Universidad Peruana Los Andes         Junín
# ...

# %%
univ_append = pd.concat([format_table_public, format_table_private]).reset_index(drop = True)
univ_append.rename(columns = {'DEPARTAMENTO': 'Department_univ', 'PROVINCIA': 'Province_univ', 'UNIVERSIDAD': 'Name_univ'}, inplace = True)

# %%
data_univ = univ_append[['Department_univ', 'Province_univ', 'Name_univ']].assign(Adress_univ = univ_append.Name_univ + ', ' + univ_append.Province_univ + ', ' + univ_append.Department_univ)
data_univ.head()
# Out:
#   Department_univ Province_univ  \
# 0            Lima          Lima
# 1        Ayacucho      Huamanga
# 2           Cusco         Cusco
# 3     La Libertad      Trujillo
# 4        Arequipa      Arequipa
#
#                                            Name_univ  \
# 0           Universidad Nacional Mayor de San Marcos
# 1  Universidad Nacional de San Cristóbal de Huamanga
# 2  Universidad Nacional de San Antonio Abad del C...
# 3                   Universidad Nacional de Trujillo
# 4    Universidad Nacional de San Agustín de Arequipa
#
#                                          Adress_univ
# 0  Universidad Nacional Mayor de San Marcos, Lima...
# 1  Universidad Nacional de San Cristóbal de Huama...
# 2  Universidad Nacional de San Antonio Abad del C...
# 3  Universidad Nacional de Trujillo, Trujillo, La...
# 4  Universidad Nacional de San Agustín de Arequip...

# %% [markdown]
# ### 2.  Use Google API Geocoding to geolocate universities and get universities' latitude and longitude. Name these new variables as Latitude_univ and Longitude_univ. Use Department, province, and university name variables to get the most accurate results. Moreover, restrict the geolocation to Peru (PE).

# %%
coord = np.zeros(shape=( data_univ["Adress_univ"].shape[0] , 2), dtype = float )

i=0

gmaps = googlemaps.Client(key='AIzaSyAb7RQJYq83UgC8fXBS7F-H8896PTwcaiM')

for index, row in tqdm(data_univ.iterrows()):   

    # Geocoding an address
    geocode_result = gmaps.geocode( row['Adress_univ'] , region='pe')
    if len(geocode_result)==0 :
        coord[i][0] = "nan"
        coord[i][1] = "nan"
        
        i=i+1
        
        print(row['Adress_univ'])
        print("el codigo encontro error")
        
    else :
        coord[i][0]=geocode_result[0]['geometry']['location']['lat']
        coord[i][1]=geocode_result[0]['geometry']['location']['lng']
        i=i+1
# Out:
# <ipython-input-44-afeaa4725932>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm(data_univ.iterrows()):
# 0it [00:00, ?it/s]
# Universidad ESAN, Lima, Lima
# el codigo encontro error

# %%
data_univ[ [ 'Latitude_univ' , 'Longitude_univ' ] ] = pd.DataFrame( coord.tolist(), index = data_univ.index )
data_univ = data_univ[['Department_univ', 'Province_univ', 'Name_univ', 'Latitude_univ', 'Longitude_univ']]
data_univ
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junín          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huánuco     Leoncio Prado
# 15          Huánuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
pd.set_option('display.max_rows', None)
data_univ
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junín          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huánuco     Leoncio Prado
# 15          Huánuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
#drop esan
data_univ = data_univ.dropna()
data_univ
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junín          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huánuco     Leoncio Prado
# 15          Huánuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
#quitar tildes
import unidecode

data_univ['Department_univ'] = data_univ['Department_univ'].apply(unidecode.unidecode)
data_univ
# Out:
# <ipython-input-48-27c2ad9e5834>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_univ['Department_univ'] = data_univ['Department_univ'].apply(unidecode.unidecode)
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junin          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# ...

# %% [markdown]
# ### 3 Merge your results with the department centroids data using the Department variables as ID. This merge should be m:1. Keep only left observations (university data) and the centroids. The department centroids data have information on the centroids of all Peru's Departments.

# %%
centroids_data = pd.read_excel(r'..\..\_data\peru_departments_centroids.xlsx', index_col=0).reset_index()
centroids_data
# Out:
#     CCDD        NOMBDEP           CAPITAL  Dpt_Centroid_Latitude  \
# 0      1       AMAZONAS       CHACHAPOYAS              -5.069369
# 1      2         ANCASH            HUARAZ              -9.406368
# 2      3       APURIMAC           ABANCAY             -14.028147
# 3      4       AREQUIPA          AREQUIPA             -15.844475
# 4      5       AYACUCHO          AYACUCHO             -14.086284
# 5      6      CAJAMARCA         CAJAMARCA              -6.432297
# 6      7         CALLAO            CALLAO             -11.940800
# 7      8          CUSCO             CUSCO             -13.189060
# 8      9   HUANCAVELICA      HUANCAVELICA             -13.023206
# 9     10        HUANUCO           HUANUCO              -9.416089
# 10    11            ICA               ICA             -14.233761
# 11    12          JUNIN          HUANCAYO             -11.538922
# 12    13    LA LIBERTAD          TRUJILLO              -7.921689
# ...

# %%
centroids_data = centroids_data[['NOMBDEP', 'Dpt_Centroid_Latitude', 'Dpt_Centroid_Longitude']]
centroids_data['NOMBDEP'] = centroids_data['NOMBDEP'].apply(lambda x: x.title())
centroids_data
# Out:
# <ipython-input-50-49ad7895a1ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centroids_data['NOMBDEP'] = centroids_data['NOMBDEP'].apply(lambda x: x.title())
#           NOMBDEP  Dpt_Centroid_Latitude  Dpt_Centroid_Longitude
# 0        Amazonas              -5.069369              -78.055235
# 1          Ancash              -9.406368              -77.670229
# 2        Apurimac             -14.028147              -72.974732
# 3        Arequipa             -15.844475              -72.472918
# 4        Ayacucho             -14.086284              -74.083968
# 5       Cajamarca              -6.432297              -78.745878
# 6          Callao             -11.940800              -77.126022
# ...

# %%
data_univ = data_univ.merge(centroids_data, left_on='Department_univ', right_on='NOMBDEP', how='left')
data_univ.pop('NOMBDEP')
data_univ
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junin          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huanuco     Leoncio Prado
# 15          Huanuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
#save to excel
data_univ.to_excel("data_univ.xlsx")

# %% [markdown]
# ### 4. Finally, use Google API Directions to find the driving travel time and distance from universities to department centroids. Set driving as the value of the parameter mode. Include information of the three options of traffic_model variable: best_guess, pessimistic, and optimistic. The final dataframe output should look like the table below:

# %%
#read excel
df = pd.read_excel('data_univ.xlsx', index_col=0)
df
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junin          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huanuco     Leoncio Prado
# 15          Huanuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
df["separador"] =','
#7 decimals
df['Latitude_univ'] = df['Latitude_univ'].round(7)
df['Longitude_univ'] = df['Longitude_univ'].round(7)
df['Dpt_Centroid_Latitude'] = df['Dpt_Centroid_Latitude'].round(7)
df['Dpt_Centroid_Longitude'] = df['Dpt_Centroid_Longitude'].round(7)

# %%
#change to string origin
df['Latitude_univ'] = df['Latitude_univ'].astype(str)
df['Longitude_univ'] = df['Longitude_univ'].astype(str)

# %%
df["origin"] = df["Latitude_univ"] + df["separador"] + df["Longitude_univ"]
df
# Out:
#     Department_univ     Province_univ  \
# 0              Lima              Lima
# 1          Ayacucho          Huamanga
# 2             Cusco             Cusco
# 3       La Libertad          Trujillo
# 4          Arequipa          Arequipa
# 5              Lima              Lima
# 6              Lima              Lima
# 7               Ica               Ica
# 8             Junin          Huancayo
# 9            Loreto            Maynas
# 10             Puno              Puno
# 11            Piura             Piura
# 12        Cajamarca         Cajamarca
# 13             Lima              Lima
# 14          Huanuco     Leoncio Prado
# 15          Huanuco           Huánuco
# 16             Lima              Lima
# 17            Pasco             Pasco
# 18           Callao            Callao
# 19             Lima            Huaura
# 20       Lambayeque        Lambayeque
# 21            Tacna             Tacna
# 22           Ancash            Huaraz
# ...

# %%
#change to string destination
df['Dpt_Centroid_Latitude'] = df['Dpt_Centroid_Latitude'].astype(str)
df['Dpt_Centroid_Longitude'] = df['Dpt_Centroid_Longitude'].astype(str)
df["destination"] = df["Dpt_Centroid_Latitude"] + df["separador"] + df["Dpt_Centroid_Longitude"]

# %%
#combination
df['combination'] = df.index+1

# %%
df2=df
df2 = df2.reset_index(inplace=False)

# %%
# Generate lists 
combination = df2['combination'].tolist()
origin = df2['origin'].tolist()
destination = df2['destination'].tolist()

# %%
# Generate dictionary to store data
data_distance = {} 
data_models = {}

# %%
models = ['best_guess', 'pessimistic', 'optimistic']
models
# Out:
# ['best_guess', 'pessimistic', 'optimistic']

# %%
for model in models:
    
    distance_info = pd.DataFrame(np.zeros(shape=(len(combination),4), dtype =float))
    i=0    
    for c,o,d in tqdm(list(zip(combination,origin, destination))):        

        try:
            # Google MapsDdirections API endpoint
            endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

            ## Fixed Parameters
            # Paramaters

            traffic_model = model 

            # Departure time
            departure_time= 'now'

            # driving, walking, biclycling, transit
            mode = 'driving'

            # key
            api_key = 'AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg'

            # region to look for 
            region = 'pe'

             ## Parameters
            # Origin
            origin_loop = o
        
            # Destinations
            destination_loop = d
        
            #Building the URL for the request
            nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin_loop , 
                        destination_loop , departure_time , traffic_model , mode, region, api_key)
        
            # https://maps.googleapis.com/maps/api/directions/json?origin=Toledo&destination=Madrid&region=es&key=AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE
            
            # Concatenate strings
            request = endpoint + nav_request

            #Sends the request and reads the response.
            response = urllib.request.urlopen(request).read()

            #Loads response as JSON
            directions = json.loads(response)
            #print(json.dumps(directions, indent = 2))

            legs = directions['routes'][0]['legs'][0]
        
            distance_info[0][i] = c
            distance_info[1][i] = legs['distance']['text']
            distance_info[2][i] = legs['duration']['text']
            distance_info[3][i] = legs['duration_in_traffic']['text']
        
            i=i+1
    
        except Exception as e:
        
            distance_info[0][i] = c
            distance_info[1][i] = "nan"
            distance_info[2][i] = "nan"
            distance_info[3][i] = "nan"
        
            i=i+1
        
    data_models[model] = distance_info
# Out:
# <ipython-input-64-33a820a66c57>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combination,origin, destination))):
#   0%|          | 0/142 [00:00<?, ?it/s]
# <ipython-input-64-33a820a66c57>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distance_info[2][i] = legs['duration']['text']
# C:\Users\CSIESOFT\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ...

# %%
#3 TYPES OF MODELS

distance_api_best_guess = data_models['best_guess'].rename(columns={0: "index",
                                                                    1: "travel_distance_best_guess",
                                                                    2: "travel_time_best_guess",
                                                                    3: "travel_time_traffic_best_guess"}, inplace= False)

distance_api_pessimistic = data_models['pessimistic'].rename(columns={0: "index",
                                                                      1: "travel_distance_pessimistic",
                                                                      2: "travel_time_pessimistic",
                                                                      3: "travel_time_traffic_pessimistic"}, inplace= False)

distance_api_optimistic = data_models['optimistic'].rename(columns={0: "index",
                                                                    1: "travel_distance_optimistic",
                                                                    2: "travel_time_optimistic",
                                                                    3: "travel_time_traffic_optimistic"}, inplace= False)
data_models[model]
# Out:
#          0        1                2                3
# 0      1.0  71.7 km  2 hours 21 mins   2 hours 5 mins
# 1      2.0      nan              nan              nan
# 2      3.0   167 km   4 hours 7 mins    4 hours 1 min
# 3      4.0   129 km  3 hours 19 mins  3 hours 10 mins
# 4      5.0   209 km  3 hours 44 mins  3 hours 25 mins
# 5      6.0  67.7 km  2 hours 16 mins   2 hours 2 mins
# 6      7.0  57.8 km  2 hours 11 mins   1 hour 55 mins
# 7      8.0  29.3 km          35 mins          36 mins
# 8      9.0   165 km  4 hours 11 mins   4 hours 6 mins
# 9     10.0      nan              nan              nan
# 10    11.0   140 km  2 hours 44 mins  2 hours 39 mins
# 11    12.0  33.8 km          37 mins          33 mins
# 12    13.0   183 km  4 hours 55 mins  4 hours 48 mins
# 13    14.0  65.1 km   2 hours 9 mins   1 hour 54 mins
# 14    15.0      nan              nan              nan
# 15    16.0      nan              nan              nan
# ...

# %%
distance_api_best_guess
# Out:
#      index travel_distance_best_guess travel_time_best_guess  \
# 0      1.0                    71.7 km        2 hours 21 mins
# 1      2.0                        nan                    nan
# 2      3.0                     167 km         4 hours 7 mins
# 3      4.0                     129 km        3 hours 19 mins
# 4      5.0                     209 km        3 hours 44 mins
# 5      6.0                    67.7 km        2 hours 16 mins
# 6      7.0                    57.8 km        2 hours 11 mins
# 7      8.0                    29.3 km                35 mins
# 8      9.0                     165 km        4 hours 11 mins
# 9     10.0                        nan                    nan
# 10    11.0                     140 km        2 hours 44 mins
# 11    12.0                    33.8 km                37 mins
# 12    13.0                     183 km        4 hours 55 mins
# 13    14.0                    65.2 km         2 hours 8 mins
# ...

# %%
distance_api_pessimistic
# Out:
#      index travel_distance_pessimistic travel_time_pessimistic  \
# 0      1.0                     71.7 km         2 hours 21 mins
# 1      2.0                         nan                     nan
# 2      3.0                      167 km          4 hours 7 mins
# 3      4.0                      129 km         3 hours 19 mins
# 4      5.0                      209 km         3 hours 44 mins
# 5      6.0                     67.7 km         2 hours 16 mins
# 6      7.0                     57.8 km         2 hours 11 mins
# 7      8.0                     29.3 km                 35 mins
# 8      9.0                      165 km         4 hours 11 mins
# 9     10.0                         nan                     nan
# 10    11.0                      140 km         2 hours 44 mins
# 11    12.0                     33.8 km                 37 mins
# 12    13.0                      183 km         4 hours 55 mins
# 13    14.0                     65.2 km          2 hours 8 mins
# ...

# %%
distance_api_optimistic
# Out:
#      index travel_distance_optimistic travel_time_optimistic  \
# 0      1.0                    71.7 km        2 hours 21 mins
# 1      2.0                        nan                    nan
# 2      3.0                     167 km         4 hours 7 mins
# 3      4.0                     129 km        3 hours 19 mins
# 4      5.0                     209 km        3 hours 44 mins
# 5      6.0                    67.7 km        2 hours 16 mins
# 6      7.0                    57.8 km        2 hours 11 mins
# 7      8.0                    29.3 km                35 mins
# 8      9.0                     165 km        4 hours 11 mins
# 9     10.0                        nan                    nan
# 10    11.0                     140 km        2 hours 44 mins
# 11    12.0                    33.8 km                37 mins
# 12    13.0                     183 km        4 hours 55 mins
# 13    14.0                    65.1 km         2 hours 9 mins
# ...

# %%
# df FINAL
df_final = df2.merge( distance_api_best_guess , on = [ 'index'] ,how = "left" , validate = "1:1" ) \
                   .merge( distance_api_pessimistic , on = [ 'index'] , how = "left" , validate = "1:1" ) \
                   .merge( distance_api_optimistic , on = [ 'index'] , how = "left" , validate = "1:1" )
df_final
# Out:
#      index Department_univ     Province_univ  \
# 0        0            Lima              Lima
# 1        1        Ayacucho          Huamanga
# 2        2           Cusco             Cusco
# 3        3     La Libertad          Trujillo
# 4        4        Arequipa          Arequipa
# 5        5            Lima              Lima
# 6        6            Lima              Lima
# 7        7             Ica               Ica
# 8        8           Junin          Huancayo
# 9        9          Loreto            Maynas
# 10      10            Puno              Puno
# 11      11           Piura             Piura
# 12      12       Cajamarca         Cajamarca
# 13      13            Lima              Lima
# 14      14         Huanuco     Leoncio Prado
# 15      15         Huanuco           Huánuco
# 16      16            Lima              Lima
# 17      17           Pasco             Pasco
# 18      18          Callao            Callao
# 19      19            Lima            Huaura
# ...
