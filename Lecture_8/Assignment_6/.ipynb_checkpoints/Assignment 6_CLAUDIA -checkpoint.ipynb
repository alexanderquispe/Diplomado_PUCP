# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )

url = 'https://www.sunedu.gob.pe/lista-universidades/'
driver.get( url )

driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# There is no [win32] chromedriver for browser  in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Claudia\.wdm\drivers\chromedriver\win32\97.0.4692.71]
# <ipython-input-3-9db1c8016f6c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %% [markdown]
# 1. Search for public universities information

# %%
public = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[1]/a" ) 
public.click()
# Out:
# <ipython-input-9-bb4dd3303fa1>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   public = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[1]/a" )

# %%
public.text
# Out:
# 'Universidades Públicas'

# %%
table_path = driver.find_element_by_id( "tablepress-22_wrapper" )
# Out:
# <ipython-input-13-8e76a3a8f546>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_id( "tablepress-22_wrapper" )

# %%
table_html = table_path.get_attribute( 'innerHTML' )

# %%
table_public = pd.read_html( table_html )
table_public
# Out:
# [    N°                                        UNIVERSIDAD   DEPARTAMENTO  \
#  0    1           Universidad Nacional Mayor de San Marcos           Lima
#  1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
#  2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
#  3    4                   Universidad Nacional de Trujillo    La Libertad
#  4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
#  5    6                 Universidad Nacional de Ingeniería           Lima
#  6    7             Universidad Nacional Agraria La Molina           Lima
#  7    8              Universidad Nacional San Luis Gonzaga            Ica
#  8    9           Universidad Nacional del Centro del Perú          Junín
#  9   10        Universidad Nacional de la Amazonía Peruana         Loreto
#  10  11                 Universidad Nacional del Altiplano           Puno
#  11  12                      Universidad Nacional de Piura          Piura
# ...

# %%
clean_table_public = table_public [0]

# %%
clean_table_public
# Out:
#     N°                                        UNIVERSIDAD   DEPARTAMENTO  \
# 0    1           Universidad Nacional Mayor de San Marcos           Lima
# 1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
# 2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
# 3    4                   Universidad Nacional de Trujillo    La Libertad
# 4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
# 5    6                 Universidad Nacional de Ingeniería           Lima
# 6    7             Universidad Nacional Agraria La Molina           Lima
# 7    8              Universidad Nacional San Luis Gonzaga            Ica
# 8    9           Universidad Nacional del Centro del Perú          Junín
# 9   10        Universidad Nacional de la Amazonía Peruana         Loreto
# 10  11                 Universidad Nacional del Altiplano           Puno
# 11  12                      Universidad Nacional de Piura          Piura
# ...

# %%
clean_table_public[ 'TIPO' ] = "Universidad publica"

# %%
clean_table_public
# Out:
#     N°                                        UNIVERSIDAD   DEPARTAMENTO  \
# 0    1           Universidad Nacional Mayor de San Marcos           Lima
# 1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
# 2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
# 3    4                   Universidad Nacional de Trujillo    La Libertad
# 4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
# 5    6                 Universidad Nacional de Ingeniería           Lima
# 6    7             Universidad Nacional Agraria La Molina           Lima
# 7    8              Universidad Nacional San Luis Gonzaga            Ica
# 8    9           Universidad Nacional del Centro del Perú          Junín
# 9   10        Universidad Nacional de la Amazonía Peruana         Loreto
# 10  11                 Universidad Nacional del Altiplano           Puno
# 11  12                      Universidad Nacional de Piura          Piura
# ...

# %% [markdown]
# 2. Search for private universities information

# %%
private = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]/a" ) 
private.click()
# Out:
# <ipython-input-25-f3b978959a91>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   private = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]/a" )

# %%
private.text
# Out:
# 'Universidades Privadas'

# %%
table_path_private = driver.find_element_by_id( "tablepress-23_wrapper" )
# Out:
# <ipython-input-33-0952844ebf8f>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path_private = driver.find_element_by_id( "tablepress-23_wrapper" )

# %%
table_html_private = table_path_private.get_attribute( 'innerHTML' )

# %%
table_private = pd.read_html( table_html_private  )
table_private
# Out:
# [    N°                                        UNIVERSIDAD DEPARTAMENTO  \
#  0    1           Pontificia Universidad Católica del Perú         Lima
#  1    2               Universidad Peruana Cayetano Heredia         Lima
#  2    3                Universidad Católica de Santa María     Arequipa
#  3    4                           Universidad del Pacífico         Lima
#  4    5                                Universidad de Lima         Lima
#  ..  ..                                                ...          ...
#  87  88  Universidad Santo Tomás de Aquino de Ciencia e...        Junín
#  88  89                           Universidad Privada SISE         Lima
#  89  90     Universidad Seminario Evangélico de Lima (*12)         Lima
#  90  91         Universidad Seminario Bíblico Andino (*12)         Lima
#  91  92                      Universidad Católica San José         Lima
#
#     PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
clean_table_private = table_private [0]

# %%
clean_table_private[ 'TIPO' ] = "Universidad privada"
clean_table_private
# Out:
#     N°                                        UNIVERSIDAD DEPARTAMENTO  \
# 0    1           Pontificia Universidad Católica del Perú         Lima
# 1    2               Universidad Peruana Cayetano Heredia         Lima
# 2    3                Universidad Católica de Santa María     Arequipa
# 3    4                           Universidad del Pacífico         Lima
# 4    5                                Universidad de Lima         Lima
# ..  ..                                                ...          ...
# 87  88  Universidad Santo Tomás de Aquino de Ciencia e...        Junín
# 88  89                           Universidad Privada SISE         Lima
# 89  90     Universidad Seminario Evangélico de Lima (*12)         Lima
# 90  91         Universidad Seminario Bíblico Andino (*12)         Lima
# 91  92                      Universidad Católica San José         Lima
#
#    PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %% [markdown]
# 3. Merge the public and private universities information

# %%
Universities = pd.concat([clean_table_public, clean_table_private])

# %%
Universities
# Out:
#     N°                                        UNIVERSIDAD DEPARTAMENTO  \
# 0    1           Universidad Nacional Mayor de San Marcos         Lima
# 1    2  Universidad Nacional de San Cristóbal de Huamanga     Ayacucho
# 2    3  Universidad Nacional de San Antonio Abad del C...        Cusco
# 3    4                   Universidad Nacional de Trujillo  La Libertad
# 4    5    Universidad Nacional de San Agustín de Arequipa     Arequipa
# ..  ..                                                ...          ...
# 87  88  Universidad Santo Tomás de Aquino de Ciencia e...        Junín
# 88  89                           Universidad Privada SISE         Lima
# 89  90     Universidad Seminario Evangélico de Lima (*12)         Lima
# 90  91         Universidad Seminario Bíblico Andino (*12)         Lima
# 91  92                      Universidad Católica San José         Lima
#
#    PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
Universities.to_csv('Universities.csv')

# %% [markdown]
# Use Google API Geocoding to geolocate universities and get universities' latitude and longitude. Name these new variables as Latitude_univ and Longitude_univ. Use Department, province, and university name variables to get the most accurate results. Moreover, restrict the geolocation to Peru (PE).

# %%
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
import pandas as pd
import csv
import datetime
import dateutil.parser
import unicodedata
import time
import requests
import chardet
import googlemaps
from datetime import datetime

# %%
rawdata = open('C:/Users/Claudia/Documents/GitHub/Diplomado_PUCP/_data/Universities.csv', 'rb').read()
result = chardet.detect(rawdata)
result
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
charenc = result['encoding']
print(charenc)
# Out:
# utf-8

# %%
GEO_UNIV = pd.read_csv( 'C:/Users/Claudia/Documents/GitHub/Diplomado_PUCP/_data/Universities.csv' , delimiter = ',' , encoding = charenc )

# %%
GEO_UNIV
# Out:
#      Unnamed: 0  N°                                        UNIVERSIDAD  \
# 0             0   1           Universidad Nacional Mayor de San Marcos
# 1             1   2  Universidad Nacional de San Cristóbal de Huamanga
# 2             2   3  Universidad Nacional de San Antonio Abad del C...
# 3             3   4                   Universidad Nacional de Trujillo
# 4             4   5    Universidad Nacional de San Agustín de Arequipa
# ..          ...  ..                                                ...
# 138          87  88  Universidad Santo Tomás de Aquino de Ciencia e...
# 139          88  89                           Universidad Privada SISE
# 140          89  90     Universidad Seminario Evangélico de Lima (*12)
# 141          90  91         Universidad Seminario Bíblico Andino (*12)
# 142          91  92                      Universidad Católica San José
#
#     DEPARTAMENTO PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
GEO_UNIV["DIRECCION"] = GEO_UNIV["UNIVERSIDAD"] + " " + GEO_UNIV["DEPARTAMENTO"] + " " + GEO_UNIV["PROVINCIA"]
GEO_UNIV
# Out:
#      Unnamed: 0  N°                                        UNIVERSIDAD  \
# 0             0   1           Universidad Nacional Mayor de San Marcos
# 1             1   2  Universidad Nacional de San Cristóbal de Huamanga
# 2             2   3  Universidad Nacional de San Antonio Abad del C...
# 3             3   4                   Universidad Nacional de Trujillo
# 4             4   5    Universidad Nacional de San Agustín de Arequipa
# ..          ...  ..                                                ...
# 138          87  88  Universidad Santo Tomás de Aquino de Ciencia e...
# 139          88  89                           Universidad Privada SISE
# 140          89  90     Universidad Seminario Evangélico de Lima (*12)
# 141          90  91         Universidad Seminario Bíblico Andino (*12)
# 142          91  92                      Universidad Católica San José
#
#     DEPARTAMENTO PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
coord = np.zeros(shape=( GEO_UNIV["DIRECCION"].shape[0] , 2), dtype = float )

i=0

gmaps = googlemaps.Client(key='AIzaSyCDr79v4CHSAmF-drAZQqtR_Bh2gIFr1wo')

for index, row in tqdm(GEO_UNIV.iterrows()):   

    # Geocoding an address
    geocode_result = gmaps.geocode( row['DIRECCION'] , region='pe')
    if len(geocode_result)==0 :
        coord[i][0] = "nan"
        coord[i][1] = "nan"
        
        i=i+1
        
        print(row['DIRECCION'])
        print("el codigo encontro error")
        
    else :
        coord[i][0]=geocode_result[0]['geometry']['location']['lat']
        coord[i][1]=geocode_result[0]['geometry']['location']['lng']
        i=i+1
# Out:
# <ipython-input-61-39f3af36f4f7>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm(GEO_UNIV.iterrows()):
# 0it [00:00, ?it/s]
# Universidad ESAN Lima Lima
# el codigo encontro error

# %%
coord
# Out:
# array([[-12.0561578, -77.0845196],
#        [-13.1612479, -74.2257722],
#        [-13.52193  , -71.9583208],
#        [ -8.1150074, -79.0383048],
#        [-16.3971385, -71.5371437],
#        [-12.0231787, -77.0476301],
#        [-12.0817493, -76.9431895],
#        [-14.0871322, -75.7335148],
#        [-12.0330575, -75.2373567],
#        [ -3.7459891, -73.2456994],
#        [-15.8243805, -70.0162544],
#        [ -5.179311 , -80.6188325],
#        [ -7.167159 , -78.4965043],
#        [-12.0475555, -77.0404519],
#        [ -9.3140208, -75.9966689],
#        [ -9.9492894, -76.2503248],
#        [-12.0663015, -76.9537651],
#        [-10.668422 , -76.254234 ],
#        [-12.0613052, -77.1172487],
#        [-11.1239202, -77.6082465],
#        [ -6.7077407, -79.9042231],
#        [-18.0249985, -70.2505346],
#        [ -9.5212334, -77.5287365],
#        [-34.5789316, -58.526188 ],
#        [ -8.3949316, -74.5776011],
#        [ -3.585267 , -80.443305 ],
#        [ -9.1208895, -78.5133316],
# ...

# %%
GEO_UNIV[ [ 'latitude' , 'longitude' ] ] = pd.DataFrame( coord.tolist(), index = GEO_UNIV.index )
GEO_UNIV
# Out:
#      Unnamed: 0  N°                                        UNIVERSIDAD  \
# 0             0   1           Universidad Nacional Mayor de San Marcos
# 1             1   2  Universidad Nacional de San Cristóbal de Huamanga
# 2             2   3  Universidad Nacional de San Antonio Abad del C...
# 3             3   4                   Universidad Nacional de Trujillo
# 4             4   5    Universidad Nacional de San Agustín de Arequipa
# ..          ...  ..                                                ...
# 138          87  88  Universidad Santo Tomás de Aquino de Ciencia e...
# 139          88  89                           Universidad Privada SISE
# 140          89  90     Universidad Seminario Evangélico de Lima (*12)
# 141          90  91         Universidad Seminario Bíblico Andino (*12)
# 142          91  92                      Universidad Católica San José
#
#     DEPARTAMENTO PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
GEO_UNIV.to_csv ( r"GEO_UNIV.csv", index = False, header = True)
