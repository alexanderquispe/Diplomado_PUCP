# %% [markdown]
# # Assigment 6

# %%
# Packages
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time
import requests
#To geocode using googlemaps
# !pip install googlemaps
import googlemaps
from datetime import datetime
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in d:\2software-estadistica\anaconda\lib\site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\2software-estadistica\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\2software-estadistica\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\2software-estadistica\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\2software-estadistica\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.11.17)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=69d79af3682ee26f344425a0787dd4ac0f153440f6d9cc5f9cae769bfd63436f
#   Stored in directory: c:\users\andrev\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %% [markdown]
# ## 1.  Import data

# %%
#we import the xlsx file containing the bbva offices's address as a data frame
data_bbva = pd.read_excel( r"../../_data/bbva_list.xlsx" )

# %%
data_bbva
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# 11      AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSIO         LIMA      LIMA
# 12                        KM. 25 CARRETERA VENTANILLA         LIMA      LIMA
# 13           MALECdN ANDRAS A. CACERES MZ C-3, LT. 19         LIMA      LIMA
# 14  AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...         LIMA      LIMA
# 15                 AV. LOS PARACAS 203 URB. SALAMANCA         LIMA      LIMA
# 16                       AV. NICOLAS AYLLON 2032-2036         LIMA      LIMA
# 17          LOCAL LS-201 - AV. NICOLAS AYLL6N N° 4770         LIMA      LIMA
# 18                    AV. NICOLAS AYLLON 8694, LC-105         LIMA      LIMA
# 19                                   AV. PROGRESO 102         LIMA      LIMA
# 20  AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...         LIMA      LIMA
# 21                      AV. GRAU 414 ESQ. CALLE UNION         LIMA      LIMA
# 22                                  PLAZA BUTTERS 301         LIMA      LIMA
# 23                                  AV. VENEZUELA 635         LIMA      LIMA
# 24                                 AV. VENEZUELA 1254         LIMA      LIMA
# 25                                     JR. HUARAZ1600         LIMA      LIMA
# 26      AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTOR         LIMA      LIMA
# 27  AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARC...         LIMA      LIMA
# 28  AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...         LIMA      LIMA
# 29                      AV. MALECON DE LA RIBERA S/N.         LIMA      LIMA
# 30  AV. PROLG. PASEO DE LA REPllBLICA S/N - CCPLAZ...         LIMA      LIMA
# 31                          AV. GUARDIA CIVIL 152-156         LIMA      LIMA
# 32                            AV. TUPAC AMARU N° 1175         LIMA      LIMA
# 33  AV. UNIVERSITARIA NORTE 7103, MZ. H LT. 22, UR...         LIMA      LIMA
# 34  AV. UNIVERSITARIA 10583-10587, MZ. X LT. 3 -SE...         LIMA      LIMA
# 35  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R...         LIMA      LIMA
# 36        AV. RIVA AG0ER01400-1404-1406, MZ. C LT. 27         LIMA      LIMA
# 37  AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...         LIMA      LIMA
# 38                       AV. CARLOS IZAGUIRRE N.- 275         LIMA      LIMA
# 39  CRUCE AV. TOMAS VALLE CON PANAMERICANA NORTE, ...         LIMA      LIMA
# 40  AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...         LIMA      LIMA
# 41  CALLE HUAMACHUC01301-1307-1309, ESQ. CON REPll...         LIMA      LIMA
# 42                        AV. REP. DOMINICANA 355-359         LIMA      LIMA
# 43           AV. GENERAL FELIPE SALAVERRY 2370, LS-04         LIMA      LIMA
# 44                     RESIDENCIAL SAN FELIPE TDA. 23         LIMA      LIMA
# 45                   AV. PROL. JAVIER PRADO ESTE 4921         LIMA      LIMA
# 46  AV. RICARDO E. APARICIO 675, MZ. H LT. 1 -URB....         LIMA      LIMA
# 47      CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO         LIMA      LIMA
# 48  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...         LIMA      LIMA
# 49   AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTANA         LIMA      LIMA
# 50                             AV. LA UNIVERSIDAD1810         LIMA      LIMA
# 51                                  AV. LA MOLINA 540         LIMA      LIMA
#
#          DISTRITO
# 0          CALLAO
# 1          CALLAO
# 2          CALLAO
# 3          CALLAO
# 4          CALLAO
# 5          CALLAO
# 6          CALLAO
# 7          CALLAO
# 8          CALLAO
# 9          CALLAO
# 10     BELLAVISTA
# 11       LA PERLA
# 12     VENTANILLA
# 13     VENTANILLA
# 14            ATE
# 15            ATE
# 16            ATE
# 17            ATE
# 18            ATE
# 19            ATE
# 20            ATE
# 21       BARRANCO
# 22       BARRANCO
# 23         BREfiA
# 24          BRENA
# 25          BRENA
# 26     CARABAYLLO
# 27     CHORRILLOS
# 28     CHORRILLOS
# 29     CHORRILLOS
# 30     CHORRILLOS
# 31     CHORRILLOS
# 32          COMAS
# 33          COMAS
# 34          COMAS
# 35          COMAS
# 36     ELAGUSTINO
# 37  INDEPENDENCIA
# 38  INDEPENDENCIA
# 39  INDEPENDENCIA
# 40    JESUS MARIA
# 41    JESUS MARIA
# 42    JESUS MARIA
# 43    JESUS MARIA
# 44    JESUS MARIA
# 45      LA MOLINA
# 46      LA MOLINA
# 47      LA MOLINA
# 48      LA MOLINA
# 49      LA MOLINA
# 50      LA MOLINA
# 51      LA MOLINA

# %% [markdown]
# ## 2. Use GoogleMaps API and geocode all the BBVA offices.

# %% [markdown]
# We test an adress to detect any possible error when not specifying the district in the geocoding process

# %%
API_key = 'AIzaSyDHj-d_wN2pzXcGtDTj87WgwZkQ-OlTJqU'
gmaps = googlemaps.Client(key=API_key)

# %%
geocode_test = gmaps.geocode( "AV. SAENZ PEN A 323" , region='pe')
geocode_test[0]['formatted_address']
# Out:
# 'Av. Sáenz, C1437 CABA, Argentina'

# %% [markdown]
# Even if we specify we want a search on the peruvian region, we may obtain results from other countries if we are not specific enough. To avoid this issues we create a new column in the data frame joining the original adress with its district.

# %%
data_bbva['direccion_comp'] = data_bbva['Direccion'] + ", " + data_bbva['DISTRITO']

# %%
data_bbva
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# 11      AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSI
OCAL LS-201 - AV. NICOLAS AYLL6N N° 4770, ATE
# 18            ATE               AV. NICOLAS AYLLON 8694, LC-105, ATE
# 19            ATE                              AV. PROGRESO 102, ATE
# 20            ATE  AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...
# 21       BARRANCO            AV. GRAU 414 ESQ. CALLE UNION, BARRANCO
# 22       BARRANCO                        PLAZA BUTTERS 301, BARRANCO
# 23         BREfiA                          AV. VENEZUELA 635, BREfiA
# 24          BRENA                          AV. VENEZUELA 1254, BRENA
# 25          BRENA                              JR. HUARAZ1600, BRENA
# 26     CARABAYLLO  AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTOR,...
# 27     CHORRILLOS  AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARC...
# 28     CHORRILLOS  AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...
# 29     CHORRILLOS          AV. MALECON DE LA RIBERA S/N., CHORRILLOS
# 30     CHORRILLOS  AV. PROLG. PASEO DE LA REPllBLICA S/N - CCPLAZ...
# 31     CHORRILLOS              AV. GUARDIA CIVIL 152-156, CHORRILLOS
# 32          COMAS                     AV. TUPAC AMARU N° 1175, COMAS
# 33          COMAS  AV. UNIVERSITARIA NORTE 7103, MZ. H LT. 22, UR...
# 34          COMAS  AV. UNIVERSITARIA 10583-10587, MZ. X LT. 3 -SE...
# 35          COMAS  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R...
# 36     ELAGUSTINO  AV. RIVA AG0ER01400-1404-1406, MZ. C LT. 27, E...
# 37  INDEPENDENCIA  AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...
# 38  INDEPENDENCIA        AV. CARLOS IZAGUIRRE N.- 275, INDEPENDENCIA
# 39  INDEPENDENCIA  CRUCE AV. TOMAS VALLE CON PANAMERICANA NORTE, ...
# 40    JESUS MARIA  AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...
# 41    JESUS MARIA  CALLE HUAMACHUC01301-1307-1309, ESQ. CON REPll...
# 42    JESUS MARIA           AV. REP. DOMINICANA 355-359, JESUS MARIA
# 43    JESUS MARIA  AV. GENERAL FELIPE SALAVERRY 2370, LS-04, JESU...
# 44    JESUS MARIA        RESIDENCIAL SAN FELIPE TDA. 23, JESUS MARIA
# 45      LA MOLINA        AV. PROL. JAVIER PRADO ESTE 4921, LA MOLINA
# 46      LA MOLINA  AV. RICARDO E. APARICIO 675, MZ. H LT. 1 -URB....
# 47      LA MOLINA  CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO,...
# 48      LA MOLINA  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...
# 49      LA MOLINA  AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTA...
# 50      LA MOLINA                  AV. LA UNIVERSIDAD1810, LA MOLINA
# 51      LA MOLINA                       AV. LA MOLINA 540, LA MOLINA

# %% [markdown]
# Now when we try geocoding the same address adding the district we get a precise result

# %%
geocode_test2 = gmaps.geocode( "AV. SAENZ PEN A 323, CALLAO" , region='pe')
geocode_test2[0]['formatted_address']
# Out:
# 'Av Saenz Peña 323, Callao 07021, Peru'

# %% [markdown]
# To automate the process we will iterate the geocoding of every complete address in the data frame, extracting the latitude and longitude in new columns

# %%
gmaps = googlemaps.Client(key=API_key)

# We add empty columns for latitude and longitude
data_bbva['latitude'] = None
data_bbva['longitude'] = None
data_bbva['combination']= None
# We iterate the geocode on every direction of the data frame
for index, row in data_bbva.iterrows():
    try:
        #geocode
        geocode_result = gmaps.geocode(row['direccion_comp'], region='pe')
        if geocode_result:
            latitude = geocode_result[0]['geometry']['location']['lat']
            longitude = geocode_result[0]['geometry']['location']['lng']
            # Store in the DataFrame
            data_bbva.at[index, 'latitude'] = latitude
            data_bbva.at[index, 'longitude'] = longitude
            data_bbva.at[index,'combination'] = index+1
    except Exception as e:
        print(f"Error geocoding address  {index}: {e}")

# %%
# We concatenate the latitude and longitud as the destination 
data_bbva['destination'] = data_bbva['latitude'].astype(str) + ',' + data_bbva['longitude'].astype(str)

# %%
data_bbva.head(3)
# Out:
#                                            Direccion DEPARTAMENTO PROVINCIA  \
# 0       CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                    AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
#
#   DISTRITO                                     direccion_comp   latitude  \
# 0   CALLAO  CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, ... -12.050849
# 1   CALLAO            AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO -12.050849
# 2   CALLAO  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN... -12.031314
#
#    longitude combination              destination
# 0 -77.125984           1  -12.0508491,-77.1259843
# 1 -77.125984           2  -12.0508491,-77.1259843
# 2 -77.101343           3   -12.0313137,-77.101343

# %% [markdown]
# ## 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.

# %% [markdown]
# We create a new data frame with the members addresses longitude and latitude

# %%
#mauricios address as origin desination
geocode_mau = gmaps.geocode( "AV. Pablo Carriquiry 855, San Isidro" , region='pe')
lat_mauricio = geocode_mau[0]['geometry']['location']['lat']
lng_mauricio = geocode_mau[0]['geometry']['location']['lng']
origin_mauricio = str(lat_mauricio) + ',' + str(lng_mauricio)

#dm address as origin desination
geocode_dm = gmaps.geocode( "AV. Salaverry 2180, Jesus Maria" , region='pe')
lat_dm = geocode_dm[0]['geometry']['location']['lat']
lng_dm = geocode_dm[0]['geometry']['location']['lng']
origin_dm = str(lat_dm) + ',' + str(lng_dm)

#Angie Quispe address as origin desination
geocode_angie = gmaps.geocode( "Jr. Callao 448, Chosica" , region='pe')
lat_angie = geocode_angie[0]['geometry']['location']['lat']
lng_angie = geocode_angie[0]['geometry']['location']['lng']
origin_angie = str(lat_angie) + ',' + str(lng_angie)

#Andre Visurraga's address as origin desination
geocode_andre = gmaps.geocode( "Clle. Saturno 112, Los Olivos" , region='pe')
lat_andre = geocode_angie[0]['geometry']['location']['lat']
lng_andre = geocode_angie[0]['geometry']['location']['lng']
origin_andre = str(lat_andre) + ',' + str(lng_andre)

# %%
# Create a new DataFrame
routes_bbva = data_bbva.copy()
# Add a new column with mauricio's latitude and longitude
routes_bbva['origin_mauricio'] = origin_mauricio
routes_bbva['origin_dm'] = origin_dm
routes_bbva['origin_angie'] = origin_angie
routes_bbva['origin_andre'] = origin_andre

# %%
routes_bbva
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# 11      AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSIO         LIMA      LIMA
# 12                        KM. 25 CARRETERA VENTANILLA         LIMA      LIMA
# 13           MALECdN ANDRAS A. CACERES MZ C-3, LT. 19         LIMA      LIMA
# 14  AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...         LIMA      LIMA
# 15                 AV. LOS PARACAS 203 URB. SALAMANCA         LIMA      LIMA
# 16                       AV. NICOLAS AYLLON 2032-2036         LIMA      LIMA
# 17          LOCAL LS-201 - AV. NICOLAS AYLL6N N° 4
# 40  -11.934801,-76.6969165  -11.934801,-76.6969165
# 41  -11.934801,-76.6969165  -11.934801,-76.6969165
# 42  -11.934801,-76.6969165  -11.934801,-76.6969165
# 43  -11.934801,-76.6969165  -11.934801,-76.6969165
# 44  -11.934801,-76.6969165  -11.934801,-76.6969165
# 45  -11.934801,-76.6969165  -11.934801,-76.6969165
# 46  -11.934801,-76.6969165  -11.934801,-76.6969165
# 47  -11.934801,-76.6969165  -11.934801,-76.6969165
# 48  -11.934801,-76.6969165  -11.934801,-76.6969165
# 49  -11.934801,-76.6969165  -11.934801,-76.6969165
# 50  -11.934801,-76.6969165  -11.934801,-76.6969165
# 51  -11.934801,-76.6969165  -11.934801,-76.6969165

# %% [markdown]
# We create a function to calculate the distance and time to get from the origin to a destination and iterate it to every row of the data frame.

# %%
#we define the function to calculate the distance and time to get from the origin to the destination
def get_distance_and_time(origin, destination, api_key):
    endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'
    params = {
        'origin': origin,
        'destination': destination,
        'key': api_key,
        'traffic_model': 'best_guess',  # We include the traffic model in the request
        'departure_time': 'now',  # We specify departure time
        'mode': 'driving'  # We specify the mode of transportation
    }
    response = requests.get(endpoint, params=params)
    directions = response.json()
    
    if directions['status'] == 'OK':
        route = directions['routes'][0]
        leg = route['legs'][0]
        distance_meters = leg['distance']['value']
        duration_seconds = leg['duration']['value']
        return distance_meters, duration_seconds
    else:
        return None, None

# We add new columns for distance and time
routes_bbva['distance_meters_mauricio'] = None
routes_bbva['duration_seconds_mauricio'] = None

routes_bbva['distance_meters_dm'] = None
routes_bbva['duration_seconds_dm'] = None

routes_bbva['distance_meters_angie'] = None
routes_bbva['duration_seconds_angie'] = None

routes_bbva['distance_meters_andre'] = None
routes_bbva['duration_seconds_andre'] = None

# We calculate the distance and time for each row in the DataFrame
for index, row in routes_bbva.iterrows():
    distance_meters, duration_seconds = get_distance_and_time(row['origin_mauricio'], row['destination'], API_key)
    
    routes_bbva.at[index, 'distance_meters_mauricio'] = distance_meters
    routes_bbva.at[index, 'duration_seconds_mauricio'] = duration_seconds
    
    distance_meters, duration_seconds = get_distance_and_time(row['origin_dm'], row['destination'], API_key)

    routes_bbva.at[index, 'distance_meters_dm'] = distance_meters
    routes_bbva.at[index, 'duration_seconds_dm'] = duration_seconds
    
    distance_meters, duration_seconds = get_distance_and_time(row['origin_angie'], row['destination'], API_key)

    routes_bbva.at[index, 'distance_meters_angie'] = distance_meters
    routes_bbva.at[index, 'duration_seconds_angie'] = duration_seconds

    distance_meters, duration_seconds = get_distance_and_time(row['origin_andre'], row['destination'], API_key)

    routes_bbva.at[index, 'distance_meters_andre'] = distance_meters
    routes_bbva.at[index, 'duration_seconds_andre'] = duration_seconds

# %% [markdown]
# ## 4. Reporte

# %%
routes_bbva_sorted_time = routes_bbva.sort_values(by='duration_seconds_mauricio')
routes_bbva_sorted_distance = routes_bbva.sort_values(by='distance_meters_mauricio')
print(f"Para Mauricio la agencia más cercana en tiempo es {routes_bbva_sorted_time['direccion_comp'].iloc[0]}, "
    f"con una duración de {routes_bbva_sorted_time['duration_seconds_mauricio'].iloc[0]} segundos, "
    f"y la agencia más cercana en metros es {routes_bbva_sorted_distance['direccion_comp'].iloc[0]}, "
    f"con una distancia de {routes_bbva_sorted_distance['distance_meters_mauricio'].iloc[0]} metros.")
# Out:
# Para Mauricio la agencia más cercana en tiempo es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una duración de None segundos, y la agencia más cercana en metros es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una distancia de None metros.

# %%
routes_bbva_sorted_time = routes_bbva.sort_values(by='duration_seconds_angie')
routes_bbva_sorted_distance = routes_bbva.sort_values(by='distance_meters_angie')
print(f"Para Angie la agencia más cercana en tiempo es {routes_bbva_sorted_time['direccion_comp'].iloc[0]}, "
    f"con una duración de {routes_bbva_sorted_time['duration_seconds_angie'].iloc[0]} segundos, "
    f"y la agencia más cercana en metros es {routes_bbva_sorted_distance['direccion_comp'].iloc[0]}, "
    f"con una distancia de {routes_bbva_sorted_distance['distance_meters_angie'].iloc[0]} metros.")
# Out:
# Para Angie la agencia más cercana en tiempo es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una duración de None segundos, y la agencia más cercana en metros es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una distancia de None metros.

# %%
routes_bbva_sorted_time = routes_bbva.sort_values(by='duration_seconds_dm')
routes_bbva_sorted_distance = routes_bbva.sort_values(by='distance_meters_dm')
print(f"Para Daniel M la agencia más cercana en tiempo es {routes_bbva_sorted_time['direccion_comp'].iloc[0]}, "
    f"con una duración de {routes_bbva_sorted_time['duration_seconds_dm'].iloc[0]} segundos, "
    f"y la agencia más cercana en metros es {routes_bbva_sorted_distance['direccion_comp'].iloc[0]}, "
    f"con una distancia de {routes_bbva_sorted_distance['distance_meters_d'].iloc[0]} metros.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\2Software-Estadistica\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File D:\2Software-Estadistica\Anaconda\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\2Software-Estadistica\Anaconda\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'distance_meters_d'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 6
#       1 routes_bbva_sorted_time = routes_bbva.sort_values(by='duration_seconds_dm')
#       2 routes_bbva_sorted_distance = routes_bbva.sort_values(by='distance_meters_dm')
#       3 print(f"Para Daniel M la agencia más cercana en tiempo es {routes_bbva_sorted_time['direccion_comp'].iloc[0]}, "
#       4     f"con una duración de {routes_bbva_sorted_time['duration_seconds_dm'].iloc[0]} segundos, "
#       5     f"y la agencia más cercana en metros es {routes_bbva_sorted_distance['direccion_comp'].iloc[0]}, "
# ----> 6     f"con una distancia de {routes_bbva_sorted_distance['distance_meters_d'].iloc[0]} metros.")
#
# File D:\2Software-Estadistica\Anaconda\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File D:\2Software-Estadistica\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'distance_meters_d'

# %%
routes_bbva_sorted_time = routes_bbva.sort_values(by='duration_seconds_andre')
routes_bbva_sorted_distance = routes_bbva.sort_values(by='distance_meters_andre')
print(f"Para Andre la agencia más cercana en tiempo es {routes_bbva_sorted_time['direccion_comp'].iloc[0]}, "
    f"con una duración de {routes_bbva_sorted_time['duration_seconds_andre'].iloc[0]} segundos, "
    f"y la agencia más cercana en metros es {routes_bbva_sorted_distance['direccion_comp'].iloc[0]}, "
    f"con una distancia de {routes_bbva_sorted_distance['distance_meters_andre'].iloc[0]} metros.")
# Out:
# Para Andre la agencia más cercana en tiempo es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una duración de None segundos, y la agencia más cercana en metros es CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, CALLAO, con una distancia de None metros.
