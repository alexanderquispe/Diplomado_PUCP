# %% [markdown]
# ### Assigment 6

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import googlemaps
import json
import pprint
from datetime import datetime
from tqdm import tqdm_notebook as tqdm
import urllib.request, json, csv
import unicodedata

# %% [markdown]
# ### We scrap the page

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )

url = 'https://www.sunedu.gob.pe/lista-universidades/'
driver.get( url )

driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\a-pal\.wdm\drivers\chromedriver\win32\97.0.4692.71]
# <ipython-input-2-9db1c8016f6c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %%
unis_publicas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[1]/div" )
table_unis_publicas = unis_publicas.get_attribute( 'innerHTML' )
table = pd.read_html( table_unis_publicas )[0]
table
# Out:
# <ipython-input-3-af33b9e441cb>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   unis_publicas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[1]/div" )
#     N°                                        UNIVERSIDAD   DEPARTAMENTO  \
# 0    1           Universidad Nacional Mayor de San Marcos           Lima
# 1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
# 2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
# 3    4                   Universidad Nacional de Trujillo    La Libertad
# 4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
# 5    6                 Universidad Nacional de Ingeniería           Lima
# 6    7             Universidad Nacional Agraria La Molina           Lima
# 7    8              Universidad Nacional San Luis Gonzaga            Ica
# ...

# %%
table1 = table.iloc[ : ,[2, 3, 1]]
cols = table1.select_dtypes(include=[np.object]).columns
table1[cols] = table1[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
table1
# Out:
# <ipython-input-4-085105a6f159>:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cols = table1.select_dtypes(include=[np.object]).columns
# C:\Users\a-pal\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      DEPARTAMENTO         PROVINCIA  \
# 0            Lima              Lima
# 1        Ayacucho          Huamanga
# 2           Cusco             Cusco
# 3     La Libertad          Trujillo
# ...

# %% [markdown]
# # Extraction and cleaning of the private universities table

# %%
unis_privadas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]" )
unis_privadas.click()
unis_privadas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[2]/div" )
table_unis_privadas = unis_privadas.get_attribute( 'innerHTML' )
table2 = pd.read_html( table_unis_privadas )[0]
cols = table2.select_dtypes(include=[np.object]).columns
table2[cols] = table2[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
table2
# Out:
# <ipython-input-5-2ea9011b36d5>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   unis_privadas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]" )
# <ipython-input-5-2ea9011b36d5>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   unis_privadas = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[2]/div" )
# <ipython-input-5-2ea9011b36d5>:6: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cols = table2.select_dtypes(include=[np.object]).columns
#     N°                                        UNIVERSIDAD DEPARTAMENTO  \
# ...

# %%
table3 = table2.iloc[ : ,[2, 3, 1]]
table3
# Out:
#    DEPARTAMENTO PROVINCIA                                        UNIVERSIDAD
# 0          Lima      Lima           Pontificia Universidad Catolica del Peru
# 1          Lima      Lima               Universidad Peruana Cayetano Heredia
# 2      Arequipa  Arequipa                Universidad Catolica de Santa Maria
# 3          Lima      Lima                           Universidad del Pacifico
# 4          Lima      Lima                                Universidad de Lima
# ..          ...       ...                                                ...
# 87        Junin  Huancayo  Universidad Santo Tomas de Aquino de Ciencia e...
# 88         Lima      Lima                           Universidad Privada SISE
# 89         Lima      Lima     Universidad Seminario Evangelico de Lima (*12)
# 90         Lima      Lima         Universidad Seminario Biblico Andino (*12)
# 91         Lima      Lima                      Universidad Catolica San Jose
#
# [92 rows x 3 columns]

# %% [markdown]
# # Merging both tables

# %%
table4 = pd.concat([table1, table3])
table4
# Out:
#    DEPARTAMENTO PROVINCIA                                        UNIVERSIDAD
# 0          Lima      Lima           Universidad Nacional Mayor de San Marcos
# 1      Ayacucho  Huamanga  Universidad Nacional de San Cristobal de Huamanga
# 2         Cusco     Cusco  Universidad Nacional de San Antonio Abad del C...
# 3   La Libertad  Trujillo                   Universidad Nacional de Trujillo
# 4      Arequipa  Arequipa    Universidad Nacional de San Agustin de Arequipa
# ..          ...       ...                                                ...
# 87        Junin  Huancayo  Universidad Santo Tomas de Aquino de Ciencia e...
# 88         Lima      Lima                           Universidad Privada SISE
# 89         Lima      Lima     Universidad Seminario Evangelico de Lima (*12)
# 90         Lima      Lima         Universidad Seminario Biblico Andino (*12)
# 91         Lima      Lima                      Universidad Catolica San Jose
#
# [143 rows x 3 columns]

# %% [markdown]
# # We geocode

# %%
API_KEY = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4'

# %%
def join_columns( row_series ):
    
    
    return address

# %%
def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
def geo_unis( row_series ):
    
    address = f"{ row_series[ 'UNIVERSIDAD' ]}, { row_series[ 'PROVINCIA' ]}"
    
    # Set Geolocation
    gmaps = googlemaps.Client( key = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4' )
    result_api = gmaps.geocode( address , region = 'PE' )
    
    # Information
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( address, lat, lon )

# %%
table4['results'] = table4.apply( lambda x: geo_unis( x )  , axis = 1 )

# %%
table4
# Out:
#    DEPARTAMENTO PROVINCIA                                        UNIVERSIDAD  \
# 0          Lima      Lima           Universidad Nacional Mayor de San Marcos
# 1      Ayacucho  Huamanga  Universidad Nacional de San Cristobal de Huamanga
# 2         Cusco     Cusco  Universidad Nacional de San Antonio Abad del C...
# 3   La Libertad  Trujillo                   Universidad Nacional de Trujillo
# 4      Arequipa  Arequipa    Universidad Nacional de San Agustin de Arequipa
# ..          ...       ...                                                ...
# 87        Junin  Huancayo  Universidad Santo Tomas de Aquino de Ciencia e...
# 88         Lima      Lima                           Universidad Privada SISE
# 89         Lima      Lima     Universidad Seminario Evangelico de Lima (*12)
# 90         Lima      Lima         Universidad Seminario Biblico Andino (*12)
# 91         Lima      Lima                      Universidad Catolica San Jose
#
# ...

# %%
table4[['addres', 'lat', 'lng']] = pd.DataFrame( table4.results.tolist() ,  index = table4.index )

# %%
table5 = table4[["DEPARTAMENTO", "PROVINCIA","UNIVERSIDAD", "lat","lng"]].rename(columns={'DEPARTAMENTO': 'Department_univ', 'PROVINCIA': 'Province_univ','UNIVERSIDAD':'Name_univ','lat': 'Latitude_univ', 'lng' : 'Longitude_univ'})
table5
# Out:
#    Department_univ Province_univ  \
# 0             Lima          Lima
# 1         Ayacucho      Huamanga
# 2            Cusco         Cusco
# 3      La Libertad      Trujillo
# 4         Arequipa      Arequipa
# ..             ...           ...
# 87           Junin      Huancayo
# 88            Lima          Lima
# 89            Lima          Lima
# 90            Lima          Lima
# 91            Lima          Lima
#
#                                             Name_univ  Latitude_univ  \
# 0            Universidad Nacional Mayor de San Marcos     -12.056158
# 1   Universidad Nacional de San Cristobal de Huamanga     -13.161248
# 2   Universidad Nacional de San Antonio Abad del C...     -13.521930
# 3                    Universidad Nacional de Trujillo      -8.115007
# 4     Universidad Nacional de San Agustin de Arequipa     -16.397139
# ..                                                ...            ...
# 87  Universidad Santo Tomas de Aquino de Ciencia e...     -12.084047
# ...

# %% [markdown]
# ### We merge with centroid data

# %%
table6 = pd.read_excel('peru_departments_centroids.xlsx')
table6
# Out:
#     CCDD        NOMBDEP           CAPITAL  Dpt_Centroid_Latitude  \
# 0      1       AMAZONAS       CHACHAPOYAS              -5.069369
# 1      2         ANCASH            HUARAZ              -9.406368
# 2      3       APURIMAC           ABANCAY             -14.028147
# 3      4       AREQUIPA          AREQUIPA             -15.844475
# 4      5       AYACUCHO          AYACUCHO             -14.086284
# 5      6      CAJAMARCA         CAJAMARCA              -6.432297
# 6      7         CALLAO            CALLAO             -11.940800
# 7      8          CUSCO             CUSCO             -13.189060
# 8      9   HUANCAVELICA      HUANCAVELICA             -13.023206
# 9     10        HUANUCO           HUANUCO              -9.416089
# 10    11            ICA               ICA             -14.233761
# 11    12          JUNIN          HUANCAYO             -11.538922
# 12    13    LA LIBERTAD          TRUJILLO              -7.921689
# ...

# %%
table6 = table6[['NOMBDEP', 'CAPITAL', 'Dpt_Centroid_Latitude', 'Dpt_Centroid_Longitude']]
table6['NOMBDEP'] = table6['NOMBDEP'].apply(lambda x: x.title())
table6['CAPITAL'] = table6['CAPITAL'].apply(lambda x: x.title())
table6
# Out:
# <ipython-input-17-cd8a68fab216>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table6['NOMBDEP'] = table6['NOMBDEP'].apply(lambda x: x.title())
# <ipython-input-17-cd8a68fab216>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table6['CAPITAL'] = table6['CAPITAL'].apply(lambda x: x.title())
#           NOMBDEP           CAPITAL  Dpt_Centroid_Latitude  \
# 0        Amazonas       Chachapoyas              -5.069369
# 1          Ancash            Huaraz              -9.406368
# ...

# %%
table7 = table5.merge(table6, how = 'left',left_on=['Department_univ'],right_on=['NOMBDEP'])
table7
# Out:
#     Department_univ Province_univ  \
# 0              Lima          Lima
# 1          Ayacucho      Huamanga
# 2             Cusco         Cusco
# 3       La Libertad      Trujillo
# 4          Arequipa      Arequipa
# ..              ...           ...
# 138           Junin      Huancayo
# 139            Lima          Lima
# 140            Lima          Lima
# 141            Lima          Lima
# 142            Lima          Lima
#
#                                              Name_univ  Latitude_univ  \
# 0             Universidad Nacional Mayor de San Marcos     -12.056158
# 1    Universidad Nacional de San Cristobal de Huamanga     -13.161248
# 2    Universidad Nacional de San Antonio Abad del C...     -13.521930
# 3                     Universidad Nacional de Trujillo      -8.115007
# 4      Universidad Nacional de San Agustin de Arequipa     -16.397139
# ..                                                 ...            ...
# ...

# %%
table7.drop(table7.columns[5], axis=1, inplace=True)
table7.drop(table7.columns[5], axis=1, inplace=True)
table7
# Out:
#     Department_univ Province_univ  \
# 0              Lima          Lima
# 1          Ayacucho      Huamanga
# 2             Cusco         Cusco
# 3       La Libertad      Trujillo
# 4          Arequipa      Arequipa
# ..              ...           ...
# 138           Junin      Huancayo
# 139            Lima          Lima
# 140            Lima          Lima
# 141            Lima          Lima
# 142            Lima          Lima
#
#                                              Name_univ  Latitude_univ  \
# 0             Universidad Nacional Mayor de San Marcos     -12.056158
# 1    Universidad Nacional de San Cristobal de Huamanga     -13.161248
# 2    Universidad Nacional de San Antonio Abad del C...     -13.521930
# 3                     Universidad Nacional de Trujillo      -8.115007
# 4      Universidad Nacional de San Agustin de Arequipa     -16.397139
# ..                                                 ...            ...
# ...

# %%
geodata = table7.iloc[ : ,[3,4,5,6]]
geodata
# Out:
#      Latitude_univ  Longitude_univ  Dpt_Centroid_Latitude  \
# 0       -12.056158      -77.084520             -11.785115
# 1       -13.161248      -74.225772             -14.086284
# 2       -13.521930      -71.958321             -13.189060
# 3        -8.115007      -79.038305              -7.921689
# 4       -16.397139      -71.537144             -15.844475
# ..             ...             ...                    ...
# 138     -12.084047      -75.208488             -11.538922
# 139     -12.077645      -77.035855             -11.785115
# 140     -12.063959      -76.960074             -11.785115
# 141     -12.069621      -77.053398             -11.785115
# 142     -12.083682      -77.069168             -11.785115
#
#      Dpt_Centroid_Longitude
# 0                -76.628934
# 1                -74.083968
# 2                -72.170789
# 3                -78.368017
# 4                -72.472918
# ..                      ...
# 138              -74.876839
# 139              -76.628934
# ...

# %%
geodata.insert(0, 'combination', range(1, 1+ len(geodata)))

# %%
geodata['origin'] = geodata['Latitude_univ'].astype(str) + "," + geodata['Longitude_univ'].astype(str) 
geodata['destination'] = geodata['Dpt_Centroid_Latitude'].astype(str) + "," + geodata['Dpt_Centroid_Longitude'].astype(str)
# Out:
# <ipython-input-22-1b3148f78855>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geodata['origin'] = geodata['Latitude_univ'].astype(str) + "," + geodata['Longitude_univ'].astype(str)

# %%
combination = geodata['combination'].tolist()
origin = geodata['origin'].tolist()
destination = geodata['destination'].tolist()

# %%
data_distance = {}

# %%
for c,o,d in tqdm(list(zip(combination,origin, destination))):
    print(c,o,d)
# Out:
# <ipython-input-25-3cd8a9fb1058>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combination,origin, destination))):
#   0%|          | 0/143 [00:00<?, ?it/s]
# 1 -12.0561578,-77.0845196 -11.7851149934921,-76.62893414942204
# 2 -13.1612479,-74.2257722 -14.08628399299046,-74.08396839739828
# 3 -13.52193,-71.9583208 -13.18905970857458,-72.17078885079073
# 4 -8.1150074,-79.03830479999999 -7.921689498366312,-78.3680173050854
# 5 -16.3971385,-71.5371437 -15.84447501555863,-72.47291786966441
# 6 -12.0231787,-77.04763009999999 -11.7851149934921,-76.62893414942204
# 7 -12.0817493,-76.9431895 -11.7851149934921,-76.62893414942204
# 8 -14.0871322,-75.7335148 -14.23376144972263,-75.57481382948437
# 9 -12.0330464,-75.237332 -11.53892223390843,-74.87683921293825
# 10 -3.7459891,-73.24569939999999 -4.114621881189913,-74.4126485793552
# ...

# %%
def google_distance( api_key, origin, destination, traffic_model, departure_time = 'now', region = 'pe', mode = 'driving' ):
    
    # Google MapsDdirections API endpoint
    endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    #Building the URL for the request
    nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                destination , departure_time , traffic_model , mode, region, api_key)



    # Concatenate strings
    request = endpoint + nav_request
    
    #Sends the request and reads the response.
    response = urllib.request.urlopen(request).read()

    #Loads response as JSON
    result = json.loads(response)
    
    try:
        
        dist = result['routes'][0]['legs'][0]['distance']['value']
        dura = result['routes'][0]['legs'][0]['duration']['value']
        
    except:
        
        dist = np.nan
        dura = np.nan
    
    return f"{dist}", f"{dura}"

# %%
best_guess=geodata.apply( lambda x: google_distance( api_key = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4', 
                                                       origin = x['origin'],  destination = x[ 'destination' ], 
                                 traffic_model = 'best_guess' ), axis = 1 )

# %%
best_guess
# Out:
#                    tidur       time   duration travel_distance_best_guess  \
# 0      ('71709', '8469')   ('71709'    '8469')                   ('71709'
# 1         ('nan', 'nan')     ('nan'     'nan')                     ('nan'
# 2    ('167137', '14791')  ('167137'   '14791')                  ('167137'
# 3    ('129255', '11962')  ('129255'   '11962')                  ('129255'
# 4    ('209020', '13417')  ('209020'   '13417')                  ('209020'
# ..                   ...        ...        ...                        ...
# 138  ('175427', '16145')  ('175427'   '16145')                  ('175427'
# 139    ('67600', '8529')   ('67600'    '8529')                   ('67600'
# 140    ('63136', '7593')   ('63136'    '7593')                   ('63136'
# 141    ('68877', '8331')   ('68877'    '8331')                   ('68877'
# 142    ('71047', '8874')   ('71047'    '8874')                   ('71047'
#
#     travel_time_best_guess
# 0                  '8469')
# ...

# %%
best_guess = pd.DataFrame (best_guess, columns=['tidur'])
best_guess["tidur"] = best_guess["tidur"].astype(str)
best_guess
# Out:
#                    tidur
# 0      ('71709', '8469')
# 1         ('nan', 'nan')
# 2    ('167137', '14791')
# 3    ('129255', '11962')
# 4    ('209020', '13417')
# ..                   ...
# 138  ('175427', '16145')
# 139    ('67600', '8529')
# 140    ('63136', '7593')
# 141    ('68877', '8331')
# 142    ('71047', '8874')
#
# [143 rows x 1 columns]

# %%
best_guess[['travel_distance_best_guess','travel_time_best_guess']] = best_guess['tidur'].str.split(',', 1, expand=True)
best_guess
# Out:
#                    tidur travel_distance_best_guess travel_time_best_guess
# 0      ('71709', '8469')                   ('71709'                '8469')
# 1         ('nan', 'nan')                     ('nan'                 'nan')
# 2    ('167137', '14791')                  ('167137'               '14791')
# 3    ('129255', '11962')                  ('129255'               '11962')
# 4    ('209020', '13417')                  ('209020'               '13417')
# ..                   ...                        ...                    ...
# 138  ('175427', '16145')                  ('175427'               '16145')
# 139    ('67600', '8529')                   ('67600'                '8529')
# 140    ('63136', '7593')                   ('63136'                '7593')
# 141    ('68877', '8331')                   ('68877'                '8331')
# 142    ('71047', '8874')                   ('71047'                '8874')
#
# [143 rows x 3 columns]

# %%
pessimistic = geodata.apply( lambda x: google_distance( api_key = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4', 
                                                       origin = f"{x['origin']}",  destination = f"{x[ 'destination' ]}" , 
                                 traffic_model = 'pessimistic' ), axis = 1 )

# %%
pessimistic
# Out:
# 0        (71709, 8469)
# 1           (nan, nan)
# 2      (167137, 14791)
# 3      (129255, 11962)
# 4      (209020, 13417)
#             ...
# 138    (175427, 16145)
# 139      (68504, 8914)
# 140      (64040, 7978)
# 141      (69882, 8959)
# 142      (71047, 8874)
# Length: 143, dtype: object

# %%
pessimistic = pd.DataFrame (pessimistic, columns=['tidur'])
pessimistic["tidur"] = pessimistic["tidur"].astype(str)
pessimistic
# Out:
#                    tidur
# 0      ('71709', '8469')
# 1         ('nan', 'nan')
# 2    ('167137', '14791')
# 3    ('129255', '11962')
# 4    ('209020', '13417')
# ..                   ...
# 138  ('175427', '16145')
# 139    ('68504', '8914')
# 140    ('64040', '7978')
# 141    ('69882', '8959')
# 142    ('71047', '8874')
#
# [143 rows x 1 columns]

# %%
pessimistic[['travel_distance_pessimistic','travel_time_pessmistic']] = pessimistic['tidur'].str.split(',', 1, expand=True)
pessimistic
# Out:
#                    tidur travel_distance_pessimistic travel_time_pessmistic
# 0      ('71709', '8469')                    ('71709'                '8469')
# 1         ('nan', 'nan')                      ('nan'                 'nan')
# 2    ('167137', '14791')                   ('167137'               '14791')
# 3    ('129255', '11962')                   ('129255'               '11962')
# 4    ('209020', '13417')                   ('209020'               '13417')
# ..                   ...                         ...                    ...
# 138  ('175427', '16145')                   ('175427'               '16145')
# 139    ('68504', '8914')                    ('68504'                '8914')
# 140    ('64040', '7978')                    ('64040'                '7978')
# 141    ('69882', '8959')                    ('69882'                '8959')
# 142    ('71047', '8874')                    ('71047'                '8874')
#
# [143 rows x 3 columns]

# %%
optimistic = geodata.apply( lambda x: google_distance( api_key = 'AIzaSyBEdjj0KkQ1Zr0kpzgLk_bG5M4Mi7qXsE4', 
                                                       origin = f"{x['origin']}",  destination = f"{x[ 'destination' ]}" , 
                                 traffic_model = 'optimistic' ), axis = 1 )

# %%
optimistic
# Out:
# 0        (71709, 8469)
# 1           (nan, nan)
# 2      (167137, 14791)
# 3      (129255, 11962)
# 4      (209020, 13417)
#             ...
# 138    (175427, 16145)
# 139      (67600, 8529)
# 140      (64040, 7978)
# 141      (68877, 8331)
# 142      (71047, 8874)
# Length: 143, dtype: object

# %%
optimistic = pd.DataFrame (optimistic, columns=['tidur'])
optimistic["tidur"] = optimistic["tidur"].astype(str)
optimistic
# Out:
#                    tidur
# 0      ('71709', '8469')
# 1         ('nan', 'nan')
# 2    ('167137', '14791')
# 3    ('129255', '11962')
# 4    ('209020', '13417')
# ..                   ...
# 138  ('175427', '16145')
# 139    ('67600', '8529')
# 140    ('64040', '7978')
# 141    ('68877', '8331')
# 142    ('71047', '8874')
#
# [143 rows x 1 columns]

# %%
optimistic[['travel_distance_optimistic','travel_time_optimistic']] = optimistic['tidur'].str.split(',', 1, expand=True)
optimistic
# Out:
#                    tidur travel_distance_optimistic travel_time_optimistic
# 0      ('71709', '8469')                   ('71709'                '8469')
# 1         ('nan', 'nan')                     ('nan'                 'nan')
# 2    ('167137', '14791')                  ('167137'               '14791')
# 3    ('129255', '11962')                  ('129255'               '11962')
# 4    ('209020', '13417')                  ('209020'               '13417')
# ..                   ...                        ...                    ...
# 138  ('175427', '16145')                  ('175427'               '16145')
# 139    ('67600', '8529')                   ('67600'                '8529')
# 140    ('64040', '7978')                   ('64040'                '7978')
# 141    ('68877', '8331')                   ('68877'                '8331')
# 142    ('71047', '8874')                   ('71047'                '8874')
#
# [143 rows x 3 columns]

# %% [markdown]
# ### We merge the databases

# %%
merge1 = pd.concat([best_guess, pessimistic, optimistic], axis=1)

# %%
merge1
# Out:
#                    tidur travel_distance_best_guess travel_time_best_guess  \
# 0      ('71709', '8469')                   ('71709'                '8469')
# 1         ('nan', 'nan')                     ('nan'                 'nan')
# 2    ('167137', '14791')                  ('167137'               '14791')
# 3    ('129255', '11962')                  ('129255'               '11962')
# 4    ('209020', '13417')                  ('209020'               '13417')
# ..                   ...                        ...                    ...
# 138  ('175427', '16145')                  ('175427'               '16145')
# 139    ('67600', '8529')                   ('67600'                '8529')
# 140    ('63136', '7593')                   ('63136'                '7593')
# 141    ('68877', '8331')                   ('68877'                '8331')
# 142    ('71047', '8874')                   ('71047'                '8874')
#
# ...

# %%
table8 = merge1.iloc[:,[2,5,8,1,4,7]]
table8
# Out:
#     travel_time_best_guess travel_time_pessmistic travel_time_optimistic  \
# 0                  '8469')                '8469')                '8469')
# 1                   'nan')                 'nan')                 'nan')
# 2                 '14791')               '14791')               '14791')
# 3                 '11962')               '11962')               '11962')
# 4                 '13417')               '13417')               '13417')
# ..                     ...                    ...                    ...
# 138               '16145')               '16145')               '16145')
# 139                '8529')                '8914')                '8529')
# 140                '7593')                '7978')                '7978')
# 141                '8331')                '8959')                '8331')
# 142                '8874')                '8874')                '8874')
#
#     travel_distance_best_guess travel_distance_pessimistic  \
# ...

# %%
table9=pd.concat([table7, table8], axis=1)
table9
# Out:
#     Department_univ Province_univ  \
# 0              Lima          Lima
# 1          Ayacucho      Huamanga
# 2             Cusco         Cusco
# 3       La Libertad      Trujillo
# 4          Arequipa      Arequipa
# ..              ...           ...
# 138           Junin      Huancayo
# 139            Lima          Lima
# 140            Lima          Lima
# 141            Lima          Lima
# 142            Lima          Lima
#
#                                              Name_univ  Latitude_univ  \
# 0             Universidad Nacional Mayor de San Marcos     -12.056158
# 1    Universidad Nacional de San Cristobal de Huamanga     -13.161248
# 2    Universidad Nacional de San Antonio Abad del C...     -13.521930
# 3                     Universidad Nacional de Trujillo      -8.115007
# 4      Universidad Nacional de San Agustin de Arequipa     -16.397139
# ..                                                 ...            ...
# ...

# %% [markdown]
# ## We export
