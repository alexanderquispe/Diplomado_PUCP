# %% [markdown]
# # Assigment 6
#
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**
#
# **GET YOUR GOOGLE API AND TOKEN. YOU WILL NEED THEM TO DO THIS TASK.**

# %% [markdown]
# 1. Import Data from [this url](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/bbva_list.xlsx). This dataset is in excel format. You have to convert to PandasDataFrame.
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.
# 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.
# 4. Finally, you have to give a report which offices are the most closest and furthest to every group member's address.

# %%
#!pip install googlemaps
#!pip install pandas

# %%
#LIBRARIES

import pandas as pd
import os # File management
import urllib.request # For URLs
import json # Parse JSON responses received from APIs and convert Python objects to JSON format
import csv # Manage CSV files
import numpy as np # Numerical operations
from tqdm import tqdm # Progress bar in loops or iterations
import requests # Send HTTP requests to web servers, retrieve responses, and handle various types of HTTP methods
import unicodedata # Work with Unicode characters, including string normalization and removing accents
import time # Add wait time between requests
import re # Work with regular expressions
import googlemaps # Use the Google Maps API

# %%
# Load data

df = pd.read_excel( '../../_data/bbva_list.xlsx')
df.head()

# Latitude and longitude columns
df['latitude'] = None
df['longitude'] = None

# COMPLETE_ADDRESS column 
df['COMPLETE_ADDRESS'] = df['Direccion'] + ', ' + df['DISTRITO'] + ', ' + df['PROVINCIA'] 

# Dataframe
df
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# 11      AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSIO         LIMA      LIMA
# 12                        KM. 25 CARRETERA VENTANILLA         LIMA      LIMA
# 13           MALECdN ANDRAS A. CACERES MZ C-3, LT. 19         LIMA      LIMA
# 14  AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...         LIMA      LIMA
# 15                 AV. LOS PARACAS 203 URB. SALAMANCA         LIMA      LIMA
# 16                       AV. NICOLAS AYLLON 2032-2036         LIMA      LIMA
# 13     VENTANILLA     None      None
# 14            ATE     None      None
# 15            ATE     None      None
# 16            ATE     None      None
# 17            ATE     None      None
# 18            ATE     None      None
# 19            ATE     None      None
# 20            ATE     None      None
# 21       BARRANCO     None      None
# 22       BARRANCO     None      None
# 23         BREfiA     None      None
# 24          BRENA     None      None
# 25          BRENA     None      None
# 26     CARABAYLLO     None      None
# 27     CHORRILLOS     None      None
# 28     CHORRILLOS     None      None
# 29     CHORRILLOS     None      None
# 30     CHORRILLOS     None      None
# 31     CHORRILLOS     None      None
# 32          COMAS     None      None
# 33          COMAS     None      None
# 34          COMAS     None      None
# 35          COMAS     None      None
# 36     ELAGUSTINO     None      None
# 37  INDEPENDENCIA     None      None
# 38  INDEPENDENCIA     None      None
# 39  INDEPENDENCIA     None      None
# 40    JESUS MARIA     None      None
# 41    JESUS MARIA     None      None
# 42    JESUS MARIA     None      None
# 43    JESUS MARIA     None      None
# 44    JESUS MARIA     None      None
# 45      LA MOLINA     None      None
# 46      LA MOLINA     None      None
# 47      LA MOLINA     None      None
# 48      LA MOLINA     None      None
# 49      LA MOLINA     None      None
# 50      LA MOLINA     None      None
# 51      LA MOLINA     None      None
#
#                                      COMPLETE_ADDRESS
# 0   CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 1       AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO, LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...
# 3                   AV. SAENZ PEN A 323, CALLAO, LIMA
# 4   CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO, ...
# 5      AV. CONTRALMIRANTE RAYGADA N°lll, CALLAO, LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...
# 7                AV. ELMER FAUCETT 6000, CALLAO, LIMA
# 8     CENTRO COMERCIAL MINKA PABELL6N 2, CALLAO, LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...
# 10                AV, COLONIAL 4584, BELLAVISTA, LIMA
# 11  AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSIO,...
# 12      KM. 25 CARRETERA VENTANILLA, VENTANILLA, LIMA
# 13  MALECdN ANDRAS A. CACERES MZ C-3, LT. 19, VENT...
# 14  AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...
# 15      AV. LOS PARACAS 203 URB. SALAMANCA, ATE, LIMA
# 16            AV. NICOLAS AYLLON 2032-2036, ATE, LIMA
# 17  LOCAL LS-201 - AV. NICOLAS AYLL6N N° 4770, ATE...
# 18         AV. NICOLAS AYLLON 8694, LC-105, ATE, LIMA
# 19                        AV. PROGRESO 102, ATE, LIMA
# 20  AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...
# 21      AV. GRAU 414 ESQ. CALLE UNION, BARRANCO, LIMA
# 22                  PLAZA BUTTERS 301, BARRANCO, LIMA
# 23                    AV. VENEZUELA 635, BREfiA, LIMA
# 24                    AV. VENEZUELA 1254, BRENA, LIMA
# 25                        JR. HUARAZ1600, BRENA, LIMA
# 26  AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTOR,...
# 27  AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARC...
# 28  AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...
# 29    AV. MALECON DE LA RIBERA S/N., CHORRILLOS, LIMA
# 30  AV. PROLG. PASEO DE LA REPllBLICA S/N - CCPLAZ...
# 31        AV. GUARDIA CIVIL 152-156, CHORRILLOS, LIMA
# 32               AV. TUPAC AMARU N° 1175, COMAS, LIMA
# 33  AV. UNIVERSITARIA NORTE 7103, MZ. H LT. 22, UR...
# 34  AV. UNIVERSITARIA 10583-10587, MZ. X LT. 3 -SE...
# 35  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R...
# 36  AV. RIVA AG0ER01400-1404-1406, MZ. C LT. 27, E...
# 37  AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...
# 38  AV. CARLOS IZAGUIRRE N.- 275, INDEPENDENCIA, LIMA
# 39  CRUCE AV. TOMAS VALLE CON PANAMERICANA NORTE, ...
# 40  AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...
# 41  CALLE HUAMACHUC01301-1307-1309, ESQ. CON REPll...
# 42     AV. REP. DOMINICANA 355-359, JESUS MARIA, LIMA
# 43  AV. GENERAL FELIPE SALAVERRY 2370, LS-04, JESU...
# 44  RESIDENCIAL SAN FELIPE TDA. 23, JESUS MARIA, LIMA
# 45  AV. PROL. JAVIER PRADO ESTE 4921, LA MOLINA, LIMA
# 46  AV. RICARDO E. APARICIO 675, MZ. H LT. 1 -URB....
# 47  CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO,...
# 48  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...
# 49  AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTA...
# 50            AV. LA UNIVERSIDAD1810, LA MOLINA, LIMA
# 51                 AV. LA MOLINA 540, LA MOLINA, LIMA

# %% [markdown]
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.

# %%
# Google Maps Key

gmaps = googlemaps.Client(key='AIzaSyB9MemHABiw8pEAlDfmOh1owE4cVOJyRp0')


# Get latitude and length

for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    try:
        geocode_result = gmaps.geocode(row['COMPLETE_ADDRESS'])
        
        if geocode_result:
            location = geocode_result[0]['geometry']['location']
            df.at[idx, 'latitude'] = location['lat']
            df.at[idx, 'longitude'] = location['lng']
        else:
            print(f"It could not be geocoded: {row['COMPLETE_ADDRESS']}")
            
    except Exception as e:
        print(f"Error when geocoding {row['COMPLETE_ADDRESS']}: {e}")

# New dataframe
df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 52/52 [00:03<00:00, 13.39it/s]
#                                            Direccion DEPARTAMENTO PROVINCIA  \
# 0       CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                    AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                AV. SAENZ PEN A 323         LIMA      LIMA
# 4       CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
#
#   DISTRITO   latitude  longitude  \
# 0   CALLAO -12.041948 -77.095272
# 1   CALLAO  -12.04328  -77.13603
# 2   CALLAO  -12.06225 -77.066524
# 3   CALLAO -12.072599 -77.163772
# 4   CALLAO  -12.05068 -77.087137
#
#                                     COMPLETE_ADDRESS
# 0  CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 1      AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO, LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...
# 3                  AV. SAENZ PEN A 323, CALLAO, LIMA
# 4  CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO, ...

# %% [markdown]
# 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.

# %%
members = [
    ('Luis Felipe', 'C. Roma 281, Lima 15076'),
    ('Ruth', 'C. Campanillas 108, Ate 15022'),
    ('Raúl', 'Gral Artigas 553, Pueblo Libre 15084'),
    ('Manuel Antonio', 'Jr. Huancavelica 411, Lima 15001'),
    ('Alejandro', 'Jirón Rio de Janeiro 140, Jesús María 15072')
]

# Calculate driving time
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    driving_times = []
    for member_name, member_address in members:
        try:
            matrix = gmaps.distance_matrix(origins=[member_address],
                                           destinations=[f"{row['latitude']},{row['longitude']}"],
                                           mode="driving",
                                           departure_time="now")
            
            if matrix['rows'][0]['elements'][0]['status'] == 'OK':
                duration = matrix['rows'][0]['elements'][0]['duration_in_traffic']['text']
                driving_times.append(f"{member_name}: {duration}")
            else:
                driving_times.append(f"{member_name}: Not available")
                
        except Exception as e:
            driving_times.append(f"{member_name}: Error")
            print(f"Error by calculating driving time from {member_address} to {row['COMPLETE_ADDRESS']}: {e}")
    
    # New column
    df.at[idx, 'driving_times'] = '; '.join(driving_times)

# New dataframe
df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 52/52 [00:51<00:00,  1.02it/s]
#                                            Direccion DEPARTAMENTO PROVINCIA  \
# 0       CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                    AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                AV. SAENZ PEN A 323         LIMA      LIMA
# 4       CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
#
#   DISTRITO   latitude  longitude  \
# 0   CALLAO -12.041948 -77.095272
# 1   CALLAO  -12.04328  -77.13603
# 2   CALLAO  -12.06225 -77.066524
# 3   CALLAO -12.072599 -77.163772
# 4   CALLAO  -12.05068 -77.087137
#
#                                     COMPLETE_ADDRESS  \
# 0  CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 1      AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO, LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...
# 3                  AV. SAENZ PEN A 323, CALLAO, LIMA
# 4  CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO, ...
#
#                                        driving_times
# 0  Luis Felipe: 37 mins; Ruth: 32 mins; Raúl: 23 ...
# 1  Luis Felipe: 32 mins; Ruth: 48 mins; Raúl: 31 ...
# 2  Luis Felipe: 21 mins; Ruth: 43 mins; Raúl: 7 m...
# 3  Luis Felipe: 26 mins; Ruth: 45 mins; Raúl: 30 ...
# 4  Luis Felipe: 30 mins; Ruth: 33 mins; Raúl: 16 ...
