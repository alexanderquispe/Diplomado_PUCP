# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains

# %%
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode

# %%
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ### Scraping

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )

url = 'https://www.sunedu.gob.pe/lista-universidades/'
driver.get( url )

driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\Yoseph\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache

# %% [markdown]
# ### Public universities

# %%
public_u = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[1]/a" ) 

public_u.click()

# %%
table_public = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[1]/div")

# %%
table_public_html = table_public.get_attribute( 'innerHTML' )

# %%
# Read the table using pandas
f_table_public = pd.read_html( table_public_html )
f_table_public
# Out:
# [    N°                                        UNIVERSIDAD   DEPARTAMENTO  \
#  0    1           Universidad Nacional Mayor de San Marcos           Lima
#  1    2  Universidad Nacional de San Cristóbal de Huamanga       Ayacucho
#  2    3  Universidad Nacional de San Antonio Abad del C...          Cusco
#  3    4                   Universidad Nacional de Trujillo    La Libertad
#  4    5    Universidad Nacional de San Agustín de Arequipa       Arequipa
#  5    6                 Universidad Nacional de Ingeniería           Lima
#  6    7             Universidad Nacional Agraria La Molina           Lima
#  7    8              Universidad Nacional San Luis Gonzaga            Ica
#  8    9           Universidad Nacional del Centro del Perú          Junín
#  9   10        Universidad Nacional de la Amazonía Peruana         Loreto
#  10  11                 Universidad Nacional del Altiplano           Puno
#  11  12                      Universidad Nacional de Piura          Piura
# ...

# %% [markdown]
# ### Private universities

# %%
private_u = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/ul/li[2]/a" ) 

private_u.click()

# %%
table_private = driver.find_element_by_xpath( "/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div[1]/div/div[2]/div")

# %%
table_private_html = table_private.get_attribute( 'innerHTML' )

# %%
# Read the table using pandas
f_table_private = pd.read_html( table_private_html )
f_table_private
# Out:
# [    N°                                        UNIVERSIDAD DEPARTAMENTO  \
#  0    1           Pontificia Universidad Católica del Perú         Lima
#  1    2               Universidad Peruana Cayetano Heredia         Lima
#  2    3                Universidad Católica de Santa María     Arequipa
#  3    4                           Universidad del Pacífico         Lima
#  4    5                                Universidad de Lima         Lima
#  ..  ..                                                ...          ...
#  87  88  Universidad Santo Tomás de Aquino de Ciencia e...        Junín
#  88  89                           Universidad Privada SISE         Lima
#  89  90     Universidad Seminario Evangélico de Lima (*12)         Lima
#  90  91         Universidad Seminario Bíblico Andino (*12)         Lima
#  91  92                      Universidad Católica San José         Lima
#
#     PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
df_public = pd.concat(f_table_public)

df_private = pd.concat(f_table_private)

# %%
df_universities = df_public.append(df_private, ignore_index=True)

# %%
df_universities
# Out:
#      N°                                        UNIVERSIDAD DEPARTAMENTO  \
# 0     1           Universidad Nacional Mayor de San Marcos         Lima
# 1     2  Universidad Nacional de San Cristóbal de Huamanga     Ayacucho
# 2     3  Universidad Nacional de San Antonio Abad del C...        Cusco
# 3     4                   Universidad Nacional de Trujillo  La Libertad
# 4     5    Universidad Nacional de San Agustín de Arequipa     Arequipa
# ..   ..                                                ...          ...
# 138  88  Universidad Santo Tomás de Aquino de Ciencia e...        Junín
# 139  89                           Universidad Privada SISE         Lima
# 140  90     Universidad Seminario Evangélico de Lima (*12)         Lima
# 141  91         Universidad Seminario Bíblico Andino (*12)         Lima
# 142  92                      Universidad Católica San José         Lima
#
#     PROVINCIA DISPOSITIVO LEGAL DE CREACIÓN FECHA DE CREACIÓN  \
# ...

# %%
df_universities = df_universities.iloc[ : ,  1 : 4 ]
df_universities
# Out:
#                                            UNIVERSIDAD DEPARTAMENTO PROVINCIA
# 0             Universidad Nacional Mayor de San Marcos         Lima      Lima
# 1    Universidad Nacional de San Cristóbal de Huamanga     Ayacucho  Huamanga
# 2    Universidad Nacional de San Antonio Abad del C...        Cusco     Cusco
# 3                     Universidad Nacional de Trujillo  La Libertad  Trujillo
# 4      Universidad Nacional de San Agustín de Arequipa     Arequipa  Arequipa
# ..                                                 ...          ...       ...
# 138  Universidad Santo Tomás de Aquino de Ciencia e...        Junín  Huancayo
# 139                           Universidad Privada SISE         Lima      Lima
# 140     Universidad Seminario Evangélico de Lima (*12)         Lima      Lima
# 141         Universidad Seminario Bíblico Andino (*12)         Lima      Lima
# 142                      Universidad Católica San José         Lima      Lima
#
# [143 rows x 3 columns]

# %% [markdown]
# ### Use Google API Geocoding to geolocate universities and get universities' latitude and longitude

# %%
import googlemaps
import json
import pprint

# %%
API_KEY = 'AIzaSyBoWesySwwcVSOhJh1E9KSaJaSeMAl4uWM'

# %%
def geo_universities( row_series ):
    
    address = f"{row_series['UNIVERSIDAD']}, {row_series['DEPARTAMENTO']}, {row_series['PROVINCIA']}"
    
    # Set Geolocation
    gmaps = googlemaps.Client( key = API_KEY )
    result_api = gmaps.geocode( address , region = 'PE' )
    
    # Information
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']   
    except:
        lat = np.nan
        lon = np.nan
    
    return ( address, lat, lon )

# %%
df_universities['results'] = df_universities.apply( lambda x: geo_universities( x )  , axis = 1 )

# %%
df_universities
# Out:
#                                            UNIVERSIDAD DEPARTAMENTO PROVINCIA  \
# 0             Universidad Nacional Mayor de San Marcos         Lima      Lima
# 1    Universidad Nacional de San Cristóbal de Huamanga     Ayacucho  Huamanga
# 2    Universidad Nacional de San Antonio Abad del C...        Cusco     Cusco
# 3                     Universidad Nacional de Trujillo  La Libertad  Trujillo
# 4      Universidad Nacional de San Agustín de Arequipa     Arequipa  Arequipa
# ..                                                 ...          ...       ...
# 138  Universidad Santo Tomás de Aquino de Ciencia e...        Junín  Huancayo
# 139                           Universidad Privada SISE         Lima      Lima
# 140     Universidad Seminario Evangélico de Lima (*12)         Lima      Lima
# 141         Universidad Seminario Bíblico Andino (*12)         Lima      Lima
# 142                      Universidad Católica San José         Lima      Lima
#
# ...

# %%
df_universities[['addres', 'lat', 'lng']] = pd.DataFrame( df_universities.results.tolist() ,  index = df_universities.index )

# %%
df2_universities = df_universities[["UNIVERSIDAD","DEPARTAMENTO","PROVINCIA","lat","lng"]].rename(columns={'DEPARTAMENTO': 'Departament_univ', 'PROVINCIA': 'Province_univ','UNIVERSIDAD':'Name_univ','lat': 'Latitude_univ', 'lng' : 'Longitude_univ'})
df2_universities
# Out:
#                                              Name_univ Departament_univ  \
# 0             Universidad Nacional Mayor de San Marcos             Lima
# 1    Universidad Nacional de San Cristóbal de Huamanga         Ayacucho
# 2    Universidad Nacional de San Antonio Abad del C...            Cusco
# 3                     Universidad Nacional de Trujillo      La Libertad
# 4      Universidad Nacional de San Agustín de Arequipa         Arequipa
# ..                                                 ...              ...
# 138  Universidad Santo Tomás de Aquino de Ciencia e...            Junín
# 139                           Universidad Privada SISE             Lima
# 140     Universidad Seminario Evangélico de Lima (*12)             Lima
# 141         Universidad Seminario Bíblico Andino (*12)             Lima
# 142                      Universidad Católica San José             Lima
#
#     Province_univ  Latitude_univ  Longitude_univ
# 0            Lima     -12.056158      -77.084520
# ...

# %% [markdown]
# ### Merge your results with the department centroids data using the Department variables as ID.

# %%
centroids = pd.ExcelFile(r'../../_data/peru_departments_centroids.xlsx').parse()

centroids.head()
# Out:
#    CCDD   NOMBDEP      CAPITAL  Dpt_Centroid_Latitude  Dpt_Centroid_Longitude
# 0     1  AMAZONAS  CHACHAPOYAS              -5.069369              -78.055235
# 1     2    ANCASH       HUARAZ              -9.406368              -77.670229
# 2     3  APURIMAC      ABANCAY             -14.028147              -72.974732
# 3     4  AREQUIPA     AREQUIPA             -15.844475              -72.472918
# 4     5  AYACUCHO     AYACUCHO             -14.086284              -74.083968

# %%
centroids['NOMBDEP'].unique()
# Out:
# array(['AMAZONAS', 'ANCASH', 'APURIMAC', 'AREQUIPA', 'AYACUCHO',
#        'CAJAMARCA', 'CALLAO', 'CUSCO', 'HUANCAVELICA', 'HUANUCO', 'ICA',
#        'JUNIN', 'LA LIBERTAD', 'LAMBAYEQUE', 'LIMA', 'LORETO',
#        'MADRE DE DIOS', 'MOQUEGUA', 'PASCO', 'PIURA', 'PUNO',
#        'SAN MARTIN', 'TACNA', 'TUMBES', 'UCAYALI'], dtype=object)

# %%
df2_universities['Departament_univ'] = df2_universities['Departament_univ'].str.upper().apply( lambda x : unidecode.unidecode( x ) )

# %%
df2_universities['Departament_univ'].unique()
# Out:
# array(['LIMA', 'AYACUCHO', 'CUSCO', 'LA LIBERTAD', 'AREQUIPA', 'ICA',
#        'JUNIN', 'LORETO', 'PUNO', 'PIURA', 'CAJAMARCA', 'HUANUCO',
#        'PASCO', 'CALLAO', 'LAMBAYEQUE', 'TACNA', 'ANCASH', 'SAN MARTIN',
#        'UCAYALI', 'TUMBES', 'HUANCAVELICA', 'MADRE DE DIOS', 'AMAZONAS',
#        'APURIMAC', 'MOQUEGUA'], dtype=object)

# %%
merge = df2_universities.merge( centroids, how='left',left_on=['Departament_univ'],right_on=['NOMBDEP'])
merge
# Out:
#                                              Name_univ Departament_univ  \
# 0             Universidad Nacional Mayor de San Marcos             LIMA
# 1    Universidad Nacional de San Cristóbal de Huamanga         AYACUCHO
# 2    Universidad Nacional de San Antonio Abad del C...            CUSCO
# 3                     Universidad Nacional de Trujillo      LA LIBERTAD
# 4      Universidad Nacional de San Agustín de Arequipa         AREQUIPA
# ..                                                 ...              ...
# 138  Universidad Santo Tomás de Aquino de Ciencia e...            JUNIN
# 139                           Universidad Privada SISE             LIMA
# 140     Universidad Seminario Evangélico de Lima (*12)             LIMA
# 141         Universidad Seminario Bíblico Andino (*12)             LIMA
# 142                      Universidad Católica San José             LIMA
#
#     Province_univ  Latitude_univ  Longitude_univ  CCDD      NOMBDEP   CAPITAL  \
# ...

# %% [markdown]
# ### Google API Directions to find the driving travel time and distance from universities to department centroids

# %%
from tqdm.notebook import tqdm
import requests
import urllib.request, json, csv

# %%
merge['Combination'] = merge.index
merge['Combination'] += 1
combination=merge['Combination'].tolist()

# %%
merge['Lat_string_destin']=merge['Dpt_Centroid_Latitude'].astype(str)
merge['Long_string_destin']=merge['Dpt_Centroid_Longitude'].astype(str)

# %%
merge['Lat_Long_destin'] = merge['Lat_string_destin'].str.cat(merge['Long_string_destin'], sep =",") 

destination=merge['Lat_Long_destin'].tolist()
destination2=merge['Lat_Long_destin'].tolist()
destination3=merge['Lat_Long_destin'].tolist()

# %%
merge['Lat_string_origin']=merge['Latitude_univ'].astype(str)
merge['Long_string_origin']=merge['Longitude_univ'].astype(str)

# %%
merge['Lat_Long_origin'] = merge['Lat_string_origin'].str.cat(merge['Long_string_origin'], sep =",") 

origin=merge['Lat_Long_origin'].tolist()
origin2=merge['Lat_Long_origin'].tolist()
origin3=merge['Lat_Long_origin'].tolist()

# %%
merge
# Out:
#                                              Name_univ Departament_univ  \
# 0             Universidad Nacional Mayor de San Marcos             LIMA
# 1    Universidad Nacional de San Cristóbal de Huamanga         AYACUCHO
# 2    Universidad Nacional de San Antonio Abad del C...            CUSCO
# 3                     Universidad Nacional de Trujillo      LA LIBERTAD
# 4      Universidad Nacional de San Agustín de Arequipa         AREQUIPA
# ..                                                 ...              ...
# 138  Universidad Santo Tomás de Aquino de Ciencia e...            JUNIN
# 139                           Universidad Privada SISE             LIMA
# 140     Universidad Seminario Evangélico de Lima (*12)             LIMA
# 141         Universidad Seminario Bíblico Andino (*12)             LIMA
# 142                      Universidad Católica San José             LIMA
#
#     Province_univ  Latitude_univ  Longitude_univ  CCDD      NOMBDEP   CAPITAL  \
# ...

# %% [markdown]
# ### Best_guess

# %%
# Generate dictionary to store data
data_distance = {}

# %%
# Loop to generate info about geolocations
distance_info = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin, destination))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'best_guess'  

        # Departure time
        departure_time= 'now'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info[i][0] = c
        distance_info[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info[i][2] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
 
        i=i+1
        
        my_keys = ['distance', 'duration']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance[c] = info 
    
    except Exception as e:
        
        distance_info[i][0] = c
        distance_info[i][1] = "nan"
        distance_info[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# ...
# 2
# 10
# 15
# 16
# 18
# 22
# 25
# 29
# 30
# 32
# 35
# 42
# 45
# 47
# 67
# 71
# 72
# 74
# 94
# 100
# 106
# 118
# 120
# 130
# 133

# %%
data_bg = pd.DataFrame(distance_info, columns = ['Combination', 'travel_distance_best_guess','travel_time__best_guess'])

# %% [markdown]
# ### Pessimistic

# %%
# Generate dictionary to store data
data_distance_p = {}

# %%
# Loop to generate info about geolocations
distance_info_p = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin2, destination2))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'pessimistic'  

        # Departure time
        departure_time= 'now'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_p[i][0] = c
        distance_info_p[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_p[i][2] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
 
        i=i+1
        
        my_keys = ['distance', 'duration']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_p[c] = info 
    
    except Exception as e:
        
        distance_info_p[i][0] = c
        distance_info_p[i][1] = "nan"
        distance_info_p[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# ...
# 2
# 10
# 15
# 16
# 18
# 22
# 25
# 29
# 30
# 32
# 35
# 42
# 45
# 47
# 67
# 71
# 72
# 74
# 94
# 100
# 106
# 118
# 120
# 130
# 133

# %%
data_p = pd.DataFrame(distance_info_p, columns = ['Combination', 'travel_distance_pessimistic','travel_time_pessimistic'])

# %% [markdown]
# ### Optimistic

# %%
# Generate dictionary to store data
data_distance_o = {}

# %%
# Loop to generate info about geolocations
distance_info_o = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin3, destination3))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'optimistic'  

        # Departure time
        departure_time= 'now'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_o[i][0] = c
        distance_info_o[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_o[i][2] = float(re.sub("[^0-9.]", "", legs['duration']['text']))
 
        i=i+1
        
        my_keys = ['distance', 'duration']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_o[c] = info 
    
    except Exception as e:
        
        distance_info_o[i][0] = c
        distance_info_o[i][1] = "nan"
        distance_info_o[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# ...
# 2
# 10
# 15
# 16
# 18
# 22
# 25
# 29
# 30
# 32
# 35
# 42
# 45
# 47
# 67
# 71
# 72
# 74
# 94
# 100
# 106
# 118
# 120
# 130
# 133

# %%
data_o = pd.DataFrame(distance_info_o, columns = ['Combination', 'travel_distance_optimistic','travel_time_optimistic'])

# %%
from functools import reduce 

dfs=[merge,data_bg, data_p, data_o]

df_final= reduce(lambda left, right: pd.merge(left, right, on='Combination'),dfs)

# %%
df_final.columns
# Out:
# Index(['Name_univ', 'Departament_univ', 'Province_univ', 'Latitude_univ',
#        'Longitude_univ', 'CCDD', 'NOMBDEP', 'CAPITAL', 'Dpt_Centroid_Latitude',
#        'Dpt_Centroid_Longitude', 'Combination', 'Lat_string_destin',
#        'Long_string_destin', 'Lat_Long_destin', 'Lat_string_origin',
#        'Long_string_origin', 'Lat_Long_origin', 'travel_distance_best_guess',
#        'travel_time__best_guess', 'travel_distance_pessimistic',
#        'travel_time_pessimistic', 'travel_distance_optimistic',
#        'travel_time_optimistic'],
#       dtype='object')

# %%
df_final2 = df_final[["Departament_univ","Province_univ","Name_univ","Latitude_univ","Longitude_univ","Dpt_Centroid_Latitude","Dpt_Centroid_Longitude","travel_time__best_guess","travel_time_pessimistic","travel_time_optimistic","travel_distance_best_guess","travel_distance_pessimistic","travel_distance_optimistic"]]

# %% [markdown]
# ### Final database

# %%
df_final2
# Out:
#     Departament_univ Province_univ  \
# 0               LIMA          Lima
# 1           AYACUCHO      Huamanga
# 2              CUSCO         Cusco
# 3        LA LIBERTAD      Trujillo
# 4           AREQUIPA      Arequipa
# ..               ...           ...
# 138            JUNIN      Huancayo
# 139             LIMA          Lima
# 140             LIMA          Lima
# 141             LIMA          Lima
# 142             LIMA          Lima
#
#                                              Name_univ  Latitude_univ  \
# 0             Universidad Nacional Mayor de San Marcos     -12.056158
# 1    Universidad Nacional de San Cristóbal de Huamanga     -13.161248
# 2    Universidad Nacional de San Antonio Abad del C...     -13.521930
# 3                     Universidad Nacional de Trujillo      -8.115007
# 4      Universidad Nacional de San Agustín de Arequipa     -16.397139
# ..                                                 ...            ...
# ...
