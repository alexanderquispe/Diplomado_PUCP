# %% [markdown]
# # Assigment 6
#
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**
#
# **GET YOUR GOOGLE API AND TOKEN. YOU WILL NEED THEM TO DO THIS TASK.**

# %% [markdown]
# 1. Import Data from [this url](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/bbva_list.xlsx). This dataset is in excel format. You have to convert to PandasDataFrame.
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.
# 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.
# 4. Finally, you have to give a report which offices are the most closest and furthest to every group member's address.

# %% [markdown]
# 1. Import Data from [this url](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/bbva_list.xlsx). This dataset is in excel format. You have to convert to PandasDataFrame.

# %%
import pandas as pd
df = pd.read_excel('../../_data/bbva_list.xlsx')
df
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# ...

# %%
df['Direccion_Completa'] = df['Direccion'] + ', ' + df['DISTRITO'] + ', ' + df['PROVINCIA']
df
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# ...

# %% [markdown]
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.

# %%
import os # for file management operations
import urllib.request #  to open and read URLs
import json # to parse JSON responses received from APIs and convert Python objects to JSON format when needed
import csv # to handle CSV files
import numpy as np # for numerical operations
from tqdm import tqdm # to display a progress bar in loops or iterations
import requests # to send HTTP requests to web servers, retrieve responses, and handle various types of HTTP methods
import unicodedata # to work with Unicode characters, including normalizing strings and removing accents.
import time # to add wait time between requests
import re # for working with regular expressions
import googlemaps # for using Google Maps API

# %%
def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']  
        
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyDVsqoJz94tGvPp8X0rPtaQCINH2DRndUE')

# %%
df["results"] = df.apply( lambda x: get_results( gmaps.geocode( x["Direccion_Completa"], region = "pe")  )  , axis = 1 ) # fila por fila
df
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# ...

# %%
df.at[36,'results'] = (-12.04812197431508, -77.00035755361033)

# %%
integrante  = ['Max','Jesus','Karen','Paolo','Luis']
direccion   = ['Jr. Enrique Pallardelli 159, Lima 15021','Av. Javier Prado Este 7107, La Molina, Lima','MZ b lt. 14-A, C. 7, Callao','Sector 1 Grupo 13 Manzana A Lote 1, Villa El Salvador, Lima','Jirón El Escorial 231- Santiago de Surco, Lima']
df_grupo    = pd.DataFrame({'Nombres': integrante, 'Direccion_Casa': direccion})
df_grupo
# Out:
#   Nombres                                     Direccion_Casa
# 0     Max            Jr. Enrique Pallardelli 159, Lima 15021
# 1   Jesus        Av. Javier Prado Este 7107, La Molina, Lima
# 2   Karen                        MZ b lt. 14-A, C. 7, Callao
# 3   Paolo  Sector 1 Grupo 13 Manzana A Lote 1, Villa El S...
# 4    Luis     Jirón El Escorial 231- Santiago de Surco, Lima

# %%
df_grupo["direc_casa"] = df_grupo.apply( lambda x: get_results( gmaps.geocode( x["Direccion_Casa"], region = "pe")  )  , axis = 1 ) # fila por fila
df_grupo
# Out:
#   Nombres                                     Direccion_Casa  \
# 0     Max            Jr. Enrique Pallardelli 159, Lima 15021
# 1   Jesus        Av. Javier Prado Este 7107, La Molina, Lima
# 2   Karen                        MZ b lt. 14-A, C. 7, Callao
# 3   Paolo  Sector 1 Grupo 13 Manzana A Lote 1, Villa El S...
# 4    Luis     Jirón El Escorial 231- Santiago de Surco, Lima
#
#                    direc_casa
# 0  (-12.0853415, -76.9953809)
# 1  (-12.0652762, -76.9420926)
# 2  (-11.9978637, -77.1085318)
# 3  (-12.2165935, -76.9312468)
# 4  (-12.1301563, -77.0023514)

# %% [markdown]
# 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.

# %%
distancias_df = pd.DataFrame(columns=['MEMBER', 'BBVA', 'TIME'])

# %%
endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'
traffic_model = 'best_guess'
departure_time = 'now'
api_key = 'AIzaSyDVsqoJz94tGvPp8X0rPtaQCINH2DRndUE'
mode = 'driving'
region = 'PE'

# %%
rows_list = []

# %%
for index_m, miembro in tqdm(df_grupo.iterrows()):
    for index_o, oficina in tqdm(df.iterrows()):
        origin      =  ','.join(map(str, miembro['direc_casa']))
        destination = ','.join(map(str, oficina['results']))
        nav_request = f'origin={origin}&destination={destination}&departure_time={departure_time}&traffic_model={traffic_model}&mode={mode}&region={region}&key={api_key}'
        request     = endpoint + nav_request
        response    = urllib.request.urlopen(request).read()
        directions  = json.loads(response)
        dura = float(re.sub("[^0-9.]", "", directions['routes'][0]['legs'][0]['duration']['text']))
        row_dict = {
            'MEMBER': miembro['Nombres'],
            'BBVA': oficina['Direccion_Completa'],
            'DURATION': dura
        }
        rows_list.append(row_dict)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00,  2.02it/s]
# 2it [00:01,  1.99it/s]
# 3it [00:01,  2.08it/s]
# 4it [00:01,  2.17it/s]
# 5it [00:02,  2.16it/s]
# 6it [00:02,  2.13it/s]
# 7it [00:03,  2.15it/s]
# 8it [00:03,  2.07it/s]
# 9it [00:04,  2.09it/s]
# 10it [00:04,  1.93it/s]
# 11it [00:05,  1.98it/s]
# 12it [00:05,  2.12it/s]
# 13it [00:06,  1.93it/s]
# 14it [00:06,  1.83it/s]
# 15it [00:07,  1.99it/s]
# 16it [00:07,  2.28it/s]
# 17it [00:08,  2.42it/s]
# 18it [00:08,  2.28it/s]
# 19it [00:08,  2.31it/s]
# 20it [00:09,  2.18it/s]
# 21it [00:10,  2.07it/s]
# 22it [00:10,  2.13it/s]
# 23it [00:10,  2.05it/s]
# 24it [00:11,  2.19it/s]
# 25it [00:11,  2.30it/s]
# 26it [00:12,  2.36it/s]
# 27it [00:12,  2.05it/s]
# 28it [00:13,  1.96it/s]
# 29it [00:13,  2.14it/s]
# 30it [00:14,  2.28it/s]
# 31it [00:14,  2.32it/s]
# 32it [00:14,  2.37it/s]
# 33it [00:15,  1.94it/s]
# 34it [00:16,  1.75it/s]
# 35it [00:16,  1.73it/s]
# 36it [00:17,  1.60it/s]
# 37it [00:18,  1.84it/s]
# ...

# %%
df_times = pd.DataFrame(rows_list)
df_times
# Out:
#     MEMBER                                               BBVA  DURATION
# 0      Max  CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A, ...      40.0
# 1      Max      AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO, LIMA      41.0
# 2      Max  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...      31.0
# 3      Max                  AV. SAENZ PEN A 323, CALLAO, LIMA      34.0
# 4      Max  CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO, ...      32.0
# ..     ...                                                ...       ...
# 255   Luis  CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO,...      25.0
# 256   Luis  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...      27.0
# 257   Luis  AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTA...      24.0
# 258   Luis            AV. LA UNIVERSIDAD1810, LA MOLINA, LIMA      32.0
# 259   Luis                 AV. LA MOLINA 540, LA MOLINA, LIMA      26.0
#
# [260 rows x 3 columns]

# %% [markdown]
# 4. Finally, you have to give a report which offices are the most closest and furthest to every group member's address.

# %%
df_wide = df_times.pivot(index='BBVA', columns=['MEMBER'], values='DURATION').reset_index()
df_wide
# Out:
# MEMBER                                               BBVA  Jesus  Karen  \
# 0                     AV, COLONIAL 4584, BELLAVISTA, LIMA   40.0   19.0
# 1       AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...   41.0   15.0
# 2       AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARC...   38.0   57.0
# 3       AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...   39.0   22.0
# 4       AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...   25.0   44.0
# 5       AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...    9.0   48.0
# 6       AV. CARLOS IZAGUIRRE N.- 275, INDEPENDENCIA, LIMA   38.0   19.0
# 7          AV. CONTRALMIRANTE RAYGADA N°lll, CALLAO, LIMA   47.0   22.0
# 8           AV. CTRMTE. MORA S/N BASE NAVAL, CALLAO, LIMA   49.0   24.0
# 9       AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...   30.0   45.0
# 10                   AV. ELMER FAUCETT 6000, CALLAO, LIMA   46.0    7.0
# 11      AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...   39.0   34.0
# ...

# %%
for col in df_wide.columns[1:]:  # Start from the second column to skip BBVA
    min_time = df_wide[col].min()
    max_time = df_wide[col].max()
    
    # Find the indices of the rows where the minimum and maximum times are located
    min_index = df_wide[col].idxmin()
    max_index = df_wide[col].idxmax()
    address = df_grupo[df_grupo['Nombres'] == col]['Direccion_Casa'].values[0]

    print(f"For {col}:")
    print(f"  Address: {address}")
    print(f"  Minimum time: {min_time} minutes (BBVA office: {df_wide.loc[min_index, 'BBVA']})")
    print(f"  Maximum time: {max_time} minutes (BBVA office: {df_wide.loc[max_index, 'BBVA']})")
# Out:
# For Jesus:
#   Address: Av. Javier Prado Este 7107, La Molina, Lima
#   Minimum time: 7.0 minutes (BBVA office: AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTANA, LA MOLINA, LIMA)
#   Maximum time: 115.0 minutes (BBVA office: MALECdN ANDRAS A. CACERES MZ C-3, LT. 19, VENTANILLA, LIMA)
# For Karen:
#   Address: MZ b lt. 14-A, C. 7, Callao
#   Minimum time: 7.0 minutes (BBVA office: AV. ELMER FAUCETT 6000, CALLAO, LIMA)
#   Maximum time: 57.0 minutes (BBVA office: AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARCELA 2, CHORRILLOS, LIMA)
# For Luis:
#   Address: Jirón El Escorial 231- Santiago de Surco, Lima
#   Minimum time: 10.0 minutes (BBVA office: PLAZA BUTTERS 301, BARRANCO, LIMA)
#   Maximum time: 120.0 minutes (BBVA office: AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTOR, CARABAYLLO, LIMA)
# For Max:
#   Address: Jr. Enrique Pallardelli 159, Lima 15021
#   Minimum time: 9.0 minutes (BBVA office: AV. LOS PARACAS 203 URB. SALAMANCA, ATE, LIMA)
# ...
