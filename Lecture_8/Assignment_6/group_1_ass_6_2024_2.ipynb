# %% [markdown]
# **Group members** :
# - Max Chipani
# - Jesus Gamboa
# - Karen Salazar
# - Paolo Gutierrez
# - Luis Camarena

# %% [markdown]
# # Assigment 6
#
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**
#
# **GET YOUR GOOGLE API AND TOKEN. YOU WILL NEED THEM TO DO THIS TASK.**

# %% [markdown]
# 1. Import Data from [this url](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/bbva_list.xlsx). This dataset is in excel format. You have to convert to PandasDataFrame.
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.
# 3. Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.
# 4. Finally, you have to give a report which offices are the most closest and furthest to every group member's address.

# %% [markdown]
# ## Question 1

# %% [markdown]
# 1. Import Data from [this url](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/bbva_list.xlsx). This dataset is in excel format. You have to convert to PandasDataFrame.

# %%
import pandas as pd
df = pd.read_excel('../../_data/bbva_list.xlsx')
df.head(4)
# Out:
#                                            Direccion DEPARTAMENTO PROVINCIA  \
# 0       CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                    AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2  AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                AV. SAENZ PEN A 323         LIMA      LIMA
#
#   DISTRITO
# 0   CALLAO
# 1   CALLAO
# 2   CALLAO
# 3   CALLAO

# %%
df['Direccion_Completa'] = df['Direccion'] + ', ' + df['DISTRITO'] + ', ' + df['PROVINCIA']
df
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L...         LIMA      LIMA
# 10                                  AV, COLONIAL 4584         LIMA      LIMA
# 11      AV. LA MARINA 495 - URB. BENJAMIN DOIG LOSSIO         LIMA      LIMA
# 12                        KM. 25 CARRETERA VENTANILLA         LIMA      LIMA
# 13           MALECdN ANDRAS A. CACERES MZ C-3, LT. 19         LIMA      LIMA
# 14  AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...         LIMA      LIMA
# 15                 AV. LOS PARACAS 203 URB. SALAMANCA         LIMA      LIMA
# 16                       AV. NICOLAS AYLLON 2032-2036         LIMA      LIMA
# 17          LOCAL LS-201 - AV. NICOLAS AYLL6N N° 4770         LIMA      LIMA
# 18                    AV. NICOLAS AYLLON 8694, LC-105         LIMA      LIMA
# 19                                   AV. PROGRESO 102         LIMA      LIMA
# 20  AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...         LIMA      LIMA
# 21                      AV. GRAU 414 ESQ. CALLE UNION         LIMA      LIMA
# 22                                  PLAZA BUTTERS 301         LIMA      LIMA
# 23                                  AV. VENEZUELA 635         LIMA      LIMA
# 24                                 AV. VENEZUELA 1254         LIMA      LIMA
# 25                                     JR. HUARAZ1600         LIMA      LIMA
# 26      AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTO
AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...
# 29     CHORRILLOS    AV. MALECON DE LA RIBERA S/N., CHORRILLOS, LIMA
# 30     CHORRILLOS  AV. PROLG. PASEO DE LA REPllBLICA S/N - CCPLAZ...
# 31     CHORRILLOS        AV. GUARDIA CIVIL 152-156, CHORRILLOS, LIMA
# 32          COMAS               AV. TUPAC AMARU N° 1175, COMAS, LIMA
# 33          COMAS  AV. UNIVERSITARIA NORTE 7103, MZ. H LT. 22, UR...
# 34          COMAS  AV. UNIVERSITARIA 10583-10587, MZ. X LT. 3 -SE...
# 35          COMAS  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R...
# 36     ELAGUSTINO  AV. RIVA AG0ER01400-1404-1406, MZ. C LT. 27, E...
# 37  INDEPENDENCIA  AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...
# 38  INDEPENDENCIA  AV. CARLOS IZAGUIRRE N.- 275, INDEPENDENCIA, LIMA
# 39  INDEPENDENCIA  CRUCE AV. TOMAS VALLE CON PANAMERICANA NORTE, ...
# 40    JESUS MARIA  AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...
# 41    JESUS MARIA  CALLE HUAMACHUC01301-1307-1309, ESQ. CON REPll...
# 42    JESUS MARIA     AV. REP. DOMINICANA 355-359, JESUS MARIA, LIMA
# 43    JESUS MARIA  AV. GENERAL FELIPE SALAVERRY 2370, LS-04, JESU...
# 44    JESUS MARIA  RESIDENCIAL SAN FELIPE TDA. 23, JESUS MARIA, LIMA
# 45      LA MOLINA  AV. PROL. JAVIER PRADO ESTE 4921, LA MOLINA, LIMA
# 46      LA MOLINA  AV. RICARDO E. APARICIO 675, MZ. H LT. 1 -URB....
# 47      LA MOLINA  CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO,...
# 48      LA MOLINA  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...
# 49      LA MOLINA  AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTA...
# 50      LA MOLINA            AV. LA UNIVERSIDAD1810, LA MOLINA, LIMA
# 51      LA MOLINA                 AV. LA MOLINA 540, LA MOLINA, LIMA

# %% [markdown]
# 2. Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.

# %%
import os # File management
import urllib.request # For URLs
import json # Parse JSON responses received from APIs and convert Python objects to JSON format
import csv # Manage CSV files
import numpy as np # Numerical operations
from tqdm import tqdm # Progress bar in loops or iterations
import requests # Send HTTP requests to web servers, retrieve responses, and handle various types of HTTP methods
import unicodedata # Work with Unicode characters, including string normalization and removing accents
import time # Add wait time between requests
import re # Work with regular expressions
import googlemaps # Use the Google Maps API

# %%
def get_results( result_api ):
# To extract latitude and longitude from the API response
    try:
        lat = result_api[0]['geometry']['location']['lat']# Get the latitude
        lon = result_api[0]['geometry']['location']['lng']# Get the longitude  
    #Assign NaN if an error occurs    
    except:
        lat = np.nan # NaN, if latitude if extraction fails
        lon = np.nan # NaN, if longitude if extraction fails
    
    return ( lat, lon ) # Return the latitude and longitude as a tuple

# %%
from datetime import datetime # We import the datetime module to handle datetime operations
gmaps = googlemaps.Client(key='AIzaSyDVsqoJz94tGvPp8X0rPtaQCINH2DRndUE')# Set up the Google Maps API client using the given API key

# %%
df["results"] = df.apply( lambda x: get_results( gmaps.geocode( x["Direccion_Completa"], region = "pe")  )  , axis = 1 )  # Apply the function row by row
df # Display the DataFrame
# Out:
#                                             Direccion DEPARTAMENTO PROVINCIA  \
# 0        CENTRO AEREO COMERCIAL LOCALES 110 A Y 111 A         LIMA      LIMA
# 1                     AV. CTRMTE. MORA S/N BASE NAVAL         LIMA      LIMA
# 2   AV. ELMER FAUCETT Y ALEJANDRO BERTELLO, CC CAN...         LIMA      LIMA
# 3                                 AV. SAENZ PEN A 323         LIMA      LIMA
# 4        CALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO         LIMA      LIMA
# 5                    AV. CONTRALMIRANTE RAYGADA N°lll         LIMA      LIMA
# 6   AV. ELMERT FAUCETT N°2121 LOCALES N° 2-101,2-1...         LIMA      LIMA
# 7                              AV. ELMER FAUCETT 6000         LIMA      LIMA
# 8                   CENTRO COMERCIAL MINKA PABELL6N 2         LIMA      LIMA
# 9   AV. OSCAR R. BENAVIDES 3866, URB. EL AGUILA, L
AV. ASTURIAS 588 - INSTALAClON DE LA PLANTA BA...
# 15            ATE      AV. LOS PARACAS 203 URB. SALAMANCA, ATE, LIMA
# 16            ATE            AV. NICOLAS AYLLON 2032-2036, ATE, LIMA
# 17            ATE  LOCAL LS-201 - AV. NICOLAS AYLL6N N° 4770, ATE...
# 18            ATE         AV. NICOLAS AYLLON 8694, LC-105, ATE, LIMA
# 19            ATE                        AV. PROGRESO 102, ATE, LIMA
# 20            ATE  AV. 15 DE JULIO, LOTE 33, PROGRAMA ESPECIAL HU...
# 21       BARRANCO      AV. GRAU 414 ESQ. CALLE UNION, BARRANCO, LIMA
# 22       BARRANCO                  PLAZA BUTTERS 301, BARRANCO, LIMA
# 23         BREfiA                    AV. VENEZUELA 635, BREfiA, LIMA
# 24          BRENA                    AV. VENEZUELA 1254, BRENA, LIMA
# 25          BRENA                        JR. HUARAZ1600, BRENA, LIMA
# 26     CARABAYLLO  AV. TUPAC AMARU 3368, AAHH PROGRESO II SECTOR,...
# 27     CHORRILLOS  AV. ALAMEDA SUR, ESQ. CON AV. SAN MARCOS, PARC...
# 28     CHORRILLOS  AV. DEFENSORES DEL MORRO 456 - 458 - URB. LOS ...
# 29     CHORRILLOS    AV. MALECON DE LA RIBERA S/N., CHORRILLOS, LIMA
# 30     CHORRILLOS  AV. PROLG. PASEO DE LA REPllBLICA S/N - CCPLAZ...
# 31     CHORRILLOS        AV. GUARDIA CIVIL 152-156, CHORRILLOS, LIMA
# 32          COMAS               AV. TUPAC AMARU N° 1175, COMAS, LIMA
# 33          COMAS  AV. UNIVERSITARIA NORTE 7103, MZ. H LT. 22, UR...
# 34          COMAS  AV. UNIVERSITARIA 10583-10587, MZ. X LT. 3 -SE...
# 35          COMAS  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R...
# 36     ELAGUSTINO  AV. RIVA AG0ER01400-1404-1406, MZ. C LT. 27, E...
# 37  INDEPENDENCIA  AV. ALFREDO MENDIOLA3698 - C. C. CONO NORTE, T...
# 38  INDEPENDENCIA  AV. CARLOS IZAGUIRRE N.- 275, INDEPENDENCIA, LIMA
# 39  INDEPENDENCIA  CRUCE AV. TOMAS VALLE CON PANAMERICANA NORTE, ...
# 40    JESUS MARIA  AV. ARENALES N° 1302- HOSPITAL EDGARDO REBAGLI...
# 41    JESUS MARIA  CALLE HUAMACHUC01301-1307-1309, ESQ. CON REPll...
# 42    JESUS MARIA     AV. REP. DOMINICANA 355-359, JESUS MARIA, LIMA
# 43    JESUS MARIA  AV. GENERAL FELIPE SALAVERRY 2370, LS-04, JESU...
# 44    JESUS MARIA  RESIDENCIAL SAN FELIPE TDA. 23, JESUS MARIA, LIMA
# 45      LA MOLINA  AV. PROL. JAVIER PRADO ESTE 4921, LA MOLINA, LIMA
# 46      LA MOLINA  AV. RICARDO E. APARICIO 675, MZ. H LT. 1 -URB....
# 47      LA MOLINA  CA. LOS ALAMOS MZ C-2 LT. 5 - URB. EL REMANSO,...
# 48      LA MOLINA  AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...
# 49      LA MOLINA  AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FONTA...
# 50      LA MOLINA            AV. LA UNIVERSIDAD1810, LA MOLINA, LIMA
# 51      LA MOLINA                 AV. LA MOLINA 540, LA MOLINA, LIMA
#
#                               results
# 0   (-12.0419476, -77.09527159999999)
# 1     (-12.04328, -77.13602999999999)
# 2          (-12.0622495, -77.0665237)
# 3          (-12.0725987, -77.1637719)
# 4          (-12.0506798, -77.0871366)
# 5          (-12.0464501, -77.1400374)
# 6          (-12.0379707, -77.0986351)
# 7          (-11.9972712, -77.1245194)
# 8    (-12.048302, -77.10948069999999)
# 9          (-12.0565632, -77.1015012)
# 10         (-12.0534252, -77.0958897)
# 11         (-12.0675936, -77.1150711)
# 12         (-11.9189396, -77.1292166)
# 13         (-11.8453779, -77.1426224)
# 14         (-12.0489231, -76.9429983)
# 15         (-12.0762692, -76.9872565)
# 16         (-12.0637187, -76.9841939)
# 17  (-12.0107549, -76.87354859999999)
# 18  (-12.0149993, -76.88566759999999)
# 19          (-12.1428769, -76.949061)
# 20         (-12.0128372, -76.8244643)
# 21         (-12.1224698, -77.0348724)
# 22         (-12.1436565, -77.0154641)
# 23         (-12.0546784, -77.0429695)
# 24         (-12.0551379, -77.0519714)
# 25   (-12.055217, -77.05107249999999)
# 26  (-11.8738495, -77.01535919999999)
# 27  (-12.1965106, -77.01086289999999)
# 28         (-12.1684004, -77.0250008)
# 29          (-12.1019489, -77.061275)
# 30         (-12.1727686, -77.0132138)
# 31         (-12.1849877, -77.0067689)
# 32  (-11.9546103, -77.05230550000002)
# 33         (-11.9389892, -77.0590599)
# 34         (-11.9009721, -77.0403492)
# 35           (-11.944697, -77.028683)
# 36         (-11.9927244, -77.1100313)
# 37   (-11.994435, -77.06199269999999)
# 38          (-11.990461, -77.0620994)
# 39          (-12.008385, -77.0601759)
# 40         (-12.0781849, -77.0367809)
# 41    (-12.07313, -77.05037999999999)
# 42         (-12.0738899, -77.0489924)
# 43  (-12.0898612, -77.05266859999999)
# 44         (-12.0890763, -77.0544828)
# 45         (-12.0416185, -76.9245978)
# 46   (-12.077758, -76.91851199999999)
# 47         (-12.0976943, -76.9510851)
# 48         (-12.0677604, -76.9585341)
# 49         (-12.0737038, -76.9560571)
# 50  (-12.0823232, -76.92840249999999)
# 51         (-12.0640616, -76.9605648)

# %%
df.at[36,'results'] = (-12.04812197431508, -77.00035755361033)# Manually assign the coordinates in row 36 of the 'results' column

# %%
# List of names of group members
integrante  = ['Max','Jesus','Karen','Paolo','Luis']
# Address list of each member
direccion   = ['Jr. Enrique Pallardelli 159, Lima 15021','Av. Javier Prado Este 7107, La Molina, Lima','MZ b lt. 14-A, C. 7, Callao','Sector 1 Grupo 13 Manzana A Lote 1, Villa El Salvador, Lima','Jirón El Escorial 231- Santiago de Surco, Lima']
# Create a Pandas DataFrame with two columns: 'Nombres' and 'Direccion_Casa'
df_grupo    = pd.DataFrame({'Nombres': integrante, 'Direccion_Casa': direccion})
# Show the created DataFrame
df_grupo
# Out:
#   Nombres                                     Direccion_Casa
# 0     Max            Jr. Enrique Pallardelli 159, Lima 15021
# 1   Jesus        Av. Javier Prado Este 7107, La Molina, Lima
# 2   Karen                        MZ b lt. 14-A, C. 7, Callao
# 3   Paolo  Sector 1 Grupo 13 Manzana A Lote 1, Villa El S...
# 4    Luis     Jirón El Escorial 231- Santiago de Surco, Lima

# %%
df_grupo["direc_casa"] = df_grupo.apply( lambda x: get_results( gmaps.geocode( x["Direccion_Casa"], region = "pe")  )  , axis = 1 ) # Apply row by row function to obtain geographic coordinates
# Show the DataFrame with the new column df_grupo
df_grupo
# Out:
#   Nombres                                     Direccion_Casa  \
# 0     Max            Jr. Enrique Pallardelli 159, Lima 15021
# 1   Jesus        Av. Javier Prado Este 7107, La Molina, Lima
# 2   Karen                        MZ b lt. 14-A, C. 7, Callao
# 3   Paolo  Sector 1 Grupo 13 Manzana A Lote 1, Villa El S...
# 4    Luis     Jirón El Escorial 231- Santiago de Surco, Lima
#
#                    direc_casa
# 0  (-12.0853415, -76.9953809)
# 1  (-12.0652762, -76.9420926)
# 2  (-11.9978637, -77.1085318)
# 3  (-12.2165935, -76.9312468)
# 4  (-12.1301563, -77.0023514)

# %% [markdown]
# ## Avance K- borrar la 3ra persona
