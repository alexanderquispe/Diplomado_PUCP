# %% [markdown]
# # 1 Assignment 3

# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request

# %% [markdown]
# 1. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %%
#Para leer las bases de datos necesitamos instalar los siguientes paquetes
# !pip install pyreadstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 30.6 MB/s eta 0:00:00
# ...

# %%
# !pip install savReaderWriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for savReaderWriter: filename=savReaderWriter-3.4.2-py3-none-any.whl size=51142021 sha256=5ce7bc335bc5c596534af3f526ce9a95ef0dbdcec9c56a3d0ccd23dcc4ac69bd
#   Stored in directory: /root/.cache/pip/wheels/da/4b/be/7d3f512ed6ed438b2a72c00a0e568b37930b461f29c0e59e09
# Successfully built savReaderWriter
# ...

# %%
import savReaderWriter as sav
#importamos la función como sav

# %%
from google.colab import drive
#guardamos las bases de datos en una carpeta drive, por lo cual, es necesario vincular el Colab con este aplicativo

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#Importamos las bases de datos de interés en Endes 2019 y les asignamos los siguientes nombres:
rec1 = pd.read_spss(r"/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/REC0111.sav")
rec2 = pd.read_spss(r"/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/RE223132.sav")
rec3 = pd.read_spss(r"/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/RE516171.sav")

# %%
rec1. head(2) #la base tiene 105 variables (columnas)
# Out:
#       ID1             HHID              CASEID  V001  V002  V003  V004  \
# 0  2019.0        000100201        000100201  2   1.0   2.0   2.0   1.0
# 1  2019.0        000100201        000100201  3   1.0   2.0   3.0   1.0
#
#      V007    V008  V009  ...  QD333_4  QD333_5  QD333_6  UBIGEO V022  \
# 0  2019.0  1434.0   4.0  ...       No       No       No  010101  3.0
# 1  2019.0  1434.0   1.0  ...       No       No       No  010101  3.0
#
#        V005  V190     V191                                   mujeres12a49  \
# 0  154803.0  Rico  1.23445                Mujeres de 15 a 49 años de edad
# 1  154803.0  Rico  1.23445  Mujeres de 12 a 14 de edad, nunca embarazadas
#
#    NCONGLOME
# 0     7065.0
# 1     7065.0
#
# [2 rows x 105 columns]

# %%
#Asginamos los directorios en donde se encuentran las bases a los siguientes elementos para simplificar el código posterior
link_1 = "/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/REC0111.sav"
link_2 = "/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/RE223132.sav"
link_3 = "/content/drive/MyDrive/DIPLOMADO_PUCP/Fundamentos_Python/endes/2019/RE516171.sav"

#obtenemos las etiquetas de los valores y de las variables desde el sav file
with sav.SavHeaderReader( link_1, 
                         ioUtf8=True) as header:
    metadata1 = header.all()
    value_labels1 = metadata1.valueLabels
    var_labels1 = metadata1.varLabels

#el código relativo a la segunda base
with sav.SavHeaderReader(link_2,
                         ioUtf8=True) as header:
    metadata2 = header.all()
    value_labels2 = metadata2.valueLabels
    var_labels2 = metadata2.varLabels
    
#el código relativo a la tercera base
with sav.SavHeaderReader(link_3,
                         ioUtf8=True) as header:
    metadata3 = header.all()
    value_labels3 = metadata3.valueLabels
    var_labels3 = metadata3.varLabels

# %%
#Ahora contamos con las etiquetas de los valores y las etiquetas de las variables en diccionarios
print(var_labels1)
print(value_labels1)
# Out:
# {'ID1': 'Año', 'HHID': 'Identificación Cuestionario del Hogar', 'CASEID': 'Identificación Cuestionario Individual', 'V001': 'Conglomerado', 'V002': 'Número de vivienda', 'V003': 'Número de línea de entrevistada', 'V004': 'Unidad de área final', 'V007': 'Año de la entrevista', 'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)', 'V009': 'Mes de nacimiento de la entrevistada', 'V010': 'Año de nacimiento de la entrevistada', 'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)', 'V012': 'Edad actual - entrevistada', 'V013': 'Edad actual por grupos de 5 años', 'V014': 'Integridad de la información para la fecha de nacimiento ', 'V015': 'Resultado entrevista individual', 'V017': 'Inicio del calendario, Codificación centenaria de mesesl CMC', 'V018': 'Columna del mes de la entrevista', 'V019': 'Duración del calendario', 'V019A': 'Número de columnas de calendario', 'V020': 'Muestra alguna vez casada', 'V021': 'Unidad de muestreo primario - conglomerado',
# ...

# %% [markdown]
# 2. Select the following columns for each data set:
#
#
#
#
# Data|Columns
# --- | ---
# rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133
# rec2| CASEID, V201, V218, V301, V302, V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380
# rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715
# -
#
# Additioanlly, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter. Update the dictionary.**

# %%
#Primero filtramos las bases para quedarnos solo con las columnas (variables) requeridas
rec1_1 = rec1.loc[ : , ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 
                        'V010', 'V011', 'V012', 'V024', 'V102', 'V120', 'V121', 'V122', 'V123',
                        'V124', 'V125', 'V127', 'V133'] ]

rec2_2 = rec2.loc[ : , ['CASEID', 'V201', 'V218', 'V301', 'V302', 'V323', 'V323A', 'V325A', 'V326', 
                        'V327', 'V337', 'V359', 'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 
                        'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380'] ]

rec3_3 = rec3.loc[ : , ['CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507', 'V508', 
                        'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V613', 'V714', 'V715'] ]

# %%
print(len(rec1_1.columns), len(rec2_2.columns), len(rec3_3.columns))
#como se observa, ahora contamos con una base REC0111 acotada a 22 columnas, una base RE223132 acotada a 25 columnas y una base RE516171 acotada a 18 columnas
# Out:
# 22 25 18

# %%
rec1_1.columns.values
#ahora nos concentraremos en actualizar las etiquetas de variables y valores
# Out:
# array(['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008',
#        'V009', 'V010', 'V011', 'V012', 'V024', 'V102', 'V120', 'V121',
#        'V122', 'V123', 'V124', 'V125', 'V127', 'V133'], dtype=object)

# %%
new_keys1 = rec1_1.columns.values #generamos un array con el nombre de las variables de interés (new_keys1 para la base acotada de REC0111)
#estamos interesados en quedarnos con las etiquetas de variables y de valores que apliquen para las variables de la base acotada 
new_value_labels1 = { key:value for ( key, value ) in value_labels1.items() if key in new_keys1 } #Por ello generamos nuevos diccionarios para las etiquetas que cumplan la condición de que sus llaves forman parte del array de strings: new_keys1, new_keys2 y new_keys3 (según corresponda)
new_var_labels1 = { key:value for ( key, value ) in var_labels1.items() if key in new_keys1 }

#replicamos el código previo para la base acotada de RE223132
new_keys2 = rec2_2.columns.values
new_value_labels2 = { key:value for ( key, value ) in value_labels2.items() if key in new_keys2 }
new_var_labels2 = { key:value for ( key, value ) in var_labels2.items() if key in new_keys2 }

#replicamos el código previo para la base acotada de RE516171 
new_keys3 = rec3_3.columns.values
new_value_labels3 = { key:value for ( key, value ) in value_labels3.items() if key in new_keys3 }
new_var_labels3 = { key:value for ( key, value ) in var_labels3.items() if key in new_keys3 }

# %%
print(len(new_var_labels1), len(new_var_labels2), len(new_var_labels3)) # ahora los diccionarios de variables new_var_labels1, new_var_labels2 y new_var_labels3 consideran solo a 22, 25 y 18 elementos, respectivamente
#esto coincide con el filtro realizado a las respectivas bases de datos
# Out:
# 22 25 18

# %% [markdown]
# 3. Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %%
#generamos una nueva columna en rec1_1 con 2019 para todas las observaciones
rec1_1.loc[ : , "year" ] = 2019
rec1_1
# Out:
#                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0            000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1            000100201  3  PE6     1.0   2.0   3.0     1.0  2019.0  1434.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2019.0  1434.0
# 3            000102801  6  PE6     1.0  28.0   6.0     1.0  2019.0  1434.0
# 4            000104801  2  PE6     1.0  48.0   2.0     1.0  2019.0  1434.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 38330        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 38331        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 38332        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 38333        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 38334        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
#        V009    V010  ...    V102  V120 V121 V122 V123 V124 V125  \
# ...

# %%
#generamos una nueva llave para la variable generada y actualizamos el diccionario de nombres de variables
new_var_labels1.update( {"year" : "Year of the survey"} )
new_var_labels1
# Out:
# {'CASEID': 'Identificación Cuestionario Individual',
#  'V001': 'Conglomerado',
#  'V002': 'Número de vivienda',
#  'V003': 'Número de línea de entrevistada',
#  'V004': 'Unidad de área final',
#  'V007': 'Año de la entrevista',
#  'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)',
#  'V009': 'Mes de nacimiento de la entrevistada',
#  'V010': 'Año de nacimiento de la entrevistada',
#  'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)',
#  'V012': 'Edad actual - entrevistada',
#  'V024': 'Región',
#  'V000': 'Código y fase del país',
#  'V102': 'Tipo de lugar de residencia',
#  'V120': 'En su hogar tiene: radio',
#  'V121': 'En su hogar tiene: televisión',
#  'V122': 'En su hogar tiene: refrigerador',
#  'V123': 'En su hogar tiene: bicicleta',
#  'V124': 'En su hogar tiene: motocicleta/motocar',
#  'V125': 'En su hogar tiene: coche/camión',
#  'V127': 'Material predominante del piso de la vivienda',
#  'V133': 'Educación en años simples',
# ...

# %% [markdown]
# 4. Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`. **Hint: Use [this link](https://stackoverflow.com/questions/53645882/pandas-merging-101)**

# %%
#para unir las bases de datos generadas usamos como identificar común la variable CASEID
endes_2019 = rec1_1.merge(rec2_2, on = "CASEID", how = "inner").merge(rec3_3, on = "CASEID", how = "inner")
endes_2019.tail() #la base unificada cuenta con 33´310 observaciones y 64 variables (columnas)
# Out:
#                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 33306        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 33307        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 33308        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 33309        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 33310        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
#        V009    V010  ...    V508    V509             V510  V511  V512  \
# 33306  12.0  1971.0  ...  1985.0  1032.0  Tiene mes y año  14.0  34.0
# 33307   6.0  1988.0  ...  2002.0  1236.0  Tiene mes y año  14.0  17.0
# 33308   7.0  1973.0  ...  1986.0  1043.0  Tiene mes y año  13.0  33.0
# 33309  12.0  1994.0  ...  2008.0  1301.0  Tiene mes y año  13.0  11.0
# 33310  10.0  1996.0  ...  2013.0  1362.0  Tiene mes y año  16.0   6.0
#
#                    V513  V525 V613 V714  V715
# 33306  De 30 a más años  12.0  3.0   No   5.0
# ...

# %% [markdown]
# 5. Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. **Hint: Use `update` method.**

# %%
#Etiquetas de variables 
var_labels = new_var_labels1.copy() #generamos un diccionario que contenga el diccionario de las etiquetas de variables que corresponden con la base acotadad de REC0111
var_labels.update(new_var_labels2) #Actualizamos el diccionario, introduciendo el diccionario de etiquetas de variables de la base acotada RE223132
var_labels.update(new_var_labels3) #Operación análoga a la anterior, pero para la base acotada RE516171 

#Etiquetas de valores
value_labels = new_value_labels1.copy() #de forma similar a lo realizado previamente, generamos una copia del primer diccionario de etiquetas de valores y actualizamos dicho diccionario agregando las etiquetas relativas a las bases acotadas RE223132 y RE516171 
value_labels.update(new_value_labels2)
value_labels.update(new_value_labels3)

endes_2019.attrs[ 'value_labels' ] = value_labels
endes_2019.attrs[ 'var_labels' ] = var_labels

# %%
type(var_labels)
# Out:
# dict

# %% [markdown]
# 6. Get the min, max, sd, n_obs, n_missing for the following columns **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)**. We want a dataframe with the following columns **Variables, Min, Max, Mean, N_obs, N_missing** and sort by the number of missing rows. **Hint: Use `describe` and `pivot` methods**

# %%
# Primero, seleccionamos las columnas de interés más la columna "CASEID", o identificador único por encuestado. 
# Guardamos este subconjunto en el objeto subset
sub = endes_2019[ [ "V201", "V613", "V715", "V511" ] ]
sub.dtypes
sub.shape
# Out:
# (33311, 4)

# %%
# Las variables "V613" y "V715" son categóricas, y no se podrá obtener estadísticas descriptivas de ellas usando el método describe.
# Por tanto, lo ideal es convertirlas a numericas.
# Para ello, observamos la proporción de valores únicos en ambas variables
sub['V613'].value_counts()
# La variable "V613" muestra 51/33311 ocurrencias de la respuesta "Respuesta no numérica".
# La variable "V613" muestra 255/33311 ocurrencias de la respuesta "No sabe".
# Out:
# 11.0    9442
# 14.0    3610
# 16.0    2764
# 6.0     2115
# 9.0     1390
# 13.0    1078
# 8.0      805
# 5.0      777
# 10.0     653
# 12.0     599
# 3.0      564
# 7.0      441
# 4.0      336
# 15.0     291
# 2.0      277
# 0.0      202
# 17.0     166
# 1.0      116
# Name: V613, dtype: int64

# %%
sub['V715'].value_counts()
# Out:
# 11.0    9442
# 14.0    3610
# 16.0    2764
# 6.0     2115
# 9.0     1390
# 13.0    1078
# 8.0      805
# 5.0      777
# 10.0     653
# 12.0     599
# 3.0      564
# 7.0      441
# 4.0      336
# 15.0     291
# 2.0      277
# 0.0      202
# 17.0     166
# 1.0      116
# Name: V715, dtype: int64

# %%
# Las respuestas anteriormente mencionadas no permiten que las variables "V613" y "V715" se conviertan en numéricas.
# Dado que su ocurrencia es muy pequeña con respecto al tamaño total de la base de datos, se descartan dichas respuestas.
sub = sub[sub[ 'V715'] != "No sabe" ]
sub = sub[sub[ 'V613' ] != "Respuesta no numérica" ]
# Posteriormente, se convierte las columnas "V613" y "V715" a numéricas.
sub[[ 'V715', 'V613' ]] = sub[ [ 'V613', 'V715' ] ].apply(pd.to_numeric, errors='coerce' )
sub.dtypes
# Out:
# V201    float64
# V613    float64
# V715    float64
# V511    float64
# dtype: object

# %%
# Generamos una tabla descriptiva transpuesta de la subase "sub" denominada "desc". Observamos que el número de observaciones totales 
desc = sub.describe().T
desc
# Out:
#         count       mean       std   min   25%   50%   75%   max
# V201  33311.0   1.975113  1.734790   0.0   1.0   2.0   3.0  13.0
# V613  25626.0  10.764965  3.578349   0.0   9.0  11.0  14.0  17.0
# V715  33260.0   2.311906  1.183034   0.0   2.0   2.0   3.0  20.0
# V511  25881.0  20.463738  4.858358  10.0  17.0  19.0  23.0  48.0

# %%
# Nos quedamos solo con los estadísticos descriptivos solicitados
desc = desc[["min", "max", "mean", "count"]]
desc
# Out:
#        min   max       mean    count
# V201   0.0  13.0   1.975113  33311.0
# V613   0.0  17.0  10.764965  25626.0
# V715   0.0  20.0   2.311906  33260.0
# V511  10.0  48.0  20.463738  25881.0

# %%
# Creamos el estadístico descriptivo "N_Missings" como la resta de "count" menos el número de observaciones total de la base: 33311
# "La variable "count" es en realidad el número de observaciones.

# %%
desc["N_missings"] = 33311 - desc["count"]
# Out:
# <ipython-input-69-cf5fea05c3ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desc["N_missings"] = 33311 - desc["count"]

# %%
# Finalmente, reseteamos el índice, y cambiamos de nombre a las variables "count" e "index".
desc = desc.reset_index()
desc = desc.rename(columns = {"count": "N_obs",
                              "index": "variables"})
desc
# Out:
#   variables   min   max       mean    N_obs  N_missings
# 0      V201   0.0  13.0   1.975113  33311.0         0.0
# 1      V613   0.0  17.0  10.764965  25626.0      7685.0
# 2      V715   0.0  20.0   2.311906  33260.0        51.0
# 3      V511  10.0  48.0  20.463738  25881.0      7430.0

# %% [markdown]
# 7. Use `endes_2019` data to generate a new object named `mean_key_vars` to find the mean of **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)** by year and department **(V024)**. Name these columns as **mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage**, respectively. **Hint: Use groupby and [this link](https://stackoverflow.com/questions/40901770/is-there-a-simple-way-to-change-a-column-of-yes-no-to-1-0-in-a-pandas-dataframe).**

# %%
#Transform two categorical variables into numeric ones
endes_2019[[ 'V715', 'V613' ]] = endes_2019[ [ 'V613', 'V715' ] ].apply(pd.to_numeric, errors = 'coerce' )
#Verify the type of variable
endes_2019[[ 'year','V024', 'V201', 'V613', 'V715', 'V511' ]].dtypes
# Out:
# year       int64
# V024    category
# V201     float64
# V613     float64
# V715     float64
# V511     float64
# dtype: object

# %%
#Create a new base where variable of interest are kept
new_base = endes_2019[[ 'year','V024', 'V201', 'V613', 'V715', 'V511' ]]

# %%
#Group new base in terms of department and year and then we obtain mean of every variable
mean_key_vars = new_base.groupby( [ 'year', 'V024' ] ).mean()
#Rename columns and reset index.
mean_key_vars = mean_key_vars.rename(columns = {"V201": "Total children (mean)",
                          "V613": "Ideal number of children (mean)",
                          "V715": "Husbands education-single yrs (mean)",
                          "V511": "Age at first marriage (mean)"}).reset_index()
mean_key_vars
# Out:
#     year            V024  Total children (mean)  \
# 0   2019         Huanuco               2.252900
# 1   2019             Ica               1.823175
# 2   2019           Junin               2.034834
# 3   2019     La Libertad               1.896188
# 4   2019      Lambayeque               1.836445
# 5   2019            Lima               1.608636
# 6   2019          Loreto               2.493190
# 7   2019   Madre de Dios               2.202166
# 8   2019        Moquegua               1.752089
# 9   2019           Pasco               2.080193
# 10  2019           Piura               2.015672
# 11  2019            Puno               1.977733
# 12  2019      San Martin               2.100392
# 13  2019           Tacna               1.544563
# 14  2019          Tumbes               1.938121
# 15  2019         Ucayali               2.290015
# 16  2019        Amazonas               2.257258
# 17  2019          Ancash               1.962996
# ...

# %% [markdown]
# 8. Reshape `mean_key_vars` from wide to long. We want a dataframe with three columns **dpto, variables, values**. Name this object as `reshape_mean_key_vars`. **Hint: Use melt method**.

# %%
me_melt = mean_key_vars.copy()
me_melt.tail()
# Out:
#     year          V024  Total children (mean)  \
# 20  2019      Ayacucho               2.052257
# 21  2019     Cajamarca               2.180258
# 22  2019        Callao               1.696154
# 23  2019         Cusco               2.109815
# 24  2019  Huancavelica               2.364774
#
#     Ideal number of children (mean)  Husbands education-single yrs (mean)  \
# 20                         2.209026                             10.470772
# 21                         2.545923                              8.708874
# 22                         2.241724                             11.663909
# 23                         2.100097                             10.569194
# 24                         2.295098                              9.879221
#
#     Age at first marriage (mean)
# 20                     20.340228
# 21                     19.610695
# 22                     21.517241
# 23                     20.283154
# 24                     19.780769

# %%
#queremos contar con los resultados de medias para cada departamento en diferentes filas
reshape_mean_key_vars = pd.melt(me_melt, id_vars=["year", "V024"], value_vars=["Total children (mean)", "Ideal number of children (mean)", "Husbands education-single yrs (mean)", "Age at first marriage (mean)"]).sort_values(by=['V024'])
#El código anterior establece a la variable de departamento como identificadora y ordena el resto de variables de forma que los resultados presentes anteriormente en distintas columnas, ahora ocupen distintas filas
reshape_mean_key_vars.rename(columns = {'V024':'depto'}, inplace = True) #cambiamos permanentemente el nombre de la columna departamento
reshape_mean_key_vars.head(8)
# Out:
#     year     depto                              variable      value
# 0   2019   Huanuco                 Total children (mean)   2.252900
# 50  2019   Huanuco  Husbands education-single yrs (mean)   8.842528
# 75  2019   Huanuco          Age at first marriage (mean)  19.818632
# 25  2019   Huanuco       Ideal number of children (mean)   2.446940
# 76  2019       Ica          Age at first marriage (mean)  20.747208
# 26  2019       Ica       Ideal number of children (mean)   2.353429
# 51  2019       Ica  Husbands education-single yrs (mean)  11.825332
# 1   2019       Ica                 Total children (mean)   1.823175

# %%
#Alternativamente, podemos aplicar los siguientes códigos y obtener un resultado similar
me_2 = me.copy() #copiamos el objeto de forma que preservemos la versión original 
me_2 = me_2.reset_index() #restablecemos los índices del objeto 
me_stack = me_2.set_index(  [ 'year' ,'V024']  ).stack().reset_index().rename( {"level_2" : "variable", 
                                                                                0 : "values" }, axis = 1 )
#la línea de código anterior establece como identificar de los elementos del dataframe a las variables de año y departamento y modifica los nombres de las columnas relativas a los resultados de medias 
me_stack.rename(columns = {'V024':'depto'}, inplace = True) #cambiamos el nombre de la columna de departamento (de 'V024' a 'depto')
me_stack.head(8)
# Out:
#    year     depto                              variable     values
# 0  2019   Huanuco                 Total children (mean)   2.252900
# 1  2019   Huanuco       Ideal number of children (mean)   8.842528
# 2  2019   Huanuco  Husbands education-single yrs (mean)   2.446940
# 3  2019   Huanuco          Age at first marriage (mean)  19.818632
# 4  2019       Ica                 Total children (mean)   1.823175
# 5  2019       Ica       Ideal number of children (mean)  11.825332
# 6  2019       Ica  Husbands education-single yrs (mean)   2.353429
# 7  2019       Ica          Age at first marriage (mean)  20.747208

# %% [markdown]
# 9. Replicate your answers for questions 7 and 8, but in one line of code. Make it the most simple as possible. **NO HINT**

# %%
base = endes_2019.loc[:,['year','V024', 'V201', 'V613', 'V715', 'V511' ]].groupby( [ 'year', 'V024' ] ).mean().reset_index().rename(columns = {'V024':'depto', "V201": "Total children (mean)", "V613": "Ideal number of children (mean)", "V715": "Husbands education-single yrs (mean)", "V511": "Age at first marriage (mean)"})
oneliner = pd.melt(base, id_vars=["year", "depto"], value_vars=base.iloc[:,2:]).sort_values(by=['depto'])
#nuestra aproximación si bien implica dos líneas de código, simplifica sustancialmente el desarrollo previo
#filtramos la base endes_2019 a través de un operador loc, agrupando los datos por año y departamento, y obteniendo la media. La primera línea también cambia el nombre de las columnas. La base acotada es reestructurada a través de la función melt

# %% [markdown]
# 10. Merge `reshape_mean_key_vars` with `endes_2019`. Name this object `final_result`. **Hint: Use merge.**

# %%
new_df = pd.merge(reshape_mean_key_vars, endes_2019,  how='left', left_on=['year', 'depto'], right_on = ['year','V024'])
#ambos objetos comparten los identificadores de años y departamento, por ello los usamos como llaves para hacer el merge
#dado que renombramos la variable V024 en reshape_mean_key_vars, debemos incluir su denominación en el left_on
new_df
# Out:
#         year         depto                      variable      value  \
# 0       2019       Huanuco         Total children (mean)   2.252900
# 1       2019       Huanuco         Total children (mean)   2.252900
# 2       2019       Huanuco         Total children (mean)   2.252900
# 3       2019       Huanuco         Total children (mean)   2.252900
# 4       2019       Huanuco         Total children (mean)   2.252900
# ...      ...           ...                           ...        ...
# 133239  2019  Huancavelica  Age at first marriage (mean)  19.780769
# 133240  2019  Huancavelica  Age at first marriage (mean)  19.780769
# 133241  2019  Huancavelica  Age at first marriage (mean)  19.780769
# 133242  2019  Huancavelica  Age at first marriage (mean)  19.780769
# 133243  2019  Huancavelica  Age at first marriage (mean)  19.780769
#
#                     CASEID V000    V001   V002  V003    V004  ...    V508  \
# 0             052003101  4  PE6   520.0   31.0   4.0   520.0  ...     NaN
# ...
