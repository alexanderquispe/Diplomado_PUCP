# %% [markdown]
# # Assignment 3

# %%
#pip install pyreadstat

# %%
#pip install savReaderWriter

# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request
import pyreadstat

# %% [markdown]
# 1. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %%
# Importar los archivos y obtener etiquetas de variables y valores
rec1, meta_1 = pyreadstat.read_sav( r"../../_data/endes/2019/REC0111.sav")
var_labels1 = meta_1.variable_value_labels
value_labels1 = meta_1.value_labels

rec2, meta_2 = pyreadstat.read_sav(r"../../_data/endes/2019/RE223132.sav")
var_labels2 = meta_2.variable_value_labels
value_labels2 = meta_2.value_labels

rec3, meta_3 = pyreadstat.read_sav( r"../../_data/endes/2019/RE516171.sav")
var_labels3 = meta_3.variable_value_labels
value_labels3 = meta_3.value_labels

# %%
var_labels1
# Out:
# {'V013': {0.0: 'De 12 a 14 años de edad',
#   1.0: 'De 15 a 19 años de edad',
#   2.0: 'De 20 a 24 años de edad',
#   3.0: 'De 25 a 29 años de edad',
#   4.0: 'De 30 a 34 años de edad',
#   5.0: 'De 35 a 39 años de edad',
#   6.0: 'De 40 a 44 años de edad',
#   7.0: 'De 45 a 49 años de edad'},
#  'V014': {1.0: 'Mes y año',
#   2.0: 'Mes y edad - año imputado',
#   3.0: 'Año y edad - mes imputado',
#   4.0: 'Año y edad - año ignorado supera el año de entrevista',
#   5.0: 'Año - edad y mes imputados',
#   6.0: 'Edad - año y mes imputados',
#   7.0: 'Mes - edad y año imputados',
#   8.0: 'Ninguno - edad, mes y año imputados'},
#  'V015': {1.0: 'Completa',
#   2.0: 'Ausente',
#   3.0: 'Aplazada',
#   4.0: 'Rechazada',
#   5.0: 'Incoompleta',
#   6.0: 'Discapacitada',
#   7.0: 'Otra'},
#  'V018': {0.0: 'Sin calendario'},
#  'V019': {0.0: 'Sin calendario'},
#  'V020': {0.0: 'Toda la mujer muestra', 1.0: 'Alguna muestra casada'},
#  'V023': {1.0: 'Amazonas',
#   2.0: 'Ancash',
# ...

# %%
value_labels1
# Out:
# {'labels0': {0.0: 'De 12 a 14 años de edad',
#   1.0: 'De 15 a 19 años de edad',
#   2.0: 'De 20 a 24 años de edad',
#   3.0: 'De 25 a 29 años de edad',
#   4.0: 'De 30 a 34 años de edad',
#   5.0: 'De 35 a 39 años de edad',
#   6.0: 'De 40 a 44 años de edad',
#   7.0: 'De 45 a 49 años de edad'},
#  'labels1': {1.0: 'Mes y año',
#   2.0: 'Mes y edad - año imputado',
#   3.0: 'Año y edad - mes imputado',
#   4.0: 'Año y edad - año ignorado supera el año de entrevista',
#   5.0: 'Año - edad y mes imputados',
#   6.0: 'Edad - año y mes imputados',
#   7.0: 'Mes - edad y año imputados',
#   8.0: 'Ninguno - edad, mes y año imputados'},
#  'labels2': {1.0: 'Completa',
#   2.0: 'Ausente',
#   3.0: 'Aplazada',
#   4.0: 'Rechazada',
#   5.0: 'Incoompleta',
#   6.0: 'Discapacitada',
#   7.0: 'Otra'},
#  'labels3': {0.0: 'Sin calendario'},
#  'labels4': {0.0: 'Sin calendario'},
#  'labels5': {0.0: 'Toda la mujer muestra', 1.0: 'Alguna muestra casada'},
#  'labels6': {1.0: 'Amazonas',
# ...

# %%
value_labels2
# Out:
# {'labels0': {0.0: 'No o no está segura', 1.0: 'Sí'},
#  'labels1': {994.0: 'En la menopausia',
#   995.0: 'Antes del último nacimiento',
#   996.0: 'Nunca menstruado',
#   997.0: 'Inconsistente',
#   998.0: 'No sabe'},
#  'labels2': {0.0: 'No', 1.0: 'Si'},
#  'labels3': {1.0: 'Durante su periodo',
#   2.0: 'Después de su período',
#   3.0: 'En medio del ciclo',
#   4.0: 'Antes del período',
#   5.0: 'En cualquier momento',
#   6.0: 'Otro',
#   8.0: 'No sabe'},
#  'labels4': {6.0: '6+'},
#  'labels5': {996.0: 'Intervalo Negativo'},
#  'labels6': {7.0: 'Mes - fecha exacta', 8.0: 'Ninguno - fecha de colocación'},
#  'labels7': {1.0: 'En ese momento',
#   2.0: 'Querìa esperar',
#   3.0: 'No querìa tener (màs) hijas/hijos'},
#  'labels8': {994.0: 'En la menopausia',
#   995.0: 'Antes del último nacimiento',
#   996.0: 'Nunca menstruado',
#   997.0: 'Inconsistente',
#   998.0: 'No sabe'},
#  'labels9': {0.0: 'No marcado',
#   1.0: 'N> int. desde el nacimiento',
# ...

# %%
value_labels3
# Out:
# {'labels0': {0.0: 'Nunca casada',
#   1.0: 'Casado',
#   2.0: 'Viviendo juntos',
#   3.0: 'Viuda',
#   4.0: 'Divorciada',
#   5.0: 'No viven juntos'},
#  'labels1': {0.0: 'Nunca casada',
#   1.0: 'Actualmente casada',
#   2.0: 'Anteriormente casada'},
#  'labels2': {1.0: 'Una vez', 2.0: 'Mas de una vez'},
#  'labels3': {1.0: 'Vive con ella', 2.0: 'Vive en otro sitio'},
#  'labels4': {0.0: 'No otras esposas', 98.0: 'No sabe'},
#  'labels5': {98.0: 'No sabe'},
#  'labels6': {1.0: 'Tiene mes y año',
#   2.0: 'Tiene mes y edad - imputa año',
#   3.0: 'Tiene año y edad - imputa mes',
#   5.0: 'Tiene año - imputa mes',
#   6.0: 'Tiene edad - imputa mes año',
#   7.0: 'Tiene mes - imputa año',
#   8.0: 'Ninguno - imputa todo'},
#  'labels7': {0.0: 'Nunca casada',
#   1.0: 'De 0 a 4 años',
#   2.0: 'De 5 a 9 años',
#   3.0: 'De 10 a 14 años',
#   4.0: 'De 15 a 19 años',
#   5.0: 'De 20 a 24 años',
#   6.0: 'De 25 a 29 años',
#   7.0: 'De 30 a más años'},
# ...

# %%
# adding labels to variables
rec1.attrs[ 'value_labels1' ] = value_labels1
rec1.attrs[ 'var_labels1' ] = var_labels1

rec2.attrs[ 'value_labels2' ] = value_labels2
rec2.attrs[ 'var_labels2' ] = var_labels2

rec3.attrs[ 'value_labels3' ] = value_labels3
rec3.attrs[ 'var_labels3' ] = var_labels3

# %% [markdown]
# 2. Select the following columns for each data set:
# |Data|Columns|
# |---|---|
# |rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133 |
# |rec2| CASEID, V201, V218, V301, V302, V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380 |
# |rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715 |
#
#
# Additioanlly, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter. Update the dictionary.**

# %%
# Make a dictionary of the columns in each data set that should be chosen
rec1_1 = rec1.loc[ : , ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 
                        'V010', 'V011', 'V012', 'V024', 'V102', 'V120', 'V121', 'V122', 'V123',
                        'V124', 'V125', 'V127', 'V133'] ]

rec2_1 = rec2.loc[ : , ['CASEID', 'V201', 'V218', 'V301', 'V302', 'V323', 'V323A', 'V325A', 'V326', 
                        'V327', 'V337', 'V359', 'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 
                        'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380'] ]

rec3_1 = rec3.loc[ : , ['CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507', 'V508', 
                        'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V613', 'V714', 'V715'] ]

#generamos un array con el nombre de las variables de interés
#Por ello generamos nuevos diccionarios para las etiquetas que cumplan la condición de que sus llaves forman parte del array.
new_keys1 = rec1_1.columns.values   
new_value_labels1 = { key:value for ( key, value ) in value_labels1.items() if key in new_keys1 }
new_var_labels1 = { key:value for ( key, value ) in var_labels1.items() if key in new_keys1 }

#replicamos el código previo para la base acotada de RE223132
new_keys2 = rec2_1.columns.values
new_value_labels2 = { key:value for ( key, value ) in value_labels2.items() if key in new_keys2 }
new_var_labels2 = { key:value for ( key, value ) in var_labels2.items() if key in new_keys2 }

#replicamos el código previo para la base acotada de RE516171 
new_keys3 = rec3_1.columns.values
new_value_labels3 = { key:value for ( key, value ) in value_labels3.items() if key in new_keys3 }
new_var_labels3 = { key:value for ( key, value ) in var_labels3.items() if key in new_keys3 }

# %% [markdown]
# 3. Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %%
# Generate a new column "year" for rec1_1 with the constant value 2019
rec1_1.loc[:, 'year'] = 2019

# Update variable labels for the new column
new_var_labels1.update({'year': "Year of the survey"})

# %% [markdown]
# 4. Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`. **Hint: Use [this link](https://stackoverflow.com/questions/53645882/pandas-merging-101)**

# %%
# Merge rec1_1, rec2_1, and rec3_1 using CASEID
endes_2019 = pd.merge(rec1_1, rec2_1, on='CASEID', how='inner')
endes_2019 = pd.merge(endes_2019, rec3_1, on='CASEID', how='inner')

# %% [markdown]
# 5. Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. **Hint: Use `update` method.**

# %%
var_labels = {}  #Generate a empty dictionary
var_labels.update(new_var_labels1)  #Update the labels of the variables.
var_labels.update(new_var_labels2)
var_labels.update(new_var_labels3)

value_labels = {} #Creating a empty dictionary
value_labels.update(new_value_labels1) #Updating the value labels
value_labels.update(new_value_labels2)
value_labels.update(new_value_labels3)

# %%
# Assigning labels to variables
endes_2019.attrs[ 'var_labels' ] = var_labels
endes_2019.attrs[ 'value_labels' ] = value_labels

# %% [markdown]
# 6. Get the min, max, sd, n_obs, n_missing for the following columns **total children ever born (V201), Ideal number of children (V613), Husbands education-single yrs (V715)**, and **Age at first marriage (V511)**. We want a dataframe with the following columns **Variables, Min, Max, Mean, N_obs, N_missing** and sort by the number of missing rows. **Hint: Use `describe` and `pivot` methods**

# %%
#Selecting the V201, V613, V715, V511 columns
df = endes_2019[["V201","V613", "V715", "V511"]]

#Generate a variable containing descriptions for the variables.
df1 = df.describe(include = 'all')

#Adding the news indexes
df1.loc['n_obs'] = len(df)  
df1.loc['n_missing'] = df.isnull().sum()

# %%
# Choose the necessary indices and rename them to "variables."
df2 = df1.loc[["min", "max", "std", "mean", "count", "n_missing"]].reset_index().rename(columns = {'index':'Variables'})

#Transform the dataframe by pivoting it and updating the column names. Then, arrange the data based on the count of missing values.
df2 = df2.pivot_table(columns= 'Variables').rename(columns=str.capitalize).sort_values(by= 'N_missing').rename(columns = {'Count':'N_obs'})
                                                                                                   
                                                                                                   
                                                                        
df2
# Out:
# Variables    N_obs   Max       Mean   Min  N_missing       Std
# V201       33311.0  13.0   1.975113   0.0        0.0  1.734790
# V613       33311.0  96.0   2.455345   0.0        0.0  3.849126
# V511       25881.0  48.0  20.463738  10.0     7430.0  4.858358
# V715       25881.0  98.0  11.624474   0.0     7430.0  9.323184

# %% [markdown]
# 7. Use endes_2019 data to generate a new object named mean_key_vars to find the mean of total children ever born (V201), Ideal number of children (V613), Husbands education-single yrs (V715), and Age at first marriage (V511) by year and department (V024). Name these columns as mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage, respectively. Hint: Use groupby and this link.

# %%
#Select the columns to group our variables by 
group_columns = ['year', 'V024']

#Select the variables to work with 
key_vars = ['V201', 'V613', 'V715', 'V511']

#group by group_colums and calculate the mean of our variables
mean_key_vars = endes_2019.groupby(group_columns)[key_vars].mean()

# Rename the columns
mean_key_vars.columns = ['mean_total_children', 'mean_ideal_children', 'mean_hb_yr_educ', 'mean_first_marriage']

# Reset the index to obtain a flat DataFrame
mean_key_vars.reset_index(inplace=True)

#Call our new object
mean_key_vars


#Recoding variable V024
departamento_mapping = {
    1: 'Amazonas',
    2: 'Ancash',
    3: 'Apurimac',
    4: 'Arequipa',
    5: 'Ayacucho',
    6: 'Cajamarca',
    7: 'Callao',
    8: 'Cusco',
    9:'Huancavelica',
    10:'Huanuco',
    11:'Ica',
    12:'Junin',
    13:'La Libertad',
    14:'Lambayeque',
    15:'Lima',
    16:'Loreto',
    17:'Madre de Dios',
    18:'Moquegua',
    19:'Pasco',
    20:'Piura',
    21:'Puno',
    22:'San Martin',
    23:'Tacna',
    24:'Tumbes',
    25:'Ucayali'
}

# Apply the recodification 
mean_key_vars['V024'] = mean_key_vars['V024'].map(departamento_mapping)

#view mean_key_vars
mean_key_vars
# Out:
#     year           V024  mean_total_children  mean_ideal_children  \
# 0   2019       Amazonas             2.257258             2.519355
# 1   2019         Ancash             1.962996             2.383260
# 2   2019       Apurimac             2.268627             2.391176
# 3   2019       Arequipa             1.653193             2.441390
# 4   2019       Ayacucho             2.052257             2.209026
# 5   2019      Cajamarca             2.180258             2.545923
# 6   2019         Callao             1.696154             2.313846
# 7   2019          Cusco             2.109815             2.100097
# 8   2019   Huancavelica             2.364774             4.008662
# 9   2019        Huanuco             2.252900             2.591647
# 10  2019            Ica             1.823175             2.494357
# 11  2019          Junin             2.034834             2.199660
# 12  2019    La Libertad             1.896188             2.431468
# ...

# %% [markdown]
# 8. Reshape mean_key_vars from wide to long. We want a dataframe with three columns dpto, variables, values. Name this object as reshape_mean_key_vars. Hint: Use melt method.

# %%
# Reshape mean_key_vars from wide to long
reshape_mean_key_vars = mean_key_vars.melt(id_vars=['year', 'V024'],
                                           value_vars=['mean_total_children', 'mean_ideal_children', 'mean_hb_yr_educ', 'mean_first_marriage'],
                                           var_name='variables',
                                           value_name='values')

# Variable V024 changes to 'dpto'
reshape_mean_key_vars = reshape_mean_key_vars.rename(columns={'V024': 'dpto'})

# View the new dataframe
reshape_mean_key_vars
# Out:
#     year        dpto            variables     values
# 0   2019    Amazonas  mean_total_children   2.257258
# 1   2019      Ancash  mean_total_children   1.962996
# 2   2019    Apurimac  mean_total_children   2.268627
# 3   2019    Arequipa  mean_total_children   1.653193
# 4   2019    Ayacucho  mean_total_children   2.052257
# ..   ...         ...                  ...        ...
# 95  2019        Puno  mean_first_marriage  20.398964
# 96  2019  San Martin  mean_first_marriage  18.953155
# 97  2019       Tacna  mean_first_marriage  22.065095
# 98  2019      Tumbes  mean_first_marriage  19.409821
# 99  2019     Ucayali  mean_first_marriage  18.985481
#
# [100 rows x 4 columns]

# %% [markdown]
# 9. Replicate your answers for questions 7 and 8, but in one line of code. Make it the most simple as possible.

# %%
#Replicating exercise 7
mean_key_vars1 = endes_2019.groupby(['year', 'V024']).agg({'V201': 'mean', 'V613': 'mean', 'V715': 'mean', 'V511': 'mean'}).rename(columns={'V201': 'mean_total_children', 'V613': 'mean_ideal_children', 'V715': 'mean_hb_yr_educ', 'V511': 'mean_first_marriage'}).reset_index().assign(V024=lambda x: x['V024'].map(departamento_mapping))
mean_key_vars1

#grouped by "year" and "V024".
#averages are calculated
#rename columns
#reset to index
#name assigned from "map" function
# Out:
#     year           V024  mean_total_children  mean_ideal_children  \
# 0   2019       Amazonas             2.257258             2.519355
# 1   2019         Ancash             1.962996             2.383260
# 2   2019       Apurimac             2.268627             2.391176
# 3   2019       Arequipa             1.653193             2.441390
# 4   2019       Ayacucho             2.052257             2.209026
# 5   2019      Cajamarca             2.180258             2.545923
# 6   2019         Callao             1.696154             2.313846
# 7   2019          Cusco             2.109815             2.100097
# 8   2019   Huancavelica             2.364774             4.008662
# 9   2019        Huanuco             2.252900             2.591647
# 10  2019            Ica             1.823175             2.494357
# 11  2019          Junin             2.034834             2.199660
# 12  2019    La Libertad             1.896188             2.431468
# ...

# %%
#Replicating exercise 8
reshape_mean_key_vars2 = mean_key_vars.melt(id_vars=['year', 'V024'], value_vars=['mean_total_children', 'mean_ideal_children', 'mean_hb_yr_educ', 'mean_first_marriage'], var_name='variables', value_name='values').rename(columns={'V024': 'dpto'})
reshape_mean_key_vars2

#We use melt to pass wide to long.
#Combine the "mean" variables
#V024 is renamed
# Out:
#     year        dpto            variables     values
# 0   2019    Amazonas  mean_total_children   2.257258
# 1   2019      Ancash  mean_total_children   1.962996
# 2   2019    Apurimac  mean_total_children   2.268627
# 3   2019    Arequipa  mean_total_children   1.653193
# 4   2019    Ayacucho  mean_total_children   2.052257
# ..   ...         ...                  ...        ...
# 95  2019        Puno  mean_first_marriage  20.398964
# 96  2019  San Martin  mean_first_marriage  18.953155
# 97  2019       Tacna  mean_first_marriage  22.065095
# 98  2019      Tumbes  mean_first_marriage  19.409821
# 99  2019     Ucayali  mean_first_marriage  18.985481
#
# [100 rows x 4 columns]

# %% [markdown]
# 10. Merge reshape_mean_key_vars with endes_2019. Name this object final_result. Hint: Use merge.

# %%
#Merge for reshape_key_vars and endes_2019
final_result = pd.merge(endes_2019, reshape_mean_key_vars, how='inner', on=['year'])
final_result

#Merge is used to join the bases by "year"
# Out:
#                      CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0              000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1              000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 2              000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 3              000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 4              000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# ...                     ...  ...     ...   ...   ...     ...     ...     ...
# 3331095        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
# 3331096        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
# 3331097        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
# 3331098        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
# 3331099        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
# ...
