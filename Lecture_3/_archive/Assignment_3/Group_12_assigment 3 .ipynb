# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request 
#!pip install pyreadstat
import pyreadstat
#!pip install savReaderWriter
import savReaderWriter as sav

# %% [markdown]
# 1. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %%
# List of SPSS file paths
file_paths = [
    r"../../_data/endes/2019/REC0111.sav",
    r"../../_data/endes/2019/RE223132.sav",
    r"../../_data/endes/2019/RE516171.sav",
]

# Lists to store DataFrames and metadata dictionaries
rec_dfs = []
var_labels_list = []
value_labels_list = []

# Loop through the file paths
for i, file_path in enumerate(file_paths):
    # Read SPSS file
    rec_df = pd.read_spss(file_path)
    rec_dfs.append(rec_df)

    # Obtain metadata
    with sav.SavHeaderReader(file_path, ioUtf8=True) as header:
        metadata = header.all()

    # Save variable labels and value labels
    value_labels = metadata.valueLabels
    var_labels = metadata.varLabels
    
    # Adding labels from sav file    
    rec_df.attrs[ 'var_labels' ] = var_labels
    rec_df.attrs[ 'value_labels' ] = value_labels
    # Assign a name to the DataFrame based on the index
    rec_df_name = f"rec_{i + 1}"
    rec_var_name = f"var_labels{i + 1}"
    rec_val_name = f"value_labels{i + 1}"
    globals()[rec_df_name] = rec_df
    globals()[rec_var_name] = var_labels
    globals()[rec_val_name] = value_labels

# Now, rec_dfs contains the DataFrames, var_labels_list contains variable labels, and value_labels_list contains value labels.
# Additionally, rec_1, rec_2, and rec_3 are assigned to the DataFrames.

# %%
# Etiqueta de las variables
var_labels3
# Etiqueta de los valores
value_labels3
# Out:
# {'V501': {0.0: 'Nunca casada',
#   1.0: 'Casado',
#   2.0: 'Viviendo juntos',
#   3.0: 'Viuda',
#   4.0: 'Divorciada',
#   5.0: 'No viven juntos'},
#  'V502': {0.0: 'Nunca casada',
#   1.0: 'Actualmente casada',
#   2.0: 'Anteriormente casada'},
#  'V503': {1.0: 'Una vez', 2.0: 'Mas de una vez'},
#  'V504': {1.0: 'Vive con ella', 2.0: 'Vive en otro sitio'},
#  'V505': {0.0: 'No otras esposas', 98.0: 'No sabe'},
#  'V506': {98.0: 'No sabe'},
#  'V510': {1.0: 'Tiene mes y año',
#   2.0: 'Tiene mes y edad - imputa año',
#   3.0: 'Tiene año y edad - imputa mes',
#   5.0: 'Tiene año - imputa mes',
#   6.0: 'Tiene edad - imputa mes año',
#   7.0: 'Tiene mes - imputa año',
#   8.0: 'Ninguno - imputa todo'},
#  'V513': {0.0: 'Nunca casada',
#   1.0: 'De 0 a 4 años',
#   2.0: 'De 5 a 9 años',
#   3.0: 'De 10 a 14 años',
#   4.0: 'De 15 a 19 años',
#   5.0: 'De 20 a 24 años',
#   6.0: 'De 25 a 29 años',
#   7.0: 'De 30 a más años'},
# ...

# %%
rec_1
# Out:
#           ID1             HHID              CASEID    V001  V002  V003  \
# 0      2019.0        000100201        000100201  2     1.0   2.0   2.0
# 1      2019.0        000100201        000100201  3     1.0   2.0   3.0
# 2      2019.0        000102801        000102801  2     1.0  28.0   2.0
# 3      2019.0        000102801        000102801  6     1.0  28.0   6.0
# 4      2019.0        000104801        000104801  2     1.0  48.0   2.0
# ...       ...              ...                 ...     ...   ...   ...
# 38330  2019.0        325406201        325406201  2  3254.0  62.0   2.0
# 38331  2019.0        325406301        325406301  2  3254.0  63.0   2.0
# 38332  2019.0        325407001        325407001  2  3254.0  70.0   2.0
# 38333  2019.0        325407201        325407201  2  3254.0  72.0   2.0
# 38334  2019.0        325407401        325407401  2  3254.0  74.0   2.0
#
#          V004    V007    V008  V009  ...  QD333_4  QD333_5  QD333_6  UBIGEO  \
# ...

# %% [markdown]
# 2. Select the following columns for each data set:
# |Data|Columns|
# |---|---|
# |rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133 |
# |rec2| CASEID, V201, V218, V301, V302, V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380 |
# |rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715 |
#
#
# Additioanlly, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter. Update the dictionary.**

# %%
# Seleccionar columnas para rec_1
selected_columns_rec_1 = ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V007', 'V008', 'V009', 'V010', 'V011', 'V012', 'V024', 'V102', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V127', 'V133']
rec1_1 = rec_1[selected_columns_rec_1]
print(rec1_1)

# Seleccionar columnas para rec_2
selected_columns_rec_2 = ['CASEID', 'V201', 'V218', 'V301', 'V302', 'V323', 'V323A', 'V325A', 'V326', 'V327', 'V337', 'V359', 'V360', 'V361', 'V362', 'V363', 'V364', 'V367', 'V372', 'V372A', 'V375A', 'V376', 'V376A', 'V379', 'V380']
rec2_1 = rec_2[selected_columns_rec_2]

# Seleccionar columnas para rec_3
selected_columns_rec_3 = ['CASEID', 'V501', 'V502', 'V503', 'V504', 'V505', 'V506', 'V507', 'V508', 'V509', 'V510', 'V511', 'V512', 'V513', 'V525', 'V613', 'V714', 'V715']
rec3_1 = rec_3[selected_columns_rec_3]
# Out:
#                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0            000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1            000100201  3  PE6     1.0   2.0   3.0     1.0  2019.0  1434.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2019.0  1434.0
# 3            000102801  6  PE6     1.0  28.0   6.0     1.0  2019.0  1434.0
# 4            000104801  2  PE6     1.0  48.0   2.0     1.0  2019.0  1434.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 38330        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 38331        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 38332        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 38333        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 38334        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
# ...

# %%
rec_1
# Out:
#           ID1             HHID              CASEID    V001  V002  V003  \
# 0      2019.0        000100201        000100201  2     1.0   2.0   2.0
# 1      2019.0        000100201        000100201  3     1.0   2.0   3.0
# 2      2019.0        000102801        000102801  2     1.0  28.0   2.0
# 3      2019.0        000102801        000102801  6     1.0  28.0   6.0
# 4      2019.0        000104801        000104801  2     1.0  48.0   2.0
# ...       ...              ...                 ...     ...   ...   ...
# 38330  2019.0        325406201        325406201  2  3254.0  62.0   2.0
# 38331  2019.0        325406301        325406301  2  3254.0  63.0   2.0
# 38332  2019.0        325407001        325407001  2  3254.0  70.0   2.0
# 38333  2019.0        325407201        325407201  2  3254.0  72.0   2.0
# 38334  2019.0        325407401        325407401  2  3254.0  74.0   2.0
#
#          V004    V007    V008  V009  ...  QD333_4  QD333_5  QD333_6  UBIGEO  \
# ...

# %%
# Actualizar diccionario de varibales 
new_var_labels1 = {col: var_labels1[col] for col in rec1_1}
new_var_labels2 = {col: var_labels2[col] for col in rec2_1}
new_var_labels3 = {col: var_labels3[col] for col in rec3_1}
new_var_labels1
# Out:
# {'CASEID': 'Identificación Cuestionario Individual',
#  'V000': 'Código y fase del país',
#  'V001': 'Conglomerado',
#  'V002': 'Número de vivienda',
#  'V003': 'Número de línea de entrevistada',
#  'V004': 'Unidad de área final',
#  'V007': 'Año de la entrevista',
#  'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)',
#  'V009': 'Mes de nacimiento de la entrevistada',
#  'V010': 'Año de nacimiento de la entrevistada',
#  'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)',
#  'V012': 'Edad actual - entrevistada',
#  'V024': 'Región',
#  'V102': 'Tipo de lugar de residencia',
#  'V120': 'En su hogar tiene: radio',
#  'V121': 'En su hogar tiene: televisión',
#  'V122': 'En su hogar tiene: refrigerador',
#  'V123': 'En su hogar tiene: bicicleta',
#  'V124': 'En su hogar tiene: motocicleta/motocar',
#  'V125': 'En su hogar tiene: coche/camión',
#  'V127': 'Material predominante del piso de la vivienda',
#  'V133': 'Educación en años simples'}

# %%
# In dictionaries of value labels, indicate that the key is in the list of columns selected
new_value_labels1 = {col: value_labels1[col] for col in rec1_1 if col in value_labels1}
new_value_labels2 = {col: value_labels2[col] for col in rec2_1 if col in value_labels2}
new_value_labels3 = {col: value_labels3[col] for col in rec3_1 if col in value_labels3}

new_value_labels1
# Out:
# {'V024': {1.0: 'Amazonas',
#   2.0: 'Ancash',
#   3.0: 'Apurimac',
#   4.0: 'Arequipa',
#   5.0: 'Ayacucho',
#   6.0: 'Cajamarca',
#   7.0: 'Callao',
#   8.0: 'Cusco',
#   9.0: 'Huancavelica',
#   10.0: ' Huanuco',
#   11.0: ' Ica',
#   12.0: ' Junin',
#   13.0: ' La Libertad',
#   14.0: ' Lambayeque',
#   15.0: ' Lima',
#   16.0: ' Loreto',
#   17.0: ' Madre de Dios',
#   18.0: ' Moquegua',
#   19.0: ' Pasco',
#   20.0: ' Piura',
#   21.0: ' Puno',
#   22.0: ' San Martin',
#   23.0: ' Tacna',
#   24.0: ' Tumbes',
#   25.0: ' Ucayali'},
#  'V102': {1.0: 'Urbano', 2.0: 'Rural'},
#  'V120': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V121': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V122': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V123': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V124': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
#  'V125': {0.0: 'No', 1.0: 'Si', 7.0: 'No es residente habitual'},
# ...

# %% [markdown]
# ## 3. Create var year and update diccionary

# %% [markdown]
# 3. Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %%
# Generar la nueva columna 'year' para rec_1_1
rec1_1.loc[:, 'year'] = 2019
# Actualizar etiquetas de variables para insertar nueva columna 'year'
new_var_labels1.update({'year': 'Year of the survey'})
new_var_labels1
# Out:
# C:\Users\SALVADOR\AppData\Local\Temp\ipykernel_7028\3706073395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec1_1.loc[:, 'year'] = 2019
# {'CASEID': 'Identificación Cuestionario Individual',
#  'V000': 'Código y fase del país',
#  'V001': 'Conglomerado',
#  'V002': 'Número de vivienda',
#  'V003': 'Número de línea de entrevistada',
#  'V004': 'Unidad de área final',
#  'V007': 'Año de la entrevista',
#  'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)',
#  'V009': 'Mes de nacimiento de la entrevistada',
#  'V010': 'Año de nacimiento de la entrevistada',
#  'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)',
#  'V012': 'Edad actual - entrevistada',
#  'V024': 'Región',
# ...

# %% [markdown]
# ## 4. Merge all data using CASEID

# %% [markdown]
# 4. Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`. **Hint: Use [this link](https://stackoverflow.com/questions/53645882/pandas-merging-101)**

# %%
# Fusión de rec1_1, rec2_1 y rec3_1 usando CASEID
endes_2019 = pd.merge(rec1_1, rec2_1, on='CASEID', how='outer')
endes_2019 = pd.merge(endes_2019, rec3_1, on='CASEID', how='outer')
endes_2019
# Out:
#                    CASEID V000    V001  V002  V003    V004    V007    V008  \
# 0            000100201  2  PE6     1.0   2.0   2.0     1.0  2019.0  1434.0
# 1            000100201  3  PE6     1.0   2.0   3.0     1.0  2019.0  1434.0
# 2            000102801  2  PE6     1.0  28.0   2.0     1.0  2019.0  1434.0
# 3            000102801  6  PE6     1.0  28.0   6.0     1.0  2019.0  1434.0
# 4            000104801  2  PE6     1.0  48.0   2.0     1.0  2019.0  1434.0
# ...                   ...  ...     ...   ...   ...     ...     ...     ...
# 38330        325406201  2  PE6  3254.0  62.0   2.0  3254.0  2019.0  1440.0
# 38331        325406301  2  PE6  3254.0  63.0   2.0  3254.0  2019.0  1440.0
# 38332        325407001  2  PE6  3254.0  70.0   2.0  3254.0  2019.0  1440.0
# 38333        325407201  2  PE6  3254.0  72.0   2.0  3254.0  2019.0  1440.0
# 38334        325407401  2  PE6  3254.0  74.0   2.0  3254.0  2019.0  1440.0
#
# ...

# %% [markdown]
# ## 5. Create endes_2019

# %% [markdown]
# 5. Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. **Hint: Use `update` method.**

# %%
# Group the variable labels
var_labels = new_var_labels1
var_labels.update(new_var_labels2)
var_labels.update(new_var_labels3)
print(var_labels)
# Out:
# {'CASEID': 'Identificación Cuestionario Individual', 'V000': 'Código y fase del país', 'V001': 'Conglomerado', 'V002': 'Número de vivienda', 'V003': 'Número de línea de entrevistada', 'V004': 'Unidad de área final', 'V007': 'Año de la entrevista', 'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)', 'V009': 'Mes de nacimiento de la entrevistada', 'V010': 'Año de nacimiento de la entrevistada', 'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)', 'V012': 'Edad actual - entrevistada', 'V024': 'Región', 'V102': 'Tipo de lugar de residencia', 'V120': 'En su hogar tiene: radio', 'V121': 'En su hogar tiene: televisión', 'V122': 'En su hogar tiene: refrigerador', 'V123': 'En su hogar tiene: bicicleta', 'V124': 'En su hogar tiene: motocicleta/motocar', 'V125': 'En su hogar tiene: coche/camión', 'V127': 'Material predominante del piso de la vivienda', 'V133': 'Educación en años simples', 'year': 'Year of the survey', 'V201': 'Total de niños nacidos', 'V2
# ...

# %%
# Group the values labels
value_labels = new_value_labels1
value_labels.update(new_value_labels2)
value_labels.update(new_value_labels3)
value_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # Group the values labels
# ----> 2 value_labels = new_value_labels1
#       3 value_labels.update(new_value_labels2)
#       4 value_labels.update(new_value_labels3)
#
# NameError: name 'new_value_labels1' is not defined

# %%
# Applied the values and variables labels to endes_2019 data
endes_2019.attrs[ 'value_labels'] = value_labels
endes_2019.attrs[ 'var_labels' ] = var_labels
endes_2019.attrs[ 'var_labels' ]
# Out:
# {'CASEID': 'Identificación Cuestionario Individual',
#  'V000': 'Código y fase del país',
#  'V001': 'Conglomerado',
#  'V002': 'Número de vivienda',
#  'V003': 'Número de línea de entrevistada',
#  'V004': 'Unidad de área final',
#  'V007': 'Año de la entrevista',
#  'V008': 'Fecha de la entrevista, Codificación centenaria de meses (CMC)',
#  'V009': 'Mes de nacimiento de la entrevistada',
#  'V010': 'Año de nacimiento de la entrevistada',
#  'V011': 'Fecha de nacimiento, Codificación centenaria de meses (CMC)',
#  'V012': 'Edad actual - entrevistada',
#  'V024': 'Región',
#  'V102': 'Tipo de lugar de residencia',
#  'V120': 'En su hogar tiene: radio',
#  'V121': 'En su hogar tiene: televisión',
#  'V122': 'En su hogar tiene: refrigerador',
#  'V123': 'En su hogar tiene: bicicleta',
#  'V124': 'En su hogar tiene: motocicleta/motocar',
#  'V125': 'En su hogar tiene: coche/camión',
#  'V127': 'Material predominante del piso de la vivienda',
#  'V133': 'Educación en años simples',
# ...

# %% [markdown]
# ## 6. Descriptive table

# %% [markdown]
# 6. Get the min, max, sd, n_obs, n_missing for the following columns **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)**. We want a dataframe with the following columns **Variables, Min, Max, Mean, N_obs, N_missing** and sort by the number of missing rows. **Hint: Use `describe` and `pivot` methods**

# %%
# Main variables
selected_columns = ['V201', 'V613', 'V715', 'V511']
categorical_columns = ['V613', 'V715']

# Use describe for a quick summary
tab_1 =  endes_2019.loc[:,selected_columns].describe()
tab_2 =  endes_2019.loc[:,categorical_columns].describe()

# The categorical columns do not appear prob because they are a different type, so we need an additional line of code
# Calculate missing values for each variables
tab_1.loc["N_missing"] = endes_2019[selected_columns].isna().sum()
tab_1
tab_2.loc["N_missing"] = endes_2019[categorical_columns].isna().sum()
tab_2

missing_categorical = tab_2.loc["N_missing"] 
missing_categorical
# Out:
# V613     5024.0
# V715    12454.0
# Name: N_missing, dtype: float64

# %%
# Convert categorical to numeric
tab_2 =  endes_2019.loc[:,categorical_columns].describe()
endes_2019['V613'] = pd.factorize(endes_2019['V613'])[0]
endes_2019['V715'] = pd.factorize(endes_2019['V715'])[0]
endes_2019[categorical_columns] = endes_2019[categorical_columns].replace(-1, np.nan)
tab_2

# Overwrite former tab_1 so that it shows the 4 variables
tab_1 =  endes_2019.loc[:,selected_columns].describe()
tab_1.loc["N_missing"] = endes_2019[selected_columns].isna().sum()

# See the resulting table
tab_1
# Out:
#                    V201          V613          V715          V511
# count      36922.000000  33311.000000  25881.000000  25881.000000
# mean           1.781946      1.266969      3.559677     20.463738
# std            1.749109      1.740427      4.621835      4.858358
# min            0.000000      0.000000      0.000000     10.000000
# 25%            0.000000      0.000000      0.000000     17.000000
# 50%            1.000000      0.000000      1.000000     19.000000
# 75%            3.000000      3.000000      6.000000     23.000000
# max           13.000000     14.000000     18.000000     48.000000
# N_missing   1413.000000   5024.000000  12454.000000  12454.000000

# %%
# Pivot descriptive summary 
tab_1 = tab_1.loc[["min","max","mean","count","N_missing"]].transpose().reset_index()
# Rename the statistics
tab_1 = tab_1.rename(columns = {"index":"Variables", "min":"Min", "max":"Mix","mean":"Mean","count":"N_Obs"}).sort_values("N_Obs") 
tab_1
# Out:
#   Variables   Min   Mix       Mean    N_Obs  N_missing
# 2      V715   0.0  18.0   3.559677  25881.0    12454.0
# 3      V511  10.0  48.0  20.463738  25881.0    12454.0
# 1      V613   0.0  14.0   1.266969  33311.0     5024.0
# 0      V201   0.0  13.0   1.781946  36922.0     1413.0

# %% [markdown]
# ## 7. Mean key vars

# %% [markdown]
# 7. Use `endes_2019` data to generate a new object named `mean_key_vars` to find the mean of **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)** by year and department **(V024)**. Name these columns as **mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage**, respectively. **Hint: Use groupby and [this link](https://stackoverflow.com/questions/40901770/is-there-a-simple-way-to-change-a-column-of-yes-no-to-1-0-in-a-pandas-dataframe).**

# %%
# #Select the columns to group by
group_columns = ['year', 'V024']

# Select the vars
key_vars = ["V201","V613","V715","V511"]
#df['column_name'] = pd.factorize(df['column_name'])[0]

# Calculate mean by department
mean_key_vars = endes_2019.groupby(group_columns)[key_vars].mean()


# Reset the index to obtain a dataFrame
mean_key_vars.reset_index(inplace=True)


# Rename in order the variables
mean_key_vars.columns = ['year', 'dpto','mean_total_children', 'mean_ideal_children', 'mean_hb_yr_educ', 'mean_first_marriage']

# %%
# Final result
mean_key_vars
# Out:
#     year            dpto  mean_total_children  mean_ideal_children  \
# 0   2019         Huanuco             1.989754             1.484919
# 1   2019             Ica             1.671034             1.249059
# 2   2019           Junin             1.836656             1.147833
# 3   2019     La Libertad             1.704082             1.282238
# 4   2019      Lambayeque             1.673928             1.360717
# 5   2019            Lima             1.476121             1.185909
# 6   2019          Loreto             2.157568             1.435125
# 7   2019   Madre de Dios             1.972514             1.344765
# 8   2019        Moquegua             1.626724             1.078923
# 9   2019           Pasco             1.854436             1.492754
# 10  2019           Piura             1.812752             1.519403
# 11  2019            Puno             1.794307             0.911943
# 12  2019      San Martin             1.903340             1.294118
# ...

# %% [markdown]
# ## 8. Melt de reshape `mean_key_vars`

# %% [markdown]
# 8. Reshape `mean_key_vars` from wide to long. We want a dataframe with three columns **dpto, variables, values**. Name this object as `reshape_mean_key_vars`. **Hint: Use melt method**.

# %%
reshape_mean_key_vars = mean_key_vars.melt(id_vars=['year', 'dpto'],
                                           value_vars=['mean_total_children', 'mean_ideal_children', 'mean_hb_yr_educ', 'mean_first_marriage'],
                                           var_name='variables',
                                           value_name='values')


# View the new dataframe
reshape_mean_key_vars
# Out:
#     year          dpto            variables     values
# 0   2019       Huanuco  mean_total_children   1.989754
# 1   2019           Ica  mean_total_children   1.671034
# 2   2019         Junin  mean_total_children   1.836656
# 3   2019   La Libertad  mean_total_children   1.704082
# 4   2019    Lambayeque  mean_total_children   1.673928
# ..   ...           ...                  ...        ...
# 95  2019      Ayacucho  mean_first_marriage  20.340228
# 96  2019     Cajamarca  mean_first_marriage  19.610695
# 97  2019        Callao  mean_first_marriage  21.517241
# 98  2019         Cusco  mean_first_marriage  20.283154
# 99  2019  Huancavelica  mean_first_marriage  19.780769
#
# [100 rows x 4 columns]

# %% [markdown]
# 9. Replicate your answers for questions 7 and 8, but in one line of code. Make it the most simple as possible. **NO HINT**

# %%
# One line
reshape_mean_key_vars = endes_2019.groupby(group_columns)[key_vars].mean().reset_index().melt(
    id_vars=['year', 'V024'],
    value_vars=["V201", "V613", "V715", "V511"],
    var_name='variables',
    value_name='values')

# %%
# View the dataframe again
reshape_mean_key_vars
# Out:
#     year          V024 variables     values
# 0   2019       Huanuco      V201   1.989754
# 1   2019           Ica      V201   1.671034
# 2   2019         Junin      V201   1.836656
# 3   2019   La Libertad      V201   1.704082
# 4   2019    Lambayeque      V201   1.673928
# ..   ...           ...       ...        ...
# 95  2019      Ayacucho      V511  20.340228
# 96  2019     Cajamarca      V511  19.610695
# 97  2019        Callao      V511  21.517241
# 98  2019         Cusco      V511  20.283154
# 99  2019  Huancavelica      V511  19.780769
#
# [100 rows x 4 columns]

# %% [markdown]
# 10. Merge `reshape_mean_key_vars` with `endes_2019`. Name this object `final_result`. **Hint: Use merge.**

# %%
final_result = reshape_mean_key_vars.merge(endes_2019, how = "left")
final_result
# Out:
#          year          dpto            variables     values  \
# 0        2019       Huanuco  mean_total_children   1.989754
# 1        2019       Huanuco  mean_total_children   1.989754
# 2        2019       Huanuco  mean_total_children   1.989754
# 3        2019       Huanuco  mean_total_children   1.989754
# 4        2019       Huanuco  mean_total_children   1.989754
# ...       ...           ...                  ...        ...
# 3833495  2019  Huancavelica  mean_first_marriage  19.780769
# 3833496  2019  Huancavelica  mean_first_marriage  19.780769
# 3833497  2019  Huancavelica  mean_first_marriage  19.780769
# 3833498  2019  Huancavelica  mean_first_marriage  19.780769
# 3833499  2019  Huancavelica  mean_first_marriage  19.780769
#
#                      CASEID V000    V001  V002  V003    V004  ...    V508  \
# 0              000100201  2  PE6     1.0   2.0   2.0     1.0  ...  2008.0
# 1              000100201  3  PE6     1.0   2.0   3.0     1.0  ...     NaN
# ...
