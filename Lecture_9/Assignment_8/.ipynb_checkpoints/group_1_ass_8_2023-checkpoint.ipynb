# %% [markdown]
# # Assigment 8
#
# 1. Each group must create their branch named group_#_ass_8_2022 (group_1_ass_8_2022) and save their results in the [Assignment_8 folder](https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/Lecture_9/Assignment_8). Name your JN like your branch.
# 2. Import the data located at this [link](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/cajamarca_data_helth_estb.xlsx). This dataset comes from this [link](https://www.datosabiertos.gob.pe/dataset/establecimientos-de-salud). It has information on all the geolocated health establishments in Cajamarca.
# 3. Import the [district's centroids data](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/peru_districts_centroids.xlsx). It has the latitude and longitude of every district in Peru.
# 4. Use these datasets and find the closest health establishment to Cajamarca district centroids. Use euclidian distance between points. DO NOT USE GOOGLE API. IT WILL BE VERY EXPENSIVE For each district, there should be only one health establishment.
# 5. Use Google API Directions to find the driving travel time and distance from health establishments to district centroids. Set driving as the value of the parameter mode and Monday 4pm as departure_time. Include information on the three options of the traffic_model variable: best_guess, pessimistic, and optimistic. The final data frame output should look like the table below:
#     1. |id_eess|
#     2. |codigo_renaes|
#     3. |categoria|
#     4. |nombre|
#     5. |diresa|
#     6. |red|
#     7. |direccion|
#     8. |longitud|
#     9. |latitud|
#     10. |id_ubigeo|
#     11. |UBIGEO|
#     12. |CCDD|
#     13. |NOMBDEP|
#     14. |CCPP|
#     15. |NOMBPROV|
#     16. |CCDI|
#     17. |NOMBDIST|
#     18. |CAPITAL|
#     19. |District|
#     20. |Dist_Centroid_Latitude|
#     21. |Dist_Centroid_Longitude|
#     22. |travel_time_best_guess|
#     23. |travel_time_pessimistic|
#     24. |travel_time_optimistic|
#     25. |travel_distance_best_guess|
#     26. |travel_distance_pessimistic|
#     27. |travel_distance_optimistic|
# 6. Make a histogram of travel time colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province..
# 7. Make a histogram of travel distance colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.
# 8. Bar plot of the mean travel distance by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.
# 9. Bar plot of the mean travel time by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.
# 10. Make plots 10 and 11 in just one figure. Hint: Use catplot. Use [this data](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/salud_places_peru.csv) for the following plot.
# 11. Make a count plot of the number of health establishments by Department colored by hue = categoria. The x-axis should be the Department Name.

# %%
# Librería necesarias para el trabajo
import tabula
import numpy as np
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
import requests
import googlemaps
from datetime import datetime

# %%
pwd
# Out:
# 'D:\\GitHub\\Diplomado_PUCP\\Lecture_9\\Assignment_8'

# %%
# Importar la data geolocalizada de los centros de salud de Cajamarca
data = pd.read_excel("https://github.com/alexanderquispe/Diplomado_PUCP/raw/main/_data/cajamarca_data_helth_estb.xlsx")
data
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# ...

# %%
# Importar la data de los centroides de los distritos
data_centroides = pd.read_excel("https://github.com/alexanderquispe/Diplomado_PUCP/raw/main/_data/peru_districts_centroids.xlsx")
data_centroides
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0        6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1        6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2        6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3        6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4        6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...    ...        ...   ...         ...   ...           ...              ...
# 1869     4   AREQUIPA     4    CASTILLA     4       CHACHAS          CHACHAS
# 1870     4   AREQUIPA     4    CASTILLA     5  CHILCAYMARCA     CHILCAYMARCA
# 1871     4   AREQUIPA     4    CASTILLA     6         CHOCO            CHOCO
# 1872     4   AREQUIPA     4    CASTILLA     7    HUANCARQUI       HUANCARQUI
# 1873    12      JUNIN     6      SATIPO     4      MAZAMARI              NaN
#
# ...

# %%
# Revisamos el nombre de las variables de las dos bases de datos
print(data.columns) 
print(data_centroides.columns)
# Out:
# Index(['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
#        'direccion', 'longitud', 'latitud', 'id_ubigeo', 'ind', 'CCDD',
#        'NOMBDEP', 'CCPP', 'NOMBPROV', 'CCDI', 'NOMBDIST', 'CAPITAL', 'UBIGEO',
#        'IDPROV', 'CODIGO', 'CNT_CCPP', 'DESCRIPCIO'],
#       dtype='object')
# Index(['CCDD', 'NOMBDEP', 'CCPP', 'NOMBPROV', 'CCDI', 'NOMBDIST', 'CAPITAL',
#        'UBIGEO', 'IDPROV', 'CODIGO', 'Centroid_Latitude',
#        'Centroid_Longitude'],
#       dtype='object')

# %%
# Eliminando las variables innecesarias y revisando las columnas
data_2 = data.drop(["ind","IDPROV","CNT_CCPP","DESCRIPCIO"], axis = 1)
data_2.columns
# Out:
# Index(['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
#        'direccion', 'longitud', 'latitud', 'id_ubigeo', 'CCDD', 'NOMBDEP',
#        'CCPP', 'NOMBPROV', 'CCDI', 'NOMBDIST', 'CAPITAL', 'UBIGEO', 'CODIGO'],
#       dtype='object')

# %%
# Eligiendo las varaibles necesarias a fusionar con el DataFrame previo
data_centroides_2 = data_centroides.loc[ : , ["CODIGO","Centroid_Latitude","Centroid_Longitude"]]
data_centroides_2
# Out:
#       CODIGO  Centroid_Latitude  Centroid_Longitude
# 0      60504          -7.364304          -78.917689
# 1      61105          -7.038039          -79.003318
# 2      61109          -6.926718          -79.131435
# 3      61110          -7.117978          -79.160968
# 4      61203          -7.159046          -78.873084
# ...      ...                ...                 ...
# 1869   40404         -15.181923          -72.116054
# 1870   40405         -15.350613          -72.385276
# 1871   40406         -15.414004          -72.068684
# 1872   40407         -16.012364          -72.368167
# 1873  120604         -11.493927          -74.241229
#
# [1874 rows x 3 columns]

# %%
# Generamos un objeto que fusiones los datos de los dataframe previos
merged_data = data_2.merge(data_centroides_2, on='CODIGO', how='inner')
merged_data
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# ...

# %%
# Revisamos las variables en la DataFrame fusionada y si hay valores perdidos
print(merged_data.columns)
print(merged_data.isnull().sum())
# Se comprueba que no hay valores perdidos
# Out:
# Index(['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
#        'direccion', 'longitud', 'latitud', 'id_ubigeo', 'CCDD', 'NOMBDEP',
#        'CCPP', 'NOMBPROV', 'CCDI', 'NOMBDIST', 'CAPITAL', 'UBIGEO', 'CODIGO',
#        'Centroid_Latitude', 'Centroid_Longitude'],
#       dtype='object')
# id_eess               0
# codigo_renaes         0
# categoria             0
# nombre                0
# diresa                0
# red                   0
# direccion             0
# longitud              0
# latitud               0
# id_ubigeo             0
# CCDD                  0
# NOMBDEP               0
# CCPP                  0
# NOMBPROV              0
# CCDI                  0
# NOMBDIST              0
# CAPITAL               0
# UBIGEO                0
# CODIGO                0
# Centroid_Latitude     0
# Centroid_Longitude    0
# dtype: int64

# %%
# Elminamos las variables innecesarias
nueva_data = merged_data.drop("ind", "UBIGEO_x","IDPROV_x",""
                              , axis=1)

# %%
# Unimos cada DataFrame contenida en la lista pdf_data a través del método concat de la librería panda
data_unida = pd.concat(pdf_data, ignore_index=True)
# Se selecciona las filas y columnas con los datos necesarios y se reinicia el índice
data = data_unida.iloc[ 2: , : 5,].reset_index(drop=True)
# Generamos el nombre de las columnas o de las variables y se logra el DataFrame final
headers = ['OFICINA','DIRECCION','DISTRITO','PROVINCIA','DEPARTAMENTO']
data.columns = headers
data
# Out:
#                  OFICINA                                          DIRECCION  \
# 0           BAGUA GRANDE                               AV. CHACHAPOYAS 2044
# 1               CHIMBOTE             AV. FRANCISCO BOLOGNESI 696 - CHIMBOTE
# 2                 HUARAZ       CALLE 2 ESQ. JR. JOSE SUCRE - PLAZA DE ARMAS
# 3     MEGAPLAZA CHIMBOTE  AV. VICTOR R. HAYA DE LA TORRE 4694, LC B4 Y B...
# 4                    NaN                                        GRAN CHAVIN
# ..                   ...                                                ...
# 369                  NaN                                                NaN
# 370  OPEN PLAZA PUCALLPA  AV. CENTENARIO 2086 Y 2192, JR. LAUREANO DEL Á...
# 371                  NaN                                  AV. AMAZONAS 2752
# 372             PUCALLPA                     ESQUINA UCAYALI Y RAYMONDI 699
# 373                  NaN                                                NaN
#
#          DISTRITO  PROVINCIA DEPARTAMENTO
# ...

# %%
# Generamos un dataframe solo de Lima Departamento
data_lima = data[data['DEPARTAMENTO'] == 'LIMA'].reset_index(drop=True)
data_lima
# Out:
#                     OFICINA  \
# 0               CAMINO REAL
# 1               28 DE JULIO
# 2          ABANCAY-CONGRESO
# 3                AEROPUERTO
# 4              ANGAMOS ESTE
# ..                      ...
# 201     NESTLE-DONOFRIO 164
# 202  BIENESTAR DE LA MARINA
# 203                 SEDAPAL
# 204         ESPECIAL SENATI
# 205          VILLA INFANTAS
#
#                                              DIRECCION  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 201                                 AV. VENEZUELA 2580
# 202                          AV. VENEZUELA S/N CDRA 34
# 203  KM. 1 AUTOPISTA RAMIRO PRIALE (AL INTERIOR DE ...
# 204                          AV. ALFREDO MENDIOLA 3520
# ...

# %%
#Identificamos la cantidad de filas con valores perdidos
filas_perdidos = data_lima.isnull().any(axis=1)
data_lima_perdidos = data_lima[filas_perdidos]
data_lima_perdidos
# Así identificamos que la primeras 14 filas tienen datos perdidos
# Out:
#                OFICINA DIRECCION  \
# 0          CAMINO REAL       NaN
# 1          28 DE JULIO       NaN
# 2     ABANCAY-CONGRESO       NaN
# 3           AEROPUERTO       NaN
# 4         ANGAMOS ESTE       NaN
# 5   ANGAMOS OPEN PLAZA       NaN
# 6                APOLO       NaN
# 7             ARAMBURU       NaN
# 8             ARENALES       NaN
# 9          AV. CENTRAL       NaN
# 10    AV. DEL EJERCITO       NaN
# 11            AV. PERU       NaN
# 12           AV. SUCRE       NaN
# 13            AVIACIÓN       NaN
#
#                                              DISTRITO             PROVINCIA  \
# 0                                 AV. CAMINO REAL 355            SAN ISIDRO
# 1                                 AV. 28 DE JULIO 775                  LIMA
# 2                                 AV. ABANCAY 260-262                  LIMA
# 3        CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A                CALLAO
# ...

# %%
data_lima.iloc[0:14, 1] = data_lima.iloc[0:14, 2]  # Reemplazar contenido de columna 1 con contenido de columna 2
data_lima.iloc[0:14, 2] = data_lima.iloc[0:14, 3]  # Reemplazar contenido de columna 2 con contenido de columna 3
data_lima.iloc[0:14, 3] = "LIMA"  # Llenar columna 3 con "LIMA"
data_lima.iloc[0:14, 4] = "LIMA"  # Llenar columna 4 con "LIMA"
data_lima_final = data_lima[data_lima['PROVINCIA'] == 'LIMA'].reset_index(drop=True)
data_lima_final
# Out:
#                     OFICINA  \
# 0               CAMINO REAL
# 1               28 DE JULIO
# 2          ABANCAY-CONGRESO
# 3                AEROPUERTO
# 4              ANGAMOS ESTE
# ..                      ...
# 193     NESTLE-DONOFRIO 164
# 194  BIENESTAR DE LA MARINA
# 195                 SEDAPAL
# 196         ESPECIAL SENATI
# 197          VILLA INFANTAS
#
#                                              DIRECCION       DISTRITO  \
# 0                                  AV. CAMINO REAL 355     SAN ISIDRO
# 1                                  AV. 28 DE JULIO 775           LIMA
# 2                                  AV. ABANCAY 260-262           LIMA
# 3         CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 4    Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 193                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
data_lima_final["DIRECCION COMPLETA"]=data_lima_final['DIRECCION'] + ', ' + data_lima_final['DISTRITO']
data_lima_final
# Out:
#                     OFICINA  \
# 0               CAMINO REAL
# 1               28 DE JULIO
# 2          ABANCAY-CONGRESO
# 3                AEROPUERTO
# 4              ANGAMOS ESTE
# ..                      ...
# 193     NESTLE-DONOFRIO 164
# 194  BIENESTAR DE LA MARINA
# 195                 SEDAPAL
# 196         ESPECIAL SENATI
# 197          VILLA INFANTAS
#
#                                              DIRECCION       DISTRITO  \
# 0                                  AV. CAMINO REAL 355     SAN ISIDRO
# 1                                  AV. 28 DE JULIO 775           LIMA
# 2                                  AV. ABANCAY 260-262           LIMA
# 3         CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 4    Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 193                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
gmaps = googlemaps.Client( key='AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE')

def get_results( result_api ):
    
    try:
        lat = result_api[0]['geometry']['location']['lat']
        lon = result_api[0]['geometry']['location']['lng']  
        
    except:
        lat = np.nan
        lon = np.nan
    
    return ( lat, lon )

# %%
data_lima_final["COORDENADAS"] = data_lima_final.apply( lambda x: get_results( gmaps.geocode( x["DIRECCION COMPLETA"], region = "PE") ), axis = 1 )

# %%
#Generamos latitud y longitud a partir de la variable coordenadas
data_lima_final['LATITUD'] = data_lima_final['COORDENADAS'].apply(lambda coord: str(coord).split(',')[0].replace('(',''))
data_lima_final['LONGITUD'] = data_lima_final['COORDENADAS'].apply(lambda coord: str(coord).split(',')[1].replace(')','').strip())

# %%
data_lima_final
# Out:
#                     OFICINA  \
# 0               CAMINO REAL
# 1               28 DE JULIO
# 2          ABANCAY-CONGRESO
# 3                AEROPUERTO
# 4              ANGAMOS ESTE
# ..                      ...
# 193     NESTLE-DONOFRIO 164
# 194  BIENESTAR DE LA MARINA
# 195                 SEDAPAL
# 196         ESPECIAL SENATI
# 197          VILLA INFANTAS
#
#                                              DIRECCION       DISTRITO  \
# 0                                  AV. CAMINO REAL 355     SAN ISIDRO
# 1                                  AV. 28 DE JULIO 775           LIMA
# 2                                  AV. ABANCAY 260-262           LIMA
# 3         CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 4    Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 193                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
#Creamos las coordenadas de las casas de cada integrante del grupo y la agregamos al dataset

lat_abel = np.repeat((-12.089472855226788), len(data_lima_final))
lng_abel =  np.repeat((-77.05897458982007), len(data_lima_final))


lat_afrania = np.repeat((-12.08015452262831), len(data_lima_final))
lng_afrania =  np.repeat((-76.98883156110965), len(data_lima_final))


lat_cristian = np.repeat((-12.085940399091843), len(data_lima_final))
lng_cristian =  np.repeat((-77.09336276110959), len(data_lima_final))


lat_meir = np.repeat((-12.083609662455098), len(data_lima_final))
lng_meir =  np.repeat((-77.05365958823917), len(data_lima_final))


data_lima_final['lat_abel'] = lat_abel
data_lima_final['lng_abel'] = lng_abel

data_lima_final['lat_afrania'] = lat_afrania
data_lima_final['lng_afrania'] = lng_afrania

data_lima_final['lat_cristian'] = lat_cristian
data_lima_final['lng_cristian'] = lng_cristian

data_lima_final['lat_meir'] = lat_meir
data_lima_final['lng_meir'] = lng_meir

# %%
data_lima_final
# Out:
#                     OFICINA  \
# 0               CAMINO REAL
# 1               28 DE JULIO
# 2          ABANCAY-CONGRESO
# 3                AEROPUERTO
# 4              ANGAMOS ESTE
# ..                      ...
# 193     NESTLE-DONOFRIO 164
# 194  BIENESTAR DE LA MARINA
# 195                 SEDAPAL
# 196         ESPECIAL SENATI
# 197          VILLA INFANTAS
#
#                                              DIRECCION       DISTRITO  \
# 0                                  AV. CAMINO REAL 355     SAN ISIDRO
# 1                                  AV. 28 DE JULIO 775           LIMA
# 2                                  AV. ABANCAY 260-262           LIMA
# 3         CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 4    Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 193                                 AV. VENEZUELA 2580           LIMA
# ...

# %%
# Identificación de valores perdidos en forma de string
rows_with_na = data_lima_final.isin(['nan']).any(axis=1)
cols_with_na = data_lima_final.isin(['nan']).any(axis=0)
na_cells = data_lima_final.loc[rows_with_na, cols_with_na]
na_cells
# Out:
#     LATITUD LONGITUD
# 38      nan      nan
# 61      nan      nan
# 72      nan      nan
# 76      nan      nan
# 109     nan      nan
# 121     nan      nan
# 162     nan      nan
# 177     nan      nan
# 184     nan      nan

# %%
# Reemplazo de los valores string nan por valores perdidos
data_lima_final = data_lima_final.replace('nan', np.nan)
data_lima_final[ data_lima_final [ 'LONGITUD' ].isna() ]
# Out:
#                              OFICINA  \
# 38                             CAPON
# 61                           EL MURO
# 72                           GAMARRA
# 76                   HIPOLITO UNANUE
# 109  MALL AVENTURA PLAZA SANTA ANITA
# 121                  NACIONES UNIDAS
# 162           SAN JUAN DE MIRAFLORES
# 177                     VALLE SHARON
# 184                VILLA EL SALVADOR
#
#                                              DIRECCION           DISTRITO  \
# 38                                     JR. UCAYALI 735        LA VICTORIA
# 61   AV. WIESSE TDA A, PROGR. CIUDAD MARISCAL CACER...        SAN JUAN DE
# 72                                PROLONG. UNANUE 1599        LA VICTORIA
# 76                  JR HIPOLITO UNANUE 1616-1620, LC 3        LA VICTORIA
# 109  AV. CARRETERA CENTRAL 111, LOCAL COMERCIAL N° ...        SANTA ANITA
# 121                          Av. Jorge Chavez Cuadra 2         MIRAFLORES
# ...

# %%
# Se agrega manualmente la longitud y latitud de las direcciones faltantes
# Oficina Capon
fila_38 = gmaps.geocode( "WXQC+649, La Victoria 15033" , region = 'pe' )

fila_38_lat = fila_38[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_38_lng = fila_38[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 38, 'LATITUD' ] = fila_38_lat
data_lima_final.at[ 38, 'LONGITUD' ] = fila_38_lng

# Oficina Muro
fila_61 = gmaps.geocode( "AV. WIESSE TDA A, PROGR. CIUDAD MARISCAL CACERES, SEC. II, MZ. J1 LT. 28, SJL" , region = 'pe' )

fila_61_lat = fila_61[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_61_lng = fila_61[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 61, 'LATITUD' ] = fila_61_lat
data_lima_final.at[ 61, 'LONGITUD' ] = fila_61_lng

# Oficina Gamarra
fila_72 = gmaps.geocode( "Prolong. Unanue 1599, Lima" , region = 'pe' )

fila_72_lat = fila_72[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_72_lng = fila_72[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 72, 'LATITUD' ] = fila_72_lat
data_lima_final.at[ 72, 'LONGITUD' ] = fila_72_lng

# Oficina HIPOLITO UNANUE
fila_76 = gmaps.geocode( "Jirón Hipólito Unanue 1616, Lima 15018" , region = 'pe' )

fila_76_lat = fila_76[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_76_lng = fila_76[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 76, 'LATITUD' ] = fila_76_lat
data_lima_final.at[ 76, 'LONGITUD' ] = fila_76_lng

# Oficina MALL AVENTURA PLAZA SANTA ANITA
fila_109 = gmaps.geocode( "local comercial lf1a, Carr. Central 111, Provincia de Lima 15008" , region = 'pe' )

fila_109_lat = fila_109[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_109_lng = fila_109[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 109, 'LATITUD' ] = fila_109_lat
data_lima_final.at[ 109, 'LONGITUD' ] = fila_109_lng

# Oficina Naciones Unidas
fila_121 = gmaps.geocode( "Av. Jorge Chavez, BBVA, Miraflores" , region = 'pe' )

fila_121_lat = fila_121[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_121_lng = fila_121[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 121, 'LATITUD' ] = fila_121_lat
data_lima_final.at[ 121, 'LONGITUD' ] = fila_121_lng

# Oficina Capon
fila_38 = gmaps.geocode( "WXQC+649, La Victoria 15033" , region = 'pe' )

fila_38_lat = fila_38[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_38_lng = fila_38[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 38, 'LATITUD' ] = fila_38_lat
data_lima_final.at[ 38, 'LONGITUD' ] = fila_38_lng

# Oficina Gamarra
fila_72 = gmaps.geocode( "Prolong. Unanue 1599, Lima" , region = 'pe' )

fila_72_lat = fila_72[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_72_lng = fila_72[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 72, 'LATITUD' ] = fila_72_lat
data_lima_final.at[ 72, 'LONGITUD' ] = fila_72_lng

# Oficina HIPOLITO UNANUE
fila_76 = gmaps.geocode( "Jirón Hipólito Unanue 1616, Lima 15018" , region = 'pe' )

fila_76_lat = fila_76[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_76_lng = fila_76[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 76, 'LATITUD' ] = fila_76_lat
data_lima_final.at[ 76, 'LONGITUD' ] = fila_76_lng

# Oficina MALL AVENTURA PLAZA SANTA ANITA
fila_109 = gmaps.geocode( "local comercial lf1a, Carr. Central 111, Provincia de Lima 15008" , region = 'pe' )

fila_109_lat = fila_109[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_109_lng = fila_109[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 109, 'LATITUD' ] = fila_109_lat
data_lima_final.at[ 109, 'LONGITUD' ] = fila_109_lng

# Oficina Naciones Unidas
fila_121 = gmaps.geocode( "Av. Jorge Chavez, BBVA, Miraflores" , region = 'pe' )

fila_121_lat = fila_121[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_121_lng = fila_121[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 121, 'LATITUD' ] = fila_121_lat
data_lima_final.at[ 121, 'LONGITUD' ] = fila_121_lng

# Oficina San Juan de Miraflores
fila_162 = gmaps.geocode( "Av. los Héroes 502, San Juan de Miraflores 15801" , region = 'pe' )

fila_162_lat = fila_162[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_162_lng = fila_162[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 162, 'LATITUD' ] = fila_162_lat
data_lima_final.at[ 162, 'LONGITUD' ] = fila_162_lng

# Oficina VALLE SHARON
fila_177 = gmaps.geocode( "Av. Víctor Castro Iglesias 790, San Juan de Miraflores 15801" , region = 'pe' )

fila_177_lat = fila_177[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_177_lng = fila_177[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 177, 'LATITUD' ] = fila_177_lat
data_lima_final.at[ 177, 'LONGITUD' ] = fila_177_lng

# Oficina VILLA EL SALVADOR
fila_184 = gmaps.geocode( "Av. Revolucion 17, Lima 15834" , region = 'pe' )

fila_184_lat = fila_184[ 0 ][ 'geometry' ][ 'location' ][ 'lat' ]
fila_184_lng = fila_184[ 0 ][ 'geometry' ][ 'location' ][ 'lng' ]

data_lima_final.at[ 184, 'LATITUD' ] = fila_184_lat
data_lima_final.at[ 184, 'LONGITUD' ] = fila_184_lng

# %%
# Asignación manual de la logitud y latitud de la oficina de la marina que presentaba problemas
data_lima_final.loc[data_lima_final['OFICINA'] == 'LA MARINA', 'LONGITUD'] = -77.08753603558203
data_lima_final.loc[data_lima_final['OFICINA'] == 'LA MARINA', 'LATITUD'] = -12.078427075875975

# %%
# Verificación de valores perdidos en la columna de longitud
data_lima_final[ data_lima_final [ 'LONGITUD' ].isna() ]
# Se observa que no hay ningún valor perdido
# Out:
# Empty DataFrame
# Columns: [OFICINA, DIRECCION, DISTRITO, PROVINCIA, DEPARTAMENTO, DIRECCION COMPLETA, COORDENADAS, LATITUD, LONGITUD, lat_abel, lng_abel, lat_afrania, lng_afrania, lat_cristian, lng_cristian, lat_meir, lng_meir]
# Index: []

# %%
class google_distance:
    
    def __init__( self, api_key = None ):
                
        if api_key is None:
            raise TypeError(f'`api_key` should not be None.')
            
        elif isinstance( api_key , str ):
            self.api_key = api_key
        else:
            raise TypeError( f'api_key` should be a str.' )

    
    def results_directions( self, result ):

        if len( result ) != 0:
            distance_meters = result[0]['legs'][0]['distance']['value']
            time_seconds = result[0]['legs'][0]['duration']['value']

        else:
            distance_meters = ''
            time_seconds = ''

        return ( distance_meters , time_seconds)
    

    def directions( self, data , lat_orig, lon_orig , lat_dest, lon_dest, output = 'all' ):
        
        # The output variable you can use the following values :  "driving" , "walking" , "bicycling", "transit"
        gmaps = googlemaps.Client( key= self.api_key )
        
        mode_directions = [ "driving" , "walking" , "bicycling", "transit" ]
        data1 = data.copy()
        
        if output != 'all':
            mode_directions = [ output ]
        
        for mode in mode_directions:
            
            # We use the lambda funtion
            result  = data1.apply( lambda row: self.results_directions( gmaps.directions(      \
                                    origin       = ( row[f'{lat_orig}'] , row[ f'{lon_orig}'] ) ,        \
                                    destination  = ( row[ f'{lat_dest}'] , row[ f'{lon_dest}'] ) ,  \
                                    mode         = mode , 
                                    alternatives = False ) ),                        \
                                    axis=1 
                                 )
            
            data1[[ f'{mode}_dist_mt', f'{mode}_time_sec' ]] = pd.DataFrame( result.tolist(), index = data1.index )
                
        return data1

# %%
#Usamos la llave de la clase

google_dir_api = google_distance( api_key = 'AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE' )

# %%
#Calculamos las distancias
dir_results_abel = google_dir_api.directions( data_lima_final  , lat_orig='LATITUD', lon_orig='LONGITUD' , lat_dest='lat_abel', lon_dest='lng_abel', output = 'all')
dir_results_afrania = google_dir_api.directions( data_lima_final  , lat_orig='LATITUD', lon_orig='LONGITUD' , lat_dest='lat_afrania', lon_dest='lng_afrania', output = 'all')
dir_results_cristian = google_dir_api.directions( data_lima_final  , lat_orig='LATITUD', lon_orig='LONGITUD' , lat_dest='lat_cristian', lon_dest='lng_cristian', output = 'all')
dir_results_meir = google_dir_api.directions( data_lima_final  , lat_orig='LATITUD', lon_orig='LONGITUD' , lat_dest='lat_meir', lon_dest='lng_meir', output = 'all')

# %%
# Encontramos las filas con la menor distancia de manejo
idx_min_dist_abel = dir_results_abel['driving_dist_mt'].idxmin()
idx_min_dist_afrania = dir_results_afrania['driving_dist_mt'].idxmin()
idx_min_dist_cristian = dir_results_cristian['driving_dist_mt'].idxmin()
idx_min_dist_meir = dir_results_meir['driving_dist_mt'].idxmin()



# Obtener el valor de la oficina correspondiente
closest_office_abel = dir_results_abel.loc[idx_min_dist_abel, 'OFICINA']
closest_office_afrania = dir_results_afrania.loc[idx_min_dist_afrania, 'OFICINA']
closest_office_cristian = dir_results_cristian.loc[idx_min_dist_cristian, 'OFICINA']
closest_office_meir  = dir_results_meir.loc[idx_min_dist_meir, 'OFICINA']

# %%
#Creamos el reporte
datafinal = pd.DataFrame({'Nombre': ["Abel", "Afrania", "Cristian", "Meir"]})

# %%
datafinal['Oficina'] = [closest_office_abel, closest_office_afrania, closest_office_cristian, closest_office_meir]

# %%
datafinal
# Out:
#      Nombre             Oficina
# 0      Abel  JAVIER PRADO OESTE
# 1   Afrania                LIMA
# 2  Cristian           LA MARINA
# 3      Meir      PLAZA SAN JOSÉ
