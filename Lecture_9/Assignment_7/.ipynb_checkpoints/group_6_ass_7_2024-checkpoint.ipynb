# %% [markdown]
# # Assignment 7

# %%
import pandas as pd
import math
# !pip install googlemaps
import googlemaps
from datetime import datetime, timedelta
# Out:
# Requirement already satisfied: googlemaps in c:\anaconda\lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\anaconda\lib\site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.7.22)

# %% [markdown]
# **1. Import the data located at this [link](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/cajamarca_data_helth_estb.xlsx). This dataset comes from this [link](https://www.datosabiertos.gob.pe/dataset/establecimientos-de-salud). It has information on all the geolocated health establishments in Cajamarca.**

# %%
#Importamos
df = pd.read_excel(r"../../_data/cajamarca_data_helth_estb.xlsx")

# %%
#Nos aseguramos que sea un data frame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Vemos que contiene el mencionado data frame
df
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# 1                           JAEN
# 2                           JAEN
# 3                           JAEN
# 4                           JAEN
# ...                          ...
# 1187                      SOCOTA
# 1188                      SOCOTA
# 1189                      SOCOTA
# 1190                      SOCOTA
# 1191                 SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1     OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2     CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4     OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
# ...                                                 ...        ...       ...
# 1187  CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471 -6.292044
# 1188  OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080 -6.279960
# 1189  OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640 -6.266560
# 1190  OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210 -6.267210
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo  ...  CCPP  NOMBPROV CCDI           NOMBDIST  \
# 0           636  ...     8      JAEN    1               JAEN
# 1           636  ...     8      JAEN    1               JAEN
# 2           636  ...     8      JAEN    1               JAEN
# 3           636  ...     8      JAEN    1               JAEN
# 4           636  ...     8      JAEN    1               JAEN
# ...         ...  ...   ...       ...  ...                ...
# 1187        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1188        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1189        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1190        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1191        650  ...     2     BAGUA    5              IMAZA
#
#                 CAPITAL  UBIGEO IDPROV CODIGO  CNT_CCPP         DESCRIPCIO
# 0                  JAEN   60801    608  60801       108               JAEN
# 1                  JAEN   60801    608  60801       108               JAEN
# 2                  JAEN   60801    608  60801       108               JAEN
# 3                  JAEN   60801    608  60801       108               JAEN
# 4                  JAEN   60801    608  60801       108               JAEN
# ...                 ...     ...    ...    ...       ...                ...
# 1187  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1188  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1189  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1190  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1191           CHIRIACO   10205    102  10205       159              IMAZA
#
# [1192 rows x 23 columns]

# %% [markdown]
# **2. Import the [district's centroids data](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/_data/peru_districts_centroids.xlsx). It has the latitude and longitude of every district in Peru**

# %%
#Importamos
df2 = pd.read_excel(r"../../_data/peru_districts_centroids.xlsx")

# %%
#Vemos que contiene el mencionado data frame
df2
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0        6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1        6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2        6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3        6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4        6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...    ...        ...   ...         ...   ...           ...              ...
# 1869     4   AREQUIPA     4    CASTILLA     4       CHACHAS          CHACHAS
# 1870     4   AREQUIPA     4    CASTILLA     5  CHILCAYMARCA     CHILCAYMARCA
# 1871     4   AREQUIPA     4    CASTILLA     6         CHOCO            CHOCO
# 1872     4   AREQUIPA     4    CASTILLA     7    HUANCARQUI       HUANCARQUI
# 1873    12      JUNIN     6      SATIPO     4      MAZAMARI              NaN
#
#       UBIGEO  IDPROV  CODIGO  Centroid_Latitude  Centroid_Longitude
# 0      60504     605   60504          -7.364304          -78.917689
# 1      61105     611   61105          -7.038039          -79.003318
# 2      61109     611   61109          -6.926718          -79.131435
# 3      61110     611   61110          -7.117978          -79.160968
# 4      61203     612   61203          -7.159046          -78.873084
# ...      ...     ...     ...                ...                 ...
# 1869   40404     404   40404         -15.181923          -72.116054
# 1870   40405     404   40405         -15.350613          -72.385276
# 1871   40406     404   40406         -15.414004          -72.068684
# 1872   40407     404   40407         -16.012364          -72.368167
# 1873  120604    1206  120604         -11.493927          -74.241229
#
# [1874 rows x 12 columns]

# %% [markdown]
# **3. Use these datasets and find the closest health establishment to Cajamarca district centroids. Use euclidian distance between points. DO NOT USE GOOGLE API. IT WILL BE VERY EXPENSIVE For each district, there should be only one health establishment.**

# %%
#Primero, nos quedamos solo con aquellos establecimiento de salud que se encuentran en Cajamarca
df_2 = df.loc[:, 'id_eess':'id_ubigeo']
df_2['UBIGEO']=df['UBIGEO']
df_2 = df_2.loc[df_2['diresa'] == 'CAJAMARCA']
df_2
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# 1                           JAEN
# 2                           JAEN
# 3                           JAEN
# 4                           JAEN
# ...                          ...
# 1187                      SOCOTA
# 1188                      SOCOTA
# 1189                      SOCOTA
# 1190                      SOCOTA
# 1191                 SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1     OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2     CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4     OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
# ...                                                 ...        ...       ...
# 1187  CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471 -6.292044
# 1188  OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080 -6.279960
# 1189  OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640 -6.266560
# 1190  OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210 -6.267210
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo  UBIGEO
# 0           636   60801
# 1           636   60801
# 2           636   60801
# 3           636   60801
# 4           636   60801
# ...         ...     ...
# 1187        627   60610
# 1188        627   60610
# 1189        627   60610
# 1190        627   60610
# 1191        650   10205
#
# [1192 rows x 11 columns]

# %%
#Segundo, seleccionamos solo los centroides que se encuentran en Cajamarca
df2_2 = df2.loc[:, 'CCDD':'UBIGEO']
df2_2['Centroid_Latitude']=df2['Centroid_Latitude']
df2_2['Centroid_Longitude']=df2['Centroid_Longitude']
df2_2 = df2_2.loc[df2_2['NOMBDEP'] == 'CAJAMARCA']
df2_2
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0        6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1        6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2        6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3        6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4        6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...    ...        ...   ...         ...   ...           ...              ...
# 1644     6  CAJAMARCA     3    CELENDIN     8      OXAMARCA         OXAMARCA
# 1645     6  CAJAMARCA     3    CELENDIN     9     SOROCHUCO        SOROCHUCO
# 1743     6  CAJAMARCA     8        JAEN    10    SAN FELIPE       SAN FELIPE
# 1744     6  CAJAMARCA     8        JAEN     6    LAS PIRIAS       LAS PIRIAS
# 1762     6  CAJAMARCA     6     CUTERVO     6     PIMPINGOS        PIMPINGOS
#
#       UBIGEO  Centroid_Latitude  Centroid_Longitude
# 0      60504          -7.364304          -78.917689
# 1      61105          -7.038039          -79.003318
# 2      61109          -6.926718          -79.131435
# 3      61110          -7.117978          -79.160968
# 4      61203          -7.159046          -78.873084
# ...      ...                ...                 ...
# 1644   60308          -7.059289          -78.061333
# 1645   60309          -6.934215          -78.297182
# 1743   60810          -5.786477          -79.310211
# 1744   60806          -5.636342          -78.849590
# 1762   60606          -6.070895          -78.768292
#
# [127 rows x 10 columns]

# %%
#Unimos las dos datas
df_unido = df2_2.merge(df_2, on='UBIGEO', how='outer')
df_unido
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI   NOMBDIST    CAPITAL  UBIGEO  \
# 0      6.0  CAJAMARCA   5.0   CONTUMAZA   4.0   GUZMANGO   GUZMANGO   60504
# 1      6.0  CAJAMARCA   5.0   CONTUMAZA   4.0   GUZMANGO   GUZMANGO   60504
# 2      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# 3      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# 4      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# ...    ...        ...   ...         ...   ...        ...        ...     ...
# 1187   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1188   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1189   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1190   NaN        NaN   NaN         NaN   NaN        NaN        NaN  131101
# 1191   NaN        NaN   NaN         NaN   NaN        NaN        NaN   10205
#
#       Centroid_Latitude  Centroid_Longitude  id_eess  codigo_renaes categoria  \
# 0             -7.364304          -78.917689    13172           4553       I-2
# 1             -7.364304          -78.917689     5348           4554       I-2
# 2             -7.038039          -79.003318    18927           4540       I-1
# 3             -7.038039          -79.003318    13899           4573       I-2
# 4             -7.038039          -79.003318    21765           4575       I-2
# ...                 ...                 ...      ...            ...       ...
# 1187          -6.070895          -78.768292    13036           5024       I-1
# 1188          -6.070895          -78.768292    13500           6867       I-1
# 1189          -6.070895          -78.768292    24108          11068       I-1
# 1190                NaN                 NaN    21617           4552       I-2
# 1191                NaN                 NaN    26156           6995       I-1
#
#               nombre     diresa          red  \
# 0           GUZMANGO  CAJAMARCA    CONTUMAZA
# 1         TOTORILLAS  CAJAMARCA    CONTUMAZA
# 2           EL GUAYO  CAJAMARCA   SAN MIGUEL
# 3         LAMASPAMPA  CAJAMARCA   SAN MIGUEL
# 4           EL PRADO  CAJAMARCA   SAN MIGUEL
# ...              ...        ...          ...
# 1187      LANCHEPATA  CAJAMARCA       SOCOTA
# 1188  LIBERTAD LIMON  CAJAMARCA       SOCOTA
# 1189          PUCALA  CAJAMARCA       SOCOTA
# 1190          JAGUEY  CAJAMARCA    CONTUMAZA
# 1191        PISAGUAS  CAJAMARCA  SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1     OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2     OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3     OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                     DISTRITO EL PRADO -79.009410 -7.033193
# ...                                                 ...        ...       ...
# 1187  OTROS COMUNIDAD LANCHEPATA DISTRITO SANTO TOMA... -78.726498 -6.122737
# 1188  OTROS COMUNIDAD LIBERTAD LIMON COMUNIDAD LIBER... -78.806574 -6.073939
# 1189  OTROS CPM PUCALA DISTRITO PIMPINGOS PROVINCIA ... -78.763947 -6.122548
# 1190  AVENIDA AV. CAJAMARCA S/N NÚMERO S/N DISTRITO ... -78.940183 -7.614431
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo
# 0           613
# 1           613
# 2           666
# 3           666
# 4           666
# ...         ...
# 1187        630
# 1188        623
# 1189        623
# 1190        614
# 1191        650
#
# [1192 rows x 20 columns]

# %%
#Borramos datos missing
df_unido_2 = df_unido.dropna()
df_unido_2
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI   NOMBDIST    CAPITAL  UBIGEO  \
# 0      6.0  CAJAMARCA   5.0   CONTUMAZA   4.0   GUZMANGO   GUZMANGO   60504
# 1      6.0  CAJAMARCA   5.0   CONTUMAZA   4.0   GUZMANGO   GUZMANGO   60504
# 2      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# 3      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# 4      6.0  CAJAMARCA  11.0  SAN MIGUEL   5.0   EL PRADO   EL PRADO   61105
# ...    ...        ...   ...         ...   ...        ...        ...     ...
# 1185   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1186   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1187   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1188   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
# 1189   6.0  CAJAMARCA   6.0     CUTERVO   6.0  PIMPINGOS  PIMPINGOS   60606
#
#       Centroid_Latitude  Centroid_Longitude  id_eess  codigo_renaes categoria  \
# 0             -7.364304          -78.917689    13172           4553       I-2
# 1             -7.364304          -78.917689     5348           4554       I-2
# 2             -7.038039          -79.003318    18927           4540       I-1
# 3             -7.038039          -79.003318    13899           4573       I-2
# 4             -7.038039          -79.003318    21765           4575       I-2
# ...                 ...                 ...      ...            ...       ...
# 1185          -6.070895          -78.768292    24913           5016       I-1
# 1186          -6.070895          -78.768292    10080           5018       I-1
# 1187          -6.070895          -78.768292    13036           5024       I-1
# 1188          -6.070895          -78.768292    13500           6867       I-1
# 1189          -6.070895          -78.768292    24108          11068       I-1
#
#               nombre     diresa         red  \
# 0           GUZMANGO  CAJAMARCA   CONTUMAZA
# 1         TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2           EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3         LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4           EL PRADO  CAJAMARCA  SAN MIGUEL
# ...              ...        ...         ...
# 1185        PANDALLE  CAJAMARCA      SOCOTA
# 1186        EL PALTO  CAJAMARCA      SOCOTA
# 1187      LANCHEPATA  CAJAMARCA      SOCOTA
# 1188  LIBERTAD LIMON  CAJAMARCA      SOCOTA
# 1189          PUCALA  CAJAMARCA      SOCOTA
#
#                                               direccion   longitud   latitud  \
# 0     JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1     OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2     OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3     OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                     DISTRITO EL PRADO -79.009410 -7.033193
# ...                                                 ...        ...       ...
# 1185  OTROS COMUNIDAD DE PANDALLE DISTRITO PIMPINGOS... -78.798570 -6.102590
# 1186  OTROS CASERIO EL PALTO S/N NÚMERO S/N DISTRITO... -78.753974 -6.108966
# 1187  OTROS COMUNIDAD LANCHEPATA DISTRITO SANTO TOMA... -78.726498 -6.122737
# 1188  OTROS COMUNIDAD LIBERTAD LIMON COMUNIDAD LIBER... -78.806574 -6.073939
# 1189  OTROS CPM PUCALA DISTRITO PIMPINGOS PROVINCIA ... -78.763947 -6.122548
#
#       id_ubigeo
# 0           613
# 1           613
# 2           666
# 3           666
# 4           666
# ...         ...
# 1185        623
# 1186        623
# 1187        630
# 1188        623
# 1189        623
#
# [1190 rows x 20 columns]

# %%
# Definimos una función para calcular la distancia euclidiana
def calcular_distancia(row):
    coords_1 = (row['Centroid_Latitude'], row['Centroid_Longitude'])
    coords_2 = (row['latitud'], row['longitud'])
    return math.sqrt((coords_2[0] - coords_1[0])**2 + (coords_2[1] - coords_1[1])**2)

# %%
# Aplicamos la función para calcular la distancia euclidiana y la agregamos como una nueva columna
df_unido_2.loc[:,'distancia'] = df_unido_2.apply(calcular_distancia, axis=1)
# Out:
# C:\Users\fersa\AppData\Local\Temp\ipykernel_10980\3545654064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unido_2.loc[:,'distancia'] = df_unido_2.apply(calcular_distancia, axis=1)

# %%
#Checamos si se unió la variable distancia 
df_unido_2.distancia
# Out:
# 0       0.028774
# 1       0.016409
# 2       0.063688
# 3       0.068684
# 4       0.007784
#           ...
# 1185    0.043833
# 1186    0.040674
# 1187    0.066591
# 1188    0.038403
# 1189    0.051835
# Name: distancia, Length: 1190, dtype: float64

# %%
#Ahora, encontramos la menor distancia por ubigeo 
idx = df_unido_2.groupby('UBIGEO')['distancia'].idxmin()

# %%
# Seleccionamos solo las filas con el valor mínimo en 'distancia' para cada 'UBIGEO'
df_unido_2_min = df_unido_2.loc[idx]
df_unido_2_min
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI    NOMBDIST     CAPITAL  UBIGEO  \
# 29     6.0  CAJAMARCA   1.0   CAJAMARCA   1.0   CAJAMARCA   CAJAMARCA   60101
# 1126   6.0  CAJAMARCA   1.0   CAJAMARCA   2.0    ASUNCION    ASUNCION   60102
# 932    6.0  CAJAMARCA   1.0   CAJAMARCA   3.0    CHETILLA    CHETILLA   60103
# 934    6.0  CAJAMARCA   1.0   CAJAMARCA   4.0      COSPAN      COSPAN   60104
# 1131   6.0  CAJAMARCA   1.0   CAJAMARCA   5.0   ENCAÑADA   ENCAÑADA   60105
# ...    ...        ...   ...         ...   ...         ...         ...     ...
# 925    6.0  CAJAMARCA  13.0  SANTA CRUZ   7.0       PULAN       PULAN   61307
# 930    6.0  CAJAMARCA  13.0  SANTA CRUZ   8.0  SAUCEPAMPA  SAUCEPAMPA   61308
# 1084   6.0  CAJAMARCA  13.0  SANTA CRUZ   9.0        SEXI        SEXI   61309
# 1085   6.0  CAJAMARCA  13.0  SANTA CRUZ  10.0    UTICYACU    UTICYACU   61310
# 1089   6.0  CAJAMARCA  13.0  SANTA CRUZ  11.0    YAUYUCAN    YAUYUCAN   61311
#
#       Centroid_Latitude  Centroid_Longitude  ...  codigo_renaes  categoria  \
# 29            -7.077465          -78.561111  ...           4640        I-3
# 1126          -7.338237          -78.527184  ...           4625        I-2
# 932           -7.142504          -78.654027  ...           4653        I-2
# 934           -7.453032          -78.516855  ...           4627        I-2
# 1131          -6.985228          -78.402941  ...           4599        I-1
# ...                 ...                 ...  ...            ...        ...
# 925           -6.746564          -78.921162  ...           4830        I-3
# 930           -6.682861          -78.908469  ...           4833        I-2
# 1084          -6.585583          -79.036353  ...           4710        I-1
# 1085          -6.614700          -78.790538  ...           4834        I-2
# 1089          -6.682860          -78.849440  ...           4836        I-1
#
#            nombre     diresa         red  \
# 29     LA TULPUNA  CAJAMARCA   CAJAMARCA
# 1126     ASUNCION  CAJAMARCA   CAJAMARCA
# 932      CHETILLA  CAJAMARCA   CAJAMARCA
# 934        COSPAN  CAJAMARCA   CAJAMARCA
# 1131  YERBA BUENA  CAJAMARCA   CAJAMARCA
# ...           ...        ...         ...
# 925         PULAN  CAJAMARCA  SANTA CRUZ
# 930    SAUCEPAMPA  CAJAMARCA  SANTA CRUZ
# 1084         SEXI  CAJAMARCA  SANTA CRUZ
# 1085     UTICYACU  CAJAMARCA  SANTA CRUZ
# 1089     PUCHUDEN  CAJAMARCA  SANTA CRUZ
#
#                                               direccion   longitud   latitud  \
# 29    AVENIDA AV. ALFONSO UGARTE S/N S/N AV. ALFONSO... -78.553230 -7.062130
# 1126  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS... -78.518526 -7.325364
# 932   JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ... -78.673751 -7.146314
# 934   JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP... -78.542951 -7.426715
# 1131  OTROS COMUNIDAD DE YERBA BUENA DISTRITO ENCAÑA... -78.373252 -6.991922
# ...                                                 ...        ...       ...
# 925   OTROS GNRL. CABREJOS S/N NÚMERO S/N DISTRITO P... -78.923230 -6.739940
# 930   OTROS CALL. 17 DE JULIO DISTRITO SAUCEPAMPA PR... -78.916056 -6.691435
# 1084  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT... -79.051096 -6.563187
# 1085  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV... -78.794564 -6.606021
# 1089  OTROS COMUNIDAD PUCHUDEN COMUNIDAD PUCHUDEN YA... -78.857844 -6.690749
#
#       id_ubigeo  distancia
# 29          563   0.017242
# 1126        564   0.015513
# 932         565   0.020088
# 934         566   0.037061
# 1131        567   0.030435
# ...         ...        ...
# 925         685   0.006940
# 930         686   0.011450
# 1084        687   0.026812
# 1085        688   0.009568
# 1089        689   0.011527
#
# [127 rows x 21 columns]

# %%
#Seleccionamos columnas objetivos para facilitar el manejo de la base
df_unido_final = df_unido_2_min.loc[:, ['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red', 'direccion', 'latitud', 'longitud', 'id_ubigeo', 'UBIGEO', 'CCDD', 'NOMBDEP', 'CCPP', 'NOMBPROV', 'CCDI', 'NOMBDIST', 'CAPITAL', 'Centroid_Latitude',
'Centroid_Longitude']]
df_unido_final = df_unido_final.reset_index(drop=True)
df_unido_final
# Out:
#      id_eess  codigo_renaes categoria       nombre     diresa         red  \
# 0      25604           4640       I-3   LA TULPUNA  CAJAMARCA   CAJAMARCA
# 1       7185           4625       I-2     ASUNCION  CAJAMARCA   CAJAMARCA
# 2       7777           4653       I-2     CHETILLA  CAJAMARCA   CAJAMARCA
# 3       9447           4627       I-2       COSPAN  CAJAMARCA   CAJAMARCA
# 4       9366           4599       I-1  YERBA BUENA  CAJAMARCA   CAJAMARCA
# ..       ...            ...       ...          ...        ...         ...
# 122    24910           4830       I-3        PULAN  CAJAMARCA  SANTA CRUZ
# 123    18932           4833       I-2   SAUCEPAMPA  CAJAMARCA  SANTA CRUZ
# 124     5471           4710       I-1         SEXI  CAJAMARCA  SANTA CRUZ
# 125    22920           4834       I-2     UTICYACU  CAJAMARCA  SANTA CRUZ
# 126     5353           4836       I-1     PUCHUDEN  CAJAMARCA  SANTA CRUZ
#
#                                              direccion   latitud   longitud  \
# 0    AVENIDA AV. ALFONSO UGARTE S/N S/N AV. ALFONSO... -7.062130 -78.553230
# 1    JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS... -7.325364 -78.518526
# 2    JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ... -7.146314 -78.673751
# 3    JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP... -7.426715 -78.542951
# 4    OTROS COMUNIDAD DE YERBA BUENA DISTRITO ENCAÑA... -6.991922 -78.373252
# ..                                                 ...       ...        ...
# 122  OTROS GNRL. CABREJOS S/N NÚMERO S/N DISTRITO P... -6.739940 -78.923230
# 123  OTROS CALL. 17 DE JULIO DISTRITO SAUCEPAMPA PR... -6.691435 -78.916056
# 124  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT... -6.563187 -79.051096
# 125  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV... -6.606021 -78.794564
# 126  OTROS COMUNIDAD PUCHUDEN COMUNIDAD PUCHUDEN YA... -6.690749 -78.857844
#
#      id_ubigeo  UBIGEO  CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI    NOMBDIST  \
# 0          563   60101   6.0  CAJAMARCA   1.0   CAJAMARCA   1.0   CAJAMARCA
# 1          564   60102   6.0  CAJAMARCA   1.0   CAJAMARCA   2.0    ASUNCION
# 2          565   60103   6.0  CAJAMARCA   1.0   CAJAMARCA   3.0    CHETILLA
# 3          566   60104   6.0  CAJAMARCA   1.0   CAJAMARCA   4.0      COSPAN
# 4          567   60105   6.0  CAJAMARCA   1.0   CAJAMARCA   5.0   ENCAÑADA
# ..         ...     ...   ...        ...   ...         ...   ...         ...
# 122        685   61307   6.0  CAJAMARCA  13.0  SANTA CRUZ   7.0       PULAN
# 123        686   61308   6.0  CAJAMARCA  13.0  SANTA CRUZ   8.0  SAUCEPAMPA
# 124        687   61309   6.0  CAJAMARCA  13.0  SANTA CRUZ   9.0        SEXI
# 125        688   61310   6.0  CAJAMARCA  13.0  SANTA CRUZ  10.0    UTICYACU
# 126        689   61311   6.0  CAJAMARCA  13.0  SANTA CRUZ  11.0    YAUYUCAN
#
#         CAPITAL  Centroid_Latitude  Centroid_Longitude
# 0     CAJAMARCA          -7.077465          -78.561111
# 1      ASUNCION          -7.338237          -78.527184
# 2      CHETILLA          -7.142504          -78.654027
# 3        COSPAN          -7.453032          -78.516855
# 4     ENCAÑADA          -6.985228          -78.402941
# ..          ...                ...                 ...
# 122       PULAN          -6.746564          -78.921162
# 123  SAUCEPAMPA          -6.682861          -78.908469
# 124        SEXI          -6.585583          -79.036353
# 125    UTICYACU          -6.614700          -78.790538
# 126    YAUYUCAN          -6.682860          -78.849440
#
# [127 rows x 20 columns]

# %% [markdown]
# **4. Use Google API Directions to find the driving travel time and distance from health establishments to district centroids. Set driving as the value of the parameter mode and Monday 4pm as departure_time. Include information on the three options of the traffic_model variable: best_guess, pessimistic, and optimistic**

# %%
# Generamos la clave API 
gmaps = googlemaps.Client(key='AIzaSyDQ8OA89GFnZvFhG03W2NFpRIDM1ad_Ff4')

# Definimos el tiempo de salida como el próximo lunes a las 4pm
now = datetime.now()
next_monday = now + timedelta(days=(7 - now.weekday() or 7))
departure_time = datetime(next_monday.year, next_monday.month, next_monday.day, 16)

# Iteramos sobre cada fila en el dataframe
for i, row in df_unido_final.iterrows():
    # Obtiene las coordenadas de origen y destino
    origen = (row['latitud'], row['longitud'])
    destino = (row['Centroid_Latitude'], row['Centroid_Longitude'])
    
    # Solicitamos las direcciones para cada modelo de tráfico
    for traffic_model in ['best_guess', 'pessimistic', 'optimistic']:
        directions_result = gmaps.directions(origen,
                                             destino,
                                             mode="driving",
                                             departure_time=departure_time,
                                             traffic_model=traffic_model)
        
        # Si no se encuentra resultados, pasa al siguiente calculo
        if not directions_result:
            print(f"No se encontraron resultados para el origen {origen} y el destino {destino} con el modelo de tráfico {traffic_model}.")
            continue

        # Extraemos la distancia y el tiempo de viaje
        distancia = directions_result[0]['legs'][0]['distance']['text']
        tiempo = directions_result[0]['legs'][0]['duration_in_traffic']['text']

        # Añade los resultados al dataframe
        df_unido_final.loc[i, f'travel_distance_{traffic_model}'] = distancia
        df_unido_final.loc[i, f'travel_time_{traffic_model}'] = tiempo
# Out:
# No se encontraron resultados para el origen (-6.60346578, -78.19837123) y el destino (-6.570579571483123, -78.18705795503254) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-6.60346578, -78.19837123) y el destino (-6.570579571483123, -78.18705795503254) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-6.60346578, -78.19837123) y el destino (-6.570579571483123, -78.18705795503254) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-6.45880937, -78.30410337) y el destino (-6.487693638144822, -78.28551672740241) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-6.45880937, -78.30410337) y el destino (-6.487693638144822, -78.28551672740241) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-6.45880937, -78.30410337) y el destino (-6.487693638144822, -78.28551672740241) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-6.2160125, -79.08397231) y el destino (-6.196787754579376, -79.09163350392943) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-6.2160125, -79.08397231) y el destino (-6.196787754579376, -79.09163350392943) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-6.2160125, -79.08397231) y el destino (-6.196787754579376, -79.09163350392943) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-6.17102, -78.60362) y el destino (-6.174218113399612, -78.60009249414134) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-6.17102, -78.60362) y el destino (-6.174218113399612, -78.60009249414134) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-6.17102, -78.60362) y el destino (-6.174218113399612, -78.60009249414134) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.64022668, -79.12639667) y el destino (-5.633938366176614, -79.1333554620538) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.64022668, -79.12639667) y el destino (-5.633938366176614, -79.1333554620538) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.64022668, -79.12639667) y el destino (-5.633938366176614, -79.1333554620538) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.87976212, -79.17677956) y el destino (-5.8753999738952, -79.19500591545217) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.87976212, -79.17677956) y el destino (-5.8753999738952, -79.19500591545217) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.87976212, -79.17677956) y el destino (-5.8753999738952, -79.19500591545217) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.65620348, -79.31577965) y el destino (-5.625686059091744, -79.31242741575443) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.65620348, -79.31577965) y el destino (-5.625686059091744, -79.31242741575443) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.65620348, -79.31577965) y el destino (-5.625686059091744, -79.31242741575443) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.54900682, -79.03845599) y el destino (-5.517367642855747, -79.05506108087833) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.54900682, -79.03845599) y el destino (-5.517367642855747, -79.05506108087833) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.54900682, -79.03845599) y el destino (-5.517367642855747, -79.05506108087833) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.16398, -78.75058) y el destino (-5.09652405211401, -78.71529057820497) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.16398, -78.75058) y el destino (-5.09652405211401, -78.71529057820497) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.16398, -78.75058) y el destino (-5.09652405211401, -78.71529057820497) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-5.08898, -79.17658) y el destino (-5.107316398456057, -79.18098681854407) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-5.08898, -79.17658) y el destino (-5.107316398456057, -79.18098681854407) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-5.08898, -79.17658) y el destino (-5.107316398456057, -79.18098681854407) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-4.92764, -78.90137) y el destino (-4.915990503475814, -78.83184908839714) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-4.92764, -78.90137) y el destino (-4.915990503475814, -78.83184908839714) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-4.92764, -78.90137) y el destino (-4.915990503475814, -78.83184908839714) con el modelo de tráfico optimistic.
# No se encontraron resultados para el origen (-6.75689, -79.04854) y el destino (-6.749358435052559, -79.07690654224525) con el modelo de tráfico best_guess.
# No se encontraron resultados para el origen (-6.75689, -79.04854) y el destino (-6.749358435052559, -79.07690654224525) con el modelo de tráfico pessimistic.
# No se encontraron resultados para el origen (-6.75689, -79.04854) y el destino (-6.749358435052559, -79.07690654224525) con el modelo de tráfico optimistic.

# %%
#Como vemos no se encuentran para algunos casos resultados de tiempo y distancia, por tanto comprobamos cuales son esos casos
df_na = df_unido_final[df_unido_final.isna().any(axis=1)]
print(df_na)
# Out:
#      id_eess  codigo_renaes categoria                      nombre     diresa  \
# 17     21960           4479       I-1                     CHUMUCH  CAJAMARCA
# 18     18468           6757       I-1                      CANDEN  CAJAMARCA
# 61      7190           5007       I-2  SANTA ROSA DE QUEROCOTILLO  CAJAMARCA
# 63     26339           7103       I-1      SANTA ROSA DE SAN JUAN  CAJAMARCA
# 75     17284           4233       I-2                PACHAPIRIANA  CAJAMARCA
# 79     11210           7166       I-1                    MANGAYPA  CAJAMARCA
# 81     13169           4250       I-3                    SALLIQUE  CAJAMARCA
# 83      7480          13058       I-1                   SAN PEDRO  CAJAMARCA
# 87     12206           4284       I-3     EL PORVENIR DE HUARANGO  CAJAMARCA
# 89     13502           7016       I-2                 PAMPA VERDE  CAJAMARCA
# 90      9442           4308       I-1                    DIAMANTE  CAJAMARCA
# 118    19453           4777       I-1                     MACUACO  CAJAMARCA
#
#              red                                          direccion   latitud  \
# 17      CELENDIN  OTROS COMUNIDAD CHUMUCH DISTRITO CHUMUCH PROVI... -6.603466
# 18      CELENDIN  OTROS LOCALIDAD CANDEN DISTRITO CORTEGANA PROV... -6.458809
# 61       CUTERVO  OTROS LOCALIDAD SANTA ROSA LOCALIDAD SANTA ROS... -6.216012
# 63        SOCOTA  OTROS COMUNIDAD DE SANTA ROSA COMUNIDAD DE SAN... -6.171020
# 75          JAEN  OTROS COMUNIDAD DE PACHAPIRIANA COMUNIDAD DE P... -5.640227
# 79          JAEN  OTROS C.P. MANGAYPA C.P. MANGAYPA POMAHUACA JA... -5.879762
# 81          JAEN  CALLE CALLE ALFONSO UGARTE S/N S/N CALLE ALFON... -5.656203
# 83          JAEN  OTROS CASERIO SAN PEDRO CASERIO SAN PEDRO SAN ... -5.549007
# 87   SAN IGNACIO  OTROS DISTRITO EL HUARANGO DISTRITO EL HUARANG... -5.163980
# 89   SAN IGNACIO  OTROS PAMPA VERDE DISTRITO NAMBALLE PROVINCIA ... -5.088980
# 90   SAN IGNACIO  OTROS COMUNIDAD EL DIAMANTE DISTRITO SAN JOSE ... -4.927640
# 118   SANTA CRUZ  OTROS COMUNIDAD MACUACO DISTRITO CATACHE PROVI... -6.756890
#
#       longitud  id_ubigeo  ...             NOMBDIST              CAPITAL  \
# 17  -78.198371        580  ...              CHUMUCH              CHUMUCH
# 18  -78.304103        581  ...            CORTEGANA  CHIMUCH (CORTEGANA)
# 61  -79.083972        624  ...         QUEROCOTILLO         QUEROCOTILLO
# 63  -78.603620        626  ...  SAN JUAN DE CUTERVO  SAN JUAN DE CUTERVO
# 75  -79.126397        638  ...             CHONTALI             CHONTALI
# 79  -79.176780        642  ...            POMAHUACA            POMAHUACA
# 81  -79.315780        644  ...             SALLIQUE             SALLIQUE
# 83  -79.038456        646  ...    SAN JOSE DEL ALTO    SAN JOSE DEL ALTO
# 87  -78.750580        650  ...             HUARANGO             HUARANGO
# 89  -79.176580        652  ...             NAMBALLE             NAMBALLE
# 90  -78.901370        653  ...  SAN JOSE DE LOURDES  SAN JOSE DE LOURDES
# 118 -79.048540        681  ...              CATACHE              CATACHE
#
#     Centroid_Latitude  Centroid_Longitude travel_distance_best_guess  \
# 17          -6.570580          -78.187058                        NaN
# 18          -6.487694          -78.285517                        NaN
# 61          -6.196788          -79.091634                        NaN
# 63          -6.174218          -78.600092                        NaN
# 75          -5.633938          -79.133355                        NaN
# 79          -5.875400          -79.195006                        NaN
# 81          -5.625686          -79.312427                        NaN
# 83          -5.517368          -79.055061                        NaN
# 87          -5.096524          -78.715291                        NaN
# 89          -5.107316          -79.180987                        NaN
# 90          -4.915991          -78.831849                        NaN
# 118         -6.749358          -79.076907                        NaN
#
#      travel_time_best_guess travel_distance_pessimistic  \
# 17                      NaN                         NaN
# 18                      NaN                         NaN
# 61                      NaN                         NaN
# 63                      NaN                         NaN
# 75                      NaN                         NaN
# 79                      NaN                         NaN
# 81                      NaN                         NaN
# 83                      NaN                         NaN
# 87                      NaN                         NaN
# 89                      NaN                         NaN
# 90                      NaN                         NaN
# 118                     NaN                         NaN
#
#     travel_time_pessimistic  travel_distance_optimistic  \
# 17                      NaN                         NaN
# 18                      NaN                         NaN
# 61                      NaN                         NaN
# 63                      NaN                         NaN
# 75                      NaN                         NaN
# 79                      NaN                         NaN
# 81                      NaN                         NaN
# 83                      NaN                         NaN
# 87                      NaN                         NaN
# 89                      NaN                         NaN
# 90                      NaN                         NaN
# 118                     NaN                         NaN
#
#      travel_time_optimistic
# 17                      NaN
# 18                      NaN
# 61                      NaN
# 63                      NaN
# 75                      NaN
# 79                      NaN
# 81                      NaN
# 83                      NaN
# 87                      NaN
# 89                      NaN
# 90                      NaN
# 118                     NaN
#
# [12 rows x 26 columns]

# %% [markdown]
# *Tal y como vemos para 11 casos el API de Google no ha podido calcular distancias entre punto de origen y destino. Tras comprobar rapidamente en maps las rutas, se observan dos causisticas: o son puntos cercanos o no hay ruta de automovil entre esos dos puntos.*

# %%
#Observamos la base de datos solicitada
df_unido_final
# Out:
#      id_eess  codigo_renaes categoria       nombre     diresa         red  \
# 0      25604           4640       I-3   LA TULPUNA  CAJAMARCA   CAJAMARCA
# 1       7185           4625       I-2     ASUNCION  CAJAMARCA   CAJAMARCA
# 2       7777           4653       I-2     CHETILLA  CAJAMARCA   CAJAMARCA
# 3       9447           4627       I-2       COSPAN  CAJAMARCA   CAJAMARCA
# 4       9366           4599       I-1  YERBA BUENA  CAJAMARCA   CAJAMARCA
# ..       ...            ...       ...          ...        ...         ...
# 122    24910           4830       I-3        PULAN  CAJAMARCA  SANTA CRUZ
# 123    18932           4833       I-2   SAUCEPAMPA  CAJAMARCA  SANTA CRUZ
# 124     5471           4710       I-1         SEXI  CAJAMARCA  SANTA CRUZ
# 125    22920           4834       I-2     UTICYACU  CAJAMARCA  SANTA CRUZ
# 126     5353           4836       I-1     PUCHUDEN  CAJAMARCA  SANTA CRUZ
#
#                                              direccion   latitud   longitud  \
# 0    AVENIDA AV. ALFONSO UGARTE S/N S/N AV. ALFONSO... -7.062130 -78.553230
# 1    JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS... -7.325364 -78.518526
# 2    JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ... -7.146314 -78.673751
# 3    JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP... -7.426715 -78.542951
# 4    OTROS COMUNIDAD DE YERBA BUENA DISTRITO ENCAÑA... -6.991922 -78.373252
# ..                                                 ...       ...        ...
# 122  OTROS GNRL. CABREJOS S/N NÚMERO S/N DISTRITO P... -6.739940 -78.923230
# 123  OTROS CALL. 17 DE JULIO DISTRITO SAUCEPAMPA PR... -6.691435 -78.916056
# 124  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT... -6.563187 -79.051096
# 125  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV... -6.606021 -78.794564
# 126  OTROS COMUNIDAD PUCHUDEN COMUNIDAD PUCHUDEN YA... -6.690749 -78.857844
#
#      id_ubigeo  ...    NOMBDIST     CAPITAL Centroid_Latitude  \
# 0          563  ...   CAJAMARCA   CAJAMARCA         -7.077465
# 1          564  ...    ASUNCION    ASUNCION         -7.338237
# 2          565  ...    CHETILLA    CHETILLA         -7.142504
# 3          566  ...      COSPAN      COSPAN         -7.453032
# 4          567  ...   ENCAÑADA   ENCAÑADA         -6.985228
# ..         ...  ...         ...         ...               ...
# 122        685  ...       PULAN       PULAN         -6.746564
# 123        686  ...  SAUCEPAMPA  SAUCEPAMPA         -6.682861
# 124        687  ...        SEXI        SEXI         -6.585583
# 125        688  ...    UTICYACU    UTICYACU         -6.614700
# 126        689  ...    YAUYUCAN    YAUYUCAN         -6.682860
#
#      Centroid_Longitude travel_distance_best_guess  travel_time_best_guess  \
# 0            -78.561111                     3.9 km                 10 mins
# 1            -78.527184                     5.5 km                 14 mins
# 2            -78.654027                    10.6 km                 26 mins
# 3            -78.516855                    14.1 km                 37 mins
# 4            -78.402941                    17.9 km                 47 mins
# ..                  ...                        ...                     ...
# 122          -78.921162                     1.4 km                  4 mins
# 123          -78.908469                     1.7 km                  4 mins
# 124          -79.036353                     1.5 km                  3 mins
# 125          -78.790538                     1.5 km                  4 mins
# 126          -78.849440                     2.2 km                  5 mins
#
#     travel_distance_pessimistic travel_time_pessimistic  \
# 0                        3.9 km                 10 mins
# 1                        5.5 km                 14 mins
# 2                       10.6 km                 26 mins
# 3                       14.1 km                 37 mins
# 4                       17.9 km                 48 mins
# ..                          ...                     ...
# 122                      1.4 km                  4 mins
# 123                      1.7 km                  4 mins
# 124                      1.5 km                  3 mins
# 125                      1.5 km                  4 mins
# 126                      2.2 km                  5 mins
#
#      travel_distance_optimistic  travel_time_optimistic
# 0                        3.9 km                 10 mins
# 1                        5.5 km                 14 mins
# 2                       10.6 km                 26 mins
# 3                       14.1 km                 37 mins
# 4                       17.9 km                 48 mins
# ..                          ...                     ...
# 122                      1.4 km                  4 mins
# 123                      1.7 km                  4 mins
# 124                      1.5 km                  3 mins
# 125                      1.5 km                  4 mins
# 126                      2.2 km                  5 mins
#
# [127 rows x 26 columns]
