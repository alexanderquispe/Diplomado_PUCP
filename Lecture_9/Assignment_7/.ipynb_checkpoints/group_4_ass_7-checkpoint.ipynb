# %%
import os
import pickle
import pandas as pd
import numpy as np
import savReaderWriter as sav
import pandas as pd
import numpy as np
from datetime import datetime
# %matplotlib inline

import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.core.display import display, HTML
import seaborn as sns

# Legend
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import unidecode
#plt.rcParams.update({'font.size': 16})

#***************************************************
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import urllib.request, json, csv
import googlemaps
from tqdm import tqdm_notebook as tqdm
import re
import unidecode
import time 
import json
import pprint

import requests
import dateutil.parser
import unicodedata
import chardet
from datetime import datetime

# %% [markdown]
# # Assignment_7

# %% [markdown]
# ### 2 Import the data located at this link. This dataset comes from this link. It has information on all the geolocated health establishments in Cajamarca.

# %%
health_establishments_0 = pd.read_excel('..\..\_data\cajamarca_data_helth_estb.xlsx',
                                       index_col = 0)

health_establishments_0
# Out:
#          codigo_renaes categoria                nombre     diresa  \
# id_eess
# 9439              4210      II-1            GRAL. JAEN  CAJAMARCA
# 27242             4211       I-4           MORRO SOLAR  CAJAMARCA
# 22911             4212       I-3             MAGLLANAL  CAJAMARCA
# 9242              4213       I-3             FILA ALTA  CAJAMARCA
# 26418             4214       I-1          LAS NARANJAS  CAJAMARCA
# ...                ...       ...                   ...        ...
# 21625             5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 8179              6853       I-1            SAIREPAMPA  CAJAMARCA
# 16451             6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 3040              7048       I-1             SEXESHITA  CAJAMARCA
# 26156             6995       I-1              PISAGUAS  CAJAMARCA
#
#                                 red  \
# id_eess
# 9439     NO PERTENECE A NINGUNA RED
# 27242                          JAEN
# 22911                          JAEN
# 9242                           JAEN
# 26418                          JAEN
# ...                             ...
# 21625                        SOCOTA
# 8179                         SOCOTA
# 16451                        SOCOTA
# 3040                         SOCOTA
# 26156                   SAN IGNACIO
#
#                                                  direccion   longitud  \
# id_eess
# 9439     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711
# 27242    OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920
# 22911    CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266
# 9242     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643
# 26418    OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347
# ...                                                    ...        ...
# 21625    CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471
# 8179     OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080
# 16451    OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640
# 3040     OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210
# 26156    OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093
#
#           latitud  id_ubigeo  ind  ...  CCPP NOMBPROV  CCDI  \
# id_eess                            ...
# 9439    -5.706214        636    1  ...     8     JAEN     1
# 27242   -5.710600        636    1  ...     8     JAEN     1
# 22911   -5.707647        636    1  ...     8     JAEN     1
# 9242    -5.739184        636    1  ...     8     JAEN     1
# 26418   -5.745295        636    1  ...     8     JAEN     1
# ...           ...        ...  ...  ...   ...      ...   ...
# 21625   -6.292044        627    1  ...     6  CUTERVO    10
# 8179    -6.279960        627    1  ...     6  CUTERVO    10
# 16451   -6.266560        627    1  ...     6  CUTERVO    10
# 3040    -6.267210        627    1  ...     6  CUTERVO    10
# 26156   -5.248693        650    1  ...     2    BAGUA     5
#
#                   NOMBDIST            CAPITAL UBIGEO IDPROV  CODIGO  CNT_CCPP  \
# id_eess
# 9439                  JAEN               JAEN  60801    608   60801       108
# 27242                 JAEN               JAEN  60801    608   60801       108
# 22911                 JAEN               JAEN  60801    608   60801       108
# 9242                  JAEN               JAEN  60801    608   60801       108
# 26418                 JAEN               JAEN  60801    608   60801       108
# ...                    ...                ...    ...    ...     ...       ...
# 21625    SAN LUIS DE LUCMA  SAN LUIS DE LUCMA  60610    606   60610        19
# 8179     SAN LUIS DE LUCMA  SAN LUIS DE LUCMA  60610    606   60610        19
# 16451    SAN LUIS DE LUCMA  SAN LUIS DE LUCMA  60610    606   60610        19
# 3040     SAN LUIS DE LUCMA  SAN LUIS DE LUCMA  60610    606   60610        19
# 26156                IMAZA           CHIRIACO  10205    102   10205       159
#
#                 DESCRIPCIO
# id_eess
# 9439                  JAEN
# 27242                 JAEN
# 22911                 JAEN
# 9242                  JAEN
# 26418                 JAEN
# ...                    ...
# 21625    SAN LUIS DE LUCMA
# 8179     SAN LUIS DE LUCMA
# 16451    SAN LUIS DE LUCMA
# 3040     SAN LUIS DE LUCMA
# 26156                IMAZA
#
# [1192 rows x 22 columns]

# %%
health_establishments = health_establishments_0.drop(['ind', 'DESCRIPCIO', 'CNT_CCPP', 'CODIGO', 'IDPROV'], axis=1)
health_establishments.head()
# Out:
#          codigo_renaes categoria        nombre     diresa  \
# id_eess
# 9439              4210      II-1    GRAL. JAEN  CAJAMARCA
# 27242             4211       I-4   MORRO SOLAR  CAJAMARCA
# 22911             4212       I-3     MAGLLANAL  CAJAMARCA
# 9242              4213       I-3     FILA ALTA  CAJAMARCA
# 26418             4214       I-1  LAS NARANJAS  CAJAMARCA
#
#                                 red  \
# id_eess
# 9439     NO PERTENECE A NINGUNA RED
# 27242                          JAEN
# 22911                          JAEN
# 9242                           JAEN
# 26418                          JAEN
#
#                                                  direccion   longitud  \
# id_eess
# 9439     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711
# 27242    OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920
# 22911    CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266
# 9242     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643
# 26418    OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347
#
#           latitud  id_ubigeo  CCDD    NOMBDEP  CCPP NOMBPROV  CCDI NOMBDIST  \
# id_eess
# 9439    -5.706214        636     6  CAJAMARCA     8     JAEN     1     JAEN
# 27242   -5.710600        636     6  CAJAMARCA     8     JAEN     1     JAEN
# 22911   -5.707647        636     6  CAJAMARCA     8     JAEN     1     JAEN
# 9242    -5.739184        636     6  CAJAMARCA     8     JAEN     1     JAEN
# 26418   -5.745295        636     6  CAJAMARCA     8     JAEN     1     JAEN
#
#         CAPITAL  UBIGEO
# id_eess
# 9439       JAEN   60801
# 27242      JAEN   60801
# 22911      JAEN   60801
# 9242       JAEN   60801
# 26418      JAEN   60801

# %% [markdown]
# ### 3. Import the district's centroids data. It has the latitude and longitude of every district in Peru.

# %%
centroids_data_0 = pd.read_excel('..\..\_data\peru_districts_centroids.xlsx',
                                 index_col=0)
centroids_data_0
# Out:
#         NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# CCDD
# 6     CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 6     CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 6     CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 6     CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 6     CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...         ...   ...         ...   ...           ...              ...
# 4      AREQUIPA     4    CASTILLA     4       CHACHAS          CHACHAS
# 4      AREQUIPA     4    CASTILLA     5  CHILCAYMARCA     CHILCAYMARCA
# 4      AREQUIPA     4    CASTILLA     6         CHOCO            CHOCO
# 4      AREQUIPA     4    CASTILLA     7    HUANCARQUI       HUANCARQUI
# 12        JUNIN     6      SATIPO     4      MAZAMARI              NaN
#
#       UBIGEO  IDPROV  CODIGO  Centroid_Latitude  Centroid_Longitude
# CCDD
# 6      60504     605   60504          -7.364304          -78.917689
# 6      61105     611   61105          -7.038039          -79.003318
# 6      61109     611   61109          -6.926718          -79.131435
# 6      61110     611   61110          -7.117978          -79.160968
# 6      61203     612   61203          -7.159046          -78.873084
# ...      ...     ...     ...                ...                 ...
# 4      40404     404   40404         -15.181923          -72.116054
# 4      40405     404   40405         -15.350613          -72.385276
# 4      40406     404   40406         -15.414004          -72.068684
# 4      40407     404   40407         -16.012364          -72.368167
# 12    120604    1206  120604         -11.493927          -74.241229
#
# [1874 rows x 11 columns]

# %%
centroids_data = centroids_data_0.drop(['IDPROV', 'CODIGO', 'CCDI','NOMBPROV','NOMBDIST', 'CAPITAL', 'CCPP'], axis=1)
centroids_data.head()
# Out:
#         NOMBDEP  UBIGEO  Centroid_Latitude  Centroid_Longitude
# CCDD
# 6     CAJAMARCA   60504          -7.364304          -78.917689
# 6     CAJAMARCA   61105          -7.038039          -79.003318
# 6     CAJAMARCA   61109          -6.926718          -79.131435
# 6     CAJAMARCA   61110          -7.117978          -79.160968
# 6     CAJAMARCA   61203          -7.159046          -78.873084

# %%
#keep only Cajamarca
centroids_data_cajamarca = centroids_data.loc[centroids_data["NOMBDEP"] == "CAJAMARCA"]
centroids_data_cajamarca
# Out:
#         NOMBDEP  UBIGEO  Centroid_Latitude  Centroid_Longitude
# CCDD
# 6     CAJAMARCA   60504          -7.364304          -78.917689
# 6     CAJAMARCA   61105          -7.038039          -79.003318
# 6     CAJAMARCA   61109          -6.926718          -79.131435
# 6     CAJAMARCA   61110          -7.117978          -79.160968
# 6     CAJAMARCA   61203          -7.159046          -78.873084
# ...         ...     ...                ...                 ...
# 6     CAJAMARCA   60308          -7.059289          -78.061333
# 6     CAJAMARCA   60309          -6.934215          -78.297182
# 6     CAJAMARCA   60810          -5.786477          -79.310211
# 6     CAJAMARCA   60806          -5.636342          -78.849590
# 6     CAJAMARCA   60606          -6.070895          -78.768292
#
# [127 rows x 4 columns]

# %% [markdown]
# ### 4.Use these datasets and find the closest health establishment to Cajamarca district centroids. For each district, there should be only one health establishment.

# %%
left_merged_0 = pd.merge(centroids_data_cajamarca, health_establishments,
                        how="left", on=["UBIGEO"])
left_merged_0.shape
# Out:
# (1190, 20)

# %%
left_merged = left_merged_0.drop(['NOMBDEP_y'], axis=1)
left_merged.head()
# Out:
#    NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 0  CAJAMARCA   60504          -7.364304          -78.917689           4553
# 1  CAJAMARCA   60504          -7.364304          -78.917689           4554
# 2  CAJAMARCA   61105          -7.038039          -79.003318           4540
# 3  CAJAMARCA   61105          -7.038039          -79.003318           4573
# 4  CAJAMARCA   61105          -7.038039          -79.003318           4575
#
#   categoria      nombre     diresa         red  \
# 0       I-2    GUZMANGO  CAJAMARCA   CONTUMAZA
# 1       I-2  TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       I-1    EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       I-2  LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       I-2    EL PRADO  CAJAMARCA  SAN MIGUEL
#
#                                            direccion   longitud   latitud  \
# 0  JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1  OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2  OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3  OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                  DISTRITO EL PRADO -79.009410 -7.033193
#
#    id_ubigeo  CCDD  CCPP    NOMBPROV  CCDI  NOMBDIST   CAPITAL
# 0        613     6     5   CONTUMAZA     4  GUZMANGO  GUZMANGO
# 1        613     6     5   CONTUMAZA     4  GUZMANGO  GUZMANGO
# 2        666     6    11  SAN MIGUEL     5  EL PRADO  EL PRADO
# 3        666     6    11  SAN MIGUEL     5  EL PRADO  EL PRADO
# 4        666     6    11  SAN MIGUEL     5  EL PRADO  EL PRADO

# %%
# find the closest health establishment
#diferencia longitud
left_merged["diferencia_latitud"] = left_merged["Centroid_Latitude"] - left_merged["latitud"]
#diferencia latitud
left_merged["diferencia_longitud"] = left_merged["Centroid_Longitude"] - left_merged["longitud"]
left_merged.head()
# Out:
#    NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 0  CAJAMARCA   60504          -7.364304          -78.917689           4553
# 1  CAJAMARCA   60504          -7.364304          -78.917689           4554
# 2  CAJAMARCA   61105          -7.038039          -79.003318           4540
# 3  CAJAMARCA   61105          -7.038039          -79.003318           4573
# 4  CAJAMARCA   61105          -7.038039          -79.003318           4575
#
#   categoria      nombre     diresa         red  \
# 0       I-2    GUZMANGO  CAJAMARCA   CONTUMAZA
# 1       I-2  TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       I-1    EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       I-2  LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       I-2    EL PRADO  CAJAMARCA  SAN MIGUEL
#
#                                            direccion  ...   latitud  \
# 0  JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA...  ... -7.384092
# 1  OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ...  ... -7.353468
# 2  OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO...  ... -7.101318
# 3  OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P...  ... -7.104470
# 4                                  DISTRITO EL PRADO  ... -7.033193
#
#    id_ubigeo  CCDD  CCPP    NOMBPROV CCDI  NOMBDIST   CAPITAL  \
# 0        613     6     5   CONTUMAZA    4  GUZMANGO  GUZMANGO
# 1        613     6     5   CONTUMAZA    4  GUZMANGO  GUZMANGO
# 2        666     6    11  SAN MIGUEL    5  EL PRADO  EL PRADO
# 3        666     6    11  SAN MIGUEL    5  EL PRADO  EL PRADO
# 4        666     6    11  SAN MIGUEL    5  EL PRADO  EL PRADO
#
#   diferencia_latitud  diferencia_longitud
# 0           0.019788            -0.020891
# 1          -0.010836             0.012322
# 2           0.063279             0.007207
# 3           0.066431            -0.017448
# 4          -0.004846             0.006092
#
# [5 rows x 21 columns]

# %%
#agregado
left_merged["distancia"] = left_merged["diferencia_latitud"] + left_merged["diferencia_longitud"]
left_merged.head()
# Out:
#    NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 0  CAJAMARCA   60504          -7.364304          -78.917689           4553
# 1  CAJAMARCA   60504          -7.364304          -78.917689           4554
# 2  CAJAMARCA   61105          -7.038039          -79.003318           4540
# 3  CAJAMARCA   61105          -7.038039          -79.003318           4573
# 4  CAJAMARCA   61105          -7.038039          -79.003318           4575
#
#   categoria      nombre     diresa         red  \
# 0       I-2    GUZMANGO  CAJAMARCA   CONTUMAZA
# 1       I-2  TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       I-1    EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       I-2  LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       I-2    EL PRADO  CAJAMARCA  SAN MIGUEL
#
#                                            direccion  ...  id_ubigeo  CCDD  \
# 0  JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA...  ...        613     6
# 1  OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ...  ...        613     6
# 2  OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO...  ...        666     6
# 3  OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P...  ...        666     6
# 4                                  DISTRITO EL PRADO  ...        666     6
#
#    CCPP    NOMBPROV  CCDI  NOMBDIST   CAPITAL diferencia_latitud  \
# 0     5   CONTUMAZA     4  GUZMANGO  GUZMANGO           0.019788
# 1     5   CONTUMAZA     4  GUZMANGO  GUZMANGO          -0.010836
# 2    11  SAN MIGUEL     5  EL PRADO  EL PRADO           0.063279
# 3    11  SAN MIGUEL     5  EL PRADO  EL PRADO           0.066431
# 4    11  SAN MIGUEL     5  EL PRADO  EL PRADO          -0.004846
#
#   diferencia_longitud  distancia
# 0           -0.020891  -0.001103
# 1            0.012322   0.001486
# 2            0.007207   0.070486
# 3           -0.017448   0.048982
# 4            0.006092   0.001245
#
# [5 rows x 22 columns]

# %%
#en valor absoluto
left_merged['distancia'] = left_merged['distancia'].abs()
left_merged.head()
# Out:
#    NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 0  CAJAMARCA   60504          -7.364304          -78.917689           4553
# 1  CAJAMARCA   60504          -7.364304          -78.917689           4554
# 2  CAJAMARCA   61105          -7.038039          -79.003318           4540
# 3  CAJAMARCA   61105          -7.038039          -79.003318           4573
# 4  CAJAMARCA   61105          -7.038039          -79.003318           4575
#
#   categoria      nombre     diresa         red  \
# 0       I-2    GUZMANGO  CAJAMARCA   CONTUMAZA
# 1       I-2  TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       I-1    EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       I-2  LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       I-2    EL PRADO  CAJAMARCA  SAN MIGUEL
#
#                                            direccion  ...  id_ubigeo  CCDD  \
# 0  JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA...  ...        613     6
# 1  OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ...  ...        613     6
# 2  OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO...  ...        666     6
# 3  OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P...  ...        666     6
# 4                                  DISTRITO EL PRADO  ...        666     6
#
#    CCPP    NOMBPROV  CCDI  NOMBDIST   CAPITAL diferencia_latitud  \
# 0     5   CONTUMAZA     4  GUZMANGO  GUZMANGO           0.019788
# 1     5   CONTUMAZA     4  GUZMANGO  GUZMANGO          -0.010836
# 2    11  SAN MIGUEL     5  EL PRADO  EL PRADO           0.063279
# 3    11  SAN MIGUEL     5  EL PRADO  EL PRADO           0.066431
# 4    11  SAN MIGUEL     5  EL PRADO  EL PRADO          -0.004846
#
#   diferencia_longitud  distancia
# 0           -0.020891   0.001103
# 1            0.012322   0.001486
# 2            0.007207   0.070486
# 3           -0.017448   0.048982
# 4            0.006092   0.001245
#
# [5 rows x 22 columns]

# %%
#minimo
left_merged.groupby(['UBIGEO'], sort=False)['distancia'].min()
# Out:
# UBIGEO
# 60504    0.001103
# 61105    0.001245
# 61109    0.003022
# 61110    0.087646
# 61203    0.006421
#            ...
# 60308    0.006445
# 60309    0.001916
# 60810    0.013596
# 60806    0.006443
# 60606    0.010047
# Name: distancia, Length: 127, dtype: float64

# %%
left_merged.groupby(['UBIGEO'])['distancia'].idxmin()
# Out:
# UBIGEO
# 60101     150
# 60102    1126
# 60103     932
# 60104     934
# 60105    1130
#          ...
# 61307     927
# 61308     931
# 61309    1084
# 61310    1085
# 61311    1090
# Name: distancia, Length: 127, dtype: int64

# %%
df = left_merged.iloc[left_merged.groupby(['UBIGEO'])['distancia'].idxmin()]
df.head()
# Out:
#       NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 150   CAJAMARCA   60101          -7.077465          -78.561111          28477
# 1126  CAJAMARCA   60102          -7.338237          -78.527184           4625
# 932   CAJAMARCA   60103          -7.142504          -78.654027           4653
# 934   CAJAMARCA   60104          -7.453032          -78.516855           4627
# 1130  CAJAMARCA   60105          -6.985228          -78.402941           4598
#
#      categoria                   nombre     diresa  \
# 150        I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1126       I-2                 ASUNCION  CAJAMARCA
# 932        I-2                 CHETILLA  CAJAMARCA
# 934        I-2                   COSPAN  CAJAMARCA
# 1130       I-1              LA VICTORIA  CAJAMARCA
#
#                              red  \
# 150   NO PERTENECE A NINGUNA RED
# 1126                   CAJAMARCA
# 932                    CAJAMARCA
# 934                    CAJAMARCA
# 1130                   CAJAMARCA
#
#                                               direccion  ...  id_ubigeo  CCDD  \
# 150   AVENIDA HOYOS RUBIO NÚMERO 2042 DISTRITO CAJAM...  ...        563     6
# 1126  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS...  ...        564     6
# 932   JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...  ...        565     6
# 934   JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...  ...        566     6
# 1130  OTROS COMUNIDAD DE LA VICTORIA DISTRITO ENCAÑA...  ...        567     6
#
#       CCPP   NOMBPROV  CCDI   NOMBDIST    CAPITAL diferencia_latitud  \
# 150      1  CAJAMARCA     1  CAJAMARCA  CAJAMARCA           0.068572
# 1126     1  CAJAMARCA     2   ASUNCION   ASUNCION          -0.012873
# 932      1  CAJAMARCA     3   CHETILLA   CHETILLA           0.003810
# 934      1  CAJAMARCA     4     COSPAN     COSPAN          -0.026317
# 1130     1  CAJAMARCA     5  ENCAÑADA  ENCAÑADA           0.092815
#
#      diferencia_longitud  distancia
# 150            -0.063406   0.005166
# 1126           -0.008657   0.021530
# 932             0.019724   0.023534
# 934             0.026095   0.000221
# 1130           -0.093085   0.000269
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (127, 22)

# %%
df.to_excel("df.xlsx")

# %% [markdown]
# ### 5. Use Google API Directions to find the driving travel time and distance from health establishments to district centroids. Set driving as the value of the parameter mode and Monday 4pm as departure_time. Include information on the three options of the traffic_model variable: #best_guess, pessimistic, and optimistic. The final data frame output should look like the table below:

# %%
df = pd.read_excel('df.xlsx',
                  index_col = 0)

df
# Out:
#       NOMBDEP_x  UBIGEO  Centroid_Latitude  Centroid_Longitude  codigo_renaes  \
# 150   CAJAMARCA   60101          -7.077465          -78.561111          28477
# 1126  CAJAMARCA   60102          -7.338237          -78.527184           4625
# 932   CAJAMARCA   60103          -7.142504          -78.654027           4653
# 934   CAJAMARCA   60104          -7.453032          -78.516855           4627
# 1130  CAJAMARCA   60105          -6.985228          -78.402941           4598
# ...         ...     ...                ...                 ...            ...
# 927   CAJAMARCA   61307          -6.746564          -78.921162           4832
# 931   CAJAMARCA   61308          -6.682861          -78.908469           6795
# 1084  CAJAMARCA   61309          -6.585583          -79.036353           4710
# 1085  CAJAMARCA   61310          -6.614700          -78.790538           4834
# 1090  CAJAMARCA   61311          -6.682860          -78.849440           4837
#
#      categoria                   nombre     diresa  \
# 150        I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1126       I-2                 ASUNCION  CAJAMARCA
# 932        I-2                 CHETILLA  CAJAMARCA
# 934        I-2                   COSPAN  CAJAMARCA
# 1130       I-1              LA VICTORIA  CAJAMARCA
# ...        ...                      ...        ...
# 927        I-1              SUCCHAPAMPA  CAJAMARCA
# 931        I-1             ROMERO CIRCA  CAJAMARCA
# 1084       I-1                     SEXI  CAJAMARCA
# 1085       I-2                 UTICYACU  CAJAMARCA
# 1090       I-1            YANAYACU ALTO  CAJAMARCA
#
#                              red  \
# 150   NO PERTENECE A NINGUNA RED
# 1126                   CAJAMARCA
# 932                    CAJAMARCA
# 934                    CAJAMARCA
# 1130                   CAJAMARCA
# ...                          ...
# 927                   SANTA CRUZ
# 931                   SANTA CRUZ
# 1084                  SANTA CRUZ
# 1085                  SANTA CRUZ
# 1090                  SANTA CRUZ
#
#                                               direccion  ...  id_ubigeo  CCDD  \
# 150   AVENIDA HOYOS RUBIO NÚMERO 2042 DISTRITO CAJAM...  ...        563     6
# 1126  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS...  ...        564     6
# 932   JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...  ...        565     6
# 934   JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...  ...        566     6
# 1130  OTROS COMUNIDAD DE LA VICTORIA DISTRITO ENCAÑA...  ...        567     6
# ...                                                 ...  ...        ...   ...
# 927   OTROS COMUNIDAD SUCCHAPAMPA DISTRITO PULAN PRO...  ...        685     6
# 931   OTROS COMUNIDAD ROMERO CIRA DISTRITO SAUCEPAMP...  ...        686     6
# 1084  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT...  ...        687     6
# 1085  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV...  ...        688     6
# 1090  OTROS COMUNIDAD YANAYACU COMUNIDAD YANAYACU YA...  ...        689     6
#
#       CCPP    NOMBPROV  CCDI    NOMBDIST     CAPITAL diferencia_latitud  \
# 150      1   CAJAMARCA     1   CAJAMARCA   CAJAMARCA           0.068572
# 1126     1   CAJAMARCA     2    ASUNCION    ASUNCION          -0.012873
# 932      1   CAJAMARCA     3    CHETILLA    CHETILLA           0.003810
# 934      1   CAJAMARCA     4      COSPAN      COSPAN          -0.026317
# 1130     1   CAJAMARCA     5   ENCAÑADA   ENCAÑADA           0.092815
# ...    ...         ...   ...         ...         ...                ...
# 927     13  SANTA CRUZ     7       PULAN       PULAN          -0.033154
# 931     13  SANTA CRUZ     8  SAUCEPAMPA  SAUCEPAMPA           0.010003
# 1084    13  SANTA CRUZ     9        SEXI        SEXI          -0.022395
# 1085    13  SANTA CRUZ    10    UTICYACU    UTICYACU          -0.008680
# 1090    13  SANTA CRUZ    11    YAUYUCAN    YAUYUCAN          -0.019977
#
#      diferencia_longitud  distancia
# 150            -0.063406   0.005166
# 1126           -0.008657   0.021530
# 932             0.019724   0.023534
# 934             0.026095   0.000221
# 1130           -0.093085   0.000269
# ...                  ...        ...
# 927             0.033848   0.000694
# 931            -0.018850   0.008847
# 1084            0.014742   0.007653
# 1085            0.004026   0.004653
# 1090            0.013262   0.006715
#
# [127 rows x 22 columns]

# %%
#df["separador"] =','
#7 decimals
df['latitud'] = df['latitud'].round(7)
df['longitud'] = df['longitud'].round(7)
df['Centroid_Latitude'] = df['Centroid_Latitude'].round(7)
df['Centroid_Longitude'] = df['Centroid_Longitude'].round(7)

# %%
#change to string origin and destination
df['latitud'] = df['latitud'].astype(str)
df['longitud'] = df['longitud'].astype(str)
df['Centroid_Latitude'] = df['Centroid_Latitude'].astype(str)
df['Centroid_Longitude'] = df['Centroid_Longitude'].astype(str)

# %%
df["healthest_origin"] = df["latitud"] + ',' + df["longitud"]
df["Centroid_destination"] = df["Centroid_Latitude"] + ',' + df["Centroid_Longitude"]
df.head()
# Out:
#       NOMBDEP_x  UBIGEO Centroid_Latitude Centroid_Longitude  codigo_renaes  \
# 150   CAJAMARCA   60101        -7.0774651        -78.5611113          28477
# 1126  CAJAMARCA   60102         -7.338237        -78.5271836           4625
# 932   CAJAMARCA   60103        -7.1425041        -78.6540271           4653
# 934   CAJAMARCA   60104        -7.4530319        -78.5168553           4627
# 1130  CAJAMARCA   60105        -6.9852282         -78.402941           4598
#
#      categoria                   nombre     diresa  \
# 150        I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1126       I-2                 ASUNCION  CAJAMARCA
# 932        I-2                 CHETILLA  CAJAMARCA
# 934        I-2                   COSPAN  CAJAMARCA
# 1130       I-1              LA VICTORIA  CAJAMARCA
#
#                              red  \
# 150   NO PERTENECE A NINGUNA RED
# 1126                   CAJAMARCA
# 932                    CAJAMARCA
# 934                    CAJAMARCA
# 1130                   CAJAMARCA
#
#                                               direccion  ... CCPP   NOMBPROV  \
# 150   AVENIDA HOYOS RUBIO NÚMERO 2042 DISTRITO CAJAM...  ...    1  CAJAMARCA
# 1126  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS...  ...    1  CAJAMARCA
# 932   JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...  ...    1  CAJAMARCA
# 934   JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...  ...    1  CAJAMARCA
# 1130  OTROS COMUNIDAD DE LA VICTORIA DISTRITO ENCAÑA...  ...    1  CAJAMARCA
#
#       CCDI   NOMBDIST    CAPITAL diferencia_latitud  diferencia_longitud  \
# 150      1  CAJAMARCA  CAJAMARCA           0.068572            -0.063406
# 1126     2   ASUNCION   ASUNCION          -0.012873            -0.008657
# 932      3   CHETILLA   CHETILLA           0.003810             0.019724
# 934      4     COSPAN     COSPAN          -0.026317             0.026095
# 1130     5  ENCAÑADA  ENCAÑADA           0.092815            -0.093085
#
#      distancia        healthest_origin    Centroid_destination
# 150   0.005166  -7.1460372,-78.4977056  -7.0774651,-78.5611113
# 1126  0.021530  -7.3253637,-78.5185264   -7.338237,-78.5271836
# 932   0.023534  -7.1463139,-78.6737509  -7.1425041,-78.6540271
# 934   0.000221   -7.426715,-78.5429507  -7.4530319,-78.5168553
# 1130  0.000269  -7.0780435,-78.3098563   -6.9852282,-78.402941
#
# [5 rows x 24 columns]

# %%
#combination
df['combination'] = df.index+1

# %%
df2=df
df2 = df2.reset_index(inplace=False)
df2
# Out:
#      index  NOMBDEP_x  UBIGEO Centroid_Latitude Centroid_Longitude  \
# 0      150  CAJAMARCA   60101        -7.0774651        -78.5611113
# 1     1126  CAJAMARCA   60102         -7.338237        -78.5271836
# 2      932  CAJAMARCA   60103        -7.1425041        -78.6540271
# 3      934  CAJAMARCA   60104        -7.4530319        -78.5168553
# 4     1130  CAJAMARCA   60105        -6.9852282         -78.402941
# ..     ...        ...     ...               ...                ...
# 122    927  CAJAMARCA   61307        -6.7465642        -78.9211618
# 123    931  CAJAMARCA   61308        -6.6828605        -78.9084687
# 124   1084  CAJAMARCA   61309        -6.5855825        -79.0363532
# 125   1085  CAJAMARCA   61310        -6.6147002        -78.7905375
# 126   1090  CAJAMARCA   61311        -6.6828597        -78.8494396
#
#      codigo_renaes categoria                   nombre     diresa  \
# 0            28477       I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1             4625       I-2                 ASUNCION  CAJAMARCA
# 2             4653       I-2                 CHETILLA  CAJAMARCA
# 3             4627       I-2                   COSPAN  CAJAMARCA
# 4             4598       I-1              LA VICTORIA  CAJAMARCA
# ..             ...       ...                      ...        ...
# 122           4832       I-1              SUCCHAPAMPA  CAJAMARCA
# 123           6795       I-1             ROMERO CIRCA  CAJAMARCA
# 124           4710       I-1                     SEXI  CAJAMARCA
# 125           4834       I-2                 UTICYACU  CAJAMARCA
# 126           4837       I-1            YANAYACU ALTO  CAJAMARCA
#
#                             red  ...    NOMBPROV CCDI    NOMBDIST     CAPITAL  \
# 0    NO PERTENECE A NINGUNA RED  ...   CAJAMARCA    1   CAJAMARCA   CAJAMARCA
# 1                     CAJAMARCA  ...   CAJAMARCA    2    ASUNCION    ASUNCION
# 2                     CAJAMARCA  ...   CAJAMARCA    3    CHETILLA    CHETILLA
# 3                     CAJAMARCA  ...   CAJAMARCA    4      COSPAN      COSPAN
# 4                     CAJAMARCA  ...   CAJAMARCA    5   ENCAÑADA   ENCAÑADA
# ..                          ...  ...         ...  ...         ...         ...
# 122                  SANTA CRUZ  ...  SANTA CRUZ    7       PULAN       PULAN
# 123                  SANTA CRUZ  ...  SANTA CRUZ    8  SAUCEPAMPA  SAUCEPAMPA
# 124                  SANTA CRUZ  ...  SANTA CRUZ    9        SEXI        SEXI
# 125                  SANTA CRUZ  ...  SANTA CRUZ   10    UTICYACU    UTICYACU
# 126                  SANTA CRUZ  ...  SANTA CRUZ   11    YAUYUCAN    YAUYUCAN
#
#      diferencia_latitud  diferencia_longitud distancia  \
# 0              0.068572            -0.063406  0.005166
# 1             -0.012873            -0.008657  0.021530
# 2              0.003810             0.019724  0.023534
# 3             -0.026317             0.026095  0.000221
# 4              0.092815            -0.093085  0.000269
# ..                  ...                  ...       ...
# 122           -0.033154             0.033848  0.000694
# 123            0.010003            -0.018850  0.008847
# 124           -0.022395             0.014742  0.007653
# 125           -0.008680             0.004026  0.004653
# 126           -0.019977             0.013262  0.006715
#
#            healthest_origin    Centroid_destination combination
# 0    -7.1460372,-78.4977056  -7.0774651,-78.5611113         151
# 1    -7.3253637,-78.5185264   -7.338237,-78.5271836        1127
# 2    -7.1463139,-78.6737509  -7.1425041,-78.6540271         933
# 3     -7.426715,-78.5429507  -7.4530319,-78.5168553         935
# 4    -7.0780435,-78.3098563   -6.9852282,-78.402941        1131
# ..                      ...                     ...         ...
# 122      -6.71341,-78.95501  -6.7465642,-78.9211618         928
# 123  -6.6928634,-78.8896186  -6.6828605,-78.9084687         932
# 124  -6.5631872,-79.0510956  -6.5855825,-79.0363532        1085
# 125   -6.6060207,-78.794564  -6.6147002,-78.7905375        1086
# 126  -6.6628825,-78.8627019  -6.6828597,-78.8494396        1091
#
# [127 rows x 26 columns]

# %%
# Generate lists 
combination = df2['combination'].tolist()
healthest_origin = df2['healthest_origin'].tolist()
Centroid_destination = df2['Centroid_destination'].tolist()
df2.head()
# Out:
#    index  NOMBDEP_x  UBIGEO Centroid_Latitude Centroid_Longitude  \
# 0    150  CAJAMARCA   60101        -7.0774651        -78.5611113
# 1   1126  CAJAMARCA   60102         -7.338237        -78.5271836
# 2    932  CAJAMARCA   60103        -7.1425041        -78.6540271
# 3    934  CAJAMARCA   60104        -7.4530319        -78.5168553
# 4   1130  CAJAMARCA   60105        -6.9852282         -78.402941
#
#    codigo_renaes categoria                   nombre     diresa  \
# 0          28477       I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1           4625       I-2                 ASUNCION  CAJAMARCA
# 2           4653       I-2                 CHETILLA  CAJAMARCA
# 3           4627       I-2                   COSPAN  CAJAMARCA
# 4           4598       I-1              LA VICTORIA  CAJAMARCA
#
#                           red  ...   NOMBPROV CCDI   NOMBDIST    CAPITAL  \
# 0  NO PERTENECE A NINGUNA RED  ...  CAJAMARCA    1  CAJAMARCA  CAJAMARCA
# 1                   CAJAMARCA  ...  CAJAMARCA    2   ASUNCION   ASUNCION
# 2                   CAJAMARCA  ...  CAJAMARCA    3   CHETILLA   CHETILLA
# 3                   CAJAMARCA  ...  CAJAMARCA    4     COSPAN     COSPAN
# 4                   CAJAMARCA  ...  CAJAMARCA    5  ENCAÑADA  ENCAÑADA
#
#    diferencia_latitud  diferencia_longitud distancia        healthest_origin  \
# 0            0.068572            -0.063406  0.005166  -7.1460372,-78.4977056
# 1           -0.012873            -0.008657  0.021530  -7.3253637,-78.5185264
# 2            0.003810             0.019724  0.023534  -7.1463139,-78.6737509
# 3           -0.026317             0.026095  0.000221   -7.426715,-78.5429507
# 4            0.092815            -0.093085  0.000269  -7.0780435,-78.3098563
#
#      Centroid_destination combination
# 0  -7.0774651,-78.5611113         151
# 1   -7.338237,-78.5271836        1127
# 2  -7.1425041,-78.6540271         933
# 3  -7.4530319,-78.5168553         935
# 4   -6.9852282,-78.402941        1131
#
# [5 rows x 26 columns]

# %%
# Generate dictionary to store data
data_distance = {} 
data_models = {}

# %%
models = ['best_guess', 'pessimistic', 'optimistic']
models
# Out:
# ['best_guess', 'pessimistic', 'optimistic']

# %%
list(zip(combination,healthest_origin, Centroid_destination))
# Out:
# [(151, '-7.1460372,-78.4977056', '-7.0774651,-78.5611113'),
#  (1127, '-7.3253637,-78.5185264', '-7.338237,-78.5271836'),
#  (933, '-7.1463139,-78.6737509', '-7.1425041,-78.6540271'),
#  (935, '-7.426715,-78.5429507', '-7.4530319,-78.5168553'),
#  (1131, '-7.0780435,-78.3098563', '-6.9852282,-78.402941'),
#  (953, '-7.3656687,-78.3257397', '-7.298308,-78.3666482'),
#  (955, '-7.1922419,-78.4256762', '-7.1895986,-78.411841'),
#  (962, '-7.11848,-78.4463', '-7.0901231,-78.4559751'),
#  (972, '-7.213976,-78.632315', '-7.2247285,-78.6223847'),
#  (976, '-7.25651,-78.26372', '-7.2720188,-78.2594778'),
#  (977, '-7.2199298,-78.253609', '-7.184364,-78.2840707'),
#  (982, '-7.2923446,-78.4950626', '-7.27391,-78.4819792'),
#  (987, '-7.6323382,-78.0304932', '-7.6314509,-78.0321422'),
#  (1144, '-7.6567491,-78.182624', '-7.5676875,-78.2533289'),
#  (1151, '-7.5274594,-78.0698072', '-7.5301224,-78.0911352'),
#  (1160, '-7.429924,-77.9379017', '-7.4743852,-77.9063149'),
#  (586, '-6.8040428,-78.1350244', '-6.7749389,-78.1172714'),
#  (267, '-6.5395425,-78.213589', '-6.5705796,-78.187058'),
#  (268, '-6.5109942,-78.257016', '-6.4876936,-78.2855167'),
#  (605, '-6.9419531,-78.2079756', '-6.8283013,-78.3256277'),
#  (993, '-6.9408037,-78.0940756', '-6.9395166,-78.0694924'),
#  (1164, '-6.9295306,-78.1308202', '-6.9198951,-78.1587725'),
#  (759, '-6.6089542,-78.3028738', '-6.6510372,-78.2653374'),
#  (6, '-6.9267286,-79.128402', '-6.9267178,-79.1314352'),
#  (10, '-7.06395,-79.12735', '-7.117978,-79.1609682'),
#  (1042, '-6.93277,-78.69851', '-6.931431,-78.7252618'),
#  (905, '-6.8075996,-78.8149004', '-6.7881613,-78.8335472'),
#  (1046, '-7.0804452,-79.0414859', '-7.1188978,-79.0541958'),
#  (1050, '-7.0841097,-78.7817804', '-7.0860139,-78.7857818'),
#  (1056, '-7.167212,-78.8287017', '-7.1749807,-78.7856496'),
#  (14, '-7.1566476,-78.8690618', '-7.1590459,-78.8730841'),
#  (1059, '-6.95964,-78.67149', '-6.987533,-78.6761978'),
#  (324, '-6.6248759,-78.944333', '-6.6275565,-78.9419147'),
#  (326, '-6.66291,-78.81947', '-6.664009,-78.8097223'),
#  (908, '-6.75689,-79.04854', '-6.7493584,-79.0769065'),
#  (914, '-6.5502578,-78.889599', '-6.5559633,-78.8779367'),
#  (921, '-6.64162,-78.83928', '-6.6209164,-78.8593797'),
#  (925, '-6.6758397,-78.7944707', '-6.6957313,-78.7686898'),
#  (928, '-6.71341,-78.95501', '-6.7465642,-78.9211618'),
#  (932, '-6.6928634,-78.8896186', '-6.6828605,-78.9084687'),
#  (1085, '-6.5631872,-79.0510956', '-6.5855825,-79.0363532'),
#  (1086, '-6.6060207,-78.794564', '-6.6147002,-78.7905375'),
#  (1091, '-6.6628825,-78.8627019', '-6.6828597,-78.8494396')]

# %%
for model in models:
    
    print(model)
    
    distance_info = pd.DataFrame(np.zeros(shape=(len(combination),4), dtype =float))
    i=0    
    for c,o,d in tqdm(list(zip(combination,healthest_origin, Centroid_destination))):        

        try:
            # Google MapsDdirections API endpoint
            endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

            ## Fixed Parameters
            # Paramaters

            traffic_model = model 

            # Departure time
            departure_time= '1643058000'

            # driving, walking, biclycling, transit
            mode = 'driving'

            # key
            api_key = 'AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg'

            # region to look for 
            region = 'pe'

             ## Parameters
            # Origin
            origin_loop = o
        
            # Destinations
            destination_loop = d
        
            #Building the URL for the request
            
            nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin_loop , 
                        destination_loop , departure_time , traffic_model , mode, region, api_key)
            
            # Concatenate strings
            request = endpoint + nav_request
            print(request)
            #Sends the request and reads the response.
            response = urllib.request.urlopen(request).read()

            #Loads response as JSON
            directions = json.loads(response)
            #print(json.dumps(directions, indent = 2))

            legs = directions['routes'][0]['legs'][0]
        
            distance_info[0][i] = c
            distance_info[1][i] = legs['distance']['text']
            distance_info[2][i] = legs['duration']['value']
            distance_info[3][i] = legs['duration_in_traffic']['value']
        
            i=i+1
            
            #my_keys = ['distance', 'duration', 'duration_in_traffic']
            #info = { my_key: legs[my_key] for my_key in my_keys }
            #data_distance[c] = info 
            
    
        except Exception as e:
        
            distance_info[0][i] = c
            distance_info[1][i] = "nan"
            distance_info[2][i] = "nan"
            distance_info[3][i] = "nan"
        
            i=i+1
    print(distance_info)    
    data_models[model] = distance_info 
    #data_models[model].append(data_distance
# Out:
# best_guess
# <ipython-input-28-096fc8bf471a>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(comb
departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-7.167212,-78.8287017&destination=-7.1749807,-78.7856496&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-7.1566476,-78.8690618&destination=-7.1590459,-78.8730841&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.95964,-78.67149&destination=-6.987533,-78.6761978&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.6248759,-78.944333&destination=-6.6275565,-78.9419147&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.66291,-78.81947&destination=-6.664009,-78.8097223&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.75689,-79.04854&destination=-6.7493584,-79.0769065&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.5502578,-78.889599&destination=-6.5559633,-78.8779367&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.64162,-78.83928&destination=-6.6209164,-78.8593797&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.6758397,-78.7944707&destination=-6.6957313,-78.7686898&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.71341,-78.95501&destination=-6.7465642,-78.9211618&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.6928634,-78.8896186&destination=-6.6828605,-78.9084687&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.5631872,-79.0510956&destination=-6.5855825,-79.0363532&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.6060207,-78.794564&destination=-6.6147002,-78.7905375&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
# https://maps.googleapis.com/maps/api/directions/json?origin=-6.6628825,-78.8627019&destination=-6.6828597,-78.8494396&departure_time=1643058000&traffic_model=optimistic&mode=driving&region=pe&key=AIzaSyDskcq6F0p1fSQ6ul_QqgPfB1Go3Mc-zBg
#           0        1       2       3
# 0     151.0  15.1 km  2440.0  2372.0
# 1    1127.0   5.5 km   886.0   886.0
# 2     933.0  10.6 km  1614.0  1613.0
# 3     935.0  14.1 km  2214.0  2213.0
# 4    1131.0  34.9 km  5147.0  5123.0
# ..      ...      ...     ...     ...
# 122   928.0   9.1 km  1497.0  1496.0
# 123   932.0   6.9 km  1023.0  1023.0
# 124  1085.0   1.5 km   189.0   188.0
# 125  1086.0   1.5 km   233.0   232.0
# 126  1091.0   6.5 km   891.0   890.0
#
# [127 rows x 4 columns]

# %%
data_models
# Out:
# {'best_guess':           0        1       2       3
#  0     151.0  15.1 km  2440.0  2606.0
#  1    1127.0   5.5 km   886.0   886.0
#  2     933.0  10.6 km  1614.0  1613.0
#  3     935.0  14.1 km  2214.0  2213.0
#  4    1131.0  34.9 km  5147.0  5140.0
#  ..      ...      ...     ...     ...
#  122   928.0   9.1 km  1497.0  1496.0
#  123   932.0   6.9 km  1023.0  1023.0
#  124  1085.0   1.5 km   189.0   188.0
#  125  1086.0   1.5 km   233.0   232.0
#  126  1091.0   6.5 km   891.0   890.0
#
#  [127 rows x 4 columns],
#  'pessimistic':           0        1       2       3
#  0     151.0  15.1 km  2440.0  2833.0
#  1    1127.0   5.5 km   886.0   886.0
#  2     933.0  10.6 km  1614.0  1613.0
#  3     935.0  14.1 km  2214.0  2213.0
#  4    1131.0  34.9 km  5147.0  5159.0
#  ..      ...      ...     ...     ...
#  122   928.0   9.1 km  1497.0  1496.0
#  123   932.0   6.9 km  1023.0  1023.0
#  124  1085.0   1.5 km   189.0   188.0
#  125  1086.0   1.5 km   233.0   232.0
#  126  1091.0   6.5 km   891.0   890.0
#
#  [127 rows x 4 columns],
#  'optimistic':           0        1       2       3
#  0     151.0  15.1 km  2440.0  2372.0
#  1    1127.0   5.5 km   886.0   886.0
#  2     933.0  10.6 km  1614.0  1613.0
#  3     935.0  14.1 km  2214.0  2213.0
#  4    1131.0  34.9 km  5147.0  5123.0
#  ..      ...      ...     ...     ...
#  122   928.0   9.1 km  1497.0  1496.0
#  123   932.0   6.9 km  1023.0  1023.0
#  124  1085.0   1.5 km   189.0   188.0
#  125  1086.0   1.5 km   233.0   232.0
#  126  1091.0   6.5 km   891.0   890.0
#
#  [127 rows x 4 columns]}

# %%
#3 TYPES OF MODELS

distance_api_best_guess = data_models['best_guess'].rename(columns={0: "combination",
                                                                    1: "travel_distance_best_guess",
                                                                    2: "travel_time_best_guess",
                                                                    3: "travel_time_traffic_best_guess"}, inplace= False)

distance_api_pessimistic = data_models['pessimistic'].rename(columns={0: "combination",
                                                                      1: "travel_distance_pessimistic",
                                                                      2: "travel_time_pessimistic",
                                                                      3: "travel_time_traffic_pessimistic"}, inplace= False)

distance_api_optimistic = data_models['optimistic'].rename(columns={0: "combination",
                                                                    1: "travel_distance_optimistic",
                                                                    2: "travel_time_optimistic",
                                                                    3: "travel_time_traffic_optimistic"}, inplace= False)
data_models[model]
# Out:
#           0        1       2       3
# 0     151.0  15.1 km  2440.0  2372.0
# 1    1127.0   5.5 km   886.0   886.0
# 2     933.0  10.6 km  1614.0  1613.0
# 3     935.0  14.1 km  2214.0  2213.0
# 4    1131.0  34.9 km  5147.0  5123.0
# ..      ...      ...     ...     ...
# 122   928.0   9.1 km  1497.0  1496.0
# 123   932.0   6.9 km  1023.0  1023.0
# 124  1085.0   1.5 km   189.0   188.0
# 125  1086.0   1.5 km   233.0   232.0
# 126  1091.0   6.5 km   891.0   890.0
#
# [127 rows x 4 columns]

# %%
distance_api_best_guess
# Out:
#      combination travel_distance_best_guess  travel_time_best_guess  \
# 0          151.0                    15.1 km                  2440.0
# 1         1127.0                     5.5 km                   886.0
# 2          933.0                    10.6 km                  1614.0
# 3          935.0                    14.1 km                  2214.0
# 4         1131.0                    34.9 km                  5147.0
# ..           ...                        ...                     ...
# 122        928.0                     9.1 km                  1497.0
# 123        932.0                     6.9 km                  1023.0
# 124       1085.0                     1.5 km                   189.0
# 125       1086.0                     1.5 km                   233.0
# 126       1091.0                     6.5 km                   891.0
#
#      travel_time_traffic_best_guess
# 0                            2606.0
# 1                             886.0
# 2                            1613.0
# 3                            2213.0
# 4                            5140.0
# ..                              ...
# 122                          1496.0
# 123                          1023.0
# 124                           188.0
# 125                           232.0
# 126                           890.0
#
# [127 rows x 4 columns]

# %%
distance_api_pessimistic
# Out:
#      combination travel_distance_pessimistic  travel_time_pessimistic  \
# 0          151.0                     15.1 km                   2440.0
# 1         1127.0                      5.5 km                    886.0
# 2          933.0                     10.6 km                   1614.0
# 3          935.0                     14.1 km                   2214.0
# 4         1131.0                     34.9 km                   5147.0
# ..           ...                         ...                      ...
# 122        928.0                      9.1 km                   1497.0
# 123        932.0                      6.9 km                   1023.0
# 124       1085.0                      1.5 km                    189.0
# 125       1086.0                      1.5 km                    233.0
# 126       1091.0                      6.5 km                    891.0
#
#      travel_time_traffic_pessimistic
# 0                             2833.0
# 1                              886.0
# 2                             1613.0
# 3                             2213.0
# 4                             5159.0
# ..                               ...
# 122                           1496.0
# 123                           1023.0
# 124                            188.0
# 125                            232.0
# 126                            890.0
#
# [127 rows x 4 columns]

# %%
distance_api_optimistic
# Out:
#      combination travel_distance_optimistic  travel_time_optimistic  \
# 0          151.0                    15.1 km                  2440.0
# 1         1127.0                     5.5 km                   886.0
# 2          933.0                    10.6 km                  1614.0
# 3          935.0                    14.1 km                  2214.0
# 4         1131.0                    34.9 km                  5147.0
# ..           ...                        ...                     ...
# 122        928.0                     9.1 km                  1497.0
# 123        932.0                     6.9 km                  1023.0
# 124       1085.0                     1.5 km                   189.0
# 125       1086.0                     1.5 km                   233.0
# 126       1091.0                     6.5 km                   891.0
#
#      travel_time_traffic_optimistic
# 0                            2372.0
# 1                             886.0
# 2                            1613.0
# 3                            2213.0
# 4                            5123.0
# ..                              ...
# 122                          1496.0
# 123                          1023.0
# 124                           188.0
# 125                           232.0
# 126                           890.0
#
# [127 rows x 4 columns]

# %%
df_final = df2.merge( distance_api_best_guess , on = [ 'combination'] ,how = "left" , validate = "1:1" ) \
                   .merge( distance_api_pessimistic , on = [ 'combination'] , how = "left" , validate = "1:1" ) \
                   .merge( distance_api_optimistic , on = [ 'combination'] , how = "left" , validate = "1:1" )
df_final
# Out:
#      index  NOMBDEP_x  UBIGEO Centroid_Latitude Centroid_Longitude  \
# 0      150  CAJAMARCA   60101        -7.0774651        -78.5611113
# 1     1126  CAJAMARCA   60102         -7.338237        -78.5271836
# 2      932  CAJAMARCA   60103        -7.1425041        -78.6540271
# 3      934  CAJAMARCA   60104        -7.4530319        -78.5168553
# 4     1130  CAJAMARCA   60105        -6.9852282         -78.402941
# ..     ...        ...     ...               ...                ...
# 122    927  CAJAMARCA   61307        -6.7465642        -78.9211618
# 123    931  CAJAMARCA   61308        -6.6828605        -78.9084687
# 124   1084  CAJAMARCA   61309        -6.5855825        -79.0363532
# 125   1085  CAJAMARCA   61310        -6.6147002        -78.7905375
# 126   1090  CAJAMARCA   61311        -6.6828597        -78.8494396
#
#      codigo_renaes categoria                   nombre     diresa  \
# 0            28477       I-3  CENTRO MEDICO INFAMEDIC  CAJAMARCA
# 1             4625       I-2                 ASUNCION  CAJAMARCA
# 2             4653       I-2                 CHETILLA  CAJAMARCA
# 3             4627       I-2                   COSPAN  CAJAMARCA
# 4             4598       I-1              LA VICTORIA  CAJAMARCA
# ..             ...       ...                      ...        ...
# 122           4832       I-1              SUCCHAPAMPA  CAJAMARCA
# 123           6795       I-1             ROMERO CIRCA  CAJAMARCA
# 124           4710       I-1                     SEXI  CAJAMARCA
# 125           4834       I-2                 UTICYACU  CAJAMARCA
# 126           4837       I-1            YANAYACU ALTO  CAJAMARCA
#
#                             red  ... combination travel_distance_best_guess  \
# 0    NO PERTENECE A NINGUNA RED  ...         151                    15.1 km
# 1                     CAJAMARCA  ...        1127                     5.5 km
# 2                     CAJAMARCA  ...         933                    10.6 km
# 3                     CAJAMARCA  ...         935                    14.1 km
# 4                     CAJAMARCA  ...        1131                    34.9 km
# ..                          ...  ...         ...                        ...
# 122                  SANTA CRUZ  ...         928                     9.1 km
# 123                  SANTA CRUZ  ...         932                     6.9 km
# 124                  SANTA CRUZ  ...        1085                     1.5 km
# 125                  SANTA CRUZ  ...        1086                     1.5 km
# 126                  SANTA CRUZ  ...        1091                     6.5 km
#
#     travel_time_best_guess  travel_time_traffic_best_guess  \
# 0                   2440.0                          2606.0
# 1                    886.0                           886.0
# 2                   1614.0                          1613.0
# 3                   2214.0                          2213.0
# 4                   5147.0                          5140.0
# ..                     ...                             ...
# 122                 1497.0                          1496.0
# 123                 1023.0                          1023.0
# 124                  189.0                           188.0
# 125                  233.0                           232.0
# 126                  891.0                           890.0
#
#      travel_distance_pessimistic  travel_time_pessimistic  \
# 0                        15.1 km                   2440.0
# 1                         5.5 km                    886.0
# 2                        10.6 km                   1614.0
# 3                        14.1 km                   2214.0
# 4                        34.9 km                   5147.0
# ..                           ...                      ...
# 122                       9.1 km                   1497.0
# 123                       6.9 km                   1023.0
# 124                       1.5 km                    189.0
# 125                       1.5 km                    233.0
# 126                       6.5 km                    891.0
#
#     travel_time_traffic_pessimistic  travel_distance_optimistic  \
# 0                            2833.0                     15.1 km
# 1                             886.0                      5.5 km
# 2                            1613.0                     10.6 km
# 3                            2213.0                     14.1 km
# 4                            5159.0                     34.9 km
# ..                              ...                         ...
# 122                          1496.0                      9.1 km
# 123                          1023.0                      6.9 km
# 124                           188.0                      1.5 km
# 125                           232.0                      1.5 km
# 126                           890.0                      6.5 km
#
#     travel_time_optimistic travel_time_traffic_optimistic
# 0                   2440.0                         2372.0
# 1                    886.0                          886.0
# 2                   1614.0                         1613.0
# 3                   2214.0                         2213.0
# 4                   5147.0                         5123.0
# ..                     ...                            ...
# 122                 1497.0                         1496.0
# 123                 1023.0                         1023.0
# 124                  189.0                          188.0
# 125                  233.0                          232.0
# 126                  891.0                          890.0
#
# [127 rows x 35 columns]

# %% [markdown]
# ### 6. Make a histogram of travel time colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.

# %%
df_plot6=df_final[['combination','direccion','NOMBPROV','travel_time_best_guess','travel_time_pessimistic','travel_time_optimistic']].copy()

df_plot6_1=pd.melt(df_plot6,id_vars=['combination','direccion','NOMBPROV'],var_name='traffic_model', value_name='travel_time')

# %%
type(df_plot6_1['travel_time'].values)
# Out:
# numpy.ndarray

# %%
df_plot6_1
# Out:
#      combination                                          direccion  \
# 0            151  AVENIDA HOYOS RUBIO NÚMERO 2042 DISTRITO CAJAM...
# 1           1127  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS...
# 2            933  JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...
# 3            935  JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...
# 4           1131  OTROS COMUNIDAD DE LA VICTORIA DISTRITO ENCAÑA...
# ..           ...                                                ...
# 376          928  OTROS COMUNIDAD SUCCHAPAMPA DISTRITO PULAN PRO...
# 377          932  OTROS COMUNIDAD ROMERO CIRA DISTRITO SAUCEPAMP...
# 378         1085  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT...
# 379         1086  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV...
# 380         1091  OTROS COMUNIDAD YANAYACU COMUNIDAD YANAYACU YA...
#
#        NOMBPROV           traffic_model  travel_time
# 0     CAJAMARCA  travel_time_best_guess       2440.0
# 1     CAJAMARCA  travel_time_best_guess        886.0
# 2     CAJAMARCA  travel_time_best_guess       1614.0
# 3     CAJAMARCA  travel_time_best_guess       2214.0
# 4     CAJAMARCA  travel_time_best_guess       5147.0
# ..          ...                     ...          ...
# 376  SANTA CRUZ  travel_time_optimistic       1497.0
# 377  SANTA CRUZ  travel_time_optimistic       1023.0
# 378  SANTA CRUZ  travel_time_optimistic        189.0
# 379  SANTA CRUZ  travel_time_optimistic        233.0
# 380  SANTA CRUZ  travel_time_optimistic        891.0
#
# [381 rows x 5 columns]

# %%
# traffic_model = best_guess
#df_plot6_2 = df_plot6_1.loc[df_plot6_1["traffic_model"] == "travel_time_best_guess"]

#figure1 = sns.FacetGrid(df_plot6_2, col="NOMBPROV", margin_titles=True,row='column')
#figure1.map(plt.hist, 'travel_time', bins=np.linspace(0, 20, 30))


g = sns.FacetGrid(df_plot6_1, col='NOMBPROV', hue="traffic_model",col_wrap = 3,height=4)#,hue = 'traffic_model')

#plt.figure(figsize=(20,10)) # Make it 14x7 inch
#plt.style.use('seaborn-whitegrid')
g.map(plt.hist, 'travel_time')
g.add_legend()

# %% [markdown]
# ### 7. Make a histogram of travel distance colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.

# %%
df_plot7= df_final[['combination','direccion','NOMBPROV','travel_distance_best_guess','travel_distance_pessimistic','travel_distance_optimistic']].copy()

df_plot7_1= pd.melt(df_plot7,id_vars=['combination','direccion','NOMBPROV'],var_name='traffic_model', value_name='travel_distance')

# %%
df_plot7_1
# Out:
#      combination                                          direccion  \
# 0            151  AVENIDA HOYOS RUBIO NÚMERO 2042 DISTRITO CAJAM...
# 1           1127  JIRÓN JR. EL INCA N° 358 JR. EL INCA N° 358 AS...
# 2            933  JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...
# 3            935  JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...
# 4           1131  OTROS COMUNIDAD DE LA VICTORIA DISTRITO ENCAÑA...
# ..           ...                                                ...
# 376          928  OTROS COMUNIDAD SUCCHAPAMPA DISTRITO PULAN PRO...
# 377          932  OTROS COMUNIDAD ROMERO CIRA DISTRITO SAUCEPAMP...
# 378         1085  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT...
# 379         1086  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV...
# 380         1091  OTROS COMUNIDAD YANAYACU COMUNIDAD YANAYACU YA...
#
#        NOMBPROV               traffic_model travel_distance
# 0     CAJAMARCA  travel_distance_best_guess         15.1 km
# 1     CAJAMARCA  travel_distance_best_guess          5.5 km
# 2     CAJAMARCA  travel_distance_best_guess         10.6 km
# 3     CAJAMARCA  travel_distance_best_guess         14.1 km
# 4     CAJAMARCA  travel_distance_best_guess         34.9 km
# ..          ...                         ...             ...
# 376  SANTA CRUZ  travel_distance_optimistic          9.1 km
# 377  SANTA CRUZ  travel_distance_optimistic          6.9 km
# 378  SANTA CRUZ  travel_distance_optimistic          1.5 km
# 379  SANTA CRUZ  travel_distance_optimistic          1.5 km
# 380  SANTA CRUZ  travel_distance_optimistic          6.5 km
#
# [381 rows x 5 columns]

# %%
hist_dist = sns.FacetGrid(df_plot7_1, col='NOMBPROV', hue= "traffic_model", col_wrap = 3,height=4)
hist_dist.map(plt.hist, 'travel_distance', bins=np.linspace(0, 40))

# %% [markdown]
# ### 9. Bar plot of the mean travel time by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province

# %%
df_plot9=df_plot6_1.copy()
df_plot9['mean_travel_time']=df_plot9.groupby(['NOMBPROV','traffic_model'])['travel_time'].transform('mean')
df_plot9=df_plot9.drop_duplicates(['NOMBPROV','mean_travel_time','traffic_model'])[['NOMBPROV','mean_travel_time','traffic_model']]

df_plot9
# Out:
#         NOMBPROV  mean_travel_time            traffic_model
# 0      CAJAMARCA       1847.750000   travel_time_best_guess
# 12     CAJABAMBA       2484.750000   travel_time_best_guess
# 16      CELENDIN       1909.454545   travel_time_best_guess
# 28         CHOTA       1855.944444   travel_time_best_guess
# 47     CONTUMAZA       1660.142857   travel_time_best_guess
# 55       CUTERVO       1017.727273   travel_time_best_guess
# 70     HUALGAYOC       2172.000000   travel_time_best_guess
# 73          JAEN       2921.833333   travel_time_best_guess
# 85   SAN IGNACIO       3902.500000   travel_time_best_guess
# 92    SAN MARCOS        838.000000   travel_time_best_guess
# 99    SAN MIGUEL        746.000000   travel_time_best_guess
# 112    SAN PABLO        690.750000   travel_time_best_guess
# 116   SANTA CRUZ       1191.400000   travel_time_best_guess
# 127    CAJAMARCA       1847.750000  travel_time_pessimistic
# 139    CAJABAMBA       2484.750000  travel_time_pessimistic
# 143     CELENDIN       1909.454545  travel_time_pessimistic
# 155        CHOTA       1803.368421  travel_time_pessimistic
# 174    CONTUMAZA       1683.333333  travel_time_pessimistic
# 182      CUTERVO       1017.727273  travel_time_pessimistic
# 197    HUALGAYOC       1852.333333  travel_time_pessimistic
# 200         JAEN       2921.833333  travel_time_pessimistic
# 212  SAN IGNACIO       3902.500000  travel_time_pessimistic
# 219   SAN MARCOS        838.000000  travel_time_pessimistic
# 226   SAN MIGUEL        746.000000  travel_time_pessimistic
# 239    SAN PABLO        690.750000  travel_time_pessimistic
# 243   SANTA CRUZ       1191.400000  travel_time_pessimistic
# 254    CAJAMARCA       1847.750000   travel_time_optimistic
# 266    CAJABAMBA       2484.750000   travel_time_optimistic
# 270     CELENDIN       1909.454545   travel_time_optimistic
# 282        CHOTA       1803.368421   travel_time_optimistic
# 301    CONTUMAZA       1660.142857   travel_time_optimistic
# 309      CUTERVO       1017.727273   travel_time_optimistic
# 324    HUALGAYOC       1852.333333   travel_time_optimistic
# 327         JAEN       2921.833333   travel_time_optimistic
# 339  SAN IGNACIO       3902.500000   travel_time_optimistic
# 346   SAN MARCOS        838.000000   travel_time_optimistic
# 353   SAN MIGUEL        746.000000   travel_time_optimistic
# 366    SAN PABLO        690.750000   travel_time_optimistic
# 370   SANTA CRUZ       1191.400000   travel_time_optimistic

# %% [markdown]
# ### 11. Make a count plot of the number of health establishments by Department colored by hue = categoria. The x-axis should be the Department Name. Use this data.

# %%
data_healthes_0 = open('..\..\_data\salud_places_peru.csv', 'rb').read()
result = chardet.detect(data_healthes_0)
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
data_healthes = pd.read_csv('..\..\_data\salud_places_peru.csv', delimiter = ','  )
data_healthes
# Out:
#        id_eess  codigo_renaes categoria  \
# 0         5845              1      II-2
# 1        15599              2        SD
# 2        18282              3     III-1
# 3        18156              4       I-3
# 4          858              5       I-1
# ...        ...            ...       ...
# 28837    20228        9999164       I-3
# 28838     4292        9999165       I-3
# 28839     5423        9999166       I-3
# 28840    28694        9999167       I-3
# 28841    21087        9999168       I-3
#
#                                                   nombre  diresa  \
# 0                HOSPITAL IQUITOS "CESAR GARAYAR GARCIA"  LORETO
# 1                   CENTRO REHABILITACION ENFERMO MENTAL  LORETO
# 2      HOSPITAL REGIONAL DE LORETO "FELIPE SANTIAGO A...  LORETO
# 3                          C.S. I-3 SANTA MARIA DE NANAY  LORETO
# 4                                                 SAMITO  LORETO
# ...                                                  ...     ...
# 28837  CENTRO DE SALUD MENTAL COMUNITARIO "SAN ISIDRO...    PUNO
# 28838  CENTRO DE  SALUD MENTAL COMUNITARIO "LA CAPILL...    PUNO
# 28839  CENTRO DE SALUD MENTAL COMUNITARIO "SAN MIGUEL...    PUNO
# 28840        CENTRO DE SALUD MENTAL COMUNITARIO "CALLAO"  CALLAO
# 28841  CENTRO DE SALUD MENTAL COMUNITARIO "VILLA LOS ...  CALLAO
#
#                               red  \
# 0      NO PERTENECE A NINGUNA RED
# 1      NO PERTENECE A NINGUNA RED
# 2      NO PERTENECE A NINGUNA RED
# 3                   MAYNAS CIUDAD
# 4                   MAYNAS CIUDAD
# ...                           ...
# 28837  NO PERTENECE A NINGUNA RED
# 28838  NO PERTENECE A NINGUNA RED
# 28839  NO PERTENECE A NINGUNA RED
# 28840  NO PERTENECE A NINGUNA RED
# 28841  NO PERTENECE A NINGUNA RED
#
#                                                direccion   longitud   latitud  \
# 0      CALLE CORNEJO PORTUGAL 1710 IQUITOS MAYNAS LORETO -73.253653 -3.762818
# 1                    CALLE 3 DE MAYO S/N CPM QUILCATACTA -73.323250 -3.731890
# 2      AVENIDA AVENIDA 28 DE JULIO S/N S/N AVENIDA 28... -73.253417 -3.726960
# 3      OTROS CASERIO DE SANTA MARIA DE NANAY CASERIO ... -73.696785 -3.888998
# 4      OTROS CASERIO DE SAMITO SIN NUMERO DISTRITO AL... -73.610928 -3.865167
# ...                                                  ...        ...       ...
# 28837                                                NaN   0.000000  0.000000
# 28838                                                NaN   0.000000  0.000000
# 28839                                                NaN   0.000000  0.000000
# 28840                                                NaN   0.000000  0.000000
# 28841                                                NaN   0.000000  0.000000
#
#        id_ubigeo
# 0           1453
# 1           1463
# 2           1460
# 3           1454
# 4           1454
# ...          ...
# 28837       1719
# 28838       1719
# 28839       1719
# 28840        690
# 28841        695
#
# [28842 rows x 10 columns]

# %%
sns.set( style="darkgrid" )

#figure size
fig, ax = plt.subplots( figsize=(7,4) )
x = sns.countplot( x="diresa", data=data_healthes)
plt.title('Número de eess según departamento')
plt.xlabel(' ')
plt.ylabel(' ')
# Out:
# Text(0, 0.5, ' ')
