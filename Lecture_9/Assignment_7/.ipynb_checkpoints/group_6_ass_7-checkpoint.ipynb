# %%
import googlemaps
import json
import pprint
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode

# %%
API_KEY = 'AIzaSyBoWesySwwcVSOhJh1E9KSaJaSeMAl4uWM'

# %%
data_cajamarca = pd.ExcelFile(r'../../_data/cajamarca_data_helth_estb.xlsx').parse()

# %%
districts_centroids = pd.ExcelFile(r'../../_data/peru_districts_centroids.xlsx').parse()

# %%
data_cajamarca.head()
# Out:
#    id_eess  codigo_renaes categoria        nombre     diresa  \
# 0     9439           4210      II-1    GRAL. JAEN  CAJAMARCA
# 1    27242           4211       I-4   MORRO SOLAR  CAJAMARCA
# 2    22911           4212       I-3     MAGLLANAL  CAJAMARCA
# 3     9242           4213       I-3     FILA ALTA  CAJAMARCA
# 4    26418           4214       I-1  LAS NARANJAS  CAJAMARCA
#
#                           red  \
# 0  NO PERTENECE A NINGUNA RED
# 1                        JAEN
# 2                        JAEN
# 3                        JAEN
# 4                        JAEN
#
#                                            direccion   longitud   latitud  \
# 0  AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1  OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2  CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3  OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4  OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
#
#    id_ubigeo  ...  CCPP  NOMBPROV CCDI  NOMBDIST CAPITAL  UBIGEO IDPROV  \
# 0        636  ...     8      JAEN    1      JAEN    JAEN   60801    608
# 1        636  ...     8      JAEN    1      JAEN    JAEN   60801    608
# 2        636  ...     8      JAEN    1      JAEN    JAEN   60801    608
# 3        636  ...     8      JAEN    1      JAEN    JAEN   60801    608
# 4        636  ...     8      JAEN    1      JAEN    JAEN   60801    608
#
#   CODIGO  CNT_CCPP  DESCRIPCIO
# 0  60801       108        JAEN
# 1  60801       108        JAEN
# 2  60801       108        JAEN
# 3  60801       108        JAEN
# 4  60801       108        JAEN
#
# [5 rows x 23 columns]

# %%
len(data_cajamarca)
# Out:
# 129

# %%
data_cajamarca.NOMBPROV.unique()
# Out:
# array(['JAEN', 'SAN IGNACIO', 'CELENDIN', 'CHOTA', 'SAN MARCOS',
#        'CAJAMARCA', 'CAJABAMBA', 'SAN MIGUEL', 'CONTUMAZA', 'SAN PABLO',
#        'GRAN CHIMU', 'SANTA CRUZ', 'HUALGAYOC', 'CUTERVO', 'BAGUA'],
#       dtype=object)

# %%
data_cajamarca.diresa.unique()
# Out:
# array(['CAJAMARCA'], dtype=object)

# %%
data_cajamarca.UBIGEO.unique()
# Out:
# array([ 60801,  60802,  60803,  60804,  60805,  60811,  60806,  60807,
#         60808,  60809,  60810,  60812,  60901,  60905,  60902,  60903,
#         60904,  60906,  60907,  60301,  60311,  60309,  60304,  60303,
#         60413,  60307,  60302,  60312,  60310,  60308,  60306,  60305,
#         61005,  61002,  61003,  61006,  61007,  61001,  61004,  60110,
#         60201,  60202,  60203,  60204,  61108,  61102,  61110,  60502,
#         61202,  61105,  61101,  61113,  60507,  60501,  60506,  60505,
#        131101,  60504,  61106,  61109,  61107,  61111,  61103,  61201,
#         61204,  61203,  60508,  60503,  60108,  60105,  60111,  60107,
#         61104,  61112,  60101,  60102,  60104,  60109,  60112,  60106,
#         60103,  60401,  60410,  60414,  60407,  60405,  60409,  61309,
#         60415,  60419,  60701,  60403,  60406,  60417,  60402,  60404,
#         60408,  60411,  60412,  61303,  60416,  60418,  60703,  60702,
#         61301,  61302,  61306,  61304,  61305,  61307,  61308,  61310,
#         61311,  60602,  60607,  60603,  60604,  60613,  60611,  60601,
#         60612,  60606,  60615,  60608,  60605,  60609,  60614,  60610,
#         10205], dtype=int64)

# %%
districts_centroids.head()
# Out:
#    CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0     6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1     6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2     6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3     6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4     6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
#
#    UBIGEO  IDPROV  CODIGO  Centroid_Latitude  Centroid_Longitude
# 0   60504     605   60504          -7.364304          -78.917689
# 1   61105     611   61105          -7.038039          -79.003318
# 2   61109     611   61109          -6.926718          -79.131435
# 3   61110     611   61110          -7.117978          -79.160968
# 4   61203     612   61203          -7.159046          -78.873084

# %%
districts_centroids.UBIGEO.unique().tolist()
# Out:
# [60504,
#  61105,
#  61109,
#  61110,
#  61203,
#  140103,
#  140106,
#  140107,
#  140108,
#  140114,
#  140115,
#  140116,
#  150201,
#  150806,
#  150902,
#  150903,
#  150904,
#  150905,
#  150202,
#  150204,
#  150205,
#  20301,
#  21206,
#  20502,
#  20503,
#  20505,
#  20506,
#  20507,
#  20511,
#  20512,
#  20513,
#  20514,
#  20515,
#  20105,
#  20305,
#  21809,
#  20901,
#  20902,
#  40608,
#  40408,
#  40409,
#  40410,
#  40412,
#  40413,
#  40506,
#  40507,
#  40508,
#  40509,
#  40510,
#  40511,
#  40512,
#  40513,
#  40705,
#  40706,
#  40801,
#  40802,
#  40803,
#  40804,
#  40805,
#  40806,
#  40807,
#  40810,
#  40811,
#  40504,
#  40115,
#  40119,
#  40120,
#  40121,
#  40122,
#  40123,
#  40124,
#  40125,
#  40127,
#  40128,
#  40201,
#  40202,
#  40203,
#  40204,
#  40205,
#  40206,
#  40207,
#  40208,
#  40103,
#  40104,
#  40111,
#  40113,
#  40116,
#  40118,
#  40302,
#  40305,
#  80108,
#  40101,
#  40102,
#  40129,
#  40110,
#  40112,
#  40117,
#  40107,
#  40109,
#  40126,
#  40704,
#  50510,
#  50410,
#  80911,
#  50411,
#  80912,
#  90720,
#  30108,
#  30601,
#  30104,
#  30605,
#  30105,
#  30216,
#  30208,
#  30602,
#  200301,
#  200402,
#  200305,
#  200405,
#  200410,
#  200404,
#  200105,
#  200101,
#  200206,
#  200403,
#  200401,
#  200104,
#  200501,
#  200202,
#  200504,
#  200506,
#  200208,
#  200603,
#  200204,
#  200607,
#  200207,
#  200205,
#  200111,
#  200201,
#  200703,
#  200203,
#  200209,
#  200604,
#  200210,
#  200701,
#  200704,
#  200705,
#  200706,
#  200602,
#  200702,
#  200115,
#  230111,
#  30610,
#  80913,
#  50412,
#  90721,
#  120609,
#  30609,
#  90722,
#  100113,
#  100607,
#  100704,
#  100705,
#  100608,
#  60605,
#  80902,
#  250202,
#  170301,
#  50505,
#  30611,
#  90723,
#  100609,
#  100610,
#  100603,
#  211105,
#  40514,
#  40701,
#  40702,
#  40502,
#  40105,
#  40106,
#  40108,
#  210502,
#  210405,
#  210404,
#  210504,
#  210403,
#  210402,
#  210505,
#  210407,
#  211303,
#  211302,
#  211307,
#  210401,
#  211305,
#  210106,
#  210703,
#  210701,
#  210202,
#  210903,
#  210607,
#  210210,
#  210205,
#  210808,
#  210101,
#  210114,
#  210109,
#  210110,
#  210115,
#  210104,
#  210709,
#  210103,
#  211102,
#  211103,
#  210108,
#  210107,
#  210105,
#  210904,
#  210702,
#  211101,
#  210902,
#  210707,
#  210605,
#  210901,
#  210606,
#  210601,
#  210704,
#  210706,
#  210608,
#  210710,
#  210203,
#  210206,
#  210214,
#  210708,
#  210705,
#  211003,
#  210213,
#  210602,
#  210804,
#  210215,
#  211004,
#  210809,
#  210803,
#  211001,
#  210801,
#  210201,
#  210204,
#  210805,
#  210208,
#  210807,
#  211002,
#  210211,
#  210212,
#  211202,
#  210209,
#  211204,
#  210806,
#  211005,
#  211201,
#  210802,
#  211206,
#  210306,
#  211208,
#  211207,
#  211205,
#  210302,
#  210301,
#  211209,
#  210310,
#  210305,
#  210307,
#  210308,
#  40515,
#  40516,
#  40517,
#  21508,
#  21509,
#  21510,
#  21511,
#  21601,
#  21602,
#  21603,
#  100510,
#  100601,
#  100311,
#  100501,
#  100503,
#  100504,
#  100505,
#  100602,
#  100502,
#  100605,
#  100701,
#  100703,
#  100207,
#  100201,
#  100202,
#  100904,
#  120704,
#  120608,
#  120301,
#  120302,
#  120303,
#  120304,
#  120502,
#  150807,
#  151001,
#  151002,
#  20306,
#  20401,
#  20402,
#  20701,
#  20801,
#  20802,
#  21409,
#  21410,
#  21702,
#  21703,
#  21704,
#  21705,
#  21706,
#  21707,
#  21708,
#  21709,
#  22001,
#  22002,
#  22003,
#  22004,
#  22005,
#  22006,
#  22007,
#  22008,
#  20103,
#  21202,
#  21203,
#  21204,
#  21205,
#  20702,
#  20703,
#  21208,
#  21209,
#  21210,
#  21301,
#  21302,
#  21303,
#  21304,
#  21305,
#  21306,
#  21307,
#  21308,
#  21501,
#  21502,
#  20803,
#  20608,
#  20609,
#  20610,
#  20611,
#  21001,
#  21002,
#  21003,
#  21004,
#  21005,
#  21006,
#  21007,
#  21401,
#  21402,
#  21403,
#  21404,
#  21406,
#  21407,
#  21408,
#  21503,
#  21504,
#  21505,
#  21506,
#  21507,
#  21604,
#  21801,
#  21802,
#  21804,
#  21808,
#  21901,
#  21902,
#  21903,
#  21904,
#  21905,
#  21906,
#  21907,
#  21908,
#  21909,
#  21910,
#  150304,
#  150305,
#  150802,
#  150804,
#  150808,
#  150809,
#  150811,
#  150812,
#  150901,
#  150906,
#  150203,
#  150301,
#  150302,
#  150303,
#  130102,
#  60101,
#  140104,
#  60608,
#  60609,
#  60610,
#  60612,
#  60613,
#  60614,
#  60302,
#  60303,
#  60402,
#  60404,
#  60405,
#  60407,
#  60410,
#  60414,
#  60418,
#  61104,
#  61301,
#  61302,
#  60901,
#  60902,
#  60903,
#  60904,
#  60905,
#  60906,
#  60802,
#  60811,
#  60803,
#  60809,
#  60801,
#  60807,
#  60804,
#  60805,
#  60603,
#  60615,
#  240101,
#  240102,
#  240103,
#  240104,
#  240105,
#  240106,
#  240201,
#  240202,
#  240203,
#  240301,
#  240302,
#  240303,
#  240304,
#  60301,
#  60304,
#  60601,
#  60607,
#  60611,
#  60701,
#  60703,
#  60307,
#  60312,
#  60401,
#  60403,
#  60406,
#  60408,
#  60409,
#  60411,
#  60412,
#  60413,
#  60415,
#  60416,
#  60417,
#  60419,
#  61112,
#  61303,
#  61304,
#  61305,
#  61306,
#  61307,
#  61308,
#  150118,
#  150113,
#  150101,
#  150116,
#  150122,
#  150120,
#  150121,
#  150130,
#  150134,
#  150136,
#  150137,
#  150141,
#  150105,
#  150128,
#  150112,
#  150132,
#  150139,
#  150131,
#  150115,
#  150104,
#  50116,
#  120805,
#  70107,
#  10106,
#  100101,
#  100102,
#  100110,
#  100111,
#  100104,
#  100106,
#  100108,
#  100112,
#  100307,
#  100313,
#  100317,
#  100321,
#  100801,
#  101102,
#  101103,
#  101104,
#  101105,
#  101107,
#  101108,
#  101004,
#  101006,
#  101007,
#  100103,
#  100323,
#  100105,
#  100802,
#  100109,
#  100316,
#  100203,
#  100204,
#  100205,
#  100206,
#  100208,
#  100301,
#  100322,
#  100803,
#  100804,
#  101101,
#  101106,
#  101001,
#  101002,
#  101003,
#  101005,
#  100506,
#  100507,
#  100508,
#  100509,
#  100901,
#  100902,
#  100511,
#  100606,
#  100401,
#  100402,
#  100403,
#  100404,
#  100604,
#  100702,
#  100903,
#  120504,
#  100905,
#  160601,
#  160602,
#  160603,
#  160604,
#  220703,
#  220202,
#  30502,
#  30607,
#  30209,
#  30215,
#  30603,
#  30109,
#  30101,
#  80702,
#  80703,
#  81003,
#  81005,
#  81006,
#  80704,
#  80705,
#  80706,
#  80707,
#  80503,
#  80504,
#  80505,
#  80508,
#  80602,
#  81201,
#  81202,
#  80201,
#  80202,
#  80204,
#  80205,
#  80206,
#  80207,
#  80203,
#  80701,
#  50609,
#  50803,
#  50810,
#  50801,
#  50809,
#  50807,
#  50706,
#  50806,
#  50705,
#  50804,
#  50802,
#  50702,
#  50808,
#  50805,
#  50619,
#  50701,
#  50707,
#  50605,
#  50303,
#  50909,
#  150607,
#  150608,
#  150609,
#  150610,
#  150612,
#  151003,
#  151004,
#  151005,
#  151007,
#  151010,
#  151013,
#  151014,
#  151016,
#  151017,
#  151018,
#  151020,
#  151021,
#  151022,
#  151024,
#  151025,
#  151026,
#  151027,
#  151028,
#  151029,
#  151030,
#  151033,
#  70106,
#  80105,
#  70104,
#  70103,
#  70101,
#  70102,
#  70105,
#  110210,
#  110201,
#  110207,
#  120114,
#  120125,
#  120908,
#  150102,
#  150103,
#  150107,
#  150125,
#  150133,
#  150140,
#  150142,
#  150143,
#  150135,
#  150110,
#  150111,
#  150114,
#  150117,
#  20903,
#  20904,
#  20905,
#  20906,
#  20907,
#  21405,
#  60103,
#  60104,
#  60503,
#  60505,
#  20205,
#  21008,
#  21009,
#  21010,
#  21011,
#  21012,
#  21013,
#  21014,
#  21015,
#  21016,
#  21101,
#  21102,
#  21103,
#  21104,
#  21105,
#  21201,
#  21207,
#  20204,
#  20302,
#  20303,
#  20304,
#  20504,
#  20508,
#  20509,
#  20601,
#  20602,
#  20603,
#  20604,
#  20605,
#  20606,
#  20607,
#  20101,
#  20102,
#  20104,
#  20106,
#  20107,
#  20108,
#  20109,
#  20110,
#  20111,
#  20112,
#  20201,
#  20202,
#  20203,
#  120901,
#  120904,
#  120413,
#  120210,
#  120215,
#  120423,
#  120127,
#  120403,
#  120420,
#  120207,
#  120421,
#  120409,
#  120428,
#  120407,
#  120408,
#  120425,
#  120404,
#  120434,
#  120414,
#  120410,
#  120135,
#  120405,
#  120424,
#  120411,
#  120417,
#  120412,
#  120415,
#  120406,
#  120802,
#  120422,
#  120205,
#  120433,
#  120432,
#  120803,
#  120810,
#  120209,
#  120808,
#  120427,
#  120801,
#  120703,
#  120701,
#  120603,
#  120605,
#  120709,
#  120806,
#  120705,
#  120702,
#  120419,
#  120606,
#  120706,
#  120602,
#  120804,
#  120601,
#  120707,
#  120607,
#  120306,
#  120708,
#  120305,
#  120807,
#  120501,
#  120503,
#  120430,
#  120429,
#  150507,
#  150509,
#  150512,
#  150515,
#  150601,
#  150605,
#  150611,
#  150701,
#  150702,
#  150703,
#  150704,
#  150705,
#  150706,
#  150707,
#  150708,
#  150709,
#  150106,
#  150109,
#  150119,
#  150123,
#  150124,
#  150126,
#  150127,
#  51005,
#  50704,
#  50621,
#  50708,
#  50614,
#  50617,
#  50615,
#  50703,
#  50601,
#  50616,
#  50611,
#  50613,
#  50612,
#  50604,
#  50606,
#  50603,
#  50608,
#  50618,
#  50610,
#  50620,
#  50908,
#  50905,
#  50602,
#  50911,
#  50607,
#  50906,
#  50910,
#  51004,
#  51003,
#  50901,
#  50907,
#  50904,
#  50301,
#  51106,
#  50304,
#  50903,
#  51010,
#  51006,
#  51102,
#  50902,
#  50302,
#  51105,
#  51008,
#  51001,
#  51103,
#  51009,
#  51007,
#  51107,
#  51101,
#  51002,
#  51011,
#  51012,
#  81007,
#  81008,
#  81009,
#  81001,
#  81002,
#  81004,
#  80708,
#  80802,
#  80501,
#  80502,
#  80506,
#  80507,
#  80601,
#  80603,
#  80604,
#  80605,
#  81206,
#  81207,
#  81208,
#  81212,
#  80606,
#  80607,
#  80608,
#  80801,
#  80803,
#  80804,
#  80805,
#  90612,
#  90614,
#  90606,
#  90603,
#  90608,
#  90605,
#  90615,
#  90602,
#  90604,
#  110301,
#  110302,
#  110303,
#  110304,
#  110305,
#  110401,
#  110402,
#  110403,
#  110405,
#  110501,
#  110404,
#  110102,
#  110103,
#  110104,
#  110105,
#  110106,
#  110110,
#  110111,
#  30202,
#  30608,
#  30219,
#  30606,
#  30604,
#  50112,
#  50102,
#  50113,
#  50111,
#  80305,
#  80301,
#  80306,
#  80307,
#  80308,
#  81105,
#  80401,
#  80403,
#  81303,
#  81305,
#  81302,
#  80103,
#  80104,
#  80107,
#  81103,
#  80910,
#  80901,
#  80914,
#  80903,
#  80404,
#  80904,
#  80905,
#  80906,
#  80408,
#  80907,
#  80908,
#  80909,
#  81304,
#  81306,
#  81307,
#  81106,
#  81301,
#  80302,
#  80303,
#  80304,
#  51104,
#  50201,
#  50204,
#  50205,
#  50206,
#  50106,
#  50105,
#  50114,
#  50511,
#  50110,
#  50504,
#  50101,
#  50115,
#  50109,
#  50103,
#  50108,
#  50107,
#  50502,
#  50403,
#  50501,
#  50404,
#  50104,
#  81101,
#  81104,
#  80402,
#  80405,
#  80406,
#  80407,
#  81209,
#  81210,
#  81211,
#  90413,
#  90404,
#  90410,
#  ...]

# %%
districts_centroids.NOMBDEP.unique().tolist()
# Out:
# ['CAJAMARCA',
#  'LAMBAYEQUE',
#  'LIMA',
#  'ANCASH',
#  'AREQUIPA',
#  'CUSCO',
#  'AYACUCHO',
#  'HUANCAVELICA',
#  'APURIMAC',
#  'PIURA',
#  'TACNA',
#  'JUNIN',
#  'HUANUCO',
#  'UCAYALI',
#  'MADRE DE DIOS',
#  'PUNO',
#  'LA LIBERTAD',
#  'TUMBES',
#  'CALLAO',
#  'AMAZONAS',
#  'LORETO',
#  'SAN MARTIN',
#  'ICA',
#  'PASCO',
#  'MOQUEGUA']

# %%
data_merge=data_cajamarca.merge( districts_centroids, how='left',left_on=['UBIGEO'],right_on=['UBIGEO'])
data_merge.head()
# Out:
#    id_eess  codigo_renaes categoria        nombre     diresa  \
# 0     9439           4210      II-1    GRAL. JAEN  CAJAMARCA
# 1    27242           4211       I-4   MORRO SOLAR  CAJAMARCA
# 2    22911           4212       I-3     MAGLLANAL  CAJAMARCA
# 3     9242           4213       I-3     FILA ALTA  CAJAMARCA
# 4    26418           4214       I-1  LAS NARANJAS  CAJAMARCA
#
#                           red  \
# 0  NO PERTENECE A NINGUNA RED
# 1                        JAEN
# 2                        JAEN
# 3                        JAEN
# 4                        JAEN
#
#                                            direccion   longitud   latitud  \
# 0  AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1  OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2  CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3  OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4  OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
#
#    id_ubigeo  ...  NOMBDEP_y  CCPP_y NOMBPROV_y  CCDI_y NOMBDIST_y  CAPITAL_y  \
# 0        636  ...  CAJAMARCA       8       JAEN       1       JAEN       JAEN
# 1        636  ...  CAJAMARCA       8       JAEN       1       JAEN       JAEN
# 2        636  ...  CAJAMARCA       8       JAEN       1       JAEN       JAEN
# 3        636  ...  CAJAMARCA       8       JAEN       1       JAEN       JAEN
# 4        636  ...  CAJAMARCA       8       JAEN       1       JAEN       JAEN
#
#   IDPROV_y CODIGO_y  Centroid_Latitude  Centroid_Longitude
# 0      608    60801          -5.770179          -78.852551
# 1      608    60801          -5.770179          -78.852551
# 2      608    60801          -5.770179          -78.852551
# 3      608    60801          -5.770179          -78.852551
# 4      608    60801          -5.770179          -78.852551
#
# [5 rows x 34 columns]

# %%
data_merge["UBIGEO"][1191]
# Out:
# 10205

# %% [markdown]
# Use these datasets and find the closest health establishment to Cajamarca district centroids. For each district, there should be only one health establishment.

# %%
from tqdm.notebook import tqdm
import requests
import urllib.request, json, csv

# %%
data_merge['Combination'] = data_merge.index
data_merge['Combination'] += 1
combination=data_merge['Combination'].tolist()

# %%
data_merge['Lat_string_destin']=data_merge['Centroid_Latitude'].astype(str)
data_merge['Long_string_destin']=data_merge['Centroid_Longitude'].astype(str)

# %%
data_merge['Lat_Long_destin'] = data_merge['Lat_string_destin'].str.cat(data_merge['Long_string_destin'], sep =",") 

destination=data_merge['Lat_Long_destin'].tolist()

# %%
data_merge['Lat_string_origin']=data_merge['latitud'].astype(str)
data_merge['Long_string_origin']=data_merge['longitud'].astype(str)

# %%
data_merge['Lat_Long_origin'] = data_merge['Lat_string_origin'].str.cat(data_merge['Long_string_origin'], sep =",") 

origin=data_merge['Lat_Long_origin'].tolist()

# %%
data_merge
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# 1                           JAEN
# 2                           JAEN
# 3                           JAEN
# 4                           JAEN
# ...                          ...
# 1187                      SOCOTA
# 1188                      SOCOTA
# 1189                      SOCOTA
# 1190                      SOCOTA
# 1191                 SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1     OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2     CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4     OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
# ...                                                 ...        ...       ...
# 1187  CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471 -6.292044
# 1188  OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080 -6.279960
# 1189  OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640 -6.266560
# 1190  OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210 -6.267210
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo  ...  CODIGO_y  Centroid_Latitude Centroid_Longitude  \
# 0           636  ...     60801          -5.770179         -78.852551
# 1           636  ...     60801          -5.770179         -78.852551
# 2           636  ...     60801          -5.770179         -78.852551
# 3           636  ...     60801          -5.770179         -78.852551
# 4           636  ...     60801          -5.770179         -78.852551
# ...         ...  ...       ...                ...                ...
# 1187        627  ...     60610          -6.279101         -78.578753
# 1188        627  ...     60610          -6.279101         -78.578753
# 1189        627  ...     60610          -6.279101         -78.578753
# 1190        627  ...     60610          -6.279101         -78.578753
# 1191        650  ...     10205          -4.991267         -78.389595
#
#       Combination   Lat_string_destin  Long_string_destin  \
# 0               1  -5.770178526822774  -78.85255115664602
# 1               2  -5.770178526822774  -78.85255115664602
# 2               3  -5.770178526822774  -78.85255115664602
# 3               4  -5.770178526822774  -78.85255115664602
# 4               5  -5.770178526822774  -78.85255115664602
# ...           ...                 ...                 ...
# 1187         1188     -6.279101100284  -78.57875268121131
# 1188         1189     -6.279101100284  -78.57875268121131
# 1189         1190     -6.279101100284  -78.57875268121131
# 1190         1191     -6.279101100284  -78.57875268121131
# 1191         1192   -4.99126684432514  -78.38959521553005
#
#                             Lat_Long_destin Lat_string_origin  \
# 0     -5.770178526822774,-78.85255115664602       -5.70621441
# 1     -5.770178526822774,-78.85255115664602           -5.7106
# 2     -5.770178526822774,-78.85255115664602       -5.70764748
# 3     -5.770178526822774,-78.85255115664602         -5.739184
# 4     -5.770178526822774,-78.85255115664602         -5.745295
# ...                                     ...               ...
# 1187     -6.279101100284,-78.57875268121131       -6.29204385
# 1188     -6.279101100284,-78.57875268121131          -6.27996
# 1189     -6.279101100284,-78.57875268121131          -6.26656
# 1190     -6.279101100284,-78.57875268121131          -6.26721
# 1191   -4.99126684432514,-78.38959521553005       -5.24869333
#
#       Long_string_origin           Lat_Long_origin
# 0           -78.80471119  -5.70621441,-78.80471119
# 1              -78.81192         -5.7106,-78.81192
# 2           -78.81726576  -5.70764748,-78.81726576
# 3             -78.791643      -5.739184,-78.791643
# 4             -78.846347      -5.745295,-78.846347
# ...                  ...                       ...
# 1187        -78.60747056  -6.29204385,-78.60747056
# 1188           -78.63108        -6.27996,-78.63108
# 1189           -78.59764        -6.26656,-78.59764
# 1190           -78.62721        -6.26721,-78.62721
# 1191        -78.64009333  -5.24869333,-78.64009333
#
# [1192 rows x 41 columns]

# %%
# Generate dictionary to store data
data_distance = {}

# %%
# Loop to generate info about geolocations
distance_info = np.zeros(shape=(len(combination),2), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin, destination))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info[i][0] = c
        distance_info[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
 
        i=i+1
           
    except Exception as e:
        
        distance_info[i][0] = c
        distance_info[i][1] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1192.0), HTML(value='')))
# 118
# 123
# 124
# 125
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 157
# 158
# 159
# 160
# 161
# 162
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 176
# 178
# 180
# 181
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 267
# 310
# 327
# 328
# 387
# 414
# 434
# 440
# 485
# 495
# 509
# 717
# 739
# 824
# 850
# 865
# 886
# 895
# 908
# 936
# 937
# 938
# 939
# 940
# 941
# 1004
# 1009
# 1014
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1047
# 1048
# 1049
# 1158
# 1161
# 1165
# 1166
# 1167
# 1168
# 1169
# 1170
# 1171
# 1192

# %%
data_distance = pd.DataFrame(distance_info, columns = ['Combination', 'distance'])

from functools import reduce 

dfs = [data_merge, data_distance]

data_merge2 = reduce(lambda left, right: pd.merge(left, right, on='Combination'),dfs)

# %%
data_merge2.columns
# Out:
# Index(['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
#        'direccion', 'longitud', 'latitud', 'id_ubigeo', 'ind', 'CCDD_x',
#        'NOMBDEP_x', 'CCPP_x', 'NOMBPROV_x', 'CCDI_x', 'NOMBDIST_x',
#        'CAPITAL_x', 'UBIGEO', 'IDPROV_x', 'CODIGO_x', 'CNT_CCPP', 'DESCRIPCIO',
#        'CCDD_y', 'NOMBDEP_y', 'CCPP_y', 'NOMBPROV_y', 'CCDI_y', 'NOMBDIST_y',
#        'CAPITAL_y', 'IDPROV_y', 'CODIGO_y', 'Centroid_Latitude',
#        'Centroid_Longitude', 'Combination', 'Lat_string_destin',
#        'Long_string_destin', 'Lat_Long_destin', 'Lat_string_origin',
#        'Long_string_origin', 'Lat_Long_origin', 'distance'],
#       dtype='object')

# %%
data_closest = data_merge2.copy()

# %%
data_closest2 = data_closest.sort_values('distance').groupby('UBIGEO', as_index= False).first()

# %%
data_closest2
# Out:
#      UBIGEO  id_eess  codigo_renaes categoria      nombre     diresa  \
# 0     10205    26156           6995       I-1    PISAGUAS  CAJAMARCA
# 1     60101    25604           4640       I-3  LA TULPUNA  CAJAMARCA
# 2     60102    26117           4623       I-1       SAPUC  CAJAMARCA
# 3     60103     7777           4653       I-2    CHETILLA  CAJAMARCA
# 4     60104     9447           4627       I-2      COSPAN  CAJAMARCA
# ..      ...      ...            ...       ...         ...        ...
# 124   61308    18932           4833       I-2  SAUCEPAMPA  CAJAMARCA
# 125   61309     5471           4710       I-1        SEXI  CAJAMARCA
# 126   61310    22920           4834       I-2    UTICYACU  CAJAMARCA
# 127   61311     5353           4836       I-1    PUCHUDEN  CAJAMARCA
# 128  131101    21617           4552       I-2      JAGUEY  CAJAMARCA
#
#              red                                          direccion  \
# 0    SAN IGNACIO  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ...
# 1      CAJAMARCA  AVENIDA AV. ALFONSO UGARTE S/N S/N AV. ALFONSO...
# 2      CAJAMARCA  OTROS COMUNIDAD DE SAPUC DISTRITO ASUNCION PRO...
# 3      CAJAMARCA  JIRÓN JR. SAN PEDRO S/N S/N JR. SAN PEDRO S/N ...
# 4      CAJAMARCA  JIRÓN JR. BOLIVAR S/N S/N JR. BOLIVAR S/N COSP...
# ..           ...                                                ...
# 124   SANTA CRUZ  OTROS CALL. 17 DE JULIO DISTRITO SAUCEPAMPA PR...
# 125   SANTA CRUZ  CALLE CALLE EL PROGRESO S/N NÚMERO S/N DISTRIT...
# 126   SANTA CRUZ  OTROS DISTRITO UTICYACU DISTRITO UTICYACU PROV...
# 127   SANTA CRUZ  OTROS COMUNIDAD PUCHUDEN COMUNIDAD PUCHUDEN YA...
# 128    CONTUMAZA  AVENIDA AV. CAJAMARCA S/N NÚMERO S/N DISTRITO ...
#
#       longitud   latitud  ...  Centroid_Latitude  Centroid_Longitude  \
# 0   -78.640093 -5.248693  ...          -4.991267          -78.389595
# 1   -78.553230 -7.062130  ...          -7.077465          -78.561111
# 2   -78.536053 -7.356402  ...          -7.338237          -78.527184
# 3   -78.673751 -7.146314  ...          -7.142504          -78.654027
# 4   -78.542951 -7.426715  ...          -7.453032          -78.516855
# ..         ...       ...  ...                ...                 ...
# 124 -78.916056 -6.691435  ...          -6.682861          -78.908469
# 125 -79.051096 -6.563187  ...          -6.585583          -79.036353
# 126 -78.794564 -6.606021  ...          -6.614700          -78.790538
# 127 -78.857844 -6.690749  ...          -6.682860          -78.849440
# 128 -78.940183 -7.614431  ...          -7.501508          -78.763948
#
#      Combination   Lat_string_destin  Long_string_destin  \
# 0           1192   -4.99126684432514  -78.38959521553005
# 1            527  -7.077465094056442  -78.56111128956503
# 2            711  -7.338237028825001   -78.5271835710878
# 3            729  -7.142504145663757  -78.65402714365003
# 4            716  -7.453031861989977  -78.51685530281875
# ..           ...                 ...                 ...
# 124          994  -6.682860526811872   -78.9084686522991
# 125          818  -6.585582547393862   -79.0363532251021
# 126          996  -6.614700237533157  -78.79053750141917
# 127         1000  -6.682859653400819  -78.84943957704252
# 128          440  -7.501507538534319  -78.76394795430816
#
#                            Lat_Long_destin  Lat_string_origin  \
# 0     -4.99126684432514,-78.38959521553005        -5.24869333
# 1    -7.077465094056442,-78.56111128956503           -7.06213
# 2     -7.338237028825001,-78.5271835710878        -7.35640199
# 3    -7.142504145663757,-78.65402714365003        -7.14631393
# 4    -7.453031861989977,-78.51685530281875        -7.42671499
# ..                                     ...                ...
# 124   -6.682860526811872,-78.9084686522991        -6.69143542
# 125   -6.585582547393862,-79.0363532251021        -6.56318719
# 126  -6.614700237533157,-78.79053750141917        -6.60602069
# 127  -6.682859653400819,-78.84943957704252        -6.69074851
# 128  -7.501507538534319,-78.76394795430816        -7.61443072
#
#     Long_string_origin           Lat_Long_origin  distance
# 0         -78.64009333  -5.24869333,-78.64009333       NaN
# 1            -78.55323        -7.06213,-78.55323       3.9
# 2         -78.53605266  -7.35640199,-78.53605266       3.7
# 3          -78.6737509   -7.14631393,-78.6737509      10.6
# 4         -78.54295072  -7.42671499,-78.54295072      14.1
# ..                 ...                       ...       ...
# 124         -78.916056    -6.69143542,-78.916056       1.7
# 125       -79.05109564  -6.56318719,-79.05109564       1.5
# 126       -78.79456398  -6.60602069,-78.79456398       1.5
# 127       -78.85784368  -6.69074851,-78.85784368       2.2
# 128       -78.94018339  -7.61443072,-78.94018339       NaN
#
# [129 rows x 42 columns]

# %%
data_closest2['Combination'] = data_closest2.index
data_closest2['Combination'] += 1
combination=data_closest2['Combination'].tolist()

# %%
destination1=data_closest2['Lat_Long_destin'].tolist()
destination2=data_closest2['Lat_Long_destin'].tolist()
destination3=data_closest2['Lat_Long_destin'].tolist()

# %%
origin1=data_closest2['Lat_Long_origin'].tolist()
origin2=data_closest2['Lat_Long_origin'].tolist()
origin3=data_closest2['Lat_Long_origin'].tolist()

# %%
# Generate dictionary to store data
data_distance_b = {}

# %%
# Loop to generate info about geolocations
distance_info_b = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin1, destination1))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'best_guess'  

        # Departure time
        departure_time= '1643058000'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_b[i][0] = c
        distance_info_b[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_b[i][2] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
 
        i=i+1
        
    except Exception as e:
        
        distance_info_b[i][0] = c
        distance_info_b[i][1] = "nan"
        distance_info_b[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=129.0), HTML(value='')))
# 1
# 19
# 63
# 65
# 77
# 79
# 81
# 83
# 85
# 89
# 90
# 91
# 92
# 120
# 129

# %%
data_distance_b = pd.DataFrame(distance_info_b, columns = ['Combination', 'travel_distance_best_guess','travel_time_best_guess'])

# %%
data_distance_b
# Out:
#      Combination  travel_distance_best_guess  travel_time_best_guess
# 0            1.0                         NaN                     NaN
# 1            2.0                         3.9                    11.0
# 2            3.0                         3.7                     8.0
# 3            4.0                        10.6                    27.0
# 4            5.0                        14.1                    37.0
# ..           ...                         ...                     ...
# 124        125.0                         1.7                     4.0
# 125        126.0                         1.5                     3.0
# 126        127.0                         1.5                     4.0
# 127        128.0                         2.2                     5.0
# 128        129.0                         NaN                     NaN
#
# [129 rows x 3 columns]

# %%
# Generate dictionary to store data
data_distance_o = {}

# %%
# Loop to generate info about geolocations
distance_info_o = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin2, destination2))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'optimistic'  

        # Departure time
        departure_time= '1643058000'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_o[i][0] = c
        distance_info_o[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_o[i][2] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
 
        i=i+1
        
    except Exception as e:
        
        distance_info_o[i][0] = c
        distance_info_o[i][1] = "nan"
        distance_info_o[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=129.0), HTML(value='')))
# 1
# 19
# 63
# 65
# 77
# 79
# 81
# 83
# 85
# 89
# 90
# 91
# 92
# 120
# 129

# %%
data_distance_o = pd.DataFrame(distance_info_o, columns = ['Combination', 'travel_distance_optimistic','travel_time_optimistic'])

# %%
# Generate dictionary to store data
data_distance_p = {}

# %%
# Loop to generate info about geolocations
distance_info_p = np.zeros(shape=(len(combination),3), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination,origin3, destination3))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'pessimistic'  

        # Departure time
        departure_time= '1643058000'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = API_KEY

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
                
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        
        distance_info_p[i][0] = c
        distance_info_p[i][1] = float(re.sub("[^0-9.]", "", legs['distance']['text']))
        distance_info_p[i][2] = float(re.sub("[^0-9.]", "", legs['duration_in_traffic']['text']))
 
        i=i+1
        
    except Exception as e:
        
        distance_info_p[i][0] = c
        distance_info_p[i][1] = "nan"
        distance_info_p[i][2] = "nan"
        
        i=i+1
        
        #data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=129.0), HTML(value='')))
# 1
# 19
# 63
# 65
# 77
# 79
# 81
# 83
# 85
# 89
# 90
# 91
# 92
# 120
# 129

# %%
data_distance_p = pd.DataFrame(distance_info_p, columns = ['Combination', 'travel_distance_pessimistic','travel_time_pessimistic'])

# %%
from functools import reduce 

dfs1 = [data_closest2, data_distance_b, data_distance_p , data_distance_o]

df_final= reduce(lambda left, right: pd.merge(left, right, on='Combination'),dfs1)

# %%
df_final.columns
# Out:
# Index(['UBIGEO', 'id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa',
#        'red', 'direccion', 'longitud', 'latitud', 'id_ubigeo', 'ind', 'CCDD_x',
#        'NOMBDEP_x', 'CCPP_x', 'NOMBPROV_x', 'CCDI_x', 'NOMBDIST_x',
#        'CAPITAL_x', 'IDPROV_x', 'CODIGO_x', 'CNT_CCPP', 'DESCRIPCIO', 'CCDD_y',
#        'NOMBDEP_y', 'CCPP_y', 'NOMBPROV_y', 'CCDI_y', 'NOMBDIST_y',
#        'CAPITAL_y', 'IDPROV_y', 'CODIGO_y', 'Centroid_Latitude',
#        'Centroid_Longitude', 'Combination', 'Lat_string_destin',
#        'Long_string_destin', 'Lat_Long_destin', 'Lat_string_origin',
#        'Long_string_origin', 'Lat_Long_origin', 'distance',
#        'travel_distance_best_guess', 'travel_time_best_guess',
#        'travel_distance_pessimistic', 'travel_time_pessimistic',
#        'travel_distance_optimistic', 'travel_time_optimistic'],
#       dtype='object')

# %%
df_final.to_excel('data_final_Caj.xlsx')

# %%
# df_final2 = df_final[['id_eess','codigo_renaes','categoria','nombre','diresa','red','direccion','longitud','latitud','id_ubigeo','UBIGEO','CCDD','NOMBDEP','CCPP','NOMBPROV','CCDI','NOMBDIST','CAPITAL','District','Dist_Centroid_Latitude','Dist_Centroid_Longitude','travel_time_best_guess','travel_time_pessimistic','travel_time_optimistic','travel_distance_best_guess','travel_distance_pessimistic','travel_distance_optimistic']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-c777b0f43b15> in <module>
# ----> 1 df_final2 = df_final[['id_eess','codigo_renaes','categoria','nombre','diresa','red','direccion','longitud','latitud','id_ubigeo','UBIGEO','CCDD','NOMBDEP','CCPP','NOMBPROV','CCDI','NOMBDIST','CAPITAL','District','Dist_Centroid_Latitude','Dist_Centroid_Longitude','travel_time_best_guess','travel_time_pessimistic','travel_time_optimistic','travel_distance_best_guess','travel_distance_pessimistic','travel_distance_optimistic']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['Dist_Centroid_Longitude', 'CAPITAL', 'District', 'Dist_Centroid_Latitude', 'CCDI', 'NOMBDEP', 'CCDD', 'CCPP', 'NOMBPROV', 'NOMBDIST'] not in index"
