# %% [markdown]
# ## [First Round](https://resultadoshistorico.onpe.gob.pe/EG2021/ResumenGeneral/10/T)

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }a
# </style>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode
import time 
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %% [markdown]
# # Driver Path Address

# %%
driver = webdriver.Chrome(executable_path=r'chromedriver-win64/chromedriver.exe')
# Maximize window
driver.maximize_window()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/523775411.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'chromedriver-win64/chromedriver.exe')

# %% [markdown]
# # Extracting all tables

# %%
# go to the link
driver.get( "https://resultadoshistorico.onpe.gob.pe/EG2021/" )
resumen_general = driver.find_element(By.XPATH, '/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[1]/div/div/a/div[2]/div')
resumen_general.click()

# %% [markdown]
# ## Pesidential results

# %%
# presidential section
presidential = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-menu/div/nav/div/div/div[2]/div/div[2]/a" )
presidential.click()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/2688991303.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   presidential = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-menu/div/nav/div/div/div[2]/div/div[2]/a" )

# %% [markdown]
# ### Get all elements from scope

# %%
scope.text
# Out:
# 'TODOS\nPERÚ\nEXTRANJERO'

# %%
scope = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div/select" )

# All selenium objects in scope
scope_options = [ x for x in scope.find_elements_by_tag_name("option") ]
dict_scope_options = { option.text : option for option in scope_options }
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/2813769754.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scope = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div/select" )

# %%
# There are three options
dict_scope_options.keys()
# Out:
# dict_keys(['TODOS', 'PERÚ', 'EXTRANJERO'])

# %%
# We click on Peru
dict_scope_options['TODOS'].click()

# %% [markdown]
# We have to be careful since everytime we make a click, the url changes.

# %% [markdown]
# ### Clean Table Example

# %%
# All selenium objects in department select
dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )

# Get number of total options
num_prov_options = len( dpt.options )
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/2516179819.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )

# %%
raw_table = driver.find_element_by_id( "table-scroll" )

raw_table_html = raw_table.get_attribute( 'innerHTML' )
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/899710150.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   raw_table = driver.find_element_by_id( "table-scroll" )

# %%
raw_table_html
# Out:
# '<div _ngcontent-oah-c101="" class="table-wrap"><table _ngcontent-oah-c101="" width="100%" id="table1" class="main-table table table-striped tabla_resultado"><tr _ngcontent-oah-c101=""><th _ngcontent-oah-c101="" align="center" colspan="6" class="fixed-side">TOTAL DE VOTOS</th></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" align="center" colspan="3" class="titulo_td fixed-side">ORGANIZACIONES POLÍTICAS</td><td _ngcontent-oah-c101="" align="center" class="titulo_td fixed-side">TOTAL</td><td _ngcontent-oah-c101="" align="center" class="titulo_td fixed-side">%VÁLIDOS</td><td _ngcontent-oah-c101="" align="center" class="titulo_td fixed-side">%EMITIDOS</td></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/iconos/iconos_reales/00000012.jpg"></td><!----><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/imagenes/candidatos/00000012.jpg"></td><!----><!----><!----><td _ngcontent-oah-c101="" width="40%" class="fixed-side" style="min-width: 440px;"> PARTIDO NACIONALISTA PERUANO</td><!----><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">15,642</td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side"> 11.832% <!----><!----></td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">8.498%</td></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/iconos/iconos_reales/00000005.jpg"></td><!----><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/imagenes/candidatos/00000005.jpg"></td><!----><!----><!----><td _ngcontent-oah-c101="" width="40%" class="fixed-side" style="min-width: 440px;"> EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD</td><!----><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">1,285</td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side"> 0.972% <!----><!----></td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">0.698%</td></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/iconos/iconos_reales/00000011.jpg"></td><!----><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/imagenes/candidatos/00000011.jpg"></td><!----><!----><!----><td _ngcontent-oah-c101="" width="40%" class="fixed-side" style="min-width: 440px;"> PARTIDO MORADO</td><!----><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">1,858</td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side"> 1.405% <!----><!----></td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">1.009%</td></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/iconos/iconos_reales/00000017.jpg"></td><!----><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrupacion" src="./assets/imagenes/candidatos/00000017.jpg"></td><!----><!----><!----><td _ngcontent-oah-c101="" width="40%" class="fixed-side" style="min-width: 440px;"> PERU PATRIA SEGURA</td><!----><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">279</td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side"> 0.211% <!----><!----></td><td _ngcontent-oah-c101="" width="auto" align="center" class="fixed-side">0.152%</td></tr><tr _ngcontent-oah-c101=""><td _ngcontent-oah-c101="" width="2.5%" class="fixed-side"><img _ngcontent-oah-c101="" alt="" class="foto_agrup ...

# %%
pd.read_html(raw_table_html)[0].iloc[ : ,2:]
# Out:
#                                   TOTAL DE VOTOS.2 TOTAL DE VOTOS.3  \
# 0                         ORGANIZACIONES POLÍTICAS            TOTAL
# 1                     PARTIDO NACIONALISTA PERUANO            15642
# 2   EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD             1285
# 3                                   PARTIDO MORADO             1858
# 4                               PERU PATRIA SEGURA              279
# 5                                VICTORIA NACIONAL             4374
# 6                                   ACCION POPULAR            12703
# 7      AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL             4433
# 8                                     PODEMOS PERU             4937
# 9                               JUNTOS POR EL PERU             8894
# 10                 PARTIDO POPULAR CRISTIANO - PPC              492
# 11                                  FUERZA POPULAR            17815
# 12                               UNION POR EL PERU             2284
# 13                              RENOVACION POPULAR             8274
# 14                     RENACIMIENTO UNIDO NACIONAL              774
# 15                  PARTIDO DEMOCRATICO SOMOS PERU             1926
# 16            PARTIDO POLITICO NACIONAL PERU LIBRE            34464
# 17                              DEMOCRACIA DIRECTA              234
# 18                        ALIANZA PARA EL PROGRESO            11531
# 19                          TOTAL DE VOTOS VÁLIDOS           132199
# 20                                 VOTOS EN BLANCO            37376
# 21                                     VOTOS NULOS            14482
# 22                         TOTAL DE VOTOS EMITIDOS           184057
#
#    TOTAL DE VOTOS.4 TOTAL DE VOTOS.5
# 0          %VÁLIDOS        %EMITIDOS
# 1           11.832%           8.498%
# 2            0.972%           0.698%
# 3            1.405%           1.009%
# 4            0.211%           0.152%
# 5            3.309%           2.376%
# 6            9.609%           6.902%
# 7            3.353%           2.408%
# 8            3.735%           2.682%
# 9            6.728%           4.832%
# 10           0.372%           0.267%
# 11          13.476%           9.679%
# 12           1.728%           1.241%
# 13           6.259%           4.495%
# 14           0.585%           0.421%
# 15           1.457%           1.046%
# 16          26.070%          18.725%
# 17           0.177%           0.127%
# 18           8.722%           6.265%
# 19         100.000%          71.825%
# 20              NaN          20.307%
# 21              NaN           7.868%
# 22              NaN         100.000%

# %%
raw_table = driver.find_element_by_id( "table-scroll" )

raw_table_html = raw_table.get_attribute( 'innerHTML' )

pd_table = pd.read_html( raw_table_html )[ 0 ]

pd_table2 = pd_table.iloc[ :, 2: ]

new_columns = pd_table2.iloc[ 0, : ].str.replace( " ", "_") \
                      .str.lower() \
                      .str.replace( "%", "share_") \
                      .apply( lambda x : unidecode.unidecode( x ) ) \
                      .tolist()

pd_table2.columns = new_columns
pd_table2

clean_table = pd_table2.iloc[ 1:, : ]

clean_table
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/961086210.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   raw_table = driver.find_element_by_id( "table-scroll" )
#                           organizaciones_politicas   total share_validos  \
# 1                     PARTIDO NACIONALISTA PERUANO   15642       11.832%
# 2   EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD    1285        0.972%
# 3                                   PARTIDO MORADO    1858        1.405%
# 4                               PERU PATRIA SEGURA     279        0.211%
# 5                                VICTORIA NACIONAL    4374        3.309%
# 6                                   ACCION POPULAR   12703        9.609%
# 7      AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL    4433        3.353%
# 8                                     PODEMOS PERU    4937        3.735%
# 9                               JUNTOS POR EL PERU    8894        6.728%
# 10                 PARTIDO POPULAR CRISTIANO - PPC     492        0.372%
# 11                                  FUERZA POPULAR   17815       13.476%
# 12                               UNION POR EL PERU    2284        1.728%
# 13                              RENOVACION POPULAR    8274        6.259%
# 14                     RENACIMIENTO UNIDO NACIONAL     774        0.585%
# 15                  PARTIDO DEMOCRATICO SOMOS PERU    1926        1.457%
# 16            PARTIDO POLITICO NACIONAL PERU LIBRE   34464       26.070%
# 17                              DEMOCRACIA DIRECTA     234        0.177%
# 18                        ALIANZA PARA EL PROGRESO   11531        8.722%
# 19                          TOTAL DE VOTOS VÁLIDOS  132199      100.000%
# 20                                 VOTOS EN BLANCO   37376           NaN
# 21                                     VOTOS NULOS   14482           NaN
# 22                         TOTAL DE VOTOS EMITIDOS  184057           NaN
#
#    share_emitidos
# 1          8.498%
# 2          0.698%
# 3          1.009%
# 4          0.152%
# 5          2.376%
# 6          6.902%
# 7          2.408%
# 8          2.682%
# 9          4.832%
# 10         0.267%
# 11         9.679%
# 12         1.241%
# 13         4.495%
# 14         0.421%
# 15         1.046%
# 16        18.725%
# 17         0.127%
# 18         6.265%
# 19        71.825%
# 20        20.307%
# 21         7.868%
# 22       100.000%

# %% [markdown]
# ### Loop over all departments

# %%
# Store all_tables
all_tables = {}

# %%
# All selenium objects in department select
dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )

# Get number of total options
num_prov_options = len( dpt.options )
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/2516179819.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )

# %%
num_prov_options
# Out:
# 26

# %%
for dpt_idx in range( num_prov_options ):
    
    # Get again all departments since HTML is refreshing
    # all elements
    # Click on one specific department
    dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
    department = dpt.options[ dpt_idx ]
    print( department.text )
    print( dpt_idx )
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/1445964091.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
# --TODOS--
# 0
# AMAZONAS
# 1
# ANCASH
# 2
# APURIMAC
# 3
# AREQUIPA
# 4
# AYACUCHO
# 5
# CAJAMARCA
# 6
# CALLAO
# 7
# CUSCO
# 8
# HUANCAVELICA
# 9
# HUANUCO
# 10
# ICA
# 11
# JUNIN
# 12
# LA LIBERTAD
# 13
# LAMBAYEQUE
# 14
# LIMA
# 15
# LORETO
# 16
# MADRE DE DIOS
# 17
# MOQUEGUA
# 18
# PASCO
# 19
# PIURA
# 20
# PUNO
# 21
# SAN MARTIN
# 22
# TACNA
# 23
# TUMBES
# 24
# UCAYALI
# 25

# %%
# Get all elements of province
prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
num_prov_options = len( prov.options )

# %%
num_prov_options
# Out:
# 8

# %%
for prov_idx in range( num_prov_options ):
            
    # Get again all districts since HTML is refreshing
    # all elements
    prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
    province = prov.options[ prov_idx ]

    # Get province name
    prov_name = province.text
    
    print( prov_idx ,  prov_name )
# Out:
# 0 --TODOS--
# 1 BAGUA
# 2 BONGARA
# 3 CHACHAPOYAS
# 4 CONDORCANQUI
# 5 LUYA
# 6 RODRIGUEZ DE MENDOZA
# 7 UTCUBAMBA

# %%
# Get all elements from district
dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
num_dist_options = len( dist.options )

for dist_idx in range( num_dist_options ):

    # Get again all districts since HTML is refreshing
    # all elements
    dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
    district = dist.options[ dist_idx ]

    # Get district name
    dist_name = district.text
    
    print( dist_idx ,  dist_name )
# Out:
# 0 -- SELECCIONE --
# 1 ARAMANGO
# 2 BAGUA
# 3 COPALLIN
# 4 EL PARCO
# 5 IMAZA
# 6 LA PECA

# %%
dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
dpt.options[ 1 ].text
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/2806241952.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
# 'AMAZONAS'

# %%
# we can loop over all departments
# for dpt_idx in range( num_prov_options ):
# but it will take too much time
# We are going to do it over two departments
for dpt_idx in range( 2 ):
    
    # Get again all departments since HTML is refreshing
    # all elements
    # Click on one specific department
    dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
    department = dpt.options[ dpt_idx ]
    
    # Get departmant name
    dpt_name = department.text
    
    # We select a different department name
    if dpt_name != "--TODOS--" :
        
        # click on department
        department.click()
        
        # Get all elements of province
        prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
        num_prov_options = len( prov.options )
        
        for prov_idx in range( num_prov_options ):
            
            # Get again all districts since HTML is refreshing
            # all elements
            prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
            province = prov.options[ prov_idx ]
                
            # Get province name
            prov_name = province.text
            
            if prov_name != "--TODOS--" :
                
                # click on province
                province.click()
                
                # Get all elements from district
                dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
                num_dist_options = len( dist.options )
                
                for dist_idx in range( num_dist_options ):
                    
                    # Get again all districts since HTML is refreshing
                    # all elements
                    dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
                    district = dist.options[ dist_idx ]
                    
                    # Get district name
                    dist_name = district.text
                    
                    if dist_name != "-- SELECCIONE --" :
                        
                        # click on district
                        district.click()
                        
                        # Get UBIGEO
                        ubigeo = driver.current_url.split("/")[ -1 ]
                        
                        ## Get table of presidential votes
                        # Get html at this point
                        table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
                        table_html = table_path.get_attribute( 'innerHTML' )
                        # Read the table using pandas
                        table = pd.read_html( table_html )
                        
                        # Cleaning tables
                        row_new_columns = table[ 0 ].iloc[ 0 , 2: ]
                        clean_columns = row_new_columns \
                                              .str.replace( " ", "_") \
                                              .str.lower().str.replace( "%", "share_") \
                                              .apply( lambda x : unidecode.unidecode( x ) ) \
                                              .tolist()
                        
                        # Selecting specific columns
                        table_clean = table[0].iloc[ 1:, 2: ].copy()
                        
                        # rename columns
                        table_clean.columns = clean_columns
                        
                        # New values to columns 
                        table_clean[ 'department' ] = dpt_name
                        table_clean[ 'province' ]   = prov_name
                        table_clean[ 'district' ]   = dist_name
                        table_clean[ 'ubigeo' ]     = ubigeo
                        table_clean[ 'link' ]       = driver.current_url
                        
                        # store tables
                        all_tables[ ubigeo ] = table_clean
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prov = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dist = Select( driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select" ) )
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14192/3580228208.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )

# %%
final_data = pd.concat( all_tables.values() ).reset_index( drop = True )

# %%
final_data
# Out:
#                             organizaciones_politicas total share_validos  \
# 0                       PARTIDO NACIONALISTA PERUANO   356        9.327%
# 1     EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD    13        0.341%
# 2                                     PARTIDO MORADO    41        1.074%
# 3                                 PERU PATRIA SEGURA     4        0.105%
# 4                                  VICTORIA NACIONAL   151        3.956%
# ...                                              ...   ...           ...
# 1601                        ALIANZA PARA EL PROGRESO   378       11.154%
# 1602                          TOTAL DE VOTOS VÁLIDOS  3389      100.000%
# 1603                                 VOTOS EN BLANCO  1201           NaN
# 1604                                     VOTOS NULOS   195           NaN
# 1605                         TOTAL DE VOTOS EMITIDOS  4785           NaN
#
#      share_emitidos department   province  district  ubigeo  \
# 0            6.389%   AMAZONAS      BAGUA  ARAMANGO  010202
# 1            0.233%   AMAZONAS      BAGUA  ARAMANGO  010202
# 2            0.736%   AMAZONAS      BAGUA  ARAMANGO  010202
# 3            0.072%   AMAZONAS      BAGUA  ARAMANGO  010202
# 4            2.710%   AMAZONAS      BAGUA  ARAMANGO  010202
# ...             ...        ...        ...       ...     ...
# 1601         7.900%   AMAZONAS  UTCUBAMBA     YAMON  010707
# 1602        70.825%   AMAZONAS  UTCUBAMBA     YAMON  010707
# 1603        25.099%   AMAZONAS  UTCUBAMBA     YAMON  010707
# 1604         4.075%   AMAZONAS  UTCUBAMBA     YAMON  010707
# 1605       100.000%   AMAZONAS  UTCUBAMBA     YAMON  010707
#
#                                                    link
# 0     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 2     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 3     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4     https://resultadoshistorico.onpe.gob.pe/EG2021...
# ...                                                 ...
# 1601  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1602  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1603  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1604  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1605  https://resultadoshistorico.onpe.gob.pe/EG2021...
#
# [1606 rows x 9 columns]

# %%
final_data.to_excel( r'example_round_1.xlsx' , index = False )
