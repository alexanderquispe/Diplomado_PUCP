# %% [markdown]
# # Assignment 4

# %% [markdown]
# In this task you have to scrape all the results from "Extranjero". [Here is link](https://resultadoshistorico.onpe.gob.pe/EG2021/EleccionesPresidenciales/RePres/E).
# You have to **follow the setps as we did in Lecture 7** and get information from all tabs in "Continente", "País" and "Estado".
#
# 1. Take the data table TOTAL DE VOTOS.
# 2. Store the four columns ORGANIZACIONES POLÍTICAS, TOTAL, %VÁLIDOS and %EMITIDOS. Rename these columns to political_parties, total, share_valid, share_emitied, respectively.
# 3. Add the columns continent, country, state, ubigeo, and link. These last two items you can extract from the url.
# 4. Append all the tables in just one DataFrame and export an excel file and save it in the folder [\_data\_results](https://github.com/alexanderquispe/Diplomado_PUCP/tree/main/Lecture_7/_data_results).
# 5. The name of your Excel file should be the same as the name of your branches.

# %%
#from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode
import time 
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
#HTML ISNT WORKING, WE ARE USING THIS CODE FOR THAT REASON


driver = webdriver.Chrome( ChromeDriverManager().install() )
driver.maximize_window()
driver.get('https://resultadoshistorico.onpe.gob.pe/EG2021/')
results = driver.find_element_by_xpath('/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[2]/div/div/a/div[1]/img')

results.click()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\PC\.wdm\drivers\chromedriver\win32\96.0.4664.45]
# <ipython-input-2-06510855b001>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )
# <ipython-input-2-06510855b001>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   results = driver.find_element_by_xpath('/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[2]/div/div/a/div[1]/img')

# %%
time.sleep(5)
scope = driver.find_element_by_xpath('/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div/select')
scope_options = [ x for x in scope.find_elements_by_tag_name('option')]
# Out:
# <ipython-input-3-c471907a3c32>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scope = driver.find_element_by_xpath('/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div/select')
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
dict_scope_options = { option.text : option for option in scope_options }
dict_scope_options.keys()
dict_scope_options['EXTRANJERO']
dict_scope_options['EXTRANJERO'].click()

# %% [raw]
# #IF HTML WORKS WE CAN OMMIT PREVIUS 3 CELLS AND ONLY USE THIS AND CONTINUE
# ## open link
# driver = webdriver.Chrome( ChromeDriverManager().install() )
# driver.maximize_window()
#
# url = 'https://resultadoshistorico.onpe.gob.pe/EG2021/EleccionesPresidenciales/RePres/E'
# driver.get( url )

# %%
#num opciones
continentes = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
num_continente = len(continentes.options)
num_continente
# Out:
# <ipython-input-5-cc16980747c8>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   continentes = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
# 6

# %%
# Store all_tables
all_tables = {}

continentes = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
continentes_opt = len( continentes.options )

# We are going to loop over all continents
#for continente_idx in range( continentes_opt ):
for continente_idx in range( 6 ):
    continente01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
    continente02 = continente01.options[ continente_idx ]
    
    # Get continent name
    continente_name = continente02.text
    
    # We select a different continent name    
    if continente_name != '--TODOS--':
        
        # click on continent
        continente02.click()
        
        # Get all elements of country
        countries = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
        countries_opt = len( countries.options )
        
        # We are going to loop over all countries
        for country_idx in range( countries_opt ):
            country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
            country02 = country01.options[ country_idx ]
            
            # Get country name
            country_name = country02.text
            
            # We select a different country name 
            if country_name != '--TODOS--':  
                
                # click on country
                country02.click()
                
                # Get all elements of state
                states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
                states_opt = len( states.options )
####
# Completar acá - Parte 3
# We are going to loop over all states
                for state_idx in range( states_opt ):
                    state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
                    state02 = state01.options[ state_idx ]
                    
                    # Get state name
                    state_name = state02.text
                    
                    # We select a different state name                     
                    if state_name != '--TODOS--':
                        
                        # click on state
                        state02.click()
                        
                        # Get UBIGEO
                        ubigeo = driver.current_url.split("/")[ -1 ]
                        
                        # Get html at this point
                        #Take the data table TOTAL DE VOTOS
                        table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
                        table_html = table_path.get_attribute( 'innerHTML' )
                        
                        # Read the table using pandas
                        table = pd.read_html( table_html )

####                        
                        # Cleaning tables
                        #Store the four columns ORGANIZACIONES POLÍTICAS, TOTAL, %VÁLIDOS and %EMITIDOS
                        #Rename these columns to political_parties, total, share_valid, share_emitied, respectively.
                        row_new_columns = table[ 0 ].iloc[ 0 , 2: ] # quito los NAN debido a imagenes
                        clean_columns = row_new_columns \
                                              .str.replace( " ", "_") \
                                              .str.lower().str.replace( "organizaciones_políticas", "political_parties" ) \
                                              .str.replace( "total", "total_share" ) \
                                              .str.replace( "%válidos", "share_valid" ) \
                                              .str.replace( "%emitidos", "share_emitied") \
                                              .apply( lambda x : unidecode.unidecode( x ) ) \
                                              .tolist()
                        
                        # Selecting specific columns
                        table_clean = table[0].iloc[ 1:, 2: ].copy()
                        
                        # rename columns
                        table_clean.columns = clean_columns

                        # New values to columns 
                        #Add the columns continent, country, state, ubigeo, and link. These last two items you can extract from the url.
                        table_clean[ 'continent' ]  = continente_name
                        table_clean[ 'country' ]    = country_name
                        table_clean[ 'state' ]      = state_name
                        table_clean[ 'ubigeo' ]     = ubigeo
                        table_clean[ 'link' ]       = driver.current_url
                        
                        # store tables
                        all_tables[ ubigeo ] = table_clean
# Out:
# <ipython-input-6-03f78b6b8921>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   continentes = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
# <ipython-input-6-03f78b6b8921>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   continente01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
# <ipython-input-6-03f78b6b8921>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   countries = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   continente01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
# <ipython-input-6-03f78b6b8921>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   countries = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# ...
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   continente01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select' ) )
# <ipython-input-6-03f78b6b8921>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   countries = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   country01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select' ) )
# <ipython-input-6-03f78b6b8921>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   states = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )
# <ipython-input-6-03f78b6b8921>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   state01 = Select( driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select' ) )
# <ipython-input-6-03f78b6b8921>:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_xpath( '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div' )

# %%
# Part 5

# %%
results = pd.concat( all_tables.values() ).reset_index( drop = True )
results
# Out:
#                                    political_parties total_share share_valid  \
# 0                       PARTIDO NACIONALISTA PERUANO           0      0.000%
# 1     EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD           0      0.000%
# 2                                     PARTIDO MORADO           0      0.000%
# 3                                 PERU PATRIA SEGURA           0      0.000%
# 4                                  VICTORIA NACIONAL           0      0.000%
# ...                                              ...         ...         ...
# 4615                        ALIANZA PARA EL PROGRESO           0      0.000%
# 4616                          TOTAL DE VOTOS VÁLIDOS          34    100.000%
# 4617                                 VOTOS EN BLANCO           0         NaN
# 4618                                     VOTOS NULOS           1         NaN
# 4619                         TOTAL DE VOTOS EMITIDOS          35         NaN
#
#      share_emitied continent        country       state  ubigeo  \
# 0           0.000%    AFRICA        ARGELIA       ARGEL  910101
# 1           0.000%    AFRICA        ARGELIA       ARGEL  910101
# 2           0.000%    AFRICA        ARGELIA       ARGEL  910101
# 3           0.000%    AFRICA        ARGELIA       ARGEL  910101
# 4           0.000%    AFRICA        ARGELIA       ARGEL  910101
# ...            ...       ...            ...         ...     ...
# 4615        0.000%   OCEANIA  NUEVA ZELANDA  WELLINGTON  950202
# 4616       97.143%   OCEANIA  NUEVA ZELANDA  WELLINGTON  950202
# 4617        0.000%   OCEANIA  NUEVA ZELANDA  WELLINGTON  950202
# 4618        2.857%   OCEANIA  NUEVA ZELANDA  WELLINGTON  950202
# 4619      100.000%   OCEANIA  NUEVA ZELANDA  WELLINGTON  950202
#
#                                                    link
# 0     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 1     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 2     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 3     https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4     https://resultadoshistorico.onpe.gob.pe/EG2021...
# ...                                                 ...
# 4615  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4616  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4617  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4618  https://resultadoshistorico.onpe.gob.pe/EG2021...
# 4619  https://resultadoshistorico.onpe.gob.pe/EG2021...
#
# [4620 rows x 9 columns]

# %%
#save to excel
results.to_excel( r'../_data_results/group_4_ass_4.xlsx' , index = False )
