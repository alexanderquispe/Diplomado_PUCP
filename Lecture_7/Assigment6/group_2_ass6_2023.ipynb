# %% [markdown]
# # Assigment 6
#
# This assigment will be graded if everything works well. I will run the script as once and everything should be done without errors and mistakes. I should be able to run your scripts in my computer and get all the results. **USE RELATIVE PATHS**. An error or exception or anything that breaks the code will means NO GRADE (0). Additionally, you are not able to modify any file handly. It also means NO GRADE (0). Comment everything you think will help others read your script. We expect 0 errors using GitHub. Everything will be graded!
#
# **ASK EVERYTHING! WE ARE HERE TO HELP YOU!**
#
#
#
# 1.   Generate a folder with the name of your group in this folder GitHub\Diplomado_PUCP_output\sbs\municipal. The code should run even if the folder exists.
# 2.   Scrape all the available information in this link. Save an excel file by year and month request. The excel file should be name using the month and year of the sheet.

# %% [markdown]
# First, we install the packages that allow us to web scrapping

# %%
#!pip install selenium
#!pip install webdriver-manager

# %% [markdown]
# Then, we import the libraries that allow us to work in the websites. Also, we import pandas to work with the dataframes we want to download and the library time to settle some seconds that allow the web page to refresh.

# %%
# this library is to manipulate browser
from selenium import webdriver

# it allows you to work with differen versions of drivers
# We call ChromeDriver
from webdriver_manager.chrome import ChromeDriverManager
import re
import time 
from selenium.webdriver.common.by import By

import pandas as pd
from pandas import json_normalize

import time
from time import sleep
import random
from selenium.webdriver.common.by import By

import unidecode
#unaccented_string = unidecode.unidecode(accented_string)

# Manipulate Json files
import json
import re
import numpy as np
import os

# %% [markdown]
# Then, we check were we settle our work space

# %%
pwd
# Out:
# 'D:\\Diplomado Ciencia de Datos\\3. Python Intermedio\\Assigment 6'

# %% [markdown]
# Se genera el relative path.

# %%
folder_name = "group_2_ass_6_2023"
relative_path = "..\..\_output\sbs\municipal/" + folder_name

# %% [markdown]
# We open the SBS web page to start browsing the information available.

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )
driver.maximize_window()
url = 'https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=C'
driver.get( url )
# Out:
# C:\Users\GUSTAVO\AppData\Local\Temp\ipykernel_12572\723154656.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %% [markdown]
# Then, we check the buttons in the web page. First, we have to identify the year button. Then, we have to identify the month button. We also need to identify the consult button and the download button.

# %%
dropdown_button_year = driver.find_element( By.ID, "ctl00_cphContent_rAnio")
dropdown_button_year.click()

list_year = driver.find_element( By.ID,  "ctl00_cphContent_rAnio_DropDown" )
years_list = list_year.find_elements( By.TAG_NAME, 'li')
list_year_options = len(years_list)

# Dropdown button list
dropdown_button_month = driver.find_element( By.ID,  "ctl00_cphContent_rMes")
dropdown_button_month.click()

# # List of months options
list_month = driver.find_element( By.ID,  "ctl00_cphContent_rMes_DropDown" )
months_list = list_month.find_elements( By.TAG_NAME, 'li')
list_month_options = len(months_list)
driver.find_element( By.ID, "ctl00_cphContent_btnConsultaMensual").click()
driver.get("https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=C")

# %% [markdown]
# We create an ID for the year, that has to go from 2002 until 2023. And we do the same with the month, that goes from 1 to 12. For that, we use the ID created before with the driver.find.element option.

# %%
year_numbers_opt = np.array( [1, 0 ] + np.arange(2, list_year_options).tolist() )
month_numbers_opt = np.array( [1, 0 ] + np.arange(2, list_month_options).tolist() )

# %% [markdown]
# In this section, we create the loop that allows us to download all the information available in the SBS web page. This code allows us to download all the monthly interest rate of all the "cajas municipales" that are in the SBS database from january 2003 to january 2023.

# %%
years_info_list = []
months_info_list = []
tables_info_list = []

for year_number in year_numbers_opt[0:22]:
    
    # Dropdown button list
    dropdown_button_year = driver.find_element( By.ID, "ctl00_cphContent_rAnio") 
    dropdown_button_year.click()

    # List of years options
    time.sleep(0.5)
    driver.find_element( By.XPATH,  f"/html/body/form/div[1]/div/ul/li[{year_number + 1 }]" ).click()
    year_text = driver.find_element( By.ID, "ctl00_cphContent_rAnio").text

    
        
    for month_number in month_numbers_opt[0:12]:
        
        # Dropdown button list
        dropdown_button_month = driver.find_element( By.ID, "ctl00_cphContent_rMes") 
        dropdown_button_month.click()

        # # List of months options
        time.sleep(0.5)
        driver.find_element( By.XPATH,  f"/html/body/form/div[1]/div/ul/li[{month_number + 1 }]" ).click()
        month_text = driver.find_element( By.ID, "ctl00_cphContent_rMes").text
        print( year_text )
        print( month_text )
        
        # Click consultar
        driver.find_element( By.ID,"ctl00_cphContent_btnConsultaMensual").click()
        time.sleep(5)
        
        year_float = int(year_text)
        
        try:
            # Switch elements
            driver.switch_to.frame(driver.find_element( By.ID,"ctl00_cphContent_pnContenidoAnteriorMnASP"))
            section_tab_table = driver.find_element( By.XPATH,  "/html/body/form/table/tbody" )
            table_html = section_tab_table.get_attribute('outerHTML')
            table_pd = pd.read_html( table_html )

            # Cleaning tablr
            table_clean_1 = table_pd[1].iloc[5:, :].copy().reset_index( drop = True )

            # Changing switch
            driver.switch_to.default_content()

            print("Table Tipo 1 - Cambiar de Frame y una tabla simple")

        except:
            print("No table Tipo 1")
            table_clean_1 = "Null"
            
            
        try:
            # Switch elements
            driver.switch_to.frame(driver.find_element( By.ID,"ctl00_cphContent_pnContenidoAnteriorMnASP"))
            section_tab_table = driver.find_element( By.XPATH,  "/html/body/form/table/tbody" )
            table_html = section_tab_table.get_attribute('outerHTML')
            table_pd = pd.read_html( table_html )

            # generate table objects
            table0, table1 = table_pd[0], table_pd[1]
            table_clean_2 = table1.copy()

            # Number of rows of second table
            tb1_rows = table1.shape[0]
            drop_rows = np.arange( 1, tb1_rows + 2 )

            # Clean first table
            table0 = table0.drop( drop_rows, axis = 0 )

            # Assign values to new table
            col_name = table0.iloc[0, 0]
            col_values = table0.iloc[1:, 0].tolist()
            table_clean_2.insert( loc = 0, column= col_name, value = col_values)
            
            print("Table Tipo 2 - Cambiar de Frame y una tabla Compleja")
            
             # Changing switch
            driver.switch_to.default_content()
            
        except:
            print("No table Tipo 2")
            table_clean_2 = "Null"
            

        try:
            # Get tables
            section_id_table = driver.find_element( By.ID, "ctl00_cphContent_rpgActualMn_OT" )
            table_html = section_id_table.get_attribute('outerHTML')
            table_pd = pd.read_html( table_html )

            # generate table objects
            table0, table1 = table_pd[0], table_pd[1]
            table_clean_3 = table1.copy()

            # Number of rows of second table
            tb1_rows = table1.shape[0]
            drop_rows = np.arange( 1, tb1_rows + 2 )

            # Clean first table
            table0 = table0.drop( drop_rows, axis = 0 )

            # Assign values to new table
            col_name = table0.iloc[0, 0]
            col_values = table0.iloc[1:, 0].tolist()
            table_clean_3.insert( loc = 0, column= col_name, value = col_values)
            
            print("Table Tipo 3 - No Cambiar de Frame y una tabla Compleja")
            
        except:
            print("No table Tipo 3")
            table_clean_3 = "Null"
            
            
        # Check what to save
        if ( ( isinstance( table_clean_3, str ) == False ) and ( table_clean_3.shape[1] > 5 ) ):
            
            # Data with no frame
            table_clean_3.to_excel( fr"caja_municipal_{year_text}_{month_text}.xlsx", index = False )
            
            years_info_list.append( year_float)
            months_info_list.append( month_text )
            tables_info_list.append( "Table 3" )
            print("guardo3")
            
        elif ( ( isinstance( table_clean_2, str ) == False ) and ( table_clean_2.shape[1] > 5 ) ):
            
            # Data with frame and 2 tables
            table_clean_2.to_excel( fr"caja_municipal_{year_text}_{month_text}.xlsx", index = False, header = False )
            # To break
            years_info_list.append( year_float)
            months_info_list.append( month_text )
            tables_info_list.append( "Table 2" )
            print("guardo2")
            
        elif ( ( isinstance( table_clean_1, str ) == False ) and ( table_clean_1.shape[1] > 5 ) ):
            # Data with frame and 1 table
            table_clean_1.to_excel( fr"caja_municipal_{year_text}_{month_text}.xlsx", index = False , header = False )
            
            years_info_list.append( year_float)
            months_info_list.append( month_text )
            tables_info_list.append( "Table 1" )
            print("guardo1")
            
        # No table information
        # Go to a previous day
        else:
            # Day ago
            years_info_list.append( year_float)
            months_info_list.append( month_text )
            tables_info_list.append( "No Table" )
            
        driver.switch_to.default_content()
# Out:
# 2022
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2022
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2023
# Febrero
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2023
# Marzo
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Abril
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Mayo
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Junio
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Julio
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Agosto
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Setiembre
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Octubre
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Noviembre
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2023
# Diciembre
# No table Tipo 1
# No table Tipo 2
# No table Tipo 3
# 2021
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2021
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2020
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2019
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2018
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2017
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Febrero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Enero
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Marzo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Abril
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Mayo
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Junio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Julio
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Agosto
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Setiembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2016
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2015
# Febrero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Enero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Marzo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Abril
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Mayo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Junio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Julio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Agosto
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Setiembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2015
# Octubre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2015
# Noviembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2015
# Diciembre
# No table Tipo 1
# No table Tipo 2
# Table Tipo 3 - No Cambiar de Frame y una tabla Compleja
# guardo3
# 2014
# Febrero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Enero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Marzo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Abril
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Mayo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Junio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Julio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Agosto
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Setiembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Octubre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Noviembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2014
# Diciembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Febrero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Enero
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Marzo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Abril
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Mayo
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Junio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Julio
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Agosto
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Setiembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Octubre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Noviembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# 2013
# Diciembre
# Table Tipo 1 - Cambiar de Frame y una tabla simple
# No table Tipo 2
# No table Tipo 3
# guardo1
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12572\468333537.py in <module>
#      24         # # List of months options
#      25         time.sleep(0.5)
# ---> 26         driver.find_element( By.XPATH,  f"/html/body/form/div[1]/div/ul/li[{month_number + 1 }]" ).click()
#      27         month_text = driver.find_element( By.ID, "ctl00_cphContent_rMes").text
#      28         print( year_text )
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/form/div[1]/div/ul/li[2]"}
#   (Session info: chrome=110.0.5481.104)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x010837D3]
# 	(No symbol) [0x01018B81]
# 	(No symbol) [0x00F1B36D]
# 	(No symbol) [0x00F4D382]
# 	(No symbol) [0x00F4D4BB]
# 	(No symbol) [0x00F83302]
# 	(No symbol) [0x00F6B464]
# 	(No symbol) [0x00F81215]
# 	(No symbol) [0x00F6B216]
# 	(No symbol) [0x00F40D97]
# 	(No symbol) [0x00F4253D]
# 	GetHandleVerifier [0x012FABF2+2510930]
# 	GetHandleVerifier [0x01328EC1+2700065]
# 	GetHandleVerifier [0x0132C86C+2714828]
# 	GetHandleVerifier [0x01133480+645344]
# 	(No symbol) [0x01020FD2]
# 	(No symbol) [0x01026C68]
# 	(No symbol) [0x01026D4B]
# 	(No symbol) [0x01030D6B]
# 	BaseThreadInitThunk [0x755E00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77407BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77407B8E+238]
