# %%
import numpy as np

# %%
np.random.seed(123)
students = np.arange( 1, 50 )

# %%
original = np.arange( 0 , 49 ).tolist()
results = []

# %%
for i in range(10):
    try:
        values = np.random.choice( original, size=5, replace=False)
    except:
        values = np.random.choice( original, size=4, replace=False)
    original = list(set(original).difference(values))
    results.append( values )

# %%
import random

def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
import pandas as pd

# %%
data1 = pd.read_excel( r"C:\Users\Anzony\Downloads\ListaParticipantes_2022 Curso de Capac (1).xls" )

# %%
data1
# Out:
#     N°    Código                    Apellidos y nombres  \
# 0    1  19910029      CORNEJO SANCHEZ, CHRISTIAN SANTOS
# 1    2  19977308       ORELLANA QUISPE, CRISTIAN NASSER
# 2    3  20060447  MORALES CHOQUEHUANCA, ANGELICA KARINA
# 3    4  20083223         GUIMARAY RIBEYRO, JOSE ROBERTO
# 4    5  20095080         CAMACHO GAVIDIA, ABEL FERNANDO
# 5    6  20098137          TINTAYA ORIHUELA, MEIR ALVARO
# 6    7  20102168     CHAVEZ MARTINEZ, JOSELIN ALEXANDRA
# 7    8  20105737           FIGUEROA MURO, LEONEL ARTURO
# 8    9  20116355          GOMEZ CRIBILLERO, JOSE FELIPE
# 9   10  20122733               PALOMINO SEGUÍN, AFRANIA
# 10  11  20130006           LUZON CUEVA, BIANCA MARIETTE
# 11  12  20131279            SUAÑA ZEGARRA, ADRIAN ANDRE
# 12  13  20131444  SOTO POMACHAGUA, DORKAS YOMIRA JHERMY
# 13  14  20132766          FIORENTINO MARTINEZ, LADY ALY
# 14  15  20132781              LAMA MAVILA, HECTOR ANDRE
# 15  16  20141672                   MEZA HINOJO, GUSTAVO
# 16  17  20155675         LOZADA MURILLO, PERSEO MARCELO
# 17  18  20160109        ZAMBRANO JIMENEZ, MIGUEL ALONZO
# 18  19  20160844                  JACOBS LUQUE, NICOLAS
# 19  20  20161626            VIDAL VIDAL, ROCIO GABRIELA
# 20  21  20161821            TORRES ANICAMA, JANE CAMILA
# 21  22  20162040             LOPEZ ESTRADA, MARIA ELISA
# 22  23  20162305                 BOYCO ORAMS, ALEJANDRO
# 23  24  20167070         DIAZ BERROSPI, KARLINE ROSMELI
# 24  25  20171426        RIEGA ESCALANTE, STEPHY ROSARIO
# 25  26  20171713         LEVANO TORRES, VALERIA CECILIA
# 26  27  20172359       ESQUIVES BRAVO, SEBASTIAN RENATO
# 27  28  20173089            PEREZ GONZALES, JUAN CARLOS
# 28  29  20175439                 OTERO MAGUIÑA, MARIANA
# 29  30  20176040           CLAVO CAMPOS, ANDREA BRIZETH
# 30  31  20182474            AGUILAR GARCIA, ERICK JOSUE
# 31  32  20182814         CALDAS VELASQUEZ, JOSUE DANIEL
# 32  33  20185062        SALAS NUÑEZ BORJA, FABIO MANUEL
# 33  34  20191460     PIZARRO VILLANES, FERNANDA NICOLLE
# 34  35  20193853     QUILLATUPA MORALES, ANGELA ADELINA
# 35  36  F0576653            HUANCAYA IDONE, CESAR DANTE
# 36  37  F0632095    CALVO PORTOCARRERO, GABRIELA ISABEL
# 37  38  F0740669          IBAÑEZ ABANTO, ANGEL MAURICIO
# 38  39  F0783929            MELÉNDEZ APONTE, JUAN DIEGO
# 39  40  F0872708                CRISTIAN SERRANO, ARONE
# 40  41  F0873079        HINOJOSA CAHUANA, PERCY ALBERTH
# 41  42  F0909693            ANGLAS GARCÍA, KEVIN ARTURO
# 42  43  F0970201           ALDAVE ACOSTA, CESAR ERNESTO
# 43  44  F1100839             NÚÑEZ HUAMÁN, CÉSAR AGUSTO
# 44  45  F1150976            OBREGON HUAMAN, DIANA EDITH
# 45  46  F1302466         SOTO PACHERRES, RODRIGO FRANCO
# 46  47  F1307545     INGARUCA RIVERA, GRETTEL ALEXANDRA
# 47  48  F1307976              ROJAS HUAMAN, ROSA ANGELA
# 48  49  F1308355                NEYRA SALAS, DANTE OMAR
# 49  50  F1311690     HUERTA ESPINOZA, YAJAIRA ALEXANDRA
# 50  51  F1314997         HUANCA MARTINEZ, JORGE ALBERTO
# 51  52  H0000801                 FLORES CADILLO, ALEXIS
#
#          Correo electrónico PUCP            Correo electrónico no PUCP  \
# 0          cscornejo@pucp.edu.pe                 cscornejo@hotmail.com
# 1        orellana.cn@pucp.edu.pe                  crisnass@hotmail.com
# 2     karina.morales@pucp.edu.pe             karinamorales35@gmail.com
# 3              a20083223@pucp.pe                                   NaN
# 4           abel.camacho@pucp.pe                abel.camacho@gmail.com
# 5           mtintaya@pucp.edu.pe                  mto_ar08@hotmail.com
# 6     joselin.chavez@pucp.edu.pe                josi_12_17@hotmail.com
# 7              a20105737@pucp.pe                 leo16_010@hotmail.com
# 8               jfgomezc@pucp.pe                     jfgcl@hotmail.com
# 9       afrania.palomino@pucp.pe            aps_1994_dic16@hotmail.com
# 10          luzon.bianca@pucp.pe                   bmlc_95@hotmail.com
# 11         adrian.suanaz@pucp.pe               adrian.suanaz@gmail.com
# 12            soto.y@pucp.edu.pe                   doryomi@hotmail.com
# 13             a20132766@pucp.pe           lady-fiorentino@hotmail.com
# 14        andre.lama@pucp.edu.pe        hectorious_dx_2012@hotmail.com
# 15      gustavo.meza@pucp.edu.pe             gustavo.31_97@hotmail.com
# 16          pmlozada@pucp.edu.pe          marcelo.lozada97@hotmail.com
# 17       m.zambranoj@pucp.edu.pe                miguelzamb99@gmail.com
# 18    nicolas.jacobs@pucp.edu.pe                nicojacobs98@gmail.com
# 19            gvidal@pucp.edu.pe               rociogvidal14@gmail.com
# 20       jane.torres@pucp.edu.pe                jctanicama@hotmail.com
# 21           m.lopez@pucp.edu.pe            maria_elisa_99@hotmail.com
# 22   alejandro.boyco@pucp.edu.pe              alejandroboyco@gmail.com
# 23         a20167070@pucp.edu.pe               karline.diazb@gmail.com
# 24      riega.stephy@pucp.edu.pe                riega.stephy@gmail.com
# 25          vlevanot@pucp.edu.pe               let.valeria@hotmail.com
# 26         sesquives@pucp.edu.pe                                   NaN
# 27       perez.juanc@pucp.edu.pe              juan.carliux@hotmail.com
# 28     mariana.otero@pucp.edu.pe               marianaoterom@gmail.com
# 29            aclavo@pucp.edu.pe             andreabrizeth@hotmail.com
# 30         a20182474@pucp.edu.pe                 josue.erik1@gmail.com
# 31      josue.caldas@pucp.edu.pe        coartac.josue.caldas@gmail.com
# 32       fabio.salas@pucp.edu.pe                fabiosnb1998@gmail.com
# 33  fernanda.pizarro@pucp.edu.pe          fernanda_19_2002@hotmail.com
# 34           aquillatupa@pucp.pe                                   NaN
# 35                           NaN               dantehuancaya@gmail.com
# 36                           NaN           gabriela.calvo@unmsm.edu.pe
# 37                           NaN                    anibab28@gmail.com
# 38                           NaN            juan.melendez@unmsm.edu.pe
# 39                           NaN               cristian.serrano@uni.pe
# 40          f0873079@pucp.edu.pe               percy.hinojosa.c@uni.pe
# 41                           NaN                 kevhin_ar@hotmail.com
# 42                           NaN   cesaraldave@visionainmobiliaria.com
# 43                           NaN              ca.nunezhuaman@gmail.com
# 44                           NaN             pe.diana.obregon.h@uni.pe
# 45                           NaN  rodrigofrancosotopacherres@gmail.com
# 46                           NaN         grettel.ingaruca@unmsm.edu.pe
# 47                           NaN           rosangela.rohua@outlook.com
# 48                           NaN                 dante.neyra@gmail.com
# 49                           NaN           yajaira.huerta.97@gmail.com
# 50                           NaN                  jorgeahm98@gmail.com
# 51     flores.alexis@pucp.edu.pe               alex_148_84@hotmail.com
#
#          DNI  Carnet de Extranjería  Pasaporte
# 0    9868135                    NaN        NaN
# 1   40448088                    NaN        NaN
# 2   45801977                    NaN        NaN
# 3   47474754                    NaN        NaN
# 4   70669340                    NaN        NaN
# 5   70618764                    NaN        NaN
# 6   48034389                    NaN  6153516.0
# 7   48230530                    NaN        NaN
# 8   71857929                    NaN        NaN
# 9   71020437                    NaN        NaN
# 10  72029215                    NaN        NaN
# 11  74020955                    NaN        NaN
# 12  72724747                    NaN        NaN
# 13  75046800                    NaN        NaN
# 14  76536864                    NaN        NaN
# 15  73034422                    NaN        NaN
# 16  70667116                    NaN        NaN
# 17  74074372                    NaN        NaN
# 18  72152614                    NaN        NaN
# 19  77423029                    NaN        NaN
# 20  73150565                    NaN        NaN
# 21  72154184                    NaN        NaN
# 22  74599631                    NaN        NaN
# 23  44827659                    NaN        NaN
# 24  71696530                    NaN        NaN
# 25  70314318                    NaN        NaN
# 26  74528181                    NaN        NaN
# 27  74862049                    NaN        NaN
# 28  74610428                    NaN        NaN
# 29  70088748                    NaN        NaN
# 30  73307469                    NaN        NaN
# 31  70313538                    NaN        NaN
# 32  71558745                    NaN        NaN
# 33  72466445                    NaN        NaN
# 34  70434890                    NaN        NaN
# 35  43807286                    NaN        NaN
# 36  71839230                    NaN        NaN
# 37  70669324                    NaN  6530302.0
# 38  70268957                    NaN        NaN
# 39  71265178                    NaN        NaN
# 40  46992545                    NaN        NaN
# 41  70332517                    NaN        NaN
# 42  45843356                    NaN        NaN
# 43  70448914                    NaN        NaN
# 44  47648782                    NaN        NaN
# 45  70470202                    NaN        NaN
# 46  73118812                    NaN        NaN
# 47  75233054                    NaN        NaN
# 48  10432487                    NaN        NaN
# 49  70049035                    NaN        NaN
# 50  71004209                    NaN        NaN
# 51  70444605                    NaN        NaN

# %%
data1.iloc[results[9] , 2 ]
# Out:
# 14    GASTAÑADUY FIESTAS, JESUS EDUARDO
# 20        VILLENA TAGLE, CLAUDIA ARIANA
# 34     DE LA CRUZ ORIUNDO, JOSE EDUARDO
# 1              BALBIN INGA, NOE AUGUSTO
# Name: name_last_name, dtype: object

# %%
results
# Out:
# [array([13,  9, 22, 18, 42]),
#  array([12, 17, 35, 47,  4]),
#  array([30, 16, 32,  5, 11]),
#  array([20,  2, 19, 43,  3]),
#  array([28, 44, 33,  8, 39]),
#  array([29, 45, 14, 23,  6]),
#  array([38,  1, 27,  7, 48]),
#  array([40, 25, 46, 41, 15]),
#  array([ 0, 31, 21, 24, 26]),
#  array([36, 37, 10, 34])]
