# %%
import pandas as pd

# %%
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\jarin\\CURSO_PYTHON\\Diplomado_PUCP\\Lecture_2'

# %%
full_path = r"C:\Users\jarin\CURSO_PYTHON\Diplomado_PUCP\_data\enaho\Enaho01A-2023-300.csv"
pd.read_csv(full_path, encoding="ISO-8859-10")
# Out:
# C:\Users\jarin\AppData\Local\Temp\ipykernel_23320\748331030.py:2: DtypeWarning: Columns (26,32,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(full_path, encoding="ISO-8859-10")
#          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# ...

# %%
print("Primeras 5 filas del dataset:")
print(df.head())
# Out:
# Primeras 5 filas del dataset:
#     AÑO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  ESTRATO  \
# 0  2023    1      5030         2     11         1   10201        7        4
# 1  2023    1      5030         2     11         2   10201        7        4
# 2  2023    1      5030         2     11         3   10201        7        4
# 3  2023    1      5030         2     11         4   10201        7        4
# 4  2023    1      5030        11     11         1   10201        7        4
#
#    CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C I315B    FACTOR07  \
# 0         1  ...                                                  118.374542
# 1         2  ...                                                  118.374542
# 2         2  ...                                                  118.374542
# 3         2  ...                          8                       118.374542
# 4         1  ...                                                  118.374542
#
# ...

# %%
variables = ["AÑO", "MES", "VIVIENDA", "UBIGEO"]
df_sel = df[variables].copy()   

print("Subconjunto de variables seleccionadas:")
print(df_sel.head())
# Out:
# Subconjunto de variables seleccionadas:
#     AÑO  MES  VIVIENDA  UBIGEO
# 0  2023    1         2   10201
# 1  2023    1         2   10201
# 2  2023    1         2   10201
# 3  2023    1         2   10201
# 4  2023    1        11   10201

# %%
df_sel["AÑO"] = pd.to_numeric(df_sel["AÑO"], errors="coerce")
df_sel["MES"] = pd.to_numeric(df_sel["MES"], errors="coerce")

print("\nTipos de datos después de la conversión:")
print(df_sel.dtypes)
# Out:
# Tipos de datos después de la conversión:
# AÑO         int64
# MES         int64
# VIVIENDA    int64
# UBIGEO      int64
# dtype: object

# %%
# EJEMPLO 1

df_sel.loc[df_sel["MES"] == 1, "MES"] = "ENERO"

# EJEMPLO 2
df_sel.loc[df_sel["UBIGEO"] == 150101, "UBIGEO"] = "LIMA-CERCADO"

print("\nDatos después de las modificaciones:")
print(df_sel.head(20))
# Out:
# Datos después de las modificaciones:
#      AÑO    MES  VIVIENDA UBIGEO
# 0   2023  ENERO         2  10201
# 1   2023  ENERO         2  10201
# 2   2023  ENERO         2  10201
# 3   2023  ENERO         2  10201
# 4   2023  ENERO        11  10201
# 5   2023  ENERO        11  10201
# 6   2023  ENERO        11  10201
# 7   2023  ENERO        37  10201
# 8   2023  ENERO        37  10201
# 9   2023  ENERO        37  10201
# 10  2023  ENERO        37  10201
# 11  2023  ENERO        45  10201
# 12  2023  ENERO        45  10201
# 13  2023  ENERO        56  10201
# 14  2023  ENERO        60  10201
# 15  2023  ENERO        60  10201
# 16  2023  ENERO        60  10201
# 17  2023  ENERO        60  10201
# 18  2023  ENERO        25  10513
# 19  2023  ENERO        25  10513

# %%
# Out:
# Tipos de datos:
# AÑO         int64
# MES         int64
# VIVIENDA    int64
# UBIGEO      int64
# dtype: object
