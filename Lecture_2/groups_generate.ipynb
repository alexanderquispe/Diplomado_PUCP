# %%
import numpy as np

# %%
np.random.seed(123)
students = np.arange( 1, 53 )

# %%
original = np.arange( 0 , 52 ).tolist()
results = []

# %%
for i in range(10):
    try:
        values = np.random.choice( original, size=5, replace=False)
    except:
        values = np.random.choice( original, size=4, replace=False)
    original = list(set(original).difference(values))
    results.append( values )

# %%
import random

def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
grupos = list(chunks( np.arange(0, 52), 4))

# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
data1 = pd.read_excel( r"/Users/ar8787/Downloads/Lista Participantes.xls" )

# %%
df2 = data1.loc[:, ['Código', 'Apellidos y nombres']].copy()

# %%
s = pd.Series([None,None],index=['Código', 'Apellidos y nombres'])

# Appending empty series to df
data1 = df2.append(s,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_28021/615138868.py in ?()
#       1 s = pd.Series([None,None],index=['Código', 'Apellidos y nombres'])
#       2
#       3 # Appending empty series to df
# ----> 4 data1 = df2.append(s,ignore_index=True)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
data1['Grupos'] = "" 

i = 1
for gr in grupos:
    data1.iloc[ gr, -1 ] = f"Grupo {i}"
    i = i + 1

# %%
groups = data1.loc[:, [ 'Apellidos y nombres', 'Grupos' ]] \
                .assign(order= data1.groupby(['Grupos']).cumcount()) \
                .pivot( index = ['order'] , columns = ['Grupos']) \
                .replace( np.nan, "")

# %%
groups
# Out:
#                         Apellidos y nombres                                   \
# Grupos                              Grupo 1                         Grupo 10
# order
# 0              ORTIZ PAREDES, CÉSAR MARCELO      CALDERON NEYRA, JOSE DANIEL
# 1       CHINCHAY HABICH, FIORELLA ALEXANDRA    PINCHI MOREY, CINTHYA VALERIA
# 2               RAMIREZ GOMERO, VIVIAN RUTH      HERRERA ALCOCER, MARIA INES
# 3          MENCHOLA GUERRERO, JULISSA ELENA  SÁNCHEZ PRIETO, FERNANDO ALONSO
#
#                                                                         \
# Grupos                          Grupo 11                      Grupo 12
# order
# 0       FLOREZ OKUMURA, LEONARDO ANTONIO    SORIA PEÑA, CARLOS ALFREDO
# 1                    MORRO MUÑOZ, AURI W            MOLLA LEON, WALTER
# 2                   HUAMAN LOAYZA, GUIDO  CAJAS FALCÓN, ALONDRA NICOLE
# 3                  TOLEDO RENGIFO, NURIA  PANDO PILCO, MARTIN DE JESUS
#
#                                                                              \
# Grupos                            Grupo 13                          Grupo 2
# order
# 0                  DIAZ GONZALES, EMMANUEL     TITO SANTA CRUZ, KERLY MABEL
# 1       ALARCON GUTIERREZ, EDUARDO BASILIO           MEZA VASQUEZ, MILAGROS
# 2               ABURTO CAMACLLANQUI, ELÍAS     REYNA NIEVA, GINO SALVATTORE
# 3                  SANTANDER ALVA, DANIELA  ARISTA APARI, SERGHI GIANFRANCO
#
#                                             \
# Grupos                             Grupo 3
# order
# 0                CORDOVA GAMBOA, ANA PAOLA
# 1       GAVILAN CASTAÑEDA, MAYRA ALEXANDRA
# 2                     RIVAS SU, JUAN DIEGO
# 3            AVILES ELIAS, GABRIEL MARCIAL
#
#                                                  \
# Grupos                                  Grupo 4
# order
# 0                ZUÑIGA ROMERO, ADRIANA VIOLETA
# 1            PLASENCIA CUSTODIO, CLAUDIA JIMENA
# 2       ECHEVARRIA CARHUANCHO, FRANCISCO ANDRES
# 3                 VERA ROMAN, JOSSELYNE ANTUANE
#
#                                                                           \
# Grupos                          Grupo 5                          Grupo 6
# order
# 0          MIÑAN SANCHEZ, LUIS FERNANDO   QUISPE MACAVILCA, LUIS CLAUDIO
# 1         HUAMAN GARCIA, YANELL VALERYN  VENERO ACURIO, MARIA DEL CARMEN
# 2          PASAPERA OROZCO, OSMAN ALDER      DELGADO DIAZ, DIEGO GONZALO
# 3       FLORES GOICOCHEA, DANIELA SOFIA  CANELO CASTILLO, GONZALO ANDRES
#
#                                              \
# Grupos                              Grupo 7
# order
# 0       RAMIREZ DE LA CRUZ, KELLY GUADALUPE
# 1                ZAPATA ROJAS, ALVARO DANTE
# 2        REMUZGO MELENDEZ, CARMEN ELIZABETH
# 3                    VELAZCO MUÑOZ, ANAMILE
#
#
# Grupos                             Grupo 8                             Grupo 9
# order
# 0          BENITES GARNIQUE, JOSUE MARCIAL          MONTJOY PITA, DANIEL GERAY
# 1       SUAREZ PATILONGO, MICHAEL SALVADOR         VISURRAGA RODIL, JOEL ANDRE
# 2               SILVA ZARATE, CECILIA ISAI  SALAZAR RODRIGUEZ, MATTIAS GUSTAVO
# 3       TORREJON MAGUIÑA, CLAUDIA FIORELLA     RIVAS MADUEÑO, MAURICIO RICARDO

# %%
col1, col2 = zip(*groups.columns)

# %%
groups.columns = list(col2)

# %%
groups
# Out:
#                                    Grupo 1                         Grupo 10  \
# order
# 0             ORTIZ PAREDES, CÉSAR MARCELO      CALDERON NEYRA, JOSE DANIEL
# 1      CHINCHAY HABICH, FIORELLA ALEXANDRA    PINCHI MOREY, CINTHYA VALERIA
# 2              RAMIREZ GOMERO, VIVIAN RUTH      HERRERA ALCOCER, MARIA INES
# 3         MENCHOLA GUERRERO, JULISSA ELENA  SÁNCHEZ PRIETO, FERNANDO ALONSO
#
#                                Grupo 11                      Grupo 12  \
# order
# 0      FLOREZ OKUMURA, LEONARDO ANTONIO    SORIA PEÑA, CARLOS ALFREDO
# 1                   MORRO MUÑOZ, AURI W            MOLLA LEON, WALTER
# 2                  HUAMAN LOAYZA, GUIDO  CAJAS FALCÓN, ALONDRA NICOLE
# 3                 TOLEDO RENGIFO, NURIA  PANDO PILCO, MARTIN DE JESUS
#
#                                  Grupo 13                          Grupo 2  \
# order
# 0                 DIAZ GONZALES, EMMANUEL     TITO SANTA CRUZ, KERLY MABEL
# 1      ALARCON GUTIERREZ, EDUARDO BASILIO           MEZA VASQUEZ, MILAGROS
# 2              ABURTO CAMACLLANQUI, ELÍAS     REYNA NIEVA, GINO SALVATTORE
# 3                 SANTANDER ALVA, DANIELA  ARISTA APARI, SERGHI GIANFRANCO
#
#                                   Grupo 3  \
# order
# 0               CORDOVA GAMBOA, ANA PAOLA
# 1      GAVILAN CASTAÑEDA, MAYRA ALEXANDRA
# 2                    RIVAS SU, JUAN DIEGO
# 3           AVILES ELIAS, GABRIEL MARCIAL
#
#                                        Grupo 4  \
# order
# 0               ZUÑIGA ROMERO, ADRIANA VIOLETA
# 1           PLASENCIA CUSTODIO, CLAUDIA JIMENA
# 2      ECHEVARRIA CARHUANCHO, FRANCISCO ANDRES
# 3                VERA ROMAN, JOSSELYNE ANTUANE
#
#                                Grupo 5                          Grupo 6  \
# order
# 0         MIÑAN SANCHEZ, LUIS FERNANDO   QUISPE MACAVILCA, LUIS CLAUDIO
# 1        HUAMAN GARCIA, YANELL VALERYN  VENERO ACURIO, MARIA DEL CARMEN
# 2         PASAPERA OROZCO, OSMAN ALDER      DELGADO DIAZ, DIEGO GONZALO
# 3      FLORES GOICOCHEA, DANIELA SOFIA  CANELO CASTILLO, GONZALO ANDRES
#
#                                    Grupo 7  \
# order
# 0      RAMIREZ DE LA CRUZ, KELLY GUADALUPE
# 1               ZAPATA ROJAS, ALVARO DANTE
# 2       REMUZGO MELENDEZ, CARMEN ELIZABETH
# 3                   VELAZCO MUÑOZ, ANAMILE
#
#                                   Grupo 8                             Grupo 9
# order
# 0         BENITES GARNIQUE, JOSUE MARCIAL          MONTJOY PITA, DANIEL GERAY
# 1      SUAREZ PATILONGO, MICHAEL SALVADOR         VISURRAGA RODIL, JOEL ANDRE
# 2              SILVA ZARATE, CECILIA ISAI  SALAZAR RODRIGUEZ, MATTIAS GUSTAVO
# 3      TORREJON MAGUIÑA, CLAUDIA FIORELLA     RIVAS MADUEÑO, MAURICIO RICARDO

# %%
data1.loc[:, : ].to_excel(r"C:\Users\Anzony\Downloads/alumnos_diplomado.xlsx", index = False )

# %%
groups.to_html( r"../_data/groups2023.html", index = False )

# %%
groups.iloc[:, :].to_html( r"C:\Users\Anzony\Documents\GitHub\Diplomado_PUCP/groups2022_2_pt2.html", index = False )

# %%
groups
# Out:
#                                 Grupo 1                      Grupo 2  \
# order
# 0      ORELLANA QUISPE, CRISTIAN NASSER  SUAÑA ZEGARRA, ADRIAN ANDRE
# 1        CAMACHO GAVIDIA, ABEL FERNANDO    LAMA MAVILA, HECTOR ANDRE
# 2         TINTAYA ORIHUELA, MEIR ALVARO         MEZA HINOJO, GUSTAVO
# 3              PALOMINO SEGUÍN, AFRANIA        JACOBS LUQUE, NICOLAS
#
#                                Grupo 3                              Grupo 4  \
# order
# 0          VIDAL VIDAL, ROCIO GABRIELA       CALDAS VELASQUEZ, JOSUE DANIEL
# 1               BOYCO ORAMS, ALEJANDRO      SALAS NUÑEZ BORJA, FABIO MANUEL
# 2      RIEGA ESCALANTE, STEPHY ROSARIO  CALVO PORTOCARRERO, GABRIELA ISABEL
# 3          PEREZ GONZALES, JUAN CARLOS        IBAÑEZ ABANTO, ANGEL MAURICIO
#
#                               Grupo 5                             Grupo 6
# order
# 0         MELÉNDEZ APONTE, JUAN DIEGO  INGARUCA RIVERA, GRETTEL ALEXANDRA
# 1             CRISTIAN SERRANO, ARONE  HUERTA ESPINOZA, YAJAIRA ALEXANDRA
# 2          NÚÑEZ HUAMÁN, CÉSAR AGUSTO      HUANCA MARTINEZ, JORGE ALBERTO
# 3      SOTO PACHERRES, RODRIGO FRANCO
