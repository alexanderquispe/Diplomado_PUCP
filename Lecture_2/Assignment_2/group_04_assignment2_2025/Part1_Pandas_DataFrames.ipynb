# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\santi\OneDrive\Desktop\Python\Enaho01A-2023-300.csv",encoding="ISO-8859-10",low_memory=False)

# %%
#Read and display the first 5 rows.
df.head()
# Out:
#     AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  ESTRATO  \
# 0  2023    1      5030         2     11         1   10201        7        4
# 1  2023    1      5030         2     11         2   10201        7        4
# 2  2023    1      5030         2     11         3   10201        7        4
# 3  2023    1      5030         2     11         4   10201        7        4
# 4  2023    1      5030        11     11         1   10201        7        4
#
#    CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C I315B    FACTOR07  \
# 0         1  ...                                                  118.374542
# 1         2  ...                                                  118.374542
# 2         2  ...                                                  118.374542
# 3         2  ...                          8                       118.374542
# 4         1  ...                                                  118.374542
#
#     FACTORA07 NCONGLOME SUB_CONGLOME
# ...

# %%
#Convert the column names into a list and print it.
column_list = df.columns.tolist()
print(column_list)
# Out:
# ['AÑO', 'MES', 'CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO', 'UBIGEO', 'DOMINIO', 'ESTRATO', 'CODINFOR', 'P300N', 'P300I', 'P300A', 'P301A', 'P301B', 'P301C', 'P301D', 'P301A0', 'P301A1', 'P301B0', 'P301B1', 'P301B3', 'P302', 'P302X', 'P302A', 'P302B', 'P303', 'P304A', 'P304B', 'P304C', 'P304D', 'P305', 'P306', 'P307', 'P307A1', 'P307A2', 'P307A3', 'P307A4', 'P307A4_5', 'P307A4_6', 'P307A4_7', 'P307B1', 'P307B2', 'P307B3', 'P307B4', 'P307B4_5', 'P307B4_6', 'P307B4_7', 'P307C', 'P308A', 'P308B', 'P308C', 'P308D', 'P308B1', 'P308B2', 'P308B3', 'P308B4', 'P308B5', 'P308C1', 'P308C2', 'P310', 'P310B1', 'P310C0', 'P310C1', 'P310D1', 'P310D2', 'P310E0', 'P310E1', 'P310E3', 'P311N$1', 'P311N$2', 'P311N$3', 'P311N$4', 'P311N$5', 'P311N$6', 'P311N$7', 'P311N$8', 'P311N$9', 'P311$1', 'P311$2', 'P311$3', 'P311$4', 'P311$5', 'P311$6', 'P311$7', 'P311$8', 'P311$9', 'P311A1$1', 'P311A1$2', 'P311A1$3', 'P311A1$4', 'P311A1$5', 'P311A1$6', 'P311A1$7', 'P311A1$8', 'P311A1$9', 'P311A2$1', 'P311A2$2', 'P
# ...

# %%
#Check the data types of the DataFrame.
print(df.dtypes)
# Out:
# AÑO               int64
# MES               int64
# CONGLOME          int64
# VIVIENDA          int64
# HOGAR             int64
#                  ...
# I315B            object
# FACTOR07        float64
# FACTORA07       float64
# NCONGLOME         int64
# SUB_CONGLOME      int64
# Length: 511, dtype: object

# %%
#Select a subsample containing the variables ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO'] and between 3–5 additional variables of your interest.
required_variables = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO']
selected_variables = ['P300A','P302X','P308A','P308B3','P308B4']

both_variables = required_variables + selected_variables

# %%
subsample = df[both_variables]
subsample
# Out:
#         CONGLOME  VIVIENDA  HOGAR  CODPERSO  P300A P302X P308A P308B3 P308B4
# 0           5030         2     11         1      4
# 1           5030         2     11         2      4
# 2           5030         2     11         3      4
# 3           5030         2     11         4      8
# 4           5030        11     11         1      4
# ...          ...       ...    ...       ...    ...   ...   ...    ...    ...
# 108349     20670        67     11         5      4
# 108350     20670        68     11         1      4
# 108351     20670        69     11         1      4     1
# 108352     20670        69     11         2      4
# 108353     20670        69     11         3      4
#
# [108354 rows x 9 columns]

# %%
#Explore the DataFrame using summary functions.
df.describe()
# Out:
#             AÑO            MES       CONGLOME       VIVIENDA          HOGAR  \
# count  108354.0  108354.000000  108354.000000  108354.000000  108354.000000
# mean     2023.0       6.495127   16944.756797      77.820330      11.146271
# std         0.0       3.445244    3144.386733      68.547022       1.370084
# min      2023.0       1.000000    5007.000000       1.000000      11.000000
# 25%      2023.0       3.000000   16028.000000      31.000000      11.000000
# 50%      2023.0       7.000000   17500.000000      66.000000      11.000000
# 75%      2023.0       9.000000   19014.000000     106.000000      11.000000
# max      2023.0      12.000000   21001.000000     991.000000      44.000000
#
#             CODPERSO         UBIGEO        DOMINIO        ESTRATO  \
# count  108354.000000  108354.000000  108354.000000  108354.000000
# mean        2.546293  131185.171087       4.864961       4.138961
# std         1.577737   67736.903764       2.404443       2.432348
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          AÑO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# 108352  2023   12     20670        69     11         2   10503        4
# 108353  2023   12     20670        69     11         3   10503        4
#
# ...

# %%
df.shape
# Out:
# (108354, 511)

# %%
#Identify if there are missing values.
missing_values = subsample.isnull().sum().sum()
missing_values
# Out:
# 0

# %%
subsample
# Out:
#         CONGLOME  VIVIENDA  HOGAR  CODPERSO  P300A P302X P308A P308B3 P308B4
# 0           5030         2     11         1      4
# 1           5030         2     11         2      4
# 2           5030         2     11         3      4
# 3           5030         2     11         4      8
# 4           5030        11     11         1      4
# ...          ...       ...    ...       ...    ...   ...   ...    ...    ...
# 108349     20670        67     11         5      4
# 108350     20670        68     11         1      4
# 108351     20670        69     11         1      4     1
# 108352     20670        69     11         2      4
# 108353     20670        69     11         3      4
#
# [108354 rows x 9 columns]

# %%
missing_codes = ["99", "9"," ",]
subsample_clean = subsample.replace(missing_codes, np.nan)
subsample_clean
# Out:
#         CONGLOME  VIVIENDA  HOGAR  CODPERSO  P300A P302X P308A P308B3 P308B4
# 0           5030         2     11         1      4   NaN   NaN    NaN    NaN
# 1           5030         2     11         2      4   NaN   NaN    NaN    NaN
# 2           5030         2     11         3      4   NaN   NaN    NaN    NaN
# 3           5030         2     11         4      8   NaN   NaN    NaN    NaN
# 4           5030        11     11         1      4   NaN   NaN    NaN    NaN
# ...          ...       ...    ...       ...    ...   ...   ...    ...    ...
# 108349     20670        67     11         5      4   NaN   NaN    NaN    NaN
# 108350     20670        68     11         1      4   NaN   NaN    NaN    NaN
# 108351     20670        69     11         1      4     1   NaN    NaN    NaN
# 108352     20670        69     11         2      4   NaN   NaN    NaN    NaN
# 108353     20670        69     11         3      4   NaN   NaN    NaN    NaN
#
# [108354 rows x 9 columns]

# %%
subsample_clean.isnull().sum()
# Out:
# CONGLOME        0
# VIVIENDA        0
# HOGAR           0
# CODPERSO        0
# P300A           0
# P302X       93236
# P308A       77350
# P308B3      80858
# P308B4      86098
# dtype: int64

# %%
subsample_dropna = subsample_clean.dropna()
subsample_dropna
# Out:
#         CONGLOME  VIVIENDA  HOGAR  CODPERSO  P300A P302X P308A P308B3 P308B4
# 27518       8210        67     13         4      4     3     2      3      3
# 30927      17076        37     11         2      4     3     2      3      3
# 39132      16559         3     11         3      4     3     2      3      3
# 40170      17213         1     11         3      4     2     2      3      3
# 44987      20572        32     11         2      4     1     2      3      3
# 45496       7709        12     11         5      4     3     2      3      3
# 45767      10293        96     11         3     13     3     2      3      3
# 49565      17419        43     11         7      4     1     2      4      3
# 50768      18226        32     11         2      4     1     2      3      3
# 52852      19734        92     11         2      4     2     2      3      5
# 53398      20110        38     11         3      4     2     7      3      3
# ...

# %%
df2 = pd.read_csv(r"C:\Users\santi\OneDrive\Desktop\Python\Enaho01A-2023-300.csv", encoding = "ISO-8859-10", low_memory = False)
df2
# Out:
#          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# 108352  2023   12     20670        69     11         2   10503        4
# 108353  2023   12     20670        69     11         3   10503        4
#
#         ESTRATO  CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C  \
# ...

# %%
#Display the first 5 rows.
df2.head()
# Out:
#     AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  ESTRATO  \
# 0  2023    1      5030         2     11         1   10201        7        4
# 1  2023    1      5030         2     11         2   10201        7        4
# 2  2023    1      5030         2     11         3   10201        7        4
# 3  2023    1      5030         2     11         4   10201        7        4
# 4  2023    1      5030        11     11         1   10201        7        4
#
#    CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C I315B    FACTOR07  \
# 0         1  ...                                                  118.374542
# 1         2  ...                                                  118.374542
# 2         2  ...                                                  118.374542
# 3         2  ...                          8                       118.374542
# 4         1  ...                                                  118.374542
#
#     FACTORA07 NCONGLOME SUB_CONGLOME
# ...

# %%
#Convert the column names into a list and print it.
column2_list = df2.columns.tolist()
print(column_list)
# Out:
# ['AÑO', 'MES', 'CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO', 'UBIGEO', 'DOMINIO', 'ESTRATO', 'CODINFOR', 'P300N', 'P300I', 'P300A', 'P301A', 'P301B', 'P301C', 'P301D', 'P301A0', 'P301A1', 'P301B0', 'P301B1', 'P301B3', 'P302', 'P302X', 'P302A', 'P302B', 'P303', 'P304A', 'P304B', 'P304C', 'P304D', 'P305', 'P306', 'P307', 'P307A1', 'P307A2', 'P307A3', 'P307A4', 'P307A4_5', 'P307A4_6', 'P307A4_7', 'P307B1', 'P307B2', 'P307B3', 'P307B4', 'P307B4_5', 'P307B4_6', 'P307B4_7', 'P307C', 'P308A', 'P308B', 'P308C', 'P308D', 'P308B1', 'P308B2', 'P308B3', 'P308B4', 'P308B5', 'P308C1', 'P308C2', 'P310', 'P310B1', 'P310C0', 'P310C1', 'P310D1', 'P310D2', 'P310E0', 'P310E1', 'P310E3', 'P311N$1', 'P311N$2', 'P311N$3', 'P311N$4', 'P311N$5', 'P311N$6', 'P311N$7', 'P311N$8', 'P311N$9', 'P311$1', 'P311$2', 'P311$3', 'P311$4', 'P311$5', 'P311$6', 'P311$7', 'P311$8', 'P311$9', 'P311A1$1', 'P311A1$2', 'P311A1$3', 'P311A1$4', 'P311A1$5', 'P311A1$6', 'P311A1$7', 'P311A1$8', 'P311A1$9', 'P311A2$1', 'P311A2$2', 'P
# ...

# %%
#Check the data types.
print(df2.dtypes)
# Out:
# AŅO               int64
# MES               int64
# CONGLOME          int64
# VIVIENDA          int64
# HOGAR             int64
#                  ...
# I315B            object
# FACTOR07        float64
# FACTORA07       float64
# NCONGLOME         int64
# SUB_CONGLOME      int64
# Length: 511, dtype: object

# %%
#Select a subsample containing the variables ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO'] and between 3–5 additional variables of your interest.
required2_variables = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO']
selected2_variables = ['P300N', 'P300I', 'P300A', 'P301A', 'P301B']

both2_variables = required_variables + selected_variables

# %%
subsample2 = df[both2_variables]

# %%
#Change the data type of a variable (e.g., from text to numeric).
df2["P301A"] = df2['P301A'].astype(str)

# %%
print(df2['P301A'].dtype)
# Out:
# object

# %%
#Modify some values in a specific column.
df2["MES"].replace({
    1: "Enero",
    2: "Febrero",
    3: "Marzo",
    4: "Abril",
    5: "Mayo",
    6: "Junio",
    7: "Julio",
    8: "Agosto",
    9: "Septiembre",
    10: "Octubre",
    11: "Noviembre",
    12: "Diciembre"
})
df2["MES"]
# Out:
# 0             Enero
# 1             Enero
# 2             Enero
# 3             Enero
# 4             Enero
#             ...
# 108349    Diciembre
# 108350    Diciembre
# 108351    Diciembre
# 108352    Diciembre
# 108353    Diciembre
# Name: MES, Length: 108354, dtype: object

# %%
common_columns = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO']

# %%
#Merging Datasets
merge = subsample.merge(subsample2, on = common_columns, how = "inner")

# %%
merge.head()
# Out:
#    CONGLOME  VIVIENDA  HOGAR  CODPERSO  P300A_x P302X_x P308A_x P308B3_x  \
# 0      5030         2     11         1        4
# 1      5030         2     11         2        4
# 2      5030         2     11         3        4
# 3      5030         2     11         4        8
# 4      5030        11     11         1        4
#
#   P308B4_x  P300A_y P302X_y P308A_y P308B3_y P308B4_y
# 0                 4
# 1                 4
# 2                 4
# 3                 8
# 4                 4

# %%
#Group the data by a variable of your choice using groupby().
merge.groupby("CONGLOME")["P300A_x"].value_counts().reset_index()
# Out:
#       CONGLOME  P300A_x  count
# 0         5007        4      4
# 1         5027        4     19
# 2         5030        4     17
# 3         5030        8      1
# 4         5039        4     12
# ...        ...      ...    ...
# 9098     20669        4     14
# 9099     20669        1      5
# 9100     20670        4     22
# 9101     21001        2     19
# 9102     21001        4      5
#
# [9103 rows x 3 columns]
