# %%
# Group_11
#Members:
#1. Roy Rojas
#2. Claudia Cordova
#3. Zuly Cruz
#4. Reynaldo Padilla
#5. Karen Salazar
#6. Luis Camarena

# %% [markdown]
# # 1 Assignment
#
# It is totally prohibited to use any kind of loop. You can use stackoverflow. If you copy codes from previous answers, explain each step. No explanation is `0 points`.

# %% [markdown]
# ## 1.1 Tuple
#
#
#
# 1. Print the first item of the second item of `tuple1` object. **Hint: Use indexing**<br><br>
# 2. Print the last item of the `tuple1` object.**Hint: Use indexing**<br><br>
# 3. Change the value "orange" for "pink grapefruit". Comment the output. **Hint: Is it possible?** <br><br>
# 4. Print the length of `tuple1`. **Hint: Length function**<br><br>
# 5. Sum all the elements of tuple2 and describe your steps and explain each of them. **Hint: Use `map` function.**<br><br>
# 6. Generate a new tuple object named as `tuple3` with the half values of `tuple2`. This tuple should be similar as `tuple2`, tuple of lists.  **Hint: Use `map` funciont.**<br><br>

# %%
tuple1 = ("Orange", [10, 20, 30], (5, 15, 25))
tuple2 = ([7, 8], [9, 1], [10, 7])

# %%
#Claudia Córdova

# %%
#1.Tuple exercises: Print first item of the second item
tuple1[1][0]
# Out:
# 10

# %%
#2.Print the last item of the tuple1 object
tuple1[-1]
# Out:
# (5, 15, 25)

# %%
#3.Change the value "orange" for "pink grapefruit". Comment the output. Hint: Is it possible?
tuple1[0]="pink grapefruit"  #It is not possible to change values to tupla object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Change the value "orange" for "pink grapefruit". Comment the output. Hint: Is it possible?
# ----> 2 tuple1[0]="pink grapefruit"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Roy Rojas

# %%
#4.Print the length of tuple1
len(tuple1)
# Out:
# 3

# %%
#5.Sum all the elements of tuple2 and describe your steps and explain each of them
tuple2 = ([7, 8], [9, 1], [10, 7])

from itertools import chain
# Given tuple
tuple2 = ([7, 8], [9, 1], [10, 7])

# Flatten the tuple into a single iterable
flattened_iterable = chain.from_iterable(tuple2)

# Convert the iterable to a list
flattened_list = list(flattened_iterable)

# Sum all elements in the list
total_sum = sum(flattened_list)

print(total_sum)
# Out:
# 42

# %%
#6.Generate a new tuple object named as tuple3 with the half values of tuple2. This tuple should be similar as tuple2, tuple of lists
# Given tuple
tuple2 = ([7, 8], [9, 1], [10, 7])
# Define a function to halve each element
def halve_elements(lst):
    return list(map(lambda x: x / 2, lst))
# Apply the function to each list in the tuple
tuple3 = tuple(map(halve_elements, tuple2))
print(tuple3)
# Out:
# ([3.5, 4.0], [4.5, 0.5], [5.0, 3.5])

# %% [markdown]
# ## 1.2 Lists
# 1. Show the indices of the `np.nan` values  in the `f_list` list. We want to see this output: `The indices 0, 1, 4, 7 have np.nan values.` **Hint: Use print function and [f-strings](https://realpython.com/python-f-strings/) to insert the indices values.**<br><br>
#
# 2. Replicate 4 times the values of the list `p2_list`. We expect an ouput like this: `[ 2 , 3, 4, 5, 2 , 3, 4, 5, 2 , 3, 4, 5, 2 , 3, 4, 5]`.  **Hint: Use multiplication function in `lists`and see the output.**<br><br>
# 3. Print the length of `f_list`. **Hint: Length function**<br><br>
# 4. Print `My teacher assistant is so boring.` using `text1` list. **Hint: Use the [`join` function](https://stackoverflow.com/questions/493819/why-is-it-string-joinlist-instead-of-list-joinstring)**<br><br>
# 5. Print `My TA is so boring, but is very funny.` using `text1` list.**Hint: Use the `join` function, and `extend` method.**<br><br>
# 6. Print <br>
# `The max value of values1 is 86 and is located in the 0 index. ` <br>
# `The min value of values1 is 0 and is located in the 7 index. ` <br> **Hint: Use the `f-string`, `min`, and `max` functions.**
# <br>
# 7. Get two lists: `names` and `last_names` using `last_and_name` list. **Hint: Use `map` and `split`.**
# <br>
# 8. Give only the last names of students who do not have email. Use the `emails` and `last_names` listt. **Hint: Use `map` and `split`.**
# <br>

# %%
#Reynaldo Padilla

# %%
#List exercises, from 1 to 4

# %%
# 1. Show the indices of the np.nan values in the f_list list. 

# indices of np.nan values
nan_indices = [index for index, value in enumerate(f_list) if isinstance(value, float) and np.isnan(value)]

# print the result
print(f"Los indices {', '.join(map(str, nan_indices))} have np.nan values.")
# Out:
# Los indices 0, 1, 4, 7 have np.nan values.

# %%
# 2. Replicate 4 times the values of the list p2_list

# we replicate the list 4 times
replicated_list = p2_list * 4

# we print the result
print(replicated_list)
# Out:
# [2, 3, 4, 5, 2, 3, 4, 5, 2, 3, 4, 5, 2, 3, 4, 5]

# %%
# 3. Print the length of f_list

lenght = len(f_list)

print(lenght)
# Out:
# 8

# %%
# 4. Print My teacher assistant is so boring. using text1 list
all_together = " ".join(text1)

print(all_together)
# Out:
# My teacher assistant is so boring.

# %%
#Zuly Cruz Asto

# %%
#5. Print My TA is so boring, but is very funny. using text1 list.
#First, we defined the complement of the sentence
text2 = [ ',', 'but', 'is', 'very', 'funny.']

#Then we use the function extend and we join the texts
text1.extend(text2)
final= " ".join(text1)

#We print the results
print(final)
# Out:
# My teacher assistant is so boring. , but is very funny.

# %%
#6. Print The max value of values1 is 86 and is located in the 0 index. The min value of values1 is 0 and is located in the 7 index. 
#Using the max and min functions
max_value = max(values1)
max_index = values1.index(max_value)
min_value = min(values1)
min_index = values1.index(min_value)

#Print
print(f"The max value of values1 is {max_value} and is located in the {max_index} index.")
print(f"The min value of values1 is {min_value} and is located in the {min_index} index.")
# Out:
# The max value of values1 is 86 and is located in the 0 index.
# The min value of values1 is 0 and is located in the 7 index.

# %%
#7. Get two lists: names and last_names using last_and_name list.
# First, we extract last names and names
last_names, names = zip(*map(lambda x: x.split(", "), last_and_name))

# Then, we convert the tuples to get the two lists
last_names = list(last_names)
names = list(names)

# Finally, we print the results
print("Last Names:")
print(last_names)
print("\nNames:")
print(names)
# Out:
# Last Names:
# ['CORNEJO SANCHEZ', 'ORELLANA QUISPE', 'MORALES CHOQUEHUANCA', 'GUIMARAY RIBEYRO', 'CAMACHO GAVIDIA', 'TINTAYA ORIHUELA', 'CHAVEZ MARTINEZ', 'FIGUEROA MURO', 'GOMEZ CRIBILLERO', 'PALOMINO SEGUÍN', 'LUZON CUEVA', 'SUAÑA ZEGARRA', 'SOTO POMACHAGUA', 'FIORENTINO MARTINEZ', 'LAMA MAVILA', 'MEZA HINOJO', 'LOZADA MURILLO', 'ZAMBRANO JIMENEZ', 'JACOBS LUQUE', 'VIDAL VIDAL', 'TORRES ANICAMA', 'LOPEZ ESTRADA', 'BOYCO ORAMS', 'DIAZ BERROSPI', 'RIEGA ESCALANTE', 'LEVANO TORRES', 'ESQUIVES BRAVO', 'PEREZ GONZALES', 'OTERO MAGUIÑA', 'CLAVO CAMPOS', 'AGUILAR GARCIA', 'CALDAS VELASQUEZ', 'SALAS NUÑEZ BORJA', 'PIZARRO VILLANES', 'QUILLATUPA MORALES', 'HUANCAYA IDONE', 'CALVO PORTOCARRERO', 'IBAÑEZ ABANTO', 'MELÉNDEZ APONTE', 'CRISTIAN SERRANO', 'HINOJOSA CAHUANA', 'ANGLAS GARCÍA', 'ALDAVE ACOSTA', 'NÚÑEZ HUAMÁN', 'OBREGON HUAMAN', 'SOTO PACHERRES', 'INGARUCA RIVERA', 'ROJAS HUAMAN', 'NEYRA SALAS', 'HUERTA ESPINOZA', 'HUANCA MARTINEZ', 'FLORES CADILLO']
#
# Names:
# ...

# %%
#8. Give only the last names of students who do not have email. Use the emails and last_names list. 
#Extract last names of students 
last_names = list(map(lambda x: x.split(", ")[0], last_and_name))

# Get the indices of missing emails
missing_email_ = [i for i, email in enumerate(emails) if email == ""]

# Extract last names for students without emails
last_names_missing_email = [last_names[i] for i in missing_email_]

# Print the result
print("Last names of students who do not have an email:")
print(last_names_missing_email)
# Out:
# Last names of students who do not have an email:
# ['HUANCAYA IDONE', 'CALVO PORTOCARRERO', 'IBAÑEZ ABANTO', 'MELÉNDEZ APONTE', 'CRISTIAN SERRANO', 'ANGLAS GARCÍA', 'ALDAVE ACOSTA', 'NÚÑEZ HUAMÁN', 'OBREGON HUAMAN', 'SOTO PACHERRES', 'INGARUCA RIVERA', 'ROJAS HUAMAN', 'NEYRA SALAS', 'HUERTA ESPINOZA', 'HUANCA MARTINEZ']

# %%
import numpy as np

# %%
f_list = [np.nan , np.nan, "Austria", "Germany", np.nan, "Pakistan", "np.nan", np.nan ]

# %%
text1 = ['My', 'teacher', 'assistant', 'is', 'so', 'boring.']

# %%
p2_list = [ 2 , 3, 4, 5 ]

# %%
values1 = [ 86, 86, 85, 85, 85, 83, 23, 0, 84, 1 ]

# %%
# These two lists a
last_and_name = [ "CORNEJO SANCHEZ, CHRISTIAN SANTOS", "ORELLANA QUISPE, CRISTIAN NASSER", "MORALES CHOQUEHUANCA, ANGELICA KARINA", "GUIMARAY RIBEYRO, JOSE ROBERTO", "CAMACHO GAVIDIA, ABEL FERNANDO", "TINTAYA ORIHUELA, MEIR ALVARO", "CHAVEZ MARTINEZ, JOSELIN ALEXANDRA", "FIGUEROA MURO, LEONEL ARTURO", "GOMEZ CRIBILLERO, JOSE FELIPE", "PALOMINO SEGUÍN, AFRANIA", "LUZON CUEVA, BIANCA MARIETTE", "SUAÑA ZEGARRA, ADRIAN ANDRE", "SOTO POMACHAGUA, DORKAS YOMIRA JHERMY", "FIORENTINO MARTINEZ, LADY ALY", "LAMA MAVILA, HECTOR ANDRE", "MEZA HINOJO, GUSTAVO", "LOZADA MURILLO, PERSEO MARCELO", "ZAMBRANO JIMENEZ, MIGUEL ALONZO", "JACOBS LUQUE, NICOLAS", "VIDAL VIDAL, ROCIO GABRIELA", "TORRES ANICAMA, JANE CAMILA", "LOPEZ ESTRADA, MARIA ELISA", "BOYCO ORAMS, ALEJANDRO", "DIAZ BERROSPI, KARLINE ROSMELI", "RIEGA ESCALANTE, STEPHY ROSARIO", "LEVANO TORRES, VALERIA CECILIA", "ESQUIVES BRAVO, SEBASTIAN RENATO", "PEREZ GONZALES, JUAN CARLOS", "OTERO MAGUIÑA, MARIANA", "CLAVO CAMPOS, ANDREA BRIZETH", "AGUILAR GARCIA, ERICK JOSUE", "CALDAS VELASQUEZ, JOSUE DANIEL", "SALAS NUÑEZ BORJA, FABIO MANUEL", "PIZARRO VILLANES, FERNANDA NICOLLE", "QUILLATUPA MORALES, ANGELA ADELINA", "HUANCAYA IDONE, CESAR DANTE", "CALVO PORTOCARRERO, GABRIELA ISABEL", "IBAÑEZ ABANTO, ANGEL MAURICIO", "MELÉNDEZ APONTE, JUAN DIEGO", "CRISTIAN SERRANO, ARONE", "HINOJOSA CAHUANA, PERCY ALBERTH", "ANGLAS GARCÍA, KEVIN ARTURO", "ALDAVE ACOSTA, CESAR ERNESTO", "NÚÑEZ HUAMÁN, CÉSAR AGUSTO", "OBREGON HUAMAN, DIANA EDITH", "SOTO PACHERRES, RODRIGO FRANCO", "INGARUCA RIVERA, GRETTEL ALEXANDRA", "ROJAS HUAMAN, ROSA ANGELA", "NEYRA SALAS, DANTE OMAR", "HUERTA ESPINOZA, YAJAIRA ALEXANDRA", "HUANCA MARTINEZ, JORGE ALBERTO", "FLORES CADILLO, ALEXIS" ]
emails = ["cscornejo@pucp.edu.pe", "orellana.cn@pucp.edu.pe", "karina.morales@pucp.edu.pe", "a20083223@pucp.pe", "abel.camacho@pucp.pe", "mtintaya@pucp.edu.pe", "joselin.chavez@pucp.edu.pe", "a20105737@pucp.pe", "jfgomezc@pucp.pe", "afrania.palomino@pucp.pe", "luzon.bianca@pucp.pe", "adrian.suanaz@pucp.pe", "soto.y@pucp.edu.pe", "a20132766@pucp.pe", "andre.lama@pucp.edu.pe", "gustavo.meza@pucp.edu.pe", "pmlozada@pucp.edu.pe", "m.zambranoj@pucp.edu.pe", "nicolas.jacobs@pucp.edu.pe", "gvidal@pucp.edu.pe", "jane.torres@pucp.edu.pe", "m.lopez@pucp.edu.pe", "alejandro.boyco@pucp.edu.pe", "a20167070@pucp.edu.pe", "riega.stephy@pucp.edu.pe", "vlevanot@pucp.edu.pe", "sesquives@pucp.edu.pe", "perez.juanc@pucp.edu.pe", "mariana.otero@pucp.edu.pe", "aclavo@pucp.edu.pe", "a20182474@pucp.edu.pe", "josue.caldas@pucp.edu.pe", "fabio.salas@pucp.edu.pe", "fernanda.pizarro@pucp.edu.pe", "aquillatupa@pucp.pe", "", "", "", "", "", "f0873079@pucp.edu.pe", "", "", "", "", "", "", "", "", "", "", "flores.alexis@pucp.edu.pe", ]

# %% [markdown]
# ## 1.3 Strings
#
#
# 1. Drop the duplicated blank spaces in `str1`. Do not use the regular expresions. Do not use the code shown in class. Explain your steps.**Hint: Use `split` method and `join` function.**
#
# 2. Get the number of letters in the string .**Hint: Use `len`function.**
#
# 3. Get the number of blank spaces (all of them) in the string .**Hint: Use `len`function.**
#
# 4. Get the position of `@` in each string in the emails list. **Hint: Use `map`function and `find` method.**
#
# 5. Identifies if exists `.edu.`  in each string in the `emails` list. Get a list of Booleans. **Hint: Use `map`function and `find` method.**
#
# 6. Get all the strings before the first dot `.`in each string in the `emails` list. Identifies how many of them has `@`. **Hint: Use `map`function and `find` method.**

# %%
str1 = 'I am                            too                                                        old'

# %%
emails = ["cscornejo@pucp.edu.pe", "orellana.cn@pucp.edu.pe", "karina.morales@pucp.edu.pe", "a20083223@pucp.pe", "abel.camacho@pucp.pe", "mtintaya@pucp.edu.pe", "joselin.chavez@pucp.edu.pe", "a20105737@pucp.pe", "jfgomezc@pucp.pe", "afrania.palomino@pucp.pe", "luzon.bianca@pucp.pe", "adrian.suanaz@pucp.pe", "soto.y@pucp.edu.pe", "a20132766@pucp.pe", "andre.lama@pucp.edu.pe", "gustavo.meza@pucp.edu.pe", "pmlozada@pucp.edu.pe", "m.zambranoj@pucp.edu.pe", "nicolas.jacobs@pucp.edu.pe", "gvidal@pucp.edu.pe", "jane.torres@pucp.edu.pe", "m.lopez@pucp.edu.pe", "alejandro.boyco@pucp.edu.pe", "a20167070@pucp.edu.pe", "riega.stephy@pucp.edu.pe", "vlevanot@pucp.edu.pe", "sesquives@pucp.edu.pe", "perez.juanc@pucp.edu.pe", "mariana.otero@pucp.edu.pe", "aclavo@pucp.edu.pe", "a20182474@pucp.edu.pe", "josue.caldas@pucp.edu.pe", "fabio.salas@pucp.edu.pe", "fernanda.pizarro@pucp.edu.pe", "aquillatupa@pucp.pe"]

# %%
#Karen Salazar

# %%
#1. Drop the duplicated blank spaces in str1
str1 = 'I am                            too                                                        old'
words = str1.split()
c_str1 = ' '.join(words)
print(c_str1)
# Out:
# I am too old

# %%
#2. Get the number of letters in the string
#We count the number of characters in 'c_str1' after removing all whitespace and calculate the length of the resulting string
num_letters = len(c_str1.replace(' ', '')) 
#Print the results
print(num_letters)
# Out:
# 9

# %%
#3. Get the number of blank spaces (all of them) in the string
#We count the spaces with the count function
num_spaces = c_str1.count(' ')
#Print the results
print(num_spaces)
# Out:
# 3

# %%
#4.Get the position of @ in each string in the emails list
emails = ["cscornejo@pucp.edu.pe", "orellana.cn@pucp.edu.pe", "karina.morales@pucp.edu.pe", "a20083223@pucp.pe", "abel.camacho@pucp.pe", "mtintaya@pucp.edu.pe", "joselin.chavez@pucp.edu.pe", "a20105737@pucp.pe", "jfgomezc@pucp.pe", "afrania.palomino@pucp.pe", "luzon.bianca@pucp.pe", "adrian.suanaz@pucp.pe", "soto.y@pucp.edu.pe", "a20132766@pucp.pe", "andre.lama@pucp.edu.pe", "gustavo.meza@pucp.edu.pe", "pmlozada@pucp.edu.pe", "m.zambranoj@pucp.edu.pe", "nicolas.jacobs@pucp.edu.pe", "gvidal@pucp.edu.pe", "jane.torres@pucp.edu.pe", "m.lopez@pucp.edu.pe", "alejandro.boyco@pucp.edu.pe", "a20167070@pucp.edu.pe", "riega.stephy@pucp.edu.pe", "vlevanot@pucp.edu.pe", "sesquives@pucp.edu.pe", "perez.juanc@pucp.edu.pe", "mariana.otero@pucp.edu.pe", "aclavo@pucp.edu.pe", "a20182474@pucp.edu.pe", "josue.caldas@pucp.edu.pe", "fabio.salas@pucp.edu.pe", "fernanda.pizarro@pucp.edu.pe", "aquillatupa@pucp.pe"]
#We find the position of `@` in each email in the `emails` list.
at_positions = list(map(lambda email: email.find('@'), emails))

#Print the results
print(at_positions)
# Out:
# [9, 11, 14, 9, 12, 8, 14, 9, 8, 16, 12, 13, 6, 9, 10, 12, 8, 11, 14, 6, 11, 7, 15, 9, 12, 8, 9, 11, 13, 6, 9, 12, 11, 16, 11]

# %%
#5.Identifies if exists .edu. in each string in the emails list. Get a list of Booleans. Hint: Use mapfunction and find method.
#We use the function find('edu')!= -1 to check if "edu" is in email, returning "True" or "False"
edu=list(map(lambda email: email.find('edu')!=-1, emails))
print(edu)
# Out:
# [True, True, True, False, False, True, True, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False]

# %%
#6. Get all the strings before the first dot .in each string in the emails list. Identifies how many of them has @. Hint: Use mapfunction and find method.
#Extract substrings before the first period of each email
parts_b = list(map(lambda email: email.split('.')[0], emails))
#Identify how many of those substrings contain '@'
count_at = sum('@' in part for part in parts_b)
print("Substrings before the first dot:", parts_b)
print("Presence of '@' in substrings:", count_at)
# Out:
# Substrings before the first dot: ['cscornejo@pucp', 'orellana', 'karina', 'a20083223@pucp', 'abel', 'mtintaya@pucp', 'joselin', 'a20105737@pucp', 'jfgomezc@pucp', 'afrania', 'luzon', 'adrian', 'soto', 'a20132766@pucp', 'andre', 'gustavo', 'pmlozada@pucp', 'm', 'nicolas', 'gvidal@pucp', 'jane', 'm', 'alejandro', 'a20167070@pucp', 'riega', 'vlevanot@pucp', 'sesquives@pucp', 'perez', 'mariana', 'aclavo@pucp', 'a20182474@pucp', 'josue', 'fabio', 'fernanda', 'aquillatupa@pucp']
# Presence of '@' in substrings: 14

# %% [markdown]
# ## 1.4 Pandas

# %% [markdown]
# 1. Import this dataset new_up_data_sysdif_block_lvl_ver2.csv located in the `_data` folder.
# 2. Import this dataset ESA_CLIMATE_CHANGE_tree_layers.csv located in the `_data` folder.
# 3. Merge both datasets using the key variables `pc11_s_id`,	`pc11_d_id,`	`pc11_sd_id`, `year`.
# 4. Generate a descriptive statistics for `per_TREES-BD`, `per_TREES-BE`, `per_TREES-ND`, `per_TREES-NE`.
# 5. Sum these 4 columns and name the new column as `sum_tree` and get a histogram.
# 6. Generate the histogram of these 4 columns `per_TREES-BD`, `per_TREES-BE`, `per_TREES-ND`, `per_TREES-NE` for the above and below median dataset filtered by the sum_tree variable.
#
# Do not forget to use relative paths.

# %%
#luis Camarena

# %%
#1. Import this dataset new_up_data_sysdif_block_lvl_ver2.csv located in the `_data` folder.
import pandas as pd
df1 = pd.read_csv(r"../../_data/new_up_data_sysdif_block_lvl_ver2.csv")
df1
# Out:
#         pc11_s_id  pc11_d_id  pc11_sd_id  year  post_ror_data_entry_block_any  \
# 0               1          1           1  2000                              0
# 1               1          1           1  2001                              0
# 2               1          1           1  2002                              0
# 3               1          1           1  2003                              0
# 4               1          1           1  2004                              0
# ...           ...        ...         ...   ...                            ...
# 131537          9        202        1012  2018                              1
# 131538          9        202        1012  2019                              1
# 131539          9        202        1012  2020                              1
# 131540          9        202        1012  2021                              1
# 131541          9        202        1012  2022                              1
#
# ...

# %%
#2. Import this dataset ESA_CLIMATE_CHANGE_tree_layers.csv located in the `_data` folder.

# %%
import pandas as pd
df2 = pd.read_csv(r"../../_data/ESA_CLIMATE_CHANGE_tree_layers.csv")

df2
# Out:
#         pc11_s_id  pc11_d_id  pc11_sd_id          sd_name  per_TREES-BD  year  \
# 0              24        468           0  Rann Of Kachchh      0.020038  2006
# 1              24        468        3722          Lakhpat      1.768032  2006
# 2              24        468        3723            Rapar      0.001384  2006
# 3              24        468        3724          Bhachau      0.005311  2006
# 4              24        468        3725            Anjar      0.010257  2006
# ...           ...        ...         ...              ...           ...   ...
# 125344         35        639        5921           Rangat      1.323027  2003
# 125345         35        640        5923       Port Blair      0.000000  2003
# 125346         35        640        5924   Little Andaman      3.892228  2003
# 125347         35        640        5922       Ferrargunj      0.187679  2003
# 125348          1          0           0              NaN      0.134543  2003
#
# ...

# %%
#3.
#Merging both datasets using the key variables `pc11_s_id`,	`pc11_d_id,`	`pc11_sd_id`, `year
merged_df = pd.merge(df1, df2, 
                     on=['pc11_s_id', 'pc11_d_id', 'pc11_sd_id', 'year'])
merged_df
# Out:
#         pc11_s_id  pc11_d_id  pc11_sd_id  year  post_ror_data_entry_block_any  \
# 0               1          1           1  2000                              0
# 1               1          1           1  2001                              0
# 2               1          1           1  2002                              0
# 3               1          1           1  2003                              0
# 4               1          1           1  2004                              0
# ...           ...        ...         ...   ...                            ...
# 125260          9        202        1012  2016                              1
# 125261          9        202        1012  2017                              1
# 125262          9        202        1012  2018                              1
# 125263          9        202        1012  2019                              1
# 125264          9        202        1012  2020                              1
#
# ...

# %%
#4. Generate a descriptive statistics for `per_TREES-BD`, `per_TREES-BE`, `per_TREES-ND`, `per_TREES-NE`.

#Selecting the requested columns
requested_columns = merged_df[['per_TREES-BD', 'per_TREES-BE', 'per_TREES-ND', 'per_TREES-NE']]

#Generating the descriptive statistics of the requested columns
requested_columns.describe()
# Out:
#         per_TREES-BD   per_TREES-BE   per_TREES-ND   per_TREES-NE
# count  125265.000000  125265.000000  125265.000000  125265.000000
# mean        2.346108       4.268641       0.006143       1.974766
# std         5.021063      13.565375       0.148299       6.656288
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.005265       0.000000       0.000000       0.000000
# 50%         0.283303       0.000000       0.000000       0.000000
# 75%         2.236597       0.065836       0.000000       0.037414
# max        48.696053      86.316345      10.135350      55.175827

# %%
# 5 Sum these 4 columns and name the new column as `sum_tree` and get a histogram

#importing Matplot library
import matplotlib.pyplot as plt

#5.1 
#sum of the 4 columns and creating the new column "sum_tree"

merged_df['sum_tree'] = requested_columns.sum(axis=1)
merged_df[['per_TREES-BD', 'per_TREES-BE', 'per_TREES-ND', 'per_TREES-NE','sum_tree']]
# Out:
#         per_TREES-BD  per_TREES-BE  per_TREES-ND  per_TREES-NE   sum_tree
# 0           1.964613      1.117632           0.0     29.015697  32.097942
# 1           1.956872      1.117632           0.0     28.908140  31.982644
# 2           1.969693      1.117632           0.0     28.930830  32.018155
# 3           1.968723      1.117632           0.0     28.954021  32.040376
# 4           1.972254      1.140225           0.0     29.136803  32.249282
# ...              ...           ...           ...           ...        ...
# 125260      0.015884      0.000000           0.0      0.000000   0.015884
# 125261      0.015884      0.000000           0.0      0.000000   0.015884
# 125262      0.015884      0.000000           0.0      0.000000   0.015884
# 125263      0.015884      0.000000           0.0      0.000000   0.015884
# 125264      0.015884      0.000000           0.0      0.000000   0.015884
#
# [125265 rows x 5 columns]

# %%
#5.2
#Generating the requested Histogram
plt.hist(merged_df['sum_tree'],bins=20, edgecolor='black')
plt.title('Histogram 1')
plt.xlabel('Sum')
plt.ylabel('Frecuency')
plt.grid(True)
plt.show()

# %%
# 6. Generate the histogram of these 4 columns `per_TREES-BD`, `per_TREES-BE`, `per_TREES-ND`, `per_TREES-NE` for the above and below median dataset filtered by the sum_tree variable.

#Finding the median of sum_tree
median_sum_tree = df['sum_tree'].median()

#Creating two separated datasets: 'above median' and ´below median'
above_median_df = merged_df[df['sum_tree'] > median_sum_tree]
below_median_df = merged_df[df['sum_tree'] <= median_sum_tree]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 4
#       1 # 6. Generate the histogram of these 4 columns `per_TREES-BD`, `per_TREES-BE`, `per_TREES-ND`, `per_TREES-NE` for the above and below median dataset filtered by the sum_tree variable.
#       2
#       3 #Finding the median of sum_tree
# ----> 4 median_sum_tree = df['sum_tree'].median()
#       6 #Creating two separated datasets: 'above median' and ´below median'
#       7 above_median_df = merged_df[df['sum_tree'] > median_sum_tree]
#
# NameError: name 'df' is not defined

# %%
## RM-Roy Rojas
Good Job. There is only one exercise that has not been answered
