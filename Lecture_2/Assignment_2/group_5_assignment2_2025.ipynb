# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/susanmontalvo/Documents/GitHub/Diplomado_PUCP/Lecture_2/Assignment_2'

# %%
Enaho01A=pd.read_csv("/Users/susanmontalvo/Desktop/ENAHO-2023/Enaho01A-2023-300.csv", encoding="ISO-8859-10")
Enaho01A
# Out:
# /var/folders/xq/9y7gptwn01s29w73bn8qj9c40000gn/T/ipykernel_1995/3117440273.py:1: DtypeWarning: Columns (26,32,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   Enaho01A=pd.read_csv("/Users/susanmontalvo/Desktop/ENAHO-2023/Enaho01A-2023-300.csv", encoding="ISO-8859-10")
#          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# ...

# %%
print (Enaho01A.head())
# Out:
#     AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  ESTRATO  \
# 0  2023    1      5030         2     11         1   10201        7        4
# 1  2023    1      5030         2     11         2   10201        7        4
# 2  2023    1      5030         2     11         3   10201        7        4
# 3  2023    1      5030         2     11         4   10201        7        4
# 4  2023    1      5030        11     11         1   10201        7        4
#
#    CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C I315B    FACTOR07  \
# 0         1  ...                                                  118.374542
# 1         2  ...                                                  118.374542
# 2         2  ...                                                  118.374542
# 3         2  ...                          8                       118.374542
# 4         1  ...                                                  118.374542
#
#     FACTORA07 NCONGLOME SUB_CONGLOME
# ...

# %%
print (list(Enaho01A.columns))
# Out:
# ['AŅO', 'MES', 'CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO', 'UBIGEO', 'DOMINIO', 'ESTRATO', 'CODINFOR', 'P300N', 'P300I', 'P300A', 'P301A', 'P301B', 'P301C', 'P301D', 'P301A0', 'P301A1', 'P301B0', 'P301B1', 'P301B3', 'P302', 'P302X', 'P302A', 'P302B', 'P303', 'P304A', 'P304B', 'P304C', 'P304D', 'P305', 'P306', 'P307', 'P307A1', 'P307A2', 'P307A3', 'P307A4', 'P307A4_5', 'P307A4_6', 'P307A4_7', 'P307B1', 'P307B2', 'P307B3', 'P307B4', 'P307B4_5', 'P307B4_6', 'P307B4_7', 'P307C', 'P308A', 'P308B', 'P308C', 'P308D', 'P308B1', 'P308B2', 'P308B3', 'P308B4', 'P308B5', 'P308C1', 'P308C2', 'P310', 'P310B1', 'P310C0', 'P310C1', 'P310D1', 'P310D2', 'P310E0', 'P310E1', 'P310E3', 'P311N$1', 'P311N$2', 'P311N$3', 'P311N$4', 'P311N$5', 'P311N$6', 'P311N$7', 'P311N$8', 'P311N$9', 'P311$1', 'P311$2', 'P311$3', 'P311$4', 'P311$5', 'P311$6', 'P311$7', 'P311$8', 'P311$9', 'P311A1$1', 'P311A1$2', 'P311A1$3', 'P311A1$4', 'P311A1$5', 'P311A1$6', 'P311A1$7', 'P311A1$8', 'P311A1$9', 'P311A2$1', 'P311A2$2', 'P
# ...

# %%
Enaho01A.dtypes
# Out:
# AŅO               int64
# MES               int64
# CONGLOME          int64
# VIVIENDA          int64
# HOGAR             int64
#                  ...
# I315B            object
# FACTOR07        float64
# FACTORA07       float64
# NCONGLOME         int64
# SUB_CONGLOME      int64
# Length: 511, dtype: object

# %%
print(Enaho01A.columns.tolist())
# Out:
# ['AŅO', 'MES', 'CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO', 'UBIGEO', 'DOMINIO', 'ESTRATO', 'CODINFOR', 'P300N', 'P300I', 'P300A', 'P301A', 'P301B', 'P301C', 'P301D', 'P301A0', 'P301A1', 'P301B0', 'P301B1', 'P301B3', 'P302', 'P302X', 'P302A', 'P302B', 'P303', 'P304A', 'P304B', 'P304C', 'P304D', 'P305', 'P306', 'P307', 'P307A1', 'P307A2', 'P307A3', 'P307A4', 'P307A4_5', 'P307A4_6', 'P307A4_7', 'P307B1', 'P307B2', 'P307B3', 'P307B4', 'P307B4_5', 'P307B4_6', 'P307B4_7', 'P307C', 'P308A', 'P308B', 'P308C', 'P308D', 'P308B1', 'P308B2', 'P308B3', 'P308B4', 'P308B5', 'P308C1', 'P308C2', 'P310', 'P310B1', 'P310C0', 'P310C1', 'P310D1', 'P310D2', 'P310E0', 'P310E1', 'P310E3', 'P311N$1', 'P311N$2', 'P311N$3', 'P311N$4', 'P311N$5', 'P311N$6', 'P311N$7', 'P311N$8', 'P311N$9', 'P311$1', 'P311$2', 'P311$3', 'P311$4', 'P311$5', 'P311$6', 'P311$7', 'P311$8', 'P311$9', 'P311A1$1', 'P311A1$2', 'P311A1$3', 'P311A1$4', 'P311A1$5', 'P311A1$6', 'P311A1$7', 'P311A1$8', 'P311A1$9', 'P311A2$1', 'P311A2$2', 'P
# ...

# %%
subset=Enaho01A[['CONGLOME','VIVIENDA','HOGAR','CODPERSO','MES','SUB_CONGLOME','UBIGEO']]
subset
# Out:
#         CONGLOME  VIVIENDA  HOGAR  CODPERSO  MES  SUB_CONGLOME  UBIGEO
# 0           5030         2     11         1    1             0   10201
# 1           5030         2     11         2    1             0   10201
# 2           5030         2     11         3    1             0   10201
# 3           5030         2     11         4    1             0   10201
# 4           5030        11     11         1    1             0   10201
# ...          ...       ...    ...       ...  ...           ...     ...
# 108349     20670        67     11         5   12             0   10503
# 108350     20670        68     11         1   12             0   10503
# 108351     20670        69     11         1   12             0   10503
# 108352     20670        69     11         2   12             0   10503
# 108353     20670        69     11         3   12             0   10503
#
# [108354 rows x 7 columns]

# %%
Enaho01A.info
# Out:
# <bound method DataFrame.info of          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# 108352  2023   12     20670        69     11         2   10503        4
# 108353  2023   12     20670        69     11         3   10503        4
#
# ...

# %%
Enaho01A.describe
# Out:
# <bound method NDFrame.describe of          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       2023    1      5030         2     11         1   10201        7
# 1       2023    1      5030         2     11         2   10201        7
# 2       2023    1      5030         2     11         3   10201        7
# 3       2023    1      5030         2     11         4   10201        7
# 4       2023    1      5030        11     11         1   10201        7
# ...      ...  ...       ...       ...    ...       ...     ...      ...
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# 108352  2023   12     20670        69     11         2   10503        4
# 108353  2023   12     20670        69     11         3   10503        4
#
# ...

# %%
Enaho01A.describe(include='all')
# Out:
#              AŅO            MES       CONGLOME       VIVIENDA          HOGAR  \
# count   108354.0  108354.000000  108354.000000  108354.000000  108354.000000
# unique       NaN            NaN            NaN            NaN            NaN
# top          NaN            NaN            NaN            NaN            NaN
# freq         NaN            NaN            NaN            NaN            NaN
# mean      2023.0       6.495127   16944.756797      77.820330      11.146271
# std          0.0       3.445244    3144.386733      68.547022       1.370084
# min       2023.0       1.000000    5007.000000       1.000000      11.000000
# 25%       2023.0       3.000000   16028.000000      31.000000      11.000000
# 50%       2023.0       7.000000   17500.000000      66.000000      11.000000
# 75%       2023.0       9.000000   19014.000000     106.000000      11.000000
# max       2023.0      12.000000   21001.000000     991.000000      44.000000
#
# ...

# %%
Enaho01A.shape
# Out:
# (108354, 511)

# %%
Enaho01A.head()
# Out:
#     AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  ESTRATO  \
# 0  2023    1      5030         2     11         1   10201        7        4
# 1  2023    1      5030         2     11         2   10201        7        4
# 2  2023    1      5030         2     11         3   10201        7        4
# 3  2023    1      5030         2     11         4   10201        7        4
# 4  2023    1      5030        11     11         1   10201        7        4
#
#    CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C I315B    FACTOR07  \
# 0         1  ...                                                  118.374542
# 1         2  ...                                                  118.374542
# 2         2  ...                                                  118.374542
# 3         2  ...                          8                       118.374542
# 4         1  ...                                                  118.374542
#
#     FACTORA07 NCONGLOME SUB_CONGLOME
# ...

# %%
Enaho01A.tail()
# Out:
#          AŅO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 108349  2023   12     20670        67     11         5   10503        4
# 108350  2023   12     20670        68     11         1   10503        4
# 108351  2023   12     20670        69     11         1   10503        4
# 108352  2023   12     20670        69     11         2   10503        4
# 108353  2023   12     20670        69     11         3   10503        4
#
#         ESTRATO  CODINFOR  ...  I311D$5  I311D$6  I311D$7  I3121C I3122C  \
# 108349        8         2  ...
# 108350        8         1  ...
# 108351        8         1  ...
# 108352        8         2  ...
# 108353        8         3  ...
#
#        I315B   FACTOR07  FACTORA07 NCONGLOME SUB_CONGLOME
# 108349        65.991585  76.758545      7051            0
# 108350        65.991585  94.397972      7051            0
# 108351        65.991585  54.246708      7051            0
# 108352        65.991585  69.487373      7051            0
# ...

# %%
Enaho01A.isnull()
# Out:
#           AŅO    MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  UBIGEO  DOMINIO  \
# 0       False  False     False     False  False     False   False    False
# 1       False  False     False     False  False     False   False    False
# 2       False  False     False     False  False     False   False    False
# 3       False  False     False     False  False     False   False    False
# 4       False  False     False     False  False     False   False    False
# ...       ...    ...       ...       ...    ...       ...     ...      ...
# 108349  False  False     False     False  False     False   False    False
# 108350  False  False     False     False  False     False   False    False
# 108351  False  False     False     False  False     False   False    False
# 108352  False  False     False     False  False     False   False    False
# 108353  False  False     False     False  False     False   False    False
#
# ...

# %%
Enaho01A_cleaned = Enaho01A.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Enaho01A_cleaned = Enaho01A.dropna()
#
# NameError: name 'Enaho01A' is not defined
