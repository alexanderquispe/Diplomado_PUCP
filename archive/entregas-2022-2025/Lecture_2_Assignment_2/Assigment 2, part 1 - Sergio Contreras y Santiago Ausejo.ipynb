# %%
#PARTE 1

# Pregunta 1
#importo pandas


import pandas as pd
import numpy as np

# %%
#importo dataset Enaho01A-2023-300.csv

df1 = pd.read_csv("/Users/sergio/Documents/GitHub/Diplomado_PUCP/_data/Enaho01A-2023-300.csv",
                  encoding = "ISO-8859-10",
                 low_memory=False)

# %%
df1.head(5)

# %%
# Convert the column names into a list and print it.

col_list = df1.columns.tolist()
print(col_list)

# %%
# Check the data types of the DataFrame.

df1.dtypes

# %%
# Select a subsample containing the variables ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO'] and between 3–5 additional variables of your interest.

df1_sub = df1[["CONGLOME", "VIVIENDA", "HOGAR", "CODPERSO", "DOMINIO", "ESTRATO", "MES"]]
df1_sub

# %%
# pregunta 2, Manipulación de data

#Explore the DataFrame using summary functions.


df1.info()

# %%
 df1.shape

# %%
 df1.describe()

# %%
# Identify if there are missing values. If they exist, remove them.

df1_nulls = df1.isnull().sum()
df1_nulls

# %%
df1 = df1.dropna()
df1

# %%
# pregunta 3
#Import a second dataset (choose between Enaho01A-2023-200.csv or Enaho01A-2023-500.csv).

df2 = pd.read_csv("/Users/sergio/Documents/GitHub/Diplomado_PUCP/_data/Enaho01a-2023-500.csv", 
                  encoding = "ISO-8859-10" ,
                   low_memory=False)

# %%
# display 5 rows
df2.head(5)

# %%
# Convert the column names into a list and print it.

df2_cols = df2.columns.tolist()
print(df2_cols)

# %%
#chequea lostipos de data 

df2.dtypes

# %%
# selecciona los subsamples a las de las variables y 3 variables o 5 ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO']


df2_sub = df2[['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO', 'EMPLPSEC', 'TICUEST01A', 'OCUPINF', 'SUB_CONGLOME']]
df2_sub

# %%
# Perform the following modifications:
#A. Change the data type of a variable (e.g., from text to numeric).

df2["P301A"] = df2['P301A'].astype(str)
print(df2['P301A'].dtype)

# %%
#B. modifing some values

df2["VIVIENDA"] = df2["VIVIENDA"] * 3 +2

df2[["VIVIENDA"]].head()

# %%
# pregunta 4 - Merge


common_columns = df1.columns.intersection(df2.columns).tolist()
print(common_columns)

# %%
# Inicio de merge

common_columns = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'CODPERSO']

merged_df = pd.merge(df1, df2, on=common_columns, how="inner")
merged_df.head(5)

# %%
# pregunta 5 elegir un indicador estadístico

merged_df = merged_df.groupby("CODPERSO").mean(numeric_only = True)
merged_df
