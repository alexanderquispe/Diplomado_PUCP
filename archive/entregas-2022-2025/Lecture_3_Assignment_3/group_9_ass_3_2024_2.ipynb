# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Members and questions for group 9

# %% [markdown]
# |Name|Questions|
# |---|---|
# | Armando | 01-02 |
# | Alonso | 03-04 |
# | Paolo | 05-06 |
# | Julián | 07-08 |
# | Pamela | 09-10 |

# %% [markdown]
# ## Installing and importing librarys

# %%
# !pip install pyreadstat
# !pip install savReaderWriter
# !pip install pandas

# %%
import os
import os
import pickle
import pandas as pd
import numpy as np
import urllib.request
import pyreadstat

# %% [markdown]
# ## Files Path

# %%
## File Path
# path = "G:/Académico/FormacionContinua/Ciencia de datos Cs Sociales/Python básico/2019"
path = "../../_data/endes/2019/"

# %% [markdown]
# ## Question 01

# %% [markdown]
# Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their variables and values labels from this path `"../../_data/endes/2019"`. The name of imported files should be named as `rec_1`, `rec_2` and `rec_3` for files `REC0111.sav`, `RE223132.sav` and `RE516171.sav` respectively. The name of the variable and value labels should be `var_labels1` and `value_labels1` for `rec1`, `var_labels2` and `value_labels2` for `rec2`, and `var_labels3` and `value_labels3` for `rec3`. **Hint: See the section 3.3.4 of [the lecture 3](https://github.com/alexanderquispe/Diplomado_PUCP/blob/main/Lecture_3/Lecture_3.ipynb)**

# %% [markdown]
# ### Solution

# %%
# Reading REC0111.sav and creating variables labels and value variable labels objects
rec_1, meta_data = pyreadstat.read_sav(f"{path}REC0111.sav")
var_labels1 = meta_data.column_names_to_labels
value_labels1 = meta_data.variable_value_labels

rec_1.head()

# %%
# Reading RE223132.sav and creating variables labels and value variable labels objects
rec_2, meta_data = pyreadstat.read_sav(f"{path}RE223132.sav")
var_labels2 = meta_data.column_names_to_labels
value_labels2 = meta_data.variable_value_labels

rec_2.head()

# %%
# Reading RE516171.sav and creating variables labels and value variable labels objects
rec_3, meta_data = pyreadstat.read_sav(f"{path}RE516171.sav")
var_labels3 = meta_data.column_names_to_labels
value_labels3 = meta_data.variable_value_labels

rec_3.head()

# %% [markdown]
# **Reference:** https://github.com/Roche/pyreadstat

# %% [markdown]
# ## Question 02

# %% [markdown]
# Select the following columns for each data set. Check if all the columns are in the dataset. Make a code that check the columns that are not included. Please, reporte them.
#
# |Data|Columns|
# |---|---|
# |rec1| CASEID, V000, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V024, V102, V120, V121, V122, V123, V124, V125, V127, V133 |
# |rec2| CASEID, V201, V218, V301, V302, V323, V323A, V325A, V326, V327, V337, V359, V360, V361, V362, V363, V364, V367, V372, V372A, V375A, V376, V376A, V379, V380 |
# |rec3| CASEID, V501, V502, V503, V504, V505, V506, V507, V508, V509, V510, V511, V512, V513, V525, V613, V714, V715 |
#
#
# Additionally, you should update the variables and value labels objects. They must have information only for the selected columns. The new dataframes should be name as `rec1_1`, `rec2_1`, and `rec3_1`. The new varible labels objects should be named as `new_var_labels1`, `new_var_labels2`, and `new_var_labels3`. The new value labels objects should be named as `new_value_labels1`, `new_value_labels2`, and `new_value_labels3` **Hint: Use the `loc` and column names to filter, `for loop`,   and [this link](https://stackoverflow.com/questions/3420122/filter-dict-to-contain-only-certain-keys) to update the var and value dictionary.**

# %% [markdown]
# ### Solution

# %% [markdown]
# #### i. Checking if all the columns are in the datasets

# %% [markdown]
# ##### a. For rec_1

# %%
# Selected columns for rec_1
columns_rec1 = ["CASEID", "V000", "V001", "V002", "V003", "V004", "V007", "V008", "V009", "V010", "V011", "V012", "V024", "V102", "V120", "V121", "V122", "V123", "V124", "V125", "V127", "V133"]

# Checking if the selected columns are in rec_1. In case they are not, column's name will be printed.
for column in columns_rec1:
    if column not in rec_1.columns:
        print(column)

# %% [markdown]
# ##### b. For rec_2

# %%
# Selected columns for rec_2
columns_rec2 = ["CASEID", "V201", "V218", "V301", "V302", "V323", "V323A", "V325A", "V326", "V327", "V337", "V359", "V360", "V361", "V362", "V363", "V364", "V367", "V372", "V372A", "V375A", "V376", "V376A", "V379", "V380"]

# Checking if the selected columns are in rec_2. In case they are not, column's name will be printed.
for column in columns_rec2:
    if column not in rec_2.columns:
        print(column)

# %% [markdown]
# ##### c. For rec_3

# %%
# Selected columns for rec_3
columns_rec3 = ["CASEID", "V501", "V502", "V503", "V504", "V505", "V506", "V507", "V508", "V509", "V510", "V511", "V512", "V513","V525", "V613", "V714", "V715"]

# Checking if the selected columns are in rec_3. In case they are not, column's name will be printed.
for column in columns_rec3:
    if column not in rec_3.columns:
        print(column)

# %% [markdown]
# **Comment:** All the selected columns are in rec_1, rec_2 and rec_3

# %% [markdown]
# #### ii. Selecting columns in new data frames

# %% [markdown]
# ##### a. For rec_1

# %%
# Selecting columns from rec_1
rec1_1 = rec_1.loc[:, columns_rec1]
rec1_1.head()

# %% [markdown]
# ##### b. For rec_2

# %%
# Selecting columns from rec_2
rec2_1 = rec_2.loc[:, columns_rec2]
rec2_1.head()

# %% [markdown]
# ##### c. For rec_3

# %%
# Selecting columns from rec_3
rec3_1 = rec_3.loc[:, columns_rec3]
rec3_1.head()

# %% [markdown]
# #### iii. Updating the variables labels objects

# %% [markdown]
# ##### a. For rec_1

# %%
# Selecting keys and variables labels from columns selected in rec1_1
new_var_labels1 = {key: var_labels1[key] for key in columns_rec1}
new_var_labels1

# %% [markdown]
# ##### b. For rec_2

# %%
# Selecting keys and variables labels from columns selected in rec2_1
new_var_labels2 = {key: var_labels2[key] for key in columns_rec2}
new_var_labels2

# %% [markdown]
# ##### c. For rec_3

# %%
# Selecting keys and variables labels from columns selected in rec3_1
new_var_labels3 = {key: var_labels3[key] for key in columns_rec3}
new_var_labels3

# %% [markdown]
# #### iv. Updating the value labels objects

# %% [markdown]
# ##### For rec_1

# %%
# Selecting keys and value labels from columns selected in rec1_1
new_value_labels1 = {key: value_labels1[key] for key in columns_rec1 if key in value_labels1.keys()}
new_value_labels1

# %% [markdown]
# ##### b. For rec_2

# %%
# Selecting keys and value labels from columns selected in rec2_1
new_value_labels2 = {key: value_labels2[key] for key in columns_rec2 if key in value_labels2.keys()}
new_value_labels2

# %% [markdown]
# ##### c. For rec_3

# %%
# Selecting keys and value labels from columns selected in rec3_1
new_value_labels3 = {key: value_labels3[key] for key in columns_rec3 if key in value_labels3.keys()}
new_value_labels3

# %% [markdown]
# ## Question 03

# %% [markdown]
# Generate a new column for `rec1_1` named as `year`. It should be equal to `2019`. Also, you must update this new variable for the `var_labels` dictionary. Generate a new key for `new_var_labels1` and the value for this key should be **"Year of the survey"** **Hint: Use `loc` and `update` method.**

# %% [markdown]
# ### Solution

# %% [markdown]
# #### i. Create a new column as 'year' with the value '2019' using 'loc' function

# %%
rec1_1.loc[:, 'Año'] = 2019

# %% [markdown]
# #### ii. Update the data dictionary

# %%
# new_var_labels1.update({'year': 'Year of the survey'})
new_var_labels1.update({'Año': 'Año de la encuesta'})

# %% [markdown]
# #### iii. Print to verify

# %%
print(rec1_1.head())
print(new_var_labels1)

# %% [markdown]
# ## Question 4

# %% [markdown]
# Merge `rec1_1`, `rec2_1`, and `rec3_1` using **CASEID**. Name this new object as `endes_2019`

# %% [markdown]
# ### Solution

# %% [markdown]
# #### i. Make sure that the CASEID column is the index in each DataFrame

# %%
rec1_1.set_index('CASEID', inplace=True)
rec2_1.set_index('CASEID', inplace=True)
rec3_1.set_index('CASEID', inplace=True)

# %% [markdown]
# #### ii. Merging the DataFrames

# %%
merged_df = pd.merge(rec1_1, rec2_1, on='CASEID', how='outer')
endes_2019 = pd.merge(merged_df, rec3_1, on='CASEID', how='outer')

# %% [markdown]
# #### iii. Print to verify

# %%
print(endes_2019.head())

# %% [markdown]
# ## Question 5

# %% [markdown]
# Unify all the `new_var_labels` in one object and `new_value_labels` in another one object. Name these two objects as `var_labels` and `value_labels`. Use them to generate new attributes for `endes_2019`. These attributes should be named as `var_labels` and `value_labels`. **Hint: Use `update` method.**

# %% [markdown]
# ### Solution

# %%
# Unifying the variable labels dictionaries
var_labels = new_var_labels1.copy()
var_labels.update(new_var_labels2)
var_labels.update(new_var_labels3)
var_labels

# %%
# Unifying the value labels dictionaries
value_labels = new_value_labels1.copy()
value_labels.update(new_value_labels2)
value_labels.update(new_value_labels3)
value_labels

# %%
# Giving attributes to 'endes_2019'
endes_2019.attrs['var_labels'] = var_labels
endes_2019.attrs['value_labels'] = value_labels
endes_2019.attrs

# %% [markdown]
# ## Question 6

# %% [markdown]
# Now, replicate your code of the prevoius sections but for years **2019, 2018, 2017, 2016, 2015**. Import the `REC0111.sav`, `RE223132.sav` and `RE516171.sav` files and their **variables and values labels** from this path `"../../_data/endes/"`. For this excersie you must use a for loop. This loop must iterate over **2019, 2018, 2017, 2016, 2015 folders** and import these files. All the files have the same name. You must store these files and their labels in a nested dictionary named as `all_data`. The keys of the dictionary should be named as `year_2019`, for example, and the keys of the nested dictionary should be `data`, `var_labels`, and `value_labels`. **Hint: Use [this link](https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=4d6de78e00e7001f16bf6473c2eb7ce24fb611cd&device=unknown_device&enc_url=&logged_in=true&nwo=alexanderquispe%2FDiplomado_PUCP&path=Lecture_4%2FLecture_4.ipynb&platform=windows&repository_id=427747212&repository_type=Repository&version=95#4.2.)**

# %% [markdown]
# ### Solution

# %%
# Creating all_data dictionary
#all_data = {}
#path = f'../../_data/endes/'

all_data = {}
#path = f'D:/Documents/GitHub/Diplomado_PUCP/_data/endes'

path = "../../_data/endes"

for year in range(2015, 2019 + 1):
    # Creating nested dictionary for each year
    all_data[f'year_{year}'] = {}

    # Reading sav files and creating variables labels and value variable labels objects 
    path_1 = f'{path}\\{year}\\REC0111.sav'
    rec_1, meta_data = pyreadstat.read_sav(path_1)
    var_labels1 = meta_data.column_names_to_labels
    value_labels1 = meta_data.variable_value_labels

    path_2 = f'{path}\\{year}\\RE223132.sav'
    rec_2, meta_data = pyreadstat.read_sav(path_2)
    var_labels2 = meta_data.column_names_to_labels
    value_labels2 = meta_data.variable_value_labels
    
    path_3 = f'{path}\\{year}\\RE516171.sav'
    rec_3, meta_data = pyreadstat.read_sav(path_3)
    var_labels3 = meta_data.column_names_to_labels
    value_labels3 = meta_data.variable_value_labels

    # Selecting selected columns
    rec1_1 = rec_1.reindex(columns = [col for col in columns_rec1 if col in rec_1.columns])
    rec2_1 = rec_2.reindex(columns = [col for col in columns_rec2 if col in rec_2.columns])
    rec3_1 = rec_3.reindex(columns = [col for col in columns_rec3 if col in rec_3.columns])

    # Selecting keys and variables labels from columns selected
    new_var_labels1 = {key: var_labels1[key] for key in columns_rec1 if key in var_labels1.keys()}
    new_var_labels2 = {key: var_labels2[key] for key in columns_rec2 if key in var_labels2.keys()}
    new_var_labels3 = {key: var_labels3[key] for key in columns_rec3 if key in var_labels3.keys()}

    # Selecting keys and value labels from columns selected
    new_value_labels1 = {key: value_labels1[key] for key in columns_rec1 if key in value_labels1.keys()}
    new_value_labels2 = {key: value_labels2[key] for key in columns_rec2 if key in value_labels2.keys()}
    new_value_labels3 = {key: value_labels3[key] for key in columns_rec3 if key in value_labels3.keys()}

    # By adding the column 'year' for each year
    rec1_1.loc[:, 'year'] = year
    new_var_labels1.update({'year': 'Year of the survey'})

    # Merging rec1_1, rec2_1 and rec3_1
    aux = pd.merge(rec1_1, rec2_1, on='CASEID', how='inner')
    data = pd.merge(aux, rec3_1, on='CASEID', how='inner')

    # Unifying the variable labels dictionaries
    var_labels = new_var_labels1.copy()
    var_labels.update(new_var_labels2)
    var_labels.update(new_var_labels3)

    # Unifying the value labels dictionaries
    value_labels = new_value_labels1.copy()
    value_labels.update(new_value_labels2)
    value_labels.update(new_value_labels3)   

    # Giving attributes to 'data' dataframe
    data.attrs['var_labels'] = var_labels
    data.attrs['value_labels'] = value_labels    

    # By assigning data, var_labels and value_labels to nested dictionary for each year
    all_data[f'year_{year}']['data'] = data.copy()
    all_data[f'year_{year}']['var_labels'] = var_labels.copy()
    all_data[f'year_{year}']['value_labels'] = value_labels.copy()

# %% [markdown]
# ## Question 7
# Use all_data to append all the data sets. Store all data sets in a list using for loop. Then, use pd.concat to append all the data sets. Also, you must reset the index to have a good-looking data. This new object should be named as endes_data_2015_2019. Hint: Use this code

# %%
# Declaring the variable list to use "data_list", empty by default, to store the data sets
data_list = []

# The first loop was from 2015 to 2019 so we must follow the same path, and collect the data sets, dataframes
# The key in the dictionary "all_data" corresponds to each "year", so the content (data) of each key must be extracted
for year in range(2015, 2019 + 1):
    year_key = f'year_{year}'
    if 'data' in all_data[year_key]:
        data_list.append(all_data[year_key]['data'])

# We proceed to concatenate the content of the data_list using pd.concat
endes_data_2015_2019 = pd.concat(data_list, ignore_index=True)
print(type(endes_data_2015_2019))

# reset the index with the "reset_index" function, because the variable "endes_data_2015_2019" that contains the list elements is a panda
endes_data_2015_2019.reset_index(drop=True, inplace=True)

# the result is verified, content of the variable "endes_data_2015_2019"
print(endes_data_2015_2019)

# %%
type(var_labels1)

# %% [markdown]
# ## Question 8
# Store all the var_labels and value_labels in a dictionary named as all_var_labels and all_value_labels. The first keys should be the year for both dictionaries.Then, use them to generate new attributes for endes_data_2015_2019. These attributes should be named as var_labels and value_labels. Hint: Use this link

# %%
all_var_labels = {}
all_value_labels = {}

# Path, file location
#base_path = 'D:/Documents/GitHub/Diplomado_PUCP/_data/endes'

base_path = "../../_data/endes"

# We define a loop to enter the files according to the years and assign the keys
# Checking the key assignment in the dictionary
for year in range(2015, 2020):
    year_str = str(year)
    all_var_labels[year_str] = {}
    all_value_labels[year_str] = {}
    # verify iteration
    # print(all_var_labels.keys())
    print(all_value_labels.keys())
    
    # Define a dictionary called "files" to assign a tuple and use it as a vehicle to extract information from the different files by year
    files = {
        'REC0111.sav': ('var_labels1', 'value_labels1'),
        'RE223132.sav': ('var_labels2', 'value_labels2'),
        'RE516171.sav': ('var_labels3', 'value_labels3')
    }
    
    for file_name, labels in files.items():
        # assign file location based on previous data and temporary variables inside the loop; read .sav
        file_path = f'{base_path}/{year_str}/{file_name}'
        df, meta_data = pyreadstat.read_sav(file_path)
        
        # extract data, columns are labels and values of variable are values
        var_labels = meta_data.column_names_to_labels
        value_labels = meta_data.variable_value_labels
        
        # copy information and assign it in the variables all_var_labels and all_value_labels, is updated in each iteration
        if labels[0] == 'var_labels1':
            all_var_labels[year_str].update(var_labels)
        elif labels[0] == 'var_labels2':
            all_var_labels[year_str].update(var_labels)
        elif labels[0] == 'var_labels3':
            all_var_labels[year_str].update(var_labels)
        
        if labels[1] == 'value_labels1':
            all_value_labels[year_str].update(value_labels)
        elif labels[1] == 'value_labels2':
            all_value_labels[year_str].update(value_labels)
        elif labels[1] == 'value_labels3':
            all_value_labels[year_str].update(value_labels)

# %%
# define two dictionaries to combine all_var_labels and all_values_​​labels for the entire DataFrame, endes_data_2015_2019
combined_var_labels = {}
combined_value_labels = {}

# The loop will perform iterations until 2019, one less than the set limit; record and update data
for year in range(2015, 2020):
    year_str = str(year)
    combined_var_labels.update(all_var_labels[year_str])
    combined_value_labels.update(all_value_labels[year_str])

# Generate new attributes
endes_data_2015_2019.attrs['var_labels'] = combined_var_labels
endes_data_2015_2019.attrs['value_labels'] = combined_value_labels

# %%
endes_data_2015_2019

# %% [markdown]
# ## Question 9

# %% [markdown]
# Use `endes_data_2015_2019` data to generate a new object named `mean_key_vars` to find the mean of **total children ever born (V201)**, **Ideal number of children (V613)**, **Husbands education-single yrs (V715)**, and **Age at first marriage (V511)** by year and department **(V024)**. Name these columns as **mean_total_children, mean_ideal_children, mean_hb_yr_educ and mean_first_marriage**, respectively. **Hint: Use groupby and [this link](https://stackoverflow.com/questions/40901770/is-there-a-simple-way-to-change-a-column-of-yes-no-to-1-0-in-a-pandas-dataframe).**

# %%
# Step 1: Calculate the mean of key variables by year and department
mean_key_vars = endes_data_2015_2019.groupby(['year', 'V024']).agg(
    mean_total_children=('V201', 'mean'),
    mean_ideal_children=('V613', 'mean'),
    mean_hb_yr_educ=('V715', 'mean'),
    mean_first_marriage=('V511', 'mean')
).reset_index()

# %%
mean_key_vars

# %% [markdown]
# ## Question 10

# %% [markdown]
# Merge `mean_key_vars` with `endes_data_2015_2019`. Name this object `final_result`. **Hint: Use merge.**

# %%
#Step 2: Merge the means with the original DataFrame
final_result = pd.merge(endes_data_2015_2019, mean_key_vars, on=['year', 'V024'], how='left')

# %%
final_result
