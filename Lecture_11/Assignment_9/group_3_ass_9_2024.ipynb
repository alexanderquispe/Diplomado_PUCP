# %%
# !pip install pysal
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet
import folium as fm
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap, StripePattern
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import branca as br
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet
import pandas as pd
import numpy as np
import folium
from folium.plugins import BeautifyIcon
import branca
import folium
from folium.plugins import MarkerCluster
from folium import IFrame
import shapely
from shapely.geometry import Point

import pandas as pd
import geopandas as gpd
from geopandas.tools import sjoin

import base64
import math
import os
import numpy as np
import seaborn as sns
import unicodedata
import pysal as ps
import branca
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time
import re
import unidecode
import time 
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import re
# Out:
# Collecting pysal
#   Downloading pysal-24.1-py3-none-any.whl (17 kB)
# Collecting esda>=2.4.1
#   Downloading esda-2.5.1-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.4/132.4 kB 3.8 MB/s eta 0:00:00
# Collecting spreg>=1.2.4
#   Downloading spreg-1.4.2-py3-none-any.whl (331 kB)
#      ------------------------------------- 331.8/331.8 kB 10.4 MB/s eta 0:00:00
# Collecting spint>=1.0.7
#   Downloading spint-1.0.7.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mgwr>=2.1.2
#   Downloading mgwr-2.2.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB 2.4 MB/s eta 0:00:00
# Collecting segregation>=2.3.1
#   Downloading segregation-2.5-py3-none-any.whl (141 kB)
#      -------------------------------------- 141.3/141.3 kB 8.2 MB/s eta 0:00:00
# Collecting spvcm>=0.3.0
#   Downloading spvcm-0.3.0.tar.gz (5.7 MB)
#      ---------------------------------------- 5.7/5.7 MB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting inequality>=1.0.0
#   Downloading inequality-1.0.0.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting spopt>=0.4.1
#   Downloading spopt-0.5.0-py3-none-any.whl (112 kB)
#      -------------------------------------- 112.9/112.9 kB 6.4 MB/s eta 0:00:00
# Collecting momepy>=0.5.3
#   Downloading momepy-0.6.0-py3-none-any.whl (275 kB)
#      ------------------------------------- 275.7/275.7 kB 16.6 MB/s eta 0:00:00
# Collecting mapclassify>=2.4.3
#   Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Collecting pointpats>=2.2.0
#   Downloading pointpats-2.4.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.4/58.4 kB 3.0 MB/s eta 0:00:00
# Collecting libpysal>=4.6.2
#   Downloading libpysal-4.8.1-py3-none-any.whl (2.8 MB)
#      ---------------------------------------- 2.8/2.8 MB 17.8 MB/s eta 0:00:00
# Collecting access>=1.1.8
#   Downloading access-1.1.9-py3-none-any.whl (21 kB)
# Collecting spaghetti>=1.6.6
#   Downloading spaghetti-1.7.4-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# Collecting giddy>=2.3.3
#   Downloading giddy-2.3.5-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.1/61.1 kB 3.2 MB/s eta 0:00:00
# Collecting splot>=1.1.5.post1
#   Downloading splot-1.1.5.post1-py3-none-any.whl (39 kB)
# Collecting spglm>=1.0.8
#   Downloading spglm-1.1.0-py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.4/41.4 kB 1.0 MB/s eta 0:00:00
# Collecting tobler>=0.8.2
#   Downloading tobler-0.11.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\ddelgado\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (1.4.4)
# Requirement already satisfied: geopandas in c:\users\ddelgado\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (0.14.3)
# Requirement already satisfied: numpy>=1.3 in c:\users\ddelgado\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (1.21.5)
# Requirement already satisfied: requests>=2 in c:\users\ddelgado\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (2.28.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\ddelgado\anaconda3\lib\site-packages (from esda>=2.4.1->pysal) (1.9.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from esda>=2.4.1->pysal) (1.0.2)
# Collecting quantecon>=0.4.7
#   Downloading quantecon-0.7.1-py3-none-any.whl (214 kB)
#      ------------------------------------- 214.8/214.8 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=2 in c:\users\ddelgado\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (2.0.3)
# Requirement already satisfied: packaging in c:\users\ddelgado\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (21.3)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\ddelgado\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (2.5.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\ddelgado\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (4.11.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\ddelgado\anaconda3\lib\site-packages (from mapclassify>=2.4.3->pysal) (2.8.4)
# Collecting numpy>=1.3
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from momepy>=0.5.3->pysal) (4.64.1)
# Requirement already satisfied: matplotlib in c:\users\ddelgado\anaconda3\lib\site-packages (from pointpats>=2.2.0->pysal) (3.5.2)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyproj>=3 in c:\users\ddelgado\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (3.6.1)
# Requirement already satisfied: numba in c:\users\ddelgado\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (0.55.1)
# Requirement already satisfied: seaborn in c:\users\ddelgado\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (0.11.2)
# Requirement already satisfied: joblib in c:\users\ddelgado\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (1.1.0)
# Requirement already satisfied: rtree in c:\users\ddelgado\anaconda3\lib\site-packages (from spaghetti>=1.6.6->pysal) (0.9.7)
# Collecting pulp
#   Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#      --------------------------------------- 17.7/17.7 MB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in c:\users\ddelgado\anaconda3\lib\site-packages (from tobler>=0.8.2->pysal) (0.13.2)
# Collecting rasterio
#   Downloading rasterio-1.3.9-cp39-cp39-win_amd64.whl (23.4 MB)
#      --------------------------------------- 23.4/23.4 MB 16.4 MB/s eta 0:00:00
# Collecting rasterstats
#   Downloading rasterstats-0.19.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ddelgado\anaconda3\lib\site-packages (from beautifulsoup4>=4.10->libpysal>=4.6.2->pysal) (2.3.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ddelgado\anaconda3\lib\site-packages (from geopandas->access>=1.1.8->pysal) (1.9.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ddelgado\anaconda3\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ddelgado\anaconda3\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2022.1)
# Requirement already satisfied: certifi in c:\users\ddelgado\anaconda3\lib\site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2022.9.14)
# Requirement already satisfied: sympy in c:\users\ddelgado\anaconda3\lib\site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.10.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\ddelgado\anaconda3\lib\site-packages (from numba->segregation>=2.3.1->pysal) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\ddelgado\anaconda3\lib\site-packages (from numba->segregation>=2.3.1->pysal) (63.4.1)
# Collecting numba
#   Downloading numba-0.59.0-cp39-cp39-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 28.0 MB/s eta 0:00:00
# Collecting llvmlite<0.43,>=0.42.0dev0
#   Downloading llvmlite-0.42.0-cp39-cp39-win_amd64.whl (28.1 MB)
#      --------------------------------------- 28.1/28.1 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ddelgado\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ddelgado\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ddelgado\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (1.26.11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal) (2.2.0)
# Collecting numpy>=1.3
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\ddelgado\anaconda3\lib\site-packages (from tqdm>=4.27.0->momepy>=0.5.3->pysal) (0.4.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ddelgado\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ddelgado\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ddelgado\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.11.0)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: attrs in c:\users\ddelgado\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\ddelgado\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: click>=4.0 in c:\users\ddelgado\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (8.0.4)
# Requirement already satisfied: click-plugins in c:\users\ddelgado\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Collecting simplejson
#   Downloading simplejson-3.19.2-cp39-cp39-win_amd64.whl (75 kB)
#      ---------------------------------------- 75.5/75.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ddelgado\anaconda3\lib\site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.2)
# Requirement already satisfied: importlib-metadata in c:\users\ddelgado\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (4.11.3)
# Requirement already satisfied: six in c:\users\ddelgado\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ddelgado\anaconda3\lib\site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.2.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ddelgado\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (3.8.0)
# Building wheels for collected packages: inequality, spint, spvcm
#   Building wheel for inequality (setup.py): started
#   Building wheel for inequality (setup.py): finished with status 'done'
#   Created wheel for inequality: filename=inequality-1.0.0-py3-none-any.whl size=11782 sha256=25699dbd911a9a5a2021d2d17c6ac50431f1679ca551777aa392068abcef30c0
#   Stored in directory: c:\users\ddelgado\appdata\local\pip\cache\wheels\80\71\07\4d4c8ecaba710bd79e91014602e70fc4d008328c99d524db40
#   Building wheel for spint (setup.py): started
#   Building wheel for spint (setup.py): finished with status 'done'
#   Created wheel for spint: filename=spint-1.0.7-py3-none-any.whl size=31364 sha256=1ce42d33c879457191b1dacbe8d49ebee1ab6cd413e8e82ce47df9dcab924da1
#   Stored in directory: c:\users\ddelgado\appdata\local\pip\cache\wheels\93\a7\ea\0e65be5d06cd2860a4c2ea99656ead582f96aa3954652b6ad7
#   Building wheel for spvcm (setup.py): started
#   Building wheel for spvcm (setup.py): finished with status 'done'
#   Created wheel for spvcm: filename=spvcm-0.3.0-py3-none-any.whl size=5777185 sha256=a0e12f15628d22f8b3f16912dfdadff99947725eacefe86f7e3e7a9cd8688852
#   Stored in directory: c:\users\ddelgado\appdata\local\pip\cache\wheels\73\d0\2c\ef650f39e25225566643b2839ebfe7a2d4adc5d777dc8d7d73
# Successfully built inequality spint spvcm
# Installing collected packages: simplejson, pulp, numpy, llvmlite, affine, snuggs, numba, deprecation, rasterio, quantecon, inequality, rasterstats, mapclassify, libpysal, access, tobler, spreg, segregation, pointpats, momepy, esda, spvcm, spglm, spaghetti, giddy, spopt, splot, spint, mgwr, pysal
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.38.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28924\3997611130.py in <module>
#      38 import seaborn as sns
#      39 import unicodedata
# ---> 40 import pysal as ps
#      41 import branca
#      42 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'pysal'

# %%
# Define file path
file_path = '../../_data/institutos1.csv'

# Load the data
inst = pd.read_csv(file_path)

# Show first rows of the df
inst.head()
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
# 3   262311                    423                               526
# 4   273979                    425                               544
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
# 3                     353                      349  0.825059  1.243499  -74
# 4                     411                      405  0.952941  1.280000  -20
#
#    dif1   nlat_ie  ...  population_ccpp  altitude  Dblock1km  Dblock2km  \
# 0   174 -13.52107  ...         106400.0    3386.0   14840369     742184
# 1   262 -13.63997  ...          45864.0    2342.0   14970470     748235
# 2   510 -15.47827  ...         216716.0    3831.0   17000163     850081
# 3   103  -6.23041  ...          23202.0    2358.0    6781025     339512
# 4   119  -6.49004  ...          67362.0     309.0    7070857     353428
#
#    Dblock3km  Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge
# 0     494123     296073      148036        7418        4912  matched (3)
# 1     499156     299094      149047        7423        4915  matched (3)
# 2     566054     340032      170016        8508        5605  matched (3)
# 3     226341     135205       67102        3351        2234  matched (3)
# 4     235285     141171       70085        3542        2328  matched (3)
#
# [5 rows x 21 columns]

# %%
inst_geo = gpd.GeoDataFrame(inst, crs = "EPSG:4326",
                               geometry = gpd.points_from_xy(inst.nlong_ie,
                                                            inst.nlat_ie))

shp_dpt = gpd.read_file(r"../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp")

intersct_inst_geo = gpd.overlay(inst_geo, shp_dpt, how = "intersection")

# Variables of interest

vars_sum = ['ltimoden_metaatencion' , 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado']

tot_dpt = intersct_inst_geo.groupby(['CCDD'], as_index = False )[vars_sum].sum()
tot_dpt_shp = shp_dpt.merge(tot_dpt, on = 'CCDD')
