# %% [markdown]
# # 1. Importing the data

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

file_path = '../../_data/institutos1.csv'

# Load the CSV data into a DataFrame
institutos_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data is loaded correctly
print(institutos_df.head())
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
# 3   262311                    423                               526
# 4   273979                    425                               544
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
# 3                     353                      349  0.825059  1.243499  -74
# 4                     411                      405  0.952941  1.280000  -20
#
#    dif1   nlat_ie  ...  population_ccpp  altitude  Dblock1km  Dblock2km  \
# 0   174 -13.52107  ...         106400.0    3386.0   14840369     742184
# 1   262 -13.63997  ...          45864.0    2342.0   14970470     748235
# 2   510 -15.47827  ...         216716.0    3831.0   17000163     850081
# 3   103  -6.23041  ...          23202.0    2358.0    6781025     339512
# 4   119  -6.49004  ...          67362.0     309.0    7070857     353428
#
#    Dblock3km  Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge
# 0     494123     296073      148036        7418        4912  matched (3)
# 1     499156     299094      149047        7423        4915  matched (3)
# 2     566054     340032      170016        8508        5605  matched (3)
# 3     226341     135205       67102        3351        2234  matched (3)
# 4     235285     141171       70085        3542        2328  matched (3)
#
# [5 rows x 21 columns]

# %%
encabezados = institutos_df.columns.tolist()

# Print the list of column headers
print(encabezados)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge']

# %% [markdown]
# # 2. generate a Choropleth map of the total institutes' vacancies by the department

# %%
import geopandas as gpd
import pandas as pd
inst_geo = gpd.GeoDataFrame(
    institutos_df,
    geometry=gpd.points_from_xy(institutos_df.nlong_ie, institutos_df.nlat_ie),
    crs='EPSG:4326'
)
# Now 'inst_geo' is a GeoDataFrame with the institutes' data including a geometry column with point data

# %%
# Read the shapefile for department boundaries
dept_boundaries_path = '../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp'
dept_boundaries = gpd.read_file(dept_boundaries_path)

# %%
# Intersect institutes with department boundaries
institutes_with_departments = gpd.overlay(inst_geo, dept_boundaries, how='intersection')

# %%
encabezados_columnas = institutes_with_departments.columns.tolist()

# Print the list of column headers
print(encabezados_columnas)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge', 'OBJECTID_1', 'OBJECTID', 'CCDD', 'NOMBDEP', 'CAPITAL', 'Shape_STAr', 'Shape_STLe', 'ORIG_FID', 'Shape_Leng', 'Shape_Area', 'CORREO', 'CONTACTO', 'WHATSAPP', 'geometry']

# %%
# group data by department name ('NOMBDEP') and aggregate specific columns to calculate the total 
#number of vacancies, applicants, entrants, and enrolled students for each department
grouped = institutes_with_departments.groupby('NOMBDEP').agg({
    'ltimoden_metaatencion': 'sum',  # total vacancies
    'cuentadeid_postulante_procesoadm': 'sum',  # Total applicants
    'sumaden_flagingresante': 'sum',  # Total entrants
    'sumaden_flagmatriculado': 'sum'  # Total enrolled students
}).reset_index()

# Merge the aggregated data with the departmental boundaries
dept_vacancies = dept_boundaries.merge(vacancies_by_department, on='NOMBDEP')

# Create the choropleth map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
dept_vacancies.plot(
    column='ltimoden_metaatencion',
    cmap='YlGnBu',
    legend=True,
    scheme='quantiles',
    ax=ax
)

# Manually configure the legend
leg = ax.get_legend()
leg.set_title('Total Vacancies by Department')
leg.set_bbox_to_anchor((1.5, 0.5))

plt.show()

# %% [markdown]
# # 3. Make an interactive map of markes using visual_html function and show total vacancies, applicants, entrants, and enrolled information in a table popup

# %%
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/isaisilva/anaconda3/lib/python3.11/site-packages (from requests->folium) (2024.2.2)

# %%
# Create a base map
mapa1 = folium.Map(location=[-9.19, -75.0152], zoom_start=6)  # Coordenadas centrales de Perú

# Add markers to the map.
for idx, row in institutes_with_departments.iterrows():
    # Crear el contenido HTML para la ventana emergente
    html_content = folium.Html(f"""
        <table>
            <tr><th>Total Vacancies:</th><td>{row['ltimoden_metaatencion']}</td></tr>
            <tr><th>Total Applicants:</th><td>{row['cuentadeid_postulante_procesoadm']}</td></tr>
            <tr><th>Total Entrants:</th><td>{row['sumaden_flagingresante']}</td></tr>
            <tr><th>Total Enrolled:</th><td>{row['sumaden_flagmatriculado']}</td></tr>
        </table>
    """, script=True)

    # Create the popup window with HTML content
    popup = folium.Popup(html_content, max_width=2650)

    # Add the marker with the popup window to the map
    folium.Marker(
        [row['nlat_ie'], row['nlong_ie']],
        popup=popup,
        icon=folium.Icon(icon='university', prefix='fa')  # Utiliza el ícono de universidad de FontAwesome
    ).add_to(mapa1)

# Display the map
mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49b43533e38117b3d77e29ef33e85a5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49b43533e38117b3d77e29ef33e85a5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49b43533e38117b3d77e29ef33e85a5a = L.map(
#                 &quot;map_49b43533e38117b3d77e29ef33e85a5a&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5459c0e607116cfc31bc5a0d23a0f8ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49b43533e38117b3d77e29ef33e85a5a);
#
#
#             var marker_a4d06edb8839ad03624e6608b5dd89dc = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(map_49b43533e38117b3d77e29ef33e85a5a);
#
#
#             var icon_2c6db903a49b8d45154f00ac6d3e7816 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a4d06edb8839ad03624e6608b5dd89dc.setIcon(icon_2c6db903a49b8d45154f00ac6d3e7816);
#
#
#         var popup_7aed4a1fc14bd7e27d65783b95cd0eae = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_7551399770ddafd99034d5d428464dea = $(`&lt;div id=&quot;html_7551399770ddafd99034d5d428464dea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;307&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;481&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;302&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;301&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_7aed4a1fc14bd7e27d65783b95cd0eae.setContent(html_7551399770ddafd99034d5d428464dea);
#
#
#
#         marker_a4d06edb8839ad03624e6608b5dd89dc.bindPopup(popup_7aed4a1fc14bd7e27d65783b95cd0eae)
#         ;
#
#
#
#
#             var marker_81d3bbbe0133d3e359430946654becc8 = L.marker(
#                 [-14.1424, -71.40813],
#                 {}
#             ).addTo(map_49b43533e38117b3d77e29ef33e85a5a);
#
#
#             var icon_f33d2e28864d3ceef298c7eebfee0af7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_81d3bbbe0133d3e359430946654becc8.setIcon(icon_f33d2e28864d3ceef298c7eebfee0af7);
#
#
#         var popup_27c4c654a158467aa78f4778e01a4f4c = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_a27b05117a5a7fb654b1df415794afe9 = $(`&lt;div id=&quot;html_a27b05117a5a7fb654b1df415794afe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;516&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;1047&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;515&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;544&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_27c4c654a158467aa78f4778e01a4f4c.setContent(html_a27b05117a5a7fb654b1df415794afe9);
#
#
#
#         marker_81d3bbbe0133d3e359430946654becc8.bindPopup(popup_27c4c654a158467aa78f4778e01a4f4c)
#         ;
#
#
#
#
#             var marker_d5644b357bc6337bc0985f520e63963c = L.marker(
#                 [-13.30178, -72.12163],
#                 {}
#             ).addTo(map_49b43533e38117b3d77e29ef33e85a5a);
#
#
#             var icon_3db89b77a90116ba05ee5ac4118a0ee5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d5644b357bc6337bc0985f520e63963c.setIcon(icon_3db89b77a90116ba05ee5ac4118a0ee5);
#
#
#         var popup_0130e40280c400c6aa2e1dab7dd6915e = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_bc41d9e76a3f7562741f48218bbebfa0 = $(`&lt

# %% [markdown]
# # 3

# %% [markdown]
# # 4

# %% [markdown]
# # 5

# %% [markdown]
# # 6
