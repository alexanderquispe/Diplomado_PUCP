# %% [markdown]
# # 1. Importing the data

# %%
# !pip install mapclassify
# Out:
# Requirement already satisfied: mapclassify in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (2.6.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from mapclassify) (3.2.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from mapclassify) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from mapclassify) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from mapclassify) (1.4.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from mapclassify) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from scikit-learn>=1.0->mapclassify) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from scikit-learn>=1.0->mapclassify) (3.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %%
#!pip install jupyterthemes
# !jt -t monokai

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

file_path = '../../_data/institutos1.csv'
# Load the CSV data into a DataFrame
institutos_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data is loaded correctly
print(institutos_df.head())
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
# 3   262311                    423                               526
# 4   273979                    425                               544
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
# 3                     353                      349  0.825059  1.243499  -74
# 4                     411                      405  0.952941  1.280000  -20
#
#    dif1   nlat_ie  ...  population_ccpp  altitude  Dblock1km  Dblock2km  \
# 0   174 -13.52107  ...         106400.0    3386.0   14840369     742184
# 1   262 -13.63997  ...          45864.0    2342.0   14970470     748235
# 2   510 -15.47827  ...         216716.0    3831.0   17000163     850081
# 3   103  -6.23041  ...          23202.0    2358.0    6781025     339512
# 4   119  -6.49004  ...          67362.0     309.0    7070857     353428
#
#    Dblock3km  Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge
# 0     494123     296073      148036        7418        4912  matched (3)
# 1     499156     299094      149047        7423        4915  matched (3)
# 2     566054     340032      170016        8508        5605  matched (3)
# 3     226341     135205       67102        3351        2234  matched (3)
# 4     235285     141171       70085        3542        2328  matched (3)
#
# [5 rows x 21 columns]

# %%
encabezados = institutos_df.columns.tolist()

# Print the list of column headers
print(encabezados)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge']

# %% [markdown]
# # 1. 2. generate a Choropleth map of the total institutes' vacancies by the department

# %%
import geopandas as gpd
import pandas as pd
inst_geo = gpd.GeoDataFrame(
    institutos_df,
    geometry=gpd.points_from_xy(institutos_df.nlong_ie, institutos_df.nlat_ie),
    crs='EPSG:4326'
)
# Now 'inst_geo' is a GeoDataFrame with the institutes' data including a geometry column with point data
inst_geo
# Out:
#      cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0     207597                    307                               481
# 1     207613                    240                               502
# 2     239970                    537                              1047
# 3     262311                    423                               526
# 4     273979                    425                               544
# ..       ...                    ...                               ...
# 210  1468594                   1566                               250
# 211  1468610                    284                                74
# 212  1545623                    210                               266
# 213  1595495                    206                               144
# 214  1637859                    180                               134
#
#      sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  \
# 0                       302                      301  0.980456  1.566775
# 1                       204                      204  0.850000  2.091667
# 2                       484                      476  0.886406  1.949721
# 3                       353                      349  0.825059  1.243499
# 4                       411                      405  0.952941  1.280000
# ..                      ...                      ...       ...       ...
# 210                     241                      202  0.128991  0.159642
# 211                      71                       71  0.250000  0.260563
# 212                     184                      177  0.842857  1.266667
# 213                     141                      137  0.665049  0.699029
# 214                     125                      125  0.694444  0.744444
#
#       dif  dif1   nlat_ie  ...  altitude  Dblock1km  Dblock2km  Dblock3km  \
# 0      -6   174 -13.52107  ...    3386.0   14840369     742184     494123
# 1     -36   262 -13.63997  ...    2342.0   14970470     748235     499156
# 2     -61   510 -15.47827  ...    3831.0   17000163     850081     566054
# 3     -74   103  -6.23041  ...    2358.0    6781025     339512     226341
# 4     -20   119  -6.49004  ...     309.0    7070857     353428     235285
# ..    ...   ...       ...  ...       ...        ...        ...        ...
# 210 -1364 -1316 -12.02987  ...     125.0   13190935     659467     439311
# 211  -213  -210 -12.08215  ...     115.0   13250934     662467     441311
# 212   -33    56 -16.13940  ...    3780.0   17740208     887104     591069
# 213   -69   -62 -18.01370  ...     577.0   19810177     990088     660059
# 214   -55   -46 -13.63631  ...    2392.0   14970469     748234     499156
#
#      Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge  \
# 0       296073      148036        7418        4912  matched (3)
# 1       299094      149047        7423        4915  matched (3)
# 2       340032      170016        8508        5605  matched (3)
# 3       135205       67102        3351        2234  matched (3)
# 4       141171       70085        3542        2328  matched (3)
# ..         ...         ...         ...         ...          ...
# 210     263187      131093        6546        4331  matched (3)
# 211     265186      132093        6646        4431  matched (3)
# 212     354041      177020        8810        5906  matched (3)
# 213     396035      198017        9908        6605  matched (3)
# 214     299093      149046        7423        4915  matched (3)
#
#                         geometry
# 0    POINT (-71.97748 -13.52107)
# 1    POINT (-72.88261 -13.63997)
# 2    POINT (-70.12756 -15.47827)
# 3     POINT (-77.86943 -6.23041)
# 4     POINT (-76.36539 -6.49004)
# ..                           ...
# 210  POINT (-77.05831 -12.02987)
# 211  POINT (-77.05295 -12.08215)
# 212  POINT (-70.53580 -16.13940)
# 213  POINT (-70.25080 -18.01370)
# 214  POINT (-72.87916 -13.63631)
#
# [215 rows x 22 columns]

# %%
# Read the shapefile for department boundaries
dept_boundaries_path = '../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp'
dept_boundaries = gpd.read_file(dept_boundaries_path) #We use read_file from GeoPandas to charge the data from the shapefile specified in dept_boundaries_path 

#Now we have a GeoDataFrame "dept_boundaries" which contains the department boundaries from the shapefile 
dept_boundaries
# Out:
#     OBJECTID_1  OBJECTID CCDD        NOMBDEP           CAPITAL  Shape_STAr  \
# 0            1       1.0   01       AMAZONAS       CHACHAPOYAS    3.203006
# 1            2       2.0   02         ANCASH            HUARAZ    2.954592
# 2            3       3.0   03       APURIMAC           ABANCAY    1.765933
# 3            4       4.0   04       AREQUIPA          AREQUIPA    5.330203
# 4            5       5.0   05       AYACUCHO          AYACUCHO    3.643705
# 5            6       6.0   06      CAJAMARCA         CAJAMARCA    2.684527
# 6            7       7.0   07         CALLAO            CALLAO    0.011738
# 7            8       8.0   08          CUSCO             CUSCO    6.000331
# 8            9       9.0   09   HUANCAVELICA      HUANCAVELICA    1.839851
# 9           10      10.0   10        HUANUCO           HUANUCO    3.089811
# 10          11      11.0   11            ICA               ICA    1.767025
# 11          12      12.0   12          JUNIN          HUANCAYO    3.658881
# 12          13      13.0   13    LA LIBERTAD          TRUJILLO    2.068780
# 13          14      14.0   14     LAMBAYEQUE          CHICLAYO    1.184994
# 14          15      15.0   15           LIMA              LIMA    2.904475
# 15          19      16.0   16         LORETO           IQUITOS   30.550256
# 16          20      17.0   17  MADRE DE DIOS  PUERTO MALDONADO    7.023854
# 17          21      18.0   18       MOQUEGUA          MOQUEGUA    1.334888
# 18          22      19.0   19          PASCO    CERRO DE PASCO    1.972864
# 19          23      20.0   20          PIURA             PIURA    2.899223
# 20          24      21.0   21           PUNO              PUNO    5.666684
# 21          31      22.0   22     SAN MARTIN         MOYOBAMBA    4.174664
# 22          32      23.0   23          TACNA             TACNA    1.362022
# 23          33      24.0   24         TUMBES            TUMBES    0.378757
# 24          34      25.0   25        UCAYALI          PUCALLPA    8.660111
#
#     Shape_STLe  ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0    12.912088         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1    11.780424         1   11.780424    2.954592  juan.suyo@geogpsperu.com
# 2     7.730154         2    7.730154    1.765933  juan.suyo@geogpsperu.com
# 3    17.405040         3   17.405040    5.330203  juan.suyo@geogpsperu.com
# 4    17.127166         4   17.127166    3.643705  juan.suyo@geogpsperu.com
# 5    12.397424         5   12.397424    2.684527  juan.suyo@geogpsperu.com
# 6     1.111221         6    1.111221    0.011738  juan.suyo@geogpsperu.com
# 7    21.794434         7   21.794434    6.000331  juan.suyo@geogpsperu.com
# 8     9.561245         8    9.561245    1.839851  juan.suyo@geogpsperu.com
# 9    14.589840         9   14.589840    3.089811  juan.suyo@geogpsperu.com
# 10   10.374368        10   10.374368    1.767025  juan.suyo@geogpsperu.com
# 11   14.314727        11   14.314727    3.658881  juan.suyo@geogpsperu.com
# 12   13.148266        12   13.148266    2.068780  juan.suyo@geogpsperu.com
# 13    6.685351        13    6.685351    1.184994  juan.suyo@geogpsperu.com
# 14   12.745226        14   12.745226    2.904475  juan.suyo@geogpsperu.com
# 15   46.701789        15   46.701789   30.550256  juan.suyo@geogpsperu.com
# 16   15.416397        16   15.416397    7.023854  juan.suyo@geogpsperu.com
# 17    7.720424        17    7.720424    1.334888  juan.suyo@geogpsperu.com
# 18   10.891698        18   10.891698    1.972864  juan.suyo@geogpsperu.com
# 19   11.299471        19   11.299471    2.899223  juan.suyo@geogpsperu.com
# 20   26.709721        20   26.709721    5.666684  juan.suyo@geogpsperu.com
# 21   16.162954        21   16.162954    4.174664  juan.suyo@geogpsperu.com
# 22    6.088704        22    6.088704    1.362022  juan.suyo@geogpsperu.com
# 23    3.787977        23    3.787977    0.378757  juan.suyo@geogpsperu.com
# 24   27.470159        24   27.470159    8.660111  juan.suyo@geogpsperu.com
#
#               CONTACTO   WHATSAPP  \
# 0   www.geogpsperu.com  931381206
# 1   www.geogpsperu.com  931381206
# 2   www.geogpsperu.com  931381206
# 3   www.geogpsperu.com  931381206
# 4   www.geogpsperu.com  931381206
# 5   www.geogpsperu.com  931381206
# 6   www.geogpsperu.com  931381206
# 7   www.geogpsperu.com  931381206
# 8   www.geogpsperu.com  931381206
# 9   www.geogpsperu.com  931381206
# 10  www.geogpsperu.com  931381206
# 11  www.geogpsperu.com  931381206
# 12  www.geogpsperu.com  931381206
# 13  www.geogpsperu.com  931381206
# 14  www.geogpsperu.com  931381206
# 15  www.geogpsperu.com  931381206
# 16  www.geogpsperu.com  931381206
# 17  www.geogpsperu.com  931381206
# 18  www.geogpsperu.com  931381206
# 19  www.geogpsperu.com  931381206
# 20  www.geogpsperu.com  931381206
# 21  www.geogpsperu.com  931381206
# 22  www.geogpsperu.com  931381206
# 23  www.geogpsperu.com  931381206
# 24  www.geogpsperu.com  931381206
#
#                                              geometry
# 0   POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1   POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2   POLYGON ((-73.74655 -13.17442, -73.74570 -13.1...
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
# 5   POLYGON ((-78.22182 -7.76346, -78.22233 -7.763...
# 6   POLYGON ((-77.13504 -11.81820, -77.13484 -11.8...
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...
# 9   POLYGON ((-75.99200 -8.32108, -75.99015 -8.321...
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...
# 14  MULTIPOLYGON (((-76.79732 -12.47686, -76.79732...
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...
# 19  POLYGON ((-81.02621 -4.10594, -81.02557 -4.106...
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...

# %%
# Intersect institutes with department boundaries
institutes_with_departments = gpd.overlay(inst_geo, dept_boundaries, how='intersection')
        #with GPD OVERLAY we can calculate the geometrical intersection between the ubications of institutes and department boundaries
institutes_with_departments
# Out:
#      cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0     207597                    307                               481
# 1     207613                    240                               502
# 2     239970                    537                              1047
# 3     262311                    423                               526
# 4     273979                    425                               544
# ..       ...                    ...                               ...
# 210  1468594                   1566                               250
# 211  1468610                    284                                74
# 212  1545623                    210                               266
# 213  1595495                    206                               144
# 214  1637859                    180                               134
#
#      sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  \
# 0                       302                      301  0.980456  1.566775
# 1                       204                      204  0.850000  2.091667
# 2                       484                      476  0.886406  1.949721
# 3                       353                      349  0.825059  1.243499
# 4                       411                      405  0.952941  1.280000
# ..                      ...                      ...       ...       ...
# 210                     241                      202  0.128991  0.159642
# 211                      71                       71  0.250000  0.260563
# 212                     184                      177  0.842857  1.266667
# 213                     141                      137  0.665049  0.699029
# 214                     125                      125  0.694444  0.744444
#
#       dif  dif1   nlat_ie  ...      CAPITAL  Shape_STAr  Shape_STLe  ORIG_FID  \
# 0      -6   174 -13.52107  ...        CUSCO    6.000331   21.794434         7
# 1     -36   262 -13.63997  ...      ABANCAY    1.765933    7.730154         2
# 2     -61   510 -15.47827  ...         PUNO    5.666684   26.709721        20
# 3     -74   103  -6.23041  ...  CHACHAPOYAS    3.203006   12.912088         0
# 4     -20   119  -6.49004  ...    MOYOBAMBA    4.174664   16.162954        21
# ..    ...   ...       ...  ...          ...         ...         ...       ...
# 210 -1364 -1316 -12.02987  ...         LIMA    2.904475   12.745226        14
# 211  -213  -210 -12.08215  ...         LIMA    2.904475   12.745226        14
# 212   -33    56 -16.13940  ...     MOQUEGUA    1.334888    7.720424        17
# 213   -69   -62 -18.01370  ...        TACNA    1.362022    6.088704        22
# 214   -55   -46 -13.63631  ...      ABANCAY    1.765933    7.730154         2
#
#      Shape_Leng  Shape_Area                    CORREO            CONTACTO  \
# 0     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 1      7.730154    1.765933  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 2     26.709721    5.666684  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 3     12.912088    3.203006  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 4     16.162954    4.174664  juan.suyo@geogpsperu.com  www.geogpsperu.com
# ..          ...         ...                       ...                 ...
# 210   12.745226    2.904475  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 211   12.745226    2.904475  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 212    7.720424    1.334888  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 213    6.088704    1.362022  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 214    7.730154    1.765933  juan.suyo@geogpsperu.com  www.geogpsperu.com
#
#       WHATSAPP                     geometry
# 0    931381206  POINT (-71.97748 -13.52107)
# 1    931381206  POINT (-72.88261 -13.63997)
# 2    931381206  POINT (-70.12756 -15.47827)
# 3    931381206   POINT (-77.86943 -6.23041)
# 4    931381206   POINT (-76.36539 -6.49004)
# ..         ...                          ...
# 210  931381206  POINT (-77.05831 -12.02987)
# 211  931381206  POINT (-77.05295 -12.08215)
# 212  931381206  POINT (-70.53580 -16.13940)
# 213  931381206  POINT (-70.25080 -18.01370)
# 214  931381206  POINT (-72.87916 -13.63631)
#
# [215 rows x 35 columns]

# %%
encabezados_columnas = institutes_with_departments.columns.tolist()

# Print the list of column headers
print(encabezados_columnas)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge', 'OBJECTID_1', 'OBJECTID', 'CCDD', 'NOMBDEP', 'CAPITAL', 'Shape_STAr', 'Shape_STLe', 'ORIG_FID', 'Shape_Leng', 'Shape_Area', 'CORREO', 'CONTACTO', 'WHATSAPP', 'geometry']

# %%
# group data by department name ('NOMBDEP') and aggregate specific columns to calculate the total 
#number of vacancies, applicants, entrants, and enrolled students for each department
grouped = institutes_with_departments.groupby('NOMBDEP').agg({
    'ltimoden_metaatencion': 'sum',  # total vacancies
    'cuentadeid_postulante_procesoadm': 'sum',  # Total applicants
    'sumaden_flagingresante': 'sum',  # Total entrants
    'sumaden_flagmatriculado': 'sum'  # Total enrolled students
}).reset_index()

# Merge the aggregated data with the departmental boundaries
dept_vacancies = dept_boundaries.merge(grouped, on='NOMBDEP')

# Create the choropleth map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
dept_vacancies.plot(
    column='ltimoden_metaatencion',
    cmap='YlGnBu',
    legend=True,
    scheme='quantiles',
    ax=ax
)

# Manually configure the legend
leg = ax.get_legend()
leg.set_title('Total Vacancies by Department')
leg.set_bbox_to_anchor((1.5, 0.5))

plt.show()

# %% [markdown]
# # 2. Make an interactive map of markes using visual_html function and show total vacancies, applicants, entrants, and enrolled information in a table popup

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (0.15.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: branca>=0.6.0 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from folium) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from requests->folium) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josue\anaconda3\envs\grupo4\lib\site-packages (from requests->folium) (2024.2.2)

# %%
import folium

# %%
#1.  Create a base map
mapa1 = folium.Map(location=[-9.19, -75.0152], zoom_start=6)  # Coordenadas centrales de Perú

#2.  Add markers to the map.
for idx, row in institutes_with_departments.iterrows(): 
    # Crear el contenido HTML para la ventana emergente
    html_content = folium.Html(f"""
        <table>
            <tr><th>Total Vacancies:</th><td>{row['ltimoden_metaatencion']}</td></tr>
            <tr><th>Total Applicants:</th><td>{row['cuentadeid_postulante_procesoadm']}</td></tr>
            <tr><th>Total Entrants:</th><td>{row['sumaden_flagingresante']}</td></tr>
            <tr><th>Total Enrolled:</th><td>{row['sumaden_flagmatriculado']}</td></tr>
        </table>
    """, script=True)

    # Create the popup window with HTML content
    popup = folium.Popup(html_content, max_width=2650)

    # Add the marker with the popup window to the map
    folium.Marker(    #Crear un marcador para cada institución, ubicándolo en las coordenadas especificadas
        [row['nlat_ie'], row['nlong_ie']],
        popup=popup,
        icon=folium.Icon(icon='university', prefix='fa')  # Utiliza el ícono de universidad de FontAwesome
    ).add_to(mapa1)

#3. Display the map
mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4d013aea5f2e2a1be1b42029cedf37f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4d013aea5f2e2a1be1b42029cedf37f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4d013aea5f2e2a1be1b42029cedf37f = L.map(
#                 &quot;map_a4d013aea5f2e2a1be1b42029cedf37f&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ba78ecdda80ff2d7aa995e19637bb83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ba78ecdda80ff2d7aa995e19637bb83.addTo(map_a4d013aea5f2e2a1be1b42029cedf37f);
#
#
#             var marker_19613525fa47f3f0e680085ad9ce539b = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(map_a4d013aea5f2e2a1be1b42029cedf37f);
#
#
#             var icon_601e77fbd7179ef13fc1a91c86535beb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_19613525fa47f3f0e680085ad9ce539b.setIcon(icon_601e77fbd7179ef13fc1a91c86535beb);
#
#
#         var popup_11bebac0ec3e04a9df4f203e62839a6d = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_52ea9f1d274cd940a384077527bfbf80 = $(`&lt;div id=&quot;html_52ea9f1d274cd940a384077527bfbf80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;307&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;481&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;302&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;301&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_11bebac0ec3e04a9df4f203e62839a6d.setContent(html_52ea9f1d274cd940a384077527bfbf80);
#
#
#
#         marker_19613525fa47f3f0e680085ad9ce539b.bindPopup(popup_11bebac0ec3e04a9df4f203e62839a6d)
#         ;
#
#
#
#
#             var marker_dfcb8c2f4fc279372747c1ac010e7e18 = L.marker(
#                 [-13.63997, -72.88261],
#                 {}
#             ).addTo(map_a4d013aea5f2e2a1be1b42029cedf37f);
#
#
#             var icon_b0994c5c458b085b916e401730d76bf7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dfcb8c2f4fc279372747c1ac010e7e18.setIcon(icon_b0994c5c458b085b916e401730d76bf7);
#
#
#         var popup_6c8e21c6ffa1d9cbe8fd387345143d89 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_8abe8e6716fa53d0cf69b861b2dbb303 = $(`&lt;div id=&quot;html_8abe8e6716fa53d0cf69b861b2dbb303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;240&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;502&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_6c8e21c6ffa1d9cbe8fd387345143d89.setContent(html_8abe8e6716fa53d0cf69b861b2dbb303);
#
#
#
#         marker_dfcb8c2f4fc279372747c1ac010e7e18.bindPopup(popup_6c8e21c6ffa1d9cbe8fd387345143d89)
#         ;
#
#
#
#
#             var marker_8bdb604e5c680f4f27508fd2aa2b6308 = L.marker(
#                 [-15.47827, -70.12756],
#                 {}
#             ).addTo(map_a4d013aea5f2e2a1be1b42029cedf37f);
#
#
#             var icon_9c4785fa1acf245fee9bcb9bdff709d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8bdb604e5c680f4f27508fd2aa2b6308.setIcon(icon_9c4785fa1acf245fee9bcb9bdff709d1);
#
#
#         var popup_6b76a7f73f54e2316a76c5d69c876505 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_1a4dd79cca93d2110832c62c110c38d5 = $(`&lt;div id=&quot;html_1a4dd79cca93d2110832c62c110c38d5&quot; style=&quo

# %% [markdown]
# ### 3. Generate the ratio of applicants by vacancies and store it in a new column called ratio_applicants_vacancies ( total applicants / total vacancies ).

# %%
import folium
from folium.plugins import MarkerCluster

# %%
institutes_with_departments['ratio_applicants_vacancies'] = (
    institutes_with_departments['cuentadeid_postulante_procesoadm'] /
    institutes_with_departments['ltimoden_metaatencion']
)

institutes_with_departments.columns.tolist() #We see that we have created the desired column "Ratio_applicants_vacancies"
# Out:
# ['cod_mod',
#  'ltimoden_metaatencion',
#  'cuentadeid_postulante_procesoadm',
#  'sumaden_flagingresante',
#  'sumaden_flagmatriculado',
#  'ratio',
#  'ratio1',
#  'dif',
#  'dif1',
#  'nlat_ie',
#  'nlong_ie',
#  'population_ccpp',
#  'altitude',
#  'Dblock1km',
#  'Dblock2km',
#  'Dblock3km',
#  'Dblock5km',
#  'Dblock10km',
#  'Dblock20km',
#  'Dblock30km',
#  '_merge',
#  'OBJECTID_1',
#  'OBJECTID',
#  'CCDD',
#  'NOMBDEP',
#  'CAPITAL',
#  'Shape_STAr',
#  'Shape_STLe',
#  'ORIG_FID',
#  'Shape_Leng',
#  'Shape_Area',
#  'CORREO',
#  'CONTACTO',
#  'WHATSAPP',
#  'geometry',
#  'ratio_applicants_vacancies']

# %% [markdown]
# ### 3.1. Then, generate a cluster map with two groups of marker clusters.
#
# The first group should be compound by those institutes where there were more applicants than vacancies. Name this group as **Applicant Surplus**. The second group should be compound by those institutes where there were more vacancies than applicants. Name this group as **Applicant Deficit**

# %%
#Create a base map 
mapa = folium.Map(location=[-9.19, -75.0152], zoom_start=6)

# Crear clusters de marcadores
surplus_cluster = MarkerCluster(name='Applicant Surplus').add_to(mapa)
deficit_cluster = MarkerCluster(name='Applicant Deficit').add_to(mapa)

# Iterar sobre el DataFrame y añadir los marcadores a los clusters correspondientes
for idx, row in institutes_with_departments.iterrows():
    if row['ratio_applicants_vacancies'] > 1:
        # Más solicitantes que vacantes
        folium.Marker(
            location=[row['nlat_ie'], row['nlong_ie']],
            popup=f"Surplus: {row['ratio_applicants_vacancies']}",
            icon=folium.Icon(color='red')
        ).add_to(surplus_cluster)
        surplus_cluster
    else:
        # Más vacantes que solicitantes
        folium.Marker(
            location=[row['nlat_ie'], row['nlong_ie']],
            popup=f"Deficit: {row['ratio_applicants_vacancies']}",
            icon=folium.Icon(color='green')
        ).add_to(deficit_cluster)

# Añadir capas de control para alternar la visualización de los clusters
folium.LayerControl().add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c795aae18f29ccd82a4669ae8fa7190 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c795aae18f29ccd82a4669ae8fa7190&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c795aae18f29ccd82a4669ae8fa7190 = L.map(
#                 &quot;map_0c795aae18f29ccd82a4669ae8fa7190&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c757a715bab876a6784045a027d3f73a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c757a715bab876a6784045a027d3f73a.addTo(map_0c795aae18f29ccd82a4669ae8fa7190);
#
#
#             var marker_cluster_257a985a6a2f8385ddac229d2cf67354 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_57460762c423db0d1d4474aac674ad60 = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(marker_cluster_257a985a6a2f8385ddac229d2cf67354);
#
#
#             var icon_e1d6a2d78ed731be1dd9903eb91e8593 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57460762c423db0d1d4474aac674ad60.setIcon(icon_e1d6a2d78ed731be1dd9903eb91e8593);
#
#
#         var popup_7adb86f32cd3cbbc3c805ab46ebd8cc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20dc1abcbb2e52d18c45b5aa7a2498c0 = $(`&lt;div id=&quot;html_20dc1abcbb2e52d18c45b5aa7a2498c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 1.5667752442996743&lt;/div&gt;`)[0];
#                 popup_7adb86f32cd3cbbc3c805ab46ebd8cc2.setContent(html_20dc1abcbb2e52d18c45b5aa7a2498c0);
#
#
#
#         marker_57460762c423db0d1d4474aac674ad60.bindPopup(popup_7adb86f32cd3cbbc3c805ab46ebd8cc2)
#         ;
#
#
#
#
#             var marker_8e009a99015225e5ae5b2bc2f83b34dc = L.marker(
#                 [-13.63997, -72.88261],
#                 {}
#             ).addTo(marker_cluster_257a985a6a2f8385ddac229d2cf67354);
#
#
#             var icon_ad58e2fc173091c93d2388b15f17cbb2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e009a99015225e5ae5b2bc2f83b34dc.setIcon(icon_ad58e2fc173091c93d2388b15f17cbb2);
#
#
#         var popup_781bfbce177890fb554b78cc1c52a65c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_924230e4a65083106e9efcfe23294a0e = $(`&lt;div id=&quot;html_924230e4a65083106e9efcfe23294a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 2.091666666666667&lt;/div&gt;`)[0];
#                 popup_781bfbce177890fb554b78cc1c52a65c.setContent(html_924230e4a65083106e9efcfe23294a0e);
#
#
#
#         marker_8e009a99015225e5ae5b2bc2f83b34dc.bindPopup(popup_781bfbce177890fb554b78cc1c52a65c)
#         ;
#
#
#
#
#             var marker_8a85b4f2da91dde2761c8b16f9e3af74 = L.marker(
#                 [-15.47827, -70.12756],
#                 {}
#             ).addTo(marker_cluster_257a985a6a2f8385ddac229d2cf67354);
#
#
#             var icon_32f43ccc5d8c2553e8b7a3ee547f2aea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a85b4f2da91dde2761c8b16f9e3af74.setIcon(icon_32f43ccc5d8c2553e8b7a3ee547f2aea);
#
#
#         var popup_4534c2462f01da1eb58cc48e8fe656ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ef6d68d37e3a94e899f5a7176a5d200 = $(`&lt;div id=&quot;html_8ef6d68d37e3a94e899f5a7176a5d200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 1.9497206703910615&lt;/div&gt;`)[0];
#                 popup_4534c2462f01da1eb58cc48e8fe656e

# %% [markdown]
# # 4. Generate a Circle map and plot only institutes with more applicants than vacancies. Make the radius= *ratio_applicants_vacancies* * 10000 . Make these circles of color green. Name the layer of circles as Applicant Surplus. Use FeatureGroup
# Take this map as an example

# %%
# Filtering institutes with more applicants than vacancies and storing the result in 'applicant_surplus_data'
applicant_surplus_data= institutes_with_departments[institutes_with_departments['ratio_applicants_vacancies']>1]

# Displaying the first three rows of the filtered data
applicant_surplus_data.head(3)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
#
#    dif1   nlat_ie  ...  Shape_STAr  Shape_STLe  ORIG_FID  Shape_Leng  \
# 0   174 -13.52107  ...    6.000331   21.794434         7   21.794434
# 1   262 -13.63997  ...    1.765933    7.730154         2    7.730154
# 2   510 -15.47827  ...    5.666684   26.709721        20   26.709721
#
#    Shape_Area                    CORREO            CONTACTO   WHATSAPP  \
# 0    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 1    1.765933  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 2    5.666684  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
#
#                       geometry  ratio_applicants_vacancies
# 0  POINT (-71.97748 -13.52107)                    1.566775
# 1  POINT (-72.88261 -13.63997)                    2.091667
# 2  POINT (-70.12756 -15.47827)                    1.949721
#
# [3 rows x 36 columns]

# %%
# Creating a Circle Map for Applicant Surplus centered on Peru
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

# Creating a FeatureGroup for Applicant Surplus with control enabled
ap_s = folium.FeatureGroup(name='Applicant Surplus', control=True)

# Iterating over the DataFrame to add circles representing institutes with more applicants than vacancies
for _, row in applicant_surplus_data.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#4da170",
                  color="#4da170").add_to(ap_s)
    
# Adding the Applicant Surplus FeatureGroup to the map
ap_s.add_to(mapa)  

# Adding layer control to the map
folium.LayerControl().add_to(mapa)  

# Displaying the map
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_615c9443bdeb956b5859e9b27ee366cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_615c9443bdeb956b5859e9b27ee366cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_615c9443bdeb956b5859e9b27ee366cc = L.map(
#                 &quot;map_615c9443bdeb956b5859e9b27ee366cc&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6c58339ea4ac44f1e3f16defa35b11b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d6c58339ea4ac44f1e3f16defa35b11b.addTo(map_615c9443bdeb956b5859e9b27ee366cc);
#
#
#             var feature_group_409cdabccd49103eec8d373198fa2150 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_fa62bb7ff7684cf33abe52bfb8b8d7d8 = L.circle(
#                 [-13.52107, -71.97748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15667.752442996743, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_409cdabccd49103eec8d373198fa2150);
#
#
#             var circle_474f387c97ddefde128fc40a3844ec9e = L.circle(
#                 [-13.63997, -72.88261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20916.666666666668, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_409cdabccd49103eec8d373198fa2150);
#
#
#             var circle_e88d0f24a011d022304aeff209807e5b = L.circle(
#                 [-15.47827, -70.12756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19497.206703910615, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_409cdabccd49103eec8d373198fa2150);
#
#
#             var circle_941ca2bf64ec14cf803b12316d40cc17 = L.circle(
#                 [-6.23041, -77.86943],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12434.988179669032, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_409cdabccd49103eec8d373198fa2150);
#
#
#             var circle_49efc5f0a55e8a71907f6a305440a658 = L.circle(
#                 [-6.49004, -76.36539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12800.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_409cdabccd49103eec8d373198fa2150);
#
#
#             var circle_c1ecac846ff6fc05ffe941f8dfde840a = L.circle(
#                 [-9.9344, -76.2369],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19590.36144578313, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(featu

# %% [markdown]
# # 5. Generate a Circle map and plot only institutes with less applicants than vacancies. Make the radius= ratio_applicants_vacancies * 10000 . Make these circles of color red. Name the layer of circles as Applicant Deficit. Use FeatureGroup.

# %%
# Filtering institutes with less applicants than vacancies and storing the result in 'applicant_deficit_data'
applicant_deficit_data= institutes_with_departments[institutes_with_departments['ratio_applicants_vacancies']<1]

# Displaying the first three rows of the filtered data
applicant_deficit_data.head(3)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 5   276188                    570                               461
# 8   356972                    480                               430
# 9   380501                    180                               112
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 5                     426                      406  0.712281  0.808772 -164
# 8                     316                      316  0.658333  0.895833 -164
# 9                     112                      110  0.611111  0.622222  -70
#
#    dif1   nlat_ie  ...  Shape_STAr  Shape_STLe  ORIG_FID  Shape_Leng  \
# 5  -109 -14.05115  ...    1.767025   10.374368        10   10.374368
# 8   -50  -5.18106  ...    2.899223   11.299471        19   11.299471
# 9   -68 -11.25390  ...    3.658881   14.314727        11   14.314727
#
#    Shape_Area                    CORREO            CONTACTO   WHATSAPP  \
# 5    1.767025  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 8    2.899223  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 9    3.658881  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
#
#                       geometry  ratio_applicants_vacancies
# 5  POINT (-75.75387 -14.05115)                    0.808772
# 8   POINT (-80.66289 -5.18106)                    0.895833
# 9  POINT (-74.63700 -11.25390)                    0.622222
#
# [3 rows x 36 columns]

# %%
# Creating a Circle Map for Applicant Deficit centered on Peru
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

# Creating a FeatureGroup for Applicant Deficit with control enabled
ap_d = folium.FeatureGroup(name='Applicant Deficit', control=True)

# Iterating over the DataFrame to add circles representing institutes with less applicants than vacancies
for _, row in applicant_deficit_data.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="red",
                  color="red").add_to(ap_d)
    
# Adding the Applicant Deficit FeatureGroup to the map
ap_d.add_to(mapa)  

# Adding layer control to the map
folium.LayerControl().add_to(mapa)  

# Displaying the map
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48a59a1be18fc2f8103025467913ccff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48a59a1be18fc2f8103025467913ccff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48a59a1be18fc2f8103025467913ccff = L.map(
#                 &quot;map_48a59a1be18fc2f8103025467913ccff&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a32ab6b4eafb57eaf00c734244d1349 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a32ab6b4eafb57eaf00c734244d1349.addTo(map_48a59a1be18fc2f8103025467913ccff);
#
#
#             var feature_group_a6321a230030fb0017e8e22aaf6fac77 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_53ec307961b6b7bec58ed8bfd3de8975 = L.circle(
#                 [-14.05115, -75.75387],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8087.719298245614, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);
#
#
#             var circle_f9c913308e04cb8ae1f30d3f598a07fb = L.circle(
#                 [-5.18106, -80.66289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8958.333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);
#
#
#             var circle_9d4ca32a923bf129f1fdecb569970ee4 = L.circle(
#                 [-11.2539, -74.637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6222.222222222223, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);
#
#
#             var circle_1067f1ea8e2659db5555f25121903047 = L.circle(
#                 [-12.04935, -77.03284],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1576.283441793203, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);
#
#
#             var circle_b64ef161372d190b270cc5534dab3d10 = L.circle(
#                 [-11.38346, -75.68851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9980.079681274901, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);
#
#
#             var circle_0452c78f3f1eead3ea63da67fedd1f64 = L.circle(
#                 [-7.9025, -78.5657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7021.857923497268, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a6321a230030fb0017e8e22aaf6fac77);

# %% [markdown]
# # 6. Generate a Circle Map that combines map 4 and 5 into a unique map. Use FeatureGroup. Additionally, generate a legend for this map indicating the color and label.

# %% [markdown]
# ### Import packages that we used to create the html legend

# %%
from folium import plugins
from branca.element import Template, MacroElement

# %% [markdown]
# ### Create base map

# %%
## Create map
# Creating a Circle Map for Applicant Deficit centered on Peru
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

## Include Applicant Deficit
# Creating a FeatureGroup for Applicant Deficit with control enabled
ap_d = folium.FeatureGroup(name='Applicant Deficit', col = "red", control=True)

# Iterating over the DataFrame to add circles representing institutes with less applicants than vacancies
for _, row in applicant_deficit_data.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="red",
                  color="red").add_to(ap_d)
    
# Adding the Applicant Deficit FeatureGroup to the map
ap_d.add_to(mapa)  

## Include Applicant Surplus
# Creating a FeatureGroup for Applicant Surplus with control enabled
ap_s = folium.FeatureGroup(name='Applicant Surplus', col = "#4da170", control=True)

# Iterating over the DataFrame to add circles representing institutes with more applicants than vacancies
for _, row in applicant_surplus_data.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#4da170",
                  color="#4da170").add_to(ap_s)
    
# Adding the Applicant Surplus FeatureGroup to the map
ap_s.add_to(mapa)  
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00442ca46f85a7e45b7a31b44ca9d4e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00442ca46f85a7e45b7a31b44ca9d4e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00442ca46f85a7e45b7a31b44ca9d4e3 = L.map(
#                 &quot;map_00442ca46f85a7e45b7a31b44ca9d4e3&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1021508b3dff27fa92b712ddff8b4eac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1021508b3dff27fa92b712ddff8b4eac.addTo(map_00442ca46f85a7e45b7a31b44ca9d4e3);
#
#
#             var feature_group_c06ee8cae605d73a61c5fb34c903cb78 = L.featureGroup(
#                 {&quot;col&quot;: &quot;red&quot;}
#             );
#
#
#             var circle_9d82dfb6b528dccaae239b2c49861068 = L.circle(
#                 [-14.05115, -75.75387],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8087.719298245614, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06ee8cae605d73a61c5fb34c903cb78);
#
#
#             var circle_3c8442878f1339a588e72128a178b1c3 = L.circle(
#                 [-5.18106, -80.66289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8958.333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06ee8cae605d73a61c5fb34c903cb78);
#
#
#             var circle_9260a6e69e502741ab0b65b18dce44ca = L.circle(
#                 [-11.2539, -74.637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6222.222222222223, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06ee8cae605d73a61c5fb34c903cb78);
#
#
#             var circle_dd4438961e1894ffa2e2ee9d68303595 = L.circle(
#                 [-12.04935, -77.03284],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1576.283441793203, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06ee8cae605d73a61c5fb34c903cb78);
#
#
#             var circle_7f9c81ea73f6d59a8923c93a822cc02e = L.circle(
#                 [-11.38346, -75.68851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9980.079681274901, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06ee8cae605d73a61c5fb34c903cb78);
#
#
#             var circle_e0b430e1f47cc8a07e242c322fbe4bd2 = L.circle(
#                 [-7.9025, -78.5657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7021.857923497268, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c06

# %% [markdown]
# ### Include legend with html code in the map

# %%
# Create hmtl legend: set position, style and details
legend_html = '''
     <div style="position: fixed; 
                 bottom: 50px; left: 50px; width: 150px; height: 90px; 
                 border:2px solid grey; z-index:9999; font-size:10px;
                 background-color:white;
                 ">&nbsp; <b>Leyenda</b> <br>
                  &nbsp; Déficit de Solicitantes &nbsp; <i class="fa fa-circle fa-1x" style="color:red"></i><br>
                  &nbsp; Excedente de Solicitantes &nbsp; <i class="fa fa-circle fa-1x" style="color:#4da170"></i>
      </div>
     '''
# Add html legend to our mapa object
mapa.get_root().html.add_child(folium.Element(legend_html))

# Add control to our Mapa
folium.map.LayerControl('topleft', collapsed=False).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_516d5798062a6c4be17ea5b84f75004d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_516d5798062a6c4be17ea5b84f75004d&quot; &gt;&lt;/div&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#                  bottom: 50px; left: 50px; width: 150px; height: 90px;
#                  border:2px solid grey; z-index:9999; font-size:10px;
#                  background-color:white;
#                  &quot;&gt;&amp;nbsp; &lt;b&gt;Leyenda&lt;/b&gt; &lt;br&gt;
#                   &amp;nbsp; Déficit de Solicitantes &amp;nbsp; &lt;i class=&quot;fa fa-circle fa-1x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&lt;br&gt;
#                   &amp;nbsp; Excedente de Solicitantes &amp;nbsp; &lt;i class=&quot;fa fa-circle fa-1x&quot; style=&quot;color:#4da170&quot;&gt;&lt;/i&gt;
#       &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_516d5798062a6c4be17ea5b84f75004d = L.map(
#                 &quot;map_516d5798062a6c4be17ea5b84f75004d&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46da3e1cb084554b4fbe5baa94b4b28e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_46da3e1cb084554b4fbe5baa94b4b28e.addTo(map_516d5798062a6c4be17ea5b84f75004d);
#
#
#             var feature_group_a02933afb6a20ec58ac5303d80230b8c = L.featureGroup(
#                 {&quot;col&quot;: &quot;red&quot;}
#             );
#
#
#             var circle_08e2621252aa2c0de490be50029edd8f = L.circle(
#                 [-14.05115, -75.75387],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8087.719298245614, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a02933afb6a20ec58ac5303d80230b8c);
#
#
#             var circle_5a10b42ced2dda1fcbdf4969e4aad60f = L.circle(
#                 [-5.18106, -80.66289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8958.333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a02933afb6a20ec58ac5303d80230b8c);
#
#
#             var circle_b789daed2a88878faacb6237baecb6f7 = L.circle(
#                 [-11.2539, -74.637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6222.222222222223, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a02933afb6a20ec58ac5303d80230b8c);
#
#
#             var circle_723170c7bd526af012a241abb79e3d37 = L.circle(
#                 [-12.04935, -77.03284],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1576.283441793203, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a02933afb6a20ec58ac5303d80230b8c);
#
#
#             var circle_21b8ee7742676ad7e0cbec2d16dd3a19 = L.circle(
#                 [-11.38346, -75.68851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9980.079681274901, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a02933afb6a20ec58ac5303d8023
