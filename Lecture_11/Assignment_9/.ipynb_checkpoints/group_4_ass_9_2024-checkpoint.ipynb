# %% [markdown]
# # 1. Importing the data

# %%
# !pip install mapclassify
# Out:
# Collecting mapclassify
#   Obtaining dependency information for mapclassify from https://files.pythonhosted.org/packages/3f/f1/8db36df379703311c16e5341b408dad04e34cfded66f38e351c380fbd5ae/mapclassify-2.6.1-py3-none-any.whl.metadata
#   Downloading mapclassify-2.6.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: networkx>=2.7 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from mapclassify) (3.1)
# Requirement already satisfied: numpy>=1.23 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.24.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.3.0)
# Requirement already satisfied: scipy>=1.8 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.1

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

file_path = '../../_data/institutos1.csv'

# Load the CSV data into a DataFrame
institutos_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data is loaded correctly
print(institutos_df.head())
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
# 3   262311                    423                               526
# 4   273979                    425                               544
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
# 3                     353                      349  0.825059  1.243499  -74
# 4                     411                      405  0.952941  1.280000  -20
#
#    dif1   nlat_ie  ...  population_ccpp  altitude  Dblock1km  Dblock2km  \
# 0   174 -13.52107  ...         106400.0    3386.0   14840369     742184
# 1   262 -13.63997  ...          45864.0    2342.0   14970470     748235
# 2   510 -15.47827  ...         216716.0    3831.0   17000163     850081
# 3   103  -6.23041  ...          23202.0    2358.0    6781025     339512
# 4   119  -6.49004  ...          67362.0     309.0    7070857     353428
#
#    Dblock3km  Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge
# 0     494123     296073      148036        7418        4912  matched (3)
# 1     499156     299094      149047        7423        4915  matched (3)
# 2     566054     340032      170016        8508        5605  matched (3)
# 3     226341     135205       67102        3351        2234  matched (3)
# 4     235285     141171       70085        3542        2328  matched (3)
#
# [5 rows x 21 columns]

# %%
encabezados = institutos_df.columns.tolist()

# Print the list of column headers
print(encabezados)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge']

# %% [markdown]
# # 1. 2. generate a Choropleth map of the total institutes' vacancies by the department

# %%
import geopandas as gpd
import pandas as pd
inst_geo = gpd.GeoDataFrame(
    institutos_df,
    geometry=gpd.points_from_xy(institutos_df.nlong_ie, institutos_df.nlat_ie),
    crs='EPSG:4326'
)
# Now 'inst_geo' is a GeoDataFrame with the institutes' data including a geometry column with point data
inst_geo
# Out:
#      cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0     207597                    307                               481
# 1     207613                    240                               502
# 2     239970                    537                              1047
# 3     262311                    423                               526
# 4     273979                    425                               544
# ..       ...                    ...                               ...
# 210  1468594                   1566                               250
# 211  1468610                    284                                74
# 212  1545623                    210                               266
# 213  1595495                    206                               144
# 214  1637859                    180                               134
#
#      sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  \
# 0                       302                      301  0.980456  1.566775
# 1                       204                      204  0.850000  2.091667
# 2                       484                      476  0.886406  1.949721
# 3                       353                      349  0.825059  1.243499
# 4                       411                      405  0.952941  1.280000
# ..                      ...                      ...       ...       ...
# 210                     241                      202  0.128991  0.159642
# 211                      71                       71  0.250000  0.260563
# 212                     184                      177  0.842857  1.266667
# 213                     141                      137  0.665049  0.699029
# 214                     125                      125  0.694444  0.744444
#
#       dif  dif1   nlat_ie  ...  altitude  Dblock1km  Dblock2km  Dblock3km  \
# 0      -6   174 -13.52107  ...    3386.0   14840369     742184     494123
# 1     -36   262 -13.63997  ...    2342.0   14970470     748235     499156
# 2     -61   510 -15.47827  ...    3831.0   17000163     850081     566054
# 3     -74   103  -6.23041  ...    2358.0    6781025     339512     226341
# 4     -20   119  -6.49004  ...     309.0    7070857     353428     235285
# ..    ...   ...       ...  ...       ...        ...        ...        ...
# 210 -1364 -1316 -12.02987  ...     125.0   13190935     659467     439311
# 211  -213  -210 -12.08215  ...     115.0   13250934     662467     441311
# 212   -33    56 -16.13940  ...    3780.0   17740208     887104     591069
# 213   -69   -62 -18.01370  ...     577.0   19810177     990088     660059
# 214   -55   -46 -13.63631  ...    2392.0   14970469     748234     499156
#
#      Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge  \
# 0       296073      148036        7418        4912  matched (3)
# 1       299094      149047        7423        4915  matched (3)
# 2       340032      170016        8508        5605  matched (3)
# 3       135205       67102        3351        2234  matched (3)
# 4       141171       70085        3542        2328  matched (3)
# ..         ...         ...         ...         ...          ...
# 210     263187      131093        6546        4331  matched (3)
# 211     265186      132093        6646        4431  matched (3)
# 212     354041      177020        8810        5906  matched (3)
# 213     396035      198017        9908        6605  matched (3)
# 214     299093      149046        7423        4915  matched (3)
#
#                         geometry
# 0    POINT (-71.97748 -13.52107)
# 1    POINT (-72.88261 -13.63997)
# 2    POINT (-70.12756 -15.47827)
# 3     POINT (-77.86943 -6.23041)
# 4     POINT (-76.36539 -6.49004)
# ..                           ...
# 210  POINT (-77.05831 -12.02987)
# 211  POINT (-77.05295 -12.08215)
# 212  POINT (-70.53580 -16.13940)
# 213  POINT (-70.25080 -18.01370)
# 214  POINT (-72.87916 -13.63631)
#
# [215 rows x 22 columns]

# %%
# Read the shapefile for department boundaries
dept_boundaries_path = '../../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp'
dept_boundaries = gpd.read_file(dept_boundaries_path) #We use read_file from GeoPandas to charge the data from the shapefile specified in dept_boundaries_path 

#Now we have a GeoDataFrame "dept_boundaries" which contains the department boundaries from the shapefile 
dept_boundaries
# Out:
#     OBJECTID_1  OBJECTID CCDD        NOMBDEP           CAPITAL  Shape_STAr  \
# 0            1       1.0   01       AMAZONAS       CHACHAPOYAS    3.203006
# 1            2       2.0   02         ANCASH            HUARAZ    2.954592
# 2            3       3.0   03       APURIMAC           ABANCAY    1.765933
# 3            4       4.0   04       AREQUIPA          AREQUIPA    5.330203
# 4            5       5.0   05       AYACUCHO          AYACUCHO    3.643705
# 5            6       6.0   06      CAJAMARCA         CAJAMARCA    2.684527
# 6            7       7.0   07         CALLAO            CALLAO    0.011738
# 7            8       8.0   08          CUSCO             CUSCO    6.000331
# 8            9       9.0   09   HUANCAVELICA      HUANCAVELICA    1.839851
# 9           10      10.0   10        HUANUCO           HUANUCO    3.089811
# 10          11      11.0   11            ICA               ICA    1.767025
# 11          12      12.0   12          JUNIN          HUANCAYO    3.658881
# 12          13      13.0   13    LA LIBERTAD          TRUJILLO    2.068780
# 13          14      14.0   14     LAMBAYEQUE          CHICLAYO    1.184994
# 14          15      15.0   15           LIMA              LIMA    2.904475
# 15          19      16.0   16         LORETO           IQUITOS   30.550256
# 16          20      17.0   17  MADRE DE DIOS  PUERTO MALDONADO    7.023854
# 17          21      18.0   18       MOQUEGUA          MOQUEGUA    1.334888
# 18          22      19.0   19          PASCO    CERRO DE PASCO    1.972864
# 19          23      20.0   20          PIURA             PIURA    2.899223
# 20          24      21.0   21           PUNO              PUNO    5.666684
# 21          31      22.0   22     SAN MARTIN         MOYOBAMBA    4.174664
# 22          32      23.0   23          TACNA             TACNA    1.362022
# 23          33      24.0   24         TUMBES            TUMBES    0.378757
# 24          34      25.0   25        UCAYALI          PUCALLPA    8.660111
#
#     Shape_STLe  ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0    12.912088         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1    11.780424         1   11.780424    2.954592  juan.suyo@geogpsperu.com
# 2     7.730154         2    7.730154    1.765933  juan.suyo@geogpsperu.com
# 3    17.405040         3   17.405040    5.330203  juan.suyo@geogpsperu.com
# 4    17.127166         4   17.127166    3.643705  juan.suyo@geogpsperu.com
# 5    12.397424         5   12.397424    2.684527  juan.suyo@geogpsperu.com
# 6     1.111221         6    1.111221    0.011738  juan.suyo@geogpsperu.com
# 7    21.794434         7   21.794434    6.000331  juan.suyo@geogpsperu.com
# 8     9.561245         8    9.561245    1.839851  juan.suyo@geogpsperu.com
# 9    14.589840         9   14.589840    3.089811  juan.suyo@geogpsperu.com
# 10   10.374368        10   10.374368    1.767025  juan.suyo@geogpsperu.com
# 11   14.314727        11   14.314727    3.658881  juan.suyo@geogpsperu.com
# 12   13.148266        12   13.148266    2.068780  juan.suyo@geogpsperu.com
# 13    6.685351        13    6.685351    1.184994  juan.suyo@geogpsperu.com
# 14   12.745226        14   12.745226    2.904475  juan.suyo@geogpsperu.com
# 15   46.701789        15   46.701789   30.550256  juan.suyo@geogpsperu.com
# 16   15.416397        16   15.416397    7.023854  juan.suyo@geogpsperu.com
# 17    7.720424        17    7.720424    1.334888  juan.suyo@geogpsperu.com
# 18   10.891698        18   10.891698    1.972864  juan.suyo@geogpsperu.com
# 19   11.299471        19   11.299471    2.899223  juan.suyo@geogpsperu.com
# 20   26.709721        20   26.709721    5.666684  juan.suyo@geogpsperu.com
# 21   16.162954        21   16.162954    4.174664  juan.suyo@geogpsperu.com
# 22    6.088704        22    6.088704    1.362022  juan.suyo@geogpsperu.com
# 23    3.787977        23    3.787977    0.378757  juan.suyo@geogpsperu.com
# 24   27.470159        24   27.470159    8.660111  juan.suyo@geogpsperu.com
#
#               CONTACTO   WHATSAPP  \
# 0   www.geogpsperu.com  931381206
# 1   www.geogpsperu.com  931381206
# 2   www.geogpsperu.com  931381206
# 3   www.geogpsperu.com  931381206
# 4   www.geogpsperu.com  931381206
# 5   www.geogpsperu.com  931381206
# 6   www.geogpsperu.com  931381206
# 7   www.geogpsperu.com  931381206
# 8   www.geogpsperu.com  931381206
# 9   www.geogpsperu.com  931381206
# 10  www.geogpsperu.com  931381206
# 11  www.geogpsperu.com  931381206
# 12  www.geogpsperu.com  931381206
# 13  www.geogpsperu.com  931381206
# 14  www.geogpsperu.com  931381206
# 15  www.geogpsperu.com  931381206
# 16  www.geogpsperu.com  931381206
# 17  www.geogpsperu.com  931381206
# 18  www.geogpsperu.com  931381206
# 19  www.geogpsperu.com  931381206
# 20  www.geogpsperu.com  931381206
# 21  www.geogpsperu.com  931381206
# 22  www.geogpsperu.com  931381206
# 23  www.geogpsperu.com  931381206
# 24  www.geogpsperu.com  931381206
#
#                                              geometry
# 0   POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1   POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2   POLYGON ((-73.74655 -13.17442, -73.74570 -13.1...
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
# 5   POLYGON ((-78.22182 -7.76346, -78.22233 -7.763...
# 6   POLYGON ((-77.13504 -11.81820, -77.13484 -11.8...
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...
# 9   POLYGON ((-75.99200 -8.32108, -75.99015 -8.321...
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...
# 14  MULTIPOLYGON (((-76.79732 -12.47686, -76.79732...
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...
# 19  POLYGON ((-81.02621 -4.10594, -81.02557 -4.106...
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...

# %%
# Intersect institutes with department boundaries
institutes_with_departments = gpd.overlay(inst_geo, dept_boundaries, how='intersection')
        #with GPD OVERLAY we can calculate the geometrical intersection between the ubications of institutes and department boundaries
institutes_with_departments
# Out:
#      cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0     207597                    307                               481
# 1     586669                    516                              1047
# 2     591909                    180                               297
# 3     783399                    220                               404
# 4     928655                    322                               342
# ..       ...                    ...                               ...
# 210  1260223                    210                               134
# 211  1345081                    238                               116
# 212  1192830                    300                               304
# 213  1192954                    480                               285
# 214  1275759                    390                               483
#
#      sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                       302                      301  0.980456  1.566775   -6
# 1                       515                      544  1.054264  2.029070   28
# 2                       169                      169  0.938889  1.650000  -11
# 3                       198                      198  0.900000  1.836364  -22
# 4                       290                      284  0.881988  1.062112  -38
# ..                      ...                      ...       ...       ...  ...
# 210                     134                      134  0.638095  0.638095  -76
# 211                     116                      115  0.483193  0.487395 -123
# 212                     242                      242  0.806667  1.013333  -58
# 213                     267                      264  0.550000  0.593750 -216
# 214                     336                      223  0.571795  1.238462 -167
#
#      dif1   nlat_ie  ...   CAPITAL  Shape_STAr  Shape_STLe  ORIG_FID  \
# 0     174 -13.52107  ...     CUSCO    6.000331   21.794434         7
# 1     531 -14.14240  ...     CUSCO    6.000331   21.794434         7
# 2     117 -13.30178  ...     CUSCO    6.000331   21.794434         7
# 3     184 -14.28296  ...     CUSCO    6.000331   21.794434         7
# 4      20 -13.51273  ...     CUSCO    6.000331   21.794434         7
# ..    ...       ...  ...       ...         ...         ...       ...
# 210   -76 -16.40434  ...  AREQUIPA    5.330203   17.405040         3
# 211  -122 -16.07656  ...  AREQUIPA    5.330203   17.405040         3
# 212     4 -12.01212  ...    CALLAO    0.011738    1.111221         6
# 213  -195 -12.07409  ...    CALLAO    0.011738    1.111221         6
# 214    93  -3.55727  ...    TUMBES    0.378757    3.787977        23
#
#      Shape_Leng  Shape_Area                    CORREO            CONTACTO  \
# 0     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 1     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 2     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 3     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 4     21.794434    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com
# ..          ...         ...                       ...                 ...
# 210   17.405040    5.330203  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 211   17.405040    5.330203  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 212    1.111221    0.011738  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 213    1.111221    0.011738  juan.suyo@geogpsperu.com  www.geogpsperu.com
# 214    3.787977    0.378757  juan.suyo@geogpsperu.com  www.geogpsperu.com
#
#       WHATSAPP                     geometry
# 0    931381206  POINT (-71.97748 -13.52107)
# 1    931381206  POINT (-71.40813 -14.14240)
# 2    931381206  POINT (-72.12163 -13.30178)
# 3    931381206  POINT (-71.22042 -14.28296)
# 4    931381206  POINT (-71.97511 -13.51273)
# ..         ...                          ...
# 210  931381206  POINT (-71.53947 -16.40434)
# 211  931381206  POINT (-72.49262 -16.07656)
# 212  931381206  POINT (-77.10461 -12.01212)
# 213  931381206  POINT (-77.16323 -12.07409)
# 214  931381206   POINT (-80.44333 -3.55727)
#
# [215 rows x 35 columns]

# %%
encabezados_columnas = institutes_with_departments.columns.tolist()

# Print the list of column headers
print(encabezados_columnas)
# Out:
# ['cod_mod', 'ltimoden_metaatencion', 'cuentadeid_postulante_procesoadm', 'sumaden_flagingresante', 'sumaden_flagmatriculado', 'ratio', 'ratio1', 'dif', 'dif1', 'nlat_ie', 'nlong_ie', 'population_ccpp', 'altitude', 'Dblock1km', 'Dblock2km', 'Dblock3km', 'Dblock5km', 'Dblock10km', 'Dblock20km', 'Dblock30km', '_merge', 'OBJECTID_1', 'OBJECTID', 'CCDD', 'NOMBDEP', 'CAPITAL', 'Shape_STAr', 'Shape_STLe', 'ORIG_FID', 'Shape_Leng', 'Shape_Area', 'CORREO', 'CONTACTO', 'WHATSAPP', 'geometry']

# %%
# group data by department name ('NOMBDEP') and aggregate specific columns to calculate the total 
#number of vacancies, applicants, entrants, and enrolled students for each department
grouped = institutes_with_departments.groupby('NOMBDEP').agg({
    'ltimoden_metaatencion': 'sum',  # total vacancies
    'cuentadeid_postulante_procesoadm': 'sum',  # Total applicants
    'sumaden_flagingresante': 'sum',  # Total entrants
    'sumaden_flagmatriculado': 'sum'  # Total enrolled students
}).reset_index()

# Merge the aggregated data with the departmental boundaries
dept_vacancies = dept_boundaries.merge(grouped, on='NOMBDEP')

# Create the choropleth map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
dept_vacancies.plot(
    column='ltimoden_metaatencion',
    cmap='YlGnBu',
    legend=True,
    scheme='quantiles',
    ax=ax
)

# Manually configure the legend
leg = ax.get_legend()
leg.set_title('Total Vacancies by Department')
leg.set_bbox_to_anchor((1.5, 0.5))

plt.show()

# %%
dept_vacancies
# Out:
#     OBJECTID_1  OBJECTID CCDD        NOMBDEP           CAPITAL  Shape_STAr  \
# 0            1       1.0   01       AMAZONAS       CHACHAPOYAS    3.203006
# 1            2       2.0   02         ANCASH            HUARAZ    2.954592
# 2            3       3.0   03       APURIMAC           ABANCAY    1.765933
# 3            4       4.0   04       AREQUIPA          AREQUIPA    5.330203
# 4            5       5.0   05       AYACUCHO          AYACUCHO    3.643705
# 5            6       6.0   06      CAJAMARCA         CAJAMARCA    2.684527
# 6            7       7.0   07         CALLAO            CALLAO    0.011738
# 7            8       8.0   08          CUSCO             CUSCO    6.000331
# 8            9       9.0   09   HUANCAVELICA      HUANCAVELICA    1.839851
# 9           10      10.0   10        HUANUCO           HUANUCO    3.089811
# 10          11      11.0   11            ICA               ICA    1.767025
# 11          12      12.0   12          JUNIN          HUANCAYO    3.658881
# 12          13      13.0   13    LA LIBERTAD          TRUJILLO    2.068780
# 13          14      14.0   14     LAMBAYEQUE          CHICLAYO    1.184994
# 14          15      15.0   15           LIMA              LIMA    2.904475
# 15          19      16.0   16         LORETO           IQUITOS   30.550256
# 16          20      17.0   17  MADRE DE DIOS  PUERTO MALDONADO    7.023854
# 17          21      18.0   18       MOQUEGUA          MOQUEGUA    1.334888
# 18          22      19.0   19          PASCO    CERRO DE PASCO    1.972864
# 19          23      20.0   20          PIURA             PIURA    2.899223
# 20          24      21.0   21           PUNO              PUNO    5.666684
# 21          31      22.0   22     SAN MARTIN         MOYOBAMBA    4.174664
# 22          32      23.0   23          TACNA             TACNA    1.362022
# 23          33      24.0   24         TUMBES            TUMBES    0.378757
# 24          34      25.0   25        UCAYALI          PUCALLPA    8.660111
#
#     Shape_STLe  ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0    12.912088         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1    11.780424         1   11.780424    2.954592  juan.suyo@geogpsperu.com
# 2     7.730154         2    7.730154    1.765933  juan.suyo@geogpsperu.com
# 3    17.405040         3   17.405040    5.330203  juan.suyo@geogpsperu.com
# 4    17.127166         4   17.127166    3.643705  juan.suyo@geogpsperu.com
# 5    12.397424         5   12.397424    2.684527  juan.suyo@geogpsperu.com
# 6     1.111221         6    1.111221    0.011738  juan.suyo@geogpsperu.com
# 7    21.794434         7   21.794434    6.000331  juan.suyo@geogpsperu.com
# 8     9.561245         8    9.561245    1.839851  juan.suyo@geogpsperu.com
# 9    14.589840         9   14.589840    3.089811  juan.suyo@geogpsperu.com
# 10   10.374368        10   10.374368    1.767025  juan.suyo@geogpsperu.com
# 11   14.314727        11   14.314727    3.658881  juan.suyo@geogpsperu.com
# 12   13.148266        12   13.148266    2.068780  juan.suyo@geogpsperu.com
# 13    6.685351        13    6.685351    1.184994  juan.suyo@geogpsperu.com
# 14   12.745226        14   12.745226    2.904475  juan.suyo@geogpsperu.com
# 15   46.701789        15   46.701789   30.550256  juan.suyo@geogpsperu.com
# 16   15.416397        16   15.416397    7.023854  juan.suyo@geogpsperu.com
# 17    7.720424        17    7.720424    1.334888  juan.suyo@geogpsperu.com
# 18   10.891698        18   10.891698    1.972864  juan.suyo@geogpsperu.com
# 19   11.299471        19   11.299471    2.899223  juan.suyo@geogpsperu.com
# 20   26.709721        20   26.709721    5.666684  juan.suyo@geogpsperu.com
# 21   16.162954        21   16.162954    4.174664  juan.suyo@geogpsperu.com
# 22    6.088704        22    6.088704    1.362022  juan.suyo@geogpsperu.com
# 23    3.787977        23    3.787977    0.378757  juan.suyo@geogpsperu.com
# 24   27.470159        24   27.470159    8.660111  juan.suyo@geogpsperu.com
#
#               CONTACTO   WHATSAPP  \
# 0   www.geogpsperu.com  931381206
# 1   www.geogpsperu.com  931381206
# 2   www.geogpsperu.com  931381206
# 3   www.geogpsperu.com  931381206
# 4   www.geogpsperu.com  931381206
# 5   www.geogpsperu.com  931381206
# 6   www.geogpsperu.com  931381206
# 7   www.geogpsperu.com  931381206
# 8   www.geogpsperu.com  931381206
# 9   www.geogpsperu.com  931381206
# 10  www.geogpsperu.com  931381206
# 11  www.geogpsperu.com  931381206
# 12  www.geogpsperu.com  931381206
# 13  www.geogpsperu.com  931381206
# 14  www.geogpsperu.com  931381206
# 15  www.geogpsperu.com  931381206
# 16  www.geogpsperu.com  931381206
# 17  www.geogpsperu.com  931381206
# 18  www.geogpsperu.com  931381206
# 19  www.geogpsperu.com  931381206
# 20  www.geogpsperu.com  931381206
# 21  www.geogpsperu.com  931381206
# 22  www.geogpsperu.com  931381206
# 23  www.geogpsperu.com  931381206
# 24  www.geogpsperu.com  931381206
#
#                                              geometry  ltimoden_metaatencion  \
# 0   POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...                   1213
# 1   POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...                   2969
# 2   POLYGON ((-73.74655 -13.17442, -73.74570 -13.1...                   1647
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...                   3000
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...                   3107
# 5   POLYGON ((-78.22182 -7.76346, -78.22233 -7.763...                   5943
# 6   POLYGON ((-77.13504 -11.81820, -77.13484 -11.8...                    780
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...                   6441
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...                    705
# 9   POLYGON ((-75.99200 -8.32108, -75.99015 -8.321...                   1599
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...                   2882
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...                   4864
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...                   5708
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...                   2671
# 14  MULTIPOLYGON (((-76.79732 -12.47686, -76.79732...                  20885
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...                   2106
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...                    292
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...                    508
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...                    802
# 19  POLYGON ((-81.02621 -4.10594, -81.02557 -4.106...                   1010
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...                   4455
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...                   1747
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...                    846
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...                    390
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...                    907
#
#     cuentadeid_postulante_procesoadm  sumaden_flagingresante  \
# 0                               1346                     925
# 1                               4007                    2535
# 2                               2997                    1506
# 3                               2829                    1976
# 4                               3824                    2406
# 5                               7744                    5104
# 6                                589                     509
# 7                               6575                    4758
# 8                               1694                     705
# 9                               2360                    1482
# 10                              1451                    1248
# 11                              4042                    3075
# 12                              4387                    3230
# 13                              1936                    1769
# 14                              9159                    7847
# 15                              3249                    1841
# 16                               307                     257
# 17                               566                     452
# 18                               964                     692
# 19                              1094                     759
# 20                              5114                    2904
# 21                              2327                    1660
# 22                               887                     667
# 23                               483                     336
# 24                              1200                     754
#
#     sumaden_flagmatriculado
# 0                       917
# 1                      2501
# 2                      1506
# 3                      1941
# 4                      2374
# 5                      5068
# 6                       506
# 7                      4694
# 8                       646
# 9                      1463
# 10                     1199
# 11                     2945
# 12                     3132
# 13                     1752
# 14                     6832
# 15                     1709
# 16                      266
# 17                      431
# 18                      680
# 19                      755
# 20                     2798
# 21                     1649
# 22                      662
# 23                      223
# 24                      744

# %% [markdown]
# # 2. Make an interactive map of markes using visual_html function and show total vacancies, applicants, entrants, and enrolled information in a table popup

# %%
pip install folium
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/18/09/8569904c8ce5679cc02826d98de633c07abcd2443a23181e5f71ff9dacbc/folium-0.15.1-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/17/ce/14166d0e273d12065516625fb02426350298e7b4ba59198b5fe454b46202/branca-0.7.1-py3-none-any.whl.metadata
#   Downloading branca-0.7.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\carmen.remuzgo\appdata\local\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/97.0 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 97.0/97.0 kB 1.1 MB/s eta 0:00:00
# Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.1 folium-0.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
#1.  Create a base map
mapa1 = folium.Map(location=[-9.19, -75.0152], zoom_start=6)  # Coordenadas centrales de Perú

#2.  Add markers to the map.
for idx, row in institutes_with_departments.iterrows(): 
    # Crear el contenido HTML para la ventana emergente
    html_content = folium.Html(f"""
        <table>
            <tr><th>Total Vacancies:</th><td>{row['ltimoden_metaatencion']}</td></tr>
            <tr><th>Total Applicants:</th><td>{row['cuentadeid_postulante_procesoadm']}</td></tr>
            <tr><th>Total Entrants:</th><td>{row['sumaden_flagingresante']}</td></tr>
            <tr><th>Total Enrolled:</th><td>{row['sumaden_flagmatriculado']}</td></tr>
        </table>
    """, script=True)

    # Create the popup window with HTML content
    popup = folium.Popup(html_content, max_width=2650)

    # Add the marker with the popup window to the map
    folium.Marker(    #Crear un marcador para cada institución, ubicándolo en las coordenadas especificadas
        [row['nlat_ie'], row['nlong_ie']],
        popup=popup,
        icon=folium.Icon(icon='university', prefix='fa')  # Utiliza el ícono de universidad de FontAwesome
    ).add_to(mapa1)

#3. Display the map
mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a768be5a9a739961de04b6761b019135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a768be5a9a739961de04b6761b019135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a768be5a9a739961de04b6761b019135 = L.map(
#                 &quot;map_a768be5a9a739961de04b6761b019135&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5ac59d93e9f7af4f3147e2d763e957d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5ac59d93e9f7af4f3147e2d763e957d.addTo(map_a768be5a9a739961de04b6761b019135);
#
#
#             var marker_28f72fb38b4cb9f29a80ac55137c76df = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(map_a768be5a9a739961de04b6761b019135);
#
#
#             var icon_2ee644a7caece1e265cf55f0008418be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_28f72fb38b4cb9f29a80ac55137c76df.setIcon(icon_2ee644a7caece1e265cf55f0008418be);
#
#
#         var popup_255eb94c549d2df3086e0df12f7bf6e5 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_189809c46d014fd70e6716a523c663a7 = $(`&lt;div id=&quot;html_189809c46d014fd70e6716a523c663a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;307&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;481&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;302&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;301&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_255eb94c549d2df3086e0df12f7bf6e5.setContent(html_189809c46d014fd70e6716a523c663a7);
#
#
#
#         marker_28f72fb38b4cb9f29a80ac55137c76df.bindPopup(popup_255eb94c549d2df3086e0df12f7bf6e5)
#         ;
#
#
#
#
#             var marker_162872ad9c52342248e1330c7c5afc2d = L.marker(
#                 [-14.1424, -71.40813],
#                 {}
#             ).addTo(map_a768be5a9a739961de04b6761b019135);
#
#
#             var icon_06b8d90ca7168e6ddd18cc15d057c002 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_162872ad9c52342248e1330c7c5afc2d.setIcon(icon_06b8d90ca7168e6ddd18cc15d057c002);
#
#
#         var popup_c3de27e6b608cc9ed038a8626919ce77 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_13425fb433d692880a1a9f5c94c551fc = $(`&lt;div id=&quot;html_13425fb433d692880a1a9f5c94c551fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;table&gt;             &lt;tr&gt;&lt;th&gt;Total Vacancies:&lt;/th&gt;&lt;td&gt;516&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Applicants:&lt;/th&gt;&lt;td&gt;1047&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Entrants:&lt;/th&gt;&lt;td&gt;515&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;th&gt;Total Enrolled:&lt;/th&gt;&lt;td&gt;544&lt;/td&gt;&lt;/tr&gt;         &lt;/table&gt;     &lt;/div&gt;`)[0];
#                 popup_c3de27e6b608cc9ed038a8626919ce77.setContent(html_13425fb433d692880a1a9f5c94c551fc);
#
#
#
#         marker_162872ad9c52342248e1330c7c5afc2d.bindPopup(popup_c3de27e6b608cc9ed038a8626919ce77)
#         ;
#
#
#
#
#             var marker_518e4462c3f76b59ec3d3867375fca9f = L.marker(
#                 [-13.30178, -72.12163],
#                 {}
#             ).addTo(map_a768be5a9a739961de04b6761b019135);
#
#
#             var icon_31d425cc79d1c903ff80d4820e51f65e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_518e4462c3f76b59ec3d3867375fca9f.setIcon(icon_31d425cc79d1c903ff80d4820e51f65e);
#
#
#         var popup_e7c752bdd34803bba9fe765576bdc4ae = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var html_628499613b13243c2b7ff4c04d415a79 = $(`&lt;div id=&quot;html_628499613b13243c2b7ff4c04d415a79&quot; style=&quo

# %% [markdown]
# ### 3. Generate the ratio of applicants by vacancies and store it in a new column called ratio_applicants_vacancies ( total applicants / total vacancies ).

# %%
import folium
from folium.plugins import MarkerCluster

# %%
institutes_with_departments['ratio_applicants_vacancies'] = (
    institutes_with_departments['cuentadeid_postulante_procesoadm'] /
    institutes_with_departments['ltimoden_metaatencion']
)

institutes_with_departments.columns.tolist() #We see that we have created the desired column "Ratio_applicants_vacancies"
# Out:
# ['cod_mod',
#  'ltimoden_metaatencion',
#  'cuentadeid_postulante_procesoadm',
#  'sumaden_flagingresante',
#  'sumaden_flagmatriculado',
#  'ratio',
#  'ratio1',
#  'dif',
#  'dif1',
#  'nlat_ie',
#  'nlong_ie',
#  'population_ccpp',
#  'altitude',
#  'Dblock1km',
#  'Dblock2km',
#  'Dblock3km',
#  'Dblock5km',
#  'Dblock10km',
#  'Dblock20km',
#  'Dblock30km',
#  '_merge',
#  'OBJECTID_1',
#  'OBJECTID',
#  'CCDD',
#  'NOMBDEP',
#  'CAPITAL',
#  'Shape_STAr',
#  'Shape_STLe',
#  'ORIG_FID',
#  'Shape_Leng',
#  'Shape_Area',
#  'CORREO',
#  'CONTACTO',
#  'WHATSAPP',
#  'geometry',
#  'ratio_applicants_vacancies']

# %% [markdown]
# ### 3.1. Then, generate a cluster map with two groups of marker clusters.
#
# The first group should be compound by those institutes where there were more applicants than vacancies. Name this group as **Applicant Surplus**. The second group should be compound by those institutes where there were more vacancies than applicants. Name this group as **Applicant Deficit**

# %%
#Create a base map 
mapa = folium.Map(location=[-9.19, -75.0152], zoom_start=6)

# Crear clusters de marcadores
surplus_cluster = MarkerCluster(name='Applicant Surplus').add_to(mapa)
deficit_cluster = MarkerCluster(name='Applicant Deficit').add_to(mapa)

# Iterar sobre el DataFrame y añadir los marcadores a los clusters correspondientes
for idx, row in institutes_with_departments.iterrows():
    if row['ratio_applicants_vacancies'] > 1:
        # Más solicitantes que vacantes
        folium.Marker(
            location=[row['nlat_ie'], row['nlong_ie']],
            popup=f"Surplus: {row['ratio_applicants_vacancies']}",
            icon=folium.Icon(color='red')
        ).add_to(surplus_cluster)
    else:
        # Más vacantes que solicitantes
        folium.Marker(
            location=[row['nlat_ie'], row['nlong_ie']],
            popup=f"Deficit: {row['ratio_applicants_vacancies']}",
            icon=folium.Icon(color='green')
        ).add_to(deficit_cluster)

# Añadir capas de control para alternar la visualización de los clusters
folium.LayerControl().add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7f8b57d56c4b8de9e342f68fc713aae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7f8b57d56c4b8de9e342f68fc713aae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7f8b57d56c4b8de9e342f68fc713aae = L.map(
#                 &quot;map_b7f8b57d56c4b8de9e342f68fc713aae&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9caca47d802b9b0e92196699937f95af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9caca47d802b9b0e92196699937f95af.addTo(map_b7f8b57d56c4b8de9e342f68fc713aae);
#
#
#             var marker_cluster_71f8c5ae84780cfced8ced83a7cd9677 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_d9774fad87fe62d7580d502e96600417 = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(marker_cluster_71f8c5ae84780cfced8ced83a7cd9677);
#
#
#             var icon_6dc972a2bb25277f787abb201bb7182a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9774fad87fe62d7580d502e96600417.setIcon(icon_6dc972a2bb25277f787abb201bb7182a);
#
#
#         var popup_a5e398475d9c8e3f6535f7564af6f8f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db545ada1cb1e2ce194a480154ae8c3b = $(`&lt;div id=&quot;html_db545ada1cb1e2ce194a480154ae8c3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 1.5667752442996743&lt;/div&gt;`)[0];
#                 popup_a5e398475d9c8e3f6535f7564af6f8f4.setContent(html_db545ada1cb1e2ce194a480154ae8c3b);
#
#
#
#         marker_d9774fad87fe62d7580d502e96600417.bindPopup(popup_a5e398475d9c8e3f6535f7564af6f8f4)
#         ;
#
#
#
#
#             var marker_6ee85deacab5cfb2cd464943c0028b15 = L.marker(
#                 [-14.1424, -71.40813],
#                 {}
#             ).addTo(marker_cluster_71f8c5ae84780cfced8ced83a7cd9677);
#
#
#             var icon_0cb0478c122ee35127f77bb7ded505e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ee85deacab5cfb2cd464943c0028b15.setIcon(icon_0cb0478c122ee35127f77bb7ded505e2);
#
#
#         var popup_94bc16c28e575c0774e20bc45dc61be4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_562a65db4eb65f620c77989318e90151 = $(`&lt;div id=&quot;html_562a65db4eb65f620c77989318e90151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 2.0290697674418605&lt;/div&gt;`)[0];
#                 popup_94bc16c28e575c0774e20bc45dc61be4.setContent(html_562a65db4eb65f620c77989318e90151);
#
#
#
#         marker_6ee85deacab5cfb2cd464943c0028b15.bindPopup(popup_94bc16c28e575c0774e20bc45dc61be4)
#         ;
#
#
#
#
#             var marker_a65aa0b195f9764c15f6f46ca8f4b283 = L.marker(
#                 [-13.30178, -72.12163],
#                 {}
#             ).addTo(marker_cluster_71f8c5ae84780cfced8ced83a7cd9677);
#
#
#             var icon_e3df9e878866b5a175fcc8d359854f52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a65aa0b195f9764c15f6f46ca8f4b283.setIcon(icon_e3df9e878866b5a175fcc8d359854f52);
#
#
#         var popup_1778471b6ff524bde6e11f51d51565f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0eaf22910d15d05a34caa0a85b769fd = $(`&lt;div id=&quot;html_b0eaf22910d15d05a34caa0a85b769fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Surplus: 1.65&lt;/div&gt;`)[0];
#                 popup_1778471b6ff524bde6e11f51d51565f2.setContent(h

# %% [markdown]
# # 4. Generate a Circle map and plot only institutes with more applicants than vacancies. Make the radius= *ratio_applicants_vacancies* * 10000 . Make these circles of color green. Name the layer of circles as Applicant Surplus. Use FeatureGroup
# Take this map as an example

# %%
# Filtering institutes with more applicants than vacancies and storing the result in 'applicant_surplus_data'
applicant_surplus_data= institutes_with_departments[institutes_with_departments['ratio_applicants_vacancies']>1]

# Displaying the first three rows of the filtered data
applicant_surplus_data.head(3)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   586669                    516                              1047
# 2   591909                    180                               297
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     515                      544  1.054264  2.029070   28
# 2                     169                      169  0.938889  1.650000  -11
#
#    dif1   nlat_ie  ...  Shape_STAr  Shape_STLe  ORIG_FID  Shape_Leng  \
# 0   174 -13.52107  ...    6.000331   21.794434         7   21.794434
# 1   531 -14.14240  ...    6.000331   21.794434         7   21.794434
# 2   117 -13.30178  ...    6.000331   21.794434         7   21.794434
#
#    Shape_Area                    CORREO            CONTACTO   WHATSAPP  \
# 0    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 1    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
# 2    6.000331  juan.suyo@geogpsperu.com  www.geogpsperu.com  931381206
#
#                       geometry  ratio_applicants_vacancies
# 0  POINT (-71.97748 -13.52107)                    1.566775
# 1  POINT (-71.40813 -14.14240)                    2.029070
# 2  POINT (-72.12163 -13.30178)                    1.650000
#
# [3 rows x 36 columns]

# %%
# Creating a Circle Map for Applicant Surplus centered on Peru
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

# Creating a FeatureGroup for Applicant Surplus with control enabled
ap_s = folium.FeatureGroup(name='Applicant Surplus', control=True)

# Iterating over the DataFrame to add circles representing institutes with more applicants than vacancies
for _, row in applicant_surplus_data.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#4da170",
                  color="#4da170").add_to(ap_s)
    
# Adding the Applicant Surplus FeatureGroup to the map
ap_s.add_to(mapa)  

# Adding layer control to the map
folium.LayerControl().add_to(mapa)  

# Displaying the map
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce664e98694b689340b63f562b6edff9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce664e98694b689340b63f562b6edff9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce664e98694b689340b63f562b6edff9 = L.map(
#                 &quot;map_ce664e98694b689340b63f562b6edff9&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52ac1a395b2be11ed6550f0d0a3ed85f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_52ac1a395b2be11ed6550f0d0a3ed85f.addTo(map_ce664e98694b689340b63f562b6edff9);
#
#
#             var feature_group_7dac91df42ad6e68eb22849505a7269b = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_a5dc38dd210cd398426a3eec119b7873 = L.circle(
#                 [-13.52107, -71.97748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15667.752442996743, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7dac91df42ad6e68eb22849505a7269b);
#
#
#             var circle_4ca397cc4a5de55ae5e716d3dc5388b8 = L.circle(
#                 [-14.1424, -71.40813],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20290.697674418607, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7dac91df42ad6e68eb22849505a7269b);
#
#
#             var circle_3665f04e24f8464cbdcd4093ff146aed = L.circle(
#                 [-13.30178, -72.12163],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16500.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7dac91df42ad6e68eb22849505a7269b);
#
#
#             var circle_b24d87025c9a8cef1a444883d6481c93 = L.circle(
#                 [-14.28296, -71.22042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18363.636363636364, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7dac91df42ad6e68eb22849505a7269b);
#
#
#             var circle_3a8bdaefda0adcae34ff2dc90e8ba86f = L.circle(
#                 [-13.51273, -71.97511],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10621.11801242236, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7dac91df42ad6e68eb22849505a7269b);
#
#
#             var circle_83e98cbf28061bef4a82eaa959e323d8 = L.circle(
#                 [-13.2565, -71.6239],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14842.105263157895, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(fea

# %% [markdown]
# # 5

# %% [markdown]
# # 6
